# %%
import pandas as pd

# Open csv, skip first 3 rows
df = pd.read_csv("Candidates.csv",delimiter='\t')
print(df)

#Code to get the required skills from Criteria text

to_find = "Required skills" #define search term

with open("AdmissionsCriteria.txt") as a_file:
    for line in a_file:
        if to_find in line:
                required_skills = line
                print("\nSkills to look for in an applicant:", required_skills*1, sep="\n") # *1 to print once

# Creating a container to hold list of recommendations
recommended_candidate = []

apps_subset = df['Applications']
Cands = df['Candidate']
others = ['r','programming','python','algebra','analytical','math','troubleshoot','errors','analytical','computer','communicate','java','c++']
#Set count to zero to count recommendations
count=0
#Loop to traverse through csv column 'Applications' and return applicants
for f in apps_subset:

    App = open("{}.txt".format(f), "r")
    lines = App.read()
    skills_of_applicant = lines.split(' ')

    number_of_found_skills = 0

    for skill in skills_of_applicant:
        if skill.strip() in required_skills and skill.strip().lower() in others:
            number_of_found_skills += 1 #applicant has atleast 2 skills

    if number_of_found_skills >=2: #applicant has atleast 3 required skills
        count += 1
        print(f,"\nRecommended Candidate", count,":")
        print(lines, sep="\n")
# Out:
#                Candidate Applications
# 0     Annita Goode-Grade         App1
# 1             Jane Jones         App2
# 2             David John         App3
# 3         Prishna Vandhi         App4
# 4         Danni Espinoza         App5
# 5            Jack London         App6
# 6      Precious Williams         App7
# 7          Michael Tires         App8
# 8             Luke Locke         App9
# 9           Brandy Mason        App10
# 10           Jaxon Lopez        App11
# 11    Christopher Knight        App12
# 12               Xiu Xia        App13
# 13  Ferdinand Macapagal         App14
# 14      Dashell Williams        App15
#
# Skills to look for in an applicant:
# Required skills: Programming proficiency/programming experience in a high-level language such as R or Python analytical thinking advanced math ability to troubleshoot complicated errors strong analytical thinking high level of quantitative ability working knowledge of fundamental computer concepts ability to communicate effectively
#
# App1
# Recommended Candidate 1 :
# Annita Goode-Grade, Term: Fall 2022, 4.0, Job: secretary, Degree: Associates Major: Criminal Justice Univeristy: University of the California San Jose, Extra Curricular: Volunteer work for non-profit, Accessing Resources with Crime Data Adapting to Changing Circumstances
# Policy Analyzing Societal and Economic Factors Contributing to Crime Ethics Assessing Models for Correctional Facilities Compliance Adherence to Safety Standards Problem Sensitivity. Additional activities/passions/hobbies: I am a TikTok star and produce content on the daily. My dream is to be come nationally known and endorsed by major companies.
# Skills: typing, computer skills, phone skills, ability to troubleshoot
# App2
# Recommended Candidate 2 :
# Jane Jones, 3.7, Full-time student, Business Administration, University of the Pacific, Volleyball Horse Back Riding, Technology skills Administrative skills Interpersonal skills Critical thinking
# Communication skills Active listening Public speaking Attention to detail
# Required Skills: ability to troubleshoot problems programming experience in C++ experience with python experience in linear algebra Google Analytics marketing and business development
# App3
# Recommended Candidate 3 :
# David John 2.7 full-time student Computer Science Sacramento State University Archery Gaming Coding Attention to detail IT experience attention to detail Creativity Communication
# Time management Teamwork & cooperation Analysis Organization Training and teaching My passions are horse back riding and helping people in need
# Required skills Python C++ Java troubleshooting Macine learning analytical thinking advanced math ability to troubleshoot complicated errors strong communicate skills
# App6
# Recommended Candidate 4 :
# Jack London 4.0 Data Analayst Data Analysis Tennesee State University graphic design NFT Skills: Programming in Python R C++ Java analytical thinking and experience fixing code errors advanced math ability to troubleshoot complicated errors, knowledge of fundamental computer mechanisms, exceelent leadership skipps
#
#
#
#
# App8
# Recommended Candidate 5 :
# Michael Tires 4.0 Scientist Molecular Biology Harvard University programming experience in high-level language C++ analytical thinking 6 years of experience working as a high-school Biology teacher my greatest skill patience and the ability to learn quickly
#
# App10
# Recommended Candidate 6 :
# Brandy Mason GPA: 4.0 IT Manager Certificate of Completion Devry University More than 10 years of experience planning directing and overseeing activities dealing with a company's computer and information systems Extra curricular: I run a computer repair shop.
#
#
#
# App12
# Recommended Candidate 7 :
# Christopher Knight 2.5 English teacher Degree: Philosophy University: Michigan State I have 10+ years as an English teacher But in my spare time I've studied computer programming and analytics I have a strong troubleshooting skills and can debug most code errors I am also a member of my local community center where I volunteer to teach seniors how to safely use computers.
#
# App13
# Recommended Candidate 8 :
# Xiu Xiau GPA: 4.0 Graduate studies: Physics University: Princeton University Programming Skills: I have several years of experience programming in a high-level languages including C++ R Python Java Javascript I have many years of experience with advanced math such as statistics linear algebra and calculus I also have many years of experience working in the field of AI research My extra curricular activities include triathalons and being president of my university's science and math clubs
#
#
# App14
# Recommended Candidate 9 :
# Ferdinand Macapagal GPA 3.9 Degree: Robotics University: MIT More than 2 years of experience with computer coding advanced robotics systems and artificial intelligent robotics engineering and software programming using Java high elvel language Extra curricular activites include competeing in robotics engineering competitions worldwide
