# %%
# import os.path
# import shutil
# import json
# import mymodule as md
# BASIC_CONFIG_PATH = 'text_files/basic_config.json'
# OVERWRITTEN_CONFIG_PATH = 'text_files/config_override.json'
# path = BASIC_CONFIG_PATH
        
# def main():
#     if os.path.exists(OVERWRITTEN_CONFIG_PATH):
#         path = OVERWRITTEN_CONFIG_PATH   
#     data = md.read(path)
#     md.display(data)
#     data = md.edit_config(data)
#     md.save(data,path)
    
# if __name__ == '__main__':
#     main()

# %%
import os.path
import shutil
import json
from Functions import read,save,edit_config,display

BASIC_CONFIG_PATH = 'text_files/basic_config.json'
OVERWRITTEN_CONFIG_PATH = 'text_files/config_override.json'
path = BASIC_CONFIG_PATH
        
def main():
    if os.path.exists(OVERWRITTEN_CONFIG_PATH):
        path = OVERWRITTEN_CONFIG_PATH   
    data = read.read(path)
    display.display(data)
    data = edit_config.edit_config(data)
    save.save(data,path)
    
if __name__ == '__main__':
    main()
# Out:
# #1. Safe Mode - "On"
# #2. Memory - "32MB"
# #3. Error logs - "logs/errors.log"
# #4. Allow File Uploads - "Yes"
# #5. Mail Host - "eee"
#
# Make your selection what you want to do
# #1 Add
# #2 Modify
# #3 Delete
# Type your choice (in numeric): 1
# Enter a variable name: hahaha
# Enter the value: aaaa
#
# The final configurations are:
# #1. Safe Mode - "On"
# #2. Memory - "32MB"
# #3. Error logs - "logs/errors.log"
# #4. Allow File Uploads - "Yes"
# #5. Mail Host - "eee"
# #6. hahaha - "aaaa"
# Do you want to continue Add/Modify/Delete y/n: y
#
# Make your selection what you want to do
# #1 Add
# #2 Modify
# #3 Delete
# Type your choice (in numeric): 3
# Enter the sequence no to Delete: 6
# Entry for Sequence 6 deleted
#
# The final configurations are:
# #1. Safe Mode - "On"
# #2. Memory - "32MB"
# #3. Error logs - "logs/errors.log"
# #4. Allow File Uploads - "Yes"
# #5. Mail Host - "eee"
# Do you want to continue Add/Modify/Delete y/n: y
#
# Make your selection what you want to do
# #1 Add
# #2 Modify
# #3 Delete
# Type your choice (in numeric): 3
# Enter the sequence no to Delete: 5
# Entry for Sequence 5 deleted
#
# The final configurations are:
# #1. Safe Mode - "On"
# #2. Memory - "32MB"
# #3. Error logs - "logs/errors.log"
# #4. Allow File Uploads - "Yes"
# Do you want to continue Add/Modify/Delete y/n: n
#
# The final configurations are:
# #1. Safe Mode - "On"
# #2. Memory - "32MB"
# #3. Error logs - "logs/errors.log"
# #4. Allow File Uploads - "Yes"
# Enter 1 to save or any other number to discard: 1
# Backup is created.
# Configurations has been saved Successfully as config_override.json
