# %%
import pandas as pd

# %%
df1 = pd.read_csv("new1.csv")
df2 = pd.read_csv("PatientLevelData.csv")

# %%
df1
# Out:
#       Unnamed: 0   SURVEY_ID  CLIENT_ID SERVICE     RECDATE     DISDATE  \
# 0              0   730056639      17291      OY  2020-04-03  2020-02-14
# 1              1   730056639      17291      OY  2020-04-03  2020-02-14
# 2              2   730056639      17291      OY  2020-04-03  2020-02-14
# 3              3   730056639      17291      OY  2020-04-03  2020-02-14
# 4              4   730056639      17291      OY  2020-04-03  2020-02-14
# ...          ...         ...        ...     ...         ...         ...
# 1693          38  2319035452        749      OU  2020-06-30  2020-06-15
# 1694          39  2319035452        749      OU  2020-06-30  2020-06-15
# 1695          40  2319035452        749      OU  2020-06-30  2020-06-15
# 1696          41  2319035452        749      OU  2020-06-30  2020-06-15
# 1697          42  2319035452        749      OU  2020-06-30  2020-06-15
#
#      analysis_varname  analysis_value demographics_varname demographics_value  \
# ...

# %%
df2
# Out:
#       Unnamed: 0   SURVEY_ID  CLIENT_ID SERVICE     RECDATE     DISDATE  \
# 0              0   730056639      17291      OY  2020-04-03  2020-02-14
# 1              1   730056639      17291      OY  2020-04-03  2020-02-14
# 2              2   730056639      17291      OY  2020-04-03  2020-02-14
# 3              3   730056639      17291      OY  2020-04-03  2020-02-14
# 4              4   730056639      17291      OY  2020-04-03  2020-02-14
# ...          ...         ...        ...     ...         ...         ...
# 1693          38  2319035452        749      OU  2020-06-30  2020-06-15
# 1694          39  2319035452        749      OU  2020-06-30  2020-06-15
# 1695          40  2319035452        749      OU  2020-06-30  2020-06-15
# 1696          41  2319035452        749      OU  2020-06-30  2020-06-15
# 1697          42  2319035452        749      OU  2020-06-30  2020-06-15
#
#      analysis_varname  analysis_value demographics_varname demographics_value  \
# ...

# %%
df_diff = pd.concat([df1,df2]).drop_duplicates(keep=False)

# %%
df_diff.shape
# Out:
# (10, 20)
