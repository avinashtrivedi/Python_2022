# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "https://philchodrow.github.io/PIC16A/datasets/gapminder.csv"
gapminder = pd.read_csv(url)

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
def f(x):
    continent = x.continent.iloc[0]
    x.plot(x="year",y="lifeExp",legend = False,ax=cont_axes[continent],title=continent,color=color[continent])

color = {'Asia':'blue','Africa':'green','Europe':'red','Americas':'yellow','Oceania':'black'}

# %%
fig, axes = plt.subplots(nrows=1, ncols=5)
fig.set_figheight(3.75)
fig.set_figwidth(20)

cont_axes = {'Asia':axes[0],'Africa':axes[2],'Europe':axes[1],'Americas':axes[3],'Oceania':axes[4]}

p = gapminder.groupby(['country']).apply(f)

# %%
import os

# %%
os.cpu_count()
# Out:
# 8

# %%
n_jobs = 3
