# %%
import pandas as pd

# %%
df = pd.read_csv('news_articles (1).csv')

# %%
df.head().T
# Out:
#                                                                          0  \
# author                                                   Barracuda Brigade
# published                                    2016-10-26T21:41:00.000+03:00
# title                    muslims busted they stole millions in govt ben...
# text                     print they should pay all the back all the mon...
# language                                                           english
# site_url                                               100percentfedup.com
# main_img_url             http://bb4sp.com/wp-content/uploads/2016/10/Fu...
# type                                                                  bias
# label                                                                 Real
# title_without_stopwords        muslims busted stole millions govt benefits
# text_without_stopwords   print pay back money plus interest entire fami...
# ...
