# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\OneDrive - NITT\Custom_Download\titanic.csv")

# %% [markdown]
# a. Create a scatterplot using the "titanic.csv" data that displays "Age" on the X axis, "Fare" on the Y axis, and the points by Sex.
#
#     b. Change the scatterplot inputs so that "Pclass" is on the X axis, and "Age" is on the Y axis.  Explain why the scatterplot looks the way that it does.
#
#     c. Change the inputs back to Age v. Fare by Sex, and add a trend line.  What does the trend line tell you?
#
#     d. Now, try using lmplot to draw multiple trend lines by input.  What do the trend lines tell you now?

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Q1

# %%
import seaborn as sns

# %%
sns.scatterplot(df['Age'],df['Fare'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# q2

# %%
sns.scatterplot(df['Pclass'],df['Age'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
# Q3

# %%
df_male = df[df['Sex']=='male']
df_female = df[df['Sex']=='female']

# %%
sns.lineplot(df_male['Age'],df_male['Fare'],color='r',label='male')
sns.lineplot(df_female['Age'],df_female['Fare'],color='g',label='female')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# Q4

# %%
sns.lmplot(x="Age", y="Fare", data=df)
sns.lmplot(x="Age", y="Pclass", data=df)

# %% [markdown]
# First, import pandas and sqlalchemy, then create a connection to the course database with the following connection string:
#
#
#
#     server="bus312.cx8ahe0jsec5.us-east-1.rds.amazonaws.com/"
#
#     db_name="world"
#
#     user_name="BUS312"
#
#     password="Longyuan0558"
#
#
#
#     engine_url="mysql+pymysql://"+user_name+":"+password+"@"+server+db_name
#
#
#
#     engine_url
#
#
#
#     db=sqla.create_engine(engine_url)
#
#
#
# (cont'd) Next, write an embedded SQL query within the pandas function "read_sql" that returns the names of all of the continents.
#
#     a. Now, write an embedded SQL query that returns the names of all of the cities within all of the countries in South America along with the population of each city.
#
#     b. Next, create a Python list of 10 of the cities from the query result above.
#
#     c. Then, create a function that is passed in as a parameter to SQL query that cycles through each city name and returns all of the information from the "city" table about each of the cities.

# %%
import pandas as pd
import sqlalchemy as sqla

# %%
server="bus312.cx8ahe0jsec5.us-east-1.rds.amazonaws.com/"
db_name="world"
user_name="BUS312"
password="Longyuan0558"
engine_url="mysql+pymysql://"+user_name+":"+password+"@"+server+db_name
db=sqla.create_engine(engine_url)

# %%
db

# %%
pd.read_sql("select * from city", db)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File ~\anaconda3\lib\socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
#     846     # Break explicitly a reference cycle
#
# File ~\anaconda3\lib\socket.py:832, in create_connection(address, timeout, source_address)
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# ...
