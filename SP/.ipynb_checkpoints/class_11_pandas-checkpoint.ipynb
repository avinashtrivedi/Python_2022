# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[9,11,12]],columns= ['A','B','C'])

# %%
df
# Out:
#    A   B   C
# 0  1   2   3
# 1  4   5   6
# 2  9  11  12

# %%
pd.DataFrame([[1,2,3],[4,5,6],[9,11,12]],columns= ['A','B','C'],index=['a','b','c'])
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
list(df)
# Out:
# ['A', 'B', 'C']

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# C    int64
# dtype: object

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df['A']
# Out:
# a    1
# b    4
# c    9
# Name: A, dtype: int64

# %%
df[['A','B']]
# Out:
#    A   B
# a  1   2
# b  4   5
# c  9  11

# %%
df[['A','B']]
# Out:
#    A   B
# a  1   2
# b  4   5
# c  9  11

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
list(df)
# Out:
# ['A', 'B', 'C']

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df.A
# Out:
# a    1
# b    4
# c    9
# Name: A, dtype: int64

# %%
df['A']
# Out:
# a    1
# b    4
# c    9
# Name: A, dtype: int64

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df[:]
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df[:2]
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6

# %%
df[:1]
# Out:
#    A  B  C
# a  1  2  3

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df.loc['a']
# Out:
# A    1
# B    2
# C    3
# Name: a, dtype: int64

# %%
df['A']
# Out:
# a    1
# b    4
# c    9
# Name: A, dtype: int64

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df.loc[['b','c']]
# Out:
#    A   B   C
# b  4   5   6
# c  9  11  12

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df.iloc[1:,1:]
# Out:
#     B   C
# b   5   6
# c  11  12

# %%
df
# Out:
#    A   B   C
# a  1   2   3
# b  4   5   6
# c  9  11  12

# %%
df.iloc[:2,1:]
# Out:
#    B  C
# a  2  3
# b  5  6

# %%
df = pd.read_csv('demoaccts.csv')

# %%
df.columns
# Out:
# Index(['acctid', 'repid', 'repname', 'name', 'acctname', 'value', 'model',
#        'profile', 'opened', 'e-mail', 'phone', 'dob', '1mo', '1yr', '3yr',
#        'ytd', 'inception'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=58, step=1)

# %%
df
# Out:
#        acctid repid        repname               name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL         JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL        JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL      SHARON HARRIS  Taxable   629922.90
# 3   903684690  AR4K  ABC FINANCIAL          LORI NEAL  Taxable     3014.71
# 4   906520600  AR4K  ABC FINANCIAL        NEAL NAVARO  Taxable   405784.14
# 5   908223080  AR4K  ABC FINANCIAL          JANET ROW  Taxable    22509.45
# 6   911032842  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    109937.24
# 7   911954714  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    845273.56
# 8   911955318  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA     88155.54
# 9   912052187  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       318.66
# 10  912052563  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       337.60
# ...

# %%
df['e-mail']
# Out:
# 0     client@gmail.com
# 1     client@gmail.com
# 2     client@gmail.com
# 3     client@gmail.com
# 4     client@gmail.com
# 5     client@gmail.com
# 6     client@gmail.com
# 7     client@gmail.com
# 8     client@gmail.com
# 9     client@gmail.com
# 10    client@gmail.com
# 11    client@gmail.com
# 12    client@gmail.com
# 13    client@gmail.com
# 14    client@gmail.com
# 15    client@gmail.com
# 16    client@gmail.com
# 17    client@gmail.com
# 18    client@gmail.com
# 19    client@gmail.com
# 20    client@gmail.com
# 21    client@gmail.com
# 22    client@gmail.com
# 23    client@gmail.com
# 24    client@gmail.com
# 25    client@gmail.com
# 26    client@gmail.com
# 27    client@gmail.com
# 28    client@gmail.com
# 29    client@gmail.com
# 30    client@gmail.com
# 31    client@gmail.com
# 32    client@gmail.com
# 33    client@gmail.com
# 34    client@gmail.com
# 35    client@gmail.com
# 36    client@gmail.com
# 37    client@gmail.com
# 38    client@gmail.com
# 39    client@gmail.com
# ...

# %%
df['acctid'].value_counts()
# Out:
# 944955520    1
# 945914460    1
# 916031677    1
# 915919679    1
# 931918531    1
# 929900996    1
# 931918533    1
# 912980430    1
# 936022865    1
# 926917074    1
# 912052563    1
# 901783640    1
# 962964430    1
# 912052187    1
# 917017821    1
# 944931330    1
# 929901023    1
# 962964450    1
# 908223080    1
# 942611945    1
# 943569387    1
# 962964460    1
# 943569392    1
# 937050867    1
# 943569397    1
# 911955318    1
# 912976249    1
# 938006525    1
# 917935420    1
# 939153752    1
# 944336426    1
# 915919669    1
# 912970756    1
# 962964480    1
# 931004938    1
# 912971531    1
# 942561805    1
# 929900943    1
# 911032842    1
# 931004946    1
# 903684690    1
# 936947477    1
# 931000983    1
# 906520600    1
# 911954714    1
# 901835570    1
# 944336420    1
# 944336422    1
# 920954280    1
# 920954290    1
# 939937450    1
# 920938670    1
# 943866415    1
# 912975536    1
# 912059313    1
# 936022867    1
# 901122740    1
# 962956030    1
# ...

# %%
df['acctid'].unique()
# Out:
# array([901122740, 901783640, 901835570, 903684690, 906520600, 908223080,
#        911032842, 911954714, 911955318, 912052187, 912052563, 912059313,
#        912970756, 912971531, 912975536, 912976249, 912980430, 915919669,
#        915919679, 916031677, 917017821, 917935420, 920938670, 920954280,
#        920954290, 926917074, 929900943, 929900996, 929901023, 931000983,
#        931004938, 931004946, 931918531, 931918533, 936022865, 936022867,
#        936947477, 937050867, 938006525, 939153752, 939937450, 942561805,
#        942611945, 943569387, 943569392, 943569397, 943866415, 944336420,
#        944336422, 944336426, 944931330, 944955520, 945914460, 962956030,
#        962964430, 962964450, 962964460, 962964480], dtype=int64)

# %%
df['e-mail'].unique()
# Out:
# array(['client@gmail.com'], dtype=object)

# %%
df['e-mail'].value_counts()
# Out:
# client@gmail.com    58
# Name: e-mail, dtype: int64

# %%
df[['e-mail','acctid']]
# Out:
#               e-mail     acctid
# 0   client@gmail.com  901122740
# 1   client@gmail.com  901783640
# 2   client@gmail.com  901835570
# 3   client@gmail.com  903684690
# 4   client@gmail.com  906520600
# 5   client@gmail.com  908223080
# 6   client@gmail.com  911032842
# 7   client@gmail.com  911954714
# 8   client@gmail.com  911955318
# 9   client@gmail.com  912052187
# 10  client@gmail.com  912052563
# 11  client@gmail.com  912059313
# 12  client@gmail.com  912970756
# 13  client@gmail.com  912971531
# 14  client@gmail.com  912975536
# 15  client@gmail.com  912976249
# 16  client@gmail.com  912980430
# 17  client@gmail.com  915919669
# 18  client@gmail.com  915919679
# 19  client@gmail.com  916031677
# 20  client@gmail.com  917017821
# 21  client@gmail.com  917935420
# 22  client@gmail.com  920938670
# 23  client@gmail.com  920954280
# 24  client@gmail.com  920954290
# 25  client@gmail.com  926917074
# 26  client@gmail.com  929900943
# 27  client@gmail.com  929900996
# ...

# %%
df
# Out:
#        acctid repid        repname               name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL         JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL        JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL      SHARON HARRIS  Taxable   629922.90
# 3   903684690  AR4K  ABC FINANCIAL          LORI NEAL  Taxable     3014.71
# 4   906520600  AR4K  ABC FINANCIAL        NEAL NAVARO  Taxable   405784.14
# 5   908223080  AR4K  ABC FINANCIAL          JANET ROW  Taxable    22509.45
# 6   911032842  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    109937.24
# 7   911954714  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    845273.56
# 8   911955318  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA     88155.54
# 9   912052187  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       318.66
# 10  912052563  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       337.60
# ...

# %%
912970756

# %%
df[df['acctid']==912970756]
# Out:
#        acctid repid        repname           name acctname     value  \
# 12  912970756  AR4K  ABC FINANCIAL  SHANNON SHARP   ROTH    50484.26
#
#                  model   profile      opened            e-mail         phone  \
# 12  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  344 385 0325
#
#           dob    1mo     1yr    3yr    ytd inception
# 12  5/22/1977  1.10%  15.20%  9.10%  5.30%     5.30%

# %%
df['acctname'].value_counts()
# Out:
# Taxable    27
# IRA        21
# ROTH        5
# IRA         5
# Name: acctname, dtype: int64

# %%
df['acctname']
# Out:
# 0     Taxable
# 1     Taxable
# 2     Taxable
# 3     Taxable
# 4     Taxable
# 5     Taxable
# 6        IRA
# 7        IRA
# 8        IRA
# 9        IRA
# 10       IRA
# 11     ROTH
# 12     ROTH
# 13     ROTH
# 14     ROTH
# 15     ROTH
# 16        IRA
# 17        IRA
# 18        IRA
# 19        IRA
# 20        IRA
# 21        IRA
# 22        IRA
# 23        IRA
# 24        IRA
# 25        IRA
# 26        IRA
# 27        IRA
# 28        IRA
# 29        IRA
# 30        IRA
# 31        IRA
# 32        IRA
# 33        IRA
# 34        IRA
# 35        IRA
# 36        IRA
# 37    Taxable
# 38    Taxable
# 39    Taxable
# 40    Taxable
# 41    Taxable
# 42    Taxable
# 43    Taxable
# 44    Taxable
# 45    Taxable
# 46    Taxable
# 47    Taxable
# 48    Taxable
# 49    Taxable
# 50    Taxable
# 51    Taxable
# 52    Taxable
# 53    Taxable
# 54    Taxable
# 55    Taxable
# 56    Taxable
# 57    Taxable
# Name: acctname, dtype: object

# %%
df.head()
# Out:
#       acctid repid        repname           name acctname       value  \
# 0  901122740  AR4K  ABC FINANCIAL     JOHN SMITH  Taxable  1162761.59
# 1  901783640  AR4K  ABC FINANCIAL    JAMES JONES  Taxable   900455.95
# 2  901835570  AR4K  ABC FINANCIAL  SHARON HARRIS  Taxable   629922.90
# 3  903684690  AR4K  ABC FINANCIAL      LORI NEAL  Taxable     3014.71
# 4  906520600  AR4K  ABC FINANCIAL    NEAL NAVARO  Taxable   405784.14
#
#                 model   profile      opened            e-mail         phone  \
# 0  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  370 385 0325
# 1  Moderate Portfolio  Balanced  10/24/2017  client@gmail.com  358 385 0325
# 2  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  357 385 0325
# 3  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  332 385 0325
# 4  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  349 385 0325
#
#          dob    1mo    1yr    3yr    ytd inception
# ...

# %%
df.tail()
# Out:
#        acctid repid        repname           name acctname      value  \
# 53  962956030  AR4K  ABC FINANCIAL    MARIA MARSH  Taxable   10056.23
# 54  962964430  AR4K  ABC FINANCIAL    MARIA MARSH  Taxable   32562.39
# 55  962964450  AR4K  ABC FINANCIAL  NEAL WILLIAMS  Taxable  251872.26
# 56  962964460  AR4K  ABC FINANCIAL  NEAL WILLIAMS  Taxable  135274.10
# 57  962964480  AR4K  ABC FINANCIAL  NEAL WILLIAMS  Taxable   24124.61
#
#                  model   profile      opened            e-mail         phone  \
# 53  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  347 385 0325
# 54  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  348 385 0325
# 55  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  350 385 0325
# 56  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  351 385 0325
# 57  Moderate Portfolio  Balanced  10/19/2017  client@gmail.com  352 385 0325
#
#            dob    1mo     1yr     3yr     ytd inception
# ...

# %%
df
# Out:
#        acctid repid        repname               name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL         JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL        JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL      SHARON HARRIS  Taxable   629922.90
# 3   903684690  AR4K  ABC FINANCIAL          LORI NEAL  Taxable     3014.71
# 4   906520600  AR4K  ABC FINANCIAL        NEAL NAVARO  Taxable   405784.14
# 5   908223080  AR4K  ABC FINANCIAL          JANET ROW  Taxable    22509.45
# 6   911032842  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    109937.24
# 7   911954714  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    845273.56
# 8   911955318  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA     88155.54
# 9   912052187  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       318.66
# 10  912052563  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       337.60
# ...

# %%
#53295

# %%
x = df[df['acctname']=='Taxable']
x
# Out:
#        acctid repid        repname             name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL       JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL      JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL    SHARON HARRIS  Taxable   629922.90
# 3   903684690  AR4K  ABC FINANCIAL        LORI NEAL  Taxable     3014.71
# 4   906520600  AR4K  ABC FINANCIAL      NEAL NAVARO  Taxable   405784.14
# 5   908223080  AR4K  ABC FINANCIAL        JANET ROW  Taxable    22509.45
# 37  937050867  AR4K  ABC FINANCIAL      PAUL LENNON  Taxable   401974.24
# 38  938006525  AR4K  ABC FINANCIAL      PAUL LENNON  Taxable   401669.37
# 39  939153752  AR4K  ABC FINANCIAL      ROGER STARR  Taxable    53295.80
# 40  939937450  AR4K  ABC FINANCIAL      ROGER STARR  Taxable   280961.99
# 41  942561805  AR4K  ABC FINANCIAL      ROGER STARR  Taxable    15515.73
# 42  942611945  AR4K  ABC FINANCIAL  ANDREA MITCHELL  Taxable    45653.64
# ...

# %%
df.shape
# Out:
# (58, 17)

# %%
x[x['value']>= 50000]
# Out:
#        acctid repid        repname            name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL      JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL     JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL   SHARON HARRIS  Taxable   629922.90
# 4   906520600  AR4K  ABC FINANCIAL     NEAL NAVARO  Taxable   405784.14
# 37  937050867  AR4K  ABC FINANCIAL     PAUL LENNON  Taxable   401974.24
# 38  938006525  AR4K  ABC FINANCIAL     PAUL LENNON  Taxable   401669.37
# 39  939153752  AR4K  ABC FINANCIAL     ROGER STARR  Taxable    53295.80
# 40  939937450  AR4K  ABC FINANCIAL     ROGER STARR  Taxable   280961.99
# 45  943569397  AR4K  ABC FINANCIAL     DAVID ORTIZ  Taxable   173938.24
# 47  944336420  AR4K  ABC FINANCIAL      BEN HARRIS  Taxable  1321909.51
# 50  944931330  AR4K  ABC FINANCIAL  BECKY GOLDBERG  Taxable  1104473.02
# 51  944955520  AR4K  ABC FINANCIAL  BECKY GOLDBERG  Taxable   142795.59
# ...

# %%
df[(df['acctname']=='Taxable') & (df['value']>= 50000)]
# Out:
#        acctid repid        repname            name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL      JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL     JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL   SHARON HARRIS  Taxable   629922.90
# 4   906520600  AR4K  ABC FINANCIAL     NEAL NAVARO  Taxable   405784.14
# 37  937050867  AR4K  ABC FINANCIAL     PAUL LENNON  Taxable   401974.24
# 38  938006525  AR4K  ABC FINANCIAL     PAUL LENNON  Taxable   401669.37
# 39  939153752  AR4K  ABC FINANCIAL     ROGER STARR  Taxable    53295.80
# 40  939937450  AR4K  ABC FINANCIAL     ROGER STARR  Taxable   280961.99
# 45  943569397  AR4K  ABC FINANCIAL     DAVID ORTIZ  Taxable   173938.24
# 47  944336420  AR4K  ABC FINANCIAL      BEN HARRIS  Taxable  1321909.51
# 50  944931330  AR4K  ABC FINANCIAL  BECKY GOLDBERG  Taxable  1104473.02
# 51  944955520  AR4K  ABC FINANCIAL  BECKY GOLDBERG  Taxable   142795.59
# ...

# %%
df['acctname'].unique()
# Out:
# array(['Taxable', 'IRA ', 'ROTH  ', 'IRA'], dtype=object)

# %%
df.dtypes
# Out:
# acctid         int64
# repid         object
# repname       object
# name          object
# acctname      object
# value        float64
# model         object
# profile       object
# opened        object
# e-mail        object
# phone         object
# dob           object
# 1mo           object
# 1yr           object
# 3yr           object
# ytd           object
# inception     object
# dtype: object

# %%
x = df.groupby('acctname')['value'].sum()

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x1 = df.groupby('acctname')[['value']].sum()

# %%
x1
# Out:
#                value
# acctname
# IRA       8390427.30
# IRA       1044022.60
# ROTH       196838.55
# Taxable   7998973.75

# %%
type(x1)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.Series(['A1','A2','A3'])
# Out:
# 0    A1
# 1    A2
# 2    A3
# dtype: object

# %%
df['NEW_COLUMN'] = 100

# %%
df
# Out:
#        acctid repid        repname               name acctname       value  \
# 0   901122740  AR4K  ABC FINANCIAL         JOHN SMITH  Taxable  1162761.59
# 1   901783640  AR4K  ABC FINANCIAL        JAMES JONES  Taxable   900455.95
# 2   901835570  AR4K  ABC FINANCIAL      SHARON HARRIS  Taxable   629922.90
# 3   903684690  AR4K  ABC FINANCIAL          LORI NEAL  Taxable     3014.71
# 4   906520600  AR4K  ABC FINANCIAL        NEAL NAVARO  Taxable   405784.14
# 5   908223080  AR4K  ABC FINANCIAL          JANET ROW  Taxable    22509.45
# 6   911032842  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    109937.24
# 7   911954714  AR4K  ABC FINANCIAL      EDDIE KROVITZ     IRA    845273.56
# 8   911955318  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA     88155.54
# 9   912052187  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       318.66
# 10  912052563  AR4K  ABC FINANCIAL     CINDY ZALEWSKI     IRA       337.60
# ...

# %%
df['acctname'] = np.where(df['acctname']=='Taxable','Tax',df['acctname'])

# %%
df.drop('name',axis=1,inplace=True)

# %%
df
# Out:
#        acctid repid        repname acctname       value               model  \
# 0   901122740  AR4K  ABC FINANCIAL      Tax  1162761.59  Moderate Portfolio
# 1   901783640  AR4K  ABC FINANCIAL      Tax   900455.95  Moderate Portfolio
# 2   901835570  AR4K  ABC FINANCIAL      Tax   629922.90  Moderate Portfolio
# 3   903684690  AR4K  ABC FINANCIAL      Tax     3014.71  Moderate Portfolio
# 4   906520600  AR4K  ABC FINANCIAL      Tax   405784.14  Moderate Portfolio
# 5   908223080  AR4K  ABC FINANCIAL      Tax    22509.45  Moderate Portfolio
# 6   911032842  AR4K  ABC FINANCIAL     IRA    109937.24  Moderate Portfolio
# 7   911954714  AR4K  ABC FINANCIAL     IRA    845273.56  Moderate Portfolio
# 8   911955318  AR4K  ABC FINANCIAL     IRA     88155.54  Moderate Portfolio
# 9   912052187  AR4K  ABC FINANCIAL     IRA       318.66  Moderate Portfolio
# 10  912052563  AR4K  ABC FINANCIAL     IRA       337.60  Moderate Portfolio
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>
