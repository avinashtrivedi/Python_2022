# %%
import pandas as pd

# %%
df = pd.read_csv('dataset-new.xlsx')

# %%
df
# Out:
#   Corporate         Zone            Region                    Branch  \
# 0     NORTH        DELHI  DELHI NORTH WEST      DELHI-MANGOLPUR KALN
# 1     NORTH        NORTH            KARNAL              ROORKEE-(UT)
# 2     SOUTH    KARNATAKA            MYSORE       BELUR - HASSAN DIST
# 3     NORTH      CENTRAL            NAGPUR                 REWA-(MP)
# 4     SOUTH    TELANGANA         CYBERABAD     HYDERABAD - ERRAGADDA
# 5     NORTH  BHUBANESWAR       BHUBANESWAR       ODISHA-KESINGA TOWN
# 6     NORTH  BHUBANESWAR       BHUBANESWAR                NIALI-(OR)
# 7     NORTH  BHUBANESWAR       BHUBANESWAR                NIALI-(OR)
# 8     NORTH         EAST           KOLKATA       DAKSHIN BARASAT(WB)
# 9     NORTH         WEST       NAVI MUMBAI  PIMPALGAONBASWANT - (MA)
#
#    Branch Code    Lead ID Lead Product  Lead Amount Lead Rating  \
# 0          1311  42238330    Gold Loan         9500         Hot
# 1          2695  41260593    Gold Loan        30000        Warm
# 2          4046  41260595    Gold Loan        14000         Hot
# 3          2919  42238329    Gold Loan        20000         Hot
# 4          3703  42238322    Gold Loan         8400        Cold
# 5          4168  42238160    Gold Loan         2000        Warm
# 6          4962  42238044    Gold Loan        15000        Warm
# 7          4962  42237457    Gold Loan         1500        Warm
# 8          4372  42220803    Gold Loan         2000         Hot
# 9          4551  42343819    Gold Loan         1500        Warm
#
#           Lead Source  ... Date of Birth       Age  Gender Purpose Category  \
# 0             Walk-in  ...       31048.0  36 Years  Female         Personal
# 1             Walk-in  ...       35626.0  23 Years    Male         Personal
# 2  Marketing Activity  ...       32143.0  33 Years    Male         Personal
# 3      Sales Activity  ...       34201.0  27 Years    Male         Personal
# 4  Marketing Activity  ...       33386.0  29 Years    Male         Personal
# 5  Customer Reference  ...           NaN       NaN     NaN         Personal
# 6  Marketing Activity  ...           NaN       NaN    Male         Personal
# 7  Marketing Activity  ...           NaN       NaN    Male         Personal
# 8         Aggregators  ...       33159.0  30 Years    Male         Personal
# 9  Customer Reference  ...           NaN       NaN     NaN         Personal
#
#                        Occupation  Marital Status  Qualification  \
# 0                      House Wife         Married       Graduate
# 1                   Self Employed         Married       Graduate
# 2  Agriculture/Related Activities         Married         School
# 3                        Salaried          Single       Graduate
# 4                        Salaried         Married       Graduate
# 5                             NaN             NaN            NaN
# 6                             NaN             NaN            NaN
# 7                             NaN             NaN            NaN
# 8                          Others             NaN       Graduate
# 9                             NaN             NaN            NaN
#
#   Appointment Date  Assign To Name  Time In StatusCode
# 0              NaN         PURNIMA                 6 D
# 1              NaN           SINGH                31 D
# 2              NaN               N                31 D
# 3              NaN            RUBY                 6 D
# 4              NaN     VINOD KUMAR                 6 D
# 5     44103.006944      Khandelwal                 3 D
# 6      4418.465278         MOHANTY                 6 D
# 7     44127.468750         MOHANTY                 6 D
# 8              NaN         RUKHSAR                 2 D
# 9     44105.444444         NIPHADE                 1 D
#
# [10 rows x 31 columns]

# %%
df['Corporate'].value_counts()
# Out:
# NORTH    8
# SOUTH    2
# Name: Corporate, dtype: int64

# %%
df = pd.get_dummies(df, columns=['Corporate'])

# %%
df
# Out:
#           Zone            Region                    Branch  Branch Code   \
# 0        DELHI  DELHI NORTH WEST      DELHI-MANGOLPUR KALN          1311
# 1        NORTH            KARNAL              ROORKEE-(UT)          2695
# 2    KARNATAKA            MYSORE       BELUR - HASSAN DIST          4046
# 3      CENTRAL            NAGPUR                 REWA-(MP)          2919
# 4    TELANGANA         CYBERABAD     HYDERABAD - ERRAGADDA          3703
# 5  BHUBANESWAR       BHUBANESWAR       ODISHA-KESINGA TOWN          4168
# 6  BHUBANESWAR       BHUBANESWAR                NIALI-(OR)          4962
# 7  BHUBANESWAR       BHUBANESWAR                NIALI-(OR)          4962
# 8         EAST           KOLKATA       DAKSHIN BARASAT(WB)          4372
# 9         WEST       NAVI MUMBAI  PIMPALGAONBASWANT - (MA)          4551
#
#     Lead ID Lead Product  Lead Amount Lead Rating         Lead Source  \
# 0  42238330    Gold Loan         9500         Hot             Walk-in
# 1  41260593    Gold Loan        30000        Warm             Walk-in
# 2  41260595    Gold Loan        14000         Hot  Marketing Activity
# 3  42238329    Gold Loan        20000         Hot      Sales Activity
# 4  42238322    Gold Loan         8400        Cold  Marketing Activity
# 5  42238160    Gold Loan         2000        Warm  Customer Reference
# 6  42238044    Gold Loan        15000        Warm  Marketing Activity
# 7  42237457    Gold Loan         1500        Warm  Marketing Activity
# 8  42220803    Gold Loan         2000         Hot         Aggregators
# 9  42343819    Gold Loan         1500        Warm  Customer Reference
#
#                  Medium  ...  Gender  Purpose Category  \
# 0           Bit Notices  ...  Female          Personal
# 1           Bit Notices  ...    Male          Personal
# 2              Demo Van  ...    Male          Personal
# 3           Refer N Win  ...    Male          Personal
# 4          Market Chalo  ...    Male          Personal
# 5     Branch Activation  ...     NaN          Personal
# 6     Branch Activation  ...    Male          Personal
# 7     Branch Activation  ...    Male          Personal
# 8   paynearby-Agrigator  ...    Male          Personal
# 9  Booklet Distribution  ...     NaN          Personal
#
#                        Occupation Marital Status  Qualification  \
# 0                      House Wife        Married       Graduate
# 1                   Self Employed        Married       Graduate
# 2  Agriculture/Related Activities        Married         School
# 3                        Salaried         Single       Graduate
# 4                        Salaried        Married       Graduate
# 5                             NaN            NaN            NaN
# 6                             NaN            NaN            NaN
# 7                             NaN            NaN            NaN
# 8                          Others            NaN       Graduate
# 9                             NaN            NaN            NaN
#
#    Appointment Date Assign To Name  Time In StatusCode  Corporate_NORTH  \
# 0               NaN        PURNIMA                 6 D                1
# 1               NaN          SINGH                31 D                1
# 2               NaN              N                31 D                0
# 3               NaN           RUBY                 6 D                1
# 4               NaN    VINOD KUMAR                 6 D                0
# 5      44103.006944     Khandelwal                 3 D                1
# 6       4418.465278        MOHANTY                 6 D                1
# 7      44127.468750        MOHANTY                 6 D                1
# 8               NaN        RUKHSAR                 2 D                1
# 9      44105.444444        NIPHADE                 1 D                1
#
#   Corporate_SOUTH
# 0               0
# 1               0
# 2               1
# 3               0
# 4               1
# 5               0
# 6               0
# 7               0
# 8               0
# 9               0
#
# [10 rows x 32 columns]

# %%
df = pd.get_dummies(df, columns=['Zone'])

# %%
df['Zone']
# Out:
# 0          DELHI
# 1          NORTH
# 2      KARNATAKA
# 3        CENTRAL
# 4      TELANGANA
# 5    BHUBANESWAR
# 6    BHUBANESWAR
# 7    BHUBANESWAR
# 8           EAST
# 9           WEST
# Name: Zone, dtype: object

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

y = label_encoder.fit_transform(df['Zone'])

# %%
df['Zone'].unique()
# Out:
# array(['DELHI', 'NORTH', 'KARNATAKA', 'CENTRAL', 'TELANGANA',
#        'BHUBANESWAR', 'EAST', 'WEST'], dtype=object)

# %%
list(range(len(df['Zone'].unique())))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df['Region'] = df['Region'].replace(df['Region'].unique(),list(range(len(df['Region'].unique()))))

# %%
df
# Out:
#    Zone  Region                    Branch  Branch Code    Lead ID  \
# 0     0       0      DELHI-MANGOLPUR KALN          1311  42238330
# 1     1       1              ROORKEE-(UT)          2695  41260593
# 2     2       2       BELUR - HASSAN DIST          4046  41260595
# 3     3       3                 REWA-(MP)          2919  42238329
# 4     4       4     HYDERABAD - ERRAGADDA          3703  42238322
# 5     5       5       ODISHA-KESINGA TOWN          4168  42238160
# 6     5       5                NIALI-(OR)          4962  42238044
# 7     5       5                NIALI-(OR)          4962  42237457
# 8     6       6       DAKSHIN BARASAT(WB)          4372  42220803
# 9     7       7  PIMPALGAONBASWANT - (MA)          4551  42343819
#
#   Lead Product  Lead Amount Lead Rating         Lead Source  \
# 0    Gold Loan         9500         Hot             Walk-in
# 1    Gold Loan        30000        Warm             Walk-in
# 2    Gold Loan        14000         Hot  Marketing Activity
# 3    Gold Loan        20000         Hot      Sales Activity
# 4    Gold Loan         8400        Cold  Marketing Activity
# 5    Gold Loan         2000        Warm  Customer Reference
# 6    Gold Loan        15000        Warm  Marketing Activity
# 7    Gold Loan         1500        Warm  Marketing Activity
# 8    Gold Loan         2000         Hot         Aggregators
# 9    Gold Loan         1500        Warm  Customer Reference
#
#                  Medium  ...  Gender  Purpose Category  \
# 0           Bit Notices  ...  Female          Personal
# 1           Bit Notices  ...    Male          Personal
# 2              Demo Van  ...    Male          Personal
# 3           Refer N Win  ...    Male          Personal
# 4          Market Chalo  ...    Male          Personal
# 5     Branch Activation  ...     NaN          Personal
# 6     Branch Activation  ...    Male          Personal
# 7     Branch Activation  ...    Male          Personal
# 8   paynearby-Agrigator  ...    Male          Personal
# 9  Booklet Distribution  ...     NaN          Personal
#
#                        Occupation Marital Status  Qualification  \
# 0                      House Wife        Married       Graduate
# 1                   Self Employed        Married       Graduate
# 2  Agriculture/Related Activities        Married         School
# 3                        Salaried         Single       Graduate
# 4                        Salaried        Married       Graduate
# 5                             NaN            NaN            NaN
# 6                             NaN            NaN            NaN
# 7                             NaN            NaN            NaN
# 8                          Others            NaN       Graduate
# 9                             NaN            NaN            NaN
#
#    Appointment Date Assign To Name  Time In StatusCode  Corporate_NORTH  \
# 0               NaN        PURNIMA                 6 D                1
# 1               NaN          SINGH                31 D                1
# 2               NaN              N                31 D                0
# 3               NaN           RUBY                 6 D                1
# 4               NaN    VINOD KUMAR                 6 D                0
# 5      44103.006944     Khandelwal                 3 D                1
# 6       4418.465278        MOHANTY                 6 D                1
# 7      44127.468750        MOHANTY                 6 D                1
# 8               NaN        RUKHSAR                 2 D                1
# 9      44105.444444        NIPHADE                 1 D                1
#
#   Corporate_SOUTH
# 0               0
# 1               0
# 2               1
# 3               0
# 4               1
# 5               0
# 6               0
# 7               0
# 8               0
# 9               0
#
# [10 rows x 32 columns]

# %%
list(df)
# Out:
# ['Zone',
#  'Region',
#  'Branch',
#  'Branch Code ',
#  'Lead ID',
#  'Lead Product',
#  'Lead Amount',
#  'Lead Rating',
#  'Lead Source',
#  'Medium',
#  'Lead Status Code (Text)',
#  'Disbursed Amount',
#  'Created by Code',
#  'Lead Owner',
#  'Lead Created On',
#  'Lead Converted On',
#  'Assign To Code',
#  'Date of Purchase',
#  'CIF No.',
#  'Existing Customer',
#  'Date of Birth',
#  'Age',
#  'Gender',
#  'Purpose Category',
#  'Occupation',
#  'Marital Status',
#  'Qualification',
#  'Appointment Date',
#  'Assign To Name',
#  'Time In StatusCode',
#  'Corporate_NORTH',
#  'Corporate_SOUTH']

# %%
df['Medium'] = df['Medium'].replace(df['Medium'].unique(),list(range(len(df['Medium'].unique()))))

# %%
df['Lead Status Code (Text)']
# Out:
# 0    Disbursed
# 1    Disbursed
# 2    Disbursed
# 3    Disbursed
# 4    Disbursed
# 5    Rejected
# 6    Rejected
# 7    Rejected
# 8    Rejected
# 9    Rejected
# Name: Lead Status Code (Text), dtype: object

# %%
df['Lead Status Code (Text)'] = 

df['Lead Status Code (Text)'] = df['Lead Status Code (Text)'].replace(df['Lead Status Code (Text)'].unique(),list(range(len(df['Lead Status Code (Text)'].unique()))))

# %%
df['Lead Owner']
# Out:
# 0                            PURNIMA
# 1                              SINGH
# 2                                  N
# 3                               RUBY
# 4                        VINOD KUMAR
# 5               Ms. KIRTI KHANDELWAL
# 6    Ms. RUPALI PRIYADARSHIN MOHANTY
# 7    Ms. RUPALI PRIYADARSHIN MOHANTY
# 8                            Finance
# 9           Ms. NILAM LAXMAN NIPHADE
# Name: Lead Owner, dtype: object

# %%
df['Age']
# Out:
# 0    36 Years
# 1    23 Years
# 2    33 Years
# 3    27 Years
# 4    29 Years
# 5         NaN
# 6         NaN
# 7         NaN
# 8    30 Years
# 9         NaN
# Name: Age, dtype: object

# %%
df = pd.get_dummies(df, columns=['Purpose Category'])

# %%
df['Qualification']

# %%
df.isna().sum()

# %%
df.shape
# Out:
# (10, 32)

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Zone, Region, Branch, Branch Code , Lead ID, Lead Product, Lead Amount, Lead Rating, Lead Source, Medium, Lead Status Code (Text), Disbursed Amount, Created by Code, Lead Owner, Lead Created On, Lead Converted On, Assign To Code, Date of Purchase, CIF No., Existing Customer, Date of Birth, Age, Gender, Purpose Category, Occupation, Marital Status, Qualification, Appointment Date, Assign To Name, Time In StatusCode, Corporate_NORTH, Corporate_SOUTH]
# Index: []
#
# [0 rows x 32 columns]

# %%
df.isna().sum()[df.isna().sum()>0]
# Out:
# Disbursed Amount     5
# Lead Converted On    5
# Date of Purchase     5
# Date of Birth        4
# Age                  4
# Gender               2
# Occupation           4
# Marital Status       5
# Qualification        4
# Appointment Date     6
# dtype: int64

# %%
X = data.drop('Lead Status Code (Text)',axis=1)
y = data['Lead Status Code (Text)']

# %%
y = df['Lead Status Code (Text)']
