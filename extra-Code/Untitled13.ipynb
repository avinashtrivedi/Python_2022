# %%
# Instructions: modify only the __?__ sections of the code

import random
# Recursive Max
# > Finds the max value in a list
# > Max value search starts from beginning of the list
def maxValue(list, i, max):
    '''
    if ___?__:
        return max
    elif ___?__:
        return ___?__
    else:
        return ___?__
    '''
    
    if len(list)==1:
        return max
    elif ___?__:
        return ___?__
    else:
        return ___?__
    
    

# Recursive Summation (evens only)
# > Sums all even values in a list
# > Search begins from the end of the list (searches backwards)
def sumEvens(list, i):
    '''
    if ___?__:
        return ___?__
    elif ___?__:
        return ___?__
    else:
        return ___?__
    '''
        
# Recursive Power
# > Computes a^b, where b can be positive or negative 
# > example: a^(-3) = 0.125
def recPower(a, b):
    '''
    if b == 0:
        return ___?__
    if ___?__:
        return ___?__
    if ___?__:
        ___?__
    '''

# Recursive Search
# > Searches if the target exists in list, returns true if found, false otherwise
# > Search starts from the beginning of the list
def search(list, i, target):
    '''
    if ___?__:
        return ___?__
    elif ___?__:
        return True
    else:
        return ___?__
    '''

# Recursive Pattern 
# > Prints an upside down triangle starting with 'n' many symbols
# > Every new line will print one less symbol until it prints only 1
def printPattern(symbol, i, n):
    '''
    if ___?__:
        return
    else:
        ___?__
        ___?__
    '''


############ DO NOT MODIFY ANY CODE BELOW THIS LINE #####################

# Random List Generator
# > Generates a random list(ints) of a given size
def generateList(size):
    list = [random.randrange(1, 20) for i in range(size)]
    print(list)
    return list

def main():
    
    ############## MAXVALUE TESTS ###############
    list = generateList(10)
    print('Max:', maxValue(list, 0, -1))
    print('-' * 35)
    
    list = generateList(15)
    print('Max:', maxValue(list, 0, -1))
    print('-' * 35)

    ############## SUMEVEN TESTS ###############
    list = generateList(10)
    print('Sum:', sumEvens(list, len(list)-1))
    print('-' * 35)

    list = generateList(15) 
    print('Sum:', sumEvens(list, len(list)-1))
    print('-' * 35)

    ############## RECPOWER TESTS ###############
    # Positive values for b
    a = random.randrange(2, 5)
    b = random.randrange(2, 5)
    print(f'{a}^{b} = {recPower(a, b)}')
    print('-' * 35)

    # Negative values for b
    a = random.randrange(2, 5)
    b = random.randrange(-5, -2)
    print(f'{a}^{b} = {recPower(a, b)}')
    print('-' * 35)

    ############## SEARCH TESTS ###############
    list = generateList(10) 
    num = random.randrange(1, 20)
    print(f'Search {num}: {search(list, 0, num)}')
    print('-' * 35)

    list = generateList(10) 
    num = random.randrange(1, 20)
    print(f'Search {num}: {search(list, 0, num)}')
    print('-' * 35)
    
    ############## PRINTPATTERN TESTS ###############
    printPattern('+', 0, 4)
    printPattern('*', 0, 5)
    printPattern('@', 0, 7)
    printPattern('#', 0, 12)

main()
# Out:
# [9, 15, 5, 12, 2, 10, 8, 12, 19, 9]
# Max: None
# -----------------------------------
# [19, 2, 13, 9, 12, 11, 15, 3, 15, 8, 8, 6, 13, 16, 15]
# Max: None
# -----------------------------------
# [7, 3, 17, 14, 12, 1, 5, 15, 18, 4]
# Sum: None
# -----------------------------------
# [12, 15, 6, 8, 17, 18, 11, 16, 6, 3, 11, 10, 10, 11, 1]
# Sum: None
# -----------------------------------
# 2^3 = None
# -----------------------------------
# 3^-3 = None
# -----------------------------------
# [19, 10, 6, 6, 4, 14, 5, 3, 19, 7]
# Search 16: None
# -----------------------------------
# [6, 4, 18, 6, 1, 11, 5, 15, 11, 4]
# Search 16: None
# -----------------------------------
