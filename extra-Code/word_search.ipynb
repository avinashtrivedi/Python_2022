# %%
# %load WordleAssistant.py


##def createWordlist(filename):
##    text = open(filename, "r")
##    wordlist = []
##    for word in text:
##        word = word.strip()
##        if len(word) == 5 or len(word) != len(set(word)) or word[-1] != 's':
##            wordlist.append(word)
##
##    count = len(wordlist)
##    return(wordlist, count)
            



##
def createWordlist(filename): 
####    """ Read words from the provided file and store them in a list.
####    The file contains only lowercase ascii characters, are sorted
####    alphabetically, one word per line. Filter out any words that are
####    not 5 letters long, have duplicate letters, or end in 's'.  Return
####    the list of words and the number of words as a pair. """
####    with open('C:\name\MyDesktop\words.txt') as f:
####        lines = f.read().splitlines()
    text = open("words1.txt", "r")
    wordlist = []

    for word in text:
        word = word.strip()
        if len(word) == 5:
            for i in word:
                if len(set(word))!=len(word):
                    pass
                else:
                    if word[-1] != "s":
                        wordlist.append(word)
                        break
    count = len(wordlist)
    return (wordlist, count)

def containsAll(wordlist, include):
    keep = set()
    for word in wordlist:
        if set(include) <= set(word):
            keep.add(word)
    return keep
    
##    set1 = {}
##    for word in wordlist:
##        for i in word:
##            if include == i:
##                set1.append(word)
##    return(set1)             
##    """ Given your wordlist, return a set of all words from the wordlist
##    that contain all of the letters in the string include.  
##    """
##    ...
##
def containsNone(wordlist, exclude):
##    """ Given your wordlist, return a set of all words from the wordlist
##    that do not contain any of the letters in the string exclude.  
##    """
##    ...
    import re
    keep = set()
    for word in wordlist:
        if re.search (exclude, word):
            pass
        else:
            keep.add(word)
    print(keep)
    return keep
##
def containsAtPositions(wordlist, posInfo):
    keep = set()
##    """ posInfo is a dictionary that maps letters to positions.
##    You can assume that the positions are in [0..4].  Return a set of
##    all words from the wordlist that contain the letters from the
##    dictionary at the indicated positions. For example, given posInfo
##    {'a': 0, 'y': 4}.   This function might return the set:
##    {'angry', 'aptly', 'amply', 'amity', 'artsy', 'agony'}. """

  

    v = list(posInfo.values())
    k = list (posInfo.keys())

    for word in wordlist:
        if word[v[0]] == k[0] and word[v[1]] == k[1]:
            keep.add(word)
    return keep

##    ...
##
def getPossibleWords(wordlist, posInfo, include, exclude):
    """ Finally, given a wordlist, dictionary posInfo, and
    strings include and exclude, return the set of all words from 
    the wordlist that contains the words that satisfy all of 
    the following:
    * has letters in positions indicated in posInfo
    * contains all letters from string include
    * contains none of the letters from string exclude.
    """
    filtered_wordlist = set()
    for word in wordlist:
        flag = True
        for k,v in pos_info.items():
            if word[v] == k:
                continue
            else:
                flag = False
                break

        if flag == True:
            filtered_wordlist.add(word)

    words = containsAll(filtered_wordlist,include)
    words = containsNone(words,exclude)
    return words

# %%
pos_info = {'a': 0, 'b': 1}
exclude = 'v'
include = 'o'

getPossibleWords(wordlist,pos_info,include,exclude)
# Out:
# {'abort', 'abode', 'abhor', 'about'}
# {'abhor', 'abode', 'abort', 'about'}

# %%
wordlist,count = createWordlist('hhh')

# %%
wordlist
# Out:
# ['abhor',
#  'abide',
#  'abler',
#  'abode',
#  'abort',
#  'about',
#  'above',
#  'abuse',
#  'ached',
#  'acing',
#  'acorn',
#  'acrid',
#  'acted',
#  'actor',
#  'acute',
#  'adept',
#  'adieu',
#  'admen',
#  'admit',
#  'adobe',
#  'adopt',
#  'adore',
#  'adorn',
#  'adult',
#  'afire',
#  'afoul',
#  'after',
#  'agent',
#  'agile',
#  'aglow',
#  'agony',
#  'ailed',
#  'aimed',
#  'aired',
#  'aisle',
#  'album',
#  'alder',
#  'alert',
#  'alien',
#  'align',
#  'alike',
#  'alive',
#  'aloft',
#  'alone',
#  'along',
#  'aloud',
#  'alter',
#  'amber',
#  'amble',
#  'amend',
#  'amigo',
#  'amity',
#  'among',
#  'amour',
#  'amped',
#  'ample',
#  'amply',
#  'ampul',
#  'amuck',
#  'amuse',
#  'angel',
#  'anger',
#  'angle',
#  'angry',
#  'angst',
#  'anise',
#  'ankle',
#  'anode',
#  'anted',
#  'antic',
#  'anvil',
#  'aphid',
#  'aping',
#  'apron',
#  'apter',
#  'aptly',
#  'arced',
#  'argon',
#  'argot',
#  'argue',
#  'arise',
#  'armed',
#  'arose',
#  'arson',
#  'artsy',
#  'ascot',
#  'ashed',
#  'ashen',
#  'aside',
#  'asked',
#  'askew',
#  'aspen',
#  'aspic',
#  'aster',
#  'astir',
#  'atone',
#  'audio',
#  'audit',
#  'auger',
#  'aught',
#  'avert',
#  'avoid',
#  'awful',
#  'awing',
#  'awoke',
#  'axing',
#  'axiom',
#  'azure',
#  'bacon',
#  'badge',
#  'badly',
#  'bagel',
#  'baize',
#  'baked',
#  'baker',
#  'baled',
#  'balky',
#  'balmy',
#  'bandy',
#  'baned',
#  'banjo',
#  'bared',
#  'barge',
#  'baron',
#  'based',
#  'baser',
#  'basic',
#  'basil',
#  'basin',
#  'baste',
#  'batch',
#  'bated',
#  'bathe',
#  'batik',
#  'baton',
#  'bawdy',
#  'bayed',
#  'bayou',
#  'beach',
#  'beady',
#  'beard',
#  'beast',
#  'beaux',
#  'befit',
#  'befog',
#  'began',
#  'begin',
#  'begot',
#  'begun',
#  'being',
#  'belay',
#  'belch',
#  'below',
#  'bench',
#  'berth',
#  'beryl',
#  'besom',
#  'besot',
#  'bicep',
#  'bidet',
#  'bight',
#  'bigot',
#  'biked',
#  'biker',
#  'bilge',
#  'binge',
#  'bingo',
#  'biped',
#  'birch',
#  'birth',
#  'bison',
#  'bitch',
#  'black',
#  'blade',
#  'blame',
#  'bland',
#  'blank',
#  'blare',
#  'blast',
#  'blase',
#  'blaze',
#  'bleak',
#  'bleat',
#  'blend',
#  'blent',
#  'blest',
#  'blimp',
#  'blind',
#  'blink',
#  'blitz',
#  'bloat',
#  'block',
#  'blond',
#  'blown',
#  'blued',
#  'bluer',
#  'blunt',
#  'blurt',
#  'blush',
#  'board',
#  'boast',
#  'bogey',
#  'bogie',
#  'boned',
#  'boner',
#  'boney',
#  'borax',
#  'bored',
#  'borne',
#  'bosun',
#  'botch',
#  'bough',
#  'bound',
#  'bowed',
#  'bowel',
#  'bower',
#  'boxed',
#  'boxer',
#  'brace',
#  'bract',
#  'braid',
#  'brain',
#  'brake',
#  'brand',
#  'brash',
#  'brave',
#  'bravo',
#  'brawl',
#  'brawn',
#  'bread',
#  'break',
#  'brick',
#  'bride',
#  'brief',
#  'brine',
#  'bring',
#  'brink',
#  'briny',
#  'brisk',
#  'broad',
#  'broil',
#  'broke',
#  'broth',
#  'brown',
#  'bruin',
#  'brunt',
#  'brush',
#  'brute',
#  'budge',
#  'bugle',
#  'build',
#  'built',
#  'bulge',
#  'bulgy',
#  'bulky',
#  'bumpy',
#  'bunch',
#  'burly',
#  'burnt',
#  'burst',
#  'bused',
#  'bushy',
#  'butch',
#  'buxom',
#  'buyer',
#  'bylaw',
#  'cabin',
#  'cable',
#  'cadet',
#  'cadge',
#  'cadre',
#  'caged',
#  'cagey',
#  'cairn',
#  'caked',
#  'calve',
#  'calyx',
#  'camel',
#  'cameo',
#  'campy',
#  'candy',
#  'caned',
#  'canoe',
#  'canto',
#  'caped',
#  'caper',
#  'capon',
#  'cared',
#  'caret',
#  'cargo',
#  'carol',
#  'carom',
#  'carpi',
#  'carve',
#  'cased',
#  'caste',
#  'cater',
#  'caulk',
#  'cause',
#  'caved',
#  'cavil',
#  'cawed',
#  'cedar',
#  'chafe',
#  'chain',
#  'chair',
#  'chalk',
#  'champ',
#  'chant',
#  'chapt',
#  'charm',
#  'chart',
#  'chary',
#  'chase',
#  'chasm',
#  'cheap',
#  'cheat',
#  'chest',
#  'chewy',
#  'chide',
#  'chief',
#  'child',
#  'chile',
#  'chime',
#  'chimp',
#  'china',
#  'chink',
#  'chino',
#  'chirp',
#  'chive',
#  'choir',
#  'choke',
#  'chomp',
#  'chord',
#  'chore',
#  'chose',
#  'chump',
#  'chunk',
#  'churl',
#  'churn',
#  'chute',
#  'cider',
#  'cigar',
#  'cited',
#  'civet',
#  'claim',
#  'clamp',
#  'clang',
#  'clank',
#  'clash',
#  'clasp',
#  'clean',
#  'clear',
#  'cleat',
#  'cleft',
#  'clerk',
#  'climb',
#  'clime',
#  'cling',
#  'clink',
#  'clipt',
#  'cloak',
#  'clomp',
#  'clone',
#  'close',
#  'cloth',
#  'cloud',
#  'clout',
#  'clove',
#  'clown',
#  'clued',
#  'clump',
#  'clung',
#  'clunk',
#  'coast',
#  'cobra',
#  'codex',
#  'coked',
#  'coled',
#  'comae',
#  'comer',
#  'comet',
#  'comfy',
#  'conga',
#  'coped',
#  'copra',
#  'copse',
#  'coral',
#  'cored',
#  'corny',
#  'cough',
#  'could',
#  'count',
#  'coupe',
#  'court',
#  'coven',
#  'cover',
#  'covet',
#  'covey',
#  'cowed',
#  'cower',
#  'coyer',
#  'cozen',
#  'craft',
#  'cramp',
#  'crane',
#  'crank',
#  'crape',
#  'crash',
#  'crate',
#  'crave',
#  'crawl',
#  'craze',
#  'crazy',
#  'creak',
#  'cream',
#  'credo',
#  'crept',
#  'crest',
#  'cried',
#  'crime',
#  'crimp',
#  'crisp',
#  'croak',
#  'crone',
#  'crony',
#  'croup',
#  'crowd',
#  'crown',
#  'crude',
#  'cruel',
#  'cruet',
#  'crumb',
#  'crush',
#  'crust',
#  'crypt',
#  'cubed',
#  'cubit',
#  'cuing',
#  'cumin',
#  'cured',
#  'curie',
#  'curio',
#  'curly',
#  'curse',
#  'curst',
#  'curve',
#  'curvy',
#  'cushy',
#  'cuter',
#  'daily',
#  'dairy',
#  'daisy',
#  'dance',
#  'datum',
#  'daunt',
#  'davit',
#  'dealt',
#  'death',
#  'debar',
#  'debit',
#  'debug',
#  'debut',
#  'decaf',
#  'decal',
#  'decay',
#  'decor',
#  'decoy',
#  'decry',
#  'deify',
#  'deign',
#  'deism',
#  'deity',
#  'delay',
#  'delta',
#  'demon',
#  'demur',
#  'denim',
#  'depot',
#  'depth',
#  'derby',
#  'detox',
#  'devil',
#  'dhoti',
#  'diary',
#  'dicey',
#  'dicky',
#  'dicta',
#  'dimer',
#  'dimly',
#  'diner',
#  'dingo',
#  'dingy',
#  'dinky',
#  'dirge',
#  'dirty',
#  'disco',
#  'ditch',
#  'divan',
#  'diver',
#  'divot',
#  'doest',
#  'dogie',
#  'dogma',
#  'doily',
#  'doing',
#  'donut',
#  'dopey',
#  'dorky',
#  'doubt',
#  'dough',
#  'douse',
#  'dowel',
#  'downy',
#  'dowry',
#  'dowse',
#  'doyen',
#  'dozen',
#  'draft',
#  'drain',
#  'drake',
#  'drank',
#  'drape',
#  'drawl',
#  'drawn',
#  'dream',
#  'drift',
#  'drily',
#  'drink',
#  'drive',
#  'drone',
#  'drove',
#  'drown',
#  'drunk',
#  'ducal',
#  'ducat',
#  'duchy',
#  'dumpy',
#  'dunce',
#  'dusky',
#  'dusty',
#  'duvet',
#  'dwarf',
#  'dwelt',
#  'dying',
#  'early',
#  'earth',
#  'ebony',
#  'edict',
#  'edify',
#  'eight',
#  'eking',
#  'elbow',
#  'elfin',
#  'email',
#  'empty',
#  'enact',
#  'endow',
#  'enjoy',
#  'enrol',
#  'entry',
#  'envoy',
#  'epoch',
#  'epoxy',
#  'equal',
#  'equip',
#  'erupt',
#  'ethic',
#  'evict',
#  'exact',
#  'exalt',
#  'exist',
#  'extol',
#  'extra',
#  'exult',
#  'eying',
#  'fable',
#  'faced',
#  'facet',
#  'fagot',
#  'faint',
#  'fairy',
#  'faith',
#  'faked',
#  'faker',
#  'fakir',
#  'false',
#  'famed',
#  'fancy',
#  'farce',
#  'fared',
#  'fated',
#  'fault',
#  'favor',
#  'faxed',
#  'fazed',
#  'feast',
#  'fecal',
#  'feign',
#  'feint',
#  'felon',
#  'femur',
#  'feral',
#  'fetal',
#  'fetch',
#  'fetid',
#  'fiber',
#  'fiche',
#  'field',
#  'fiend',
#  'fiery',
#  'fight',
#  'filch',
#  'filed',
#  'filet',
#  'filmy',
#  'filth',
#  'final',
#  'finch',
#  'fined',
#  'finer',
#  'fiord',
#  'fired',
#  'first',
#  'firth',
#  'fishy',
#  'fitly',
#  'fiver',
#  'fixed',
#  'fixer',
#  'fjord',
#  'flack',
#  'flair',
#  'flake',
#  'flaky',
#  'flame',
#  'flank',
#  'flare',
#  'flash',
#  'flask',
#  'fleck',
#  'flesh',
#  'flick',
#  'flied',
#  'flier',
#  'fling',
#  'flint',
#  'flirt',
#  'float',
#  'flock',
#  'flora',
#  'flour',
#  'flout',
#  'flown',
#  'fluid',
#  'fluke',
#  'fluky',
#  'flume',
#  'flung',
#  'flunk',
#  'flush',
#  'flute',
#  'flyer',
#  'foamy',
#  'focal',
#  'fogey',
#  'foist',
#  'foray',
#  'force',
#  'forge',
#  'forte',
#  'forth',
#  'forty',
#  'forum',
#  'found',
#  'fount',
#  'foxed',
#  'foyer',
#  'frail',
#  'frame',
#  'franc',
#  'frank',
#  'fraud',
#  'freak',
#  'fresh',
#  'fried',
#  'frisk',
#  'frock',
#  'frond',
#  'front',
#  'frost',
#  'froth',
#  'frown',
#  'froze',
#  'fruit',
#  'frump',
#  'fudge',
#  'fumed',
#  'fungi',
#  'funky',
#  'furze',
#  'fused',
#  'fusty',
#  'futon',
#  'fuzed',
#  'gable',
#  'gaily',
#  'gamed',
#  'gamer',
#  'gamey',
#  'gamin',
#  'gamut',
#  'gaped',
#  'gated',
#  'gaudy',
#  'gaunt',
#  'gauze',
#  'gauzy',
#  'gavel',
#  'gawky',
#  'gayer',
#  'gazed',
#  'gazer',
#  'gecko',
#  'gelid',
#  'getup',
#  'ghost',
#  'ghoul',
#  'giant',
#  'gibed',
#  'gimpy',
#  'gipsy',
#  'girth',
#  'gismo',
#  'given',
#  'gizmo',
#  'glade',
#  'gland',
#  'glare',
#  'glaze',
#  'gleam',
#  'glean',
#  'glide',
#  'glint',
#  'glitz',
#  'gloat',
#  'globe',
#  'glory',
#  'glove',
#  'glued',
#  'gluey',
#  'glyph',
#  'gnarl',
#  'gnash',
#  'gnome',
#  'godly',
#  'gofer',
#  'gonad',
#  'goner',
#  'gored',
#  'gorse',
#  'gourd',
#  'gouty',
#  'grace',
#  'grade',
#  'graft',
#  'grail',
#  'grain',
#  'grand',
#  'grant',
#  'grape',
#  'graph',
#  'grasp',
#  'grate',
#  'grave',
#  'gravy',
#  'graze',
#  'great',
#  'grief',
#  'grime',
#  'grimy',
#  'grind',
#  'gripe',
#  'grist',
#  'groan',
#  'groin',
#  'grope',
#  'group',
#  'grout',
#  'grove',
#  'growl',
#  'grown',
#  'gruel',
#  'grunt',
#  'guano',
#  'guard',
#  'guest',
#  'guide',
#  'guild',
#  'guile',
#  'guilt',
#  'guise',
#  'gulch',
#  'gumbo',
#  'gushy',
#  'gusto',
#  'gusty',
#  'gutsy',
#  'guyed',
#  'gybed',
#  'habit',
#  'haiku',
#  'hairy',
#  'haled',
#  'haler',
#  'halon',
#  'halve',
#  'handy',
#  'hanky',
#  'hardy',
#  'hared',
#  'harem',
#  'harpy',
#  'haste',
#  'hasty',
#  'hated',
#  'hater',
#  'haunt',
#  'haven',
#  'havoc',
#  'hawed',
#  'hayed',
#  'hazed',
#  'hazel',
#  'heady',
#  'heard',
#  'heart',
#  'heavy',
#  'hefty',
#  'heist',
#  'helix',
#  'helot',
#  'heron',
#  'hertz',
#  'hiked',
#  'hiker',
#  'hinge',
#  'hired',
#  'hived',
#  'hoagy',
#  'hoard',
#  'hoary',
#  'hogan',
#  'hoist',
#  'hokey',
#  'hokum',
#  'holed',
#  'homed',
#  'homer',
#  'homey',
#  'honed',
#  'honer',
#  'honey',
#  'hoped',
#  'horde',
#  'horny',
#  'horse',
#  'horsy',
#  'hosed',
#  'hotel',
#  'hotly',
#  'hound',
#  'house',
#  'hovel',
#  'hover',
#  'howdy',
#  'huger',
#  'human',
#  'humid',
#  'humor',
#  'husky',
#  'hydra',
#  'hyena',
#  'hying',
#  'hymen',
#  'hyped',
#  'hyper',
#  'ideal',
#  'idler',
#  'image',
#  'imbed',
#  'imbue',
#  'impel',
#  'imply',
#  'inapt',
#  'incur',
#  'index',
#  'inept',
#  'inert',
#  'infer',
#  'ingot',
#  'inked',
#  'inlay',
#  'inlet',
#  'input',
#  'inset',
#  'inter',
#  'inure',
#  'irate',
#  'irked',
#  'irony',
#  'islet',
#  'itchy',
#  'ivory',
#  'jabot',
#  'japed',
#  'jaunt',
#  'jawed',
#  'jerky',
#  'jibed',
#  'jihad',
#  'jived',
#  'joint',
#  'joist',
#  'joked',
#  'joker',
#  'joule',
#  'joust',
#  'joyed',
#  'judge',
#  'juice',
#  'juicy',
#  'julep',
#  'jumbo',
#  'jumpy',
#  'junco',
#  'junky',
#  'junta',
#  'kaput',
#  'ketch',
#  'kinda',
#  'kited',
#  'klutz',
#  'knave',
#  'knead',
#  'knelt',
#  'knife',
#  'krone',
#  'labor',
#  'laced',
#  'laden',
#  'lager',
#  'laity',
#  'laked',
#  'lamed',
#  'lamer',
#  'lance',
#  'lanky',
#  'lapse',
#  'larch',
#  'large',
#  'largo',
#  'laser',
#  'latch',
#  'later',
#  'latex',
#  'lathe',
#  'laugh',
#  'laxer',
#  'layer',
#  'lazed',
#  'leach',
#  'leafy',
#  'leaky',
#  'leant',
#  'leapt',
#  'learn',
#  'leash',
#  'least',
#  'lefty',
#  'legit',
#  'lemon',
#  'lemur',
#  'letup',
#  'lifer',
#  'light',
#  'liked',
#  'liken',
#  'liker',
#  'limbo',
#  'limed',
#  'lined',
#  'liner',
#  'lingo',
#  'liter',
#  'lithe',
#  'lived',
#  'liven',
#  'liver',
#  'loamy',
#  ...]

# %%
exclude = 'abcdefghijklmn'

newlist = set()
for word in wordlist[0]:
    flag = True
    for letter in exclude:
        if letter in word:
            flag = False
            break
            
    if flag==True:
        newlist.add(word)

# %%
pos_info = {'a': 0, 'b': 1}
exclude = 'v'
include = 'o'
# wordlist

# %%
filtered_wordlist = set()
for word in wordlist[0]:
    flag = True
    for k,v in pos_info.items():
        if word[v] == k:
            continue
        else:
            flag = False
            break
            
    if flag == True:
        filtered_wordlist.add(word)

words = containsAll(filtered_wordlist,include)
words = containsNone(words,exclude)
print(words)
# Out:
# {'abort', 'abode', 'abhor', 'about'}
# {'abort', 'abode', 'abhor', 'about'}

# %%
filtered_wordlist
# Out:
# {'abhor', 'abide', 'abler', 'abode', 'abort', 'about', 'above', 'abuse'}

# %%
list(pos_info)
# Out:
# ['a', 'b']

# %%
def containsAll(wordlist, include):
    keep = set()
    for word in wordlist:
        if set(include) <= set(word):
            keep.add(word)
    return keep

# %%
containsAll(wordlist[0],'o')
# Out:
# {'abhor',
#  'abode',
#  'abort',
#  'about',
#  'above',
#  'acorn',
#  'actor',
#  'adobe',
#  'adopt',
#  'adore',
#  'adorn',
#  'afoul',
#  'aglow',
#  'agony',
#  'aloft',
#  'alone',
#  'along',
#  'aloud',
#  'amigo',
#  'among',
#  'amour',
#  'anode',
#  'apron',
#  'argon',
#  'argot',
#  'arose',
#  'arson',
#  'ascot',
#  'atone',
#  'audio',
#  'avoid',
#  'awoke',
#  'axiom',
#  'bacon',
#  'banjo',
#  'baron',
#  'baton',
#  'bayou',
#  'befog',
#  'begot',
#  'below',
#  'besom',
#  'besot',
#  'bigot',
#  'bingo',
#  'bison',
#  'bloat',
#  'block',
#  'blond',
#  'blown',
#  'board',
#  'boast',
#  'bogey',
#  'bogie',
#  'boned',
#  'boner',
#  'boney',
#  'borax',
#  'bored',
#  'borne',
#  'bosun',
#  'botch',
#  'bough',
#  'bound',
#  'bowed',
#  'bowel',
#  'bower',
#  'boxed',
#  'boxer',
#  'bravo',
#  'broad',
#  'broil',
#  'broke',
#  'broth',
#  'brown',
#  'buxom',
#  'cameo',
#  'canoe',
#  'canto',
#  'capon',
#  'cargo',
#  'carol',
#  'carom',
#  'chino',
#  'choir',
#  'choke',
#  'chomp',
#  'chord',
#  'chore',
#  'chose',
#  'cloak',
#  'clomp',
#  'clone',
#  'close',
#  'cloth',
#  'cloud',
#  'clout',
#  'clove',
#  'clown',
#  'coast',
#  'cobra',
#  'codex',
#  'coked',
#  'coled',
#  'comae',
#  'comer',
#  'comet',
#  'comfy',
#  'conga',
#  'coped',
#  'copra',
#  'copse',
#  'coral',
#  'cored',
#  'corny',
#  'cough',
#  'could',
#  'count',
#  'coupe',
#  'court',
#  'coven',
#  'cover',
#  'covet',
#  'covey',
#  'cowed',
#  'cower',
#  'coyer',
#  'cozen',
#  'credo',
#  'croak',
#  'crone',
#  'crony',
#  'croup',
#  'crowd',
#  'crown',
#  'curio',
#  'decor',
#  'decoy',
#  'demon',
#  'depot',
#  'detox',
#  'dhoti',
#  'dingo',
#  'disco',
#  'divot',
#  'doest',
#  'dogie',
#  'dogma',
#  'doily',
#  'doing',
#  'donut',
#  'dopey',
#  'dorky',
#  'doubt',
#  'dough',
#  'douse',
#  'dowel',
#  'downy',
#  'dowry',
#  'dowse',
#  'doyen',
#  'dozen',
#  'drone',
#  'drove',
#  'drown',
#  'ebony',
#  'elbow',
#  'endow',
#  'enjoy',
#  'enrol',
#  'envoy',
#  'epoch',
#  'epoxy',
#  'extol',
#  'fagot',
#  'favor',
#  'felon',
#  'fiord',
#  'fjord',
#  'float',
#  'flock',
#  'flora',
#  'flour',
#  'flout',
#  'flown',
#  'foamy',
#  'focal',
#  'fogey',
#  'foist',
#  'foray',
#  'force',
#  'forge',
#  'forte',
#  'forth',
#  'forty',
#  'forum',
#  'found',
#  'fount',
#  'foxed',
#  'foyer',
#  'frock',
#  'frond',
#  'front',
#  'frost',
#  'froth',
#  'frown',
#  'froze',
#  'futon',
#  'gecko',
#  'ghost',
#  'ghoul',
#  'gismo',
#  'gizmo',
#  'gloat',
#  'globe',
#  'glory',
#  'glove',
#  'gnome',
#  'godly',
#  'gofer',
#  'gonad',
#  'goner',
#  'gored',
#  'gorse',
#  'gourd',
#  'gouty',
#  'groan',
#  'groin',
#  'grope',
#  'group',
#  'grout',
#  'grove',
#  'growl',
#  'grown',
#  'guano',
#  'gumbo',
#  'gusto',
#  'halon',
#  'havoc',
#  'helot',
#  'heron',
#  'hoagy',
#  'hoard',
#  'hoary',
#  'hogan',
#  'hoist',
#  'hokey',
#  'hokum',
#  'holed',
#  'homed',
#  'homer',
#  'homey',
#  'honed',
#  'honer',
#  'honey',
#  'hoped',
#  'horde',
#  'horny',
#  'horse',
#  'horsy',
#  'hosed',
#  'hotel',
#  'hotly',
#  'hound',
#  'house',
#  'hovel',
#  'hover',
#  'howdy',
#  'humor',
#  'ingot',
#  'irony',
#  'ivory',
#  'jabot',
#  'joint',
#  'joist',
#  'joked',
#  'joker',
#  'joule',
#  'joust',
#  'joyed',
#  'jumbo',
#  'junco',
#  'krone',
#  'labor',
#  'largo',
#  'lemon',
#  'limbo',
#  'lingo',
#  'loamy',
#  'loath',
#  'lobed',
#  'lodge',
#  'lofty',
#  'logic',
#  'loner',
#  'loped',
#  'loser',
#  'louse',
#  'lousy',
#  'loved',
#  'lover',
#  'lowed',
#  'lower',
#  'loxed',
#  'macho',
#  'macro',
#  'major',
#  'mango',
#  'manor',
#  'mason',
#  'matzo',
#  'mayor',
#  'melon',
#  'metro',
#  'minor',
#  'misdo',
#  'mocha',
#  'modal',
#  'model',
#  'moder',
#  'mogul',
#  'moire',
#  'moist',
#  'molar',
#  'moldy',
#  'money',
#  'month',
#  'moped',
#  'moral',
#  'moray',
#  'mosey',
#  'motel',
#  'motif',
#  'moult',
#  'mound',
#  'mount',
#  'mourn',
#  'mouse',
#  'mousy',
#  'mouth',
#  'moved',
#  'mover',
#  'movie',
#  'mowed',
#  'mower',
#  'nacho',
#  'noble',
#  'nobly',
#  'nodal',
#  'noise',
#  'noisy',
#  'nomad',
#  'north',
#  'nosed',
#  'nosey',
#  'notch',
#  'noted',
#  'novae',
#  'novel',
#  'noway',
#  'oaken',
#  'oakum',
#  'oared',
#  'oaten',
#  'ocean',
#  'ocher',
#  'ochre',
#  'octal',
#  'odium',
#  'often',
#  'ofter',
#  'ogled',
#  'oiled',
#  'olden',
#  'older',
#  'oldie',
#  'olive',
#  'omega',
#  'onset',
#  'opera',
#  'opine',
#  'opium',
#  'opted',
#  'optic',
#  'orate',
#  'orbit',
#  'organ',
#  'osier',
#  'other',
#  'ought',
#  'ounce',
#  'outed',
#  'outer',
#  'outre',
#  'ovary',
#  'overt',
#  'ovule',
#  'owing',
#  'owlet',
#  'owned',
#  'owner',
#  'oxide',
#  'patio',
#  'peony',
#  'phlox',
#  'phone',
#  'phony',
#  'piano',
#  'pilot',
#  'pinto',
#  'piton',
#  'pivot',
#  'poach',
#  'podia',
#  'poesy',
#  'point',
#  'poise',
#  'poked',
#  'poker',
#  'pokey',
#  'polar',
#  'poled',
#  'polka',
#  'porch',
#  'pored',
#  'posed',
#  'poser',
#  'posit',
#  'pouch',
#  'pound',
#  'power',
#  'poxed',
#  'probe',
#  'prone',
#  'prong',
#  'prose',
#  'prosy',
#  'proud',
#  'prove',
#  'prowl',
#  'proxy',
#  'pylon',
#  'quoit',
#  'quota',
#  'quote',
#  'quoth',
#  'radio',
#  'radon',
#  'ratio',
#  'rayon',
#  'rhino',
#  'roach',
#  'roast',
#  'robed',
#  'robin',
#  'rocky',
#  'rogue',
#  'roman',
#  'roped',
#  'rosin',
#  'roted',
#  'rouge',
#  'rough',
#  'round',
#  'rouse',
#  'route',
#  'roved',
#  'rowdy',
#  'rowed',
#  'rowel',
#  'royal',
#  'salon',
#  'salvo',
#  'savor',
#  'scion',
#  'scold',
#  'scone',
#  'scope',
#  'score',
#  'scorn',
#  'scour',
#  'scout',
#  'scowl',
#  'scrod',
#  'servo',
#  'shoal',
#  'shock',
#  'shoed',
#  'shone',
#  'shore',
#  'shorn',
#  'short',
#  'shout',
#  'shove',
#  'shown',
#  'showy',
#  'slope',
#  'sloth',
#  'smock',
#  'smoke',
#  'smoky',
#  'smote',
#  'snore',
#  'snort',
#  'snout',
#  'snowy',
#  'soapy',
#  'sober',
#  'softy',
#  'solar',
#  'soled',
#  'solid',
#  'solve',
#  'sonar',
#  'sonic',
#  'sored',
#  'sorta',
#  'sough',
#  'sound',
#  'soupy',
#  'south',
#  'sowed',
#  'sower',
#  'spoil',
#  'spoke',
#  'spore',
#  'sport',
#  'spout',
#  'stock',
#  'stoic',
#  'stoke',
#  'stole',
#  'stomp',
#  'stone',
#  'stony',
#  'store',
#  'stork',
#  'storm',
#  'story',
#  'stove',
#  'strop',
#  'sword',
#  'swore',
#  'sworn',
#  'synod',
#  'talon',
#  'tango',
#  'tempo',
#  'tenor',
#  'thong',
#  'thorn',
#  'those',
#  'throb',
#  'throe',
#  'throw',
#  'toady',
#  'today',
#  'togae',
#  'toked',
#  'token',
#  'tonal',
#  'toned',
#  'toner',
#  'tonic',
#  'topaz',
#  'topic',
#  'toque',
#  'torch',
#  'torsi',
#  'touch',
#  'tough',
#  'towed',
#  'towel',
#  'tower',
#  'toxic',
#  'toxin',
#  'toyed',
#  'tromp',
#  'trope',
#  'tumor',
#  'valor',
#  'vapor',
#  'velor',
#  'venom',
#  'video',
#  'vigor',
#  'viola',
#  'vireo',
#  'visor',
#  'vizor',
#  'vocal',
#  'vodka',
#  'vogue',
#  'voice',
#  'voile',
#  'voled',
#  'vomit',
#  'voted',
#  'voter',
#  'vouch',
#  'vowed',
#  'vowel',
#  'wacko',
#  'wagon',
#  'whole',
#  'whore',
#  'whorl',
#  'whose',
#  'woken',
#  'woman',
#  'women',
#  'wordy',
#  'world',
#  'wormy',
#  'worse',
#  'worst',
#  'worth',
#  'would',
#  'wound',
#  'woven',
#  'wrong',
#  'wrote',
#  'wroth',
#  'yodel',
#  'yoked',
#  'yokel',
#  'young',
#  'youth',
#  'zonal',
#  'zoned'}
