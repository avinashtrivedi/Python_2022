# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('E:/accepted_2007_to_2018Q4.csv',low_memory=False)

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
# ...

# %%
df_copy.shape
# Out:
# (2260701, 151)

# %%
list(df_copy)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
# ...

# %%
df_copy['loan_status']
# Out:
# 0           Fully Paid
# 1           Fully Paid
# 2           Fully Paid
# 3              Current
# 4           Fully Paid
#               ...
# 2260696        Current
# 2260697    Charged Off
# 2260698        Current
# 2260699            NaN
# 2260700            NaN
# Name: loan_status, Length: 2260701, dtype: object

# %%
df_copy['loan_status'].value_counts()
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %%
df_copy['loan_status'].replace(['Does not meet the credit policy. Status:Fully Paid','Does not meet the credit policy. Status:Charged Off'],['Fully Paid','Charged Off'],inplace=True)

# %%
df_copy['loan_status'].value_counts(normalize=True)*100
# Out:
# Fully Paid     80.021646
# Charged Off    19.978354
# Name: loan_status, dtype: float64

# %%
df_copy['loan_status']
# Out:
# 0           Fully Paid
# 1           Fully Paid
# 2           Fully Paid
# 4           Fully Paid
# 5           Fully Paid
#               ...
# 2260688     Fully Paid
# 2260690     Fully Paid
# 2260691    Charged Off
# 2260692     Fully Paid
# 2260697    Charged Off
# Name: loan_status, Length: 1348059, dtype: object

# %%
df_copy = df_copy[df_copy['loan_status'].isin(['Fully Paid','Charged Off'])]

# %%
# df_copy[(df_copy['loan_status']=='Fully Paid') | (df_copy['loan_status']=='Charged Off')]

# %%
# x = df_copy['loan_status'].isin(['Fully Paid','Charged Off'])

# %%
# df_copy[x]

# %%
df_copy.shape
# Out:
# (1348059, 151)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
len(df_copy)
# Out:
# 1348059

# %%
drop_nan = df_copy.isna().sum()

# %%
drop_nan
# Out:
# id                                                  0
# member_id                                     1348059
# loan_amnt                                           0
# funded_amnt                                         0
# funded_amnt_inv                                     0
# term                                                0
# int_rate                                            0
# installment                                         0
# grade                                               0
# sub_grade                                           0
# emp_title                                       85944
# emp_length                                      78545
# home_ownership                                      0
# annual_inc                                          4
# verification_status                                 0
# issue_d                                             0
# loan_status                                         0
# ...

# %%
drop_nan = drop_nan[drop_nan.values>len(df_copy)*0.10]

# %%
drop_nan.index
# Out:
# Index(['member_id', 'desc', 'mths_since_last_delinq', 'mths_since_last_record', 'next_pymnt_d', 'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'mths_since_recent_bc_dlq', 'mths_since_recent_inq', 'mths_since_recent_revol_delinq', 'revol_bal_joint', 'sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_earliest_cr_line', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il', 'sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog', 'hardship_type', 'hardship_reason', 'hardship_status', 'deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date',
# ...

# %%
df_copy.drop(labels=drop_nan.index,inplace=True,axis=1)
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_14192\2224360886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.drop(labels=drop_nan.index,inplace=True,axis=1)

# %%
df_copy.shape
# Out:
# (1348059, 92)

# %%
df_copy.head()
# Out:
#          id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment grade sub_grade             emp_title emp_length home_ownership  annual_inc verification_status   issue_d loan_status pymnt_plan                                                url             purpose               title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  policy_code application_type  acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# ...

# %%
df_copy.dtypes
# Out:
# id                             object
# loan_amnt                     float64
# funded_amnt                   float64
# funded_amnt_inv               float64
# term                           object
# int_rate                      float64
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                        object
# loan_status                    object
# pymnt_plan                     object
# url                            object
# purpose                        object
# title                          object
# zip_code                       object
# addr_state                     object
# dti                           float64
# delinq_2yrs                   float64
# earliest_cr_line               object
# ...

# %%
df_copy.select_dtypes('object').columns
# Out:
# Index(['id', 'term', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'initial_list_status', 'last_pymnt_d', 'last_credit_pull_d', 'application_type', 'hardship_flag', 'disbursement_method', 'debt_settlement_flag'], dtype='object')

# %%
df_copy['term'].value_counts()
# Out:
#  36 months    1023181
#  60 months     324878
# Name: term, dtype: int64

# %%
df_copy['term'] = df_copy['term'].replace([' 36 months',' 60 months'],[36,60])

# %%
df_copy['term'].value_counts()
# Out:
# 36    1023181
# 60     324878
# Name: term, dtype: int64

# %%
df_copy['grade'].value_counts()
# Out:
# B    393095
# C    382315
# A    235188
# D    201644
# E     94186
# F     32305
# G      9326
# Name: grade, dtype: int64

# %%
df_copy['grade'].unique()
# Out:
# array(['C', 'B', 'F', 'A', 'E', 'D', 'G'], dtype=object)

# %%
list(range(7))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
df_copy['grade'] = df_copy['grade'].replace(['C', 'B', 'F', 'A', 'E', 'D', 'G'],[0,1,2,3,4,5,6])

# %%
df_copy['grade'].value_counts()
# Out:
# 1    393095
# 0    382315
# 3    235188
# 5    201644
# 4     94186
# 2     32305
# 6      9326
# Name: grade, dtype: int64

# %%
df_copy['emp_title'].value_counts()
# Out:
# Teacher                            21268
# Manager                            19470
# Owner                              10302
# Registered Nurse                    8774
# RN                                  8522
#                                    ...
# Sr. Facilities Mgr                     1
# Licensed Refrigeration Engineer        1
# Sr. Financial Analyst - FP&A           1
# Elegibility Tech                       1
# Exec Dir Internal Audit                1
# Name: emp_title, Length: 379858, dtype: int64

# %%
df_copy['emp_length'].value_counts()
# Out:
# 10+ years    442669
# 2 years      122092
# < 1 year     108533
# 3 years      107863
# 1 year        88842
# 5 years       84326
# 4 years       80761
# 6 years       62877
# 8 years       60808
# 7 years       59724
# 9 years       51019
# Name: emp_length, dtype: int64
