# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('non_encrypt_NPS_SCU_Subset.csv')

# %%
len(df)
# Out:
# 98

# %%
df.shape
# Out:
# (98, 128)

# %%
df
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 2                                      11/15/21 21:04
# 3                                       11/10/21 9:00
# 4                                      11/15/21 21:32
# ..                                                ...
# 93                                     11/15/21 22:02
# 94                                     11/15/21 22:32
# 95                                     11/15/21 21:46
# 96                                     11/15/21 22:17
# 97                                     11/15/21 21:58
#
#                                               EndDate                 Status  \
# 0                                            End Date          Response Type
# 1   {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                      11/15/21 21:07               Imported
# 3                                       11/10/21 9:05               Imported
# 4                                      11/15/21 21:36               Imported
# ..                                                ...                    ...
# 93                                     11/15/21 22:09               Imported
# 94                                     11/15/21 22:34               Imported
# 95                                     11/15/21 21:50               Imported
# 96                                     11/15/21 22:22               Imported
# 97                                     11/15/21 22:00               Imported
#
#                    Progress    Duration (in seconds)                 Finished  \
# 0                  Progress    Duration (in seconds)                 Finished
# 1   {"ImportId":"progress"}  {"ImportId":"duration"}  {"ImportId":"finished"}
# 2                       100                      223                     TRUE
# 3                       100                      262                     TRUE
# 4                       100                      228                     TRUE
# ..                      ...                      ...                      ...
# 93                      100                      418                     TRUE
# 94                      100                       88                     TRUE
# 95                      100                      198                     TRUE
# 96                      100                      307                     TRUE
# 97                      100                      129                     TRUE
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 2                                      12/15/21 10:05
# 3                                      12/15/21 10:05
# 4                                      12/15/21 10:05
# ..                                                ...
# 93                                     12/15/21 10:05
# 94                                     12/15/21 10:05
# 95                                     12/15/21 10:05
# 96                                     12/15/21 10:05
# 97                                     12/15/21 10:05
#
#                   ResponseId                 DistributionChannel  \
# 0                Response ID                Distribution Channel
# 1   {"ImportId":"_recordId"}  {"ImportId":"distributionChannel"}
# 2          R_6AaCEkIn7LRXuUS                               email
# 3          R_74yZFhxf5VRBN2e                               email
# 4          R_81cqwo6bIRMxDf0                               email
# ..                       ...                                 ...
# 93         R_egQBT4ifxm96PZA                               email
# 94         R_0BqtEBpjFeivh2K                               email
# 95         R_0Dpt2H7wTzyVLvw                               email
# 96         R_0kaHTrtKtegXadw                               email
# 97         R_0w7fTqOoGj8Uex0                               email
#
#                    UserLanguage  ...  \
# 0                 User Language  ...
# 1   {"ImportId":"userLanguage"}  ...
# 2                            EN  ...
# 3                            DE  ...
# 4                            JA  ...
# ..                          ...  ...
# 93                           KO  ...
# 94                           JA  ...
# 95                           EN  ...
# 96                           EN  ...
# 97                           JA  ...
#
#                                                Q2B_EN  \
# 0   Your feedback goes a long way to helping us bu...
# 1      {"ImportId":"QID180_TEXT_TRANSLATEDen9ewb5mw"}
# 2                                                 NaN
# 3                                                 NaN
# 4   I'm not impressed that anyone other than mysel...
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                              Q7b_1_EN  \
# 0                                            q7b_1_EN
# 1     {"ImportId":"QID190_x11_1_TRANSLATEDentnqq60m"}
# 2                                                 NaN
# 3                           Technically very reliable
# 4   I am using vSphere, but it is free and easy to...
# ..                                                ...
# 93        Long-standing technology and stable service
# 94                                                NaN
# 95                                                NaN
# 96                                                  8
# 97                                                NaN
#
#                                            Q7b_2_EN  \
# 0                                          q7b_2_EN
# 1   {"ImportId":"QID190_x12_1_TRANSLATEDen2fkokcb"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93              Isolated virtualization environment
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_3_EN  \
# 0                                          q7b_3_EN
# 1   {"ImportId":"QID190_x14_1_TRANSLATEDenfaplxe0"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                                       start step
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_4_EN  \
# 0                                          q7b_4_EN
# 1   {"ImportId":"QID190_x15_1_TRANSLATEDenrkg48f7"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                       User-friendly GUI required
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_9_EN  \
# 0                                          q7b_9_EN
# 1   {"ImportId":"QID190_x17_1_TRANSLATEDenumofwtd"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                                              NaN
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                              Q7b_5_EN  \
# 0                                            q7b_5_EN
# 1      {"ImportId":"QID190_x1_1_TRANSLATEDent3f2pz4"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Expensive licensing policy compared to competi...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                           Q7b_6_EN  \
# 0                                         q7b_6_EN
# 1   {"ImportId":"QID190_x5_1_TRANSLATEDeni9nif2s"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                           Q7b_8_EN  \
# 0                                         q7b_8_EN
# 1   {"ImportId":"QID190_x6_1_TRANSLATEDentufoyj2"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                           Q7b_7_EN
# 0                                         q7b_7_EN
# 1   {"ImportId":"QID190_x7_1_TRANSLATEDenggjrshl"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
# [98 rows x 128 columns]

# %%
df = df.drop(labels={'StartDate','EndDate','Status'}, axis = 1)

# %%
df
# Out:
#                    Progress    Duration (in seconds)                 Finished  \
# 0                  Progress    Duration (in seconds)                 Finished
# 1   {"ImportId":"progress"}  {"ImportId":"duration"}  {"ImportId":"finished"}
# 2                       100                      223                     TRUE
# 3                       100                      262                     TRUE
# 4                       100                      228                     TRUE
# ..                      ...                      ...                      ...
# 93                      100                      418                     TRUE
# 94                      100                       88                     TRUE
# 95                      100                      198                     TRUE
# 96                      100                      307                     TRUE
# 97                      100                      129                     TRUE
#
#                                          RecordedDate  \
# 0                                       Recorded Date
# 1   {"ImportId":"recordedDate","timeZone":"America...
# 2                                      12/15/21 10:05
# 3                                      12/15/21 10:05
# 4                                      12/15/21 10:05
# ..                                                ...
# 93                                     12/15/21 10:05
# 94                                     12/15/21 10:05
# 95                                     12/15/21 10:05
# 96                                     12/15/21 10:05
# 97                                     12/15/21 10:05
#
#                   ResponseId                 DistributionChannel  \
# 0                Response ID                Distribution Channel
# 1   {"ImportId":"_recordId"}  {"ImportId":"distributionChannel"}
# 2          R_6AaCEkIn7LRXuUS                               email
# 3          R_74yZFhxf5VRBN2e                               email
# 4          R_81cqwo6bIRMxDf0                               email
# ..                       ...                                 ...
# 93         R_egQBT4ifxm96PZA                               email
# 94         R_0BqtEBpjFeivh2K                               email
# 95         R_0Dpt2H7wTzyVLvw                               email
# 96         R_0kaHTrtKtegXadw                               email
# 97         R_0w7fTqOoGj8Uex0                               email
#
#                    UserLanguage                 Q_RecaptchaScore  \
# 0                 User Language                 Q_RecaptchaScore
# 1   {"ImportId":"userLanguage"}  {"ImportId":"Q_RecaptchaScore"}
# 2                            EN                      0.600000024
# 3                            DE                                1
# 4                            JA                      0.899999976
# ..                          ...                              ...
# 93                           KO                      0.800000012
# 94                           JA                      0.899999976
# 95                           EN                                1
# 96                           EN                      0.800000012
# 97                           JA                                1
#
#                                          Q1_NPS_GROUP  \
# 0   How likely are you to recommend VMware product...
# 1                       {"ImportId":"QID8_NPS_GROUP"}
# 2                                            Promoter
# 3                                             Passive
# 4                                           Detractor
# ..                                                ...
# 93                                           Promoter
# 94                                          Detractor
# 95                                           Promoter
# 96                                            Passive
# 97                                            Passive
#
#                                                    Q1  ...  \
# 0   How likely are you to recommend VMware product...  ...
# 1                                 {"ImportId":"QID8"}  ...
# 2                                                   9  ...
# 3                                                   8  ...
# 4                                                   5  ...
# ..                                                ...  ...
# 93                                                 10  ...
# 94                                                  5  ...
# 95                                                  9  ...
# 96                                                  8  ...
# 97                                                  8  ...
#
#                                                Q2B_EN  \
# 0   Your feedback goes a long way to helping us bu...
# 1      {"ImportId":"QID180_TEXT_TRANSLATEDen9ewb5mw"}
# 2                                                 NaN
# 3                                                 NaN
# 4   I'm not impressed that anyone other than mysel...
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                              Q7b_1_EN  \
# 0                                            q7b_1_EN
# 1     {"ImportId":"QID190_x11_1_TRANSLATEDentnqq60m"}
# 2                                                 NaN
# 3                           Technically very reliable
# 4   I am using vSphere, but it is free and easy to...
# ..                                                ...
# 93        Long-standing technology and stable service
# 94                                                NaN
# 95                                                NaN
# 96                                                  8
# 97                                                NaN
#
#                                            Q7b_2_EN  \
# 0                                          q7b_2_EN
# 1   {"ImportId":"QID190_x12_1_TRANSLATEDen2fkokcb"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93              Isolated virtualization environment
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_3_EN  \
# 0                                          q7b_3_EN
# 1   {"ImportId":"QID190_x14_1_TRANSLATEDenfaplxe0"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                                       start step
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_4_EN  \
# 0                                          q7b_4_EN
# 1   {"ImportId":"QID190_x15_1_TRANSLATEDenrkg48f7"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                       User-friendly GUI required
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_9_EN  \
# 0                                          q7b_9_EN
# 1   {"ImportId":"QID190_x17_1_TRANSLATEDenumofwtd"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                                              NaN
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                              Q7b_5_EN  \
# 0                                            q7b_5_EN
# 1      {"ImportId":"QID190_x1_1_TRANSLATEDent3f2pz4"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Expensive licensing policy compared to competi...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                           Q7b_6_EN  \
# 0                                         q7b_6_EN
# 1   {"ImportId":"QID190_x5_1_TRANSLATEDeni9nif2s"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                           Q7b_8_EN  \
# 0                                         q7b_8_EN
# 1   {"ImportId":"QID190_x6_1_TRANSLATEDentufoyj2"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                           Q7b_7_EN
# 0                                         q7b_7_EN
# 1   {"ImportId":"QID190_x7_1_TRANSLATEDenggjrshl"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
# [98 rows x 125 columns]

# %%
# df = df.drop(labels={'Progress','Duration (in seconds)','Finished','RecordedDate','ResponseId','DistributionChannel','Q_RecaptchaScore'}, axis = 1)

# %%
list(df)
# Out:
# ['Progress',
#  'Duration (in seconds)',
#  'Finished',
#  'RecordedDate',
#  'ResponseId',
#  'DistributionChannel',
#  'UserLanguage',
#  'Q_RecaptchaScore',
#  'Q1_NPS_GROUP',
#  'Q1',
#  'Q2A',
#  'Q2B',
#  'Q2C',
#  'Q3',
#  'Q4',
#  'Q4A',
#  'Q5_1',
#  'Q5_2',
#  'Q5_3',
#  'Q5_4',
#  'Q5_5',
#  'Q5_6',
#  'Q6_1',
#  'Q6_2',
#  'Q6_3',
#  'Q6_4',
#  'Q6_5',
#  'Q6A',
#  'Q7_1',
#  'Q7_2',
#  'Q7_3',
#  'Q7_4',
#  'Q7_5',
#  'Q7_6',
#  'Q7_7',
#  'Q7_8',
#  'Q7_9',
#  'Q7_9_TEXT',
#  'Q7A_1',
#  'Q7A_2',
#  'Q7A_3',
#  'Q7A_4',
#  'Q7A_5',
#  'Q7A_6',
#  'Q7A_7',
#  'Q7A_8',
#  'Q7A_9',
#  'Q7A_9_TEXT',
#  'Q7B_1_1',
#  'Q7B_2_1',
#  'Q7B_3_1',
#  'Q7B_4_1',
#  'Q7B_5_1',
#  'Q7B_6_1',
#  'Q7B_7_1',
#  'Q7B_8_1',
#  'Q7B_9_TEXT',
#  'Q7B_9_1',
#  'Q8_1',
#  'Q8_2',
#  'Q8_3',
#  'Q8_4',
#  'Q8_5',
#  'Q8_6',
#  'Q8_7',
#  'Q8_8',
#  'Q8_9',
#  'Q8_9_TEXT',
#  'Q9_1',
#  'Q9_2',
#  'Q9_3',
#  'Q9_4',
#  'Q9_5',
#  'Q9_6',
#  'Q9_7',
#  'Q9_8',
#  'Q9_9',
#  'Q10_1_1',
#  'Q11_1',
#  'Wave',
#  'WaveUpdate',
#  'complete_status',
#  'SurveyID',
#  'ResponseID',
#  'Subject',
#  'PanelID',
#  'Language',
#  'RecipientLanguage',
#  'Q_Language',
#  'person_geo',
#  'person_region',
#  'person_country',
#  'language',
#  'person_industry',
#  'sales_segment',
#  'source',
#  'account',
#  'TranslationLanguage',
#  'CSM',
#  'CMBU_CSM',
#  'EUC_CSM',
#  'VMC_CSM',
#  'Hierarchy',
#  'Job Role',
#  'Job Title',
#  'ResponseId.1',
#  'FINALREGION',
#  'WEIGHT',
#  'CB_CSM',
#  'WT_SEGMENT',
#  'mobile_device',
#  'Q4A_EN',
#  'Q2C_EN',
#  'Q6a_EN',
#  'Q2A_EN',
#  'Q2B_EN',
#  'Q7b_1_EN',
#  'Q7b_2_EN',
#  'Q7b_3_EN',
#  'Q7b_4_EN',
#  'Q7b_9_EN',
#  'Q7b_5_EN',
#  'Q7b_6_EN',
#  'Q7b_8_EN',
#  'Q7b_7_EN']

# %%
pd.set_option('display.max_columns', None)

# %%
pd.options.display.max_rows = 20

# %%
df
# Out:
#                    UserLanguage  \
# 0                 User Language
# 1   {"ImportId":"userLanguage"}
# 2                            EN
# 3                            DE
# 4                            JA
# ..                          ...
# 93                           KO
# 94                           JA
# 95                           EN
# 96                           EN
# 97                           JA
#
#                                          Q1_NPS_GROUP  \
# 0   How likely are you to recommend VMware product...
# 1                       {"ImportId":"QID8_NPS_GROUP"}
# 2                                            Promoter
# 3                                             Passive
# 4                                           Detractor
# ..                                                ...
# 93                                           Promoter
# 94                                          Detractor
# 95                                           Promoter
# 96                                            Passive
# 97                                            Passive
#
#                                                    Q1  \
# 0   How likely are you to recommend VMware product...
# 1                                 {"ImportId":"QID8"}
# 2                                                   9
# 3                                                   8
# 4                                                   5
# ..                                                ...
# 93                                                 10
# 94                                                  5
# 95                                                  9
# 96                                                  8
# 97                                                  8
#
#                                                   Q2A  \
# 0   Your feedback goes a long way to helping us bu...
# 1                          {"ImportId":"QID179_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  ì„œë²„ ê°€ìƒí™”ì™€ ê´€ë ¨í•˜ì—¬ ì˜¤ëžœ ê¸°ìˆ ...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                   Q2B  \
# 0   Your feedback goes a long way to helping us bu...
# 1                          {"ImportId":"QID180_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4   ç¤¾å†…ã§ã¯è‡ªåˆ†ä»¥å¤–ãŒVMwareè£½å“ã‚’ä½¿ã...
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                Q2C  \
# 0       What can we do to improve your experience?
# 1                       {"ImportId":"QID173_TEXT"}
# 2                                              NaN
# 3   Technisch top, doch immer mehr kostenintensiv.
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                                    Q3  \
# 0   Currently, which option best describes your ro...
# 1                                {"ImportId":"QID49"}
# 2   Practitioner â€“ Perform the day-to-day VMware...
# 3   Budget Owner â€“ Final decision-maker on signi...
# 4   Practitioner â€“ Perform the day-to-day VMware...
# ..                                                ...
# 93  Influencer â€“ Influence what my company buys ...
# 94  Practitioner â€“ Perform the day-to-day VMware...
# 95  Practitioner â€“ Perform the day-to-day VMware...
# 96  Non-IT Influencer - Influence my companyâ€™s a...
# 97  Practitioner â€“ Perform the day-to-day VMware...
#
#                                            Q4  \
# 0   Do you consider VMware a trusted advisor?
# 1                       {"ImportId":"QID165"}
# 2                                         Yes
# 3                                         Yes
# 4                                         Yes
# ..                                        ...
# 93                                        Yes
# 94                                        Yes
# 95                                        Yes
# 96                                        Yes
# 97                                         No
#
#                                                   Q4A  \
# 0   Why would you not consider VMware a trusted ad...
# 1                          {"ImportId":"QID166_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                              é ¼ã£ãŸäº‹ãŒãªã„
#
#                                                  Q5_1  \
# 0   Please rate your satisfaction with each of the...
# 1                            {"ImportId":"QID167_13"}
# 2                                                   5
# 3                                                   3
# 4                                                   5
# ..                                                ...
# 93                                                  5
# 94                                                NaN
# 95                                                  6
# 96                                                  4
# 97                                                  6
#
#                                                  Q5_2  \
# 0   Please rate your satisfaction with each of the...
# 1                            {"ImportId":"QID167_24"}
# 2                                                   5
# 3                                                   6
# 4                                                   4
# ..                                                ...
# 93                                                  6
# 94                                                NaN
# 95                         Extremely Satisfied  -   7
# 96                                                  5
# 97                                                  6
#
#                                                  Q5_3  \
# 0   Please rate your satisfaction with each of the...
# 1                            {"ImportId":"QID167_21"}
# 2                                                   5
# 3                                                   4
# 4                                                 NaN
# ..                                                ...
# 93                                                  6
# 94                                                NaN
# 95                                                  6
# 96                                                  6
# 97                                                  6
#
#                                                  Q5_4  \
# 0   Please rate your satisfaction with each of the...
# 1                            {"ImportId":"QID167_15"}
# 2                                                   5
# 3                                                   4
# 4                                                 NaN
# ..                                                ...
# 93                                                  6
# 94                                                  5
# 95                         Extremely Satisfied  -   7
# 96                                                  5
# 97                                                  6
#
#                                                  Q5_5  \
# 0   Please rate your satisfaction with each of the...
# 1                            {"ImportId":"QID167_19"}
# 2                                                   6
# 3                                                   6
# 4                                                 NaN
# ..                                                ...
# 93                         Extremely Satisfied  -   7
# 94                                                  5
# 95                         Extremely Satisfied  -   7
# 96                                                  6
# 97                                                  6
#
#                                                  Q5_6  \
# 0   Please rate your satisfaction with each of the...
# 1                            {"ImportId":"QID167_20"}
# 2                                                   6
# 3                                                   5
# 4                                                 NaN
# ..                                                ...
# 93                                                  6
# 94                                                NaN
# 95                         Extremely Satisfied  -   7
# 96                                                  6
# 97                                                  6
#
#                                                  Q6_1  \
# 0   Please express your agreement with each of the...
# 1                             {"ImportId":"QID172_1"}
# 2                                                   5
# 3                                                   5
# 4                                                 NaN
# ..                                                ...
# 93                                                  6
# 94                                                  4
# 95                                                  5
# 96                                                  6
# 97                                                  6
#
#                                                  Q6_2  \
# 0   Please express your agreement with each of the...
# 1                             {"ImportId":"QID172_9"}
# 2                                                   4
# 3                                                   6
# 4                                                 NaN
# ..                                                ...
# 93                               Extremely Agree  - 7
# 94                                                  5
# 95                                                  6
# 96                                                  6
# 97                                                  6
#
#                                                  Q6_3  \
# 0   Please express your agreement with each of the...
# 1                            {"ImportId":"QID172_10"}
# 2                                                   5
# 3                                                   6
# 4                                                 NaN
# ..                                                ...
# 93                               Extremely Agree  - 7
# 94                                                  4
# 95                                                NaN
# 96                                                  6
# 97                                                  6
#
#                                                  Q6_4  \
# 0   Please express your agreement with each of the...
# 1                            {"ImportId":"QID172_12"}
# 2                                                   5
# 3                                                   6
# 4                                                 NaN
# ..                                                ...
# 93                               Extremely Agree  - 7
# 94                                                NaN
# 95                               Extremely Agree  - 7
# 96                                                  5
# 97                                                  6
#
#                                                  Q6_5  \
# 0   Please express your agreement with each of the...
# 1                            {"ImportId":"QID172_13"}
# 2                                                   5
# 3                                                   5
# 4                                                 NaN
# ..                                                ...
# 93                               Extremely Agree  - 7
# 94                                                NaN
# 95                               Extremely Agree  - 7
# 96                                                  5
# 97                                                  6
#
#                                                   Q6A  \
# 0   Why would you not consider VMware a strategic ...
# 1                          {"ImportId":"QID177_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_1  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"1"}
# 2   Datacenter solutions \n\n VMware vSphere, VMwa...
# 3   Datacenter solutions \n\n VMware vSphere, VMwa...
# 4   Datacenter solutions \n\n VMware vSphere, VMwa...
# ..                                                ...
# 93  Datacenter solutions \n\n VMware vSphere, VMwa...
# 94  Datacenter solutions \n\n VMware vSphere, VMwa...
# 95  Datacenter solutions \n\n VMware vSphere, VMwa...
# 96  Datacenter solutions \n\n VMware vSphere, VMwa...
# 97  Datacenter solutions \n\n VMware vSphere, VMwa...
#
#                                                  Q7_2  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"2"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Private Cloud\n\n VMware Cloud Foundation (VCF)\n
# 94                                                NaN
# 95  Private Cloud\n\n VMware Cloud Foundation (VCF)\n
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_3  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"3"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Public Cloud\n\n VMware Cloud on AWS, Azure, G...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_4  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"4"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93   Cloud Management\n\n VMware vRealize portfolio\n
# 94                                                NaN
# 95   Cloud Management\n\n VMware vRealize portfolio\n
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_5  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"5"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Modern Application Platform\n\n\tVMware Tanzu ...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_6  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"6"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_7  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"7"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_8  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"8"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q7_9  \
# 0   Which of the following VMware solutions do you...
# 1                {"ImportId":"QID185","choiceId":"9"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                             Q7_9_TEXT  \
# 0   Which of the following VMware solutions do you...
# 1                       {"ImportId":"QID185_17_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_1  \
# 0   Please rate your satisfaction with the followi...
# 1                           {"ImportId":"QID186_x11"}
# 2                            Extremely Satisfied  - 7
# 3                                                   6
# 4                                                   5
# ..                                                ...
# 93                           Extremely Satisfied  - 7
# 94                                                NaN
# 95                           Extremely Satisfied  - 7
# 96                                                  6
# 97                                                  6
#
#                                                 Q7A_2  \
# 0   Please rate your satisfaction with the followi...
# 1                           {"ImportId":"QID186_x12"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                  6
# 94                                                NaN
# 95                           Extremely Satisfied  - 7
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_3  \
# 0   Please rate your satisfaction with the followi...
# 1                           {"ImportId":"QID186_x14"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                  5
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_4  \
# 0   Please rate your satisfaction with the followi...
# 1                           {"ImportId":"QID186_x15"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                  6
# 94                                                NaN
# 95                           Extremely Satisfied  - 7
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_5  \
# 0   Please rate your satisfaction with the followi...
# 1                            {"ImportId":"QID186_x1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                  5
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_6  \
# 0   Please rate your satisfaction with the followi...
# 1                            {"ImportId":"QID186_x5"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_7  \
# 0   Please rate your satisfaction with the followi...
# 1                            {"ImportId":"QID186_x7"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_8  \
# 0   Please rate your satisfaction with the followi...
# 1                            {"ImportId":"QID186_x6"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                 Q7A_9  \
# 0   Please rate your satisfaction with the followi...
# 1                           {"ImportId":"QID186_x17"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                            Q7A_9_TEXT  \
# 0   Please rate your satisfaction with the followi...
# 1                      {"ImportId":"QID186_x17_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_1_1  \
# 0   Please tell us why you gave us the score you d...
# 1                         {"ImportId":"QID190_x11_1"}
# 2                                                 NaN
# 3                         Technisch sehr zuverlÃ¤ssig
# 4   vSphereã‚’ä½¿ã£ã¦ã„ã‚‹ãŒç„¡å„Ÿã§ä½¿ã„å‹...
# ..                                                ...
# 93           ì˜¤ëžœ ê¸°ìˆ ë ¥ ë° ì•ˆì •ì  ì„œë¹„ìŠ¤
# 94                                                NaN
# 95                                                NaN
# 96                                                  8
# 97                                                NaN
#
#                                               Q7B_2_1  \
# 0   Please tell us why you gave us the score you d...
# 1                         {"ImportId":"QID190_x12_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                      ê²©ë¦¬í™”ëœ ê°€ìƒí™” í™˜ê²½
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_3_1  \
# 0   Please tell us why you gave us the score you d...
# 1                         {"ImportId":"QID190_x14_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                      ì‹œìž‘ ë‹¨ê³„
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_4_1  \
# 0   Please tell us why you gave us the score you d...
# 1                         {"ImportId":"QID190_x15_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                  ì‚¬ìš©ìž ì¹œí™”ì ì¸ GUI í•„ìš”
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_5_1  \
# 0   Please tell us why you gave us the score you d...
# 1                          {"ImportId":"QID190_x1_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93        ê²½ìŸì‚¬ ëŒ€ë¹„ ê³ ê°€ ë¼ì´ì„ ìŠ¤ ì •ì±…
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_6_1  \
# 0   Please tell us why you gave us the score you d...
# 1                          {"ImportId":"QID190_x5_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_7_1  \
# 0   Please tell us why you gave us the score you d...
# 1                          {"ImportId":"QID190_x7_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_8_1  \
# 0   Please tell us why you gave us the score you d...
# 1                          {"ImportId":"QID190_x6_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                            Q7B_9_TEXT  \
# 0   Please tell us why you gave us the score you d...
# 1                      {"ImportId":"QID190_x17_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                               Q7B_9_1  \
# 0   Please tell us why you gave us the score you d...
# 1                         {"ImportId":"QID190_x17_1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_1  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_2  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"2"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_3  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"3"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Public Cloud\n\n VMware Cloud on AWS, Azure, G...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_4  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"4"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93   Cloud Management\n\n VMware vRealize portfolio\n
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_5  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"5"}
# 2                                                 NaN
# 3   Modern Application Platform\n\n VMware Tanzu p...
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_6  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"6"}
# 2                                                 NaN
# 3   Digital Workspace (including VDI)\n\n Workspac...
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_7  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"7"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_8  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"8"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q8_9  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                {"ImportId":"QID192","choiceId":"9"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                             Q8_9_TEXT  \
# 0   Which VMware solution(s) are you evaluating to...
# 1                       {"ImportId":"QID192_17_TEXT"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q9_1  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q9_2  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"2"}
# 2                                                 NaN
# 3                                 Expand hybrid cloud
# 4                                                 NaN
# ..                                                ...
# 93                                Expand hybrid cloud
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                Expand hybrid cloud
#
#                                                  Q9_3  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"3"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                     Expand on-prem
# 97                                     Expand on-prem
#
#                                                  Q9_4  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"4"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                  Scale down on-prem
# ..                                                ...
# 93                                 Scale down on-prem
# 94                                 Scale down on-prem
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q9_5  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"5"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                           Accelerate SaaS adoption
# 94                                                NaN
# 95                                                NaN
# 96                           Accelerate SaaS adoption
# 97                                                NaN
#
#                                                  Q9_6  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"6"}
# 2                                                 NaN
# 3                                    Remote workforce
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q9_7  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"7"}
# 2                                                 NaN
# 3                                    Enhance security
# 4                                                 NaN
# ..                                                ...
# 93                                   Enhance security
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                  Q9_8  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"8"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                Business continuity
# 97                                                NaN
#
#                                                  Q9_9  \
# 0   How will your future technology strategy evolv...
# 1                {"ImportId":"QID189","choiceId":"9"}
# 2                           Maintain with less budget
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                          Maintain with less budget
# 94                                                NaN
# 95                                                NaN
# 96                          Maintain with less budget
# 97                          Maintain with less budget
#
#                                               Q10_1_1  \
# 0   Are you interested in providing us with more f...
# 1               {"ImportId":"QID94_1","choiceId":"1"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# ...
# 1   {"ImportId":"language"}  {"ImportId":"person_industry"}
# 2                       NaN                             NaN
# 3                       NaN                           Other
# 4                       NaN                        Services
# ..                      ...                             ...
# 93                      NaN                             NaN
# 94                      NaN                           Other
# 95                      NaN    Education - Higher Education
# 96                      NaN    Banking, Finance & Insurance
# 97                      NaN                             NaN
#
#                    sales_segment                 source  \
# 0                  sales_segment                 source
# 1   {"ImportId":"sales_segment"}  {"ImportId":"source"}
# 2                            NaN                   SFDC
# 3                             C2                    MDH
# 4                            NaN                   SFDC
# ..                           ...                    ...
# 93                            C1                    MDH
# 94                           NaN                    MDH
# 95                           NaN                   SFDC
# 96                            C1                    MDH
# 97                            C2                    MDH
#
#                    account                 TranslationLanguage  \
# 0                  account                 TranslationLanguage
# 1   {"ImportId":"account"}  {"ImportId":"TranslationLanguage"}
# 2                      NaN                                 NaN
# 3                      NaN                                 NaN
# 4                      NaN                                 NaN
# ..                     ...                                 ...
# 93                     NaN                                 NaN
# 94                     NaN                                 NaN
# 95                     NaN                                 NaN
# 96                     NaN                                 NaN
# 97                     NaN                                 NaN
#
#                    CSM                 CMBU_CSM                 EUC_CSM  \
# 0                  CSM                 CMBU_CSM                 EUC_CSM
# 1   {"ImportId":"CSM"}  {"ImportId":"CMBU_CSM"}  {"ImportId":"EUC_CSM"}
# 2                    0                        0                       0
# 3                    0                        0                       0
# 4                    0                        0                       0
# ..                 ...                      ...                     ...
# 93                   0                        0                       0
# 94                   0                        0                       0
# 95                   0                        0                       0
# 96                   0                        0                       0
# 97                   0                        0                       0
#
#                    VMC_CSM                 Hierarchy                 Job Role  \
# 0                  VMC_CSM                 Hierarchy                 Job Role
# 1   {"ImportId":"VMC_CSM"}  {"ImportId":"Hierarchy"}  {"ImportId":"Job Role"}
# 2                        0                       NaN                      NaN
# 3                        0           IT PRACTITIONER    Systems Administrator
# 4                        0        PRACTITIONER-OTHER   Programmer / Developer
# ..                     ...                       ...                      ...
# 93                       0        PRACTITIONER-OTHER                      NaN
# 94                       0           IT PRACTITIONER                    Other
# 95                       0              C-1 LEVEL IT                 Director
# 96                       0              C-1 LEVEL IT                     Head
# 97                       0                       NaN                      NaN
#
#                                Job Title                   ResponseId.1  \
# 0                              Job Title                     ResponseId
# 1               {"ImportId":"Job Title"}  {"ImportId":"QSEDResponseId"}
# 2                                    NaN              R_z5MHD66SVggkg6t
# 3                               Sysadmin              R_2zjzLB3knKnIAdD
# 4         Ã¯Â¿Â½Ã¯Â¿Â½Ã¯Â¼Â³Ã¯Â¼Â²Ã©Æ’Â¨              R_3KAsh8uT0AEb4tX
# ..                                   ...                            ...
# 93                                ë¦¬ë”              R_9z7ZzdUb3OvJHC9
# 94  ã‚¤ãƒ³ãƒ•ã‚©ãƒžãƒ†ã‚£ã‚¯ã‚¹ç ”ç©¶æ‰€              R_1QEiQPOmuJ6cOI8
# 95            Director - Computer Centre              R_12tEDhx7Xh0xvpx
# 96                                 VP IT              R_5jo5yLKGWy8RTz3
# 97                                   NaN              R_2tl2p0IibZMIGgx
#
#                    FINALREGION                 WEIGHT                 CB_CSM  \
# 0                  FINALREGION                 WEIGHT                 CB_CSM
# 1   {"ImportId":"FINALREGION"}  {"ImportId":"WEIGHT"}  {"ImportId":"CB_CSM"}
# 2                          NaN            0.787109635                      0
# 3                          NaN            0.536990027                      0
# 4                          NaN            0.462734375                      0
# ..                         ...                    ...                    ...
# 93                         NaN            0.787109635                      0
# 94                         NaN            0.462734375                      0
# 95                         NaN            0.429202899                      0
# 96                         NaN            0.429202899                      0
# 97                         NaN            0.462734375                      0
#
#                    WT_SEGMENT                 mobile_device  \
# 0                  WT_SEGMENT                 mobile_device
# 1   {"ImportId":"WT_SEGMENT"}  {"ImportId":"mobile_device"}
# 2                   2HFY22__1                             0
# 3                   2HFY22__1                             0
# 4                   2HFY22__1                             0
# ..                        ...                           ...
# 93                  2HFY22__1                             0
# 94                  2HFY22__1                             0
# 95                  2HFY22__1                             0
# 96                  2HFY22__1                             0
# 97                  2HFY22__1                             0
#
#                                                Q4A_EN  \
# 0   Why would you not consider VMware a trusted ad...
# 1      {"ImportId":"QID166_TEXT_TRANSLATEDenmatveqr"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                    Never relied on
#
#                                             Q2C_EN  \
# 0    What can we do to improve your experience? EN
# 1   {"ImportId":"QID173_TEXT_TRANSLATEDenop80yuv"}
# 2                                              NaN
# 3      Technically top, but always more expensive.
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                             Q6a_EN  \
# 0                                           q6a_EN
# 1   {"ImportId":"QID177_TEXT_TRANSLATEDenbxu5qq0"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                                Q2A_EN  \
# 0   Your feedback goes a long way to helping us bu...
# 1      {"ImportId":"QID179_TEXT_TRANSLATEDenfwltfjs"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  It is the most stable solution with long-stand...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                                Q2B_EN  \
# 0   Your feedback goes a long way to helping us bu...
# 1      {"ImportId":"QID180_TEXT_TRANSLATEDen9ewb5mw"}
# 2                                                 NaN
# 3                                                 NaN
# 4   I'm not impressed that anyone other than mysel...
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                              Q7b_1_EN  \
# 0                                            q7b_1_EN
# 1     {"ImportId":"QID190_x11_1_TRANSLATEDentnqq60m"}
# 2                                                 NaN
# 3                           Technically very reliable
# 4   I am using vSphere, but it is free and easy to...
# ..                                                ...
# 93        Long-standing technology and stable service
# 94                                                NaN
# 95                                                NaN
# 96                                                  8
# 97                                                NaN
#
#                                            Q7b_2_EN  \
# 0                                          q7b_2_EN
# 1   {"ImportId":"QID190_x12_1_TRANSLATEDen2fkokcb"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93              Isolated virtualization environment
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_3_EN  \
# 0                                          q7b_3_EN
# 1   {"ImportId":"QID190_x14_1_TRANSLATEDenfaplxe0"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                                       start step
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_4_EN  \
# 0                                          q7b_4_EN
# 1   {"ImportId":"QID190_x15_1_TRANSLATEDenrkg48f7"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                       User-friendly GUI required
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                            Q7b_9_EN  \
# 0                                          q7b_9_EN
# 1   {"ImportId":"QID190_x17_1_TRANSLATEDenumofwtd"}
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 93                                              NaN
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
#
#                                              Q7b_5_EN  \
# 0                                            q7b_5_EN
# 1      {"ImportId":"QID190_x1_1_TRANSLATEDent3f2pz4"}
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93  Expensive licensing policy compared to competi...
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
#
#                                           Q7b_6_EN  \
# 0                                         q7b_6_EN
# 1   {"ImportId":"QID190_x5_1_TRANSLATEDeni9nif2s"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                           Q7b_8_EN  \
# 0                                         q7b_8_EN
# 1   {"ImportId":"QID190_x6_1_TRANSLATEDentufoyj2"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
#                                           Q7b_7_EN
# 0                                         q7b_7_EN
# 1   {"ImportId":"QID190_x7_1_TRANSLATEDenggjrshl"}
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 93                                             NaN
# 94                                             NaN
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
#
# [98 rows x 118 columns]

# %%
column_list = df.columns.to_list()

# %%
column_list
# Out:
# ['UserLanguage',
#  'Q1_NPS_GROUP',
#  'Q1',
#  'Q2A',
#  'Q2B',
#  'Q2C',
#  'Q3',
#  'Q4',
#  'Q4A',
#  'Q5_1',
#  'Q5_2',
#  'Q5_3',
#  'Q5_4',
#  'Q5_5',
#  'Q5_6',
#  'Q6_1',
#  'Q6_2',
#  'Q6_3',
#  'Q6_4',
#  'Q6_5',
#  'Q6A',
#  'Q7_1',
#  'Q7_2',
#  'Q7_3',
#  'Q7_4',
#  'Q7_5',
#  'Q7_6',
#  'Q7_7',
#  'Q7_8',
#  'Q7_9',
#  'Q7_9_TEXT',
#  'Q7A_1',
#  'Q7A_2',
#  'Q7A_3',
#  'Q7A_4',
#  'Q7A_5',
#  'Q7A_6',
#  'Q7A_7',
#  'Q7A_8',
#  'Q7A_9',
#  'Q7A_9_TEXT',
#  'Q7B_1_1',
#  'Q7B_2_1',
#  'Q7B_3_1',
#  'Q7B_4_1',
#  'Q7B_5_1',
#  'Q7B_6_1',
#  'Q7B_7_1',
#  'Q7B_8_1',
#  'Q7B_9_TEXT',
#  'Q7B_9_1',
#  'Q8_1',
#  'Q8_2',
#  'Q8_3',
#  'Q8_4',
#  'Q8_5',
#  'Q8_6',
#  'Q8_7',
#  'Q8_8',
#  'Q8_9',
#  'Q8_9_TEXT',
#  'Q9_1',
#  'Q9_2',
#  'Q9_3',
#  'Q9_4',
#  'Q9_5',
#  'Q9_6',
#  'Q9_7',
#  'Q9_8',
#  'Q9_9',
#  'Q10_1_1',
#  'Q11_1',
#  'Wave',
#  'WaveUpdate',
#  'complete_status',
#  'SurveyID',
#  'ResponseID',
#  'Subject',
#  'PanelID',
#  'Language',
#  'RecipientLanguage',
#  'Q_Language',
#  'person_geo',
#  'person_region',
#  'person_country',
#  'language',
#  'person_industry',
#  'sales_segment',
#  'source',
#  'account',
#  'TranslationLanguage',
#  'CSM',
#  'CMBU_CSM',
#  'EUC_CSM',
#  'VMC_CSM',
#  'Hierarchy',
#  'Job Role',
#  'Job Title',
#  'ResponseId.1',
#  'FINALREGION',
#  'WEIGHT',
#  'CB_CSM',
#  'WT_SEGMENT',
#  'mobile_device',
#  'Q4A_EN',
#  'Q2C_EN',
#  'Q6a_EN',
#  'Q2A_EN',
#  'Q2B_EN',
#  'Q7b_1_EN',
#  'Q7b_2_EN',
#  'Q7b_3_EN',
#  'Q7b_4_EN',
#  'Q7b_9_EN',
#  'Q7b_5_EN',
#  'Q7b_6_EN',
#  'Q7b_8_EN',
#  'Q7b_7_EN']

# %%
df['Q1']
# Out:
# 0     How likely are you to recommend VMware product...
# 1                                   {"ImportId":"QID8"}
# 2                                                     9
# 3                                                     8
# 4                                                     5
#                             ...
# 93                                                   10
# 94                                                    5
# 95                                                    9
# 96                                                    8
# 97                                                    8
# Name: Q1, Length: 98, dtype: object

# %%
dfA=df['Q1']

# %%
dfA
# Out:
# 0     How likely are you to recommend VMware product...
# 1                                   {"ImportId":"QID8"}
# 2                                                     9
# 3                                                     8
# 4                                                     5
#                             ...
# 93                                                   10
# 94                                                    5
# 95                                                    9
# 96                                                    8
# 97                                                    8
# Name: Q1, Length: 98, dtype: object

# %%
dfA.shape
# Out:
# (98,)

# %%
dfA.isna().any()
# Out:
# False

# %%
dfA=dfA.iloc[2:]

# %%
dfA
# Out:
# 2      9
# 3      8
# 4      5
# 5     10
# 6     10
#       ..
# 93    10
# 94     5
# 95     9
# 96     8
# 97     8
# Name: Q1, Length: 96, dtype: object

# %%
dfA.value_counts()
# Out:
# 10    39
# 8     19
# 9     15
# 7      8
# 5      7
# 6      3
# 3      3
# 0      2
# Name: Q1, dtype: int64

# %% [markdown]
# The no of PROMOTERS (customers who have given an NPS rating of 9 and 10) are 54 and the no of DEFRACTORS (the customers who have given a rating from 0-5) are 15
#
# So the proportion of promoters are 54/96 and proportion of defractors are 15/96
# =0.56-0.15=0.41
#
# 41% customers would promote VMWare Products.

# %%
dfB=df[['Q1','Q1_NPS_GROUP']]

# %%
dfB=dfB.iloc[2:]

# %%
dfB
# Out:
#     Q1 Q1_NPS_GROUP
# 2    9     Promoter
# 3    8      Passive
# 4    5    Detractor
# 5   10     Promoter
# 6   10     Promoter
# ..  ..          ...
# 93  10     Promoter
# 94   5    Detractor
# 95   9     Promoter
# 96   8      Passive
# 97   8      Passive
#
# [96 rows x 2 columns]

# %%
import seaborn as sns

# %%
dfB.Q1_NPS_GROUP.replace(to_replace=['Promoter','Passive','Detractor'],value=[1,0.5,0],inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
dfB
# Out:
#     Q1  Q1_NPS_GROUP
# 2    9           1.0
# 3    8           0.5
# 4    5           0.0
# 5   10           1.0
# 6   10           1.0
# ..  ..           ...
# 93  10           1.0
# 94   5           0.0
# 95   9           1.0
# 96   8           0.5
# 97   8           0.5
#
# [96 rows x 2 columns]

# %%
dfB['Q1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7f/yr_0jr414x37m5lnt3g2y5pc0000gn/T/ipykernel_42838/2697041313.py in <module>
# ----> 1 dfB['Q1'].value_counts()
#
# NameError: name 'dfB' is not defined

# %%
sns.catplot(x='Q1', y='Q1_NPS_GROUP',data=dfB,kind='bar',aspect=2)

# %% [markdown]
# # MAin Code

# %%
df = df[['Q1_NPS_GROUP',
'Q1',
'Q4',
'Q5_1',
'Q5_2',
'Q5_3',
'Q5_4',
'Q5_5',
'Q5_6',
'Q6_1',
'Q6_2',
'Q6_3',
'Q6_4',
'Q6_5',
'Q7A_1',
'Q7A_2',
'Q7A_3',
'Q7A_4',
'Q7A_5',
'Q7A_6',
'Q7A_7',
'Q7A_8',
'Q7A_9']]

# %%
df = df.loc[2:]

# %%
df.columns
# Out:
# Index(['Q1_NPS_GROUP', 'Q1', 'Q4', 'Q5_1', 'Q5_2', 'Q5_3', 'Q5_4', 'Q5_5',
#        'Q5_6', 'Q6_1', 'Q6_2', 'Q6_3', 'Q6_4', 'Q6_5', 'Q7A_1', 'Q7A_2',
#        'Q7A_3', 'Q7A_4', 'Q7A_5', 'Q7A_6', 'Q7A_7', 'Q7A_8', 'Q7A_9'],
#       dtype='object')

# %%
df['Q1_NPS_GROUP'].value_counts()
# Out:
# Promoter     54
# Passive      27
# Detractor    15
# Name: Q1_NPS_GROUP, dtype: int64

# %%
df.Q1_NPS_GROUP.replace(to_replace=['Promoter','Passive','Detractor'],
                        value=[2,1,0],
                         inplace = True)

# %%
df
# Out:
#     Q1_NPS_GROUP  Q1   Q4 Q5_1                        Q5_2 Q5_3  \
# 2              2   9  Yes    5                           5    5
# 3              1   8  Yes    3                           6    4
# 4              0   5  Yes    5                           4  NaN
# 5              2  10  Yes    5                           6    5
# 6              2  10  Yes  NaN                         NaN  NaN
# ..           ...  ..  ...  ...                         ...  ...
# 93             2  10  Yes    5                           6    6
# 94             0   5  Yes  NaN                         NaN  NaN
# 95             2   9  Yes    6  Extremely Satisfied  -   7    6
# 96             1   8  Yes    4                           5    6
# 97             1   8   No    6                           6    6
#
#                           Q5_4                        Q5_5  \
# 2                            5                           6
# 3                            4                           6
# 4                          NaN                         NaN
# 5                            6  Extremely Satisfied  -   7
# 6                          NaN                         NaN
# ..                         ...                         ...
# 93                           6  Extremely Satisfied  -   7
# 94                           5                           5
# 95  Extremely Satisfied  -   7  Extremely Satisfied  -   7
# 96                           5                           6
# 97                           6                           6
#
#                           Q5_6 Q6_1  ...                  Q6_5  \
# 2                            6    5  ...                     5
# 3                            5    5  ...                     5
# 4                          NaN  NaN  ...                   NaN
# 5                            6    5  ...                   NaN
# 6                          NaN  NaN  ...                   NaN
# ..                         ...  ...  ...                   ...
# 93                           6    6  ...  Extremely Agree  - 7
# 94                         NaN    4  ...                   NaN
# 95  Extremely Satisfied  -   7    5  ...  Extremely Agree  - 7
# 96                           6    6  ...                     5
# 97                           6    6  ...                     6
#
#                        Q7A_1                     Q7A_2 Q7A_3  \
# 2   Extremely Satisfied  - 7                       NaN   NaN
# 3                          6                       NaN   NaN
# 4                          5                       NaN   NaN
# 5                          6                       NaN   NaN
# 6                        NaN                       NaN   NaN
# ..                       ...                       ...   ...
# 93  Extremely Satisfied  - 7                         6     5
# 94                       NaN                       NaN   NaN
# 95  Extremely Satisfied  - 7  Extremely Satisfied  - 7   NaN
# 96                         6                       NaN   NaN
# 97                         6                       NaN   NaN
#
#                        Q7A_4 Q7A_5 Q7A_6 Q7A_7 Q7A_8 Q7A_9
# 2                        NaN   NaN   NaN   NaN   NaN   NaN
# 3                        NaN   NaN   NaN   NaN   NaN   NaN
# 4                        NaN   NaN   NaN   NaN   NaN   NaN
# 5                        NaN   NaN   NaN   NaN   NaN   NaN
# 6                        NaN   NaN   NaN   NaN   NaN   NaN
# ..                       ...   ...   ...   ...   ...   ...
# 93                         6     5   NaN   NaN   NaN   NaN
# 94                       NaN   NaN   NaN   NaN   NaN   NaN
# 95  Extremely Satisfied  - 7   NaN   NaN   NaN   NaN   NaN
# 96                       NaN   NaN   NaN   NaN   NaN   NaN
# 97                       NaN   NaN   NaN   NaN   NaN   NaN
#
# [96 rows x 23 columns]

# %%
df.Q4.replace(to_replace=['Yes','No'],
                        value=[1,0],
                         inplace = True)

# %%
df.Q4.value_counts()
# Out:
# 1.0    82
# 0.0    12
# Name: Q4, dtype: int64

# %%
df
# Out:
#     Q1_NPS_GROUP  Q1   Q4 Q5_1                        Q5_2 Q5_3  \
# 2              2   9  1.0    5                           5    5
# 3              1   8  1.0    3                           6    4
# 4              0   5  1.0    5                           4  NaN
# 5              2  10  1.0    5                           6    5
# 6              2  10  1.0  NaN                         NaN  NaN
# ..           ...  ..  ...  ...                         ...  ...
# 93             2  10  1.0    5                           6    6
# 94             0   5  1.0  NaN                         NaN  NaN
# 95             2   9  1.0    6  Extremely Satisfied  -   7    6
# 96             1   8  1.0    4                           5    6
# 97             1   8  0.0    6                           6    6
#
#                           Q5_4                        Q5_5  \
# 2                            5                           6
# 3                            4                           6
# 4                          NaN                         NaN
# 5                            6  Extremely Satisfied  -   7
# 6                          NaN                         NaN
# ..                         ...                         ...
# 93                           6  Extremely Satisfied  -   7
# 94                           5                           5
# 95  Extremely Satisfied  -   7  Extremely Satisfied  -   7
# 96                           5                           6
# 97                           6                           6
#
#                           Q5_6 Q6_1  ...                  Q6_5  \
# 2                            6    5  ...                     5
# 3                            5    5  ...                     5
# 4                          NaN  NaN  ...                   NaN
# 5                            6    5  ...                   NaN
# 6                          NaN  NaN  ...                   NaN
# ..                         ...  ...  ...                   ...
# 93                           6    6  ...  Extremely Agree  - 7
# 94                         NaN    4  ...                   NaN
# 95  Extremely Satisfied  -   7    5  ...  Extremely Agree  - 7
# 96                           6    6  ...                     5
# 97                           6    6  ...                     6
#
#                        Q7A_1                     Q7A_2 Q7A_3  \
# 2   Extremely Satisfied  - 7                       NaN   NaN
# 3                          6                       NaN   NaN
# 4                          5                       NaN   NaN
# 5                          6                       NaN   NaN
# 6                        NaN                       NaN   NaN
# ..                       ...                       ...   ...
# 93  Extremely Satisfied  - 7                         6     5
# 94                       NaN                       NaN   NaN
# 95  Extremely Satisfied  - 7  Extremely Satisfied  - 7   NaN
# 96                         6                       NaN   NaN
# 97                         6                       NaN   NaN
#
#                        Q7A_4 Q7A_5 Q7A_6 Q7A_7 Q7A_8 Q7A_9
# 2                        NaN   NaN   NaN   NaN   NaN   NaN
# 3                        NaN   NaN   NaN   NaN   NaN   NaN
# 4                        NaN   NaN   NaN   NaN   NaN   NaN
# 5                        NaN   NaN   NaN   NaN   NaN   NaN
# 6                        NaN   NaN   NaN   NaN   NaN   NaN
# ..                       ...   ...   ...   ...   ...   ...
# 93                         6     5   NaN   NaN   NaN   NaN
# 94                       NaN   NaN   NaN   NaN   NaN   NaN
# 95  Extremely Satisfied  - 7   NaN   NaN   NaN   NaN   NaN
# 96                       NaN   NaN   NaN   NaN   NaN   NaN
# 97                       NaN   NaN   NaN   NaN   NaN   NaN
#
# [96 rows x 23 columns]

# %%
df.Q5_1.value_counts()
# Out:
# 5                               24
# Extremely Satisfied  -   7      17
# 6                               15
# 3                                8
# 4                                8
# 2                                7
# Extremely Dissatisfied  -  1     3
# Name: Q5_1, dtype: int64

# %%
df.Q5_1.isna().sum()
# Out:
# 14

# %%
df.columns
# Out:
# Index(['Q1_NPS_GROUP', 'Q1', 'Q4', 'Q5_1', 'Q5_2', 'Q5_3', 'Q5_4', 'Q5_5',
#        'Q5_6', 'Q6_1', 'Q6_2', 'Q6_3', 'Q6_4', 'Q6_5', 'Q7A_1', 'Q7A_2',
#        'Q7A_3', 'Q7A_4', 'Q7A_5', 'Q7A_6', 'Q7A_7', 'Q7A_8', 'Q7A_9'],
#       dtype='object')

# %%
# for col in list(df)[3:]:
#     df[col] = df[col].replace(['Extremely Satisfied  -   7','Extremely Dissatisfied  -  1']
#                                ,[7,1])

# %%
# for col in list(df)[14:]:
#     df[col] = df[col].replace(['Extremely Satisfied  - 7','Extremely Dissatisfied  -  1']
#                                ,[7,1])

# %%
df.Q7A_1.values
# Out:
# array(['Extremely Satisfied  - 7', '6', '5', '6', nan, '5',
#        'Extremely Satisfied  - 7', '6', '6', 'Extremely Satisfied  - 7',
#        nan, nan, nan, 'Extremely Satisfied  - 7',
#        'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7', '4', '6',
#        '5', 'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7', '5',
#        '5', '5', 'Extremely Satisfied  - 7', '5', '5',
#        'Extremely Satisfied  - 7', nan, 'Extremely Satisfied  - 7',
#        'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7', nan,
#        'Extremely Satisfied  - 7', nan, '6', '6', '6', '6', '6', nan,
#        'Extremely Satisfied  - 7', nan, '6', nan, nan, '5', '5',
#        'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7',
#        'Extremely Satisfied  - 7', nan, '6', '5', '6',
#        'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7', '6', nan,
#        nan, nan, 'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7',
#        '4', nan, 'Extremely Satisfied  - 7', '6',
#        'Extremely Satisfied  - 7', nan, 'Extremely Satisfied  - 7', nan,
#        nan, 'Extremely Satisfied  - 7', '5', 'Extremely Satisfied  - 7',
#        nan, nan, '5', '5', 'Extremely Satisfied  - 7',
#        'Extremely Dissatisfied - 1', 'Extremely Satisfied  - 7', '6', '6',
#        nan, '6', nan, '6', '6', 'Extremely Satisfied  - 7',
#        'Extremely Satisfied  - 7', 'Extremely Satisfied  - 7', nan,
#        'Extremely Satisfied  - 7', '6', '6'], dtype=object)

# %%
for col in list(df)[3:]:
    df[col] = df[col].apply(lambda x: x if isinstance(x,float) else (x.split()[-1] if len(x.split())>1 else x))

# %%
df
# Out:
#     Q1_NPS_GROUP  Q1   Q4 Q5_1 Q5_2 Q5_3 Q5_4 Q5_5 Q5_6 Q6_1  ... Q6_5 Q7A_1  \
# 2              2   9  1.0    5    5    5    5    6    6    5  ...    5     7
# 3              1   8  1.0    3    6    4    4    6    5    5  ...    5     6
# 4              0   5  1.0    5    4  NaN  NaN  NaN  NaN  NaN  ...  NaN     5
# 5              2  10  1.0    5    6    5    6    7    6    5  ...  NaN     6
# 6              2  10  1.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN   NaN
# ..           ...  ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 93             2  10  1.0    5    6    6    6    7    6    6  ...    7     7
# 94             0   5  1.0  NaN  NaN  NaN    5    5  NaN    4  ...  NaN   NaN
# 95             2   9  1.0    6    7    6    7    7    7    5  ...    7     7
# 96             1   8  1.0    4    5    6    5    6    6    6  ...    5     6
# 97             1   8  0.0    6    6    6    6    6    6    6  ...    6     6
#
#    Q7A_2 Q7A_3 Q7A_4 Q7A_5 Q7A_6 Q7A_7 Q7A_8 Q7A_9
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..   ...   ...   ...   ...   ...   ...   ...   ...
# 93     6     5     6     5   NaN   NaN   NaN   NaN
# 94   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 95     7   NaN     7   NaN   NaN   NaN   NaN   NaN
# 96   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 97   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [96 rows x 23 columns]

# %%
imp_col = []
for col in list(df):
    cnt = df[col].isna().sum()
    per = cnt*100/len(df)
    if per<30:
        imp_col.append(col)
#     print(col,'-->',df[col].isna().sum())

# %%
df = df[imp_col]

# %%
for col in df:
    df[col] = df[col].astype('float')
    df[col] = round(df[col].fillna(df[col].mean()))

# %%
df
# Out:
#     Q1_NPS_GROUP    Q1   Q4  Q5_1  Q5_2  Q5_3  Q5_4  Q5_5  Q5_6  Q6_1  Q6_2  \
# 2            2.0   9.0  1.0   5.0   5.0   5.0   5.0   6.0   6.0   5.0   4.0
# 3            1.0   8.0  1.0   3.0   6.0   4.0   4.0   6.0   5.0   5.0   6.0
# 4            0.0   5.0  1.0   5.0   4.0   5.0   6.0   6.0   6.0   5.0   6.0
# 5            2.0  10.0  1.0   5.0   6.0   5.0   6.0   7.0   6.0   5.0   6.0
# 6            2.0  10.0  1.0   5.0   5.0   5.0   6.0   6.0   6.0   5.0   6.0
# ..           ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 93           2.0  10.0  1.0   5.0   6.0   6.0   6.0   7.0   6.0   6.0   7.0
# 94           0.0   5.0  1.0   5.0   5.0   5.0   5.0   5.0   6.0   4.0   5.0
# 95           2.0   9.0  1.0   6.0   7.0   6.0   7.0   7.0   7.0   5.0   6.0
# 96           1.0   8.0  1.0   4.0   5.0   6.0   5.0   6.0   6.0   6.0   6.0
# 97           1.0   8.0  0.0   6.0   6.0   6.0   6.0   6.0   6.0   6.0   6.0
#
#     Q6_3  Q6_4  Q6_5  Q7A_1
# 2    5.0   5.0   5.0    7.0
# 3    6.0   6.0   5.0    6.0
# 4    6.0   6.0   6.0    5.0
# 5    5.0   5.0   6.0    6.0
# 6    6.0   6.0   6.0    6.0
# ..   ...   ...   ...    ...
# 93   7.0   7.0   7.0    7.0
# 94   4.0   6.0   6.0    6.0
# 95   6.0   7.0   7.0    7.0
# 96   6.0   5.0   5.0    6.0
# 97   6.0   6.0   6.0    6.0
#
# [96 rows x 15 columns]

# %%
# promoter: 2
# destractor: 1
# passive: 0

# %%
df['Q1_NPS_GROUP'].value_counts()
# Out:
# 2.0    54
# 1.0    27
# 0.0    15
# Name: Q1_NPS_GROUP, dtype: int64

# %%
# data imbalance

# %%
x  = df['Q1'].value_counts()

# %%
x.index
# Out:
# Float64Index([10.0, 8.0, 9.0, 7.0, 5.0, 3.0, 6.0, 0.0], dtype='float64')

# %%
x  =df['Q1'].value_counts()
plt.bar(x.index,x)
plt.xlabel('rating')
plt.ylabel('Frequency')
plt.show()

# %%
df.corr()
# Out:
#               Q1_NPS_GROUP        Q1        Q4      Q5_1      Q5_2      Q5_3  \
# Q1_NPS_GROUP      1.000000  0.906000  0.206349  0.388348  0.438717  0.452819
# Q1                0.906000  1.000000  0.340281  0.451635  0.487968  0.500482
# Q4                0.206349  0.340281  1.000000 -0.020203  0.099442  0.165177
# Q5_1              0.388348  0.451635 -0.020203  1.000000  0.599758  0.573796
# Q5_2              0.438717  0.487968  0.099442  0.599758  1.000000  0.856011
# Q5_3              0.452819  0.500482  0.165177  0.573796  0.856011  1.000000
# Q5_4              0.455093  0.547805  0.127995  0.561138  0.649883  0.699602
# Q5_5              0.494466  0.553419  0.104793  0.574025  0.602161  0.582622
# Q5_6              0.472405  0.515017  0.111154  0.597343  0.708882  0.705111
# Q6_1              0.607407  0.683866  0.127132  0.581604  0.619471  0.654546
# Q6_2              0.542714  0.622206  0.144473  0.582083  0.619389  0.572220
# Q6_3              0.588039  0.646390  0.101128  0.567297  0.526994  0.518593
# Q6_4              0.520370  0.633911  0.170698  0.689536  0.627407  0.570442
# Q6_5              0.515268  0.620300  0.184204  0.484902  0.530230  0.471282
# Q7A_1             0.477539  0.526549  0.078143  0.551325  0.609721  0.585005
#
#                   Q5_4      Q5_5      Q5_6      Q6_1      Q6_2      Q6_3  \
# Q1_NPS_GROUP  0.455093  0.494466  0.472405  0.607407  0.542714  0.588039
# Q1            0.547805  0.553419  0.515017  0.683866  0.622206  0.646390
# Q4            0.127995  0.104793  0.111154  0.127132  0.144473  0.101128
# Q5_1          0.561138  0.574025  0.597343  0.581604  0.582083  0.567297
# Q5_2          0.649883  0.602161  0.708882  0.619471  0.619389  0.526994
# Q5_3          0.699602  0.582622  0.705111  0.654546  0.572220  0.518593
# Q5_4          1.000000  0.753628  0.801700  0.703565  0.656578  0.591964
# Q5_5          0.753628  1.000000  0.781395  0.622727  0.599941  0.718412
# Q5_6          0.801700  0.781395  1.000000  0.717158  0.721705  0.646530
# Q6_1          0.703565  0.622727  0.717158  1.000000  0.732549  0.727639
# Q6_2          0.656578  0.599941  0.721705  0.732549  1.000000  0.694432
# Q6_3          0.591964  0.718412  0.646530  0.727639  0.694432  1.000000
# Q6_4          0.665147  0.695590  0.680382  0.691325  0.784210  0.790195
# Q6_5          0.650895  0.605760  0.712224  0.748339  0.747723  0.726714
# Q7A_1         0.563217  0.735839  0.656991  0.572320  0.540483  0.649460
#
#                   Q6_4      Q6_5     Q7A_1
# Q1_NPS_GROUP  0.520370  0.515268  0.477539
# Q1            0.633911  0.620300  0.526549
# Q4            0.170698  0.184204  0.078143
# Q5_1          0.689536  0.484902  0.551325
# Q5_2          0.627407  0.530230  0.609721
# Q5_3          0.570442  0.471282  0.585005
# Q5_4          0.665147  0.650895  0.563217
# Q5_5          0.695590  0.605760  0.735839
# Q5_6          0.680382  0.712224  0.656991
# Q6_1          0.691325  0.748339  0.572320
# Q6_2          0.784210  0.747723  0.540483
# Q6_3          0.790195  0.726714  0.649460
# Q6_4          1.000000  0.783032  0.693592
# Q6_5          0.783032  1.000000  0.572541
# Q7A_1         0.693592  0.572541  1.000000

# %%
# implement classification logistic/SVM , DT
# insampling/outsampling

# %% [markdown]
# eam,
#   I need all 4 of you to work together and merge your Jupyter files into 1 common version.  The "common " file should provide us the following:
# - A common initial version should include:
#   - proper columns renamed
#   - proper column dropping(needs to be careful, don't drop anything not sure)
#   - proper typing (like Data/Time)
#   - proper cleanup on Nan (needs to be careful)
#   - initial analysis graphs on color consistency
# 1) There are a lot of fields in the survey data, I would suggest the most important fields to focus on for analyses are these ones (along with NPS and other 1-7 likert scale questions)
#
# Q3: Role Question (different roles)
#
# Q4: Trusted Advisor (Yes, No)
#
# Q7_1 - Q7_8: Franchise Selection (skip Q7_9 free text other)
#
# person_geo:  APJ, EMEA, AMER
#
#
#
# 2) Moumi pointed out that Q10_1_1 was missing from the actual survey. This is a question inviting respondents to inner circle community, this question only appeared under strict conditions and very few people received it.
#
#
#
# 3) It may be helpful to clean some of the fields up, here are some suggested transformations:
#
#
#
# Q3, string extract:
#
# Practioner, Budget Owner, Influencer, Non-IT Influencer, Partner
#
#
#
# Q5_1 - Q5_6, Q6_1 - Q6_5, Q7A1 - Q7A9
#
# string extract regex code = ‘\d’
#
# (blanks = NA)
#
#
#
# Let me know if there are additional questions.
