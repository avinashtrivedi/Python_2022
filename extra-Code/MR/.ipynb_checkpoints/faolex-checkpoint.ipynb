# %%
# https://www.fao.org/faolex/opendata/en/

import pandas as pd

# %%
# http://extwprlegs1.fao.org/docs/pdf/FAOLEX_Agriculture.zip?
# download the data from above link and save 
# enter the correct path and load the dataset

df = pd.read_csv('E:\dataset\FAOLEX_Agriculture.csv')

# %%
# check one entry for Fisheries and Agriculture based on Record Id
df[(df['Record Id']=='LEX-FAOC096511') | (df['Record Id']=='LEX-FAOC022343')].T
# Out:
#                                                                      72874  \
# Record Id                                                   LEX-FAOC022343
# Record URL               http://www.fao.org/faolex/results/details/en/c...
# Document URL             http://faolex.fao.org/docs/pdf/niu22343.pdf; h...
# Title                    Territorial Sea and Exclusive Economic Zone Ac...
# Original title                                                         NaN
# Date of original text                                           30-04-1997
# Last amended date                                                  12-2006
# Available website                                           www.paclii.org
# Language of document                                               English
# Country/Territory                                       Niue (New Zealand)
# Regional organizations                                                 NaN
# Territorial subdivision                                                NaN
# Type of text                                                   Legislation
# Repealed                                                               NaN
# Abstract                 An Act to establish a territorial sea and an E...
# Primary subjects                                            Fisheries; Sea
# Domain                                                      Fisheries; Sea
# Keywords                 basic legislation; fishery management and cons...
#
#                                                                      80809
# Record Id                                                   LEX-FAOC096511
# Record URL               http://www.fao.org/faolex/results/details/en/c...
# Document URL                   http://faolex.fao.org/docs/pdf/den96511.pdf
# Title                             Rural Development Act (No. 316 of 2007).
# Original title           Lov om udvikling af landdistrikterne (landdist...
# Date of original text                                           31-03-2007
# Last amended date                                                      NaN
# Available website                                              retsinfo.dk
# Language of document                                                Danish
# Country/Territory                                                  Denmark
# Regional organizations                                                 NaN
# Territorial subdivision                                                NaN
# Type of text                                                   Legislation
# Repealed                                                                 Y
# Abstract                 The Act is intended to contribute to the susta...
# Primary subjects                          Agricultural & rural development
# Domain                                            Agriculture; Land & soil
# Keywords                 basic legislation; agricultural development; f...

# %%
list(df)
# Out:
# ['Record Id',
#  'Record URL',
#  'Document URL',
#  'Title',
#  'Original title',
#  'Date of original text',
#  'Last amended date',
#  'Available website',
#  'Language of document',
#  'Country/Territory',
#  'Regional organizations',
#  'Territorial subdivision',
#  'Type of text',
#  'Repealed',
#  'Abstract',
#  'Primary subjects',
#  'Domain',
#  'Keywords']

# %%
# select necessary columns
imp_col = ['Record Id','Abstract','Title','Type of text','Date of original text','Document URL',
 'Keywords','Country/Territory','Primary subjects','Domain','Repealed','Territorial subdivision']

# %%
# filter the dataframe
df = df[imp_col]

# %%
# new columns to be created based on few key word search
new_col = ['digital innovations','data infrastructure', 'business development',
          'enabling environments for digitalization']

# key words to look for, while creating new columns
key_dict = {'digital innovations':['digital', 'development', 'innovation', 'tech', 'advance', 'advancement'],
            'data infrastructure' :['data', 'development', 'tech', 'info'],
            'business development':['business', 'development', 'growth'],
            'enabling environments for digitalization' : ['enabling', 'enable', 'supporting']}

# %%
# function to search keyword within abstract (text)
def search(keys,text):
    
    # if text is string then it will search the keywords
    if isinstance(text,str):
        return any(key in text for key in keys)
    
    # for few entry there is no abstract i.e NaN, therefore handle it in else case
    else:
        return False
    
for col in new_col:
    df[col] = df['Abstract'].apply(lambda text:'Yes' if search(key_dict[col],text) else 'No')

# %%
df.head()
# Out:
#         Record Id                                           Abstract  \
# 0  LEX-FAOC027670  The purpose of this Act is to enact appropriat...
# 1  LEX-FAOC029030  Cette loi modifie les loi suivantes: Loi du 15...
# 2  LEX-FAOC043198  La presente Ley crea las organizaciones de cad...
# 3  LEX-FAOC095279  This Decision approves the Scheme on the devel...
# 4  LEX-FAOC121539  This Regional Act sets out the legislative fra...
#
#                                                Title Type of text  \
# 0  Act on Japanese Agricultural Standards (Act No...  Legislation
# 1  Loi portant des dispositions diverses et relat...  Legislation
# 2  Ley Nº 811 - Crea las organizaciones de cadena...  Legislation
# 3  Decision No. 2194/QD-TTg approving the Scheme ...   Regulation
# 4  Regional Act No. 31 on agriculture, forests, f...  Legislation
#
#   Date of original text                                       Document URL  \
# 0            11-05-1950  http://faolex.fao.org/docs/pdf/jap27670.pdf; h...
# 1            05-02-1999        http://faolex.fao.org/docs/pdf/bel29030.pdf
# 2            26-06-2003        http://faolex.fao.org/docs/pdf/col43198.pdf
# 3            25-12-2009        http://faolex.fao.org/docs/pdf/vie95279.pdf
# 4            05-12-2008       http://faolex.fao.org/docs/pdf/ita121539.pdf
#
#                                             Keywords Country/Territory  \
# 0  basic legislation; certification; standards; i...             Japan
# 1  special fund; financial agricultural measures;...           Belgium
# 2  agricultural development; institution; extensi...          Colombia
# 3  agricultural development; indigenous peoples; ...          Viet Nam
# 4  agricultural development; subsidy/incentive; a...             Italy
#
#                                     Primary subjects  \
# 0  Agricultural & rural development; Food & nutri...
# 1                   Agricultural & rural development
# 2                   Agricultural & rural development
# 3                       Fisheries; Cultivated plants
# 4                   Agricultural & rural development
#
#                                               Domain Repealed  \
# 0  Agriculture; Livestock; Food & nutrition; Fish...      NaN
# 1  Agriculture; Fisheries; Food & nutrition; Fore...      NaN
# 2  Agriculture; Livestock; Food & nutrition; Fish...      NaN
# 3  Agriculture; Livestock; Fisheries; Forestry; C...      NaN
# 4  Agriculture; Livestock; Fisheries; Forestry; C...      NaN
#
#   Territorial subdivision digital innovations data infrastructure  \
# 0                     NaN                 Yes                 Yes
# 1                     NaN                  No                  No
# 2                     NaN                  No                 Yes
# 3                     NaN                 Yes                 Yes
# 4               Lombardia                 Yes                 Yes
#
#   business development enabling environments for digitalization
# 0                  Yes                                       No
# 1                   No                                       No
# 2                   No                                       No
# 3                  Yes                                       No
# 4                  Yes                                       No

# %%
# save the dataframe as csv
df.to_csv('Complete_faolex_data.csv')

# %%
df['Document URL']
# Out:
# 0        http://faolex.fao.org/docs/pdf/jap27670.pdf; h...
# 1              http://faolex.fao.org/docs/pdf/bel29030.pdf
# 2              http://faolex.fao.org/docs/pdf/col43198.pdf
# 3              http://faolex.fao.org/docs/pdf/vie95279.pdf
# 4             http://faolex.fao.org/docs/pdf/ita121539.pdf
#                                ...
# 92893    http://faolex.fao.org/docs/pdf/uk38493original...
# 92894    http://faolex.fao.org/docs/pdf/est98238ENG.pdf...
# 92895          http://faolex.fao.org/docs/pdf/uk154195.pdf
# 92896         http://faolex.fao.org/docs/pdf/nsw197684.pdf
# 92897         http://faolex.fao.org/docs/pdf/uru189494.pdf
# Name: Document URL, Length: 92898, dtype: object

# %%
d = pd.read_csv('test (6).csv')

# %%
d['Link'][10]
# Out:
# 'AUSTRALIA’S TECH FUTURE (industry.gov.au)'

# %%
d
# Out:
#                                                  Title  \
# 0    Information and Communication Technologies Pol...
# 1                             Data Protection Act 2013
# 2    Electronic Crimes Act 2013 & Electronic Crimes...
# 3    Electronic Transactions Act 2013 & Electronic ...
# 4    G.A.T.E. Government Assisted Technology Endeavour
# ..                                                 ...
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
#
#                                                   Link  \
# 0    Information\nand Communication Technologies Po...
# 1    Antigua and Barbuda - Data Protection Act 2013...
# 2    Electronic Crimes Act 2013 & Electronic Crimes...
# 3    electronic-transactions-act-2013-electronic-tr...
# 4    G.A.T.E. Government Assisted Technology Endeav...
# ..                                                 ...
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
#
#                                    Definitions of Data  \
# 0                                                  NaN
# 1    Data is not defined specifically. However, pro...
# 2    Data includes representation of facts, informa...
# 3    Does not define data. However defines consumer...
# 4                                                  NaN
# ..                                                 ...
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
#
#     Does this Regulation/ Policy mirror any other Country's (Yes/No?)  \
# 0                                                  NaN
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
#
#                           Policy/Regulation it mirrors  \
# 0                                                  NaN
# 1                                 Data Protection Acts
# 2    Computer Misuse Act; Prevention of Electronic ...
# 3                   Electronic Transactions Acts/Bills
# 4                                                  NaN
# ..                                                 ...
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
#
#                                              Countries  \
# 0                                                  NaN
# 1          Singapore\nBotswana\nJamaica\nCyprus\nMalta
# 2                          Mauritius\nBrunei\nPakistan
# 3    Ghana\nSt. Vincent and the Grenadines\nSri Lan...
# 4                                                  NaN
# ..                                                 ...
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
#
#                   Categories  \
# 0                        NaN
# 1            Data Governance
# 2            Data Governance
# 3    Electronic Transactions
# 4                     Skills
# ..                       ...
# 757                      NaN
# 758                      NaN
# 759                      NaN
# 760                      NaN
# 761                      NaN
#
#                                                   Tags  Digital Innovations  \
# 0                                                  NaN                  NaN
# 1    Consent;\nData;\nData integrity;\nData process...                  NaN
# 2    Data;\nData transmission;\nElectronic crimes;\...                  NaN
# 3    Electronic commerce;\nElectronic communication...                  NaN
# 4    Broadband;\nCompetition;\nICT services;\nInter...                  NaN
# ..                                                 ...                  ...
# 757                                                NaN                  NaN
# 758                                                NaN                  NaN
# 759                                                NaN                  NaN
# 760                                                NaN                  NaN
# 761                                                NaN                  NaN
#
#      Data Infrastructure  Business Development Services  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
# ..                   ...                            ...
# 757                  NaN                            NaN
# 758                  NaN                            NaN
# 759                  NaN                            NaN
# 760                  NaN                            NaN
# 761                  NaN                            NaN
#
#      Enabling Environment for Digitalisation
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 757                                      NaN
# 758                                      NaN
# 759                                      NaN
# 760                                      NaN
# 761                                      NaN
#
# [762 rows x 12 columns]
