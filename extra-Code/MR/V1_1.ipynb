# %%
import pandas as pd
import warnings
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('NPS_SCU_02-15-2022.csv')
df=df[2:]
df.reset_index(drop=True,inplace=True)

# %%
# df[['Q4A_EN','Q4A']].isna().sum()

# %%
df.shape
# Out:
# (5923, 128)

# %%
df = df.rename({'Q_RecaptchaScore':'Recaptcha_Score','Q1_NPS_GROUP':'NPS_Group','Q1':'NPS_Score',
               'Q2A':'Reason_to_Recommend','Q2B':'Reason_to_not_Recommend','Q2C':'How_to_imporove',
               'Q3':'Role','Q4':'Trusted_Advisor','Q4A':'Not_TrustedAdvisor',
               'Q5_1':'Pricing','Q5_2':'Purchasing_Process','Q5_3':'Renewal_Process',
               'Q5_4':'Onboarding','Q5_5':'Using_VMWare_Products',
               'Q5_6':'Optimizing','Q6_1':'Flexible_Policies','Q6_2':'VMWare_As_Solver','Q6_3':'Long_Term_Partnership',
               'Q6_4':'Achieve_Business_Objectives','Q6_5':'Innovation_Leader','Q6A':'Not_Strategic_Innovation_Leader',
               'Q7_1':'DataCenter_Solutions','Q7_2':'Private_Cloud','Q7_3':'Public_Cloud','Q7_4':'Cloud_Management',
               'Q7_5':'Modern_Application_Platform','Q7_6':'Digital_Workspace','Q7_7':'Netwoking',
               'Q7_8':'Security','Q7_9':'Other','Q7_9_TEXT':'Other_Text','Q7A_1':'Rating_DataCenter_Solutions',
               'Q7A_2':'Rating_Private_Cloud','Q7A_3':'Rating_Public_Cloud','Q7A_4':'Rating_Cloud_Management',
               'Q7A_5':'Rating_Modern_Application_Platform','Q7A_6':'Rating_Digital_Workspace',
               'Q7A_7':'Rating_Networking','Q7A_8':'Rating_Security','Q7A_9':'Rating_Other',
               'Q7A_9_TEXT':'Rating_Other_Text','Q7B_1_1':'Description_Rating_Datacenter_Solutions',
               'Q7B_2_1':'Description_Rating_Private_Cloud','Q7B_3_1':'Description_Rating_Public_Cloud',
               'Q7B_4_1':'Description_Rating_Cloud_Management','Q7B_5_1':'Description_Rating_Modern_Application_Platform',
               'Q7B_6_1':'Desc_Rating_Digital_Workspace','Q7B_7_1':'Desc_Rating_Networking',
               'Q7B_8_1':'Desc_Rating_Security','Q7B_9_TEXT':'Desc_Rating_Other_Text','Q7B_9_1':'Desc_Rating_Other',
                'Q8_1':'Expand_Datacenter_Solutions','Q8_2':'Expand_Private_Cloud','Q8_3':'Expand_Public_Ccloud',
                'Q8_4':'Expand_Cloud_Management','Q8_5':'Expand_Modern_Application_Platform','Q8_6':'Expand_Digital_workSpace',
                'Q8_7':'Expand_Networking','Q8_8':'Expand_Security','Q8_9':'Expand_Other','Q8_9_TEXT':'Expand_Other_Text',
                'Q9_1':'Evolution_Iaas','Q9_2':'Evolution_HybridCloud','Q9_3':'Evolution_Perm',
                'Q9_4':'Evolution_ScaleDown_Perm','Q9_5':'Evolution_SaaS','Q9_6':'Evolution_Remote_Workforce',
                'Q9_7':'Evolution_Security','Q9_8':'Evolution_BusinessContinuity','Q9_9':'Evolution_LessBudget',
                'Q10_1_1':'MoreFeedback','Q11_1':'CanbeContacted','Q4A_EN':'NotTrustedAdvisor',
                'Q2C_EN':'Improve_Experience','Q2A_EN':'Feedback','Q2B_EN':'Feedback_EN'},axis=1)

# %%
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',500)

# %%
# display.[max_categories, max_columns, max_colwidth, max_info_columns,
#   max_info_rows, max_rows, max_seq_items, memory_usage,

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                   11/15/2021 21:04
# 3                                    11/10/2021 9:00
# 4                                   11/15/2021 21:32
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                   11/15/2021 21:07               Imported
# 3                                    11/10/2021 9:05               Imported
# 4                                   11/15/2021 21:36               Imported
#
#                   Progress    Duration (in seconds)                 Finished  \
# 0                 Progress    Duration (in seconds)                 Finished
# ...

# %%
df.shape
# Out:
# (5925, 128)

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'Progress', 'Duration (in seconds)',
#        'Finished', 'RecordedDate', 'ResponseId', 'DistributionChannel',
#        'UserLanguage',
#        ...
#        'Q2B_EN', 'Q7b_1_EN', 'Q7b_2_EN', 'Q7b_3_EN', 'Q7b_4_EN', 'Q7b_9_EN',
#        'Q7b_5_EN', 'Q7b_6_EN', 'Q7b_8_EN', 'Q7b_7_EN'],
#       dtype='object', length=128)

# %%
df.UserLanguage.value_counts(normalize=True)
# Out:
# EN                             0.468861
# JA                             0.129620
# DE                             0.126751
# ES                             0.104641
# IT                             0.052827
# FR                             0.033249
# ZH-T                           0.029873
# PT-BR                          0.022616
# ZH-S                           0.021097
# KO                             0.010127
# {"ImportId":"userLanguage"}    0.000169
# User Language                  0.000169
# Name: UserLanguage, dtype: float64

# %%
# %matplotlib inline

# %%
df.UserLanguage.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# StartDate                   0
# EndDate                     0
# Status                      0
# Progress                    0
# Duration (in seconds)       0
# Finished                    0
# RecordedDate                0
# ResponseId                  0
# DistributionChannel         0
# UserLanguage                0
# Q_RecaptchaScore          153
# Q1_NPS_GROUP                0
# Q1                          0
# Q2A                      4631
# Q2B                      5418
# Q2C                      5522
# Q3                          0
# Q4                        108
# Q4A                      5612
# Q5_1                     2093
# Q5_2                     2287
# Q5_3                     2350
# Q5_4                     2210
# Q5_5                     1788
# Q5_6                     2112
# Q6_1                     2247
# Q6_2                     2174
# Q6_3                     2137
# Q6_4                     2029
# Q6_5                     2087
# Q6A                      5830
# ...

# %%
df.describe()
# Out:
#               StartDate           EndDate    Status Progress  \
# count              5925              5925      5925     5925
# unique             3948              3193         3        7
# top     11/16/2021 7:01  12/10/2021 15:46  Imported      100
# freq                 10               155      5923     4089
#
#         Duration (in seconds) Finished      RecordedDate         ResponseId  \
# count                    5925     5925              5925               5925
# unique                   1896        6                 6               5925
# top                        40     TRUE  12/15/2021 10:05  R_0f7BP69A9bRQARw
# freq                       26     4089              2800                  1
#
#        DistributionChannel UserLanguage Q_RecaptchaScore Q1_NPS_GROUP    Q1  \
# count                 5925         5925             5772         5925  5925
# unique                   3           12               21            5    24
# ...

# %%
df.Q1_NPS_GROUP.value_counts()
# Out:
# Promoter                                                                                            3624
# Passive                                                                                             1482
# Detractor                                                                                            817
# How likely are you to recommend VMware products or services to a colleague or associate? - Group       1
# {"ImportId":"QID8_NPS_GROUP"}                                                                          1
# Name: Q1_NPS_GROUP, dtype: int64

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                   11/15/2021 21:04
# 3                                    11/10/2021 9:00
# 4                                   11/15/2021 21:32
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                   11/15/2021 21:07               Imported
# 3                                    11/10/2021 9:05               Imported
# 4                                   11/15/2021 21:36               Imported
#
#                   Progress    Duration (in seconds)                 Finished  \
# 0                 Progress    Duration (in seconds)                 Finished
# ...

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'Progress', 'Duration (in seconds)',
#        'Finished', 'RecordedDate', 'ResponseId', 'DistributionChannel',
#        'UserLanguage',
#        ...
#        'Q2B_EN', 'Q7b_1_EN', 'Q7b_2_EN', 'Q7b_3_EN', 'Q7b_4_EN', 'Q7b_9_EN',
#        'Q7b_5_EN', 'Q7b_6_EN', 'Q7b_8_EN', 'Q7b_7_EN'],
#       dtype='object', length=128)

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                   11/15/2021 21:04
# 3                                    11/10/2021 9:00
# 4                                   11/15/2021 21:32
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                   11/15/2021 21:07               Imported
# 3                                    11/10/2021 9:05               Imported
# 4                                   11/15/2021 21:36               Imported
#
#                   Progress    Duration (in seconds)                 Finished  \
# 0                 Progress    Duration (in seconds)                 Finished
# ...

# %%
df.NPS_Group.value_counts().plot(kind='bar',color='green')
# Out:
# <AxesSubplot:>

# %%
list(df)
# Out:
# ['StartDate',
#  'EndDate',
#  'Status',
#  'Progress',
#  'Duration (in seconds)',
#  'Finished',
#  'RecordedDate',
#  'ResponseId',
#  'DistributionChannel',
#  'UserLanguage',
#  'Recaptcha_Score',
#  'NPS_Group',
#  'NPS_Score',
#  'Reason_to_Recommend',
#  'Reason_to_not_Recommend',
#  'How_to_imporove',
#  'Role',
#  'Trusted_Advisor',
#  'Not_TrustedAdvisor',
#  'Pricing',
#  'Purchasing_Process',
#  'Renewal_Process',
#  'Onboarding',
#  'Using_VMWare_Products',
#  'Optimizing',
#  'Flexible_Policies',
#  'VMWare_As_Solver',
#  'Long_Term_Partnership',
#  'Achieve_Business_Objectives',
#  'Innovation_Leader',
#  'Not_Strategic_Innovation_Leader',
#  'DataCenter_Solutions',
#  'Private_Cloud',
#  'Public_Cloud',
#  'Cloud_Management',
#  'Modern_Application_Platform',
#  'Digital_Workspace',
#  'Netwoking',
#  'Security',
#  'Other',
#  'Other_Text',
#  'Rating_DataCenter_Solutions',
#  'Rating_Private_Cloud',
#  'Rating_Public_Cloud',
#  'Rating_Cloud_Management',
# ...

# %%
df['Duration (in seconds)']
# Out:
# 2        223
# 3        262
# 4        228
# 5        212
# 6         32
#         ...
# 5920    1612
# 5921     279
# 5922      98
# 5923      75
# 5924     135
# Name: Duration (in seconds), Length: 5923, dtype: object

# %%
df.shape
# Out:
# (5923, 128)

# %%
df.head()
# Out:
#           StartDate           EndDate    Status Progress  \
# 0  11/15/2021 21:04  11/15/2021 21:07  Imported      100
# 1   11/10/2021 9:00   11/10/2021 9:05  Imported      100
# 2  11/15/2021 21:32  11/15/2021 21:36  Imported      100
# 3  11/15/2021 21:33  11/15/2021 21:37  Imported      100
# 4   11/10/2021 5:15   11/10/2021 6:15  Imported       35
#
#   Duration (in seconds) Finished      RecordedDate         ResponseId  \
# 0                   223     TRUE  12/15/2021 10:05  R_6AaCEkIn7LRXuUS
# 1                   262     TRUE  12/15/2021 10:05  R_74yZFhxf5VRBN2e
# 2                   228     TRUE  12/15/2021 10:05  R_81cqwo6bIRMxDf0
# 3                   212     TRUE  12/15/2021 10:05  R_8oc1McCxx2Gv5MW
# 4                    32    FALSE  12/15/2021 10:05  R_baealDUWAvUQD66
#
#   DistributionChannel UserLanguage Recaptcha_Score  NPS_Group NPS_Score  \
# 0               email           EN     0.600000024   Promoter         9
# ...

# %%
df['NPS_Score'] = df['NPS_Score'].astype('int')

# %%
# promoter 9-10
# passive-7-8
# detractor 0-6
df_promoter = df[(df['NPS_Score']==9) | (df['NPS_Score']==10)]
df_passive = df[(df['NPS_Score']==7) | (df['NPS_Score']==8)]
df_detractor = df[np.where(df['NPS_Score']<=6,True,False)]

# %%
df_promoter.shape
# Out:
# (3624, 128)

# %%
df_detractor.shape
# Out:
# (817, 128)

# %%
df_passive.shape
# Out:
# (1482, 128)

# %%
imp_com = ['NPS_Group', 
'NPS_Score', ##likert

'Reason_to_Recommend',
'Reason_to_not_Recommend',
'How_to_imporove',

'Role',

'Trusted_Advisor',
'Not_TrustedAdvisor',

#Rate your satisfaction
##likert All
           
'Pricing',
'Purchasing_Process',
'Renewal_Process',
'Onboarding',
'Using_VMWare_Products',
'Optimizing',

#Do you agree ##likert all

'Flexible_Policies',
'VMWare_As_Solver',
'Long_Term_Partnership',
'Achieve_Business_Objectives',
'Innovation_Leader',

#If not why?

'Not_Strategic_Innovation_Leader',

#Which VMWare solutions do you currently use?

'DataCenter_Solutions',
'Private_Cloud',
'Public_Cloud',
'Cloud_Management',
'Modern_Application_Platform',
'Digital_Workspace',
'Netwoking',
'Security',
'Other',
'Other_Text',
 
#Rating The Products ##likert All

'Rating_DataCenter_Solutions',
'Rating_Private_Cloud',
'Rating_Public_Cloud',
'Rating_Cloud_Management',
'Rating_Modern_Application_Platform',
'Rating_Digital_Workspace',
'Rating_Networking',
'Rating_Security',
'Rating_Other',
'Rating_Other_Text',

#Reason for your Rating

'Description_Rating_Datacenter_Solutions',
'Description_Rating_Private_Cloud',
'Description_Rating_Public_Cloud',
'Description_Rating_Cloud_Management',
'Description_Rating_Modern_Application_Platform',
'Desc_Rating_Digital_Workspace',
'Desc_Rating_Networking',
'Desc_Rating_Security',
'Desc_Rating_Other_Text',
'Desc_Rating_Other',

#Which product are you evaluationg to adopt or expand your usage

'Expand_Datacenter_Solutions',
'Expand_Private_Cloud',
'Expand_Public_Ccloud',
'Expand_Cloud_Management',
'Expand_Modern_Application_Platform',
'Expand_Digital_workSpace',
'Expand_Networking',
'Expand_Security',
'Expand_Other',
'Expand_Other_Text',

#How will you future technology startegy evolve due to current business climate

'Evolution_Iaas',
'Evolution_HybridCloud',
'Evolution_Perm',
'Evolution_ScaleDown_Perm',
'Evolution_SaaS',
'Evolution_Remote_Workforce',
'Evolution_Security',
'Evolution_BusinessContinuity',
'Evolution_LessBudget',

#Okay for more feedback?
'MoreFeedback',

#Can be contacted in future
'CanbeContacted',

#Other Fields
'Language',
'RecipientLanguage',
'person_country',
'person_industry',

'Job Role',
'Job Title',
 
'NotTrustedAdvisor',
'Improve_Experience',
'Q6a_EN',
'Feedback',
'Feedback_EN',

'Q7b_1_EN',
'Q7b_2_EN',
'Q7b_3_EN',
'Q7b_4_EN',
'Q7b_9_EN',
'Q7b_5_EN',
'Q7b_6_EN',
'Q7b_8_EN',
'Q7b_7_EN']

# %%
# df_promoter.head(2).T

# %%
# df_promoter[['NPS_Score','Reason_to_Recommend','Reason_to_not_Recommend','How_to_imporove']].head(50)

# %%
df_promoter = df_promoter[imp_com]

# %%
df_promoter.isna().sum()
# Out:
# NPS_Group                                            0
# NPS_Score                                            0
# Reason_to_Recommend                               2332
# Reason_to_not_Recommend                           3624
# How_to_imporove                                   3624
# Role                                                 0
# Trusted_Advisor                                     49
# Not_TrustedAdvisor                                3586
# Pricing                                           1257
# Purchasing_Process                                1357
# Renewal_Process                                   1376
# Onboarding                                        1300
# Using_VMWare_Products                             1051
# Optimizing                                        1233
# Flexible_Policies                                 1318
# VMWare_As_Solver                                  1292
# Long_Term_Partnership                             1275
# ...

# %%
# ImpCol = []
# for col in list(df_promoter):
#     cnt = df_promoter[col].isna().sum()
#     per = cnt*100/len(df_promoter)
#     if per<90:
#         ImpCol.append(col)

# %%
df_promoter_filtered = df_promoter[ImpCol]

# %%
df_promoter.shape
# Out:
# (3624, 91)

# %%
df_promoter
# Out:
#      NPS_Group  NPS_Score                                Reason_to_Recommend  \
# 0     Promoter          9                                                NaN
# 3     Promoter         10  The product is ultra reliable , IT offers grea...
# 4     Promoter         10                                                NaN
# 5     Promoter          9                                                NaN
# 7     Promoter         10                                                NaN
# ...        ...        ...                                                ...
# 5917  Promoter          9                                                NaN
# 5919  Promoter          9                 I works well and does what we need
# 5920  Promoter          9  ã‚¤ãƒ³ã‚¹ãƒˆãƒ¼ãƒ«ã—ã¦ã‹ã‚‰ã®ä½¿ã„å‹æ‰‹ã...
# 5921  Promoter         10                                                NaN
# 5922  Promoter         10                                    Best technology
#
# ...

# %%
likert = ['NPS_Score',
'Pricing',
'Purchasing_Process',
'Renewal_Process',
'Onboarding',
'Using_VMWare_Products',
'Optimizing',

'Flexible_Policies',
'VMWare_As_Solver',
'Long_Term_Partnership',
'Achieve_Business_Objectives',
'Innovation_Leader',

'Rating_DataCenter_Solutions',
'Rating_Private_Cloud',
'Rating_Public_Cloud',
'Rating_Cloud_Management',
'Rating_Modern_Application_Platform',
'Rating_Digital_Workspace',
'Rating_Networking',
'Rating_Security',
'Rating_Other',
'Rating_Other_Text']

# %%
df_promoter_lkert = df_promoter[likert]

# %%
df_promoter_lkert
# Out:
#       NPS_Score                     Pricing          Purchasing_Process  \
# 0             9                           5                           5
# 3            10                           5                           6
# 4            10                         NaN                         NaN
# 5             9                           3                           5
# 7            10  Extremely Satisfied  -   7  Extremely Satisfied  -   7
# ...         ...                         ...                         ...
# 5917          9                           3                           4
# 5919          9                           5                         NaN
# 5920          9                           2                           2
# 5921         10  Extremely Satisfied  -   7  Extremely Satisfied  -   7
# 5922         10  Extremely Satisfied  -   7  Extremely Satisfied  -   7
#
#                  Renewal_Process                  Onboarding  \
# ...

# %%
for col in list(df_promoter_lkert):
    df_promoter_lkert[col] = df_promoter_lkert[col].apply(lambda x: x if (isinstance(x,float) or isinstance(x,int)) else x.split()[-1])

# %%
df_promoter_lkert.isna().sum()
# Out:
# NPS_Score                                0
# Pricing                               1257
# Purchasing_Process                    1357
# Renewal_Process                       1376
# Onboarding                            1300
# Using_VMWare_Products                 1051
# Optimizing                            1233
# Flexible_Policies                     1318
# VMWare_As_Solver                      1292
# Long_Term_Partnership                 1275
# Achieve_Business_Objectives           1189
# Innovation_Leader                     1203
# Rating_DataCenter_Solutions           1490
# Rating_Private_Cloud                  3351
# Rating_Public_Cloud                   3406
# Rating_Cloud_Management               3346
# Rating_Modern_Application_Platform    3516
# Rating_Digital_Workspace              3227
# Rating_Networking                     3297
# Rating_Security                       3472
# Rating_Other                          3479
# Rating_Other_Text                     3624
# ...

# %%
df_promoter_lkert.drop('Rating_Other_Text',axis=1,inplace=True)

# %%
df_promoter_lkert.dtypes
# Out:
# NPS_Score                              int64
# Pricing                               object
# Purchasing_Process                    object
# Renewal_Process                       object
# Onboarding                            object
# Using_VMWare_Products                 object
# Optimizing                            object
# Flexible_Policies                     object
# VMWare_As_Solver                      object
# Long_Term_Partnership                 object
# Achieve_Business_Objectives           object
# Innovation_Leader                     object
# Rating_DataCenter_Solutions           object
# Rating_Private_Cloud                  object
# Rating_Public_Cloud                   object
# Rating_Cloud_Management               object
# Rating_Modern_Application_Platform    object
# Rating_Digital_Workspace              object
# Rating_Networking                     object
# Rating_Security                       object
# Rating_Other                          object
# ...

# %%
df_promoter_lkert['Purchasing_Process'].value_counts()
# Out:
# 7    864
# 6    801
# 5    338
# 4    160
# 3     60
# 2     25
# 1     19
# Name: Purchasing_Process, dtype: int64

# %%
for col in df_promoter_lkert:
    df_promoter_lkert[col] = df_promoter_lkert[col].astype('float')

# %%
df_promoter_lkert
# Out:
#       NPS_Score  Pricing  Purchasing_Process  Renewal_Process  Onboarding  \
# 0           9.0      5.0                 5.0              5.0         5.0
# 3          10.0      5.0                 6.0              5.0         6.0
# 4          10.0      NaN                 NaN              NaN         NaN
# 5           9.0      3.0                 5.0              4.0         6.0
# 7          10.0      7.0                 7.0              7.0         7.0
# ...         ...      ...                 ...              ...         ...
# 5917        9.0      3.0                 4.0              6.0         6.0
# 5919        9.0      5.0                 NaN              NaN         NaN
# 5920        9.0      2.0                 2.0              2.0         2.0
# 5921       10.0      7.0                 7.0              7.0         7.0
# 5922       10.0      7.0                 7.0              7.0         7.0
#
#       Using_VMWare_Products  Optimizing  Flexible_Policies  VMWare_As_Solver  \
# ...

# %%
plt.figure(figsize=(5,5))
for col in df_promoter_lkert:
    x = df_promoter_lkert[col].value_counts()
    y = x.index
    plt.bar(y,x,label=col,color='r')
    plt.legend()
    plt.show()

# %%
# text_col = list(set(imp_com)-set(likert))

# %%
df_promoter_product = df_promoter[['DataCenter_Solutions',
'Private_Cloud',
'Public_Cloud',
'Cloud_Management',
'Modern_Application_Platform',
'Digital_Workspace',
'Netwoking',
'Security',
]] 

# future use
# 'Other',
# 'Other_Text'

# %%
x = []
y = []
for col in df_promoter_product:
    x.append(df_promoter_product[col].value_counts()[0])
    y.append(col)

# %%
df_promoter_product.shape
# Out:
# (3624, 8)

# %%
x_per = [i*100/len(df_promoter_product) for i in x]

# %%
x_per
# Out:
# [65.09381898454747,
#  8.91280353200883,
#  7.008830022075055,
#  8.664459161147903,
#  3.6147902869757176,
#  13.107064017660043,
#  10.623620309050773,
#  5.077262693156733]

# %%
plt.figure(figsize=(5,5))
plt.bar(y,x,label=col,color='g')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.bar(y,x_per,label=col,color='g')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
df_promoter_product
# Out:
#                                    DataCenter_Solutions  \
# 0     Datacenter solutions \n\n VMware vSphere, VMwa...
# 3     Datacenter solutions \n\n VMware vSphere, VMwa...
# 4                                                   NaN
# 5     Datacenter solutions \n\n VMware vSphere, VMwa...
# 7     Datacenter solutions \n\n VMware vSphere, VMwa...
# ...                                                 ...
# 5917                                                NaN
# 5919  Datacenter solutions \n\n VMware vSphere, VMwa...
# 5920                                                NaN
# 5921                                                NaN
# 5922  Datacenter solutions \n\n VMware vSphere, VMwa...
#
#                                           Private_Cloud  \
# 0                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# ...
