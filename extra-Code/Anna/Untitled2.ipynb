# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_excel('RAWENS (1).xlsx')

# %%
x = df[['Unnamed: 1','Unnamed: 5']].dropna()

# %%
x
# Out:
#     Unnamed: 1 Unnamed: 5
# 4          4.0  56.533333
# 5          7.0  56.533333
# 6         15.0  56.533333
# 7         17.0   18.79596
# 8          9.0  14.084848
# 9         10.0    9.09899
# 10         1.0    9.09899
# 11         2.0   9.074747
# 12        13.0   9.074747
# 13         8.0   4.177778
# 14        14.0   0.646465
# 15         5.0   0.210101
# 16         6.0   0.040404
# 17        11.0          0
# 18        12.0          0
# 19        16.0          0

# %%
np.array(x)
# Out:
# array([[4.0, 56.53333333],
#        [7.0, 56.53333333],
#        [15.0, 56.53333333],
#        [17.0, 18.7959596],
#        [9.0, 14.08484848],
#        [10.0, 9.098989899],
#        [1.0, 9.098989899],
#        [2.0, 9.074747475],
#        [13.0, 9.074747475],
#        [8.0, 4.177777778],
#        [14.0, 0.6464646465],
#        [5.0, 0.2101010101],
#        [6.0, 0.0404040404],
#        [11.0, 0],
#        [12.0, 0],
#        [16.0, 0]], dtype=object)

# %%
sns.heatmap(x.corr())
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

x_list = np.random.rand(100).tolist()
x = np.array((x_list))
# x_res=x.reshape(math.sqrt(len(x)),math.sqrt(len(x))) #old
x_res=x.reshape(int(math.sqrt(len(x))),int(math.sqrt(len(x))))

fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(x_res, square=True, ax=ax)
plt.yticks(rotation=0,fontsize=16);
plt.xticks(fontsize=12);
plt.tight_layout()
plt.savefig('colorlist.png')

# %%
x.shape
# Out:
# (100,)

# %%
x_res.shape
# Out:
# (10, 10)
