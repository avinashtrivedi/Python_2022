# %%
# %%
# 1

# run and check the type
a = 2.0
b = 2.

print(type(a))
print(type(b))

# %%
# 2

a = 2.0
b = 2.

print(a==b)

# %%
# 3

a = 2
b = 5
sum_ab = a + b
# print:  Sum of 2 and 5 is  7

print(f"sum of {a} and {b} is {sum_ab}")


# %%
# 4

x = int(input())
y = int(input())
sum_xy = x + y

# print: -> Sum of X and Y is ...
print(f"sum of x and y is {sum_xy}")

# %%
# 5
x = int(input())
y = x**3 + x**2 + x + 1


# print:->  value of equation x**3 + x**2 + x + 1 is ....
print(f"value of equation x**3 + x**2 + x + 1 is {y}")

# %%
# 6
s = 'Python'

print(s[1])
print(s)

# print 2nd element
print(s[1])
# print 3rd element
print(s[2])
# print 2nd last element
print(s[-2])
# print 4th last element
print(s[-4])
# print last element
print(s[-1])

# %%
# 7

s = 'Python'

# reverse a string
print(s[::-1])

# %%
# 8 ******************************************

s = 'taxable income'

# print all characters between index position 3rd to 7th
print(s[2:6])

# %%
# 9****************************

s = 'taxable income'

# print all characters between index position 7th to last
length_s = len(s)
print(s[7:length_s])

# %%
# 10

s = 'taxable income' #**************************

# print all characters between from beginning to last

# enter the appropriate value for x and y
x = 
y = 
s[x:y]

# %%
# 11

s = 'madam'

# enter the value of t , so that print statement return True
t = -1
print(s == s[::t])

# %%
# 12

s = 'hello'

# guess the output
# guess = "hlo"
s[::2]

# %%
# 13

s = 'hello'

# guess the output
#guess= "olh"

s[::-2]

# %%
# 14

s = 'hello'

# guess the output
#guess = "olleh"

s[::-1]

# %%
# 15

s = 'Hello World'

# make all the characters in upper case

print(s.upper())

# %%
# 15

s = 'Hello World'

# make all the characters in lower case
print(s.lower())

# %%
# 16

s = 'hello world'

# make all the characters in title case
print(s.title())

# %%
# 17

s = 'hello world'

# print index of the space character between hello and world
location_space = s.find(" ")
print(location_space)

# %%
# 18

s = 'hello world'

# print index of the w
location_w = s.find("w")
print(location_w)

# %%
# 19 **********************

s = 'hello world'

# print index of last l
reverse_s = s[::-1]
location_lreverse = reverse_s.find("l")
location_l = "-"+str(location_lreverse)

print(location_l)

# %%
# 20

s = 'hello world'

# print index of 2nd l

#find first l. set equal to location_first_l
location_first_l = s.find("l")
#find length of string s
length_s = len(s)
#find string after first l until the end, set it to variable newvar
lfl1 = location_first_l + 1
newvar = s[lfl1:length_s]
#find location of l in newvar
location_second_l = newvar.find("l") + 1
#find length of s from start to first l
index_second_l = location_first_l + location_second_l
print(index_second_l)

# %%




# %% [markdown]
# # List
# - write the code so as to get the expected output

# %% [markdown]
# # Q.1

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: 'world'

#### Type your code here #########
print(mylist[1])

# %% [markdown]
# # Q.2*******************************************

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: 'python'

#### Type your code here #########
a1 = mylist.index("python")
print(mylist[a1])

# %% [markdown]
# # Q.3

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: 'is'

#### Type your code here #########
a2 = mylist.index("is")
print(mylist[a2])

# %% [markdown]
# # Q.4

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: ['hello','world']

#### Type your code here #########
new_list = [mylist[0], mylist[1]]
print(new_list)

# %% [markdown]
# # Q.5

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: ['this','is']

#### Type your code here #########
new_list_2 = [mylist[2], mylist[3]]
print(new_list_2)

# %% [markdown]
# # Q.6

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: ['this','is','python']

#### Type your code here #########
new_list_3 = [mylist[2], mylist[3], mylist[4]]
print(new_list_3)

# %% [markdown]
# # Q .7

# %%
mylist = ['hello','world', 'this','is','python']

# get 'this' and reverse
# expected output: 'siht'

#### Type your code here #########
this = mylist[2]
reverse_this = this[::-1]
print(reverse_this)

# %% [markdown]
# # Q.8

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: 'hello world this is python'

#### Type your code here #########
newstring = " ".join(mylist)
print(newstring)


# %% [markdown]
# # Q.9

# %%
mylist = ['hello','world', 'this','is','python']

# expected output: [['hello','world'], 'this','is','python']

#### Type your code here #########
list2 = [mylist[0], mylist[1]]
list3 = [list2, mylist[2], mylist[3], mylist[4]]
print(list3)

# %% [markdown]
# # Q.10

# %%
mylist = [['hello','world'], 'this','is','python']

# expected output: ['hello','world', 'this','is','python']

#### Type your code here #########
inner_list = mylist[0]
newlist_4 = [inner_list[0], inner_list[1]] + mylist[1:4]
print(newlist_4)

# %% [markdown]
# # Q.11

# %%
mylist = [['hello','world'], 'this','is','python',['get','me','outside']]

# expected output: 'world'

#### Type your code here #########
inner_list_2 = mylist[0]
print(inner_list_2[1])

# %% [markdown]
# # Q.12

# %%
mylist = [['hello','world'], 'this','is','python',['get','me','outside']]

# expected output: 'outside'

#### Type your code here #########
new_list_5 = mylist[4]
print(new_list_5[2])

# %% [markdown]
# # Q.13

# %%
mylist = [['hello','world'], 'this','is','python',['get','me','outside']]

# expected output: 'me'

#### Type your code here #########
new_list_6 = mylist[4]
print(new_list_6[1])

# %% [markdown]
# # Q.14

# %%
mylist = [['hello','world'], 'this','is','python',['get','me','outside']]

# expected output: ['hello','world', 'this','is','python','get','me','outside']

#### Type your code here #########
new_list_7 = mylist[0]
new_list_8 = mylist[4]
new_list_9 = new_list_7 + mylist[1:4] + new_list_8
print(new_list_9)

# %% [markdown]
# # Q.15

# %%
mylist = [['hello','world'], 'this','is','python',['get','me','outside']]

# find the length of each element
# expected output: [2,4,2,6,3]
# Hint: use for loop or list comprehension

#### Type your code here #########
newlist_10 = []

for item in mylist:
    newlist_10.append(len(item))

print(newlist_10)

# %% [markdown]
# # Q.16

# %%
mylist = ['hello','world', 'this','is','python']

# find the length of each element
# expected output: ['olleh', 'dlrow', 'siht', 'si', 'nohtyp']
# Hint: use for loop or list comprehension

#### Type your code here #########
new_list_11 = []
mylist_length = len(mylist)
for i in range(mylist_length):
  entity = mylist[i]
  ytitne = entity[::-1]
  new_list_11.append(ytitne)

print(new_list_11)

# %% [markdown]
# # Q.17

# %%
mylist = ['hello','world', 'this','is','python']

# find the length of each element
# expected output: ['nohtyp', 'si', 'siht', 'dlrow', 'olleh']
# Hint: use for loop or list comprehension

#### Type your code here #########
new_list_11 = []
mylist_length = len(mylist)
for i in range(mylist_length):
  entity = mylist[i]
  ytitne = entity[::-1]
  new_list_11.append(ytitne)

new_list_11 = new_list_11[::-1]
print(new_list_11)

# %%
for 
if else 
while
tuple
set
dictionary
class

# %%
*****
****
***
**
*

# %%
x = [4,6,12,34,89,12]

# %%
sorted(x,reverse=True)
# Out:
# [89, 34, 12, 12, 6, 4]

# %%
x = sorted(x)
# Out:
# [4, 6, 12, 12, 34, 89]

# %%
x
# Out:
# [4, 6, 12, 34, 89, 12]

# %%
x.sort()

# %%
x
# Out:
# [4, 6, 12, 12, 34, 89]
