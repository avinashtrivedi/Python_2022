# %%
import json
with open('vote.json', 'r') as fp:
    vote = json.load(fp)
voteDoc = vote['voteDoc']
ruDoc = vote['ruDoc']

with open('resp.json', 'r') as fp:
    resp = json.load(fp)
rspJson = [resp]

# %%
rspJson[0]
# Out:
# {'reportingSource': {'precinctsReporting': 0,
#   'usingProportional': False,
#   'sourceIds': {'voteTotal': 'StateFeed',
#    'voteByMode': 'WebScrape',
#    'totalBallotsCast': 'Stringer'},
#   'isGetting': True,
#   'trusted': True,
#   'active': True,
#   'locked': False,
#   'electoralVoteTotal': 0,
#   'candidates': [{'id': 47499,
#     'npId': 41404,
#     'name': {'last': 'Abbott',
#      'first': 'Greg',
#      'middle': '',
#      'suffix': '    ',
#      'abbrv': 'Abbott'},
#     'vote': {'partyId': 'GOP',
#      'partyName': 'Republican',
#      'incumbent': True,
#      'isFused': False,
#      'majorCandidate': True,
#      'total': 0,
#      'votePercentage': 0,
#      'electoralVotesWon': 0,
#      'raceStatus': {'status': 'none',
#       'changelog': {'created': {'timestamp': '2022-02-02 17:26:31.587000',
#         'by': 'System'},
#        'updated': {'timestamp': '2022-02-02 17:26:31.587000',
#         'by': 'System'}}},
# ...

# %%
d = {'key1':12,'key1':15}

# %%
d
# Out:
# {'key1': 12}

# %%
d['key1']=15

# %%
d
# Out:
# {'key1': 15}
