# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='ENX Paris Baskets')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'ALTC FP Equity',
#  nan,
#  'BLOC FP Equity',
#  nan,
#  'MEGA FP Equity',
#  nan,
#  'HODL FP Equity',
#  nan,
#  'HODLV FP Equity',
#  nan,
#  'HODLX FP Equity',
#  nan,
#  'ALTS FP Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares ALTC TURNOVER',
 '21Shares ALTC AVERAGE_BID',
 'WisdomTree BLOC  TURNOVER',
 'WisdomTree BLOC  AVERAGE_BID',
 'WisdomTree MEGA TURNOVER',
 'WisdomTree MEGA AVERAGE_BID',
 '21Shares HODL TURNOVER',
 '21Shares HODL AVERAGE_BID',
 '21Shares HODLV TURNOVER',
 '21Shares HODLV AVERAGE_BID',
 '21Shares HODLX TURNOVER',
 '21Shares HODLX AVERAGE_BID',
 '21Shares ALTS TURNOVER',
 '21Shares ALTS AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares ALTC TURNOVER 21Shares ALTC AVERAGE_BID  \
# 0    2021-05-03 00:00:00                    NaN                       NaN
# 1    2021-05-04 00:00:00                    NaN                       NaN
# 2    2021-05-05 00:00:00                    NaN                       NaN
# 3    2021-05-06 00:00:00                    NaN                       NaN
# 4    2021-05-07 00:00:00                    NaN                       NaN
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00                    NaN                    0.7736
# 256  2022-04-26 00:00:00                    NaN                    0.7255
# 257  2022-04-27 00:00:00                    NaN                    0.7425
# 258  2022-04-28 00:00:00                    NaN                    0.7425
# 259  2022-04-29 00:00:00                    NaN                    0.7246
#
#     WisdomTree BLOC  TURNOVER WisdomTree BLOC  AVERAGE_BID  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ..                        ...                          ...
# 255                    715.99                       0.7245
# 256                    715.99                       0.7148
# 257                    715.99                       0.7632
# 258                    715.99                       0.7397
# 259                    715.99                        0.727
#
#     WisdomTree MEGA TURNOVER WisdomTree MEGA AVERAGE_BID  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ..                       ...                         ...
# 255                 125380.6                      0.5365
# 256                 125380.6                      0.5154
# 257                 125380.6                      0.6256
# 258                 125380.6                      0.5583
# 259                 125380.6                      0.5203
#
#     21Shares HODL TURNOVER 21Shares HODL AVERAGE_BID 21Shares HODLV TURNOVER  \
# 0                      NaN                       NaN                     NaN
# 1                      NaN                       NaN                     NaN
# 2                      NaN                       NaN                     NaN
# 3                      NaN                       NaN                     NaN
# 4                      NaN                       NaN                     NaN
# ..                     ...                       ...                     ...
# 255                 1501.5                    0.6457                    7130
# 256                 1501.5                    0.6044                    7130
# 257                 1501.5                     0.627                    7130
# 258                 1501.5                    0.6208                    7130
# 259                 1501.5                    0.6225                    7130
#
#     21Shares HODLV AVERAGE_BID 21Shares HODLX TURNOVER  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ..                         ...                     ...
# 255                     0.7394                    87.8
# 256                     0.7077                    87.8
# 257                     0.7216                    87.8
# 258                     0.7256                   68.96
# 259                     0.7134                   68.96
#
#     21Shares HODLX AVERAGE_BID 21Shares ALTS TURNOVER  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ..                         ...                    ...
# 255                     0.7399                 751.76
# 256                     0.7084                 2505.8
# 257                     0.7263                 298.83
# 258                     0.7262                 298.83
# 259                     0.7174                5132.82
#
#     21Shares ALTS AVERAGE_BID
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 255                    0.7364
# 256                    0.7184
# 257                    0.7508
# 258                    0.7525
# 259                    0.7427
#
# [260 rows x 15 columns]

# %%
df.isna().sum()
# Out:
# Dates                             0
# 21Shares ALTC TURNOVER          260
# 21Shares ALTC AVERAGE_BID       205
# WisdomTree BLOC  TURNOVER       213
# WisdomTree BLOC  AVERAGE_BID    205
# WisdomTree MEGA TURNOVER        156
# WisdomTree MEGA AVERAGE_BID     153
# 21Shares HODL TURNOVER          214
# 21Shares HODL AVERAGE_BID       189
# 21Shares HODLV TURNOVER         209
# 21Shares HODLV AVERAGE_BID      189
# 21Shares HODLX TURNOVER         192
# 21Shares HODLX AVERAGE_BID      189
# 21Shares ALTS TURNOVER          229
# 21Shares ALTS AVERAGE_BID       191
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                           datetime64[ns]
# 21Shares ALTC TURNOVER                  object
# 21Shares ALTC AVERAGE_BID               object
# WisdomTree BLOC  TURNOVER               object
# WisdomTree BLOC  AVERAGE_BID            object
# WisdomTree MEGA TURNOVER                object
# WisdomTree MEGA AVERAGE_BID             object
# 21Shares HODL TURNOVER                  object
# 21Shares HODL AVERAGE_BID               object
# 21Shares HODLV TURNOVER                 object
# 21Shares HODLV AVERAGE_BID              object
# 21Shares HODLX TURNOVER                 object
# 21Shares HODLX AVERAGE_BID              object
# 21Shares ALTS TURNOVER                  object
# 21Shares ALTS AVERAGE_BID               object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                           datetime64[ns]
# 21Shares ALTC TURNOVER                 float64
# 21Shares ALTC AVERAGE_BID              float64
# WisdomTree BLOC  TURNOVER              float64
# WisdomTree BLOC  AVERAGE_BID           float64
# WisdomTree MEGA TURNOVER               float64
# WisdomTree MEGA AVERAGE_BID            float64
# 21Shares HODL TURNOVER                 float64
# 21Shares HODL AVERAGE_BID              float64
# 21Shares HODLV TURNOVER                float64
# 21Shares HODLV AVERAGE_BID             float64
# 21Shares HODLX TURNOVER                float64
# 21Shares HODLX AVERAGE_BID             float64
# 21Shares ALTS TURNOVER                 float64
# 21Shares ALTS AVERAGE_BID              float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares ALTC TURNOVER  WisdomTree BLOC  TURNOVER  \
# 0   2021      5                     0.0                       0.00
# 1   2021      6                     0.0                       0.00
# 2   2021      7                     0.0                       0.00
# 3   2021      8                     0.0                       0.00
# 4   2021      9                     0.0                       0.00
# 5   2021     10                     0.0                       0.00
# 6   2021     11                     0.0                       0.00
# 7   2021     12                     0.0                       0.00
# 8   2022      1                     0.0                       0.00
# 9   2022      2                     0.0                     639.45
# 10  2022      3                     0.0                    3928.50
# 11  2022      4                     0.0                    4458.39
#
#     WisdomTree MEGA TURNOVER  21Shares HODL TURNOVER  21Shares HODLV TURNOVER  \
# 0                       0.00                    0.00                     0.00
# 1                       0.00                    0.00                     0.00
# 2                       0.00                    0.00                     0.00
# 3                       0.00                    0.00                     0.00
# 4                       0.00                    0.00                     0.00
# 5                       0.00                    0.00                     0.00
# 6                       0.00                    0.00                     0.00
# 7                   41298.18                    0.00                     0.00
# 8                  848908.54                    0.00                     0.00
# 9                 2350616.00                   91.28                 96910.68
# 10                2805255.80                 4150.64                230834.70
# 11                2632992.60                31531.50                 92071.31
#
#     21Shares HODLX TURNOVER  21Shares ALTS TURNOVER
# 0                      0.00                    0.00
# 1                      0.00                    0.00
# 2                      0.00                    0.00
# 3                      0.00                    0.00
# 4                      0.00                    0.00
# 5                      0.00                    0.00
# 6                      0.00                    0.00
# 7                      0.00                    0.00
# 8                    618.80                    0.00
# 9                  14297.14                    0.00
# 10                 77307.41                40854.84
# 11                 11226.21                72253.64

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Paris Baskets Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("parisbaskets_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares ALTC AVERAGE_BID  WisdomTree BLOC  AVERAGE_BID  \
# 0   2021      5                        NaN                           NaN
# 1   2021      6                        NaN                           NaN
# 2   2021      7                        NaN                           NaN
# 3   2021      8                        NaN                           NaN
# 4   2021      9                        NaN                           NaN
# 5   2021     10                        NaN                           NaN
# 6   2021     11                        NaN                           NaN
# 7   2021     12                        NaN                           NaN
# 8   2022      1                        NaN                           NaN
# 9   2022      2                  75.135455                     76.162727
# 10  2022      3                  75.100000                     77.026957
# 11  2022      4                  74.914762                     79.370952
#
#     WisdomTree MEGA AVERAGE_BID  21Shares HODL AVERAGE_BID  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                     54.784091                        NaN
# 8                     35.419048                  71.998571
# 9                     44.166500                  74.121000
# 10                    53.410870                  74.441304
# 11                    57.390952                  68.372381
#
#     21Shares HODLV AVERAGE_BID  21Shares HODLX AVERAGE_BID  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                    72.537143                   71.760000
# 9                    72.606500                   73.912500
# 10                   73.245652                   74.482609
# 11                   75.850000                   76.148571
#
#     21Shares ALTS AVERAGE_BID
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                   72.364000
# 9                   73.295000
# 10                  73.246087
# 11                  73.799524

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey']

# %%
len(bid_col)
# Out:
# 7

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Paris Baskets Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.savefig("parisbaskets_bid_ask.png", bbox_inches = "tight")
plt.show()
