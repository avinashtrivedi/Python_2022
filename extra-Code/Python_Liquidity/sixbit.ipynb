# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='SIX Bitcoin ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'ABTC SE Equity',
#  nan,
#  'BTCEUSD SE Equity',
#  nan,
#  'VBTC SE Equity',
#  nan,
#  'BTCW SE  Equity',
#  nan,
#  'BITC SE Equity',
#  nan,
#  'SBTCU SE  Equity',
#  nan,
#  'BTIC SE Equity',
#  nan,
#  'XBTIUSD SE Equity',
#  nan,
#  'FBTC SE Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares ABTC TURNOVER',
 '21Shares ABTC AVERAGE_BID',
 'ETC Group BTCEUSD TURNOVER',
 'ETC Group BTCEUSD AVERAGE_BID',
 'VanEck VBTC TURNOVER',
 'VanEck VBTC AVERAGE_BID',
 'WisdomTree BTCW TURNOVER',
 'WisdomTree BTCW AVERAGE_BID',
 'Coinshares BITC  TURNOVER',
 'CoinsharesBITC  AVERAGE_BID',
 'Seba SBTCU TURNOVER',
 'Seba SBTCU AVERAGE_BID',
 'Invesco BTIC TURNOVER',
 'Invesco BTIC AVERAGE_BID',
 'Iconic Physical XBTIUSD TURNOVER',
 'Iconic Physical XBTIUSD AVERAGE_BID',
 'Fidelity FBTC TURNOVER',
 'Fidelity FBTC AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]
# df=df.iloc[2:,:] for original

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares ABTC TURNOVER 21Shares ABTC AVERAGE_BID  \
# 0    2021-05-03 00:00:00                2399376                    0.2411
# 1    2021-05-04 00:00:00                3342884                    0.2665
# 2    2021-05-05 00:00:00                1780429                     0.232
# 3    2021-05-06 00:00:00                1253340                    0.2503
# 4    2021-05-07 00:00:00                1009367                    0.2413
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00               568789.2                    0.1418
# 256  2022-04-26 00:00:00               420559.3                    0.1229
# 257  2022-04-27 00:00:00               637752.8                    0.1186
# 258  2022-04-28 00:00:00                1695182                    0.1212
# 259  2022-04-29 00:00:00               273067.8                    0.1108
#
#     ETC Group BTCEUSD TURNOVER ETC Group BTCEUSD AVERAGE_BID  \
# 0                      4236278                        0.4375
# 1                     316271.7                        0.4209
# 2                     183904.3                        0.2919
# 3                     124541.3                        0.3384
# 4                     23473.69                        0.3814
# ..                         ...                           ...
# 255                   212873.4                        0.2655
# 256                   24633.63                        0.2161
# 257                   16092.75                        0.2389
# 258                   16491.58                        0.2515
# 259                    16107.8                        0.2214
#
#     VanEck VBTC TURNOVER VanEck VBTC AVERAGE_BID WisdomTree BTCW TURNOVER  \
# 0                    NaN                     NaN                  2473946
# 1                    NaN                     NaN                  5509047
# 2                    NaN                     NaN                  1102243
# 3                    NaN                     NaN                  4607600
# 4                    NaN                     NaN                 647568.2
# ..                   ...                     ...                      ...
# 255               2334.5                  0.7826                   164103
# 256               2334.5                  0.7115                   105856
# 257             39845.78                    0.68                 997854.8
# 258             39845.78                  0.6228                 258738.4
# 259             39845.78                  0.7166                 48508.37
#
#     WisdomTree BTCW AVERAGE_BID Coinshares BITC  TURNOVER  \
# 0                        0.3212                  130359.8
# 1                        0.3355                  223639.9
# 2                         0.311                  42068.95
# 3                        0.2517                  206592.6
# 4                        0.2176                  179565.2
# ..                          ...                       ...
# 255                      0.2145                  116722.3
# 256                      0.1729                  123701.4
# 257                      0.1798                   48207.6
# 258                      0.1969                  49341.19
# 259                      0.1671                  61987.18
#
#     CoinsharesBITC  AVERAGE_BID Seba SBTCU TURNOVER Seba SBTCU AVERAGE_BID  \
# 0                        0.4064             2013449                  0.976
# 1                        0.4481             1231.66                 1.1848
# 2                        0.3014             1231.66                 1.4507
# 3                         0.311              8680.5                 1.0148
# 4                        0.3067             7353457                 0.8373
# ..                          ...                 ...                    ...
# 255                      0.2638            193362.6                  0.264
# 256                      0.2387              279570                 0.2458
# 257                      0.2377            141574.3                 0.2532
# 258                      0.2504            576136.9                 0.2358
# 259                      0.2217            245965.5                  0.219
#
#     Invesco BTIC TURNOVER Invesco BTIC AVERAGE_BID  \
# 0                     NaN                      NaN
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
# ..                    ...                      ...
# 255                 48384                   0.3503
# 256                 48384                   0.3087
# 257                 48384                   0.2994
# 258                 48384                   0.3053
# 259                 48384                   0.2991
#
#     Iconic Physical XBTIUSD TURNOVER Iconic Physical XBTIUSD AVERAGE_BID  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# ..                               ...                                 ...
# 255                         13236.51                              0.4949
# 256                         13236.51                              0.5443
# 257                         13236.51                               0.523
# 258                          1830.51                              0.4404
# 259                          1830.51                              0.5406
#
#     Fidelity FBTC TURNOVER Fidelity FBTC AVERAGE_BID
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# ..                     ...                       ...
# 255                    NaN                    0.3473
# 256                    NaN                    0.3098
# 257                    NaN                    0.2976
# 258                  12512                    0.3034
# 259                  12512                    0.2908
#
# [260 rows x 19 columns]

# %%
df.isna().sum()
# Out:
# Dates                                    0
# 21Shares ABTC TURNOVER                   0
# 21Shares ABTC AVERAGE_BID                0
# ETC Group BTCEUSD TURNOVER               0
# ETC Group BTCEUSD AVERAGE_BID            0
# VanEck VBTC TURNOVER                    30
# VanEck VBTC AVERAGE_BID                 29
# WisdomTree BTCW TURNOVER                 0
# WisdomTree BTCW AVERAGE_BID              0
# Coinshares BITC  TURNOVER                0
# CoinsharesBITC  AVERAGE_BID              0
# Seba SBTCU TURNOVER                      0
# Seba SBTCU AVERAGE_BID                   0
# Invesco BTIC TURNOVER                  188
# Invesco BTIC AVERAGE_BID               188
# Iconic Physical XBTIUSD TURNOVER        30
# Iconic Physical XBTIUSD AVERAGE_BID     19
# Fidelity FBTC TURNOVER                 258
# Fidelity FBTC AVERAGE_BID              232
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                                  datetime64[ns]
# 21Shares ABTC TURNOVER                         object
# 21Shares ABTC AVERAGE_BID                      object
# ETC Group BTCEUSD TURNOVER                     object
# ETC Group BTCEUSD AVERAGE_BID                  object
# VanEck VBTC TURNOVER                           object
# VanEck VBTC AVERAGE_BID                        object
# WisdomTree BTCW TURNOVER                       object
# WisdomTree BTCW AVERAGE_BID                    object
# Coinshares BITC  TURNOVER                      object
# CoinsharesBITC  AVERAGE_BID                    object
# Seba SBTCU TURNOVER                            object
# Seba SBTCU AVERAGE_BID                         object
# Invesco BTIC TURNOVER                          object
# Invesco BTIC AVERAGE_BID                       object
# Iconic Physical XBTIUSD TURNOVER               object
# Iconic Physical XBTIUSD AVERAGE_BID            object
# Fidelity FBTC TURNOVER                         object
# Fidelity FBTC AVERAGE_BID                      object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                                  datetime64[ns]
# 21Shares ABTC TURNOVER                        float64
# 21Shares ABTC AVERAGE_BID                     float64
# ETC Group BTCEUSD TURNOVER                    float64
# ETC Group BTCEUSD AVERAGE_BID                 float64
# VanEck VBTC TURNOVER                          float64
# VanEck VBTC AVERAGE_BID                       float64
# WisdomTree BTCW TURNOVER                      float64
# WisdomTree BTCW AVERAGE_BID                   float64
# Coinshares BITC  TURNOVER                     float64
# CoinsharesBITC  AVERAGE_BID                   float64
# Seba SBTCU TURNOVER                           float64
# Seba SBTCU AVERAGE_BID                        float64
# Invesco BTIC TURNOVER                         float64
# Invesco BTIC AVERAGE_BID                      float64
# Iconic Physical XBTIUSD TURNOVER              float64
# Iconic Physical XBTIUSD AVERAGE_BID           float64
# Fidelity FBTC TURNOVER                        float64
# Fidelity FBTC AVERAGE_BID                     float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares ABTC TURNOVER  ETC Group BTCEUSD TURNOVER  \
# 0   2021      5            8.173546e+07                 31068041.09
# 1   2021      6            2.639217e+07                 18046884.51
# 2   2021      7            1.727168e+07                  3964631.21
# 3   2021      8            2.816773e+07                 22383508.40
# 4   2021      9            3.591483e+07                 13425169.20
# 5   2021     10            1.015745e+08                 17672233.55
# 6   2021     11            6.335886e+07                 21178239.81
# 7   2021     12            2.853388e+07                  5469353.47
# 8   2022      1            4.261063e+07                  7333007.85
# 9   2022      2            3.077616e+07                  6689051.49
# 10  2022      3            1.866933e+07                   820195.44
# 11  2022      4            1.274184e+07                  1097735.75
#
#     VanEck VBTC TURNOVER  WisdomTree BTCW TURNOVER  Coinshares BITC  TURNOVER  \
# 0                   0.00              1.013811e+08                23258748.38
# 1              767052.42              4.383347e+07                 4549036.29
# 2             1399490.65              1.619311e+07                 9855573.44
# 3             6895433.70              2.105854e+07                11223606.74
# 4             7056227.42              2.443177e+07                10446695.70
# 5             4668192.77              3.845746e+07                21453377.87
# 6             3347859.75              2.572203e+07                 6320015.71
# 7             1216746.67              2.859208e+07                 3317695.41
# 8             2062704.61              2.569954e+07                 4382248.89
# 9             2384848.78              1.716206e+07                 2885498.11
# 10             441332.13              1.295502e+07                 3229375.61
# 11            1454811.79              8.540348e+06                 2326529.64
#
#     Seba SBTCU TURNOVER  Invesco BTIC TURNOVER  \
# 0           46122822.44                   0.00
# 1            3022256.72                   0.00
# 2            6231386.40                   0.00
# 3            6399039.44                   0.00
# 4           11816667.28                   0.00
# 5           14353168.42                   0.00
# 6            8480296.53                   0.00
# 7            8921102.03                   0.00
# 8            8418437.32               17302.00
# 9            6587059.18               43255.00
# 10           7060234.60               77276.65
# 11           6131128.51              313235.20
#
#     Iconic Physical XBTIUSD TURNOVER  Fidelity FBTC TURNOVER
# 0                               0.00                     0.0
# 1                           43624.23                     0.0
# 2                           67394.60                     0.0
# 3                          777068.70                     0.0
# 4                         1259197.23                     0.0
# 5                          570381.60                     0.0
# 6                          650822.50                     0.0
# 7                          493355.75                     0.0
# 8                          345461.87                     0.0
# 9                         1000536.80                     0.0
# 10                         268689.79                     0.0
# 11                         157033.83                 25024.0

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
# last month 12 for original so iloc[[0,2,4,6,8,10,12]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("SIX Bitcoin ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("amsbitcoin_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares ABTC AVERAGE_BID  ETC Group BTCEUSD AVERAGE_BID  \
# 0   2021      5                  30.470952                      40.089524
# 1   2021      6                  29.278182                      36.022727
# 2   2021      7                  25.042727                      23.732727
# 3   2021      8                  19.929545                      19.808636
# 4   2021      9                  25.652727                      31.835909
# 5   2021     10                  32.692857                      42.076190
# 6   2021     11                  31.727727                      32.569091
# 7   2021     12                  27.887391                      25.021739
# 8   2022      1                  26.475238                      25.617619
# 9   2022      2                  27.324000                      26.191000
# 10  2022      3                  19.110435                      28.243913
# 11  2022      4                  12.195714                      24.262857
#
#     VanEck VBTC AVERAGE_BID  WisdomTree BTCW AVERAGE_BID  \
# 0                       NaN                    34.452857
# 1                 31.145000                    29.560000
# 2                 30.331364                    25.303636
# 3                 22.889545                    22.068636
# 4                 31.684545                    24.672727
# 5                 33.807143                    25.218571
# 6                 38.409091                    28.003636
# 7                 29.996522                    27.333478
# 8                 32.760476                    23.812857
# 9                 36.818000                    24.711500
# 10                60.780435                    22.068261
# 11                71.831905                    19.480476
#
#     CoinsharesBITC  AVERAGE_BID  Seba SBTCU AVERAGE_BID  \
# 0                     48.153333              113.284286
# 1                     55.123636              104.365455
# 2                     28.854545               91.015909
# 3                     19.470455               75.481364
# 4                     27.777727               31.943636
# 5                     28.956190               25.738571
# 6                     34.178636               28.692273
# 7                     28.159130               32.537826
# 8                     29.437143               33.797619
# 9                     31.185500               36.860000
# 10                    36.833043               30.953043
# 11                    24.542857               25.817143
#
#     Invesco BTIC AVERAGE_BID  Iconic Physical XBTIUSD AVERAGE_BID  \
# 0                        NaN                            36.145000
# 1                        NaN                            42.001364
# 2                        NaN                            33.334545
# 3                        NaN                            32.678182
# 4                        NaN                            56.865909
# 5                        NaN                            42.219524
# 6                        NaN                            49.256818
# 7                        NaN                            48.960870
# 8                  37.017500                            55.403810
# 9                  34.190000                            39.511500
# 10                 33.696087                            52.133913
# 11                 33.235714                            86.888095
#
#     Fidelity FBTC AVERAGE_BID
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                  33.777143
# 11                  32.599048

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey']

# %%
len(bid_col)
# Out:
# 9

# %%
fig, ax = plt.subplots(figsize=(7,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
#same as above where iloc[[0,2,4,6,8,10,12]] is original
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("SIX Bitcoin ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.ylim([0,100])
plt.savefig("sixbit_bid_ask.png", bbox_inches ="tight")
plt.show()
