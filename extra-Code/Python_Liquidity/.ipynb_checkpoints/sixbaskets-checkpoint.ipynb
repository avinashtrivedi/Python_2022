# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='SIX Baskets')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'AETH SE Equity',
#  nan,
#  'ETHE SE Equity',
#  nan,
#  'ZETH SE Equity',
#  nan,
#  'VETH SE Equity',
#  nan,
#  'SETH SW  Equity',
#  nan,
#  'ETHW SE Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares AETH TURNOVER',
 '21Shares AETH AVERAGE_BID',
 'Coinshares ETHE TURNOVER',
 'Coinshares ETHE AVERAGE_BID',
 'ETC Group ZETH TURNOVER',
 'ETC Group ZETH AVERAGE_BID',
 'VanEck VETH TURNOVER',
 'VanEck VETH AVERAGE_BID',
 'Seba SETH TURNOVER',
 'Seba SETH AVERAGE_BID',
 'WisdomTree ETHW TURNOVER',
 'WisdomTree ETHW AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares AETH TURNOVER 21Shares AETH AVERAGE_BID  \
# 0    2021-05-03 00:00:00                6841896                    0.4353
# 1    2021-05-04 00:00:00               13219560                    0.4554
# 2    2021-05-05 00:00:00                9234200                    0.3172
# 3    2021-05-06 00:00:00                5763957                    0.2658
# 4    2021-05-07 00:00:00                8033618                    0.2672
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00                1529281                    0.1433
# 256  2022-04-26 00:00:00                2983519                    0.1305
# 257  2022-04-27 00:00:00                1173717                    0.1377
# 258  2022-04-28 00:00:00               609124.8                    0.1252
# 259  2022-04-29 00:00:00               470044.7                    0.1287
#
#     Coinshares ETHE TURNOVER Coinshares ETHE AVERAGE_BID  \
# 0                   597370.1                      0.4381
# 1                    2014451                      0.3367
# 2                    1465512                      0.4116
# 3                   151120.8                      0.3962
# 4                   355498.7                      0.3897
# ..                       ...                         ...
# 255                  1994300                      0.4832
# 256                    88410                      0.3138
# 257                  1917832                      0.2719
# 258                 118709.4                      0.3081
# 259                 118709.4                      0.6888
#
#     ETC Group ZETH TURNOVER ETC Group ZETH AVERAGE_BID VanEck VETH TURNOVER  \
# 0                       NaN                        NaN                  NaN
# 1                       NaN                        NaN                  NaN
# 2                       NaN                        NaN                  NaN
# 3                       NaN                        NaN                  NaN
# 4                       NaN                        NaN                  NaN
# ..                      ...                        ...                  ...
# 255                25090.22                     0.2565             15803.88
# 256                16666.54                     0.2338             15803.88
# 257                32136.02                     0.2599             15803.88
# 258                32136.02                     0.2666             15803.88
# 259                  7944.9                     0.2564                 1757
#
#     VanEck VETH AVERAGE_BID Seba SETH TURNOVER Seba SETH AVERAGE_BID  \
# 0                       NaN           65980.95                1.0741
# 1                       NaN           11062290                1.2545
# 2                       NaN             105319                1.2102
# 3                       NaN           11695.41                0.9638
# 4                       NaN            1841218                0.8169
# ..                      ...                ...                   ...
# 255                  0.4963              84345                0.2853
# 256                   0.367              88650                0.2593
# 257                  0.6029            59801.8                0.2646
# 258                  0.8379           69521.73                0.3368
# 259                  0.6871           61069.46                0.2639
#
#     WisdomTree ETHW TURNOVER WisdomTree ETHW AVERAGE_BID
# 0                    1503566                      0.3948
# 1                    6485772                      0.4126
# 2                   981612.3                       0.329
# 3                   208572.1                      0.3157
# 4                     398468                      0.3194
# ..                       ...                         ...
# 255                 172299.9                      0.2613
# 256                  64021.7                      0.2161
# 257                 10562.65                      0.2596
# 258                  5961.49                      0.2365
# 259                    28086                      0.2255
#
# [260 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# Dates                           0
# 21Shares AETH TURNOVER          0
# 21Shares AETH AVERAGE_BID       0
# Coinshares ETHE TURNOVER        0
# Coinshares ETHE AVERAGE_BID     0
# ETC Group ZETH TURNOVER        18
# ETC Group ZETH AVERAGE_BID     16
# VanEck VETH TURNOVER           30
# VanEck VETH AVERAGE_BID        29
# Seba SETH TURNOVER              0
# Seba SETH AVERAGE_BID           0
# WisdomTree ETHW TURNOVER        0
# WisdomTree ETHW AVERAGE_BID     0
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                          datetime64[ns]
# 21Shares AETH TURNOVER                 object
# 21Shares AETH AVERAGE_BID              object
# Coinshares ETHE TURNOVER               object
# Coinshares ETHE AVERAGE_BID            object
# ETC Group ZETH TURNOVER                object
# ETC Group ZETH AVERAGE_BID             object
# VanEck VETH TURNOVER                   object
# VanEck VETH AVERAGE_BID                object
# Seba SETH TURNOVER                     object
# Seba SETH AVERAGE_BID                  object
# WisdomTree ETHW TURNOVER               object
# WisdomTree ETHW AVERAGE_BID            object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                          datetime64[ns]
# 21Shares AETH TURNOVER                float64
# 21Shares AETH AVERAGE_BID             float64
# Coinshares ETHE TURNOVER              float64
# Coinshares ETHE AVERAGE_BID           float64
# ETC Group ZETH TURNOVER               float64
# ETC Group ZETH AVERAGE_BID            float64
# VanEck VETH TURNOVER                  float64
# VanEck VETH AVERAGE_BID               float64
# Seba SETH TURNOVER                    float64
# Seba SETH AVERAGE_BID                 float64
# WisdomTree ETHW TURNOVER              float64
# WisdomTree ETHW AVERAGE_BID           float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares AETH TURNOVER  Coinshares ETHE TURNOVER  \
# 0   2021      5             231876820.0               21144604.70
# 1   2021      6              42121693.1                2871922.95
# 2   2021      7              23358059.7                3107562.27
# 3   2021      8              53631476.1               13459384.95
# 4   2021      9              86304581.9               11393669.10
# 5   2021     10              92949055.4                7188646.88
# 6   2021     11              87475517.0                6605194.56
# 7   2021     12              69476998.0                2986764.16
# 8   2022      1              88189646.8                6748403.33
# 9   2022      2              58972914.7                2705692.57
# 10  2022      3              30324592.3                4907803.00
# 11  2022      4              35548623.3               12059119.51
#
#     ETC Group ZETH TURNOVER  VanEck VETH TURNOVER  Seba SETH TURNOVER  \
# 0                1464215.40                  0.00         57097768.18
# 1                1394628.80             301773.72          4879860.40
# 2                 980173.81             834988.39           931081.15
# 3                2931774.74            4267261.60          2574637.23
# 4                2516808.44            2022052.80          8815938.02
# 5                1328194.25            1114195.72          3800699.00
# 6                 996017.44            1324818.44          3065676.80
# 7                 682332.35            2086240.92          4240564.10
# 8                1157843.27            1227215.88          2776291.46
# 9                 309842.98             505687.04          1866582.58
# 10                620913.60             758334.27          5642647.60
# 11                609397.62            3630824.38          2967574.33
#
#     WisdomTree ETHW TURNOVER
# 0                21101564.94
# 1                10518403.19
# 2                 3674499.27
# 3                18235123.48
# 4                14864408.23
# 5                10888974.90
# 6                 8132760.82
# 7                 4989111.08
# 8                 5331481.19
# 9                 4557780.32
# 10                2726164.84
# 11                4860477.28

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("SIX Baskets Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("sixbaskets_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares AETH AVERAGE_BID  Coinshares ETHE AVERAGE_BID  \
# 0   2021      5                  34.751905                    47.155238
# 1   2021      6                  29.268182                    37.428182
# 2   2021      7                  24.700455                    30.517273
# 3   2021      8                  21.927727                    23.882273
# 4   2021      9                  26.621818                    32.906364
# 5   2021     10                  27.304286                    30.841905
# 6   2021     11                  36.430909                    42.098636
# 7   2021     12                  30.283043                    31.983043
# 8   2022      1                  28.698571                    31.901429
# 9   2022      2                  28.635500                    37.792500
# 10  2022      3                  19.565217                    49.893043
# 11  2022      4                  13.864762                    62.575238
#
#     ETC Group ZETH AVERAGE_BID  VanEck VETH AVERAGE_BID  \
# 0                    35.940000                      NaN
# 1                    37.471364                44.062143
# 2                    24.656364                28.532273
# 3                    20.947727                20.274091
# 4                    29.392273                34.859545
# 5                    34.956667                32.780476
# 6                    37.663182                44.944091
# 7                    29.480870                31.873913
# 8                    32.606190                34.257143
# 9                    33.234500                37.558500
# 10                   33.138696                80.423478
# 11                   26.325238                93.608095
#
#     Seba SETH AVERAGE_BID  WisdomTree ETHW AVERAGE_BID
# 0              102.003810                    51.954286
# 1               95.265000                    43.165000
# 2               90.253182                    28.234091
# 3               77.667727                    25.839091
# 4               37.066818                    37.812273
# 5               36.927143                    35.875238
# 6               27.301818                    39.511818
# 7               29.012174                    33.088696
# 8               36.538571                    33.319524
# 9               38.442000                    37.199000
# 10              32.803043                    44.395652
# 11              24.603333                    23.729048

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey']

# %%
len(bid_col)
# Out:
# 6

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("SIX Baskets Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.ylim([0,100])
plt.savefig("sixbaskets_bid_ask.png")
plt.show()
