# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='Xetra Ethereum ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'ETHA GY Equity',
#  nan,
#  'CETH GY Equity',
#  nan,
#  'ZETH GY Equity',
#  nan,
#  'VETH GY Equity',
#  nan,
#  'WETH GY  Equity',
#  nan,
#  'IETH GY  Equity',
#  nan,
#  'ET0X GY  Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares ETHA TURNOVER',
 '21Shares ETHA AVERAGE_BID',
 'ETC Group ZETH  TURNOVER',
 'ETC Group ZETH  AVERAGE_BID',
 'Vaneck VETH TURNOVER',
 'Vaneck VETH AVERAGE_BID',
 'Coinshares CETH TURNOVER',
 'Coinshares CETH AVERAGE_BID',
 'Bitpanda YBTC TURNOVER',
 'Bitpanda YBTC AVERAGE_BID',
 'Fidelity FBTC TURNOVER',
 'Fidelity FBTC AVERAGE_BID',
 'Iconic Physical IETH TURNOVER',
 'Iconic Physical IETH AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:,:]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares ETHA TURNOVER 21Shares ETHA AVERAGE_BID  \
# 0    2021-05-03 00:00:00                4428950                    0.2612
# 1    2021-05-04 00:00:00                6337787                    0.4076
# 2    2021-05-05 00:00:00                1661111                    0.3554
# 3    2021-05-06 00:00:00                1590712                    0.2617
# 4    2021-05-07 00:00:00                1771531                    0.3019
# ..                   ...                    ...                       ...
# 256  2022-04-26 00:00:00                 516723                    0.1206
# 257  2022-04-27 00:00:00               631662.9                    0.1355
# 258  2022-04-28 00:00:00                1234666                    0.1171
# 259  2022-04-29 00:00:00                1928060                    0.1038
# 260  2022-05-02 00:00:00               320483.9                    0.1038
#
#     ETC Group ZETH  TURNOVER ETC Group ZETH  AVERAGE_BID Vaneck VETH TURNOVER  \
# 0                        NaN                         NaN              4259656
# 1                        NaN                         NaN             15914400
# 2                        NaN                         NaN             11246170
# 3                        NaN                         NaN              6277655
# 4                        NaN                         NaN              3863811
# ..                       ...                         ...                  ...
# 256                 340280.8                      0.1707              3276926
# 257                  1764404                      0.1908              3416162
# 258                  1674112                      0.2014              5099854
# 259                   814434                      0.1775             10969890
# 260                 471082.1                      0.1775             730693.6
#
#     Vaneck VETH AVERAGE_BID Coinshares CETH TURNOVER  \
# 0                    0.1937                  4770692
# 1                    0.2657                  5798491
# 2                    0.2183                  5235575
# 3                    0.1917                  2740503
# 4                    0.2173                  2477834
# ..                      ...                      ...
# 256                  0.1245                  2284340
# 257                  0.1484                  1474594
# 258                  0.1527                  3342540
# 259                  0.1163                  2272453
# 260                  0.1163                 663528.2
#
#     Coinshares CETH AVERAGE_BID Bitpanda YBTC TURNOVER  \
# 0                        0.2585               253053.7
# 1                        0.2678               313716.9
# 2                        0.2457               99546.13
# 3                        0.2552               22606.89
# 4                        0.2627               709905.6
# ..                          ...                    ...
# 256                       0.159               88066.22
# 257                       0.203               261702.4
# 258                      0.1801               460759.8
# 259                      0.1752               215898.8
# 260                      0.1752               66165.79
#
#     Bitpanda YBTC AVERAGE_BID Fidelity FBTC TURNOVER  \
# 0                      0.1095                    NaN
# 1                      0.1881                    NaN
# 2                      0.1524                    NaN
# 3                      0.1336                    NaN
# 4                      0.1204                    NaN
# ..                        ...                    ...
# 256                    0.1625               10058.08
# 257                    0.1958               10058.08
# 258                    0.1672               10058.08
# 259                    0.1817               10314.44
# 260                    0.1817                  809.1
#
#     Fidelity FBTC AVERAGE_BID Iconic Physical IETH TURNOVER  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ..                        ...                           ...
# 256                    0.3315                        6562.4
# 257                    0.3752                        6562.4
# 258                    0.3884                        6562.4
# 259                    0.3408                        6562.4
# 260                    0.3408                        6562.4
#
#     Iconic Physical IETH AVERAGE_BID
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 256                           0.1989
# 257                            0.246
# 258                           0.2151
# 259                           0.2229
# 260                           0.2229
#
# [261 rows x 15 columns]

# %%
df.isna().sum()
# Out:
# Dates                                 0
# 21Shares ETHA TURNOVER                0
# 21Shares ETHA AVERAGE_BID             0
# ETC Group ZETH  TURNOVER             25
# ETC Group ZETH  AVERAGE_BID          25
# Vaneck VETH TURNOVER                  0
# Vaneck VETH AVERAGE_BID               0
# Coinshares CETH TURNOVER              0
# Coinshares CETH AVERAGE_BID           0
# Bitpanda YBTC TURNOVER                0
# Bitpanda YBTC AVERAGE_BID             0
# Fidelity FBTC TURNOVER              165
# Fidelity FBTC AVERAGE_BID           165
# Iconic Physical IETH TURNOVER       239
# Iconic Physical IETH AVERAGE_BID    222
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                               datetime64[ns]
# 21Shares ETHA TURNOVER                      object
# 21Shares ETHA AVERAGE_BID                   object
# ETC Group ZETH  TURNOVER                    object
# ETC Group ZETH  AVERAGE_BID                 object
# Vaneck VETH TURNOVER                        object
# Vaneck VETH AVERAGE_BID                     object
# Coinshares CETH TURNOVER                    object
# Coinshares CETH AVERAGE_BID                 object
# Bitpanda YBTC TURNOVER                      object
# Bitpanda YBTC AVERAGE_BID                   object
# Fidelity FBTC TURNOVER                      object
# Fidelity FBTC AVERAGE_BID                   object
# Iconic Physical IETH TURNOVER               object
# Iconic Physical IETH AVERAGE_BID            object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                               datetime64[ns]
# 21Shares ETHA TURNOVER                     float64
# 21Shares ETHA AVERAGE_BID                  float64
# ETC Group ZETH  TURNOVER                   float64
# ETC Group ZETH  AVERAGE_BID                float64
# Vaneck VETH TURNOVER                       float64
# Vaneck VETH AVERAGE_BID                    float64
# Coinshares CETH TURNOVER                   float64
# Coinshares CETH AVERAGE_BID                float64
# Bitpanda YBTC TURNOVER                     float64
# Bitpanda YBTC AVERAGE_BID                  float64
# Fidelity FBTC TURNOVER                     float64
# Fidelity FBTC AVERAGE_BID                  float64
# Iconic Physical IETH TURNOVER              float64
# Iconic Physical IETH AVERAGE_BID           float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares ETHA TURNOVER  ETC Group ZETH  TURNOVER  \
# 0   2021      5              88435318.0                      0.00
# 1   2021      6              25833427.5                1101190.87
# 2   2021      7              29129790.6                7703454.61
# 3   2021      8              33108256.6                9891406.08
# 4   2021      9              59195133.2               17841402.30
# 5   2021     10              60337506.0               12968445.46
# 6   2021     11              70198670.0               13170371.78
# 7   2021     12              48349137.2               16555692.40
# 8   2022      1              77547204.2               27982555.30
# 9   2022      2              50780945.2               20810382.80
# 10  2022      3              38452236.3               17341223.50
# 11  2022      4              36462275.0               19322450.20
# 12  2022      5                320483.9                 471082.10
#
#     Vaneck VETH TURNOVER  Coinshares CETH TURNOVER  Bitpanda YBTC TURNOVER  \
# 0            186403202.0               119509688.0             12118676.85
# 1             90244190.0                52899582.7             13728038.67
# 2             66695624.5                46914007.5             20703672.48
# 3             97843496.1               106216793.0             10554871.43
# 4             66047423.3               105148202.4             17876602.27
# 5             95847536.7               116063855.0             12739659.08
# 6            128742484.0               151367528.0             15331065.30
# 7            198760208.0               133616697.4             19307541.30
# 8            154989016.6                69032859.0             17681307.90
# 9             68835710.0                70081708.0             12491165.10
# 10            97096495.6               100411255.9              8281763.10
# 11           127952453.0                56310181.0              6573485.32
# 12              730693.6                  663528.2                66165.79
#
#     Fidelity FBTC TURNOVER  Iconic Physical IETH TURNOVER
# 0                     0.00                            0.0
# 1                     0.00                            0.0
# 2                     0.00                            0.0
# 3                     0.00                            0.0
# 4                     0.00                            0.0
# 5                     0.00                            0.0
# 6                     0.00                            0.0
# 7                304865.72                            0.0
# 8                213051.56                            0.0
# 9                635138.04                            0.0
# 10               296863.60                            0.0
# 11                92514.61                       137810.4
# 12                  809.10                         6562.4

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,12]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("Xetra Ethereum ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€m)")
plt.savefig("xetraeth_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares ETHA AVERAGE_BID  ETC Group ZETH  AVERAGE_BID  \
# 0   2021      5                  37.157143                          NaN
# 1   2021      6                  26.628182                    39.553333
# 2   2021      7                  19.006818                    25.527727
# 3   2021      8                  16.547727                    20.638182
# 4   2021      9                  20.450455                    22.244091
# 5   2021     10                  22.522381                    22.068571
# 6   2021     11                  20.414091                    20.064091
# 7   2021     12                  20.378696                    18.676522
# 8   2022      1                  19.868095                    19.484762
# 9   2022      2                  18.924500                    19.229500
# 10  2022      3                  16.198696                    21.422609
# 11  2022      4                  12.580000                    19.553333
# 12  2022      5                  10.380000                    17.750000
#
#     Vaneck VETH AVERAGE_BID  Coinshares CETH AVERAGE_BID  \
# 0                 27.564286                    30.287619
# 1                 17.643636                    21.288636
# 2                 17.001364                    16.311818
# 3                 14.811818                    13.467273
# 4                 18.180000                    18.447727
# 5                 17.912381                    17.582381
# 6                 15.122273                    14.738636
# 7                 14.453478                    15.198696
# 8                 15.504762                    17.870000
# 9                 16.565500                    18.396000
# 10                17.336522                    18.668696
# 11                14.656190                    18.040952
# 12                11.630000                    17.520000
#
#     Bitpanda YBTC AVERAGE_BID  Fidelity FBTC AVERAGE_BID  \
# 0                   32.121905                        NaN
# 1                   29.569091                        NaN
# 2                   21.957727                        NaN
# 3                   19.713182                        NaN
# 4                   23.208636                        NaN
# 5                   23.636190                        NaN
# 6                   21.308182                        NaN
# 7                   19.213913                  34.683000
# 8                   20.728095                  40.323810
# 9                   23.166000                  51.573500
# 10                  25.158696                  49.827391
# 11                  17.984286                  36.638571
# 12                  18.170000                  34.080000
#
#     Iconic Physical IETH AVERAGE_BID
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                         19.757059
# 11                         21.803810
# 12                         22.290000

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey','black']

# %%
len(bid_col)
# Out:
# 7

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,12]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("Xetra Ethereum ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.ylim([0,100])
plt.savefig("xetraeth_bid_ask.png", bbox_inches = "tight")
plt.show()
