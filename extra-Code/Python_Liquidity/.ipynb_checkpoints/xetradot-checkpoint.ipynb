# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='Xetra Polkadot ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'ADOT GY Equity',
#  nan,
#  'VDOT GY Equity',
#  nan,
#  'TDOT GY Equity',
#  nan,
#  'PLKA GY Equity',
#  nan,
#  'CDOT GY Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares ADOT TURNOVER',
 '21Shares ADOT AVERAGE_BID',
 'VanEck VDOT TURNOVER',
 'VanEck VDOT AVERAGE_BID',
 'ETC Group PLKA TURNOVER',
 'ETC Group PLKA AVERAGE_BID',
 'Coinshares CDOT TURNOVER',
 'Coinshares CDOT AVERAGE_BID',
 'Bitpanda TDOT TURNOVER',
 'Bitpanda TDOT AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares ADOT TURNOVER 21Shares ADOT AVERAGE_BID  \
# 0    2021-05-03 00:00:00                    NaN                       NaN
# 1    2021-05-04 00:00:00                    NaN                       NaN
# 2    2021-05-05 00:00:00                    NaN                       NaN
# 3    2021-05-06 00:00:00                    NaN                       NaN
# 4    2021-05-07 00:00:00                    NaN                       NaN
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00               28441.19                    0.3859
# 256  2022-04-26 00:00:00               15772.01                     0.381
# 257  2022-04-27 00:00:00               12071.17                    0.3793
# 258  2022-04-28 00:00:00                4784.71                    0.3813
# 259  2022-04-29 00:00:00                3398.43                    0.3919
#
#     VanEck VDOT TURNOVER VanEck VDOT AVERAGE_BID ETC Group PLKA TURNOVER  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
# ..                   ...                     ...                     ...
# 255             62558.84                  1.0034                     NaN
# 256              5936.89                  0.8752                     NaN
# 257              2756.63                   0.978                     NaN
# 258              38018.1                  1.2704                  1696.2
# 259             34019.28                  0.7028                  1696.2
#
#     ETC Group PLKA AVERAGE_BID Coinshares CDOT TURNOVER  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ..                         ...                      ...
# 255                     0.7155                    64.08
# 256                     0.7217                     4.09
# 257                      0.723                     4.09
# 258                     0.7132                 14148.02
# 259                      0.743                 14148.02
#
#     Coinshares CDOT AVERAGE_BID Bitpanda TDOT TURNOVER  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
# ..                          ...                    ...
# 255                      1.7339               15661.77
# 256                      0.7835                19489.2
# 257                       1.273               16732.19
# 258                      1.1165               10237.03
# 259                      0.7275                  30267
#
#     Bitpanda TDOT AVERAGE_BID
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 255                    0.6231
# 256                    0.5975
# 257                    0.5675
# 258                    0.6187
# 259                    0.5456
#
# [260 rows x 11 columns]

# %%
df.isna().sum()
# Out:
# Dates                            0
# 21Shares ADOT TURNOVER         103
# 21Shares ADOT AVERAGE_BID      103
# VanEck VDOT TURNOVER           101
# VanEck VDOT AVERAGE_BID        101
# ETC Group PLKA TURNOVER        258
# ETC Group PLKA AVERAGE_BID     253
# Coinshares CDOT TURNOVER       164
# Coinshares CDOT AVERAGE_BID    160
# Bitpanda TDOT TURNOVER         192
# Bitpanda TDOT AVERAGE_BID      192
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                          datetime64[ns]
# 21Shares ADOT TURNOVER                 object
# 21Shares ADOT AVERAGE_BID              object
# VanEck VDOT TURNOVER                   object
# VanEck VDOT AVERAGE_BID                object
# ETC Group PLKA TURNOVER                object
# ETC Group PLKA AVERAGE_BID             object
# Coinshares CDOT TURNOVER               object
# Coinshares CDOT AVERAGE_BID            object
# Bitpanda TDOT TURNOVER                 object
# Bitpanda TDOT AVERAGE_BID              object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                          datetime64[ns]
# 21Shares ADOT TURNOVER                float64
# 21Shares ADOT AVERAGE_BID             float64
# VanEck VDOT TURNOVER                  float64
# VanEck VDOT AVERAGE_BID               float64
# ETC Group PLKA TURNOVER               float64
# ETC Group PLKA AVERAGE_BID            float64
# Coinshares CDOT TURNOVER              float64
# Coinshares CDOT AVERAGE_BID           float64
# Bitpanda TDOT TURNOVER                float64
# Bitpanda TDOT AVERAGE_BID             float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares ADOT TURNOVER  VanEck VDOT TURNOVER  \
# 0   2021      5                    0.00                  0.00
# 1   2021      6                    0.00                  0.00
# 2   2021      7                    0.00                  0.00
# 3   2021      8                    0.00                  0.00
# 4   2021      9               377655.37             264514.51
# 5   2021     10              5935175.58            3023543.21
# 6   2021     11              6716451.21            4985668.99
# 7   2021     12              5183195.19            2474335.63
# 8   2022      1              3626942.99            2743433.99
# 9   2022      2              1910813.22             635886.18
# 10  2022      3              3028336.86            1349242.69
# 11  2022      4               952938.29             454506.55
#
#     ETC Group PLKA TURNOVER  Coinshares CDOT TURNOVER  Bitpanda TDOT TURNOVER
# 0                       0.0                      0.00                    0.00
# 1                       0.0                      0.00                    0.00
# 2                       0.0                      0.00                    0.00
# 3                       0.0                      0.00                    0.00
# 4                       0.0                      0.00                    0.00
# 5                       0.0                      0.00                    0.00
# 6                       0.0                      0.00                    0.00
# 7                       0.0                  77657.69                    0.00
# 8                       0.0                 421854.85                 4365.40
# 9                       0.0                 120964.17              1180887.97
# 10                      0.0                  16378.95              1343088.30
# 11                   3392.4                  31405.89              1015665.10

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("Xetra Polkadot ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("xetradot_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares ADOT AVERAGE_BID  VanEck VDOT AVERAGE_BID  \
# 0   2021      5                        NaN                      NaN
# 1   2021      6                        NaN                      NaN
# 2   2021      7                        NaN                      NaN
# 3   2021      8                        NaN                      NaN
# 4   2021      9                  59.941667                62.953750
# 5   2021     10                  61.166190                52.064286
# 6   2021     11                  67.451364                56.185000
# 7   2021     12                  62.003478                52.365217
# 8   2022      1                  59.992857                57.626190
# 9   2022      2                  88.665500                68.125500
# 10  2022      3                  67.819130                76.537826
# 11  2022      4                  48.561905                83.295238
#
#     ETC Group PLKA AVERAGE_BID  Coinshares CDOT AVERAGE_BID  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                          NaN                    60.118000
# 8                          NaN                    64.177619
# 9                          NaN                    81.332500
# 10                         NaN                    95.216957
# 11                   72.098571                   116.444286
#
#     Bitpanda TDOT AVERAGE_BID
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                   76.757500
# 9                   83.184000
# 10                  73.476522
# 11                  71.950000

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey']

# %%
len(bid_col)
# Out:
# 5

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("Xetra Polkadot ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.savefig("xetradot_bid_ask.png", bbox_inches = "tight")
plt.show()
