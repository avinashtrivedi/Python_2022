# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='ENX Amsterdam Ethereum ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'AETH NA Equity',
#  nan,
#  'CETH NA Equity',
#  nan,
#  'ZETH NA Equity',
#  nan,
#  'VETH NA Equity',
#  nan,
#  'SETH NA Equity',
#  nan,
#  'ETHW NA Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares AETH TURNOVER',
 '21Shares AETH AVERAGE_BID',
 'Coinshares CETH  TURNOVER',
 'Coinshares CETH  AVERAGE_BID',
 'Seba SETH TURNOVER',
 'Seba SETH AVERAGE_BID',
 'VanEck VETH TURNOVER',
 'VanEck VETH AVERAGE_BID',
 'ETC Group ZETH TURNOVER',
 'ETC Group ZETH AVERAGE_BID',
 'WisdomTree WETH TURNOVER',
 'WisdomTree WETH AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares AETH TURNOVER 21Shares AETH AVERAGE_BID  \
# 0    2021-05-03 00:00:00                    NaN                       NaN
# 1    2021-05-04 00:00:00                    NaN                       NaN
# 2    2021-05-05 00:00:00                    NaN                       NaN
# 3    2021-05-06 00:00:00                    NaN                       NaN
# 4    2021-05-07 00:00:00                    NaN                       NaN
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00                  33495                    0.2936
# 256  2022-04-26 00:00:00                   8320                    0.2881
# 257  2022-04-27 00:00:00                   8320                    0.3001
# 258  2022-04-28 00:00:00                   8320                     0.311
# 259  2022-04-29 00:00:00                   8320                    0.2815
#
#     Coinshares CETH  TURNOVER Coinshares CETH  AVERAGE_BID Seba SETH TURNOVER  \
# 0                         NaN                          NaN                NaN
# 1                         NaN                          NaN                NaN
# 2                         NaN                          NaN                NaN
# 3                         NaN                          NaN                NaN
# 4                         NaN                          NaN                NaN
# ..                        ...                          ...                ...
# 255                   5753.57                       0.4679           17282.82
# 256                   5753.57                       0.3209           16672.22
# 257                   5753.57                       0.4506           32136.02
# 258                  19124.82                       0.3741            40424.7
# 259                  19124.82                       0.3252             7944.9
#
#     Seba SETH AVERAGE_BID VanEck VETH TURNOVER VanEck VETH AVERAGE_BID  \
# 0                     NaN                  NaN                     NaN
# 1                     NaN                  NaN                     NaN
# 2                     NaN                  NaN                     NaN
# 3                     NaN                  NaN                     NaN
# 4                     NaN                  NaN                     NaN
# ..                    ...                  ...                     ...
# 255                 0.306             81630.31                  0.3142
# 256                 0.272              2424.38                  0.2895
# 257                0.2952             10481.15                  0.3759
# 258                0.3062             44857.63                  0.3733
# 259                 0.284              1189.83                  0.3189
#
#     ETC Group ZETH TURNOVER ETC Group ZETH AVERAGE_BID  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ..                      ...                        ...
# 255                   84330                     0.3286
# 256                   88650                     0.2963
# 257                   84990                     0.3052
# 258                   84990                     0.3439
# 259                   84990                     0.3038
#
#     WisdomTree WETH TURNOVER WisdomTree WETH AVERAGE_BID
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ..                       ...                         ...
# 255                  9037.05                      0.2786
# 256                  9037.05                       0.206
# 257                   704.35                      0.2622
# 258                 25789.05                      0.2363
# 259                 25789.05                      0.2112
#
# [260 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# Dates                             0
# 21Shares AETH TURNOVER           25
# 21Shares AETH AVERAGE_BID        23
# Coinshares CETH  TURNOVER        92
# Coinshares CETH  AVERAGE_BID     83
# Seba SETH TURNOVER               27
# Seba SETH AVERAGE_BID            21
# VanEck VETH TURNOVER             22
# VanEck VETH AVERAGE_BID          21
# ETC Group ZETH TURNOVER         232
# ETC Group ZETH AVERAGE_BID      230
# WisdomTree WETH TURNOVER         24
# WisdomTree WETH AVERAGE_BID      21
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                           datetime64[ns]
# 21Shares AETH TURNOVER                  object
# 21Shares AETH AVERAGE_BID               object
# Coinshares CETH  TURNOVER               object
# Coinshares CETH  AVERAGE_BID            object
# Seba SETH TURNOVER                      object
# Seba SETH AVERAGE_BID                   object
# VanEck VETH TURNOVER                    object
# VanEck VETH AVERAGE_BID                 object
# ETC Group ZETH TURNOVER                 object
# ETC Group ZETH AVERAGE_BID              object
# WisdomTree WETH TURNOVER                object
# WisdomTree WETH AVERAGE_BID             object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                           datetime64[ns]
# 21Shares AETH TURNOVER                 float64
# 21Shares AETH AVERAGE_BID              float64
# Coinshares CETH  TURNOVER              float64
# Coinshares CETH  AVERAGE_BID           float64
# Seba SETH TURNOVER                     float64
# Seba SETH AVERAGE_BID                  float64
# VanEck VETH TURNOVER                   float64
# VanEck VETH AVERAGE_BID                float64
# ETC Group ZETH TURNOVER                float64
# ETC Group ZETH AVERAGE_BID             float64
# WisdomTree WETH TURNOVER               float64
# WisdomTree WETH AVERAGE_BID            float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares AETH TURNOVER  Coinshares CETH  TURNOVER  \
# 0   2021      5                    0.00                       0.00
# 1   2021      6               842733.04                       0.00
# 2   2021      7               899645.51                       0.00
# 3   2021      8               985633.71                       0.00
# 4   2021      9               847450.28                    7476.70
# 5   2021     10               662501.73                 8500738.91
# 6   2021     11               778925.82                 1991326.54
# 7   2021     12               845667.95                    8100.80
# 8   2022      1              1463183.37                 2393516.13
# 9   2022      2              1037133.47                  981677.56
# 10  2022      3               600237.19                  407170.06
# 11  2022      4              1685609.00                  726129.62
#
#     Seba SETH TURNOVER  VanEck VETH TURNOVER  ETC Group ZETH TURNOVER  \
# 0                 0.00                  0.00                     0.00
# 1            305982.41            1843372.75                     0.00
# 2            842646.84             770464.02                     0.00
# 3           1181363.86            2030010.57                     0.00
# 4            416040.05            2028216.88                     0.00
# 5            817261.69            1502399.60                     0.00
# 6            953080.09            1703192.90                     0.00
# 7           1187064.88            2296570.42                     0.00
# 8            616647.70            1327627.18                     0.00
# 9            564793.03            2125708.21                     0.00
# 10          1033130.61            2154427.79                748345.00
# 11           600403.98            1054382.90               1872113.29
#
#     WisdomTree WETH TURNOVER
# 0                       0.00
# 1                  103201.60
# 2                  117711.80
# 3                   89377.20
# 4                 1175513.25
# 5                 1042449.16
# 6                 1361745.18
# 7                  261835.18
# 8                  609144.11
# 9                  429162.00
# 10                 204393.07
# 11                 424243.07

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Amsterdam Ethereum ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("amseth_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares AETH AVERAGE_BID  Coinshares CETH  AVERAGE_BID  \
# 0   2021      5                        NaN                           NaN
# 1   2021      6                  46.556500                           NaN
# 2   2021      7                  26.067727                           NaN
# 3   2021      8                  20.573636                     38.820000
# 4   2021      9                  36.926364                     38.170909
# 5   2021     10                  42.883333                     34.380476
# 6   2021     11                  32.990000                     33.900909
# 7   2021     12                  35.620435                     44.652174
# 8   2022      1                  36.513333                     37.007143
# 9   2022      2                  35.430000                     34.431500
# 10  2022      3                  37.281739                     35.672174
# 11  2022      4                  30.550476                     37.137143
#
#     Seba SETH AVERAGE_BID  VanEck VETH AVERAGE_BID  \
# 0                     NaN                      NaN
# 1               39.153636                37.252727
# 2               47.965455                30.876364
# 3               42.003636                30.540455
# 4               41.450000                40.650455
# 5               38.136190                34.081905
# 6               35.955909                35.949091
# 7               37.157391                33.658261
# 8               34.300952                31.307619
# 9               34.481000                31.900500
# 10              34.270000                33.984348
# 11              30.590000                40.269048
#
#     ETC Group ZETH AVERAGE_BID  WisdomTree WETH AVERAGE_BID
# 0                          NaN                          NaN
# 1                          NaN                    38.743636
# 2                          NaN                    45.512273
# 3                          NaN                    43.660909
# 4                          NaN                    44.026364
# 5                          NaN                    38.843333
# 6                          NaN                    35.953182
# 7                          NaN                    37.077391
# 8                          NaN                    35.583333
# 9                          NaN                    36.697500
# 10                   35.073333                    37.912609
# 11                   29.755714                    24.203333

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey']

# %%
len(bid_col)
# Out:
# 6

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Amsterdam Ethereum ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.savefig("amseth_bid_ask.png", bbox_inches = "tight")
plt.show()
