# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='ENX Paris Ethereum ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'AETH FP Equity',
#  nan,
#  'CETH FP Equity ',
#  nan,
#  'ZETH FP Equity',
#  nan,
#  'VETH FP Equity',
#  nan,
#  'SETH FP Equity',
#  nan,
#  'WETH FP Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares AETH TURNOVER',
 '21Shares AETH AVERAGE_BID',
 'Coinshares CETH  TURNOVER',
 'Coinshares CETH  AVERAGE_BID',
 'Seba SETH TURNOVER',
 'Seba SETH AVERAGE_BID',
 'VanEck VETH TURNOVER',
 'VanEck VETH AVERAGE_BID',
 'ETC Group ZETH TURNOVER',
 'ETC Group ZETH AVERAGE_BID',
 'WisdomTree WETH TURNOVER',
 'WisdomTree WETH AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares AETH TURNOVER 21Shares AETH AVERAGE_BID  \
# 0    2021-05-03 00:00:00                    NaN                       NaN
# 1    2021-05-04 00:00:00                    NaN                       NaN
# 2    2021-05-05 00:00:00                    NaN                       NaN
# 3    2021-05-06 00:00:00                    NaN                       NaN
# 4    2021-05-07 00:00:00                    NaN                       NaN
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00               47606.42                    0.2783
# 256  2022-04-26 00:00:00               20211.69                     0.291
# 257  2022-04-27 00:00:00               16016.74                    0.3043
# 258  2022-04-28 00:00:00               12657.71                    0.3175
# 259  2022-04-29 00:00:00                3547.39                    0.2839
#
#     Coinshares CETH  TURNOVER Coinshares CETH  AVERAGE_BID Seba SETH TURNOVER  \
# 0                         NaN                          NaN                NaN
# 1                         NaN                          NaN                NaN
# 2                         NaN                          NaN                NaN
# 3                         NaN                          NaN                NaN
# 4                         NaN                          NaN                NaN
# ..                        ...                          ...                ...
# 255                  124511.5                       0.4691            6957.86
# 256                  124511.5                       0.3149            18398.2
# 257                  124511.5                       0.3339           26781.58
# 258                  124511.5                       0.3394           26781.58
# 259                  124511.5                       0.3111            8875.82
#
#     Seba SETH AVERAGE_BID VanEck VETH TURNOVER VanEck VETH AVERAGE_BID  \
# 0                     NaN                  NaN                     NaN
# 1                     NaN                  NaN                     NaN
# 2                     NaN                  NaN                     NaN
# 3                     NaN                  NaN                     NaN
# 4                     NaN                  NaN                     NaN
# ..                    ...                  ...                     ...
# 255                0.2956             35641.37                  0.7332
# 256                0.2674              5294.19                  0.4097
# 257                0.2946              4289.53                  0.7244
# 258                0.3008                337.4                  0.5143
# 259                0.2818                337.4                   0.447
#
#     ETC Group ZETH TURNOVER ETC Group ZETH AVERAGE_BID  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ..                      ...                        ...
# 255                   78630                     0.3288
# 256                   78630                     0.2962
# 257                   78630                     0.3037
# 258                   78630                     0.3315
# 259                   78630                     0.2987
#
#     WisdomTree WETH TURNOVER WisdomTree WETH AVERAGE_BID
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ..                       ...                         ...
# 255                 69353.25                      0.2841
# 256                 69353.25                      0.2158
# 257                 69353.25                      0.2698
# 258                 24319.31                      0.2447
# 259                  7574.91                      0.2176
#
# [260 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# Dates                             0
# 21Shares AETH TURNOVER           21
# 21Shares AETH AVERAGE_BID        21
# Coinshares CETH  TURNOVER       110
# Coinshares CETH  AVERAGE_BID     83
# Seba SETH TURNOVER               22
# Seba SETH AVERAGE_BID            21
# VanEck VETH TURNOVER             22
# VanEck VETH AVERAGE_BID          21
# ETC Group ZETH TURNOVER         233
# ETC Group ZETH AVERAGE_BID      230
# WisdomTree WETH TURNOVER         21
# WisdomTree WETH AVERAGE_BID      21
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                           datetime64[ns]
# 21Shares AETH TURNOVER                  object
# 21Shares AETH AVERAGE_BID               object
# Coinshares CETH  TURNOVER               object
# Coinshares CETH  AVERAGE_BID            object
# Seba SETH TURNOVER                      object
# Seba SETH AVERAGE_BID                   object
# VanEck VETH TURNOVER                    object
# VanEck VETH AVERAGE_BID                 object
# ETC Group ZETH TURNOVER                 object
# ETC Group ZETH AVERAGE_BID              object
# WisdomTree WETH TURNOVER                object
# WisdomTree WETH AVERAGE_BID             object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                           datetime64[ns]
# 21Shares AETH TURNOVER                 float64
# 21Shares AETH AVERAGE_BID              float64
# Coinshares CETH  TURNOVER              float64
# Coinshares CETH  AVERAGE_BID           float64
# Seba SETH TURNOVER                     float64
# Seba SETH AVERAGE_BID                  float64
# VanEck VETH TURNOVER                   float64
# VanEck VETH AVERAGE_BID                float64
# ETC Group ZETH TURNOVER                float64
# ETC Group ZETH AVERAGE_BID             float64
# WisdomTree WETH TURNOVER               float64
# WisdomTree WETH AVERAGE_BID            float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares AETH TURNOVER  Coinshares CETH  TURNOVER  \
# 0   2021      5                    0.00                       0.00
# 1   2021      6               953509.13                       0.00
# 2   2021      7              1044468.83                       0.00
# 3   2021      8               951144.01                       0.00
# 4   2021      9              2503776.68                       0.00
# 5   2021     10              2360375.23                 9021691.89
# 6   2021     11              2206831.63                  236660.94
# 7   2021     12              2897690.98                   95200.72
# 8   2022      1              2061409.47                 1379098.48
# 9   2022      2              1141197.15                  448005.60
# 10  2022      3              1612941.67                  136950.91
# 11  2022      4              1723393.81                 2597215.00
#
#     Seba SETH TURNOVER  VanEck VETH TURNOVER  ETC Group ZETH TURNOVER  \
# 0                 0.00                  0.00                     0.00
# 1            974850.23             985331.73                     0.00
# 2           1163426.02             471233.39                     0.00
# 3            576664.29             618309.45                     0.00
# 4            270301.42             747322.70                     0.00
# 5            463382.89            1898038.76                     0.00
# 6            524792.13             711025.64                     0.00
# 7            937287.42             792192.71                     0.00
# 8            899776.67             798858.46                     0.00
# 9            524838.01             923500.52                     0.00
# 10           652926.38             763245.56                507250.26
# 11           699302.40             356735.63               2167524.50
#
#     WisdomTree WETH TURNOVER
# 0                       0.00
# 1                   46706.42
# 2                  400873.84
# 3                  647032.88
# 4                  524084.90
# 5                  384385.93
# 6                  533147.66
# 7                  156922.00
# 8                  766436.40
# 9                  309166.18
# 10                 180439.84
# 11                 696301.72

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Paris Ethereum ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("pariseth_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares AETH AVERAGE_BID  Coinshares CETH  AVERAGE_BID  \
# 0   2021      5                        NaN                           NaN
# 1   2021      6                  31.405000                           NaN
# 2   2021      7                  26.784545                           NaN
# 3   2021      8                  21.689091                     38.820000
# 4   2021      9                  34.736364                     38.157727
# 5   2021     10                  42.143333                     34.681905
# 6   2021     11                  32.665909                     34.070000
# 7   2021     12                  34.398696                     35.198696
# 8   2022      1                  35.581905                     34.363333
# 9   2022      2                  33.258500                     33.207000
# 10  2022      3                  33.570000                     36.245217
# 11  2022      4                  30.254286                     36.944286
#
#     Seba SETH AVERAGE_BID  VanEck VETH AVERAGE_BID  \
# 0                     NaN                      NaN
# 1               38.740455                37.335909
# 2               47.653636                31.465909
# 3               42.779091                30.760909
# 4               43.617727                40.304091
# 5               37.218571                35.247143
# 6               33.195909                36.323636
# 7               34.943478                34.659565
# 8               35.883810                34.178095
# 9               33.361500                36.431500
# 10              37.924783                39.440870
# 11              30.503333                61.580000
#
#     ETC Group ZETH AVERAGE_BID  WisdomTree WETH AVERAGE_BID
# 0                          NaN                          NaN
# 1                          NaN                    37.898636
# 2                          NaN                    40.443636
# 3                          NaN                    39.647727
# 4                          NaN                    42.318182
# 5                          NaN                    37.956667
# 6                          NaN                    37.565455
# 7                          NaN                    40.747826
# 8                          NaN                    38.258095
# 9                          NaN                    36.268000
# 10                   36.454444                    36.697826
# 11                   30.043810                    24.402381

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey']

# %%
len(bid_col)
# Out:
# 6

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Paris Ethereum ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.savefig("pariseth_bid_ask.png", bbox_inches = "tight")
plt.show()
