# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='ENX Amsterdam Bitcoin ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  'ABTC NA Equity',
#  nan,
#  'BTCE NA Equity',
#  nan,
#  'BITC NA Equity',
#  nan,
#  'SBTCU NA Equity',
#  nan,
#  'XBTI NA Equity',
#  nan,
#  'YBTC NA Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares ABTC TURNOVER',
 '21Shares ABTC AVERAGE_BID',
 'Coinshares BITC  TURNOVER',
 'Coinshares BITC  AVERAGE_BID',
 'Seba SBTCU TURNOVER',
 'Seba SBTCU AVERAGE_BID',
 'ETC Group BTCE TURNOVER',
 'ETC Group BTCE AVERAGE_BID',
 'Iconic Physical XBTIUSD TURNOVER',
 'Iconic Physical XBTIUSD AVERAGE_BID',
 'Bitpanda YBTC TURNOVER',
 'Bitpanda YBTC AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares ABTC TURNOVER 21Shares ABTC AVERAGE_BID  \
# 0    2021-05-03 00:00:00                    NaN                       NaN
# 1    2021-05-04 00:00:00                    NaN                       NaN
# 2    2021-05-05 00:00:00                    NaN                       NaN
# 3    2021-05-06 00:00:00                    NaN                       NaN
# 4    2021-05-07 00:00:00                    NaN                       NaN
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00                8098.01                    0.2962
# 256  2022-04-26 00:00:00                8098.01                    0.2786
# 257  2022-04-27 00:00:00                8098.01                    0.2884
# 258  2022-04-28 00:00:00                8098.01                    0.3026
# 259  2022-04-29 00:00:00                8098.01                    0.2604
#
#     Coinshares BITC  TURNOVER Coinshares BITC  AVERAGE_BID  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ..                        ...                          ...
# 255                  89279.32                       0.3003
# 256                  24777.68                       0.2503
# 257                  16092.75                       0.2721
# 258                   8274.28                        0.294
# 259                  16114.25                       0.2548
#
#     Seba SBTCU TURNOVER Seba SBTCU AVERAGE_BID ETC Group BTCE TURNOVER  \
# 0                   NaN                    NaN                     NaN
# 1                   NaN                    NaN                     NaN
# 2                   NaN                    NaN                     NaN
# 3                   NaN                    NaN                     NaN
# 4                   NaN                    NaN                     NaN
# ..                  ...                    ...                     ...
# 255                38.3                 0.4979                179839.8
# 256                38.3                 0.3107                179839.8
# 257                38.3                 0.3753                270806.8
# 258                38.3                 0.3699                372746.6
# 259                38.3                 0.4613                372746.6
#
#     ETC Group BTCE AVERAGE_BID Iconic Physical XBTIUSD TURNOVER  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
# ..                         ...                              ...
# 255                     0.3073                         72653.98
# 256                     0.2748                         72653.98
# 257                     0.2838                         72653.98
# 258                     0.2965                         72653.98
# 259                      0.249                         72653.98
#
#     Iconic Physical XBTIUSD AVERAGE_BID Bitpanda YBTC TURNOVER  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ..                                  ...                    ...
# 255                              0.3985                    NaN
# 256                              0.4052                    NaN
# 257                              0.6318                    NaN
# 258                              0.3285                    NaN
# 259                              0.4805                    NaN
#
#     Bitpanda YBTC AVERAGE_BID
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 255                    0.3856
# 256                    0.3599
# 257                     0.398
# 258                    0.4259
# 259                    0.3884
#
# [260 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# Dates                                    0
# 21Shares ABTC TURNOVER                  26
# 21Shares ABTC AVERAGE_BID               23
# Coinshares BITC  TURNOVER               35
# Coinshares BITC  AVERAGE_BID            21
# Seba SBTCU TURNOVER                    112
# Seba SBTCU AVERAGE_BID                  91
# ETC Group BTCE TURNOVER                232
# ETC Group BTCE AVERAGE_BID             230
# Iconic Physical XBTIUSD TURNOVER        52
# Iconic Physical XBTIUSD AVERAGE_BID     43
# Bitpanda YBTC TURNOVER                 260
# Bitpanda YBTC AVERAGE_BID              240
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                                  datetime64[ns]
# 21Shares ABTC TURNOVER                         object
# 21Shares ABTC AVERAGE_BID                      object
# Coinshares BITC  TURNOVER                      object
# Coinshares BITC  AVERAGE_BID                   object
# Seba SBTCU TURNOVER                            object
# Seba SBTCU AVERAGE_BID                         object
# ETC Group BTCE TURNOVER                        object
# ETC Group BTCE AVERAGE_BID                     object
# Iconic Physical XBTIUSD TURNOVER               object
# Iconic Physical XBTIUSD AVERAGE_BID            object
# Bitpanda YBTC TURNOVER                         object
# Bitpanda YBTC AVERAGE_BID                      object
# dtype: object

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                                  datetime64[ns]
# 21Shares ABTC TURNOVER                        float64
# 21Shares ABTC AVERAGE_BID                     float64
# Coinshares BITC  TURNOVER                     float64
# Coinshares BITC  AVERAGE_BID                  float64
# Seba SBTCU TURNOVER                           float64
# Seba SBTCU AVERAGE_BID                        float64
# ETC Group BTCE TURNOVER                       float64
# ETC Group BTCE AVERAGE_BID                    float64
# Iconic Physical XBTIUSD TURNOVER              float64
# Iconic Physical XBTIUSD AVERAGE_BID           float64
# Bitpanda YBTC TURNOVER                        float64
# Bitpanda YBTC AVERAGE_BID                     float64
# dtype: object

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares ABTC TURNOVER  Coinshares BITC  TURNOVER  \
# 0   2021      5                    0.00                       0.00
# 1   2021      6              1135970.91                  918525.79
# 2   2021      7               911489.55                 2557238.27
# 3   2021      8               698738.10                 2747150.11
# 4   2021      9               960534.44                 2628136.92
# 5   2021     10              6344984.90                 6014868.96
# 6   2021     11              3386990.11                 1711057.92
# 7   2021     12              2339194.15                 1268394.85
# 8   2022      1              1680605.02                 1050617.08
# 9   2022      2              1612939.43                  964672.57
# 10  2022      3               351499.23                 1534001.56
# 11  2022      4              1000387.16                  803965.72
#
#     Seba SBTCU TURNOVER  ETC Group BTCE TURNOVER  \
# 0                  0.00                     0.00
# 1                  0.00                     0.00
# 2                  0.00                     0.00
# 3                  0.00                     0.00
# 4                  0.00                     0.00
# 5            2307712.66                     0.00
# 6            1127197.38                     0.00
# 7            3876698.16                     0.00
# 8            1471962.06                     0.00
# 9             380942.10                     0.00
# 10           1193778.47                669795.82
# 11             15842.64               4188346.00
#
#     Iconic Physical XBTIUSD TURNOVER  Bitpanda YBTC TURNOVER
# 0                               0.00                     0.0
# 1                               0.00                     0.0
# 2                          808879.50                     0.0
# 3                          539048.71                     0.0
# 4                          363298.76                     0.0
# 5                          948433.76                     0.0
# 6                          945317.87                     0.0
# 7                          644330.96                     0.0
# 8                          287348.44                     0.0
# 9                          205379.33                     0.0
# 10                         442604.18                     0.0
# 11                         964922.46                     0.0

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Amsterdam Bitcoin ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("amsbit_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares ABTC AVERAGE_BID  Coinshares BITC  AVERAGE_BID  \
# 0   2021      5                        NaN                           NaN
# 1   2021      6                  38.793000                     37.735000
# 2   2021      7                  30.330455                     39.850909
# 3   2021      8                  24.136818                     32.301818
# 4   2021      9                  30.236818                     33.835909
# 5   2021     10                  25.349048                     28.521905
# 6   2021     11                  32.535455                     33.535455
# 7   2021     12                  32.957826                     32.668261
# 8   2022      1                  33.264762                     32.711905
# 9   2022      2                  34.967000                     35.188000
# 10  2022      3                  33.222609                     34.797826
# 11  2022      4                  29.205238                     29.150952
#
#     Seba SBTCU AVERAGE_BID  ETC Group BTCE AVERAGE_BID  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                37.715556                         NaN
# 5                35.683333                         NaN
# 6                34.576364                         NaN
# 7                41.073478                         NaN
# 8                36.048571                         NaN
# 9                37.032000                         NaN
# 10               38.971739                   33.385556
# 11               40.953333                   31.672381
#
#     Iconic Physical XBTIUSD AVERAGE_BID  Bitpanda YBTC AVERAGE_BID
# 0                                   NaN                        NaN
# 1                                   NaN                        NaN
# 2                             24.975909                        NaN
# 3                             23.427727                        NaN
# 4                             26.838182                        NaN
# 5                             27.250476                        NaN
# 6                             35.132273                        NaN
# 7                             38.277826                        NaN
# 8                             37.007619                        NaN
# 9                             37.887000                        NaN
# 10                            45.862174                        NaN
# 11                            67.315714                     43.095

# %%
c = ['gold','c','darkgreen','g','b','lightblue']

# %%
len(bid_col)
# Out:
# 6

# %%
fig, ax = plt.subplots(figsize=(10,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("ENX Amsterdam Bitcoin ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.savefig("amsbit_bid_ask.png", bbox_inches = "tight")
plt.show()
