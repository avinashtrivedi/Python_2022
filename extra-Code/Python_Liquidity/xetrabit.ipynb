# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('pc.xlsx',sheet_name='Xetra Bitcoin ETPs')

# %%
list(df.iloc[0])
# Out:
# [nan,
#  '2BTC GY Equity',
#  nan,
#  'BTCE GY  Equity',
#  nan,
#  'VBTC GY  Equity',
#  nan,
#  'WBIT GY Equity',
#  nan,
#  'BITC GY  Equity',
#  nan,
#  'BTIC GY  Equity',
#  nan,
#  'XBTI GY  Equity',
#  nan,
#  'YBTC GY  Equity',
#  nan,
#  'FBTC GY  Equity',
#  nan,
#  'BT0X GY  Equity',
#  nan]

# %%
list(df.iloc[1])
# Out:
# ['Dates',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%',
#  'TURNOVER',
#  'AVERAGE_BID_ASK_SPREAD_%']

# %%
col = ['Dates',
 '21Shares 2BTC TURNOVER',
 '21Shares 2BTC AVERAGE_BID',
 'ETC Group BTCE TURNOVER',
 'ETC Group BTCE AVERAGE_BID',
 'VanEck VBTC TURNOVER',
 'VanEck VBTC AVERAGE_BID',
 'WisdomTree WBIT TURNOVER',
 'WisdomTree WBIT AVERAGE_BID',
 'Coinshares BITC  TURNOVER',
 'Coinshares BITC  AVERAGE_BID',
 'Bitpanda YBTC TURNOVER',
 'Bitpanda YBTC AVERAGE_BID',
 'Invesco BTIC TURNOVER',
 'Invesco BTIC AVERAGE_BID',
 'Iconic Physical XBTI TURNOVER',
 'Iconic Physical XBTI AVERAGE_BID',
 'Fidelity FBTC TURNOVER',
 'Fidelity FBTC AVERAGE_BID',
 'Global X BT0X TURNOVER',
 'Global X BT0X AVERAGE_BID']

# %%
df.columns = col

# %%
df = df.iloc[2:262]
# df=df.iloc[2:,:] for original

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                    Dates 21Shares 2BTC TURNOVER 21Shares 2BTC AVERAGE_BID  \
# 0    2021-05-03 00:00:00                2631780                    0.1207
# 1    2021-05-04 00:00:00                2378283                    0.1551
# 2    2021-05-05 00:00:00               933895.2                    0.1433
# 3    2021-05-06 00:00:00                1429731                    0.1751
# 4    2021-05-07 00:00:00               819888.1                    0.1489
# ..                   ...                    ...                       ...
# 255  2022-04-25 00:00:00                1180811                    0.1402
# 256  2022-04-26 00:00:00               806603.8                      0.12
# 257  2022-04-27 00:00:00                1683117                    0.1265
# 258  2022-04-28 00:00:00                2808916                    0.1194
# 259  2022-04-29 00:00:00                1472697                    0.1119
#
#     ETC Group BTCE TURNOVER ETC Group BTCE AVERAGE_BID VanEck VBTC TURNOVER  \
# ...

# %%
df.isna().sum()
# Out:
# Dates                                 0
# 21Shares 2BTC TURNOVER                0
# 21Shares 2BTC AVERAGE_BID             0
# ETC Group BTCE TURNOVER               0
# ETC Group BTCE AVERAGE_BID            0
# VanEck VBTC TURNOVER                  0
# VanEck VBTC AVERAGE_BID               0
# WisdomTree WBIT TURNOVER              0
# WisdomTree WBIT AVERAGE_BID           0
# Coinshares BITC  TURNOVER            27
# Coinshares BITC  AVERAGE_BID         25
# Bitpanda YBTC TURNOVER              153
# Bitpanda YBTC AVERAGE_BID           149
# Invesco BTIC TURNOVER                 7
# Invesco BTIC AVERAGE_BID              7
# Iconic Physical XBTI TURNOVER       167
# Iconic Physical XBTI AVERAGE_BID    167
# Fidelity FBTC TURNOVER              206
# Fidelity FBTC AVERAGE_BID           206
# Global X BT0X TURNOVER              258
# Global X BT0X AVERAGE_BID           222
# dtype: int64

# %%
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
df.dtypes
# Out:
# Dates                               datetime64[ns]
# 21Shares 2BTC TURNOVER                      object
# 21Shares 2BTC AVERAGE_BID                   object
# ETC Group BTCE TURNOVER                     object
# ETC Group BTCE AVERAGE_BID                  object
# VanEck VBTC TURNOVER                        object
# VanEck VBTC AVERAGE_BID                     object
# WisdomTree WBIT TURNOVER                    object
# WisdomTree WBIT AVERAGE_BID                 object
# Coinshares BITC  TURNOVER                   object
# Coinshares BITC  AVERAGE_BID                object
# Bitpanda YBTC TURNOVER                      object
# Bitpanda YBTC AVERAGE_BID                   object
# Invesco BTIC TURNOVER                       object
# Invesco BTIC AVERAGE_BID                    object
# Iconic Physical XBTI TURNOVER               object
# Iconic Physical XBTI AVERAGE_BID            object
# Fidelity FBTC TURNOVER                      object
# ...

# %%
for col in list(df)[1:]:
    df[col] = df[col].astype('float')

# %%
df.dtypes
# Out:
# Dates                               datetime64[ns]
# 21Shares 2BTC TURNOVER                     float64
# 21Shares 2BTC AVERAGE_BID                  float64
# ETC Group BTCE TURNOVER                    float64
# ETC Group BTCE AVERAGE_BID                 float64
# VanEck VBTC TURNOVER                       float64
# VanEck VBTC AVERAGE_BID                    float64
# WisdomTree WBIT TURNOVER                   float64
# WisdomTree WBIT AVERAGE_BID                float64
# Coinshares BITC  TURNOVER                  float64
# Coinshares BITC  AVERAGE_BID               float64
# Bitpanda YBTC TURNOVER                     float64
# Bitpanda YBTC AVERAGE_BID                  float64
# Invesco BTIC TURNOVER                      float64
# Invesco BTIC AVERAGE_BID                   float64
# Iconic Physical XBTI TURNOVER              float64
# Iconic Physical XBTI AVERAGE_BID           float64
# Fidelity FBTC TURNOVER                     float64
# ...

# %%
df['Year'] = df['Dates'].dt.year 
df['Month'] = df['Dates'].dt.month

# %%
dict_mnth = {
    1:'JAN',
    2:'FEB',
    3: 'MARCH',
    4: 'APRIL',
    5: 'MAY',
    6: 'JUNE',
    7: 'JULY',
    8: 'AUG',
    9: 'SEP',
    10: 'OCT',
    11: 'NOV',
    12: 'DEC'
}

# %% [markdown]
# # Turnover

# %%
turnover_col = [name for name in list(df) if 'TURNOVER' in name]
df_new = df.groupby(['Year','Month'])[turnover_col].sum()
df_new = df_new.reset_index()

# %%
df_new
# Out:
#     Year  Month  21Shares 2BTC TURNOVER  ETC Group BTCE TURNOVER  \
# 0   2021      5              49234343.3              590343990.0
# 1   2021      6              50217775.1              382698001.0
# 2   2021      7              50431010.0              314984243.0
# 3   2021      8              36425739.3              270191319.0
# 4   2021      9              31490441.7              503750168.0
# 5   2021     10              63026400.0              897912910.0
# 6   2021     11              67474970.1              746664500.0
# 7   2021     12              59770363.9              584580380.0
# 8   2022      1              54036028.2              459226109.0
# 9   2022      2              47853378.6              288988673.0
# 10  2022      3              27751449.1              448056948.0
# 11  2022      4              21720533.7              314249965.0
#
#     VanEck VBTC TURNOVER  WisdomTree WBIT TURNOVER  Coinshares BITC  TURNOVER  \
# ...

# %%
yr_month = []
for _,row in df_new.iterrows():
    
    yr_month.append(str(row['Year']).split('.')[0]+'_'+dict_mnth[row['Month']])
    
df_new['yr_month'] = yr_month

# %%
fig, ax = plt.subplots(figsize=(10,5))
# turnover_col = [name for name in list(df_new) if 'TURNOVER' in name]
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
# last month 12 for original so iloc[[0,2,4,6,8,10,12]]
for col in turnover_col:
    ax.plot(list(range(len(df_new))),list(df_new[col]),label=col)
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("Xetra Bitcoin ETPs Turnover")
plt.xlabel("Date")
plt.ylabel("Sum of Turnover (€)")
plt.savefig("xetrabit_turnover.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Average bid

# %%
bid_col = [name for name in list(df) if 'AVERAGE_BID' in name]

# %%
df_bid = df.groupby(['Year','Month'])[bid_col].mean()*100
df_bid = df_bid.reset_index()

# %%
df_bid
# Out:
#     Year  Month  21Shares 2BTC AVERAGE_BID  ETC Group BTCE AVERAGE_BID  \
# 0   2021      5                  23.229048                   16.861429
# 1   2021      6                  16.998636                   12.025455
# 2   2021      7                  14.734091                   12.957273
# 3   2021      8                  12.161818                   10.880455
# 4   2021      9                  17.382273                   11.876364
# 5   2021     10                  19.277143                    7.732381
# 6   2021     11                  19.267273                    9.025000
# 7   2021     12                  15.090435                    9.600435
# 8   2022      1                  15.717143                    9.392381
# 9   2022      2                  17.428000                   10.182500
# 10  2022      3                  15.383478                   10.606957
# 11  2022      4                  11.923333                   10.400000
#
# ...

# %%
c = ['gold','c','darkgreen','g','b','lightblue','darkblue','brown','grey','purple']

# %%
len(bid_col)
# Out:
# 10

# %%
fig, ax = plt.subplots(figsize=(7,5))
new_name = df_new['yr_month'].iloc[[0,2,4,6,8,10,11]]
#same as above where iloc[[0,2,4,6,8,10,12]] is original
for i,col in enumerate(bid_col):
    ax.plot(list(range(len(df_bid))),list(df_bid[col]),label=col,color=c[i])
ax.set_xticklabels(new_name)
plt.legend(bbox_to_anchor=(1.0,1.0))
plt.title("Xetra Bitcoin ETPs Average Bid Ask Spread")
plt.xlabel("Date")
plt.ylabel("Average Bid Ask Spread (bps)")
plt.ylim([0,100])
plt.savefig("xetrabit_bid_ask.png", bbox_inches ="tight")
plt.show()
