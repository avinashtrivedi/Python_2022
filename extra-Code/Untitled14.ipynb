# %%
####################################################################################
# For this component of your final exam, you will find below six functions and two
# classes that you must complete.  A main() method is provided for you at the bottom
# if you wish to test anything, but writing tests is not required.  Upload this
# file, still with the name final_template.py, to Web-CAT whenever you are ready to
# test.  You may need to comment out some of the classes in order to compile and run
# this file if you have not yet written solutions for them.




####################################################################################
# Function 1
#
# Given two integers low and high representing a range, return the sum of the
# integers in that range.  For example, if low is 12 and high is 18, the returned
# value should be the sum of 12+13+...+18, which is 105.  If low is greater than
# high, return 0.

def sumRange(low, high):
    sum = 0
    i = low
    while i <= high:
        sum += i
        i+= 1
        
    return sum
    
    
    





####################################################################################
# Function 2
#
# Write a function that takes a string as input, and returns a tuple that contains the number
# of characters (defined as everything that isn't a digit) and the number of digits in the
# string.  For example, the input "Hello world 123!" should return (13,3).

def countCharsAndDigits(string):
    chars = 0
    n = 0
    for i in string:
        if i.isdigit():
            n += 1
        else:
            chars += 1
    return chars, n
    








####################################################################################
# Function 3
#
# Given two strings s1 and s2, return True if either of the strings appears at the
# very end of the other string, ignoring upper/lower case differences (in other
# words, the computation should not be "case sensitive").  Make no assumptions about
# the length of s1 and s2.

def endOther(s1, s2):
    s1 = s1.lower()[::-1]
    s2 = s2.lower()[::-1]
    return s1.startswith(s2) or s2.startswith(s1)
        

    






####################################################################################
# Function 4
#
# We'll say that a string is xy-balanced if for all the 'x' characters in the
# string, there exists a 'y' character somewhere later in the string.  So "xxy" is
# balanced, but "xyx" is not.  One "y" can balance multiple "x"s.  Return True if
# the given string s is xy-balanced.  Make no assumptions about the length of s.

def xyBalance(s):
    i = len(s)-1
    foundY = False
    while i>=0:
        if s[i]=='y':
            if foundY==False:
                return True
        elif s[i]=='x':
            if foundY==False:
                return False
    return True
      







####################################################################################
# Function 5
#
# Given a string s, find all places where a three-letter combination starting with
# 'z' and ending with 'p' occur.  Return a string where, for all such three-letter
# sequences, the middle letter has been removed.  For example, a string like
# "zipXzap" would produce a result of "zpXzp".  Make no assumptions about the length
# of s.

def zipZap(s):
    n=len(s);str=''
    c=0
    for i in range(n):
        if s[i]=='z' and s[i+2]=='p':
            str+='z'
            c=1
        elif c:
            if s[i]=='p':
                str+='p'
                c=0
        else:
            str+= s[i]
    return str
  
    







####################################################################################
# Function 6
#
# Given two strings, word and a separator sep, return a big string made of count
# occurrences of word, separated by the sep string.  For example, ("Word","X",3)
# will return "WordXWordXWord".  A count of 1 will only return word.  A count of 0
# will return the empty string.

def repeatSeparator(word, sep, count):
    new_string=''

    if count>0:
        for i in range(count):
            if i!=(count-1):
                new_string = new_string + word + sep
            else:
                new_string = new_string + word
  
  
    return new_string
    





# You can uncomment this triple-quote string line (and the one below) to easily comment
# out the classes, in case they are interfering with Web-CAT grading your earlier
# functions before you have written solutions for them.

# '''



####################################################################################
# Class 1
#
# The PythonStudent class below includes a constructor which takes a list of
# dictionaries as a parameter, representing the grades of one student.  Each
# dictionary in the list contains keys and values for:
#   assignment:  the name of the assignment (string)
#   score:       the score received for the assignment (int)
#   points:      the maximum score possible for the assignment (int)
#
# An example dictionary:
# {
#     "assignment", "Project1",
#     "score", 62
#     "points", 75
# }
#
# Your goal is to complete the functions that are listed here:
#   1.  loadGrade():     given the name of an assignment, return the score that
#                        the student received for that assignment
#   2.  computeGrade():  sum the total score and points for all assignments, and
#                        return the grade [0-100] that the student has earned
#   3.  letterGrade():   return the letter grade ("A", "B", "C", "D", "F") that the
#                        student has earned, using the ranges >=90 (A),
#                        80-89.999... (B), 70-79.999... (C), 60-69.999... (D), <60 (F)


class PythonStudent:
    
    def __init__(self, iGrades):
        self.__grades = iGrades

    def loadGrade(self, assignment):
        for item in self.__grades:
           if item["assignment"] == assignment:
               return item["score"]
        
            
    def computeGrade(self):
        totalScore = 0
        totalPoints = 0
      
        for item in self.__grades:
            totalScore = totalScore + item["score"]
            totalPoints = totalPoints + item["points"]
        grade = (totalScore / totalPoints) * 100
      
        return grade
        
    
    def letterGrade(self):
        totalScore = 0
        totalPoints = 0
      
        for item in self.__grades:
            totalScore = totalScore + item["score"]
            totalPoints = totalPoints + item["points"]
        grade = (totalScore / totalPoints) * 100
          
        if grade >= 90:
            return "A"
              
        elif grade >= 80:
            return "B"
              
        elif grade >= 70:
            return "C"
          
        elif grade >= 60:
            return "D"
            
        else:
            return "F"




####################################################################################
# Class 2
#
# Below, you will find a parent class called Date.  Your goal for this portion of 
# the final is to complete the subclass that inherits from the Date superclass to
# create a DateTime subclass.  In particular, you should complete the following
# functions for the Date and DateTime classes:
#
#   1.  Call the superclass constructor from the subclass constructor to initialize
#       the month, day, and year instance variables
#   2.  Finish the mutator methods for month, day, and year in the Date class
#   3.  Add a __timezone instance variable to the DateTime class, and write an
#       accessor method getTimezone() and a mutator method setTimezone() to the
#       class.  You should also add the __timezone variable into the __str__ function
#       output, but do not add it to the subclass constructor.  The __timezone
#       variable will store a string.
#   4.  Implement the __eq__ method in the DateTime class, which will compare the
#       date and time stored in the object passed in (time2) to the time stored in
#       the self instance variables.  In order for two times to be judged the same,
#       all seven instance variable fields must match:  month, day, year, hours, 
#       minutes, seconds, and timezone

class Date:
    def __init__(self, iM, iD, iY):
        self.__month = iM
        self.__day = iD
        self.__year = iY
        
    def __str__(self):
        return self.__month + "/" + self.__day + "/" + self.__year
    
    def getMonth(self):
        return self.__month
    
    def getDay(self):
        return self.__day
    
    def getYear(self):
        return self.__year
    
    def setMonth(self, iMonth):
        self.__month = iMonth
        pass
        
    def setDay(self, iDay):
        self.__day = iDay
        pass
        
    def setYear(self, iYear):
        self.__year = iYear
        pass
    
    

class DateTime(Date):
    def __init__(self, iM, iD, iY, iH, iMin, iS):
        self.__hours = iH
        self.__minutes = iMin
        self.__seconds = iS

    def __str__(self):
        return self.getMonth()+"/"+self.getDay()+"/"+self.getYear()+" "+self.__hours+":"+self.__minutes+":"+self.__seconds

    def __eq__(self, time2):
        if self.getMonth() == time2.getMonth() and self.getDay() == time2.getDay() and self.getYear() == time2.getYear():

            if self.getHours() == time2.getHours() and self.getMinutes() == time2.getMinutes() and self.getSeconds() == time2.getSeconds():

                if self.getTimezone() == time2.getTimezone():
                    return True
                else:
                    return False
            else:
               return False
        else:
            return False


        



# You can uncomment this triple-quote string line (and the one above) to easily comment
# out the classes, in case they are interfering with Web-CAT grading your earlier
# functions.

# '''




def main():
    print (sumRange(12,18))
    print (sumRange(1,10))
    
    print(countCharsAndDigits("Hello World 123!"))
    print(countCharsAndDigits("it is 1st final test!"))
    
    print(xyBalance("xxy"))
    print(xyBalance("xyx"))
    
    print(zipZap("zipXzap"))
    
    print(repeatSeparator("Word", "X", 3))
    print(repeatSeparator("This", "And", 2))
    print(repeatSeparator("This", "And", 1))

if __name__ == "__main__":
    main()
# Out:
# 105
# 55
# (13, 3)
# (20, 1)
# True
# False
# zpXzp
# WordXWordXWord
# ThisAndThis
# This
