# %% [markdown]
# # Analysis of water quality grades and score for Bellingen Riverwatch sites in annually and each summer

# %% [markdown]
# ## Data Description

# %% [markdown]
# #### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
river_raw = pd.read_excel('bellingen-riverwatch.xlsx',sheet_name='ALL DATA (BY LOCATION) NEW')

# %%
river_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   SITE CODE                         990 non-null    object
#  1   Location Name                     990 non-null    object
#  2   Latitude/Northings                985 non-null    float64
#  3   Longitude/Eastings                985 non-null    float64
#  4   EPSG Code                         930 non-null    object
#  5   Survey Date                       990 non-null    datetime64[ns]
#  6   Survey Time                       985 non-null    object
#  7   Site observations                 849 non-null    object
#  8   Survey duration (hrs)             596 non-null    object
#  9   Sampler group name *              990 non-null    object
#  10  Number in sampler group           716 non-null    float64
#  11  No. of volunteers testing         525 non-null    float64
#  12  Water type                        692 non-null    object
#  13  Rainfall in last 7 days           867 non-null    object
#  14  Rainfall (mm) (optional)          202 non-null    object
#  15  Water level or flow               820 non-null    object
#  16  Rate of Flow (optional)           18 non-null     float64
#  17  Air Temperature (deg C)           935 non-null    float64
#  18  Water Temperature (deg C)         950 non-null    float64
#  19  pH (pH units)                     928 non-null    float64
#  20  Electrical Conductivity (µS/cm)   902 non-null    float64
#  21  Turbidity (NTUs)                  928 non-null    float64
#  22  Available Phosphate (mg/L)        887 non-null    float64
#  23  Dissolved Oxygen (mg/L)           887 non-null    float64
#  24  Dissolved Oxygen (% sat)          883 non-null    float64
#  25  Faecal Coliforms (CFU/100mL)      67 non-null     float64
#  26  E. coli (CFU/100mL)               0 non-null      float64
#  27  Total Phosphate (mg/L)            1 non-null      float64
#  28  Nitrates (mg/L as N)              4 non-null      object
#  29  Did you calibrate your EC meter?  919 non-null    object
#  30  Water Testing Notes/Issues        552 non-null    object
#  31  Photos uploaded                   449 non-null    object
#  32  Verifyed by Ingrid                403 non-null    object
#  33  Unnamed: 33                       10 non-null     object
#  34  Unnamed: 34                       0 non-null      float64
#  35  Unnamed: 35                       0 non-null      float64
#  36  Unnamed: 36                       0 non-null      float64
#  37  Unnamed: 37                       0 non-null      float64
#  38  Unnamed: 38                       0 non-null      float64
#  39  Unnamed: 39                       0 non-null      float64
#  40  Unnamed: 40                       1 non-null      object
# dtypes: datetime64[ns](1), float64(22), object(18)
# memory usage: 317.2+ KB

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# | Variable Name | Values | Description |
# | --- | --- | --- |
# |SITE CODE| string: 'B1-'....|Unique site ID|
# |Location Name|string: 'Bellinger River-'....|Site name|
# |Latitude/Northings|float: -30.00 …|Measurement of distance of north or south of equator|
# |Longitude/Eastings|float: - 152.578….|Measurement of distance east or west of prime meridian|
# |EPSG Code|string: 'WGS 84'….|Unique code for coordinate system worldwide|
# |Survey Date|string:'DD-MM-YY'|Day of conducting survey|
# |Survey Time|string:'HH:MM AM/PM'|time of conducting the test|
# |Site observations|string:'Low flow -'…|written decription based on oberservation to the site|
# |Survey duration (hrs)|float: 0-5|Length of survey |
# |Sampler group name *|string: 'Bellinger River'....|Group name|
# |Number in sampler group|int: 0 - 30|Number in sampler group|
# |No. of volunteers testing|int: 0 - 30|Number of volunteer to do the test|
# |Water type|string:'Fresh','Estuarine','Moderate'|Different Types of Water|
# |Rainfall in last 7 days|string:'Heavy', 'Moderate','Light','Nil'|Level of rainfall|
# |Rainfall (mm) (optional)|float: 0 - 250|measurement of rainfall in millimetre|
# |Water level or flow|string:'low', 'medium', 'high', 'Flood',…..|reported water flow and level|
# |Rate of Flow (optional)|int: 0 - 5|**PENDING|
# |Air Temperature (deg C)|float: 0.0 - 35.0|temperature of air in degrees Celsius (°C)|
# |Water Temperature (deg C)|float: 0.0 - 35.0|temperature in water in degrees Celsius (°C)|
# |pH (pH units)|float: 0-14|pH value measured in water sample|
# |Electrical Conductivity (µS/cm)|float: 0 - 60000|conductivity measured in water sample (only applicable to freshwater ecosystem,exclude estuarine ecosystem)|
# |Turbidity (NTUs)|float: 0 - 500|Turbidity measured in water sample|
# |Available Phosphate (mg/L)|float: 0 - 1|phosphate measured in water sample|
# |Dissolved Oxygen (mg/L)|float: 0 - 12|dissolved oxygen measured in water sample|
# |Dissolved Oxygen (% sat)|int: 0 - 150|dissolved oxygen saturation in percentage|
# |Faecal Coliforms (CFU/100mL)|int: 0 - 550|Faecal Coliform
# bacteria|
# |E. coli (CFU/100mL)|||
# |Total Phosphate (mg/L)|||
# |Nitrates (mg/L as N)|||
# |Did you calibrate your EC meter?|string: 'True','Fales','Yes','No'|Whether clean the kit used for measuring Eletrcity conductivity|
# |Water Testing Notes/Issues|string|Comment on water testing|
# |Photos uploaded|string|url of photo upload|
# |Verifyed by Ingrid|string|comment on whether verifiy by organization that representing NSW Waterwatch|
# ||||
# ||||

# %% [markdown]
# ## Data Preparation
# ### Data cleaning
# #### In order to have a more comprehensive picture of the data, I will drop the unnecesary columns and columns with too much missing values (e.g. Faecal Coliforms)
# used fillna function in the water parameter columns (contain int or float)
#
# ### Data Extraction
# - Extracted the desired columns for further cleaning and analysis

# %%
river_extracted = river_raw[['SITE CODE','Survey Date','Water type','Rainfall in last 7 days','Air Temperature (deg C)','Water Temperature (deg C)','pH (pH units)','Electrical Conductivity (µS/cm)','Turbidity (NTUs)','Available Phosphate (mg/L)','Dissolved Oxygen (mg/L)','Dissolved Oxygen (% sat)']]

# %%
river_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   SITE CODE                        990 non-null    object
#  1   Survey Date                      990 non-null    datetime64[ns]
#  2   Water type                       692 non-null    object
#  3   Rainfall in last 7 days          867 non-null    object
#  4   Air Temperature (deg C)          935 non-null    float64
#  5   Water Temperature (deg C)        950 non-null    float64
#  6   pH (pH units)                    928 non-null    float64
#  7   Electrical Conductivity (µS/cm)  902 non-null    float64
#  8   Turbidity (NTUs)                 928 non-null    float64
#  9   Available Phosphate (mg/L)       887 non-null    float64
#  10  Dissolved Oxygen (mg/L)          887 non-null    float64
#  11  Dissolved Oxygen (% sat)         883 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(3)
# memory usage: 92.9+ KB

# %%
river_extracted .isnull().sum()
# Out:
# SITE CODE                            0
# Survey Date                          0
# Water type                         298
# Rainfall in last 7 days            123
# Air Temperature (deg C)             55
# Water Temperature (deg C)           40
# pH (pH units)                       62
# Electrical Conductivity (µS/cm)     88
# Turbidity (NTUs)                    62
# Available Phosphate (mg/L)         103
# Dissolved Oxygen (mg/L)            103
# Dissolved Oxygen (% sat)           107
# dtype: int64

# %% [markdown]
# Data cleaning: use of fowardfill

# %%
river_fill = river_extracted.fillna(method='ffill')

# %%
river_fill.shape
# Out:
# (990, 12)

# %%
print(river_fill.head(10))
# Out:
#   SITE CODE         Survey Date Water type Rainfall in last 7 days  \
# 0        B1 2017-10-10 13:20:00      Fresh                Moderate
# 1        B1 2017-11-14 14:00:00      Fresh                   Light
# 2        B1 2017-12-12 00:00:00      Fresh                Moderate
# 3        B1 2018-01-10 11:40:00      Fresh                   Light
# 4        B1 2018-02-13 12:45:00      Fresh                     Nil
# 5        B1 2018-04-01 12:30:00      Fresh                   Light
# 6        B1 2018-10-10 12:00:00      Fresh                   Light
# 7        B1 2018-11-14 10:36:00      Fresh                   Light
# 8        B1 2018-12-18 10:26:00      Fresh                   Light
# 9        B1 2019-02-12 10:23:00      Fresh                   Light
#
#    Air Temperature (deg C)  Water Temperature (deg C)  pH (pH units)  \
# 0                     22.0                       20.0            7.0
# 1                     24.0                       22.0            7.5
# 2                     26.0                       23.0            7.0
# 3                     26.0                       26.0            7.0
# 4                     26.0                       26.0            7.0
# 5                     26.0                       19.0            7.0
# 6                     26.0                       19.0            7.0
# 7                     26.0                       21.0            7.0
# 8                     26.0                       26.0            7.0
# 9                     31.0                       25.0            7.0
#
#    Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# 0                             80.0               7.0
# 1                            100.0               7.0
# 2                             80.0               7.0
# 3                             70.0               7.0
# 4                             70.0               7.0
# 5                             80.0               7.0
# 6                             70.0               7.0
# 7                             70.0               7.0
# 8                             70.0               7.0
# 9                            100.0               7.0
#
#    Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# 0                        0.05                      7.9
# 1                        0.21                      7.5
# 2                        0.04                      8.0
# 3                        0.07                      6.5
# 4                        0.06                      6.4
# 5                        0.09                      8.0
# 6                        0.02                      7.9
# 7                        0.04                      7.2
# 8                        0.02                      6.1
# 9                        0.02                      6.8
#
#    Dissolved Oxygen (% sat)
# 0                      87.0
# 1                      86.0
# 2                      93.0
# 3                      80.0
# 4                      79.0
# 5                      86.0
# 6                      85.0
# 7                      81.0
# 8                      75.0
# 9                      82.0

# %% [markdown]
# Making sure there is zero null value in all columns

# %%
river_fill.isnull().sum()
# Out:
# SITE CODE                          0
# Survey Date                        0
# Water type                         0
# Rainfall in last 7 days            0
# Air Temperature (deg C)            0
# Water Temperature (deg C)          0
# pH (pH units)                      0
# Electrical Conductivity (µS/cm)    0
# Turbidity (NTUs)                   0
# Available Phosphate (mg/L)         0
# Dissolved Oxygen (mg/L)            0
# Dissolved Oxygen (% sat)           0
# dtype: int64

# %% [markdown]
# Compare with table with nan value

# %%
river_extracted.describe()
# Out:
#        Air Temperature (deg C)  Water Temperature (deg C)  pH (pH units)  \
# count               935.000000                 950.000000     928.000000
# mean                 22.336471                  18.779368       6.820593
# std                   5.394589                   4.911246       0.600506
# min                   5.000000                   7.000000       4.000000
# 25%                  18.500000                  15.000000       6.500000
# 50%                  22.400000                  19.000000       7.000000
# 75%                  26.000000                  22.500000       7.000000
# max                  41.500000                  32.000000       9.000000
#
#        Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# count                       902.000000        928.000000
# mean                        434.398780         10.702047
# std                        3285.996541         25.293591
# min                           7.000000          0.000000
# 25%                          70.000000          7.000000
# 50%                          80.000000          7.000000
# 75%                         100.000000         10.000000
# max                       51500.000000        400.000000
#
#        Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# count                  887.000000               887.000000
# mean                     0.060629                 7.452559
# std                      0.215433                 1.840917
# min                      0.000000                 0.000000
# 25%                      0.010000                 6.550000
# 50%                      0.030000                 7.800000
# 75%                      0.070000                 8.800000
# max                      6.000000                12.000000
#
#        Dissolved Oxygen (% sat)
# count                883.000000
# mean                  79.081540
# std                   18.021974
# min                    0.000000
# 25%                   73.000000
# 50%                   83.000000
# 75%                   90.000000
# max                  148.000000

# %%
river_fill.describe()
# Out:
#        Air Temperature (deg C)  Water Temperature (deg C)  pH (pH units)  \
# count               990.000000                 990.000000     990.000000
# mean                 22.453939                  18.854141       6.828869
# std                   5.430904                   4.928582       0.594307
# min                   5.000000                   7.000000       4.000000
# 25%                  18.500000                  15.000000       6.500000
# 50%                  22.500000                  19.000000       7.000000
# 75%                  26.000000                  22.500000       7.000000
# max                  41.500000                  32.000000       9.000000
#
#        Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# count                       990.000000        990.000000
# mean                        438.234040         10.591414
# std                        3223.428304         24.511444
# min                           7.000000          0.000000
# 25%                          70.000000          7.000000
# 50%                          80.000000          7.000000
# 75%                         100.000000         10.000000
# max                       51500.000000        400.000000
#
#        Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# count                  990.000000               990.000000
# mean                     0.059604                 7.413192
# std                      0.204989                 1.990233
# min                      0.000000                 0.000000
# 25%                      0.010000                 6.500000
# 50%                      0.030000                 7.800000
# 75%                      0.070000                 8.800000
# max                      6.000000                12.000000
#
#        Dissolved Oxygen (% sat)
# count                990.000000
# mean                  78.765657
# std                   19.702069
# min                    0.000000
# 25%                   73.000000
# 50%                   83.000000
# 75%                   91.000000
# max                  148.000000

# %% [markdown]
# Needed criteria
#
# 'Air Temperature (deg C)','Water Temperature (deg C)','pH (pH units)','Electrical Conductivity (µS/cm)','Turbidity (NTUs)','Available Phosphate (mg/L)','Dissolved Oxygen (mg/L)','Dissolved Oxygen (% sat)']]

# %% [markdown]
# Define a function called "plot_boxplot"

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()

# %%
plot_boxplot(river_fill,'Air Temperature (deg C)')
plot_boxplot(river_fill,'Water Temperature (deg C)')
plot_boxplot(river_fill,'pH (pH units)')
plot_boxplot(river_fill,'Electrical Conductivity (µS/cm)')
plot_boxplot(river_fill,'Turbidity (NTUs)')
plot_boxplot(river_fill,'Available Phosphate (mg/L)')
plot_boxplot(river_fill,'Dissolved Oxygen (mg/L)')
plot_boxplot(river_fill,'Dissolved Oxygen (% sat)')

# %% [markdown]
# The columns below seem to not contain as many outliers as other columns did.
# - Air Temperature (deg C)
# - Water Temperature (deg C)
# - pH (pH units)
#
# So, decided to remove outliers in columns below:
# - Electrical Conductivity (µS/cm)
# - Turbidity (NTUs)
# - Available Phosphate (mg/L)
# - Dissolved Oxygen (mg/L)
# - Dissolved Oxygen (% sat)

# %% [markdown]
# **Remove outliers**

# %%
# define a function called "ouliers" which returns a list of index of outliers
#IQR = Q3 - Q1
#+/- 1.5* IQR

def outliers(df,ft):
    Q1 = df[ft].quantile(0.25)
    Q3 = df[ft].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

    Is=df.index[(df[ft]< lower_bound)|(df[ft] > upper_bound)]

    return Is

# %%
index_list = []

for feature in ['Electrical Conductivity (µS/cm)','Turbidity (NTUs)','Available Phosphate (mg/L)','Dissolved Oxygen (mg/L)','Dissolved Oxygen (% sat)']:
    index_list.extend(outliers(river_fill, feature))

# %%
# define a function called 'remove' which return a cleaner dataframe without outliers

def remove(df, Is):
    Is=sorted(set(Is))
    df = df.drop(Is)
    return df

# %%
river_cleaned = remove(river_fill,index_list)

# %%
river_cleaned.shape
# Out:
# (772, 12)

# %%
plot_boxplot(river_cleaned,'Electrical Conductivity (µS/cm)')
plot_boxplot(river_cleaned,'Turbidity (NTUs)')
plot_boxplot(river_cleaned,'Available Phosphate (mg/L)')
plot_boxplot(river_cleaned,'Dissolved Oxygen (mg/L)')
plot_boxplot(river_cleaned,'Dissolved Oxygen (% sat)')

# %% [markdown]
# Note for myself
# - river_raw - look at the data + data dictionary
# - river_extracted - extracted the columns I wanted to look at
# - river_fill - filled the Nan data with ffill
# - river_cleaned - removed the outliers

# %% [markdown]
# Identify the year and month of the data
# - annually
# - each summer (Dec,Jan,Feb)

# %% [markdown]
# Sorted out the year from Survey Date

# %%
river_cleaned['year']=river_cleaned['Survey Date'].dt.year

# %%
river_cleaned['month']=river_cleaned['Survey Date'].dt.month

# %%
river_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 772 entries, 0 to 989
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   SITE CODE                        772 non-null    object
#  1   Survey Date                      772 non-null    datetime64[ns]
#  2   Water type                       772 non-null    object
#  3   Rainfall in last 7 days          772 non-null    object
#  4   Air Temperature (deg C)          772 non-null    float64
#  5   Water Temperature (deg C)        772 non-null    float64
#  6   pH (pH units)                    772 non-null    float64
#  7   Electrical Conductivity (µS/cm)  772 non-null    float64
#  8   Turbidity (NTUs)                 772 non-null    float64
#  9   Available Phosphate (mg/L)       772 non-null    float64
#  10  Dissolved Oxygen (mg/L)          772 non-null    float64
#  11  Dissolved Oxygen (% sat)         772 non-null    float64
#  12  year                             772 non-null    int64
#  13  month                            772 non-null    int64
# dtypes: datetime64[ns](1), float64(8), int64(2), object(3)
# memory usage: 90.5+ KB

# %% [markdown]
# 'Air Temperature (deg C)','Water Temperature (deg C)','pH (pH units)','Electrical Conductivity (µS/cm)','Turbidity (NTUs)','Available Phosphate (mg/L)','Dissolved Oxygen (mg/L)','Dissolved Oxygen (% sat)']]

# %% [markdown]
# Find the pH value over years

# %%
river_cleaned
# Out:
#     SITE CODE         Survey Date Water type Rainfall in last 7 days  \
# 0          B1 2017-10-10 13:20:00      Fresh                Moderate
# 2          B1 2017-12-12 00:00:00      Fresh                Moderate
# 3          B1 2018-01-10 11:40:00      Fresh                   Light
# 4          B1 2018-02-13 12:45:00      Fresh                     Nil
# 5          B1 2018-04-01 12:30:00      Fresh                   Light
# ..        ...                 ...        ...                     ...
# 985        S1 2021-01-12 00:00:00      Fresh                Moderate
# 986        S1 2021-02-10 00:00:00      Fresh                   Light
# 987        S1 2021-04-13 00:00:00      Fresh                Moderate
# 988        S1 2021-08-10 00:00:00      Fresh                   Light
# 989        S1 2021-10-13 00:00:00      Fresh                Moderate
#
#      Air Temperature (deg C)  Water Temperature (deg C)  pH (pH units)  \
# 0                       22.0                       20.0            7.0
# 2                       26.0                       23.0            7.0
# 3                       26.0                       26.0            7.0
# 4                       26.0                       26.0            7.0
# 5                       26.0                       19.0            7.0
# ..                       ...                        ...            ...
# 985                     26.0                       19.0            6.0
# 986                     23.0                       21.6            7.3
# 987                     21.0                       17.0            5.5
# 988                     19.5                       14.8            7.7
# 989                     19.0                       17.0            7.4
#
#      Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# 0                               80.0               7.0
# 2                               80.0               7.0
# 3                               70.0               7.0
# 4                               70.0               7.0
# 5                               80.0               7.0
# ..                               ...               ...
# 985                            100.0               7.0
# 986                            120.0              10.0
# 987                            130.0               7.0
# 988                            145.0              10.0
# 989                            136.0               7.0
#
#      Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# 0                          0.05                      7.9
# 2                          0.04                      8.0
# 3                          0.07                      6.5
# 4                          0.06                      6.4
# 5                          0.09                      8.0
# ..                          ...                      ...
# 985                        0.05                      6.6
# 986                        0.03                      4.0
# 987                        0.02                      7.5
# 988                        0.07                      7.2
# 989                        0.01                      9.0
#
#      Dissolved Oxygen (% sat)  year  month
# 0                        87.0  2017     10
# 2                        93.0  2017     12
# 3                        80.0  2018      1
# 4                        79.0  2018      2
# 5                        86.0  2018      4
# ..                        ...   ...    ...
# 985                      71.0  2021      1
# 986                      46.0  2021      2
# 987                      78.0  2021      4
# 988                      71.0  2021      8
# 989                      93.0  2021     10
#
# [772 rows x 14 columns]

# %%
river_cleaned.groupby(['SITE CODE']).mean()
# Out:
#            Air Temperature (deg C)  Water Temperature (deg C)  pH (pH units)  \
# SITE CODE
# B1                       25.335000                  19.740000       7.000000
# B2                       21.737037                  17.485185       6.596296
# B2.1                     21.331579                  16.726316       6.542105
# B2.1                     13.400000                  14.300000       6.000000
# B3                       23.403571                  19.839286       6.928571
# B3                       22.000000                  14.000000       7.000000
# B3.1                     22.269231                  17.153846       7.000000
# B3.2                     24.904255                  20.765957       7.251064
# B3.3                     19.375000                  17.500000       7.000000
# B4                       25.142857                  20.517857       7.303571
# B5                       22.866667                  19.722222       7.022222
# B5.1                     22.812500                  18.375000       7.000000
# B6                       26.441860                  22.232558       7.139535
# B7                       24.066667                  20.702564       7.144359
# B7.1                     22.333333                  18.291667       6.408333
# K1                       21.692308                  18.692308       6.846154
# K1                       17.000000                  18.500000       7.000000
# K1.1                     17.346154                  14.974359       7.012821
# K1.2                     19.732143                  17.000000       6.928571
# K1.3                     15.642857                  12.750000       6.892857
# K1.4                     15.944444                  13.666667       6.055556
# K2                       22.073469                  19.085714       6.530612
# K3                       22.363265                  19.600000       6.526531
# K4                       22.930000                  18.965000       6.605000
# NN1                      21.300000                  17.644444       6.782889
# NN1                      16.500000                  15.000000       7.640000
# NN1.1                    20.400000                  16.366667       6.710000
# NN1.2                    21.454545                  19.386364       6.572727
# NN1.3                    20.458333                  16.625000       6.591667
# NN2                      21.869565                  17.173913       6.685217
# Nn1.2                    19.000000                  15.000000       6.500000
# R1                       21.705882                  17.161765       7.220588
# S1                       22.650000                  19.290000       6.940000
#
#            Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# SITE CODE
# B1                               76.500000          7.750000
# B2                               77.407407          7.555556
# B2.1                             87.368421          7.473684
# B2.1                             80.000000          7.000000
# B3                               81.392857          8.071429
# B3                               70.000000         10.000000
# B3.1                             65.769231          8.615385
# B3.2                             77.872340          7.127660
# B3.3                             80.000000          9.250000
# B4                               83.000000          7.107143
# B5                               77.422222          7.000000
# B5.1                             71.250000          8.500000
# B6                               75.093023          7.139535
# B7                               77.500000          7.153846
# B7.1                            106.666667          7.250000
# K1                               83.461538          7.384615
# K1                               70.000000          7.000000
# K1.1                             81.025641          7.230769
# K1.2                             83.571429          7.214286
# K1.3                             82.142857          7.000000
# K1.4                             78.888889          7.555556
# K2                               92.857143          7.367347
# K3                               97.897959          7.244898
# K4                              106.500000          9.250000
# NN1                              43.333333          7.488889
# NN1                              50.000000          7.000000
# NN1.1                            41.000000          8.266667
# NN1.2                            60.909091          8.181818
# NN1.3                            71.666667          9.000000
# NN2                              41.956522          7.000000
# Nn1.2                            70.000000         10.000000
# R1                               62.647059          7.088235
# S1                              121.620000          8.200000
#
#            Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# SITE CODE
# B1                           0.045500                 7.585000
# B2                           0.059259                 7.881481
# B2.1                         0.081053                 7.689474
# B2.1                         0.080000                 9.500000
# B3                           0.043214                 8.205714
# B3                           0.000000                 9.300000
# B3.1                         0.017692                 8.676923
# B3.2                         0.045957                 8.719149
# B3.3                         0.045000                 8.725000
# B4                           0.065893                 8.028571
# B5                           0.047778                 8.244444
# B5.1                         0.036250                 8.437500
# B6                           0.040698                 8.376744
# B7                           0.063077                 8.192821
# B7.1                         0.029167                 6.866667
# K1                           0.022308                 6.642308
# K1                           0.055000                 7.300000
# K1.1                         0.038462                 8.017949
# K1.2                         0.024643                 7.814286
# K1.3                         0.031429                 8.835714
# K1.4                         0.000000                 8.311111
# K2                           0.037204                 7.659184
# K3                           0.034082                 7.289796
# K4                           0.028000                 6.145000
# NN1                          0.021111                 7.950000
# NN1                          0.000000                 9.200000
# NN1.1                        0.027000                 8.123333
# NN1.2                        0.055909                 7.468182
# NN1.3                        0.042500                 7.008333
# NN2                          0.039130                 7.851087
# Nn1.2                        0.110000                 8.200000
# R1                           0.044412                 8.267647
# S1                           0.047000                 6.755000
#
#            Dissolved Oxygen (% sat)         year     month
# SITE CODE
# B1                        82.300000  2019.000000  6.650000
# B2                        81.703704  2018.814815  6.592593
# B2.1                      78.473684  2019.421053  5.526316
# B2.1                      92.000000  2021.000000  4.000000
# B3                        89.428571  2018.750000  7.000000
# B3                        90.000000  2019.000000  8.000000
# B3.1                      92.538462  2020.076923  6.307692
# B3.2                      89.914894  2018.765957  6.936170
# B3.3                      94.250000  2020.500000  8.250000
# B4                        88.357143  2018.642857  7.000000
# B5                        89.444444  2019.155556  6.800000
# B5.1                      89.625000  2021.000000  5.375000
# B6                        95.813953  2019.139535  6.604651
# B7                        91.179487  2019.025641  6.205128
# B7.1                      74.750000  2018.916667  4.833333
# K1                        70.653846  2018.576923  6.423077
# K1                        76.500000  2018.500000  9.500000
# K1.1                      78.564103  2018.974359  6.692308
# K1.2                      79.892857  2018.785714  6.392857
# K1.3                      83.000000  2020.428571  6.357143
# K1.4                      79.555556  2020.444444  6.111111
# K2                        81.591837  2019.183673  6.530612
# K3                        78.591837  2019.163265  6.306122
# K4                        66.150000  2019.700000  4.850000
# NN1                       82.644444  2019.177778  6.133333
# NN1                       91.000000  2019.000000  5.000000
# NN1.1                     83.000000  2019.233333  6.733333
# NN1.2                     81.045455  2019.409091  6.409091
# NN1.3                     72.250000  2019.333333  8.000000
# NN2                       80.956522  2019.282609  6.347826
# Nn1.2                     81.000000  2019.000000  9.000000
# R1                        85.147059  2019.470588  6.294118
# S1                        73.600000  2019.800000  4.700000

# %% [markdown]
# **Find the correlation by heatmap**

# %%
sub_data = river_cleaned[['Air Temperature (deg C)','Water Temperature (deg C)','pH (pH units)','Electrical Conductivity (µS/cm)','Turbidity (NTUs)','Available Phosphate (mg/L)','Dissolved Oxygen (mg/L)','Dissolved Oxygen (% sat)']]

# %%
corr = sub_data.corr()
n_var=len(corr)

plt.imshow(corr, cmap = 'autumn')
plt.xticks(range(n_var), corr.columns,rotation=90)
plt.yticks(range(n_var), corr.columns)

for i in range(n_var):
    for j in range(n_var):
        #              format to 2 decimal places  ,  horizonta/vertical align center  
        plt.text(i, j, '{:.2f}'.format(corr.iloc[i, j]), ha="center", va="center", color="k", fontsize = 10)

plt.colorbar()

plt.title('Correlations')
plt.savefig('correlation.png')

# %%
x = river_cleaned['Water Temperature (deg C)']
y = river_cleaned['pH (pH units)']

plt.xlabel('Water Temperature (deg C)')
plt.ylabel('pH (pH units)')
plt.title('Water Temperature and pH')
plt.scatter(x,y,s=20, c ='green',alpha=0.3,marker='x')
plt.savefig('plot')

# %%
xph = river_cleaned['Water Temperature (deg C)']
yph = river_cleaned['Dissolved Oxygen (mg/L)']

plt.scatter(xph,yph,s=10,alpha = 0.2)
plt.savefig('plot')

# %% [markdown]
# # CODE

# %%
river_raw['SITE CODE'].value_counts()
# Out:
# K3       55
# K2       55
# K4       54
# NN2      52
# B3.2     52
# B6       52
# B5       50
# NN1      45
# B7       44
# K1.1     43
# K1.2     39
# B3       39
# R1       37
# B2       34
# B7.1     33
# K1       30
# NN1.1    30
# B4       30
# B2.1     29
# S1       28
# NN1.2    23
# B8.1     21
# B1       21
# B8       19
# B3.1     19
# K1.3     14
# NN1.3    13
# K1.4     10
# B5.1      9
# B3.3      4
# K1        2
# NN1       1
# Nn1.2     1
# B3        1
# B2.1      1
# Name: SITE CODE, dtype: int64

# %%
df = river_raw[river_raw['SITE CODE'].apply(lambda x:True if x[0]=='B' else False)]

# %%
df
# Out:
#     SITE CODE                                      Location Name  \
# 0          B1  Bellinger B1 - Bellinger River, downstream of ...
# 1          B1  Bellinger B1 - Bellinger River, downstream of ...
# 2          B1  Bellinger B1 - Bellinger River, downstream of ...
# 3          B1  Bellinger B1 - Bellinger River, downstream of ...
# 4          B1  Bellinger B1 - Bellinger River, downstream of ...
# ..        ...                                                ...
# 453      B8.1  Bellinger B8.1 - Bellinger River, upstream Nor...
# 454      B8.1  Bellinger B8.1 - Bellinger River, upstream Nor...
# 455      B8.1  Bellinger B8.1 - Bellinger River, upstream Nor...
# 456      B8.1  Bellinger B8.1 - Bellinger River, upstream Nor...
# 457      B8.1  Bellinger B8.1 - Bellinger River, upstream Nor...
#
#      Latitude/Northings  Longitude/Eastings        EPSG Code  \
# 0            -30.466900          152.578610  WGS 84, Lat/Lon
# 1            -30.481530          152.871050  WGS 84, Lat/Lon
# 2            -30.466900          152.578610  WGS 84, Lat/Lon
# 3            -30.466900          152.578610  WGS 84, Lat/Lon
# 4            -30.466900          152.578610  WGS 84, Lat/Lon
# ..                  ...                 ...              ...
# 453          -30.451078          153.009982  WGS 84, Lat/Lon
# 454          -30.451078          153.009982  WGS 84, Lat/Lon
# 455          -30.451078          153.009982  WGS 84, Lat/Lon
# 456          -30.451078          153.009982  WGS 84, Lat/Lon
# 457          -30.451078          153.009982  WGS 84, Lat/Lon
#
#             Survey Date          Survey Time  \
# 0   2017-10-10 13:20:00  2017-10-10 13:20:00
# 1   2017-11-14 14:00:00  2017-11-14 09:35:00
# 2   2017-12-12 00:00:00             10:30:00
# 3   2018-01-10 11:40:00  2018-01-10 11:40:00
# 4   2018-02-13 12:45:00  2018-02-13 12:45:00
# ..                  ...                  ...
# 453 2021-03-10 00:00:00             11:45:00
# 454 2021-04-13 00:00:00             14:45:00
# 455 2021-05-12 00:00:00             13:15:00
# 456 2021-07-13 00:00:00             14:45:00
# 457 2021-08-11 00:00:00             15:30:00
#
#                                      Site observations Survey duration (hrs)  \
# 0    Flow has increased, no algae sited, clear wate...                   0.5
# 1    Sunny. Sound of Marsh frogs, School of bass, B...                     1
# 2    Warm sunny day, good flow, clear water, no vis...                     1
# 3                                                  NaN                   NaN
# 4       Steady flow, hot humid conditions, clear water                   NaN
# ..                                                 ...                   ...
# 453  fine, with a little cloud. The water was turbi...                     1
# 454  Sunny day, nil pollution, fish, bird life, nil...                     1
# 455  Cloudy, fish and bird life, algae present, fis...                   1.5
# 456  Cloudy day, no rain, nil pollution visible, sm...                   1.5
# 457  Beautiful sunny day, incoming tide, fish and d...                     1
#
#      Sampler group name *  ...  \
# 0    Bellingen Riverwatch  ...
# 1    Bellingen Riverwatch  ...
# 2    Bellingen Riverwatch  ...
# 3    Bellingen Riverwatch  ...
# 4    Bellingen Riverwatch  ...
# ..                    ...  ...
# 453  Bellingen Riverwatch  ...
# 454  Bellingen Riverwatch  ...
# 455  Bellingen Riverwatch  ...
# 456  Bellingen Riverwatch  ...
# 457  Bellingen Riverwatch  ...
#
#                                        Photos uploaded  Verifyed by Ingrid  \
# 0                                                  Yes                 NaN
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 453                                                NaN                 YES
# 454  [https://biocollect.ala.org.au/image?id=13-4-2...                 Yes
# 455  [https://biocollect.ala.org.au/image?id=Riverw...                 YES
# 456  [https://biocollect.ala.org.au/image?id=Riverw...                 YES
# 457  [https://biocollect.ala.org.au/image?id=9572AF...                 YES
#
#     Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0           NaN         NaN         NaN         NaN          NaN          NaN
# 1           NaN         NaN         NaN         NaN          NaN          NaN
# 2           NaN         NaN         NaN         NaN          NaN          NaN
# 3           NaN         NaN         NaN         NaN          NaN          NaN
# 4           NaN         NaN         NaN         NaN          NaN          NaN
# ..          ...         ...         ...         ...          ...          ...
# 453         NaN         NaN         NaN         NaN          NaN          NaN
# 454         NaN         NaN         NaN         NaN          NaN          NaN
# 455         NaN         NaN         NaN         NaN          NaN          NaN
# 456         NaN         NaN         NaN         NaN          NaN          NaN
# 457         NaN         NaN         NaN         NaN          NaN          NaN
#
#      Unnamed: 39  Unnamed: 40
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 453          NaN          NaN
# 454          NaN          NaN
# 455          NaN          NaN
# 456          NaN          NaN
# 457          NaN          NaN
#
# [458 rows x 41 columns]

# %%
list(df)
# Out:
# ['SITE CODE',
#  'Location Name',
#  'Latitude/Northings',
#  'Longitude/Eastings',
#  'EPSG Code',
#  'Survey Date',
#  'Survey Time',
#  'Site observations',
#  'Survey duration (hrs)',
#  'Sampler group name *',
#  'Number in sampler group',
#  'No. of volunteers testing',
#  'Water type',
#  'Rainfall in last 7 days',
#  'Rainfall (mm) (optional)',
#  'Water level or flow',
#  'Rate of Flow (optional)',
#  'Air Temperature (deg C)',
#  'Water Temperature (deg C)',
#  'pH (pH units)',
#  'Electrical Conductivity (µS/cm)',
#  'Turbidity (NTUs)',
#  'Available Phosphate (mg/L)',
#  'Dissolved Oxygen (mg/L)',
#  'Dissolved Oxygen (% sat)',
#  'Faecal Coliforms (CFU/100mL)',
#  'E. coli (CFU/100mL)',
#  'Total Phosphate (mg/L)',
#  'Nitrates (mg/L as N)',
#  'Did you calibrate your EC meter?',
#  'Water Testing Notes/Issues',
#  'Photos uploaded',
#  'Verifyed by Ingrid',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40']

# %%
# What were the water quality grades and scores for 
# Bellingen Riverwatch sites annually and each summer?

# %%
df1 = df[['Survey Date','pH (pH units)',
'Electrical Conductivity (µS/cm)',
'Turbidity (NTUs)',
'Available Phosphate (mg/L)',
'Dissolved Oxygen (mg/L)',
'Dissolved Oxygen (% sat)']]

# %%
df1.isna().sum()
# Out:
# Survey Date                         0
# pH (pH units)                      28
# Electrical Conductivity (µS/cm)    44
# Turbidity (NTUs)                   24
# Available Phosphate (mg/L)         69
# Dissolved Oxygen (mg/L)            73
# Dissolved Oxygen (% sat)           77
# dtype: int64

# %%
df1 = df1.fillna(method='ffill')

# %%
df1
# Out:
#             Survey Date  pH (pH units)  Electrical Conductivity (µS/cm)  \
# 0   2017-10-10 13:20:00            7.0                             80.0
# 1   2017-11-14 14:00:00            7.5                            100.0
# 2   2017-12-12 00:00:00            7.0                             80.0
# 3   2018-01-10 11:40:00            7.0                             70.0
# 4   2018-02-13 12:45:00            7.0                             70.0
# ..                  ...            ...                              ...
# 453 2021-03-10 00:00:00            6.0                           1940.0
# 454 2021-04-13 00:00:00            6.0                            820.0
# 455 2021-05-12 00:00:00            7.0                           8000.0
# 456 2021-07-13 00:00:00            6.0                          29000.0
# 457 2021-08-11 00:00:00            7.0                          32000.0
#
#      Turbidity (NTUs)  Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# 0                 7.0                        0.05                      7.9
# 1                 7.0                        0.21                      7.5
# 2                 7.0                        0.04                      8.0
# 3                 7.0                        0.07                      6.5
# 4                 7.0                        0.06                      6.4
# ..                ...                         ...                      ...
# 453              10.0                        0.08                      7.9
# 454              15.0                        0.00                      7.2
# 455              15.0                        0.03                      6.8
# 456              15.0                        0.00                      7.8
# 457              15.0                        0.00                      7.0
#
#      Dissolved Oxygen (% sat)
# 0                        87.0
# 1                        86.0
# 2                        93.0
# 3                        80.0
# 4                        79.0
# ..                        ...
# 453                      94.0
# 454                      78.0
# 455                      75.0
# 456                      81.0
# 457                      75.0
#
# [458 rows x 7 columns]

# %%
# Summer
# December to February

# %%
Water Quality Ratings above for * * Salinity and ** Conductivity are NOT applicable
to estuarine ecosystems and are only applicable to freshwater ecosystems;

# %%
df1.head()
# Out:
#           Survey Date  pH (pH units)  Electrical Conductivity (µS/cm)  \
# 0 2017-10-10 13:20:00            7.0                             80.0
# 1 2017-11-14 14:00:00            7.5                            100.0
# 2 2017-12-12 00:00:00            7.0                             80.0
# 3 2018-01-10 11:40:00            7.0                             70.0
# 4 2018-02-13 12:45:00            7.0                             70.0
#
#    Turbidity (NTUs)  Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# 0               7.0                        0.05                      7.9
# 1               7.0                        0.21                      7.5
# 2               7.0                        0.04                      8.0
# 3               7.0                        0.07                      6.5
# 4               7.0                        0.06                      6.4
#
#    Dissolved Oxygen (% sat)
# 0                      87.0
# 1                      86.0
# 2                      93.0
# 3                      80.0
# 4                      79.0

# %%
df1['year']=df1['Survey Date'].dt.year
df1['month']=df1['Survey Date'].dt.month

# %%
df1.drop('Survey Date',axis=1,inplace=True)

# %%
df1.head()
# Out:
#    pH (pH units)  Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# 0            7.0                             80.0               7.0
# 1            7.5                            100.0               7.0
# 2            7.0                             80.0               7.0
# 3            7.0                             70.0               7.0
# 4            7.0                             70.0               7.0
#
#    Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# 0                        0.05                      7.9
# 1                        0.21                      7.5
# 2                        0.04                      8.0
# 3                        0.07                      6.5
# 4                        0.06                      6.4
#
#    Dissolved Oxygen (% sat)  year  month
# 0                      87.0  2017     10
# 1                      86.0  2017     11
# 2                      93.0  2017     12
# 3                      80.0  2018      1
# 4                      79.0  2018      2

# %%
# What were the water quality grades and scores for 
# Bellingen Riverwatch sites annually and each summer?

df1.groupby('year')[list(df1)[:-2]].mean()
# Out:
#       pH (pH units)  Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# year
# 2017       7.128333                        83.900000          7.458333
# 2018       7.141975                        88.649383          7.333333
# 2019       7.084907                       304.218519         11.305556
# 2020       6.761029                      1616.208088         17.323529
# 2021       6.574118                       968.611765          8.576471
#
#       Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# year
# 2017                    0.046875                 8.427083
# 2018                    0.082222                 8.133333
# 2019                    0.066204                 6.882778
# 2020                    0.071728                 7.534926
# 2021                    0.042353                 7.803059
#
#       Dissolved Oxygen (% sat)
# year
# 2017                 90.687500
# 2018                 88.283951
# 2019                 76.037037
# 2020                 82.544118
# 2021                 81.952941

# %%
df2 = df1[df1['month'].isin([1,2,12])]
df2['month'] = df2['month'].apply(lambda x: 'Summer')
df2.groupby(['year','month']).mean()
# Out:
#              pH (pH units)  Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# year month
# 2017 Summer       7.255556                        77.111111          7.000000
# 2018 Summer       7.126400                        83.352000          7.080000
# 2019 Summer       7.039259                        88.833333          7.851852
# 2020 Summer       6.818421                      3690.331579         27.973684
# 2021 Summer       6.588889                       299.444444          9.333333
#
#              Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# year month
# 2017 Summer                    0.043333                 7.866667
# 2018 Summer                    0.069600                 7.164000
# 2019 Summer                    0.073704                 6.505926
# 2020 Summer                    0.097632                 6.919737
# 2021 Summer                    0.059444                 7.044444
#
#              Dissolved Oxygen (% sat)
# year month
# 2017 Summer                 91.444444
# 2018 Summer                 85.160000
# 2019 Summer                 78.185185
# 2020 Summer                 83.078947
# 2021 Summer                 80.111111

# %%
# EDA

# %%
river_cleaned['Water type'] = river_cleaned['Water type'].replace(['Fresh', 'Fres'],['Freshwater','Freshwater'])

# %%
x = river_cleaned['Water type'].value_counts()
plt.bar(x.index,x,color='g')
plt.show()

# %%
river_cleaned['Rainfall in last 7 days'] = river_cleaned['Rainfall in last 7 days'].replace(['light','nil'],['Light','Nil'])

# %%
x = river_cleaned['Rainfall in last 7 days'].value_counts()
plt.bar(x.index,x,color='g')
plt.xticks(rotation=90)
plt.show()

# %%
river_cleaned
# Out:
#     SITE CODE         Survey Date  Water type Rainfall in last 7 days  \
# 0          B1 2017-10-10 13:20:00  Freshwater                Moderate
# 2          B1 2017-12-12 00:00:00  Freshwater                Moderate
# 3          B1 2018-01-10 11:40:00  Freshwater                   Light
# 4          B1 2018-02-13 12:45:00  Freshwater                     Nil
# 5          B1 2018-04-01 12:30:00  Freshwater                   Light
# ..        ...                 ...         ...                     ...
# 985        S1 2021-01-12 00:00:00  Freshwater                Moderate
# 986        S1 2021-02-10 00:00:00  Freshwater                   Light
# 987        S1 2021-04-13 00:00:00  Freshwater                Moderate
# 988        S1 2021-08-10 00:00:00  Freshwater                   Light
# 989        S1 2021-10-13 00:00:00  Freshwater                Moderate
#
#      Air Temperature (deg C)  Water Temperature (deg C)  pH (pH units)  \
# 0                       22.0                       20.0            7.0
# 2                       26.0                       23.0            7.0
# 3                       26.0                       26.0            7.0
# 4                       26.0                       26.0            7.0
# 5                       26.0                       19.0            7.0
# ..                       ...                        ...            ...
# 985                     26.0                       19.0            6.0
# 986                     23.0                       21.6            7.3
# 987                     21.0                       17.0            5.5
# 988                     19.5                       14.8            7.7
# 989                     19.0                       17.0            7.4
#
#      Electrical Conductivity (µS/cm)  Turbidity (NTUs)  \
# 0                               80.0               7.0
# 2                               80.0               7.0
# 3                               70.0               7.0
# 4                               70.0               7.0
# 5                               80.0               7.0
# ..                               ...               ...
# 985                            100.0               7.0
# 986                            120.0              10.0
# 987                            130.0               7.0
# 988                            145.0              10.0
# 989                            136.0               7.0
#
#      Available Phosphate (mg/L)  Dissolved Oxygen (mg/L)  \
# 0                          0.05                      7.9
# 2                          0.04                      8.0
# 3                          0.07                      6.5
# 4                          0.06                      6.4
# 5                          0.09                      8.0
# ..                          ...                      ...
# 985                        0.05                      6.6
# 986                        0.03                      4.0
# 987                        0.02                      7.5
# 988                        0.07                      7.2
# 989                        0.01                      9.0
#
#      Dissolved Oxygen (% sat)  year  month
# 0                        87.0  2017     10
# 2                        93.0  2017     12
# 3                        80.0  2018      1
# 4                        79.0  2018      2
# 5                        86.0  2018      4
# ..                        ...   ...    ...
# 985                      71.0  2021      1
# 986                      46.0  2021      2
# 987                      78.0  2021      4
# 988                      71.0  2021      8
# 989                      93.0  2021     10
#
# [772 rows x 14 columns]

# %%
def grade(x):
    if x>=6 and x<=8:
        return 'good'
    else:
        return 'poor'

# %%
river_cleaned['pH_grade'] = river_cleaned['pH (pH units)'].apply(lambda x: grade(x))

# %%
x = river_cleaned['pH_grade'].value_counts()
plt.bar(x.index,x,color='g')
plt.xticks(rotation=90)
plt.show()

# %%
df4 = river_cleaned[['year','pH_grade','month']].groupby(['year','pH_grade']).count().reset_index()

# %%
df4
# Out:
#    year pH_grade  month
# 0  2017     good     84
# 1  2018     good    165
# 2  2018     poor      1
# 3  2019     good    189
# 4  2019     poor      4
# 5  2020     good    175
# 6  2020     poor     13
# 7  2021     good    127
# 8  2021     poor     14

# %%
x = df4[df4['pH_grade']=='good']
y = df4[df4['pH_grade']!='good']
plt.bar(x.year,x.month,color='g',label='good')
plt.bar(y.year,y.month,color='r',label='bad')
plt.legend()
plt.show()
