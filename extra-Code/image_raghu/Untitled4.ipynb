# %%
mylist = [['LVIV', 'LVIV', 'Stary Oskol/MGRS:37UDS1936084420//', 'anti-aircra', 'Odesa', 'Francis', 'Francis', 'Vladimir', 'Putin', 'Pietro Parolin', 'Putin', 'Francis', 'Kirill', 'Jesus', 'Yulia Kovaliv', 'Vladimir Putin', 'Kovaliv', 'Nancy Pelosi', 'Pelosi', 'Volodymyr Zelenskyy', 'Marshall', 'Pelosi', 'Joe Biden', 'Biden'],
['Samantha Lock', 'Anna Shevchenko', 'Irpin', 'Volodymyr Zelenskiy', 'Emilio Morenatti/AP', 'Volodymyr Zelenskiy', 'Vadym Boichenko', 'postpostpostpostpost\n', 'Andriy', 'Boris Johnson', 'Boris Johnson', 'Boris Johnson', 'Boris Johnson', 'Boris Johnson', 'Johnson', 'the Verkhovna Rada', 'Vladimir Putin', 'Emmanuel', 'Putin', 'Macron', 'Putin', 'Olaf Scholz', 'Sergei Lavrov', 'Adolf Hitler', 'Joe Biden', 'Iryna Venediktova', 'Vladimir Putin', 'Francis', 'Putin', 'Pocket'],
['Osnat Lubrani', 'Mariupol', 'Denys Shlega', 'Iryna Vereshchuk', 'Vladimir Putin', 'Filippo Grandi', 'Filippo Grandi', 'Filippo Grandi', 'Filippo Grandi', 'Filippo Grandi', 'Lubrani', 'Vadim Astafyev', 'ﬁring', 'Michael Carpenter', 'Luhansk', 'Carpenter', 'Boris Johnson', 'Winston Churchill', 'Volodymyr Zelenskyy', 'Inna Varenytsia', 'David Keyton', 'Jon Gambrell', 'Yuras Karmanau', 'Mstyslav Chernov'],
['Friedrich Merz', 'Putin', 'Putin', 'Merz', 'Scholz', 'Friedrich Merz', 'Olaf Scholz', 'Merz', 'Volodymyr Zelenskyy', 'Denys Shmyhal', 'Vitali Klitschko', 'Merz', 'Merz', 'Donbas', 'Frank-Walter Steinmeier', 'Frank-Walter Steinmeier', 'Frank-Walter Steinmeier', 'Donbas', 'Donbas', 'Trans-Dniester', 'Trans-Dniester', 'Andriy Sadovyi', 'Lviv', 'Kristina Kvien', 'Friedrich Merz', 'Volodymyr Zelenskyy', 'Merz', 'Merz', 'Merz', 'Merz', 'Denys Shmyhal', 'Merz', 'Christian Mihr', 'Mihr', 'Welt', 'Welt', 'Lisa Paus', 'Salome Zourabichvili', 'Zourabichvili', 'Zourabichvili', 'George W. Bush', 'Angela Merkel', 'Nicolas Sarkozy', 'Pavlo\nKyrylenko', 'Josep Borrell', 'Zaporizhzhia', 'Osnat Lubriani', 'Svyatoslav Palamar', 'Denys Shlega', 'Azovstal', 'Putin', 'Macron', 'Emmanuel Macron', 'Vladimir', 'Putin', 'Putin', 'Macron', 'Boris Johnson', 'Boris Johnson', 'Putin', 'Putin', 'Johnson', "Winston Churchill's", 'Churchill', 'Adolf Hitler', 'Johnson', 'Verkhovna Rada', 'Putin', 'Vladimir Putin', 'Tarik Jasarevic', 'Friedrich Merz', 'Merz', 'Olaf Scholz', 'Merz', 'Friedrich Merz', 'Friedrich Merz', 'Friedrich Merz', 'Frank-Walter Steinmeier', 'Andriy Melnyk', 'Peter Szijjarto', 'Szijjarto', 'Suleiman Kerimov', 'Kerimov', 'Amadea', 'Lautoka', 'Amadea', 'Kerimov', 'Pope', 'Putin', 'Amadea', 'Francis', 'Vladimir Putin', 'Putin', 'Kirill', 'Putin', 'Scott Morrison', 'Morrison', 'Mikhail\nMizintsev', 'Luhansk', 'Volodymyr\nZelenskyy', 'Josep Borrell', 'Andriy Melnyk', 'Olaf Scholz', 'Frank-Walter Steinmeier', 'Scholz', 'FrankWalter Steinmeier', 'Vladimir Putin', 'Sergey Lavrov', 'Melnyk', 'Gepard', 'Friedrich Merz', 'Friedrich Merz', 'Mariupol', 'Anja Wolz', 'Irpin', 'Hostomel', 'Wolz', 'Boris Johnson', 'Johnson', 'Volodymyr Zelenskyy', 'Zelenskyy', 'NetBlocks', 'Michael Carpenter', 'Carpenter', 'ting', 'Chuck Schumer', 'Joe Biden', 'Iryna Vereshchuk', 'Volodymyr Zelenskyy', 'Sergei Lavrov', 'Adolf Hitler', 'Lavrov', 'Silvio\n', 'Berlusconi', 'Na', 'ttali Bennett', 'Yair\nLapid', 'Mario Draghi', 'Felix Klein', 'Kadri', 'Simson', 'Simson', 'lo']]
['Erin Burnett', 'Svyatoslav Palamar', 'Svyatoslav', 'Mariupol', 'them.far', 'Mariupol']
# Out:
# ['Erin Burnett',
#  'Svyatoslav Palamar',
#  'Svyatoslav',
#  'Mariupol',
#  'them.far',
#  'Mariupol']

# %%
sum(mylist,[])
# Out:
# ['LVIV',
#  'LVIV',
#  'Stary Oskol/MGRS:37UDS1936084420//',
#  'anti-aircra',
#  'Odesa',
#  'Francis',
#  'Francis',
#  'Vladimir',
#  'Putin',
#  'Pietro Parolin',
#  'Putin',
#  'Francis',
#  'Kirill',
#  'Jesus',
#  'Yulia Kovaliv',
#  'Vladimir Putin',
#  'Kovaliv',
#  'Nancy Pelosi',
#  'Pelosi',
#  'Volodymyr Zelenskyy',
#  'Marshall',
#  'Pelosi',
#  'Joe Biden',
#  'Biden',
#  'Samantha Lock',
#  'Anna Shevchenko',
#  'Irpin',
#  'Volodymyr Zelenskiy',
#  'Emilio Morenatti/AP',
#  'Volodymyr Zelenskiy',
#  'Vadym Boichenko',
#  'postpostpostpostpost\n',
#  'Andriy',
#  'Boris Johnson',
#  'Boris Johnson',
#  'Boris Johnson',
#  'Boris Johnson',
#  'Boris Johnson',
#  'Johnson',
#  'the Verkhovna Rada',
#  'Vladimir Putin',
#  'Emmanuel',
#  'Putin',
#  'Macron',
#  'Putin',
#  'Olaf Scholz',
#  'Sergei Lavrov',
#  'Adolf Hitler',
#  'Joe Biden',
#  'Iryna Venediktova',
#  'Vladimir Putin',
#  'Francis',
#  'Putin',
#  'Pocket',
#  'Osnat Lubrani',
#  'Mariupol',
# ...

# %%
files = glob.glob("/home/john/anaconda3/1-Python_Projects/NLP-KGB/SpacyMindMapBuilder/Texts/*.txt")
mylist = []
with open('extraction_datasheet.csv', mode='w') as new_file:
    writer = csv.writer(new_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    for filename in files:

    # Take all sentences from a given file
    file = open(filename, 'rt')
    text = file.read()
    file.close()

    # Load text into NLP
    doc = nlp(text)

    # Use NLP to identify text in the sentences
    sentences = sent_tokenize(text)

    # REGEX to identify MGRS grids in reports
    mgrs = re.findall(r'//MGRS:(.*?)//', text)

    #Convert flatten mgrs list
    #mgrs = [item for sublist in mgrs for item in sublist]

    pax = re.finditer(r'(\(\(.*?)\)\)', text)

    persons = [X.text for X in doc.ents if X.label_ == 'PERSON']
    #flat_persons = [item for items in persons for item in items]
    #flat_persons = reduce(lambda x, y: [x] + y, persons)
    #flat_persons = reduce(add, persons)
    #flat_persons = list(chain(*persons))
    flat_persons = list(itertools.chain.from_iterable([persons]))
    #flat_persons = itertools.chain.from_iterable(itertools.repeat(x,1) if isinstance(x,str) else x for x in persons)
    #for i[0] in persons:
     #   flat_persons.append(i[0])
    #for rownum in range(persons.nrows):
      #  flat_persons.append(persons.row_values(rownum))
    mylist.append(flat_persons)
