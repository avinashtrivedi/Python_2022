# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()
import pandas as pd

# %%
pd.set_option('display.max_rows', 2200)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
from numpy import load
import numpy as  np
from numpy import expand_dims
from numpy import asarray
from numpy import savez_compressed
from keras.models import load_model
from keras_facenet import FaceNet
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %% [markdown]
# ## Localizing & Extracting Faces

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
from os import listdir
from os.path import isdir
from PIL import Image
from matplotlib import pyplot
from numpy import savez_compressed
from numpy import asarray
from mtcnn.mtcnn import MTCNN

# %%
#extract a single face from a given photograph
def extract_face(filename, required_size = (160, 160)):
    #load image from file
    image = Image.open(filename)
    #convert to RGB, if needed
    image = image.convert('RGB')
    # convert to array
    pixels = asarray(image)
    # create the detector, using default weights
    detector = MTCNN()
    # detect faces in the image
    results = detector.detect_faces(pixels)
    # extract the bounding box from the first face
    x1, y1, width, height = results[0]['box']
    # bug fix
    x1, y1 = abs(x1), abs(y1)
    x2, y2 = x1 + width, y1 + height
    # extract the face
    face = pixels[y1:y2, x1:x2]
    # resize pixels to the model size
    image = Image.fromarray(face)
    image = image.resize(required_size)
    face_array = asarray(image)
    return face_array

#load images and extract faces for all images in a directory
def load_faces(directory):
    faces = list()
    filenames_list = list() #NJ: A list to store all the images file names
    
    #enumerate files
    for filename in listdir(directory):
        # path
        path = directory + filename
        # get face
        face = extract_face(path)
        # store
        faces.append(face)
        filenames_list.append(path) 
        
    return faces, filenames_list

#load & extract faces for a dataset that contains one subdir for each class that in turn contains images
def load_dataset(directory):
    X, y, path_list = list(), list(), list()
    
    # enumerate folders, one per class
    for subdir in listdir(directory):
        #path
        path = directory + subdir + '/'
        # skip any files that might be in the dir
        if not isdir(path):
            continue
        # load all faces in the subdirectory
        faces, filenames_list = load_faces(path)
        
        # create labels
        labels = [subdir for _ in range(len(faces))]
        
        # summarize progress
        print ('>loaded %d example for class %s' % (len(faces), subdir))
        # store
        X.extend(faces)
        y.extend(labels)
        path_list.extend(filenames_list) # to get the actual image names
        
    return asarray(X), asarray(y), asarray(path_list)

# %% [markdown]
# ## Faces Extraction from dataset

# %%
# load train dataset
dataset_path = './dataset/'

faces, filename, images_path = load_dataset(dataset_path)
# Out:
# >loaded 11 example for class ben_afflek
# >loaded 7 example for class elton_john
# >loaded 20 example for class jerry_seinfeld
# >loaded 9 example for class madonna
# >loaded 19 example for class mindy_kaling

# %%
savez_compressed('./faces_dataset.npz', faces, filename, images_path)

# %%
# load the face dataset
faces_dataset = load('./faces_dataset.npz')

faces, filename, images_path = faces_dataset['arr_0'], faces_dataset['arr_1'], faces_dataset['arr_2'] #, data['arr_3']
print('Loaded Train dataset: ', faces.shape, filename.shape, images_path.shape)
# Out:
# Loaded Train dataset:  (66, 160, 160, 3) (66,) (66,)

# %% [markdown]
# ## Feature Extraction for the Faces extracted from dataset

# %%
from numpy import load
from numpy import expand_dims
from numpy import asarray
from numpy import savez_compressed
from keras.models import load_model
from keras_facenet import FaceNet

embedder = FaceNet()

# %%
features_dataset = embedder.embeddings(faces)

# %%
# save arrays to one file in compressed format
savez_compressed('./faces_embeddings.npz', features_dataset, filename, images_path)

# %% [markdown]
# ## Finding Duplicate Images

# %%
#load dataset
data = load('./faces_embeddings.npz')
features_dataset, filename, images_path = data['arr_0'], data['arr_1'], data['arr_2'] #, data['arr_3']

# %%
df_feature = pd.DataFrame({'Feature_vec':list(range(faces.shape[0])),
              'Filename' :filename,
              'Image_path':images_path})

d = df_feature.groupby('Filename').agg(
original_count = ('Feature_vec','count'),
)

df_feature = df_feature.groupby('Filename').head(1).reset_index(drop=True)

d.reset_index(level=0, inplace=True)
d.columns = ['Image_label','original_count']

# %%
# def get_duplicate_images_df(feature, matching_cutoff_threshold = 0.65):
#     img_dup = pd.DataFrame([],columns=['image_id','Image_label','Image_path','Duplicate_image','Duplicate_path','similarity_score'])
#     for id1,feature1 in enumerate(zip(feature['arr_0'], feature['arr_1'], feature['arr_2'])):
#         for id2,feature2 in enumerate(zip(feature['arr_0'], feature['arr_1'], feature['arr_2'])):
            
#             if id2>id1 and feature1[1]==feature2[1]:
#                 image_1,label_1,path_1 = feature1[0],feature1[1],feature1[2]
#                 image_2,label_2,path_2 = feature2[0],feature2[1],feature2[2]

#                 similarity_score = cosine_similarity(image_1.reshape(1, -1),
#                                                      image_2.reshape(1, -1))
#                 if similarity_score > matching_cutoff_threshold:
#                     img_dup.loc[len(img_dup)]= [id1,label_1,path_1,label_2,path_2,similarity_score[0][0]]
#     return img_dup

# %%
def get_duplicate_images_df1(feature, matching_cutoff_threshold = 0.65):
    features_dataset = feature['arr_0']
    img_dup = pd.DataFrame([],columns=['image_id','Image_label','Image_path','Duplicate_image','Duplicate_path','similarity_score'])
    for _, row in df_feature.iterrows():
        image_1 = features_dataset[row['Feature_vec']]
        label_1 = row['Filename']
        path_1  = row['Image_path']
        for id2,feature2 in enumerate(zip(feature['arr_0'], feature['arr_1'], feature['arr_2'])):
            
            if  label_1==feature2[1] and path_1!=feature2[2]:
#                 image_1,label_1,path_1 = feature1[0],feature1[1],feature1[2]
                
                
                image_2,label_2,path_2 = feature2[0],feature2[1],feature2[2]

                similarity_score = cosine_similarity(image_1.reshape(1, -1),
                                                     image_2.reshape(1, -1))
                if similarity_score > matching_cutoff_threshold:
                    img_dup.loc[len(img_dup)]= [id2,label_1,path_1,label_2,path_2,similarity_score[0][0]]
    return img_dup

# %%
df_dup = get_duplicate_images_df1(data,0.4)
df_dup
# Out:
#    image_id     Image_label                                         Image_path Duplicate_image                                     Duplicate_path  similarity_score
# 0         1      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (11).jpg          0.603689
# 1         2      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (12).jpg          0.626170
# 2         3      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (14).jpg          0.502282
# 3         4      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek      ./dataset/ben_afflek/train_ben_afflek (2).jpg          0.686020
# 4         6      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek      ./dataset/ben_afflek/train_ben_afflek (4).jpg          0.638228
# 5         7      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek      ./dataset/ben_afflek/train_ben_afflek (6).jpg          0.738119
# 6         8      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek      ./dataset/ben_afflek/train_ben_afflek (7).jpg          0.589024
# 7         9      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek      ./dataset/ben_afflek/train_ben_afflek (8).jpg          0.599612
# 8        10      ben_afflek     ./dataset/ben_afflek/train_ben_afflek (10).jpg      ben_afflek      ./dataset/ben_afflek/train_ben_afflek (9).jpg          0.684661
# 9        12      elton_john     ./dataset/elton_john/train_elton_john (11).jpg      elton_john     ./dataset/elton_john/train_elton_john (13).jpg          0.663875
# 10       13      elton_john     ./dataset/elton_john/train_elton_john (11).jpg      elton_john     ./dataset/elton_john/train_elton_john (14).jpg          0.608181
# 11       14      elton_john     ./dataset/elton_john/train_elton_john (11).jpg      elton_john      ./dataset/elton_john/train_elton_john (2).jpg          0.554638
# 12       15      elton_john     ./dataset/elton_john/train_elton_john (11).jpg      elton_john      ./dataset/elton_john/train_elton_john (3).jpg          0.585638
# 13       16      elton_john     ./dataset/elton_john/train_elton_john (11).jpg      elton_john      ./dataset/elton_john/train_elton_john (5).jpg          0.610374
# 14       17      elton_john     ./dataset/elton_john/train_elton_john (11).jpg      elton_john      ./dataset/elton_john/train_elton_john (7).jpg          0.679651
# 15       19  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.850476
# 16       20  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.792377
# 17       21  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.696925
# 18       22  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.843465
# 19       23  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.757538
# 20       24  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.899750
# 21       25  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.804106
# 22       26  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.734755
# 23       27  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.742912
# 24       28  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.826684
# 25       29  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.637589
# 26       30  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.844628
# 27       31  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.889489
# 28       32  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.814771
# 29       33  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.809456
# 30       34  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.801012
# 31       35  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.858157
# 32       36  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.822827
# 33       37  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...  jerry_seinfeld  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...          0.786801
# 34       39         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna           ./dataset/madonna/train_madonna (12).jpg          0.659377
# 35       40         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna           ./dataset/madonna/train_madonna (15).jpg          0.740332
# 36       41         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna           ./dataset/madonna/train_madonna (17).jpg          0.656099
# 37       42         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna           ./dataset/madonna/train_madonna (19).jpg          0.575261
# 38       43         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna            ./dataset/madonna/train_madonna (3).jpg          0.700721
# 39       44         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna            ./dataset/madonna/train_madonna (5).jpg          0.833686
# 40       45         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna            ./dataset/madonna/train_madonna (6).jpg          0.712961
# 41       46         madonna            ./dataset/madonna/train_madonna (1).jpg         madonna            ./dataset/madonna/train_madonna (8).jpg          0.463514
# 42       48    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (10)...          0.609737
# 43       49    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (11)...          0.550356
# 44       50    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (12)...          0.848987
# 45       51    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (14)...          0.557999
# 46       53    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (16)...          0.767391
# 47       54    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (17)...          0.720957
# 48       55    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (18)...          0.800526
# 49       56    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (19)...          0.779767
# 50       57    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (2).jpg          0.805908
# 51       58    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (20)...          0.830056
# 52       59    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (21)...          0.663448
# 53       60    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (4).jpg          0.809928
# 54       61    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (5).jpg          0.787782
# 55       62    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (6).jpg          0.902519
# 56       63    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (7).jpg          0.811132
# 57       64    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (8).jpg          0.672140
# 58       65    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (1).jpg    mindy_kaling  ./dataset/mindy_kaling/train_mindy_kaling (9).jpg          0.633181

# %%
df_dup[['Duplicate_path']]
# Out:
#                                        Duplicate_path
# 0      ./dataset/ben_afflek/train_ben_afflek (11).jpg
# 1      ./dataset/ben_afflek/train_ben_afflek (12).jpg
# 2      ./dataset/ben_afflek/train_ben_afflek (14).jpg
# 3       ./dataset/ben_afflek/train_ben_afflek (2).jpg
# 4       ./dataset/ben_afflek/train_ben_afflek (4).jpg
# 5       ./dataset/ben_afflek/train_ben_afflek (6).jpg
# 6       ./dataset/ben_afflek/train_ben_afflek (7).jpg
# 7       ./dataset/ben_afflek/train_ben_afflek (8).jpg
# 8       ./dataset/ben_afflek/train_ben_afflek (9).jpg
# 9      ./dataset/elton_john/train_elton_john (13).jpg
# 10     ./dataset/elton_john/train_elton_john (14).jpg
# 11      ./dataset/elton_john/train_elton_john (2).jpg
# 12      ./dataset/elton_john/train_elton_john (3).jpg
# 13      ./dataset/elton_john/train_elton_john (5).jpg
# 14      ./dataset/elton_john/train_elton_john (7).jpg
# 15  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 16  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 17  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 18  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 19  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 20  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 21  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 22  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 23  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 24  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 25  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 26  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 27  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 28  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 29  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 30  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 31  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 32  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 33  ./dataset/jerry_seinfeld/train_jerry_seinfeld ...
# 34           ./dataset/madonna/train_madonna (12).jpg
# 35           ./dataset/madonna/train_madonna (15).jpg
# 36           ./dataset/madonna/train_madonna (17).jpg
# 37           ./dataset/madonna/train_madonna (19).jpg
# 38            ./dataset/madonna/train_madonna (3).jpg
# 39            ./dataset/madonna/train_madonna (5).jpg
# 40            ./dataset/madonna/train_madonna (6).jpg
# 41            ./dataset/madonna/train_madonna (8).jpg
# 42  ./dataset/mindy_kaling/train_mindy_kaling (10)...
# 43  ./dataset/mindy_kaling/train_mindy_kaling (11)...
# 44  ./dataset/mindy_kaling/train_mindy_kaling (12)...
# 45  ./dataset/mindy_kaling/train_mindy_kaling (14)...
# 46  ./dataset/mindy_kaling/train_mindy_kaling (16)...
# 47  ./dataset/mindy_kaling/train_mindy_kaling (17)...
# 48  ./dataset/mindy_kaling/train_mindy_kaling (18)...
# 49  ./dataset/mindy_kaling/train_mindy_kaling (19)...
# 50  ./dataset/mindy_kaling/train_mindy_kaling (2).jpg
# 51  ./dataset/mindy_kaling/train_mindy_kaling (20)...
# 52  ./dataset/mindy_kaling/train_mindy_kaling (21)...
# 53  ./dataset/mindy_kaling/train_mindy_kaling (4).jpg
# 54  ./dataset/mindy_kaling/train_mindy_kaling (5).jpg
# 55  ./dataset/mindy_kaling/train_mindy_kaling (6).jpg
# 56  ./dataset/mindy_kaling/train_mindy_kaling (7).jpg
# 57  ./dataset/mindy_kaling/train_mindy_kaling (8).jpg
# 58  ./dataset/mindy_kaling/train_mindy_kaling (9).jpg

# %%
#df_duplicate.to_csv('Duplicate_images.csv')

# %%
result = df_dup.groupby('Image_label').agg(no_of_duplicate = ('Duplicate_path','count') )
result.reset_index(level=0, inplace=True)

# %%
result = pd.merge(result, d, on='Image_label')
result
# Out:
#       Image_label  no_of_duplicate  original_count
# 0      ben_afflek                9              11
# 1      elton_john                6               7
# 2  jerry_seinfeld               19              20
# 3         madonna                8               9
# 4    mindy_kaling               17              19
