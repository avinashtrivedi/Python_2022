# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(context="talk", style="white")
clf_color = sns.color_palette("pastel")[1]
mpc_color = sns.color_palette("pastel")[0]

# %%
def load_traj(path):
    traj = np.load(open(path, 'rb'))
    xs = smooth_traj(traj[:, 0])
    ys = smooth_traj(traj[:, 1])
    return xs, ys
    
def smooth_traj(xs, window_len=10):
    xs_smooth = np.zeros_like(xs)
    for i in range(xs.shape[0]):
        left = max(0, i - window_len // 2)
        right = min(xs.shape[0] - 1, left + window_len)
        xs_smooth[i] = np.mean(xs[left:right])
    return xs_smooth[:-100]

def make_transparant(img_path):
    img = cv2.imread(img_path)[:, :, :3]
    transparant = np.mean(img, axis=2, keepdims=True) == 255
    alpha = 255 * (1 - transparant).astype(np.uint8)
    img = np.concatenate([img, alpha], axis=2)
    cv2.imwrite(img_path, img)

# %% [markdown]
# # M $\times$ 1.1

# %%
CLF_TRAJ = './logs/clf_traj_m1.1.npy'
MPC_TRAJ = './logs/mpc_traj_m1.1.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/m11.png', transparant=True)
plt.show()

# %% [markdown]
# # M $\times$ 1.2

# %%
CLF_TRAJ = './logs/clf_traj_m1.2.npy'
MPC_TRAJ = './logs/mpc_traj_m1.2.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/m12.png', transparant=True)
plt.show()

# %% [markdown]
# # M $\times$ 1.3

# %%
CLF_TRAJ = './logs/clf_traj_m1.3.npy'
MPC_TRAJ = './logs/mpc_traj_m1.3.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/m13.png', transparant=True)
plt.show()

# %% [markdown]
# # M $\times$ 1.5

# %%
CLF_TRAJ = './logs/clf_traj_m1.5.npy'
MPC_TRAJ = './logs/mpc_traj_m1.5.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/m15.png', transparant=True)
plt.show()

# %% [markdown]
# # N $\times$ 1.1

# %%
CLF_TRAJ = './logs/clf_traj_n1.1.npy'
MPC_TRAJ = './logs/mpc_traj_n1.1.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/n11.png', transparant=True)
plt.show()

# %% [markdown]
# # N $\times$ 1.2

# %%
CLF_TRAJ = './logs/clf_traj_n1.2.npy'
MPC_TRAJ = './logs/mpc_traj_n1.2.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/n12.png', transparant=True)
plt.show()

# %% [markdown]
# # N $\times$ 1.3

# %%
CLF_TRAJ = './logs/clf_traj_n1.3.npy'
MPC_TRAJ = './logs/mpc_traj_n1.3.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/n13.png', transparant=True)
plt.show()

# %% [markdown]
# # N $\times$ 1.5

# %%
CLF_TRAJ = './logs/clf_traj_n1.5.npy'
MPC_TRAJ = './logs/mpc_traj_n1.5.npy'

xs_clf, ys_clf = load_traj(CLF_TRAJ)
xs_mpc, ys_mpc = load_traj(MPC_TRAJ)

fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.set_yticklabels([])
ax.set_xticklabels([])

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)

ax.plot(xs_mpc, ys_mpc, c=mpc_color, label='MPC', linewidth=3)
ax.plot(xs_clf, ys_clf, c=clf_color, label='rCLBF', linewidth=3)
plt.axis('off')
plt.legend()
fig.tight_layout()
plt.savefig('./plots/n15.png', transparant=True)
plt.show()
