# %%
import pandas as pd
import requests
import csv

url = 'http://bexar.trueautomation.com/clientdb/Property.aspx?cid=110&prop_id=525041'
page = requests.get(url)

df = pd.read_html(url, match='Property ID')

# for i in df:
#     i.to_csv("bexar.csv", index = False)

# %%
data = df[0]

# %%
data.iloc[:,0].to_list()
# Out:
# ['Account',
#  'Property ID:',
#  'Geographic ID:',
#  'Type:',
#  'Property Use Code:',
#  'Property Use Description:',
#  'Protest',
#  'Protest Status:',
#  'Informal Date:',
#  'Formal Date:',
#  'Location',
#  'Address:',
#  'Neighborhood:',
#  'Neighborhood CD:',
#  'Owner',
#  'Name:',
#  'Mailing Address:',
#  nan]

# %%
data.head()
# Out:
#                     0               1                   2                    3
# 0             Account         Account             Account              Account
# 1        Property ID:          525041  Legal Description:  NCB 13416 BLK LOT 6
# 2      Geographic ID:  13416-000-0060             Zoning:                    D
# 3               Type:            Real         Agent Code:                60585
# 4  Property Use Code:             098                 NaN                  NaN

# %%
columns = data.iloc[:,0].to_list() + data.iloc[:,2].to_list()

# %%
len(columns)
# Out:
# 36

# %%
data
# Out:
#                             0                                          1  \
# 0                     Account                                    Account
# 1                Property ID:                                     525041
# 2              Geographic ID:                             13416-000-0060
# 3                       Type:                                       Real
# 4          Property Use Code:                                        098
# 5   Property Use Description:                           TRANSITIONAL USE
# 6                     Protest                                    Protest
# 7             Protest Status:                                        NaN
# 8              Informal Date:                                        NaN
# 9                Formal Date:                                        NaN
# 10                   Location                                   Location
# 11                   Address:       215 S SAN SABA SAN ANTONIO, TX 78207
# 12              Neighborhood:                             NBHD code10030
# 13           Neighborhood CD:                                      10030
# 14                      Owner                                      Owner
# 15                      Name:               SAN SABA OPPORTUNITY FUND LP
# 16           Mailing Address:  215 S SAN SABA #120 SAN ANTONIO, TX 78207
# 17                        NaN                                        NaN
#
#                      2                    3
# 0              Account              Account
# 1   Legal Description:  NCB 13416 BLK LOT 6
# 2              Zoning:                    D
# 3          Agent Code:                60585
# 4                  NaN                  NaN
# 5                  NaN                  NaN
# 6              Protest              Protest
# 7                  NaN                  NaN
# 8                  NaN                  NaN
# 9                  NaN                  NaN
# 10            Location             Location
# 11             Mapsco:                616D5
# 12             Map ID:                  NaN
# 13     E-File Eligible      E-File Eligible
# 14               Owner                Owner
# 15           Owner ID:              3193041
# 16        % Ownership:      100.0000000000%
# 17         Exemptions:                  NaN

# %%
row_value = data.iloc[:,1].to_list() + data.iloc[:,3].to_list()
