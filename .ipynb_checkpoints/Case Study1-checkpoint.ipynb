# %%
import pandas as pd
fpath = r'D:\OneDrive - NITT\Custom_Download\Case Study - Data Source (1).xlsx'

# %%
df = pd.read_excel(fpath,sheet_name=None)

# %%
list(df)
# Out:
# ['Metrics by City', 'Device categories per city']

# %%
type(df)
# Out:
# dict

# %%
df1 = df['Metrics by City']

# %%
df2 = df['Device categories per city']

# %%
df2
# Out:
#               City  Accessories  Smartphones  Laptops  Gaming  Wearables  \
# 0            Tokyo            0           12        1       8          2
# 1         New York            0            7        2       2          3
# 2      Los Angeles            0           21        0      14          2
# 3            Seoul            2           21        0      12         11
# 4            Paris            0           27        1       2          4
# ..             ...          ...          ...      ...     ...        ...
# 130        Raleigh            0           26        3      11          9
# 131          Lille            0           12        0       3          2
# 132   Jacksonville            0            6        6       6          0
# 133     Birmingham            4           37       10      12         11
# 134  Oklahoma City            1           18        2       1          4
#
#      Headsets  Smart TVs  Tablets
# 0           0          0        8
# ...

# %%
df1
# Out:
#               City  Retailers Expected Supply (on Zain platform)  \
# 0            Tokyo                                           110
# 1         New York                                           226
# 2      Los Angeles                                           443
# 3            Seoul                                           146
# 4            Paris                                           500
# ..             ...                                           ...
# 130        Raleigh                                            35
# 131          Lille                                            22
# 132   Jacksonville                                            12
# 133     Birmingham                                            21
# 134  Oklahoma City                                            25
#
#      Total Addressable Retail Market (in the city)  \
# 0                                              383
# 1                                             1024
# ...

# %%
df1.sort_values('Conversion (% Traffic that made a purchase)',ascending=False,inplace=True)

# %%
df1.sort_values('Sessions (Expected Customer Traffic on Zain)',ascending=False,inplace=True)

# %%
df1.sort_values('% Retailers With Orders Post Signing',ascending=False,inplace=True)

# %%
df1
# Out:
#                   City  Retailers Expected Supply (on Zain platform)  \
# 112     Virginia Beach                                            60
# 12   Dallas–Fort Worth                                            79
# 40              Moscow                                           125
# 18             Seattle                                           101
# 98           Abu Dhabi                                            49
# ..                 ...                                           ...
# 86           Cleveland                                            92
# 94              Dublin                                            38
# 110          Marseille                                            34
# 115          Changzhou                                            17
# 96            Brisbane                                            45
#
#      Total Addressable Retail Market (in the city)  \
# 112                                            345
# ...

# %%
list(df1)
# Out:
# ['City',
#  'Retailers Expected Supply (on Zain platform)',
#  'Total Addressable Retail Market (in the city)',
#  '% Retailer Churn Per Month',
#  '% Retailers With Orders Post Signing',
#  'Sessions (Expected Customer Traffic on Zain)',
#  'Conversion (% Traffic that made a purchase)',
#  'Retailers Seen by Customers',
#  'Retailers Seen on nearest competitor',
#  'Profit Per Order']

# %%
col = ['City','% Retailer Churn Per Month','Total Addressable Retail Market (in the city)','% Retailers With Orders Post Signing','Sessions (Expected Customer Traffic on Zain)',
       'Conversion (% Traffic that made a purchase)','Profit Per Order']

# %%
df1[col]['% Retailers With Orders Post Signing'].max()
# Out:
# 0.95

# %%
df = df1[col]

# %%
df3 = df[df['% Retailers With Orders Post Signing']==0.95]

# %%
df3.sort_values('Sessions (Expected Customer Traffic on Zain)',ascending=False,inplace=True)
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_27980\2057401251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.sort_values('Sessions (Expected Customer Traffic on Zain)',ascending=False,inplace=True)

# %%
df3
# Out:
#                   City  % Retailer Churn Per Month  \
# 7               London                        0.05
# 12   Dallas–Fort Worth                        0.02
# 18             Seattle                        0.04
# 40              Moscow                        0.03
# 48             Chennai                        0.05
# 56           Stuttgart                        0.02
# 98           Abu Dhabi                        0.03
# 112     Virginia Beach                        0.04
# 117          Changchun                        0.03
#
#      Total Addressable Retail Market (in the city)  \
# 7                                              730
# 12                                             417
# 18                                             427
# 40                                             481
# 48                                             241
# 56                                             210
# 98                                             147
# ...

# %%
df3['Profit Per Order'] = df3['Profit Per Order']*1000
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_27980\1280611850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Profit Per Order'] = df3['Profit Per Order']*1000

# %%
df3['Conversion (% Traffic that made a purchase)'] = df3['Conversion (% Traffic that made a purchase)']*20000
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_27980\2331964849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Conversion (% Traffic that made a purchase)'] = df3['Conversion (% Traffic that made a purchase)']*20000

# %%
import matplotlib.pyplot as plt

# %%
# plt.bar(df3['City'],df3['Sessions (Expected Customer Traffic on Zain)'])
# plt.bar(df3['City'],df3['Conversion (% Traffic that made a purchase)'])
# # plt.bar(df3['City'],df3['Sessions (Expected Customer Traffic on Zain)'])
# plt.xticks(rotation=90)
# plt.show()

# %%
import numpy as np

# %%
fig = plt.figure()
X = np.arange(9)
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, df3['Sessions (Expected Customer Traffic on Zain)'], color = 'b', width = 0.25)
ax.bar(X + 0.25, df3['Conversion (% Traffic that made a purchase)'], color = 'g', width = 0.25)
ax.bar(X + 0.50, df3['Profit Per Order'], color = 'r', width = 0.25)
plt.xticks(X,df3['City'] ,rotation=70)  # Set text labels and properties.
ax.legend(labels=['Sessions', 'Conversion','Profit'])
plt.show()

# %%
df3
# Out:
#                   City  % Retailer Churn Per Month  \
# 7               London                        0.05
# 12   Dallas–Fort Worth                        0.02
# 18             Seattle                        0.04
# 40              Moscow                        0.03
# 48             Chennai                        0.05
# 56           Stuttgart                        0.02
# 98           Abu Dhabi                        0.03
# 112     Virginia Beach                        0.04
# 117          Changchun                        0.03
#
#      Total Addressable Retail Market (in the city)  \
# 7                                              730
# 12                                             417
# 18                                             427
# 40                                             481
# 48                                             241
# 56                                             210
# 98                                             147
# ...

# %%
# Q3. London

# %%
max(df['Total Addressable Retail Market (in the city)'])
# Out:
# 1847

# %%
df.sort_values('Total Addressable Retail Market (in the city)',ascending=False,inplace=True)
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_27980\2846758978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values('Total Addressable Retail Market (in the city)',ascending=False,inplace=True)

# %%
df.head(15)
# Out:
#                         City  % Retailer Churn Per Month  \
# 2                Los Angeles                        0.02
# 11                   Beijing                        0.05
# 1                   New York                        0.01
# 4                      Paris                        0.03
# 33      Minneapolis/St. Paul                        0.04
# 7                     London                        0.05
# 61            Nürnberg-Fürth                        0.01
# 26                 Guangzhou                        0.00
# 13                   Houston                        0.04
# 91                    Vienna                        0.01
# 28                  San Jose                        0.01
# 52  Riverside–San Bernardino                        0.03
# 59                 St. Louis                        0.04
# 6                 Osaka–Kobe                        0.03
# 34                    Suzhou                        0.05
#
# ...

# %% [markdown]
# # % Retailer Churn Per Month * 12
#
# x = total retailer
#
# x * % Retailers With Orders Post Signing

# %%
df['Sessions (Expected Customer Traffic on Zain)'].max()
# Out:
# 65683

# %%
df['Conversion (% Traffic that made a purchase)'].max()
# Out:
# 0.48459071106065005

# %%
df['Total Addressable Retail Market (in the city)'].sum()
# Out:
# 45171

# %%
df['% Retailer Churn Per Month'].max()
# Out:
# 0.05

# %%
df2['total'] = df2.sum(axis=1)

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df2.sort_values('total',ascending=False)
# Out:
#                          City  Accessories  Smartphones  Laptops  Gaming  Wearables  Headsets  Smart TVs  Tablets  total
# 36                     Madrid           27          104       18      43         39         2         20       77    330
# 38                Busan-Ulsan            6          110        8      57         34         3          7       38    263
# 65                    Qingdao            7           59       18      25         18         0         11       49    187
# 68                   Changsha            6           51        6      43         31         0          6       43    186
# 64                    Karachi           12           68       24      27         12         0          6       33    182
# 67                      Tampa           15           58       15      22         26         4          2       38    180
# 66                     Mumbai           13           58       20      11         14         0         11       52    179
# ...

# %%
x = df2.iloc[:,1:].sum(axis=0)
x
# Out:
# Accessories     149
# Smartphones    3236
# Laptops         603
# Gaming         1167
# Wearables       794
# Headsets         32
# Smart TVs       236
# Tablets        1592
# total          7809
# dtype: int64

# %%
list(x)
# Out:
# [149, 3236, 603, 1167, 794, 32, 236, 1592, 7809]

# %%
x.index
# Out:
# Index(['Accessories', 'Smartphones', 'Laptops', 'Gaming', 'Wearables',
#        'Headsets', 'Smart TVs', 'Tablets', 'total'],
#       dtype='object')

# %%
plt.bar(x.index[:-1],list(x)[:-1],color='g')
plt.xticks(rotation=90)  # Set text labels and properties.
plt.show()
