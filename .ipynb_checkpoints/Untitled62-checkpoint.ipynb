# %%
import pandas as pd

# %%
dfs = pd.read_excel(r"D:\OneDrive - NITT\Custom_Download\1-7.csv", sheet_name=None)

# %%
dfs.keys()
# Out:
# dict_keys(['Sheet1', 'Sheet2'])

# %%
df1 = dfs['Sheet1']
df2 = dfs['Sheet2']

# %%
df1
# Out:
#           tag                          pattern  \
# 0    greeting                               Hi
# 1    greeting                              Hey
# 2    greeting                  Is anyone there
# 3    greeting                         Hi there
# 4    greeting                            Hello
# ..        ...                              ...
# 176  stressed                  I'm too worried
# 177  stressed           Not enough time at all
# 178  stressed  There is still a lot left to do
# 179  stressed  There is not enough time at all
# 180  stressed          I reaaly need more time
#
#                                               response
# 0      Hello there. Tell me how are you feeling today?
# 1                Hi there. What brings you here today?
# 2                 Hi there. How are you feeling today?
# 3         Great to see you. How do you feel currently?
# 4    Hello there. Glad to see you're back. What's g...
# ..                                                 ...
# 176  I'm so sorry that everything sucks so much rig...
# 177  Is there anything I can do? Please let me know...
# 178  It's OK to cry and be upset. Don't feel any pr...
# 179      Do you need a hug? I hope I can give you one.
# 180                  Feel free to talk to me, anytime.
#
# [181 rows x 3 columns]

# %%
df2
# Out:
#                Unnamed: 0                                         Unnamed: 1
# 0    I am so stressed out                 What do you think is causing this?
# 1        I am so stressed  Take a deep breath and gather your thoughts. G...
# 2            I feel stuck        Give yourself a break. Go easy on yourself.
# 3   I still feel stressed  I am sorry to hear that. What is the reason be...
# 4      I am so burned out  You’re not alone in this. I may not understand...
# 5      It drives me crazy             Asking for help is a sign of strength.
# 6                     NaN  Depression is a real health issue that can be ...
# 7                     NaN                        Depression is a real thing.
# 8                     NaN  I know you probably don’t feel like it right n...
# 9                     NaN            Explain it to me. I want to understand.
# 10                    NaN                           You’re right this sucks.
# 11                    NaN  You don’t walk this path alone. I’m here if yo...
# 12                    NaN                  I believe in you. You’re awesome!
# 13                    NaN  Things will change. You won’t feel this way fo...
# 14                    NaN  I can’t imagine how you feel but I’m here for ...
# 15                    NaN  I wish I had the right words to say but just k...
# 16                    NaN       I’m sorry. I know that was important to you.
# 17                    NaN  I know things are difficult right now but I ha...
# 18                    NaN                    You’ve been doing really great!
# 19                    NaN   I know you’re strong enough to get through this.
# 20                    NaN  I'm so sorry that everything sucks so much rig...
# 21                    NaN  Is there anything I can do? Please let me know...
# 22                    NaN  It's OK to cry and be upset. Don't feel any pr...
# 23                    NaN      Do you need a hug? I hope I can give you one.
# 24                    NaN                  Feel free to talk to me, anytime.

# %%
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you?", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %%
data['intents'][0].keys()
# Out:
# dict_keys(['tag', 'patterns', 'responses'])

# %%
data['intents'][0]
# Out:
# {'tag': 'greeting',
#  'patterns': ['Hello', 'How are you?', 'Hi there', 'Hi', 'Whats up'],
#  'responses': ['Howdy Partner!',
#   'Hello',
#   'How are you doing?',
#   'Greetings!',
#   'How do you do?']}

# %%
data['intents'][1]
# Out:
# {'tag': 'age',
#  'patterns': ['how old are you?',
#   'when is your birthday?',
#   'when was you born?'],
#  'responses': ['I am 24 years old',
#   'I was born in 1996',
#   'My birthday is July 3rd and I was born in 1996',
#   '03/07/1996']}

# %%
list', 'series', 'split', 'records'

# %%
df1.to_dict(orient='records')
# Out:
# [{'tag': 'greeting',
#   'pattern': 'Hi',
#   'response': 'Hello there. Tell me how are you feeling today?'},
#  {'tag': 'greeting',
#   'pattern': 'Hey',
#   'response': 'Hi there. What brings you here today?'},
#  {'tag': 'greeting',
#   'pattern': 'Is anyone there',
#   'response': 'Hi there. How are you feeling today?'},
#  {'tag': 'greeting',
#   'pattern': 'Hi there',
#   'response': 'Great to see you. How do you feel currently?'},
#  {'tag': 'greeting',
#   'pattern': 'Hello',
#   'response': "Hello there. Glad to see you're back. What's going on in your world right now?"},
#  {'tag': 'greeting',
#   'pattern': 'Hey there',
#   'response': 'How do you do? Do you have a good day?'},
#  {'tag': 'greeting', 'pattern': 'Howdy', 'response': 'Nice to meet you sir'},
#  {'tag': 'greeting', 'pattern': 'Hola', 'response': 'Good to see you sir'},
#  {'tag': 'greeting',
#   'pattern': 'Hiya',
#   'response': 'Hey! Long-time no see. How are you?'},
#  {'tag': 'greeting', 'pattern': 'Yo', 'response': "What's the story?"},
#  {'tag': 'greeting',
#   'pattern': 'Hey chatbot',
#   'response': "It's a pleasure to meet you"},
#  {'tag': 'greeting',
#   'pattern': 'Bonjour',
#   'response': "It's pleased to meet you"},
#  {'tag': 'greeting',
#   'pattern': 'Konnichiwa',
#   'response': "How's your life talk about it."},
#  {'tag': 'greeting', 'pattern': 'Guten tag', 'response': 'Whazzup?'},
#  {'tag': 'greeting',
#   'pattern': 'Ola',
#   'response': 'How are you feeling today?'},
#  {'tag': 'greeting',
#   'pattern': 'Good Morning',
#   'response': 'How is your day going?'},
#  {'tag': 'greeting',
#   'pattern': 'Good Afternoon',
#   'response': 'How has your day been?'},
#  {'tag': 'greeting',
#   'pattern': 'Good Evening',
#   'response': 'I hope you had a good day'},
#  {'tag': 'greeting',
#   'pattern': 'I really need someone talk to me',
#   'response': "How's everything?"},
#  {'tag': 'greeting',
#   'pattern': 'Can you talk to me',
#   'response': 'How are things?'},
#  {'tag': 'greeting',
#   'pattern': 'Hello are you there',
#   'response': "It's been a while. Tell me how's your day."},
#  {'tag': 'greeting',
#   'pattern': 'Are you there',
#   'response': 'Good to see you. You can always talk to me.'},
#  {'tag': 'greeting',
#   'pattern': 'Hello chatbot',
#   'response': "It's good to see you. You can talk to me."},
#  {'tag': 'greeting',
#   'pattern': 'Hi chatbot',
#   'response': "It's nice to see you. I will here listen to you"},
#  {'tag': 'greeting',
#   'pattern': 'chatbot can you talk to me',
#   'response': 'I will listen to you here.'},
#  {'tag': 'greeting',
#   'pattern': 'chatbot what can you do',
#   'response': 'I will always be here and listen to you'},
#  {'tag': 'goodbye', 'pattern': 'Bye', 'response': 'See you later.'},
#  {'tag': 'goodbye',
#   'pattern': 'I must be going',
#   'response': 'Have a nice day.'},
#  {'tag': 'goodbye',
#   'pattern': 'See you later',
#   'response': 'Bye! Come back again.'},
#  {'tag': 'goodbye', 'pattern': 'Goodbye', 'response': "I'll see you soon."},
#  {'tag': 'goodbye',
#   'pattern': 'Au revoir',
#   'response': 'Bye Get some proper sleep.'},
#  {'tag': 'goodbye',
#   'pattern': 'Sayonara',
#   'response': 'I look forward to our next meeting.'},
#  {'tag': 'goodbye',
#   'pattern': 'ok bye',
#   'response': 'Have a great rest of your day!'},
#  {'tag': 'goodbye', 'pattern': 'Bye then', 'response': 'Have a nice day!'},
#  {'tag': 'goodbye',
#   'pattern': 'Fare thee well',
#   'response': 'It was a pleasure speaking with you.'},
#  {'tag': 'goodbye',
#   'pattern': 'Talk to you later',
#   'response': 'It was a pleasure seeing you to you.'},
#  {'tag': 'goodbye',
#   'pattern': 'See you',
#   'response': 'It was a pleasure talking you to you.'},
#  {'tag': 'goodbye', 'pattern': 'See ya', 'response': 'Speak to you then.'},
#  {'tag': 'goodbye',
#   'pattern': 'Good talking to you',
#   'response': 'Take care.'},
#  {'tag': 'goodbye', 'pattern': "I'm off", 'response': 'See you around.'},
#  {'tag': 'goodbye',
#   'pattern': 'I look forward to our next meeting',
#   'response': 'Good seeing you!'},
#  {'tag': 'goodbye',
#   'pattern': 'It was nice to see you again',
#   'response': 'Bye for now.'},
#  {'tag': 'goodbye',
#   'pattern': 'It was nice seeing you',
#   'response': 'Keep in touch.'},
#  {'tag': 'goodbye', 'pattern': 'Goodnight', 'response': 'Get well soon!'},
#  {'tag': 'goodbye',
#   'pattern': 'Catch you later',
#   'response': 'Take care my friend'},
#  {'tag': 'goodbye', 'pattern': 'Later', 'response': 'Catch you later!'},
#  {'tag': 'goodbye', 'pattern': 'Peace', 'response': 'Nice chatting with you.'},
#  {'tag': 'goodbye', 'pattern': 'Peace out', 'response': 'Cheers.'},
#  {'tag': 'goodbye', 'pattern': "I'm out", 'response': 'See you'},
#  {'tag': 'goodbye',
#   'pattern': "I'm out of here",
#   'response': 'Have a good one'},
#  {'tag': 'goodbye',
#   'pattern': 'I gotta jet',
#   'response': 'Hope all is well with you my friend!'},
#  {'tag': 'goodbye',
#   'pattern': 'I gotta take off',
#   'response': 'Hope all goes well for you my friend!'},
#  {'tag': 'goodbye', 'pattern': 'I gotta go', 'response': 'Hava a good day'},
#  {'tag': 'thanks', 'pattern': 'Thanks', 'response': 'Happy to help!'},
#  {'tag': 'thanks', 'pattern': 'Thank you', 'response': 'Any time!'},
#  {'tag': 'thanks', 'pattern': "That's helpful", 'response': 'My pleasure.'},
#  {'tag': 'thanks',
#   'pattern': 'Thanks for the help',
#   'response': "You're most welcome!"},
#  {'tag': 'thanks', 'pattern': "I'm so grateful", 'response': 'No problem.'},
#  {'tag': 'thanks',
#   'pattern': 'Thank you very much',
#   'response': 'No worries.'},
#  {'tag': 'thanks',
#   'pattern': 'Thank you a lot',
#   'response': 'Anytime my friend'},
#  {'tag': 'thanks',
#   'pattern': 'Thanks a lot',
#   'response': "I'm glad I could be of assistance."},
#  {'tag': 'thanks',
#   'pattern': 'Thanks so much',
#   'response': "I'm happy to support the team."},
#  {'tag': 'thanks',
#   'pattern': "I'm so grateful",
#   'response': "That's why Im here it's not a problem"},
#  {'tag': 'thanks',
#   'pattern': 'Thanks for having my back',
#   'response': "I'm happy to help."},
#  {'tag': 'thanks',
#   'pattern': 'Much appreciated',
#   'response': "I'll always be here for you."},
#  {'tag': 'thanks',
#   'pattern': 'Many thanks',
#   'response': "Don't worry about it."},
#  {'tag': 'thanks',
#   'pattern': 'Thanks a bunch',
#   'response': "I'm happy I was able to help you."},
#  {'tag': 'thanks',
#   'pattern': "It's very kind of you",
#   'response': "You're Welcome."},
#  {'tag': 'thanks',
#   'pattern': 'I really appreciate it',
#   'response': 'Always glad to help.'},
#  {'tag': 'thanks',
#   'pattern': 'Thank you for everything',
#   'response': 'Let me know anytime I can help.'},
#  {'tag': 'thanks',
#   'pattern': 'I owe you one',
#   'response': 'It makes me happy to help.'},
#  {'tag': 'thanks',
#   'pattern': 'Thanks a million',
#   'response': "I'm always here to help."},
#  {'tag': 'thanks',
#   'pattern': 'appreciate your time',
#   'response': 'Just ask any time I can help.'},
#  {'tag': 'thanks',
#   'pattern': 'Thanks a ton',
#   'response': 'Pleased to be of assistance.'},
#  {'tag': 'thanks',
#   'pattern': 'You are the best',
#   'response': 'Thank you for allowing me to help.'},
#  {'tag': 'thanks',
#   'pattern': 'You made my day',
#   'response': 'Glad that I could be of assistance.'},
#  {'tag': 'thanks',
#   'pattern': 'You saved my day',
#   'response': "It's always great to be of assistance."},
#  {'tag': 'thanks', 'pattern': "You're awesome", 'response': "You're so kind."},
#  {'tag': 'thanks',
#   'pattern': "You're great",
#   'response': "You're very welcome."},
#  {'tag': 'no-response',
#   'pattern': ' ',
#   'response': "Sorry I didn't understand you."},
#  {'tag': 'no-response',
#   'pattern': '  ',
#   'response': "Sorry I'm afraid I don't follow you."},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Excuse me could you repeat the question?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "I'm sorry I don't understand. Could you say it again?"},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "I'm confused. Could you tell me again?"},
#  {'tag': 'no-response', 'pattern': nan, 'response': 'Please go on.'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "I'm sorry I didn't catch what you said. Could you say it another way?"},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Not sure I understand that.'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "Please don't hesitate to talk to me."},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "I'm sorry what was that?"},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Could you say that again please?'},
#  {'tag': 'no-response', 'pattern': nan, 'response': "I'm sorry?"},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Sorry could you say that again please?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Would you mind saying that again?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "I'm afraid I didn't get that."},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "Sorry I didn't get the last bit. Say that again?"},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "Sorry I didn't catch that."},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Could you repeat the question please?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Could you tell me again?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "Sorry I don't follow you."},
#  {'tag': 'no-response', 'pattern': nan, 'response': "I'm lost."},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Could you tell me what it means?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': 'Sorry I still didn’t hear you.'},
#  {'tag': 'no-response', 'pattern': nan, 'response': 'Sorry?'},
#  {'tag': 'no-response', 'pattern': nan, 'response': 'Come again?'},
#  {'tag': 'no-response',
#   'pattern': nan,
#   'response': "I'm always here to help."},
#  {'tag': 'help',
#   'pattern': 'Could you help me',
#   'response': 'Sure. Tell me how can i assist you.'},
#  {'tag': 'help',
#   'pattern': 'give me a hand please',
#   'response': 'Tell me your problem so that i can assist you.'},
#  {'tag': 'help',
#   'pattern': 'Can you help?',
#   'response': 'Yes sure. How can I help you?'},
#  {'tag': 'help',
#   'pattern': 'What can you do for me',
#   'response': 'Is there anything you need?'},
#  {'tag': 'help',
#   'pattern': 'I need support',
#   'response': 'Can I get you anything?'},
#  {'tag': 'help',
#   'pattern': 'I need help',
#   'response': 'Do you need someone to talk to?'},
#  {'tag': 'help',
#   'pattern': 'Support me please',
#   'response': 'Would you like me to go with you?'},
#  {'tag': 'help',
#   'pattern': 'What should I do',
#   'response': 'What can I do to help your process?'},
#  {'tag': 'help',
#   'pattern': 'Can you give me a hand with this',
#   'response': 'Is there anyone else I can recruit to help.'},
#  {'tag': 'help',
#   'pattern': 'Could you help me for a second',
#   'response': "I'm happy to help with you."},
#  {'tag': 'help',
#   'pattern': 'Can I ask a favor',
#   'response': "It's no problem at all if you need me to do."},
#  {'tag': 'help',
#   'pattern': "I can't manage",
#   'response': 'If there is anything else you need please let me know.'},
#  {'tag': 'help',
#   'pattern': 'I need some help please',
#   'response': 'If I can be of any further assistance please let me know.'},
#  {'tag': 'help',
#   'pattern': 'Help',
#   'response': 'If there is anything else I can do for you please don’t hesitate to let me know.'},
#  {'tag': 'help',
#   'pattern': 'Help me',
#   'response': 'Please feel free to let me know if you require any further information.'},
#  {'tag': 'help',
#   'pattern': 'Can you help me',
#   'response': 'If I may be of any further assistance please let me know.'},
#  {'tag': 'help',
#   'pattern': 'Do you know why',
#   'response': 'If I can do anything for you just let me know.'},
#  {'tag': 'help',
#   'pattern': 'What can I do',
#   'response': 'What can I do to help you?'},
#  {'tag': 'help',
#   'pattern': 'Could you please help me',
#   'response': 'What do you want me to do to help you?'},
#  {'tag': 'help',
#   'pattern': 'Please give me some advice',
#   'response': 'Do you feel anyone else can help you?'},
#  {'tag': 'help',
#   'pattern': 'I need help',
#   'response': 'Please tell me what can I do.'},
#  {'tag': 'help',
#   'pattern': 'Could you please help me',
#   'response': "I'm always here to help you just let me know."},
#  {'tag': 'help',
#   'pattern': 'Chatbot help me',
#   'response': "I'm always there my friend."},
#  {'tag': 'help',
#   'pattern': 'Chatbot give me some help',
#   'response': "Of course just let me know what's going on."},
#  {'tag': 'help',
#   'pattern': 'Chatbot give me some advice',
#   'response': 'Please tell me how I can help you.'},
#  {'tag': 'help',
#   'pattern': 'Help me chatbot',
#   'response': "I'm always happy to help you my friend."},
#  {'tag': 'sad',
#   'pattern': 'I am feeling lonely',
#   'response': "I'm sorry to hear that. I'm here for you. "},
#  {'tag': 'sad',
#   'pattern': 'I am so lonely',
#   'response': "I'm here for you. Could you tell me why you're feeling this way?"},
#  {'tag': 'sad',
#   'pattern': 'I feel down',
#   'response': 'Why do you think you feel this way?'},
#  {'tag': 'sad',
#   'pattern': 'I feel sad',
#   'response': 'How long have you been feeling this way?'},
#  {'tag': 'sad',
#   'pattern': 'I am sad',
#   'response': "Talking about it might help. So tell me why do you think you're feeling this way?"},
#  {'tag': 'sad',
#   'pattern': 'I feel so lonely',
#   'response': 'It’s OK to not feel OK.'},
#  {'tag': 'sad', 'pattern': 'I feel empty', 'response': 'You’re not alone.'},
#  {'tag': 'sad',
#   'pattern': "I don't have anyone",
#   'response': 'I’m here for you no matter what.'},
#  {'tag': 'sad',
#   'pattern': "I'm not happy",
#   'response': "I'm here to listen whenever you need me."},
#  {'tag': 'sad',
#   'pattern': "I don't know why I'm not happy",
#   'response': "I'm so gald you can talk your sad with me."},
#  {'tag': 'sad',
#   'pattern': "I'm unhappy",
#   'response': 'Tell me what happened.'},
#  {'tag': 'sad',
#   'pattern': 'I feel miserable',
#   'response': "Tell me everything that's bothering you."},
#  {'tag': 'sad',
#   'pattern': 'I feel upset',
#   'response': "Tell me everything that's worring you."},
#  {'tag': 'sad',
#   'pattern': 'I am so upset',
#   'response': 'Tell me all of your concerns.'},
#  {'tag': 'sad',
#   'pattern': 'I am so unhappy',
#   'response': 'You don’t need to do anything that makes you uncomfortable.'},
#  {'tag': 'sad',
#   'pattern': 'I am so down',
#   'response': 'Everything is going to be OK.'},
#  {'tag': 'sad',
#   'pattern': "I don't feel good now",
#   'response': 'Talk to me as long as you need.'},
#  {'tag': 'sad',
#   'pattern': 'I am so sad',
#   'response': 'Why are you feeling this way? Talk about it.'},
#  {'tag': 'sad',
#   'pattern': 'I am lonely',
#   'response': "Tell me what what's wrong don't feel so sad."},
#  {'tag': 'sad',
#   'pattern': "I don't know what happened",
#   'response': 'This is a temporary-yet-painful situation. It won’t always be like this. And bloody hell you are right it DOES suck.'},
#  {'tag': 'sad',
#   'pattern': 'I am always sad',
#   'response': 'It IS hard to imagine a way out of this mess. We can think about where to start chipping away together after we eat these biscuits.'},
#  {'tag': 'sad',
#   'pattern': 'I am always feeling down',
#   'response': 'I’m here to listen whenever you need me. No matter when or why.'},
#  {'tag': 'sad',
#   'pattern': 'I really want to be happy',
#   'response': 'I’m sorry you have to go through this.\xa0'},
#  {'tag': 'sad',
#   'pattern': 'No body want to talk to me',
#   'response': 'What are your thoughts on what’s going on and why it’s like this?'},
#  {'tag': 'sad',
#   'pattern': 'I am so terrible',
#   'response': 'It’s so good to see you here. I know you’ve got a lot of stuff going on.'},
#  {'tag': 'stressed',
#   'pattern': 'I am so stressed out',
#   'response': 'What do you think is causing this?'},
#  {'tag': 'stressed',
#   'pattern': 'I am so stressed',
#   'response': 'Take a deep breath and gather your thoughts. Go take a walk if possible. Stay hydrated'},
#  {'tag': 'stressed',
#   'pattern': 'I feel stuck',
#   'response': 'Give yourself a break. Go easy on yourself.'},
#  {'tag': 'stressed',
#   'pattern': 'I still feel stressed',
#   'response': 'I am sorry to hear that. What is the reason behind this?'},
#  {'tag': 'stressed',
#   'pattern': 'I am so burned out',
#   'response': 'You’re not alone in this. I may not understand exactly how you feel but I care about you and want to help.'},
#  {'tag': 'stressed',
#   'pattern': 'It drives me crazy',
#   'response': 'Asking for help is a sign of strength.'},
#  {'tag': 'stressed',
#   'pattern': "I'm under too much pressure",
#   'response': 'Depression is a real health issue that can be treated. What steps can you take to talk to a doctor or counselor about how you’re feeling?'},
#  {'tag': 'stressed',
#   'pattern': 'I was under too much stress',
#   'response': 'Depression is a real thing.'},
#  {'tag': 'stressed',
#   'pattern': 'I feel trapped',
#   'response': 'I know you probably don’t feel like it right now but let’s go for a walk.'},
#  {'tag': 'stressed',
#   'pattern': 'I was so tired',
#   'response': 'Explain it to me. I want to understand.'},
#  {'tag': 'stressed',
#   'pattern': 'I was so exhausted',
#   'response': 'You’re right this sucks.'},
#  {'tag': 'stressed',
#   'pattern': 'It makes me crazy',
#   'response': 'You don’t walk this path alone. I’m here if you need me.'},
#  {'tag': 'stressed',
#   'pattern': 'It makes me feel crazy',
#   'response': 'I believe in you. You’re awesome!'},
#  {'tag': 'stressed',
#   'pattern': "There's just too much going on",
#   'response': 'Things will change. You won’t feel this way forever. Look to that day'},
#  {'tag': 'stressed',
#   'pattern': 'There are so many things that need to be done',
#   'response': 'I can’t imagine how you feel but I’m here for you if you need me.”'},
#  {'tag': 'stressed',
#   'pattern': 'There is so much to do',
#   'response': 'I wish I had the right words to say but just know that I care about you.'},
#  {'tag': 'stressed',
#   'pattern': 'There is a lot to do',
#   'response': 'I’m sorry. I know that was important to you.'},
#  {'tag': 'stressed',
#   'pattern': 'The pressure is too much',
#   'response': 'I know things are difficult right now but I have confidence in you.'},
#  {'tag': 'stressed',
#   'pattern': "I'm too anxious",
#   'response': 'You’ve been doing really great!'},
#  {'tag': 'stressed',
#   'pattern': 'I feel anxious',
#   'response': 'I know you’re strong enough to get through this.'},
#  {'tag': 'stressed',
#   'pattern': "I'm too worried",
#   'response': "I'm so sorry that everything sucks so much right now. I love you.\xa0"},
#  {'tag': 'stressed',
#   'pattern': 'Not enough time at all',
#   'response': 'Is there anything I can do? Please let me know how I can support you.'},
#  {'tag': 'stressed',
#   'pattern': 'There is still a lot left to do',
#   'response': "It's OK to cry and be upset. Don't feel any pressure to be."},
#  {'tag': 'stressed',
#   'pattern': 'There is not enough time at all',
#   'response': 'Do you need a hug? I hope I can give you one.'},
#  {'tag': 'stressed',
#   'pattern': 'I reaaly need more time',
#   'response': 'Feel free to talk to me, anytime.'}]

# %%
df = df1.groupby('tag').agg({"pattern": lambda x:list(x),
                       "response" : lambda x: list(x)
                       })

# %%
# df1.groupby('tag').agg(lambda x:list(x))

# %%
df = df.reset_index(level=0)

# %%
corpus = df.to_dict("records")

# %%
df
# Out:
#            tag                                            pattern  \
# 0      goodbye  [Bye, I must be going, See you later, Goodbye,...
# 1     greeting  [Hi, Hey, Is anyone there, Hi there, Hello, He...
# 2         help  [Could you help me, give me a hand please, Can...
# 3  no-response  [ ,   , nan, nan, nan, nan, nan, nan, nan, nan...
# 4          sad  [I am feeling lonely, I am so lonely, I feel d...
# 5     stressed  [I am so stressed out, I am so stressed, I fee...
# 6       thanks  [Thanks, Thank you, That's helpful, Thanks for...
#
#                                             response
# 0  [See you later., Have a nice day., Bye! Come b...
# 1  [Hello there. Tell me how are you feeling toda...
# 2  [Sure. Tell me how can i assist you., Tell me ...
# 3  [Sorry I didn't understand you., Sorry I'm afr...
# 4  [I'm sorry to hear that. I'm here for you. , I...
# 5  [What do you think is causing this?, Take a de...
# 6  [Happy to help!, Any time!, My pleasure., You'...

# %%
df1[df1['tag']=='no-response']
# Out:
#              tag pattern                                           response
# 79   no-response                             Sorry I didn't understand you.
# 80   no-response                       Sorry I'm afraid I don't follow you.
# 81   no-response     NaN           Excuse me could you repeat the question?
# 82   no-response     NaN  I'm sorry I don't understand. Could you say it...
# 83   no-response     NaN             I'm confused. Could you tell me again?
# 84   no-response     NaN                                      Please go on.
# 85   no-response     NaN  I'm sorry I didn't catch what you said. Could ...
# 86   no-response     NaN                        Not sure I understand that.
# 87   no-response     NaN               Please don't hesitate to talk to me.
# 88   no-response     NaN                           I'm sorry what was that?
# 89   no-response     NaN                   Could you say that again please?
# 90   no-response     NaN                                         I'm sorry?
# 91   no-response     NaN             Sorry could you say that again please?
# 92   no-response     NaN                  Would you mind saying that again?
# 93   no-response     NaN                      I'm afraid I didn't get that.
# 94   no-response     NaN   Sorry I didn't get the last bit. Say that again?
# 95   no-response     NaN                         Sorry I didn't catch that.
# 96   no-response     NaN              Could you repeat the question please?
# 97   no-response     NaN                           Could you tell me again?
# 98   no-response     NaN                          Sorry I don't follow you.
# 99   no-response     NaN                                          I'm lost.
# 100  no-response     NaN                   Could you tell me what it means?
# 101  no-response     NaN                     Sorry I still didn’t hear you.
# 102  no-response     NaN                                             Sorry?
# 103  no-response     NaN                                        Come again?
# 104  no-response     NaN                           I'm always here to help.

# %%
df
# Out:
#            tag                                            pattern  \
# 0      goodbye  [Bye, I must be going, See you later, Goodbye,...
# 1     greeting  [Hi, Hey, Is anyone there, Hi there, Hello, He...
# 2         help  [Could you help me, give me a hand please, Can...
# 3  no-response  [ ,   , nan, nan, nan, nan, nan, nan, nan, nan...
# 4          sad  [I am feeling lonely, I am so lonely, I feel d...
# 5     stressed  [I am so stressed out, I am so stressed, I fee...
# 6       thanks  [Thanks, Thank you, That's helpful, Thanks for...
#
#                                             response
# 0  [See you later., Have a nice day., Bye! Come b...
# 1  [Hello there. Tell me how are you feeling toda...
# 2  [Sure. Tell me how can i assist you., Tell me ...
# 3  [Sorry I didn't understand you., Sorry I'm afr...
# 4  [I'm sorry to hear that. I'm here for you. , I...
# 5  [What do you think is causing this?, Take a de...
# 6  [Happy to help!, Any time!, My pleasure., You'...

# %%
corpus
# Out:
# [{'tag': 'goodbye',
#   'pattern': ['Bye',
#    'I must be going',
#    'See you later',
#    'Goodbye',
#    'Au revoir',
#    'Sayonara',
#    'ok bye',
#    'Bye then',
#    'Fare thee well',
#    'Talk to you later',
#    'See you',
#    'See ya',
#    'Good talking to you',
#    "I'm off",
#    'I look forward to our next meeting',
#    'It was nice to see you again',
#    'It was nice seeing you',
#    'Goodnight',
#    'Catch you later',
#    'Later',
#    'Peace',
#    'Peace out',
#    "I'm out",
#    "I'm out of here",
#    'I gotta jet',
#    'I gotta take off',
#    'I gotta go'],
#   'response': ['See you later.',
#    'Have a nice day.',
#    'Bye! Come back again.',
#    "I'll see you soon.",
#    'Bye Get some proper sleep.',
#    'I look forward to our next meeting.',
#    'Have a great rest of your day!',
#    'Have a nice day!',
#    'It was a pleasure speaking with you.',
#    'It was a pleasure seeing you to you.',
#    'It was a pleasure talking you to you.',
#    'Speak to you then.',
#    'Take care.',
#    'See you around.',
#    'Good seeing you!',
#    'Bye for now.',
#    'Keep in touch.',
#    'Get well soon!',
#    'Take care my friend',
#    'Catch you later!',
#    'Nice chatting with you.',
#    'Cheers.',
#    'See you',
#    'Have a good one',
#    'Hope all is well with you my friend!',
#    'Hope all goes well for you my friend!',
#    'Hava a good day']},
#  {'tag': 'greeting',
#   'pattern': ['Hi',
#    'Hey',
#    'Is anyone there',
#    'Hi there',
#    'Hello',
#    'Hey there',
#    'Howdy',
#    'Hola',
#    'Hiya',
#    'Yo',
#    'Hey chatbot',
#    'Bonjour',
#    'Konnichiwa',
#    'Guten tag',
#    'Ola',
#    'Good Morning',
#    'Good Afternoon',
#    'Good Evening',
#    'I really need someone talk to me',
#    'Can you talk to me',
#    'Hello are you there',
#    'Are you there',
#    'Hello chatbot',
#    'Hi chatbot',
#    'chatbot can you talk to me',
#    'chatbot what can you do'],
#   'response': ['Hello there. Tell me how are you feeling today?',
#    'Hi there. What brings you here today?',
#    'Hi there. How are you feeling today?',
#    'Great to see you. How do you feel currently?',
#    "Hello there. Glad to see you're back. What's going on in your world right now?",
#    'How do you do? Do you have a good day?',
#    'Nice to meet you sir',
#    'Good to see you sir',
#    'Hey! Long-time no see. How are you?',
#    "What's the story?",
#    "It's a pleasure to meet you",
#    "It's pleased to meet you",
#    "How's your life talk about it.",
#    'Whazzup?',
#    'How are you feeling today?',
#    'How is your day going?',
#    'How has your day been?',
#    'I hope you had a good day',
#    "How's everything?",
#    'How are things?',
#    "It's been a while. Tell me how's your day.",
#    'Good to see you. You can always talk to me.',
#    "It's good to see you. You can talk to me.",
#    "It's nice to see you. I will here listen to you",
#    'I will listen to you here.',
#    'I will always be here and listen to you']},
#  {'tag': 'help',
#   'pattern': ['Could you help me',
#    'give me a hand please',
#    'Can you help?',
#    'What can you do for me',
#    'I need support',
#    'I need help',
#    'Support me please',
#    'What should I do',
#    'Can you give me a hand with this',
#    'Could you help me for a second',
#    'Can I ask a favor',
#    "I can't manage",
#    'I need some help please',
#    'Help',
#    'Help me',
#    'Can you help me',
#    'Do you know why',
#    'What can I do',
#    'Could you please help me',
#    'Please give me some advice',
#    'I need help',
#    'Could you please help me',
#    'Chatbot help me',
#    'Chatbot give me some help',
#    'Chatbot give me some advice',
#    'Help me chatbot'],
#   'response': ['Sure. Tell me how can i assist you.',
#    'Tell me your problem so that i can assist you.',
#    'Yes sure. How can I help you?',
#    'Is there anything you need?',
#    'Can I get you anything?',
#    'Do you need someone to talk to?',
#    'Would you like me to go with you?',
#    'What can I do to help your process?',
#    'Is there anyone else I can recruit to help.',
#    "I'm happy to help with you.",
#    "It's no problem at all if you need me to do.",
#    'If there is anything else you need please let me know.',
#    'If I can be of any further assistance please let me know.',
#    'If there is anything else I can do for you please don’t hesitate to let me know.',
#    'Please feel free to let me know if you require any further information.',
#    'If I may be of any further assistance please let me know.',
#    'If I can do anything for you just let me know.',
#    'What can I do to help you?',
#    'What do you want me to do to help you?',
#    'Do you feel anyone else can help you?',
#    'Please tell me what can I do.',
#    "I'm always here to help you just let me know.",
#    "I'm always there my friend.",
#    "Of course just let me know what's going on.",
#    'Please tell me how I can help you.',
#    "I'm always happy to help you my friend."]},
#  {'tag': 'no-response',
#   'pattern': [' ',
#    '  ',
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan],
#   'response': ["Sorry I didn't understand you.",
#    "Sorry I'm afraid I don't follow you.",
#    'Excuse me could you repeat the question?',
#    "I'm sorry I don't understand. Could you say it again?",
#    "I'm confused. Could you tell me again?",
#    'Please go on.',
#    "I'm sorry I didn't catch what you said. Could you say it another way?",
#    'Not sure I understand that.',
#    "Please don't hesitate to talk to me.",
#    "I'm sorry what was that?",
#    'Could you say that again please?',
#    "I'm sorry?",
#    'Sorry could you say that again please?',
#    'Would you mind saying that again?',
#    "I'm afraid I didn't get that.",
#    "Sorry I didn't get the last bit. Say that again?",
#    "Sorry I didn't catch that.",
#    'Could you repeat the question please?',
#    'Could you tell me again?',
#    "Sorry I don't follow you.",
#    "I'm lost.",
#    'Could you tell me what it means?',
#    'Sorry I still didn’t hear you.',
#    'Sorry?',
#    'Come again?',
#    "I'm always here to help."]},
#  {'tag': 'sad',
#   'pattern': ['I am feeling lonely',
#    'I am so lonely',
#    'I feel down',
#    'I feel sad',
#    'I am sad',
#    'I feel so lonely',
#    'I feel empty',
#    "I don't have anyone",
#    "I'm not happy",
#    "I don't know why I'm not happy",
#    "I'm unhappy",
#    'I feel miserable',
#    'I feel upset',
#    'I am so upset',
#    'I am so unhappy',
#    'I am so down',
#    "I don't feel good now",
#    'I am so sad',
#    'I am lonely',
#    "I don't know what happened",
#    'I am always sad',
#    'I am always feeling down',
#    'I really want to be happy',
#    'No body want to talk to me',
#    'I am so terrible'],
#   'response': ["I'm sorry to hear that. I'm here for you. ",
#    "I'm here for you. Could you tell me why you're feeling this way?",
#    'Why do you think you feel this way?',
#    'How long have you been feeling this way?',
#    "Talking about it might help. So tell me why do you think you're feeling this way?",
#    'It’s OK to not feel OK.',
#    'You’re not alone.',
#    'I’m here for you no matter what.',
#    "I'm here to listen whenever you need me.",
#    "I'm so gald you can talk your sad with me.",
#    'Tell me what happened.',
#    "Tell me everything that's bothering you.",
#    "Tell me everything that's worring you.",
#    'Tell me all of your concerns.',
#    'You don’t need to do anything that makes you uncomfortable.',
#    'Everything is going to be OK.',
#    'Talk to me as long as you need.',
#    'Why are you feeling this way? Talk about it.',
#    "Tell me what what's wrong don't feel so sad.",
#    'This is a temporary-yet-painful situation. It won’t always be like this. And bloody hell you are right it DOES suck.',
#    'It IS hard to imagine a way out of this mess. We can think about where to start chipping away together after we eat these biscuits.',
#    'I’m here to listen whenever you need me. No matter when or why.',
#    'I’m sorry you have to go through this.\xa0',
#    'What are your thoughts on what’s going on and why it’s like this?',
#    'It’s so good to see you here. I know you’ve got a lot of stuff going on.']},
#  {'tag': 'stressed',
#   'pattern': ['I am so stressed out',
#    'I am so stressed',
#    'I feel stuck',
#    'I still feel stressed',
#    'I am so burned out',
#    'It drives me crazy',
#    "I'm under too much pressure",
#    'I was under too much stress',
#    'I feel trapped',
#    'I was so tired',
#    'I was so exhausted',
#    'It makes me crazy',
#    'It makes me feel crazy',
#    "There's just too much going on",
#    'There are so many things that need to be done',
#    'There is so much to do',
#    'There is a lot to do',
#    'The pressure is too much',
#    "I'm too anxious",
#    'I feel anxious',
#    "I'm too worried",
#    'Not enough time at all',
#    'There is still a lot left to do',
#    'There is not enough time at all',
#    'I reaaly need more time'],
#   'response': ['What do you think is causing this?',
#    'Take a deep breath and gather your thoughts. Go take a walk if possible. Stay hydrated',
#    'Give yourself a break. Go easy on yourself.',
#    'I am sorry to hear that. What is the reason behind this?',
#    'You’re not alone in this. I may not understand exactly how you feel but I care about you and want to help.',
#    'Asking for help is a sign of strength.',
#    'Depression is a real health issue that can be treated. What steps can you take to talk to a doctor or counselor about how you’re feeling?',
#    'Depression is a real thing.',
#    'I know you probably don’t feel like it right now but let’s go for a walk.',
#    'Explain it to me. I want to understand.',
#    'You’re right this sucks.',
#    'You don’t walk this path alone. I’m here if you need me.',
#    'I believe in you. You’re awesome!',
#    'Things will change. You won’t feel this way forever. Look to that day',
#    'I can’t imagine how you feel but I’m here for you if you need me.”',
#    'I wish I had the right words to say but just know that I care about you.',
#    'I’m sorry. I know that was important to you.',
#    'I know things are difficult right now but I have confidence in you.',
#    'You’ve been doing really great!',
#    'I know you’re strong enough to get through this.',
#    "I'm so sorry that everything sucks so much right now. I love you.\xa0",
#    'Is there anything I can do? Please let me know how I can support you.',
#    "It's OK to cry and be upset. Don't feel any pressure to be.",
#    'Do you need a hug? I hope I can give you one.',
#    'Feel free to talk to me, anytime.']},
#  {'tag': 'thanks',
#   'pattern': ['Thanks',
#    'Thank you',
#    "That's helpful",
#    'Thanks for the help',
#    "I'm so grateful",
#    'Thank you very much',
#    'Thank you a lot',
#    'Thanks a lot',
#    'Thanks so much',
#    "I'm so grateful",
#    'Thanks for having my back',
#    'Much appreciated',
#    'Many thanks',
#    'Thanks a bunch',
#    "It's very kind of you",
#    'I really appreciate it',
#    'Thank you for everything',
#    'I owe you one',
#    'Thanks a million',
#    'appreciate your time',
#    'Thanks a ton',
#    'You are the best',
#    'You made my day',
#    'You saved my day',
#    "You're awesome",
#    "You're great"],
#   'response': ['Happy to help!',
#    'Any time!',
#    'My pleasure.',
#    "You're most welcome!",
#    'No problem.',
#    'No worries.',
#    'Anytime my friend',
#    "I'm glad I could be of assistance.",
#    "I'm happy to support the team.",
#    "That's why Im here it's not a problem",
#    "I'm happy to help.",
#    "I'll always be here for you.",
#    "Don't worry about it.",
#    "I'm happy I was able to help you.",
#    "You're Welcome.",
#    'Always glad to help.',
#    'Let me know anytime I can help.',
#    'It makes me happy to help.',
#    "I'm always here to help.",
#    'Just ask any time I can help.',
#    'Pleased to be of assistance.',
#    'Thank you for allowing me to help.',
#    'Glad that I could be of assistance.',
#    "It's always great to be of assistance.",
#    "You're so kind.",
#    "You're very welcome."]}]

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\avitr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\avitr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data['intents'] = corpus

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["pattern"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [99], in <cell line: 11>()
#      11 for intent in data["intents"]:
#      12     for pattern in intent["pattern"]:
# ---> 13         tokens = nltk.word_tokenize(pattern)
#      14         words.extend(tokens)
#      15         doc_X.append(pattern)
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
#     106 tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107 return tokenizer.tokenize(text)
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1276, in PunktSentenceTokenizer.tokenize(self, text, realign_boundaries)
#    1272 def tokenize(self, text, realign_boundaries=True):
#    1273     """
#    1274     Given a text, returns a list of the sentences in that text.
#    1275     """
# -> 1276     return list(self.sentences_from_text(text, realign_boundaries))
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1332, in PunktSentenceTokenizer.sentences_from_text(self, text, realign_boundaries)
#    1325 def sentences_from_text(self, text, realign_boundaries=True):
#    1326     """
#    1327     Given a text, generates the sentences in that text by only
#    1328     testing candidate sentence breaks. If realign_boundaries is
#    1329     True, includes in the sentence closing punctuation that
#    1330     follows the period.
#    1331     """
# -> 1332     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1332, in <listcomp>(.0)
#    1325 def sentences_from_text(self, text, realign_boundaries=True):
#    1326     """
#    1327     Given a text, generates the sentences in that text by only
#    1328     testing candidate sentence breaks. If realign_boundaries is
#    1329     True, includes in the sentence closing punctuation that
#    1330     follows the period.
#    1331     """
# -> 1332     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1322, in PunktSentenceTokenizer.span_tokenize(self, text, realign_boundaries)
#    1320 if realign_boundaries:
#    1321     slices = self._realign_boundaries(text, slices)
# -> 1322 for sentence in slices:
#    1323     yield (sentence.start, sentence.stop)
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1421, in PunktSentenceTokenizer._realign_boundaries(self, text, slices)
#    1408 """
#    1409 Attempts to realign punctuation that falls after the period but
#    1410 should otherwise be included in the same sentence.
#    (...)
#    1418     ["(Sent1.)", "Sent2."].
#    1419 """
#    1420 realign = 0
# -> 1421 for sentence1, sentence2 in _pair_iter(slices):
#    1422     sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1423     if not sentence2:
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:318, in _pair_iter(iterator)
#     316 iterator = iter(iterator)
#     317 try:
# --> 318     prev = next(iterator)
#     319 except StopIteration:
#     320     return
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1395, in PunktSentenceTokenizer._slices_from_text(self, text)
#    1393 def _slices_from_text(self, text):
#    1394     last_break = 0
# -> 1395     for match, context in self._match_potential_end_contexts(text):
#    1396         if self.text_contains_sentbreak(context):
#    1397             yield slice(last_break, match.end())
#
# File ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py:1375, in PunktSentenceTokenizer._match_potential_end_contexts(self, text)
#    1373 before_words = {}
#    1374 matches = []
# -> 1375 for match in reversed(list(self._lang_vars.period_context_re().finditer(text))):
#    1376     # Ignore matches that have already been captured by matches to the right of this match
#    1377     if matches and match.end() > before_start:
#    1378         continue
#
# TypeError: expected string or bytes-like object

# %%
df1
# Out:
#           tag                          pattern  \
# 0    greeting                               Hi
# 1    greeting                              Hey
# 2    greeting                  Is anyone there
# 3    greeting                         Hi there
# 4    greeting                            Hello
# ..        ...                              ...
# 176  stressed                  I'm too worried
# 177  stressed           Not enough time at all
# 178  stressed  There is still a lot left to do
# 179  stressed  There is not enough time at all
# 180  stressed          I reaaly need more time
#
#                                               response
# 0      Hello there. Tell me how are you feeling today?
# 1                Hi there. What brings you here today?
# 2                 Hi there. How are you feeling today?
# 3         Great to see you. How do you feel currently?
# 4    Hello there. Glad to see you're back. What's g...
# ..                                                 ...
# 176  I'm so sorry that everything sucks so much rig...
# 177  Is there anything I can do? Please let me know...
# 178  It's OK to cry and be upset. Don't feel any pr...
# 179      Do you need a hug? I hope I can give you one.
# 180                  Feel free to talk to me, anytime.
#
# [181 rows x 3 columns]
