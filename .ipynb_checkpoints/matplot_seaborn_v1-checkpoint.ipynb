# %%
import pandas as pd
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\OneDrive - NITT\Custom_Download\COVID-19 Nursing Home Data 11.13.2022.zip")

# %%
df.shape
# Out:
# (1982709, 120)

# %%
df.head()
# Out:
#   Week Ending Federal Provider Number             Provider Name  \
# 0    05/24/20                   15009  BURNS NURSING HOME, INC.
# 1    05/31/20                   15009  BURNS NURSING HOME, INC.
# 2    06/07/20                   15009  BURNS NURSING HOME, INC.
# 3    06/14/20                   15009  BURNS NURSING HOME, INC.
# 4    06/21/20                   15009  BURNS NURSING HOME, INC.
#
#        Provider Address Provider City Provider State  Provider Zip Code  \
# 0  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 1  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 2  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 3  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 4  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
#
#    Provider Phone Number    County Submitted Data  ...  \
# 0             2563324110  Franklin              Y  ...
# 1             2563324110  Franklin              Y  ...
# 2             2563324110  Franklin              Y  ...
# 3             2563324110  Franklin              Y  ...
# 4             2563324110  Franklin              Y  ...
#
#   Percentage of Current Residents Up to Date with COVID-19 Vaccines with No Medical Contraindications  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of Current Residents with a Completed Vaccination Up to Date with COVID-19 Vaccines  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of Healthcare Personnel with a Completed Vaccination Staying in this Facility for At Least 1 Day This Week who Received a COVID-19 Vaccine Booster at Any Time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Recent Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week Up to Date with COVID-19 Vaccines  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Recent Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 120 columns]

# %% [markdown]
# # Question 1: Get general information about your dataset including the size, column name, etc.

# %%
df.size
# Out:
# 237925080

# %%
df.shape
# Out:
# (1982709, 120)

# %%
df.columns
# Out:
# Index(['Week Ending', 'Federal Provider Number', 'Provider Name',
#        'Provider Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Provider Phone Number', 'County',
#        'Submitted Data',
#        ...
#        'Percentage of Current Residents Up to Date with COVID-19 Vaccines with No Medical Contraindications',
#        'Percentage of Current Residents with a Completed Vaccination Up to Date with COVID-19 Vaccines',
#        'Number of Healthcare Personnel with a Completed Vaccination Staying in this Facility for At Least 1 Day This Week who Received a COVID-19 Vaccine Booster at Any Time',
#        'Recent Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time',
#        'Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time',
#        'Number of Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week Up to Date with COVID-19 Vaccines',
#        'Recent Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines',
#        'Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines',
#        'Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications',
#        'Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines'],
#       dtype='object', length=120)

# %%
list(df)
# Out:
# ['Week Ending',
#  'Federal Provider Number',
#  'Provider Name',
#  'Provider Address',
#  'Provider City',
#  'Provider State',
#  'Provider Zip Code',
#  'Provider Phone Number',
#  'County',
#  'Submitted Data',
#  'Passed Quality Assurance Check',
#  'Residents Weekly Admissions COVID-19',
#  'Residents Total Admissions COVID-19',
#  'Residents Weekly Confirmed COVID-19',
#  'Residents Total Confirmed COVID-19',
#  'Residents Weekly All Deaths',
#  'Residents Total All Deaths',
#  'Residents Weekly COVID-19 Deaths',
#  'Residents Total COVID-19 Deaths',
#  'Number of All Beds',
#  'Total Number of Occupied Beds',
#  'Staff Weekly Confirmed COVID-19',
#  'Staff Total Confirmed COVID-19',
#  'Staff Weekly COVID-19 Deaths',
#  'Staff Total COVID-19 Deaths',
#  'Shortage of Nursing Staff',
#  'Shortage of Clinical Staff',
#  'Shortage of Aides',
#  'Shortage of Other Staff',
#  'Weekly Resident Confirmed COVID-19 Cases Per 1,000 Residents',
#  'Weekly Resident COVID-19 Deaths Per 1,000 Residents',
#  'Total Resident Confirmed COVID-19 Cases Per 1,000 Residents',
#  'Total Resident COVID-19 Deaths Per 1,000 Residents',
#  'Three or More Confirmed COVID-19 Cases This Week',
#  'Initial Confirmed COVID-19 Case This Week',
#  'Number of Residents with a New Positive COVID-19 Test Result',
#  'Number of Residents with New Influenza',
#  'Number of Staff and/or Personnel with a New Positive COVID-19 Test Result',
#  'Number of Staff and/or Personnel with New Influenza',
#  'Able to Test or Obtain Resources to Test All Residents, Staff, and/or Personnel',
#  'Facility No Longer Has Supply Items in 7 Days',
#  'N95 Respirator No Longer Available in 7 Days',
#  'Face Masks No Longer Available in 7 Days',
#  'Eye Protection No Longer Available in 7 Days',
#  'Gowns No Longer Available in 7 Days',
#  'Gloves No Longer Available in 7 Days',
#  'Number of Residents Not Vaccinated with COVID-19 Vaccine or who Received COVID-19 Vaccine Dose 1, 13 Days or Less Before Positive Test',
#  'Number of Residents who Received COVID-19 Vaccine Dose 1 Only, 14 Days or More Before Positive Test',
#  'Number of Residents who Received COVID-19 Vaccine Doses 1 and 2, 14 Days or More Before Positive Test',
#  'Number of Residents who Received a COVID-19 Vaccine Booster, 14 Days or More Before Positive Test',
#  'Number of Residents who Received Only One COVID-19 Vaccine Booster, 14 Days or More Before Positive Test',
#  'Number of Residents who Received Two or More COVID-19 Vaccine Boosters, 14 Days or More Before Positive Test',
#  'Number of Residents who are Up to Date on COVID-19 Vaccinations, 14 Days or More Before Positive Test',
#  'Therapeutic Bamlanivimab: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Bamlanivimab: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Casirivimab plus Imdevimab: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Casirivimab plus Imdevimab: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Bamlanivimab plus Etesevimab: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Bamlanivimab plus Etesevimab: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Sotrovimab: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Sotrovimab: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Evusheld: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Evusheld: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Molnupiravir: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Molnupiravir: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Paxlovid: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Paxlovid: Number of Residents Treated from Stock Stored at Another Facility',
#  'Therapeutic Bebtelovimab: Number of Residents Treated from Stock Stored at This Facility',
#  'Therapeutic Bebtelovimab: Number of Residents Treated from Stock Stored at Another Facility',
#  'Number of Residents Staying in this Facility for At Least 1 Day This Week',
#  'Number of Residents Staying in this Facility for At Least 1 Day This Week who Received a Completed COVID-19 Vaccination at Any Time',
#  'Number of Residents Staying in this Facility for At Least 1 Day This Week who Received a Partial COVID-19 Vaccination at Any Time',
#  'Number of Residents Staying in this Facility for At Least 1 Day This Week with a Medical Contraindication to a COVID-19 Vaccine at Any Time',
#  'Number of Residents Staying in this Facility for At Least 1 Day This Week who were Offered but Declined a COVID-19 Vaccine at Any Time',
#  'Number of Residents Staying in this Facility for At Least 1 Day This Week with an Unknown COVID-19 Vaccination Status at Any Time',
#  'Recent Percentage of Current Residents who Received a Completed COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents who Received a Completed COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents who Received a Partial COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents who Received a Completed or Partial COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents with No Medical Contraindications who Received a Completed COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents with No Medical Contraindications who Received a Partial COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents with No Medical Contraindications who Received a Completed or Partial COVID-19 Vaccination at Any Time',
#  'Percentage of Current Residents with No Medical Contraindications who Received a Completed COVID-19 Vaccination, Excluding Declinations from Eligible Residents at Any Time',
#  'Number of All Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week',
#  'Number of All Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week who Received a Completed COVID-19 Vaccination at Any Time',
#  'Number of All Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week who Received a Partial COVID-19 Vaccination at Any Time',
#  'Number of All Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week with a Medical Contraindication to a COVID-19 Vaccine at Any Time',
#  'Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines',
#  'Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications',
#  'Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines']

# %% [markdown]
# # Question 2: What is the mean, median, standard deviation, minimum, and maximum of the number of each numerical column in your dataset.

# %%
x = df.describe(percentiles=[.5]).loc[['mean','50%','std','min','max']]
x = x.rename(index={'50%': 'median'})
x
# Out:
#         Provider Zip Code  Provider Phone Number  \
# mean         50311.457794           5.877161e+09
# median       48801.000000           6.059283e+09
# std          26840.355360           2.331468e+09
# min            660.000000           1.112223e+09
# max          99929.000000           1.000000e+10
#
#         Residents Weekly Admissions COVID-19  \
# mean                                0.257706
# median                              0.000000
# std                                 1.585397
# min                                 0.000000
# max                               446.000000
#
#         Residents Total Admissions COVID-19  \
# mean                               19.80326
# median                              5.00000
# std                                53.95449
# min                                 0.00000
# max                              1913.00000
#
#         Residents Weekly Confirmed COVID-19  \
# mean                               0.675711
# median                             0.000000
# std                                3.184319
# min                                0.000000
# max                              312.000000
#
#         Residents Total Confirmed COVID-19  Residents Weekly All Deaths  \
# mean                             47.496678                     0.464486
# median                           38.000000                     0.000000
# std                              46.319374                     1.835989
# min                               0.000000                     0.000000
# max                             651.000000                   986.000000
#
#         Residents Total All Deaths  Residents Weekly COVID-19 Deaths  \
# mean                     35.553071                          0.081163
# median                   25.000000                          0.000000
# std                      55.937046                          0.697828
# min                       0.000000                          0.000000
# max                    2995.000000                         89.000000
#
#         Residents Total COVID-19 Deaths  ...  \
# mean                           8.014564  ...
# median                         5.000000  ...
# std                           10.603620  ...
# min                            0.000000  ...
# max                          164.000000  ...
#
#         Percentage of Current Residents Up to Date with COVID-19 Vaccines with No Medical Contraindications  \
# mean                                            16.395676
# median                                           0.000000
# std                                             30.435549
# min                                              0.000000
# max                                            101.176000
#
#         Percentage of Current Residents with a Completed Vaccination Up to Date with COVID-19 Vaccines  \
# mean                                            18.331285
# median                                           0.000000
# std                                             33.544196
# min                                              0.000000
# max                                            101.176000
#
#         Number of Healthcare Personnel with a Completed Vaccination Staying in this Facility for At Least 1 Day This Week who Received a COVID-19 Vaccine Booster at Any Time  \
# mean                                            46.724812
# median                                          30.000000
# std                                             60.014251
# min                                              0.000000
# max                                           1748.000000
#
#         Recent Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time  \
# mean                                            56.985058
# median                                          54.545000
# std                                             26.131568
# min                                              0.000000
# max                                            100.000000
#
#         Percentage of Current Healthcare Personnel with a Completed Vaccination who Received a COVID-19 Vaccine Booster at Any Time  \
# mean                                            32.251892
# median                                          27.778000
# std                                             31.011967
# min                                              0.000000
# max                                            100.000000
#
#         Number of Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week Up to Date with COVID-19 Vaccines  \
# mean                                            52.600254
# median                                          36.000000
# std                                             60.598087
# min                                              0.000000
# max                                           1747.000000
#
#         Recent Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines  \
# mean                                            23.686705
# median                                          13.158000
# std                                             27.150791
# min                                              0.000000
# max                                            100.000000
#
#         Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines  \
# mean                                            11.942079
# median                                           0.000000
# std                                             24.269875
# min                                              0.000000
# max                                            100.000000
#
#         Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications  \
# mean                                            12.059273
# median                                           0.000000
# std                                             24.500577
# min                                              0.000000
# max                                            100.000000
#
#         Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines
# mean                                            13.402152
# median                                           0.000000
# std                                             26.530224
# min                                              0.000000
# max                                            100.000000
#
# [5 rows x 98 columns]

# %% [markdown]
# # Question 3: For each categorical feature, how many unique values and what is the frequency of each unique value.

# %%
for cat_col in df.select_dtypes('object').columns:
    print(f"**********{cat_col}**********")
    print('number of unique values:',df[cat_col].nunique())
    print('Their frequencies are as follows:-')
    print(df[cat_col].value_counts())
# Out:
# **********Week Ending**********
# number of unique values: 130
# Their frequencies are as follows:-
# 06/14/20    15370
# 06/07/20    15368
# 06/21/20    15368
# 05/24/20    15367
# 06/28/20    15367
#             ...
# 10/16/22    15132
# 10/23/22    15132
# 10/30/22    15132
# 11/06/22    15131
# 11/13/22    15131
# Name: Week Ending, Length: 130, dtype: int64
# **********Federal Provider Number**********
# number of unique values: 15561
# Their frequencies are as follows:-
# 15009     130
# 365796    130
# 365779    130
# 365780    130
# 365781    130
#          ...
# 345521      2
# 17E665      1
# 505291      1
# 385281      1
# 16E760      1
# Name: Federal Provider Number, Length: 15561, dtype: int64
# **********Provider Name**********
# number of unique values: 15231
# Their frequencies are as follows:-
# MILLER'S MERRY MANOR                                  3900
# PARKVIEW CARE CENTER                                   780
# PROMEDICA SKILLED NURSING AND REHABILITATION           780
# LITTLE SISTERS OF THE POOR                             762
# COMMUNITY CARE CENTER                                  520
#                                                       ...
# NURSING CENTER AT UNIVERSITY VILLAGE, THE                4
# IVINSON MEMORIAL HOSPITAL                                3
# SNUG HARBOR ON NELSON BAY                                2
# HEALTHCARE AT FOSTER CREEK                               1
# RIVERVIEW LUTHERAN RETIREMENT COMMUNITY OF SPOKANE       1
# Name: Provider Name, Length: 15231, dtype: int64
# **********Provider Address**********
# number of unique values: 15443
# Their frequencies are as follows:-
# N2665 CTY RD QQ              390
# 16 VALLEY VIEW DRIVE         321
# 3550 HIGHWAY 468 WEST        309
# 400 SEVENTH STREET           260
# 160 MAIN STREET              260
#                             ...
# 12250 N 22ND ST                4
# 3057 NORTH CLEVELAND ROAD      4
# 255 N 30TH STREET              3
# 272 HIGHWAY 70                 2
# 1841 EAST UPRIVER DRIVE        1
# Name: Provider Address, Length: 15443, dtype: int64
# **********Provider City**********
# number of unique values: 5267
# Their frequencies are as follows:-
# CHICAGO          10322
# LOS ANGELES      10204
# CINCINNATI        9416
# HOUSTON           8772
# SAN ANTONIO       8066
#                  ...
# SEVILLE             14
# SPEARVILLE          10
# KAPAAU               6
# ARCHER CITY          6
# DELAWARE CITY        5
# Name: Provider City, Length: 5267, dtype: int64
# **********Provider State**********
# number of unique values: 53
# Their frequencies are as follows:-
# TX    157256
# CA    153522
# OH    123691
# IL     91669
# FL     91041
# PA     89143
# NY     79789
# IN     68696
# MO     67128
# MI     56477
# IA     56279
# NC     55455
# MA     47666
# MN     47033
# GA     46643
# NJ     46421
# WI     45115
# KS     41927
# TN     40734
# OK     38706
# VA     37285
# KY     36683
# LA     35393
# AL     29491
# MD     29269
# CO     28851
# AR     28839
# CT     27177
# MS     26506
# WA     26120
# NE     25084
# SC     24465
# AZ     18667
# OR     16854
# WV     15973
# SD     13464
# UT     12691
# ME     11943
# ID     10502
# ND     10222
# RI     10064
# NH      9518
# MT      9134
# NM      8960
# NV      8617
# DE      5908
# HI      5579
# WY      4683
# VT      4550
# AK      2599
# DC      2285
# PR       812
# GU       130
# Name: Provider State, dtype: int64
# **********County**********
# number of unique values: 1705
# Their frequencies are as follows:-
# Los Angeles    49378
# Cook           27161
# Jefferson      25509
# Montgomery     24739
# Washington     18516
#                ...
# Ontonagon         77
# Divide            67
# Desha             57
# Caribou           54
# Archer             6
# Name: County, Length: 1705, dtype: int64
# **********Submitted Data**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1968028
# N      14681
# Name: Submitted Data, dtype: int64
# **********Passed Quality Assurance Check**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1954843
# N      13185
# Name: Passed Quality Assurance Check, dtype: int64
# **********Shortage of Nursing Staff**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    1303415
# Y     378422
# Name: Shortage of Nursing Staff, dtype: int64
# **********Shortage of Clinical Staff**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    1636185
# Y      45613
# Name: Shortage of Clinical Staff, dtype: int64
# **********Shortage of Aides**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    1269103
# Y     412732
# Name: Shortage of Aides, dtype: int64
# **********Shortage of Other Staff**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    1460552
# Y     221265
# Name: Shortage of Other Staff, dtype: int64
# **********Three or More Confirmed COVID-19 Cases This Week**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    1817239
# Y     125418
# Name: Three or More Confirmed COVID-19 Cases This Week, dtype: int64
# **********Initial Confirmed COVID-19 Case This Week**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    1931455
# Y      11203
# Name: Initial Confirmed COVID-19 Case This Week, dtype: int64
# **********Able to Test or Obtain Resources to Test All Residents, Staff, and/or Personnel**********
# number of unique values: 3
# Their frequencies are as follows:-
# Y    354264
# N      3502
# 0        33
# Name: Able to Test or Obtain Resources to Test All Residents, Staff, and/or Personnel, dtype: int64
# **********Facility No Longer Has Supply Items in 7 Days**********
# number of unique values: 2
# Their frequencies are as follows:-
# N    355834
# Y      1965
# Name: Facility No Longer Has Supply Items in 7 Days, dtype: int64
# **********N95 Respirator No Longer Available in 7 Days**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1722
# N     862
# Name: N95 Respirator No Longer Available in 7 Days, dtype: int64
# **********Face Masks No Longer Available in 7 Days**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1490
# N    1095
# Name: Face Masks No Longer Available in 7 Days, dtype: int64
# **********Eye Protection No Longer Available in 7 Days**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1440
# N    1144
# Name: Eye Protection No Longer Available in 7 Days, dtype: int64
# **********Gowns No Longer Available in 7 Days**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1450
# N    1132
# Name: Gowns No Longer Available in 7 Days, dtype: int64
# **********Gloves No Longer Available in 7 Days**********
# number of unique values: 2
# Their frequencies are as follows:-
# Y    1483
# N    1099
# Name: Gloves No Longer Available in 7 Days, dtype: int64

# %% [markdown]
# # Question 4: does your data has missing values? If yes, use different methods to handle them.

# %%
x = df.isna().mean()

# %%
x # yes, dataset is having missing values
# Out:
# Week Ending                                                                                                                        0.000000
# Federal Provider Number                                                                                                            0.000000
# Provider Name                                                                                                                      0.000066
# Provider Address                                                                                                                   0.000000
# Provider City                                                                                                                      0.000000
#                                                                                                                                      ...
# Number of Healthcare Personnel Eligible to Work in this Facility for At Least 1 Day This Week Up to Date with COVID-19 Vaccines    0.821733
# Recent Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines                                                0.992545
# Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines                                                       0.426423
# Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications                     0.426423
# Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines                          0.426423
# Length: 120, dtype: float64

# %%
print('Column name and percentage of NaN')
print('**********************************')
for col,nan_avg in zip(x.index,list(x)):
    print(col,'-->',nan_avg)
# Out:
# Column name and percentage of NaN
# **********************************
# Week Ending --> 0.0
# Federal Provider Number --> 0.0
# Provider Name --> 6.556685827320095e-05
# Provider Address --> 0.0
# Provider City --> 0.0
# Provider State --> 0.0
# Provider Zip Code --> 0.0
# Provider Phone Number --> 0.0
# County --> 0.0
# Submitted Data --> 0.0
# Passed Quality Assurance Check --> 0.00740451574083741
# Residents Weekly Admissions COVID-19 --> 0.0052539227894764185
# Residents Total Admissions COVID-19 --> 0.0052539227894764185
# Residents Weekly Confirmed COVID-19 --> 0.0052539227894764185
# Residents Total Confirmed COVID-19 --> 0.0052539227894764185
# Residents Weekly All Deaths --> 0.0052539227894764185
# Residents Total All Deaths --> 0.0052539227894764185
# Residents Weekly COVID-19 Deaths --> 0.0052539227894764185
# Residents Total COVID-19 Deaths --> 0.0052539227894764185
# Number of All Beds --> 0.011065163874275044
# Total Number of Occupied Beds --> 0.009349329629310201
# Staff Weekly Confirmed COVID-19 --> 0.0052539227894764185
# Staff Total Confirmed COVID-19 --> 0.0052539227894764185
# Staff Weekly COVID-19 Deaths --> 0.0052539227894764185
# Staff Total COVID-19 Deaths --> 0.0052539227894764185
# Shortage of Nursing Staff --> 0.1517479367874963
# Shortage of Clinical Staff --> 0.15176760684497825
# Shortage of Aides --> 0.1517489455083928
# Shortage of Other Staff --> 0.1517580239964614
# Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines --> 0.42642314126783104
# Percentage of Current Healthcare Personnel Up to Date with COVID-19 Vaccines with No Medical Contraindications --> 0.42642314126783104
# Percentage of Current Healthcare Personnel with a Completed Vaccination Up to Date with COVID-19 Vaccines --> 0.42642314126783104

# %%
df = df.dropna(axis=1,thresh=len(df)*.7)

# %%
x = df.isna().sum()

# %%
x = x[x!=0]

# %%
for col in tqdm(x.index):
    try:
        if isinstance(df[col][1],float):
            df[col] = df[col].fillna(df[col].mean())
        else:
            df[col] = df[col].fillna(df[col].mode())
    except:
        print(col)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# # Question 5: does your data has duplicate values? If yes, fix them

# %%
df.shape
# Out:
# (1982709, 39)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1982709, 39)

# %% [markdown]
# - no, dataset dont have duplicate values

# %% [markdown]
# # Question 6- Find five interesting healthcare questions out of your dataset. Then, write Python code to answer the questions.

# %%
# country wise total number of bed
df.groupby('County')['Number of All Beds'].sum()
# Out:
# County
# Abbeville     12220.000000
# Acadia        73970.000000
# Accomack      17680.000000
# Ada          177374.541477
# Adair         83518.000000
#                  ...
# York         511216.207297
# Young         43550.000000
# Yuba          11180.000000
# Yuma          79806.140134
# Zapata         7670.000000
# Name: Number of All Beds, Length: 1705, dtype: float64

# %%
# country wise total number of occiped bed
df.groupby('County')['Total Number of Occupied Beds'].sum()
# Out:
# County
# Abbeville      7984.000000
# Acadia        58478.000000
# Accomack      14305.000000
# Ada          111582.923460
# Adair         45460.000000
#                  ...
# York         392520.032601
# Young         20846.000000
# Yuba           9364.000000
# Yuma          47723.179306
# Zapata         3732.000000
# Name: Total Number of Occupied Beds, Length: 1705, dtype: float64

# %%
# country wise total number of service provider
df.groupby('County')['Provider Name'].count()
# Out:
# County
# Abbeville     130
# Acadia        650
# Accomack      130
# Ada          1998
# Adair         910
#              ...
# York         4764
# Young         390
# Yuba          130
# Yuma          817
# Zapata        130
# Name: Provider Name, Length: 1705, dtype: int64

# %%
# country where total number of staff died due to COVID-19.
df.groupby('County')['Staff Total COVID-19 Deaths'].sum()
# Out:
# County
# Abbeville      0.000000
# Acadia         0.000000
# Accomack       0.000000
# Ada          608.000000
# Adair        260.000000
#                 ...
# York         373.240075
# Young          0.000000
# Yuba           0.000000
# Yuma         117.840262
# Zapata         0.000000
# Name: Staff Total COVID-19 Deaths, Length: 1705, dtype: float64

# %%
# country where staff died due to COVID-1 is highest
x = df.groupby('County')['Staff Total COVID-19 Deaths'].sum().reset_index()
x.sort_values('Staff Total COVID-19 Deaths',ascending=False).head(1)
# Out:
#           County  Staff Total COVID-19 Deaths
# 908  Los Angeles                 11872.454512

# %%
# country where total number of Residents died due to COVID-19.
df.groupby('County')['Residents Total COVID-19 Deaths'].sum()
# Out:
# County
# Abbeville        0.000000
# Acadia        6599.000000
# Accomack       743.000000
# Ada           7423.000000
# Adair         7029.000000
#                  ...
# York         47482.029129
# Young         1962.000000
# Yuba           476.000000
# Yuma          8407.101950
# Zapata        3623.000000
# Name: Residents Total COVID-19 Deaths, Length: 1705, dtype: float64

# %%
# country where Residents died due to COVID-1 is highest
x = df.groupby('County')['Residents Total COVID-19 Deaths'].sum().reset_index()
x.sort_values('Residents Total COVID-19 Deaths',ascending=False).head(1)
# Out:
#           County  Residents Total COVID-19 Deaths
# 908  Los Angeles                    448349.636374

# %% [markdown]
# # Question 7- Visualize your dataset

# %%
# data size is huge and its taking long time to plot graph,
# therefore slicing the dataset to make it small
df = df[:50000]

# %%
# country wise total number of bed
plt.figure(figsize=(10,20))
x = df.groupby('County')['Number of All Beds'].sum().reset_index()

plt.barh(x['County'],x['Number of All Beds'])
plt.xticks(rotation=90)
plt.title('Using Matplotlib')
plt.show()

plt.figure(figsize=(20,10))
sns.barplot(x = x['County'],
           y = x['Number of All Beds']
           )
plt.xticks(rotation=90)
plt.title('Using seaborn')
plt.show()

# %%
# country wise total number of occiped bed
plt.figure(figsize=(10,20))
x = df.groupby('County')['Total Number of Occupied Beds'].sum().reset_index()
plt.barh(x['County'],x['Total Number of Occupied Beds'])
plt.xticks(rotation=90)
plt.title('Using Matplotlib')
plt.show()

plt.figure(figsize=(20,10))
sns.barplot(x = x['County'],
           y = x['Total Number of Occupied Beds']
           )
plt.xticks(rotation=90)
plt.title('Using seaborn')
plt.show()

# %%
# country where total number of staff died due to COVID-19.
plt.figure(figsize=(10,20))
x_staff = df.groupby('County')['Staff Total COVID-19 Deaths'].sum().reset_index()
plt.barh(x_staff['County'],x_staff['Staff Total COVID-19 Deaths'])
plt.xticks(rotation=90)
plt.title('Using Matplotlib')
plt.show()
plt.figure(figsize=(20,10))
sns.barplot(x = x_staff['County'],
           y = x_staff['Staff Total COVID-19 Deaths']
           )
plt.xticks(rotation=90)
plt.title('Using seaborn')
plt.show()

# %%
# country where total number of Residents died due to COVID-19.
plt.figure(figsize=(10,20))
x_res = df.groupby('County')['Residents Total COVID-19 Deaths'].sum().reset_index()
plt.barh(x_res['County'],x_res['Residents Total COVID-19 Deaths'])
plt.xticks(rotation=90)
plt.title('Using Matplotlib')
plt.show()
plt.figure(figsize=(20,10))
sns.barplot(x = x_res['County'],
           y = x_res['Residents Total COVID-19 Deaths']
           )
plt.xticks(rotation=90)
plt.title('Using seaborn')
plt.show()

# %%
plt.figure(figsize=(20,10))
ax = plt.axes()
plt.plot(range(len(x_staff)),x_staff['Staff Total COVID-19 Deaths'],label='Staff')
plt.plot(range(len(x_res)),x_res['Residents Total COVID-19 Deaths'],label='Residents')
ax.set_xticklabels(x_res['County'])
plt.xticks(rotation=90)
plt.legend()
plt.title('Using Matplotlib-country wise Staff vs Residents death')
plt.ylabel('count')
plt.xlabel('country')
plt.show()

plt.figure(figsize=(20,10))
ax = plt.axes()
sns.lineplot(range(len(x_staff)),x_staff['Staff Total COVID-19 Deaths'],label='staff')
sns.lineplot(range(len(x_res)),x_res['Residents Total COVID-19 Deaths'],label='Residents')
plt.legend()
plt.xticks(rotation=90)
plt.title('Using seaborn')
ax.set_xticklabels(x_res['County'])
plt.show()
