# %%
import pandas as pd

# %%
df = pd.read_csv('MPS Borough Level Crime (most recent 24 months).csv')

# %%
df['202001'].max()
# Out:
# 1550

# %%
[f['202001']== 1550]
# Out:
#                         MajorText                           MinorText  \
# 0       Arson and Criminal Damage                               Arson
# 1       Arson and Criminal Damage                     Criminal Damage
# 2                        Burglary     Burglary Business and Community
# 3                        Burglary                   Domestic Burglary
# 4                   Drug Offences                    Drug Trafficking
# ...                           ...                                 ...
# 1550             Vehicle Offences          Theft from a Motor Vehicle
# 1551             Vehicle Offences  Theft or Taking of a Motor Vehicle
# 1552  Violence Against the Person                            Homicide
# 1553  Violence Against the Person                Violence with Injury
# 1554  Violence Against the Person             Violence without Injury
#
#         LookUp_BoroughName  202001  202002  202003  202004  202005  202006  \
# ...
