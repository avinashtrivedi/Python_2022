# %%
from gensim.models import KeyedVectors
import numpy as np
from gensim.models import Word2Vec
import pandas as pd
import warnings
import os
from gensim.parsing.preprocessing import preprocess_string
warnings.filterwarnings('ignore')

class Embedding:
    
    def __init__(self,filename):
        self.word2v_file = 'w2vec_10d.txt'
        self.filename = filename
    
    def preprocessing(self):
        
        df = pd.read_csv(self.filename,sep='\t')
        t = df[df['description'].isna() == False]
        t = t[t['kw_name']!='ToBeRemoved']
        data = t.copy()
        data.reset_index(drop=True,inplace=True)
        data['product_name'] = data['product_name'].apply(lambda x:x.strip())
        data['desc_and_productname'] = data['product_name'] + ' ' + data['description']
         
        all_description = []
        for description in data['desc_and_productname'].values:
            all_description.append(preprocess_string(description))
            
        return all_description
            
    def word2vec(self,list_of_string):
            
        
        if not os.path.exists(self.word2v_file):
            model = Word2Vec(list_of_string, 
                     min_count=1,   # word frequency
                     size=10,      # dimention of word embeddings
                     workers=8,     # Number of processors
                     sg=0, # sg=0 for cbow, sg=1 for skip gram
                     window=1,      # Context window
                    ) 
        
            # save
            model.wv.save_word2vec_format(self.word2v_file)
        w2v = KeyedVectors.load_word2vec_format(self.word2v_file)
        
        return w2v

# %%
embedding = Embedding('autotagger.tsv')

# %%
all_text = embedding.preprocessing()

# %%
all_text
# Out:
# [['addi',
#   'flip',
#   'black',
#   'bin',
#   'dispos',
#   'unwant',
#   'rubbish',
#   'have',
#   'touch',
#   'bin',
#   'qualiti',
#   'pedal',
#   'bin',
#   'simpli',
#   'open',
#   'foot',
#   'drop',
#   'garbag',
#   'trash',
#   'bag'],
#  ['brm',
#   'peri',
#   'peri',
#   'spatchcock',
#   'chicken',
#   'fulli',
#   'cook',
#   'nreadi',
#   'minut',
#   'ncook',
#   'tender',
#   'marin',
#   'famou',
#   'peri',
#   'peri',
#   'sauc',
#   'nkeep',
#   'refriger',
#   'nbrm',
#   'spatchcock',
#   'chicken',
#   'fulli',
#   'cook',
#   'peri',
#   'peri',
#   'sauc'],
#  ['crush', 'ginger', 'perfect', 'stew', 'curri'],
#  ['uss', 'vsop', 'cognac', 'uss', 'vsop', 'cognac'],
#  ['dettol',
#   'liquid',
#   'bathroom',
#   'cleaner',
#   'ocean',
#   'fresh',
#   'ndettol',
#   'liquid',
#   'bathroom',
#   'cleaner',
#   'ocean',
#   'fresh'],
#  ['frozen', 'mix', 'berri', 'special', 'selecet'],
#  ['glad',
#   'small',
#   'zipper',
#   'freezer',
#   'bag',
#   'glad',
#   'freezer',
#   'bag',
#   'strong',
#   'suitabl',
#   'freez',
#   'type',
#   'food',
#   'includ',
#   'bag',
#   'tie',
#   'seal',
#   'fresh',
#   'minim',
#   'freezer',
#   'burn'],
#  ['johnni', 'walker', 'black', 'label', 'whiski'],
#  ['orang', 'special', 'select'],
#  ['qualifresh', 'crush', 'garlic', 'special', 'select'],
#  ['strawberri', 'fresh'],
#  ['soft',
#   'rye',
#   'bread',
#   'soft',
#   'mild',
#   'rye',
#   'bread',
#   'wheat',
#   'flour',
#   'rye',
#   'flour',
#   'carawai',
#   'seed',
#   'sourdough',
#   'slow',
#   'ferment',
#   'result',
#   'uniqu',
#   'flavour'],
#  ['beef',
#   'rib',
#   'fulli',
#   'cook',
#   'readi',
#   'minut',
#   'cook',
#   'tender',
#   'marin',
#   'famou',
#   'sweet',
#   'sticki',
#   'bbq',
#   'bast',
#   'sauc',
#   'nkeep',
#   'refriger',
#   'premium',
#   'qualiti',
#   'beef',
#   'rib'],
#  ['pork',
#   'loin',
#   'rib',
#   'fulli',
#   'cook',
#   'readi',
#   'minut',
#   'ncook',
#   'tender',
#   'marin',
#   'famou',
#   'sweet',
#   'sticki',
#   'bbq',
#   'bast',
#   'sauc',
#   'refriger',
#   'npork',
#   'loin',
#   'babi',
#   'rib',
#   'ultim',
#   'cut',
#   'rib'],
#  ['bean',
#   'salad',
#   'punnet',
#   'salad',
#   'dish',
#   'consist',
#   'mix',
#   'piec',
#   'food',
#   'typic',
#   'raw',
#   'ingredi',
#   'dress',
#   'typic',
#   'serv',
#   'room',
#   'temperatur',
#   'chill'],
#  ['wash', 'treat', 'wash', 'treat'],
#  ['leav', 'condition', 'leav', 'condition'],
#  ['ac', 'super', 'maiz', 'meal', 'maiz', 'meal'],
#  ['adco', 'hygien', 'surfac', 'disinfect'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['addi',
#   'mini',
#   'flip',
#   'flap',
#   'bin',
#   'dispos',
#   'unwant',
#   'rubbish',
#   'have',
#   'touch',
#   'bin',
#   'qualiti',
#   'pedal',
#   'bin',
#   'simpli',
#   'open',
#   'foot',
#   'drop',
#   'garbag',
#   'trash',
#   'bag'],
#  ['addi',
#   'dish',
#   'terri',
#   'towel',
#   'wash',
#   'wipe',
#   'dry',
#   'dust',
#   'us',
#   'chemic',
#   'nthe',
#   'microfib',
#   'dirt',
#   'attract',
#   'hold',
#   'seven',
#   'time',
#   'weight',
#   'dirt',
#   'grime',
#   'liquid',
#   'super',
#   'absorb',
#   'leav',
#   'lint',
#   'streak',
#   'safe',
#   'us',
#   'surfac',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['addi',
#   'dustpan',
#   'brush',
#   'blue',
#   'set',
#   'addi',
#   'dustpan',
#   'brush',
#   'set',
#   'nour',
#   'brush',
#   'scrub',
#   'finest',
#   'bristl',
#   'special',
#   'design',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nwhat',
#   'box',
#   'dustpan',
#   'brush',
#   'nfeatur',
#   'finest',
#   'bristl',
#   'make',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nspecif',
#   'colour',
#   'blue',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'dustpan',
#   'brush',
#   'granit',
#   'set',
#   'addi',
#   'dustpan',
#   'brush',
#   'set',
#   'nour',
#   'brush',
#   'scrub',
#   'finest',
#   'bristl',
#   'special',
#   'design',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nwhat',
#   'box',
#   'dustpan',
#   'brush',
#   'nfeatur',
#   'finest',
#   'bristl',
#   'make',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nspecif',
#   'colour',
#   'blue',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'floor',
#   'broom',
#   'addi',
#   'floor',
#   'broom',
#   'natur',
#   'nfloor',
#   'broom',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nfeatur',
#   'handl',
#   'includ',
#   'metal',
#   'hanger',
#   'easi',
#   'storag',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nspecif',
#   'materi',
#   'plastic',
#   'colour',
#   'natur',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'floor',
#   'broom',
#   'addi',
#   'floor',
#   'broom',
#   'natur',
#   'nfloor',
#   'broom',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nfeatur',
#   'handl',
#   'includ',
#   'metal',
#   'hanger',
#   'easi',
#   'storag',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nspecif',
#   'materi',
#   'plastic',
#   'colour',
#   'natur',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'floor',
#   'polish',
#   'brush',
#   'select',
#   'clean',
#   'brush',
#   'help',
#   'deal',
#   'grime',
#   'germ',
#   'home',
#   'fresh',
#   'clean'],
#  ['addi',
#   'granit',
#   'toilet',
#   'brush',
#   'set',
#   'brush',
#   'scrub',
#   'finest',
#   'bristl',
#   'special',
#   'design',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'clean',
#   'toilet',
#   'eas'],
#  ['addi',
#   'gutter',
#   'sweeper',
#   'pvc',
#   'pvc',
#   'ngutter',
#   'sweeper',
#   'nhard',
#   'broom',
#   'exterior',
#   'us'],
#  ['addi',
#   'laundri',
#   'basket',
#   'grei',
#   'steel',
#   'addi',
#   'slot',
#   'laundri',
#   'basket',
#   'grei',
#   'nwhen',
#   'wash',
#   'mop',
#   'soak',
#   'dai',
#   'addi',
#   'water',
#   'support',
#   'team',
#   'matter',
#   'hard',
#   'chore',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'colour',
#   'grei',
#   'dimens',
#   'weight'],
#  ['addi',
#   'mop',
#   'addi',
#   'anti',
#   'bacteri',
#   'mop',
#   'nwelcom',
#   'futur',
#   'love',
#   'clean',
#   'latest',
#   'technolog',
#   'smartest',
#   'idea',
#   'bring',
#   'innov',
#   'home',
#   'clean',
#   'solut',
#   'help',
#   'quick',
#   'easi',
#   'thorough',
#   'clean',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['addi',
#   'mop',
#   'addi',
#   'anti',
#   'bacteri',
#   'mop',
#   'nwelcom',
#   'futur',
#   'love',
#   'clean',
#   'latest',
#   'technolog',
#   'smartest',
#   'idea',
#   'bring',
#   'innov',
#   'home',
#   'clean',
#   'solut',
#   'help',
#   'quick',
#   'easi',
#   'thorough',
#   'clean',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['addi',
#   'terri',
#   'swab',
#   'addi',
#   'microfib',
#   'terri',
#   'swab',
#   'super',
#   'absorb',
#   'hold',
#   'time',
#   'weight',
#   'water',
#   'dirt',
#   'grime',
#   'open',
#   'space',
#   'fiber',
#   'hold',
#   'dust',
#   'dirt',
#   'oil',
#   'wash',
#   'mild',
#   'soap',
#   'deterg',
#   'clean',
#   'method',
#   'environment',
#   'friendli'],
#  ['addi',
#   'wet',
#   'mop',
#   'addi',
#   'wet',
#   'mop',
#   'nwelcom',
#   'futur',
#   'love',
#   'clean',
#   'latest',
#   'technolog',
#   'smartest',
#   'idea',
#   'bring',
#   'innov',
#   'home',
#   'clean',
#   'solut',
#   'help',
#   'quick',
#   'easi',
#   'thorough',
#   'clean',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['airmun',
#   'effervesc',
#   'tablet',
#   'airmun',
#   'combin',
#   'healthi',
#   'diet',
#   'support',
#   'immun'],
#  ['airwav',
#   'blackcurr',
#   'flavour',
#   'sugar',
#   'free',
#   'gum',
#   'chew',
#   'sugar',
#   'free',
#   'gum',
#   'eat',
#   'drink',
#   'increas',
#   'product',
#   'saliva',
#   'increas',
#   'saliva',
#   'flow',
#   'help',
#   'neutralis',
#   'plaqu',
#   'acid',
#   'help',
#   'maintain',
#   'tooth',
#   'mineralis',
#   'help',
#   'reduc',
#   'oral',
#   'dryness'],
#  ['airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'lavend',
#   'xml',
#   'airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'lavend',
#   'xml'],
#  ['airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'turquois',
#   'oasi',
#   'xml',
#   'airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'turquois',
#   'oasi',
#   'xml'],
#  ['albani',
#   'hotdog',
#   'brown',
#   'roll',
#   'brown',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer'],
#  ['albani',
#   'hotdog',
#   'brown',
#   'roll',
#   'brown',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer'],
#  ['albani',
#   'hotdog',
#   'brown',
#   'roll',
#   'brown',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer'],
#  ['albani',
#   'superior',
#   'best',
#   'white',
#   'bread',
#   'albani',
#   'offer',
#   'comprehens',
#   'rang',
#   'bake',
#   'good',
#   'south',
#   'africa',
#   'option',
#   'famili',
#   'member',
#   'individual’',
#   'tast',
#   'lifestyl',
#   'nalbani',
#   'deliv',
#   'longer',
#   'last',
#   'fresh',
#   'bigger',
#   'consist',
#   'slice',
#   'better',
#   'textur',
#   'innov',
#   'packag',
#   'superior',
#   'qualiti',
#   'ngreat',
#   'tast',
#   'meet',
#   'balanc',
#   'lifestyl',
#   'albani',
#   'ultima',
#   'health',
#   'rang',
#   'avail',
#   'multigrain',
#   'brown',
#   'bread',
#   'rooibo',
#   'rye',
#   'brown',
#   'bread',
#   'approv',
#   'heart',
#   'stroke',
#   'foundat',
#   'it’',
#   'ultim',
#   'heart',
#   'smart',
#   'choic'],
#  ['albani',
#   'superior',
#   'best',
#   'white',
#   'bread',
#   'albani',
#   'offer',
#   'comprehens',
#   'rang',
#   'bake',
#   'good',
#   'south',
#   'africa',
#   'option',
#   'famili',
#   'member',
#   'individual’',
#   'tast',
#   'lifestyl',
#   'nalbani',
#   'deliv',
#   'longer',
#   'last',
#   'fresh',
#   'bigger',
#   'consist',
#   'slice',
#   'better',
#   'textur',
#   'innov',
#   'packag',
#   'superior',
#   'qualiti',
#   'ngreat',
#   'tast',
#   'meet',
#   'balanc',
#   'lifestyl',
#   'albani',
#   'ultima',
#   'health',
#   'rang',
#   'avail',
#   'multigrain',
#   'brown',
#   'bread',
#   'rooibo',
#   'rye',
#   'brown',
#   'bread',
#   'approv',
#   'heart',
#   'stroke',
#   'foundat',
#   'it’',
#   'ultim',
#   'heart',
#   'smart',
#   'choic'],
#  ['albani',
#   'superior',
#   'brown',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'brown',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'low',
#   'slice',
#   'brown',
#   'seed',
#   'bread',
#   'seed',
#   'pack',
#   'wholewheat',
#   'loaf',
#   'high',
#   'fibr',
#   'load',
#   'energi',
#   'long',
#   'last',
#   'fresh'],
#  ['albani',
#   'superior',
#   'low',
#   'slice',
#   'brown',
#   'seed',
#   'bread',
#   'seed',
#   'pack',
#   'wholewheat',
#   'loaf',
#   'high',
#   'fibr',
#   'load',
#   'energi',
#   'long',
#   'last',
#   'fresh'],
#  ['albani',
#   'superior',
#   'low',
#   'slice',
#   'brown',
#   'seed',
#   'bread',
#   'seed',
#   'pack',
#   'wholewheat',
#   'loaf',
#   'high',
#   'fibr',
#   'load',
#   'energi',
#   'long',
#   'last',
#   'fresh'],
#  ['albani',
#   'superior',
#   'low',
#   'white',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'low',
#   'white',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'roll',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'roll',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'wheat',
#   'brown',
#   'bread',
#   'low',
#   'bake',
#   'famili',
#   'mind',
#   'understand',
#   'import',
#   'feel',
#   'fuller',
#   'longer',
#   'help',
#   'prevent',
#   'energi',
#   '‘high',
#   'lows’',
#   'wholewheat',
#   'brown',
#   'bread',
#   'high',
#   'fibr',
#   'help',
#   'famili',
#   'regular',
#   'healthi',
#   'provid',
#   'dai',
#   'energi',
#   'accomplish',
#   'dai',
#   'task'],
#  ['albani',
#   'superior',
#   'wheat',
#   'brown',
#   'bread',
#   'low',
#   'bake',
#   'famili',
#   'mind',
#   'understand',
#   'import',
#   'feel',
#   'fuller',
#   'longer',
#   'help',
#   'prevent',
#   'energi',
#   '‘high',
#   'lows’',
#   'wholewheat',
#   'brown',
#   'bread',
#   'high',
#   'fibr',
#   'help',
#   'famili',
#   'regular',
#   'healthi',
#   'provid',
#   'dai',
#   'energi',
#   'accomplish',
#   'dai',
#   'task'],
#  ['albani',
#   'superior',
#   'wheat',
#   'brown',
#   'bread',
#   'low',
#   'bake',
#   'famili',
#   'mind',
#   'understand',
#   'import',
#   'feel',
#   'fuller',
#   'longer',
#   'help',
#   'prevent',
#   'energi',
#   '‘high',
#   'lows’',
#   'wholewheat',
#   'brown',
#   'bread',
#   'high',
#   'fibr',
#   'help',
#   'famili',
#   'regular',
#   'healthi',
#   'provid',
#   'dai',
#   'energi',
#   'accomplish',
#   'dai',
#   'task'],
#  ['albani',
#   'tinki',
#   'strawberri',
#   'tingl',
#   'flavour',
#   'creami',
#   'spong',
#   'cake'],
#  ['albani',
#   'ultima',
#   'brown',
#   'bread',
#   'multigrain',
#   'multigrain',
#   'brown',
#   'high',
#   'fibr'],
#  ['albani',
#   'ultima',
#   'brown',
#   'kilojoul',
#   'control',
#   'bread',
#   'comprehens',
#   'rang',
#   'health',
#   'bread',
#   'provid',
#   'smart',
#   'carb',
#   'choic',
#   'rooibo',
#   'rye',
#   'brown',
#   'high',
#   'antioxid',
#   'vitamin',
#   'multigrain',
#   'brown',
#   'high',
#   'fibr',
#   'low',
#   'sustain',
#   'energi',
#   'kilojoul',
#   'control',
#   'brown',
#   'bread',
#   'low',
#   'fat',
#   'high',
#   'fibr',
#   'endors',
#   'heart',
#   'stroke',
#   'foundat',
#   'diabet'],
#  ['albani',
#   'ultima',
#   'brown',
#   'kilojoul',
#   'control',
#   'bread',
#   'comprehens',
#   'rang',
#   'health',
#   'bread',
#   'provid',
#   'smart',
#   'carb',
#   'choic',
#   'rooibo',
#   'rye',
#   'brown',
#   'high',
#   'antioxid',
#   'vitamin',
#   'multigrain',
#   'brown',
#   'high',
#   'fibr',
#   'low',
#   'sustain',
#   'energi',
#   'kilojoul',
#   'control',
#   'brown',
#   'bread',
#   'low',
#   'fat',
#   'high',
#   'fibr',
#   'endors',
#   'heart',
#   'stroke',
#   'foundat',
#   'diabet'],
#  ['albani',
#   'ultima',
#   'rooibo',
#   'rye',
#   'brown',
#   'bread',
#   'albani',
#   'freshli',
#   'bake',
#   'bread',
#   'nrooibo',
#   'rye',
#   'brown',
#   'bread'],
#  ['albani',
#   'valu',
#   'pack',
#   'brown',
#   'bread',
#   'slice',
#   'love',
#   'albany’',
#   'new',
#   'everydai',
#   'toaster',
#   'bread'],
#  ['albani',
#   'valu',
#   'pack',
#   'white',
#   'bread',
#   'slice',
#   'love',
#   'albany’',
#   'new',
#   'everydai',
#   'toaster',
#   'bread'],
#  ['allergex',
#   'non',
#   'drowsi',
#   'syrup',
#   'allergex',
#   'non',
#   'drowsi',
#   'relief',
#   'symptom',
#   'associ',
#   'allerg',
#   'rhiniti',
#   'sneez',
#   'rhinorrhea',
#   'runni',
#   'nose',
#   'itch',
#   'nose',
#   'throat',
#   'indic',
#   'relief',
#   'chronic',
#   'idiopath',
#   'urticaria',
#   'hive',
#   'allerg',
#   'dermatos',
#   'allerg',
#   'skin',
#   'reaction'],
#  ['almond',
#   'breez',
#   'milk',
#   'unsweeten',
#   'won',
#   'milk',
#   'almond',
#   'hand',
#   'best',
#   'qualiti',
#   'unsweet',
#   'milk',
#   'altern',
#   'almond',
#   'milk'],
#  ['everydai',
#   'liner',
#   'larg',
#   'unscent',
#   'odour',
#   'protect',
#   'nodour',
#   'neutral',
#   'technolog',
#   'feel',
#   'fresh',
#   'confid',
#   'dai',
#   'npanti',
#   'liner',
#   'protect',
#   'zone',
#   'improv',
#   'leakag',
#   'protect',
#   'soft',
#   'topsheet',
#   'ad',
#   'absorpt',
#   'comfort',
#   'soft',
#   'npanti',
#   'liner',
#   'dermatolog',
#   'test',
#   'gentl',
#   'skin'],
#  ['maxi',
#   'long',
#   'plu',
#   'duo',
#   'pad',
#   'maxi',
#   'sanitari',
#   'pad',
#   'feel',
#   'comfort',
#   'dai'],
#  ['maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'feel',
#   'comfort',
#   'night'],
#  ['maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'feel',
#   'comfort',
#   'night'],
#  ['maxi', 'night', 'sanitari', 'pad', 'leakag', 'protect'],
#  ['maxi',
#   'normal',
#   'sanitari',
#   'pad',
#   'maxi',
#   'hygien',
#   'pad',
#   'design',
#   'fit',
#   'curv',
#   'allow',
#   'help',
#   'protect',
#   'leak',
#   'sanitari',
#   'pad',
#   'featur',
#   'leakguard',
#   'core',
#   'plu',
#   'barrier',
#   'pull',
#   'fluid',
#   'deep',
#   'core',
#   'awai',
#   'edg',
#   'cotton',
#   'like',
#   'dri',
#   'weav',
#   'cover',
#   'clean',
#   'dry',
#   'protect',
#   'nmaximum',
#   'protect',
#   'sanitari',
#   'pad',
#   'size',
#   'wider',
#   'coverag',
#   'regular',
#   'long',
#   'super',
#   'overnight',
#   'hygien',
#   'pad',
#   'sanitari',
#   'pad',
#   'sign',
#   'protect',
#   'pad',
#   'best',
#   'protect',
#   'nactipearl',
#   'neutral',
#   'odour',
#   'mask',
#   'nsecur',
#   'guard',
#   'protect',
#   'contour',
#   'keep',
#   'fluid',
#   'check',
#   'nstai',
#   'wing',
#   'doubl',
#   'curv',
#   'wing',
#   'pad',
#   'place',
#   'ncotton',
#   'like',
#   'feel',
#   'sheet',
#   'super',
#   'soft',
#   'skin',
#   'nsuper',
#   'absorb',
#   'core',
#   'lock',
#   'fluid',
#   'awai'],
#  ['ultra',
#   'cotton',
#   'soft',
#   'normal',
#   'sanitari',
#   'pad',
#   'pad',
#   'safe',
#   'reliabl',
#   'materi',
#   'ultim',
#   'protect',
#   'comfort',
#   'sacrif',
#   'health',
#   'safeti',
#   'pad',
#   'trust',
#   'million',
#   'women',
#   'found'],
#  ['ultra',
#   'normal',
#   'sanitari',
#   'pad',
#   'ultra',
#   'extra',
#   'absorb',
#   'normal',
#   'sanitari',
#   'pad',
#   'wing',
#   'valu',
#   'pack'],
#  ['ultra',
#   'sanitari',
#   'night',
#   'pad',
#   'night',
#   'leakag',
#   'protect',
#   'anti',
#   'leakag',
#   'barrier',
#   'round',
#   'protect',
#   'leak'],
#  ['ultra',
#   'long',
#   'sanitari',
#   'pad',
#   'pad',
#   'safe',
#   'reliabl',
#   'materi',
#   'ultim',
#   'protect',
#   'comfort',
#   'sacrif',
#   'health',
#   'safeti',
#   'pad',
#   'trust',
#   'million',
#   'women',
#   'found'],
#  ['amaren', 'mix', 'berri'],
#  ['amaz', 'ball', 'coconut', 'amaz'],
#  ['amaz', 'ball', 'pretzel', 'amaz'],
#  ['amstel',
#   'lager',
#   'can',
#   'distinguish',
#   'ancestri',
#   'amstel',
#   'lager',
#   'began',
#   'friendship',
#   'dedic',
#   'develop',
#   'better',
#   'beer',
#   'amstel',
#   'set',
#   'bar',
#   'consist',
#   'high',
#   'qualiti',
#   'defin',
#   'premium',
#   'beer',
#   'south',
#   'africa',
#   'green',
#   'bottl',
#   'produc'],
#  ['annabel', 'cuvé', 'blanch', 'annabel', 'cuvé'],
#  ['appl',
#   'golden',
#   'delici',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['appl',
#   'granni',
#   'smith',
#   'granni',
#   'smith',
#   'appl',
#   'famou',
#   'sour',
#   'green',
#   'appl',
#   'flavor',
#   'strong',
#   'tart',
#   'flavor',
#   'bright',
#   'acid',
#   'tang',
#   'appl',
#   'incred',
#   'crisp',
#   'firm',
#   'juici'],
#  ['appl',
#   'red',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'sparkl',
#   'appletis',
#   'crisp',
#   'tast',
#   'enjoi',
#   'moment',
#   'nno',
#   'preserv'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'quench',
#   'thirst',
#   'amaz',
#   'appl',
#   'flavour',
#   'tiser'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'quench',
#   'thirst',
#   'amaz',
#   'appl',
#   'flavour',
#   'pack',
#   'tiser'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'quench',
#   'thirst',
#   'amaz',
#   'appl',
#   'flavour',
#   'tiser'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['aquafresh',
#   'littl',
#   'teeth',
#   'toothpast',
#   'aquafresh',
#   'help',
#   'defend',
#   'teeth',
#   'caviti',
#   'plaqu',
#   'regular',
#   'brush'],
#  ['aquel',
#   'natur',
#   'sparkl',
#   'spring',
#   'water',
#   'quench',
#   'thirst',
#   'amaz',
#   'sparkl',
#   'water',
#   'aquel'],
#  ['aquel',
#   'natur',
#   'sparkl',
#   'spring',
#   'water',
#   'quench',
#   'thirst',
#   'amaz',
#   'sparkl',
#   'water',
#   'aquel'],
#  ['aquel',
#   'natur',
#   'sparkl',
#   'spring',
#   'water',
#   'quench',
#   'thirst',
#   'amaz',
#   'sparkl',
#   'water',
#   'aquel'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'nenjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'sparkl',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'sparkl',
#   'water',
#   'litchi',
#   'like',
#   'refresh',
#   'burst',
#   'flavour',
#   'try',
#   'litchi',
#   'flavour',
#   'sparkl',
#   'water'],
#  ['aquel',
#   'sparkl',
#   'water',
#   'litchi',
#   'like',
#   'refresh',
#   'burst',
#   'flavour',
#   'try',
#   'litchi',
#   'flavour',
#   'sparkl',
#   'water'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['ariel',
#   'auto',
#   'deterg',
#   'capsul',
#   'ariel',
#   'pod',
#   'wash',
#   'capsul',
#   'come',
#   'multi',
#   'compart',
#   'design',
#   'keep',
#   'ingredi',
#   'separ',
#   'reach',
#   'wash',
#   'pack',
#   'super',
#   'concentr',
#   'clean',
#   'power',
#   'littl',
#   'pod',
#   'innov',
#   'film',
#   'dissolv',
#   'contact',
#   'water',
#   'releas',
#   'power',
#   'stain',
#   'remov',
#   'technolog'],
#  ['ariel',
#   'auto',
#   'concentr',
#   'wash',
#   'liquid',
#   'us',
#   'ariel',
#   'auto',
#   'wash',
#   'liquid',
#   'great',
#   'stain',
#   'fight',
#   'power',
#   'wash',
#   'litr',
#   'liquid',
#   'wash',
#   'powder',
#   'ariel',
#   'matic',
#   'powder'],
#  ['ariel', 'automat', 'anti', 'germ', 'wash', 'powder', 'ariel'],
#  ['ariel',
#   'automat',
#   'wash',
#   'liquid',
#   'ariel',
#   'wash',
#   'liquid',
#   'pre',
#   'treat',
#   'cap',
#   'give',
#   'outstand',
#   'stain',
#   'remov',
#   'wash'],
#  ['ariel',
#   'downi',
#   'auto',
#   'wash',
#   'powder',
#   'ariel',
#   'touch',
#   'fresh',
#   'downi',
#   'long',
#   'last',
#   'fresh',
#   'impecc',
#   'clean',
#   'wash'],
#  ['ariel',
#   'power',
#   'capsul',
#   'deterg',
#   'need',
#   'concentr',
#   'laundri',
#   'solut',
#   'innov',
#   'give',
#   'outstand',
#   'stain',
#   'remov',
#   'time',
#   'ariel',
#   'pod',
#   'need',
#   'wash',
#   'capsul',
#   'brows',
#   'power',
#   'pod',
#   'learn',
#   'dose',
#   'write',
#   'review',
#   'share',
#   'wash',
#   'capsul',
#   'experi',
#   'ariel',
#   'user'],
#  ['aspen', 'brooklax', 'lax', 'pack', 'relief', 'occasion', 'constip'],
#  ['blend',
#   'canola',
#   'oliv',
#   'oil',
#   'blend',
#   'canola',
#   'oliv',
#   'oil',
#   'best',
#   'choic',
#   'want',
#   'healthier'],
#  ['canola',
#   'mayo',
#   'reduc',
#   'oil',
#   'low',
#   'oil',
#   'mayonnais',
#   'reduc',
#   'fat',
#   'content',
#   'delici',
#   'concern',
#   'waistlin',
#   'choos',
#   'healthier',
#   'life',
#   'suitabl',
#   'enjoi',
#   'uniqu',
#   'benefit',
#   'except',
#   'function',
#   'mayonnais',
#   'wise',
#   'choic'],
#  ['canola', 'oil', 'canola', 'oil', 'healthier', 'option', 'satur', 'fat'],
#  ['canola', 'oil', 'canola', 'oil', 'healthier', 'option', 'satur', 'fat'],
#  ['canola',
#   'creami',
#   'mayo',
#   'like',
#   'tast',
#   'healthi',
#   'mayonnais',
#   'stimul',
#   'tast',
#   'bud'],
#  ['pure',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'extra',
#   'virgin',
#   'oil',
#   'contain',
#   'natur',
#   'vitamin',
#   'antioxid',
#   'oliv',
#   'high',
#   'monounsatur',
#   'fat',
#   'content',
#   'make',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'smart',
#   'choic',
#   'health'],
#  ['pure',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'extra',
#   'virgin',
#   'oil',
#   'contain',
#   'natur',
#   'vitamin',
#   'antioxid',
#   'oliv',
#   'high',
#   'monounsatur',
#   'fat',
#   'content',
#   'make',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'smart',
#   'choic',
#   'health'],
#  ['babi',
#   'butternut',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['babi',
#   'dove',
#   'rich',
#   'moistur',
#   'babi',
#   'soap',
#   'formul',
#   'moisturis',
#   'cream',
#   'hypoallergen',
#   'nourish',
#   'babi',
#   'bar',
#   'care',
#   'baby’',
#   'skin',
#   'suitabl',
#   'daili',
#   'us'],
#  ['babi',
#   'dove',
#   'rich',
#   'moistur',
#   'babi',
#   'soap',
#   'formul',
#   'moisturis',
#   'cream',
#   'hypoallergen',
#   'nourish',
#   'babi',
#   'bar',
#   'care',
#   'baby’',
#   'skin',
#   'suitabl',
#   'daili',
#   'us'],
#  ['babi',
#   'potato',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'white',
#   'ply',
#   'toilet',
#   'paper',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['bacardi', 'spice', 'spirit', 'aperitif', 'rum', 'bottl', 'rum'],
#  ['bake', 'vanilla', 'cupcak', 'bake'],
#  ['baker',
#   'betta',
#   'snack',
#   'caramel',
#   'chocol',
#   'wholewheat',
#   'digest',
#   'biscuit',
#   'betta',
#   'snack',
#   'caramel',
#   'choc',
#   'flavour',
#   'biscuit',
#   'grain',
#   'snack',
#   'easi',
#   'digest',
#   'good',
#   'stomach',
#   'sweet',
#   'fresh',
#   'crunchi',
#   'best',
#   'snack',
#   'bui',
#   'monei',
#   'tast',
#   'bud',
#   'ask'],
#  ['baker',
#   'betta',
#   'snack',
#   'milk',
#   'chocol',
#   'wholewheat',
#   'digest',
#   'biscuit',
#   'sun',
#   'drench',
#   'wheat',
#   'golden',
#   'syrup',
#   'origin',
#   'baker',
#   'digest',
#   'cooki',
#   'irresist'],
#  ['baker',
#   'blue',
#   'label',
#   'mari',
#   'biscuit',
#   'nthese',
#   'mari',
#   'biscuit',
#   'bake',
#   'origin',
#   'best',
#   'wai',
#   'us',
#   'base',
#   'fridg',
#   'tart',
#   'cheesecak',
#   'mash',
#   'baby’',
#   'tast',
#   'sweet',
#   'solid',
#   'simpli',
#   'enjoi',
#   'mari',
#   'biscuit',
#   'firm',
#   'favourit',
#   'tea'],
#  ['baker',
#   'blue',
#   'label',
#   'mari',
#   'biscuit',
#   'nthese',
#   'mari',
#   'biscuit',
#   'bake',
#   'origin',
#   'best',
#   'wai',
#   'us',
#   'base',
#   'fridg',
#   'tart',
#   'cheesecak',
#   'mash',
#   'baby’',
#   'tast',
#   'sweet',
#   'solid',
#   'simpli',
#   'enjoi',
#   'mari',
#   'biscuit',
#   'firm',
#   'favourit',
#   'tea'],
#  ['baker',
#   'chees',
#   'mini',
#   'cheddar',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'chees',
#   'mini',
#   'cheddar',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'choc',
#   'kit',
#   'chocol',
#   'oat',
#   'biscuit',
#   'crispi',
#   'golden',
#   'biscuit',
#   'fill',
#   'benefit',
#   'wheat',
#   'oat',
#   'sprinkl',
#   'coconut',
#   'winner',
#   'crispi',
#   'golden',
#   'biscuit',
#   'fill',
#   'benefit',
#   'wheat',
#   'oat',
#   'sprinkl',
#   'coconut',
#   'winner'],
#  ['baker',
#   'choic',
#   'assort',
#   'biscuit',
#   'delici',
#   'baker',
#   'red',
#   'label',
#   'lemon',
#   'cream',
#   'jam',
#   'fill',
#   'baker',
#   'strawberri',
#   'whirl',
#   'perfect',
#   'afternoon',
#   'tea',
#   'time'],
#  ['baker',
#   'cream',
#   'cracker',
#   'valu',
#   'pack',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'eet',
#   'sum',
#   'mor',
#   'choc',
#   'chip',
#   'quick',
#   'snack',
#   'lunch',
#   'choc',
#   'chip',
#   'want'],
#  ['baker',
#   'eet',
#   'sum',
#   'mor',
#   'shortbread',
#   'biscuit',
#   'baker',
#   'eet',
#   'sum',
#   'mor',
#   'shortbread',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'fruit',
#   'chutnei',
#   'mini',
#   'cheddar',
#   'pack',
#   'neach',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'good',
#   'morn',
#   'milk',
#   'cereal',
#   'biscuit',
#   'great',
#   'morn',
#   'snack',
#   'busi',
#   'dai'],
#  ['baker',
#   'good',
#   'morn',
#   'peach',
#   'apricot',
#   'breakfast',
#   'biscuit',
#   'baker',
#   'good',
#   'morn',
#   'provid',
#   'sourc',
#   'fibr',
#   'contain',
#   'wheat',
#   'barlei',
#   'oat',
#   'rye',
#   'lot',
#   'energi',
#   'good',
#   'start'],
#  ['baker',
#   'gossip',
#   'strawberri',
#   'baker',
#   'gossip',
#   'wafer',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'jolli',
#   'jammer',
#   'choc',
#   'cream',
#   'delici',
#   'butteri',
#   'biscuit',
#   'choc',
#   'cream',
#   'sandiwch',
#   'delight',
#   'smilei',
#   'face',
#   'bring',
#   'joi',
#   'sweet',
#   'treat'],
#  ['baker',
#   'mini',
#   'biscuit',
#   'zoofari',
#   'kid',
#   'biscuit',
#   'great',
#   'quick',
#   'snack',
#   'school'],
#  ['baker',
#   'mini',
#   'biscuit',
#   'zoofari',
#   'kid',
#   'biscuit',
#   'great',
#   'quick',
#   'snack',
#   'school'],
#  ['baker',
#   'mini',
#   'biscuit',
#   'zoofari',
#   'kid',
#   'biscuit',
#   'great',
#   'quick',
#   'snack',
#   'school'],
#  ['baker',
#   'mini',
#   'eet',
#   'sum',
#   'mor',
#   'biscuit',
#   'baker',
#   'eet',
#   'sum',
#   'mor',
#   'shortbread',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'provita',
#   'wheat',
#   'crispbread',
#   'health',
#   'focus',
#   'delici',
#   'high',
#   'fibr',
#   'low',
#   'biscuit',
#   'calori',
#   'serv',
#   'perfect',
#   'like',
#   'smash',
#   'avo',
#   'lick',
#   'creami',
#   'peanut',
#   'butter'],
#  ['baker',
#   'romani',
#   'cream',
#   'classic',
#   'chocol',
#   'biscuit',
#   'baker',
#   'romani',
#   'cream',
#   'classic',
#   'chocol',
#   'biscuit',
#   'best',
#   'ingredi',
#   'childhood',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'strawberri',
#   'vanilla',
#   'whirl',
#   'biscuit',
#   'baker',
#   'strawberri',
#   'vanilla',
#   'flavour',
#   'whirl',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['beacon', 'mmmmallow', 'milk', 'chocol', 'mallow', 'egg', 'pack', 'egg'],
#  ['beef',
#   'biltong',
#   'beef',
#   'biltong',
#   'tradit',
#   'south',
#   'african',
#   'recip',
#   'mildli',
#   'spice',
#   'biltong',
#   'rich',
#   'meati',
#   'flavour',
#   'subtl',
#   'underton',
#   'coriand'],
#  ['beef', 'bone', 'avg', 'beef'],
#  ['beef', 'chuck', 'avg', 'fresh', 'beef', 'meat'],
#  ['beef', 'chuck', 'avg', 'fresh', 'beef', 'meat'],
#  ['beef', 'chuck', 'avg', 'fresh', 'beef', 'meat'],
#  ['beef',
#   'dry',
#   'wor',
#   'biltong',
#   'drywor',
#   'tradit',
#   'ndri',
#   'cure',
#   'nthin',
#   'beef',
#   'sausag',
#   'nspice',
#   'season',
#   'flavour',
#   'perfect',
#   'nseason',
#   'delici',
#   'tradit',
#   'recip'],
#  ['beef',
#   'liver',
#   'avg',
#   'beef',
#   'liver',
#   'special',
#   'select',
#   'flavour',
#   'tender',
#   'nthi',
#   'random',
#   'mass',
#   'product',
#   'averag',
#   'mass',
#   'displai'],
#  ['beef', 'short', 'rib', 'avg', 'beef'],
#  ['beef', 'short', 'rib', 'avg', 'beef'],
#  ['beef', 'short', 'rib', 'avg', 'beef'],
#  ['beefeat',
#   'gin',
#   'blood',
#   'orang',
#   'beefeat',
#   'blood',
#   'orang',
#   'london',
#   'dry',
#   'gin'],
#  ['beetroot',
#   'salad',
#   'punnet',
#   'home',
#   'plant',
#   'base',
#   'recip',
#   'beetroot',
#   'salad',
#   'njump',
#   'recipe·print',
#   'recip',
#   'nthi',
#   'healthi',
#   'nutriti',
#   'raw',
#   'vegan',
#   'beetroot',
#   'salad',
#   'quick',
#   'easi',
#   'make',
#   'delici',
#   'plant',
#   'base',
#   'salad',
#   'spring',
#   'summer',
#   'light',
#   'simpl',
#   'beetroot',
#   'feta',
#   'salad',
#   'balsam',
#   'dress',
#   'spiralis',
#   'fresh',
#   'beetroot',
#   'vegan',
#   'feta',
#   'chees',
#   'pepita'],
#  ['belgravia', 'london', 'dry', 'gin'],
#  ['belgravia', 'non', 'alcohol', 'gin', 'dry', 'lemon', 'non', 'alcohol'],
#  ['belgravia', 'non', 'alcohol', 'gin', 'tonic', 'non', 'alcohol'],
#  ['bennett',
#   'aqueou',
#   'cream',
#   'pump',
#   'fragranc',
#   'free',
#   'endors',
#   'dermatologist',
#   'colour',
#   'fragranc',
#   'free',
#   'recommend',
#   'bath',
#   'babi',
#   'week',
#   'baby’',
#   'life',
#   'prevent',
#   'skin',
#   'dry',
#   'recommend',
#   'moisturis',
#   'baby’',
#   'skin',
#   'bath',
#   'keep',
#   'baby’',
#   'skin',
#   'soft',
#   'moist',
#   'birth'],
#  ['bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'fragranc',
#   'bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'fragranc',
#   'effect',
#   'gentl',
#   'moisturis',
#   'altern',
#   'harsh',
#   'soap',
#   'bath',
#   'babi'],
#  ['bennett',
#   'babi',
#   'aqueou',
#   'fragranc',
#   'free',
#   'cream',
#   'endors',
#   'dermatologist',
#   'colour',
#   'fragranc',
#   'free',
#   'recommend',
#   'bath',
#   'babi',
#   'week',
#   'baby’',
#   'life',
#   'prevent',
#   'skin',
#   'dry',
#   'recommend',
#   'moisturis',
#   'baby’',
#   'skin',
#   'bath',
#   'keep',
#   'baby’',
#   'skin',
#   'soft',
#   'moist',
#   'birth'],
#  ['bennett',
#   'babi',
#   'aqueou',
#   'pump',
#   'fragranc',
#   'babi',
#   'aqueou',
#   'cream',
#   'pump',
#   'fragranc',
#   'sale',
#   'nbennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'pump',
#   'fragranc',
#   'nfast',
#   'effici',
#   'deliveri',
#   'nationwid',
#   'nfree',
#   'deliveri',
#   'order',
#   'deliveri',
#   'fee',
#   'order',
#   'dai',
#   'hassl',
#   'return',
#   'polici',
#   'nmanufactur',
#   'warranti',
#   'nsecur',
#   'check',
#   'payment',
#   'option',
#   'endors',
#   'dermatologist',
#   'slightli',
#   'fragranc',
#   'babi',
#   'pink',
#   'colour',
#   'recommend',
#   'babi',
#   'month',
#   'toddler',
#   'ag',
#   'babi',
#   'sensit',
#   'easili',
#   'irrit',
#   'skin'],
#  ['bennett', 'babi', 'bum', 'cream', 'tube', 'nthe', 'bum', 'cream', 'need'],
#  ['bennett',
#   'babi',
#   'eazi',
#   'breath',
#   'kit',
#   'congest',
#   'babi',
#   'unhappi',
#   'babi'],
#  ['bennett',
#   'babi',
#   'fragranc',
#   'free',
#   'aqueou',
#   'cream',
#   'bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'altern',
#   'soap',
#   'gentli',
#   'bath',
#   'babi'],
#  ['bennett',
#   'babi',
#   'wipe',
#   'moistur',
#   'stai',
#   'wipe',
#   'us',
#   'sensit',
#   'skin',
#   'durabl',
#   'soft',
#   'good',
#   'qualiti',
#   'wet',
#   'wipe'],
#  ['bennett',
#   'famili',
#   'care',
#   'hygien',
#   'wipe',
#   'hand',
#   'surfac',
#   'sanitis',
#   'wipe',
#   'alcohol',
#   'nalso',
#   'avail',
#   'pack'],
#  ['bennett',
#   'fragranc',
#   'babi',
#   'aqueou',
#   'cream',
#   'bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'effect',
#   'moisturis',
#   'altern',
#   'soap',
#   'bath',
#   'babi'],
#  ['bennett',
#   'hair',
#   'bodi',
#   'wash',
#   'moisturis',
#   'hr',
#   'clinic',
#   'test',
#   'mild',
#   'fragranc',
#   'free',
#   'suitabl',
#   'birth'],
#  ['bennett', 'hygien', 'wipe', 'hygien', 'famili', 'care', 'wipe'],
#  ['bennett',
#   'nippl',
#   'cream',
#   'bennett',
#   'nippl',
#   'cream',
#   'breastfeed',
#   'mother',
#   'special',
#   'formul',
#   'easili',
#   'absorb',
#   'help',
#   'sooth',
#   'crack',
#   'sore',
#   'nippl',
#   'suitabl',
#   'sensit',
#   'skin',
#   'need',
#   'wash',
#   'feed',
#   'babi',
#   'clinic',
#   'test',
#   'mild',
#   'dermatolog',
#   'approv'],
#  ['bennett',
#   'salin',
#   'nose',
#   'sprai',
#   'mom',
#   'want',
#   'babi',
#   'suffer',
#   'block',
#   'nose',
#   'occur',
#   'simpli',
#   'us',
#   'bennett',
#   'salin',
#   'nose',
#   'drop'],
#  ['bennett',
#   'salin',
#   'nose',
#   'sprai',
#   'aspir',
#   'babi',
#   'healthi',
#   'cough',
#   'flu',
#   'free',
#   'bennett',
#   'salin',
#   'nose',
#   'sprai',
#   'aspir'],
#  ['bennett',
#   'wash',
#   'bodi',
#   'hair',
#   'bennett',
#   'hair',
#   'bodi',
#   'wash',
#   'mild',
#   'moisturis',
#   'formul',
#   'gentli',
#   'effect',
#   'cleans',
#   'baby’',
#   'hair',
#   'skin'],
#  ['benylin',
#   'wet',
#   'cough',
#   'mucu',
#   'benylin',
#   'wet',
#   'cough',
#   'mucu',
#   'relief',
#   'syrup',
#   'fast',
#   'act',
#   'syrup',
#   'help',
#   'silenc',
#   'hack',
#   'disrupt',
#   'cough',
#   'dai',
#   'special',
#   'formul',
#   'loosen',
#   'chest',
#   'mucu',
#   'expel',
#   'cough',
#   'provid',
#   'quick',
#   'relief',
#   'cough',
#   'catarrh'],
#  ['bepanthen',
#   'babi',
#   'ointment',
#   'bepanthen',
#   'contain',
#   'dexpanthenol',
#   'pro',
#   'vitamin',
#   'gentli',
#   'help',
#   'sensit',
#   'skin',
#   'repair',
#   'natur',
#   'protect',
#   'barrier',
#   'keep',
#   'soft',
#   'smooth',
#   'moisturis'],
#  ['bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'sooth',
#   'repair',
#   'protect',
#   'babi',
#   'sensit',
#   'skin'],
#  ['bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'sooth',
#   'repair',
#   'protect',
#   'babi',
#   'sensit',
#   'skin'],
#  ['bernini',
#   'amber',
#   'product',
#   'weight',
#   'kgproduct',
#   'dimensionsmm',
#   'ship',
#   'weight',
#   'kgship',
#   'dimensionsmm'],
#  ['berocca',
#   'boost',
#   'liquid',
#   'energi',
#   'sachet',
#   'berocca',
#   'boost',
#   'couldn',
#   'appropri',
#   'name',
#   'delici',
#   'tast',
#   'drink',
#   'contain',
#   'guarana',
#   'help',
#   'mental',
#   'physic',
#   'boost',
#   'need'],
#  ['berocca',
#   'boost',
#   'guarana',
#   'effervesc',
#   'tablet',
#   'berocca',
#   'boost',
#   'specif',
#   'tailor',
#   'vitamin',
#   'miner',
#   'supplement',
#   'help',
#   'enhanc',
#   'mental',
#   'physic',
#   'perform',
#   'taken',
#   'daili'],
#  ['berocca',
#   'boost',
#   'guarana',
#   'effervesc',
#   'tablet',
#   'berocca',
#   'boost',
#   'specif',
#   'tailor',
#   'vitamin',
#   'miner',
#   'supplement',
#   'help',
#   'enhanc',
#   'mental',
#   'physic',
#   'perform',
#   'taken',
#   'daili'],
#  ['berocca',
#   'boost',
#   'guarana',
#   'effervesc',
#   'tablet',
#   'berocca',
#   'boost',
#   'specif',
#   'tailor',
#   'vitamin',
#   'miner',
#   'supplement',
#   'help',
#   'enhanc',
#   'mental',
#   'physic',
#   'perform',
#   'taken',
#   'daili'],
#  ['berocca',
#   'multi',
#   'vitamin',
#   'effervesc',
#   'tablet',
#   'tropic',
#   'nberocca',
#   'perform',
#   'combin',
#   'vitamin',
#   'vitamin',
#   'essenti',
#   'miner',
#   'like',
#   'calcium',
#   'magnesium',
#   'zinc',
#   'work',
#   'support',
#   'mental',
#   'alert',
#   'physic',
#   'energi',
#   'dai'],
#  ['bic',
#   'classic',
#   'dispos',
#   'razer',
#   'come',
#   'pack',
#   'ndispos',
#   'shave',
#   'razor'],
#  ['bic',
#   'sensit',
#   'dispos',
#   'razor',
#   'come',
#   'pack',
#   'ndispos',
#   'sensit',
#   'razor'],
#  ['bic', 'assort', 'crystal', 'ballpoint', 'pen', 'pack', 'pen'],
#  ['bic',
#   'atlanti',
#   'medium',
#   'ballpoint',
#   'pen',
#   'black',
#   'box',
#   'medium',
#   'point',
#   'retract',
#   'ball',
#   'pen',
#   'grip',
#   'comfort',
#   'grip',
#   'cap',
#   'colour',
#   'match',
#   'ink',
#   'colour'],
#  ['bic',
#   'black',
#   'ball',
#   'point',
#   'pen',
#   'smooth',
#   'regular',
#   'write',
#   'brass',
#   'fine',
#   'point',
#   'line',
#   'width'],
#  ['bic',
#   'clic',
#   'ballpoint',
#   'pen',
#   'pack',
#   'black',
#   'medium',
#   'point',
#   'ball',
#   'pen',
#   'retract',
#   'push',
#   'button',
#   'visibl',
#   'ink',
#   'level',
#   'pocket',
#   'clip',
#   'nwhat',
#   'box',
#   'nbic',
#   'clic',
#   'medium',
#   'ballpoint',
#   'pen',
#   'black'],
#  ['bic',
#   'cristal',
#   'black',
#   'ballpoint',
#   'pen',
#   'pack',
#   'everydai',
#   'essenti',
#   'design',
#   'mind'],
#  ['bic',
#   'cristal',
#   'black',
#   'ballpoint',
#   'pen',
#   'pack',
#   'everydai',
#   'essenti',
#   'design',
#   'mind'],
#  ['bic', 'cristal', 'ball', 'pen', 'assort', 'pack', 'assort', 'pen'],
#  ['bic', 'crystal', 'fashion', 'pen', 'assort', 'pen'],
#  ['bic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'ballpoint',
#   'pen',
#   'blue',
#   'blister',
#   'pen'],
#  ['bic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'ballpoint',
#   'pen',
#   'blue',
#   'blister',
#   'pen'],
#  ['bic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'ballpoint',
#   'pen',
#   'black',
#   'classic',
#   'bic',
#   'crystal',
#   'origin',
#   'pen',
#   'world',
#   'best',
#   'sell',
#   'ballpoint',
#   'pen',
#   'nthi',
#   'medium',
#   'point',
#   'black',
#   'ink',
#   'lightweight',
#   'hexagon',
#   'pen',
#   'write',
#   'nthe',
#   'minim',
#   'design',
#   'icon',
#   'object',
#   'perman',
#   'collect',
#   'new',
#   'york',
#   'museum',
#   'modern',
#   'art',
#   'moma',
#   'mu',
#   'art',
#   'modern',
#   'pompid',
#   'centr',
#   'pari',
#   'nventil',
#   'cap',
#   'nwhat',
#   'box',
#   'nbic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'black',
#   'ballpoint',
#   'pen',
#   'pack'],
#  ['bic',
#   'evolut',
#   'origin',
#   'graphit',
#   'pencil',
#   'pen',
#   'pencil',
#   'marker',
#   'colour',
#   'correct',
#   'bic',
#   'stationeri',
#   'product',
#   'design',
#   'longest',
#   'us',
#   'meet',
#   'consum',
#   'need',
#   'school',
#   'home',
#   'offic'],
#  ['bic',
#   'firelight',
#   'pre',
#   'cut',
#   'cube',
#   'ght',
#   'braai',
#   'eas',
#   'bic',
#   'firelight',
#   'pack',
#   'pre',
#   'cut',
#   'cube',
#   'individu',
#   'wrap',
#   'foil',
#   'light',
#   'foil',
#   'low',
#   'odor',
#   'wax',
#   'base',
#   'formula',
#   'burn',
#   'minut',
#   'nwhat',
#   'box',
#   'firelight',
#   'cube'],
#  ['bic', 'kid', 'cascad', 'fibr', 'tip', 'pen', 'marker', 'pack', 'pen'],
#  ['bic',
#   'kid',
#   'evolut',
#   'tropicolour',
#   'color',
#   'pencil',
#   'colour',
#   'world',
#   'bic',
#   'colour',
#   'pencil'],
#  ['bic',
#   'metal',
#   'men',
#   'dispos',
#   'shave',
#   'razor',
#   'bic',
#   'metal',
#   'dispos',
#   'razor',
#   'pack',
#   'featur',
#   'uniqu',
#   'metal',
#   'guard',
#   'bar',
#   'protect',
#   'skin',
#   'close',
#   'comfort',
#   'shave'],
#  ['bic',
#   'metal',
#   'men',
#   'dispos',
#   'shave',
#   'razor',
#   'bic',
#   'metal',
#   'dispos',
#   'razor',
#   'pack',
#   'featur',
#   'uniqu',
#   'metal',
#   'guard',
#   'bar',
#   'protect',
#   'skin',
#   'close',
#   'comfort',
#   'shave'],
#  ['bic', 'orang', 'fine', 'ballpoint', 'pen', 'blue', 'pack', 'pen'],
#  ['bic',
#   'orang',
#   'fine',
#   'point',
#   'black',
#   'fine',
#   'point',
#   'ball',
#   'pen',
#   'ventil',
#   'cap',
#   'ideal',
#   'school',
#   'offic',
#   'home',
#   'write',
#   'ncap',
#   'ball',
#   'pen',
#   'fine',
#   'line',
#   'width',
#   'nhexagon',
#   'transpar',
#   'barrel',
#   'control',
#   'lead',
#   'level',
#   'nball',
#   'line',
#   'width',
#   'nperman',
#   'ink',
#   'nextra',
#   'strong',
#   'tungsten',
#   'carbid',
#   'ball',
#   'nwhat',
#   'box',
#   'nbic',
#   'orang',
#   'fine',
#   'ball',
#   'point',
#   'pen',
#   'black',
#   'pack'],
#  ['bic',
#   'orang',
#   'grip',
#   'fine',
#   'point',
#   'blue',
#   'fine',
#   'point',
#   'pen',
#   'pack',
#   'colour',
#   'blue'],
#  ['bic',
#   'orang',
#   'red',
#   'pen',
#   'pen',
#   'pencil',
#   'marker',
#   'colour',
#   'correct',
#   'bic',
#   'stationeri',
#   'product',
#   'design',
#   'longest',
#   'us',
#   'meet',
#   'consum',
#   'need',
#   'school',
#   'home',
#   'offic'],
#  ['bic',
#   'perman',
#   'marker',
#   'black',
#   'perman',
#   'surfac',
#   'won',
#   'dry',
#   'cap',
#   'left',
#   'week',
#   'low',
#   'odour',
#   'xylen',
#   'toluen'],
#  ['bic',
#   'perman',
#   'marker',
#   'blue',
#   'pack',
#   'blue',
#   'bic',
#   'perman',
#   'marker',
#   'rug',
#   'bullet',
#   'nib',
#   'creat',
#   'clean',
#   'line',
#   'width',
#   'nan',
#   'indel',
#   'pen',
#   'work',
#   'surfac',
#   'paper',
#   'cardboard',
#   'plastic',
#   'glass',
#   'metal',
#   'cd',
#   'nwhat',
#   'box',
#   'nbic',
#   'perman',
#   'marker',
#   'bullet',
#   'point',
#   'blue'],
#  ['bic', 'shatterproof', 'ruler', 'shaterproof', 'ruler'],
#  ['bic', 'twin', 'ladi', 'shaver', 'women'],
#  ['bic',
#   'velleda',
#   'whiteboard',
#   'fine',
#   'point',
#   'marker',
#   'whiteboard',
#   'fine',
#   'point',
#   'marker',
#   'nfeatur',
#   'pack',
#   'fix',
#   'bullet',
#   'tip',
#   'fine',
#   'line',
#   'width',
#   'low',
#   'odour',
#   'easi',
#   'eras',
#   'whiteboard',
#   'surfac'],
#  ['bio',
#   'oil',
#   'skincar',
#   'oil',
#   'natur',
#   'clinic',
#   'proven',
#   'reduc',
#   'appear',
#   'scar',
#   'stretch',
#   'mark',
#   'natur',
#   'formul',
#   'light',
#   'non',
#   'greasi',
#   'absorb',
#   'easili',
#   'boost',
#   'elast',
#   'promot',
#   'skin',
#   'regener'],
#  ['bio',
#   'oil',
#   'skincar',
#   'oil',
#   'bio',
#   'oil',
#   'world',
#   'lead',
#   'scar',
#   'stretch',
#   'mark',
#   'product'],
#  ['bio',
#   'oil',
#   'tissu',
#   'oil',
#   'bio',
#   'oil',
#   'specialist',
#   'skincar',
#   'product',
#   'formul',
#   'help',
#   'improv',
#   'appear',
#   'scar',
#   'stretch',
#   'mar',
#   'uneven',
#   'skin',
#   'tone',
#   'uniqu',
#   'formul',
#   'contain',
#   'breakthrough',
#   'ingredi',
#   'purcellin',
#   'oil™',
#   'highli',
#   'effect',
#   'ag',
#   'dehydr',
#   'skin',
#   'nvitamin',
#   'ncalendula',
#   'lavend',
#   'rosemari',
#   'chamomil',
#   'oil',
# ...
#   'greater',
#   'comfort',
#   'fit',
#   'protect'],
#  ['lil',
#   'let',
#   'smartfit',
#   'super',
#   'plu',
#   'tampon',
#   'non',
#   'applic',
#   'tampon',
#   'round',
#   'shape',
#   'smooth',
#   'cover',
#   'eas',
#   'insert'],
#  ['lil',
#   'let',
#   'smartfit',
#   'super',
#   'plu',
#   'tampon',
#   'lil',
#   'let',
#   'smartfit',
#   'non',
#   'applic',
#   'tampon',
#   'work',
#   'expand',
#   'wai',
#   'greater',
#   'comfort',
#   'fit',
#   'protect'],
#  ['lil',
#   'let',
#   'smartfit',
#   'super',
#   'tampon',
#   'lil',
#   'let',
#   'super',
#   'tampon',
#   'suitabl',
#   'medium',
#   'heavi',
#   'flow',
#   'dai'],
#  ['lil',
#   'let',
#   'smartfit',
#   'unscent',
#   'pantylin',
#   'ncushion',
#   'comfort',
#   'everydai',
#   'protect'],
#  ['lil', 'let', 'ultra', 'duo', 'pad', 'comfort', 'finest'],
#  ['lindt',
#   'le',
#   'grand',
#   'milk',
#   'hazelnut',
#   'lindt',
#   'le',
#   'grand',
#   'hazelnut',
#   'milk',
#   'chocol',
#   'passion',
#   'creat',
#   'lindt',
#   'master',
#   'swiss',
#   'chocolati',
#   'uniqu',
#   'blend',
#   'roast',
#   'nut',
#   'crunchi',
#   'caramel',
#   'nut',
#   'sliver',
#   'enrob',
#   'smooth',
#   'swiss',
#   'chocol',
#   'le',
#   'grand',
#   'irresist',
#   'crunchi'],
#  ['lion', 'match', 'unit', 'lion', 'match', 'unit'],
#  ['lipton',
#   'ic',
#   'tea',
#   'lemon',
#   'lipton',
#   'lemon',
#   'flavour',
#   'ic',
#   'tea',
#   'low',
#   'kilojoul',
#   'blend',
#   'good',
#   'tea',
#   'delici',
#   'flavour',
#   'lemon',
#   'enjoi',
#   'refresh',
#   'drink',
#   'low',
#   'calori',
#   'sugar'],
#  ['lipton', 'ic', 'tea', 'peach', 'lipton', 'ic', 'tea', 'peach'],
#  ['lipton',
#   'ic',
#   'tea',
#   'peach',
#   'lipton',
#   'peach',
#   'ic',
#   'tea',
#   'perfectli',
#   'infus',
#   'uniqu',
#   'blend',
#   'real',
#   'tea',
#   'peach',
#   'essenc',
#   'delici',
#   'tast',
#   'refresh',
#   'bodi',
#   'mind'],
#  ['lipton',
#   'ic',
#   'tea',
#   'peach',
#   'sugar',
#   'free',
#   'lipton',
#   'ic',
#   'tea',
#   'peach',
#   'sugar',
#   'free'],
#  ['lipton',
#   'peach',
#   'ic',
#   'tea',
#   'can',
#   'soft',
#   'drink',
#   'tea',
#   'extract',
#   'peach',
#   'flavour'],
#  ['liqui',
#   'fruit',
#   'berri',
#   'blaze',
#   'fruit',
#   'juic',
#   'blend',
#   'enrich',
#   'flavour',
#   'fruit',
#   'juic',
#   'blend',
#   'bring',
#   'best',
#   'natur',
#   'good'],
#  ['liqui',
#   'fruit',
#   'berri',
#   'blaze',
#   'fruit',
#   'juic',
#   'blend',
#   'enrich',
#   'flavour',
#   'fruit',
#   'juic',
#   'blend',
#   'bring',
#   'best',
#   'natur',
#   'good'],
#  ['liqui',
#   'fruit',
#   'breakfast',
#   'punch',
#   'fruit',
#   'juic',
#   'blend',
#   'liven',
#   'morn',
#   'hit',
#   'ground',
#   'run',
#   'readi',
#   'dai',
#   'pure',
#   'fruit',
#   'good',
#   'breakfast',
#   'punch',
#   'it’',
#   'refresh',
#   'mix',
#   'citru',
#   'fruit',
#   'need',
#   'stai',
#   'game'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'fruit',
#   'juic',
#   'blend',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl',
#   'it’',
#   'pure',
#   'fruit',
#   'good',
#   'perfect',
#   'wai',
#   'refresh',
#   'moment',
#   'leav',
#   'feel',
#   'invigor'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'fruit',
#   'juic',
#   'blend',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl',
#   'it’',
#   'pure',
#   'fruit',
#   'good',
#   'perfect',
#   'wai',
#   'refresh',
#   'moment',
#   'leav',
#   'feel',
#   'invigor'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'juic',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'juic',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'juic',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'clear',
#   'appl',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liqui',
#   'fruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liqui',
#   'fruit',
#   'litchi',
#   'fruit',
#   'juic',
#   'blend',
#   'nliqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'litchi',
#   'fruit',
#   'juic',
#   'blend',
#   'nliqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'long',
#   'life',
#   'orang',
#   'kick',
#   'dai',
#   'like',
#   'refresh',
#   'glass',
#   'orang',
#   'juic',
#   'treat',
#   'wholesom',
#   'good',
#   'leav',
#   'feel',
#   'good',
#   'readi',
#   'dai',
#   'best'],
#  ['liqui',
#   'fruit',
#   'mango',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'mango',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'mango',
#   'orang',
#   'juic',
#   'box',
#   'life',
#   'better',
#   'good',
#   'thing',
#   'come',
#   'like',
#   'mango',
#   'orang',
#   'liqui',
#   'fruit',
#   'refresh',
#   'recharg',
#   'flavour',
#   'that’',
#   'soft',
#   'smooth',
#   'fill',
#   'pure',
#   'fruit',
#   'good'],
#  ['liqui',
#   'fruit',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'start',
#   'dai',
#   'classic',
#   'beat',
#   'glass',
#   'liqui',
#   'fruit',
#   'orang',
#   'juic',
#   'dai',
#   'start',
#   'indulg',
#   'healthi',
#   'good',
#   'feel',
#   'good',
#   'readi',
#   'dai'],
#  ['liqui',
#   'fruit',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'start',
#   'dai',
#   'classic',
#   'beat',
#   'glass',
#   'liqui',
#   'fruit',
#   'orang',
#   'juic',
#   'dai',
#   'start',
#   'indulg',
#   'healthi',
#   'good',
#   'feel',
#   'good',
#   'readi',
#   'dai'],
#  ['liqui',
#   'fruit',
#   'orang',
#   'juic',
#   'kick',
#   'dai',
#   'like',
#   'refresh',
#   'glass',
#   'orang',
#   'juic',
#   'treat',
#   'wholesom',
#   'good',
#   'leav',
#   'feel',
#   'good',
#   'readi',
#   'dai',
#   'best'],
#  ['liqui',
#   'fruit',
#   'red',
#   'grape',
#   'juic',
#   'juici',
#   'favourit',
#   'impress',
#   'fussiest',
#   'tast',
#   'bud',
#   'crisp',
#   'juici',
#   'refresh',
#   'tast',
#   'red',
#   'grape',
#   'it’',
#   'classic',
#   'it’',
#   'favourit',
#   'it’',
#   'refresh',
#   'life',
#   'wholesom',
#   'good'],
#  ['liqui',
#   'fruit',
#   'red',
#   'grape',
#   'juic',
#   'impress',
#   'fussiest',
#   'tast',
#   'bud',
#   'crisp',
#   'juici',
#   'refresh',
#   'tast',
#   'red',
#   'grape',
#   'it’',
#   'classic',
#   'it’',
#   'favourit',
#   'it’',
#   'refresh',
#   'life',
#   'wholesom',
#   'good'],
#  ['liqui',
#   'fruit',
#   'summer',
#   'pine',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'summer',
#   'pine',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'bui',
#   'liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'price',
#   'save'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'juic',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'juic',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler'],
#  ['liquifruit',
#   'mango',
#   'orang',
#   'juic',
#   'favourit',
#   'life',
#   'better',
#   'good',
#   'thing',
#   'come',
#   'like',
#   'mango',
#   'orang',
#   'liqui',
#   'fruit',
#   'refresh',
#   'recharg',
#   'flavour',
#   'soft',
#   'smooth',
#   'fill',
#   'pure',
#   'fruit',
#   'good'],
#  ['liquifruit',
#   'mango',
#   'orang',
#   'juic',
#   'favourit',
#   'life',
#   'better',
#   'good',
#   'thing',
#   'come',
#   'like',
#   'mango',
#   'orang',
#   'liqui',
#   'fruit',
#   'refresh',
#   'recharg',
#   'flavour',
#   'soft',
#   'smooth',
#   'fill',
#   'pure',
#   'fruit',
#   'good'],
#  ['liquifruit',
#   'tropic',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['litchi',
#   'punnet',
#   'lyche',
#   'litchi',
#   'chinensi',
#   'known',
#   'litchi',
#   'liche',
#   'small',
#   'tropic',
#   'fruit',
#   'soapberri',
#   'famili',
#   'popular',
#   'fruit',
#   'famili',
#   'includ',
#   'rambutan',
#   'longan',
#   'lyche',
#   'ined',
#   'pink',
#   'red',
#   'leatheri',
#   'skin',
#   'remov',
#   'consumpt'],
#  ['loos',
#   'avocado',
#   'avocado',
#   'fruit',
#   'provid',
#   'substanti',
#   'healthi',
#   'monounsatur',
#   'fatti',
#   'acid',
#   'avocado',
#   'natur',
#   'nutrient',
#   'dens',
#   'food',
#   'contain',
#   'nearli',
#   'vitamin',
#   'miner',
#   'readi',
#   'eat'],
#  ['loos',
#   'babi',
#   'cabbag',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'banana',
#   'banana',
#   'popular',
#   'fruit',
#   'potenti',
#   'health',
#   'benefit',
#   'boost',
#   'digest',
#   'heart',
#   'health',
#   'thank',
#   'fiber',
#   'antioxid',
#   'content'],
#  ['loos', 'brown', 'onion', 'special', 'select'],
#  ['loos', 'fresh', 'celeri', 'loos', 'fresh', 'celeri'],
#  ['loos',
#   'grape',
#   'fruit',
#   'grapefruit',
#   'incred',
#   'healthi',
#   'food',
#   'includ',
#   'diet',
#   'high',
#   'nutrient',
#   'low',
#   'calori'],
#  ['loos',
#   'green',
#   'pepper',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'lemon',
#   'versatil',
#   'flavour',
#   'dish',
#   'add',
#   'favourit',
#   'cocktail',
#   'life',
#   'give',
#   'lemon',
#   'us'],
#  ['loos',
#   'mango',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'orang',
#   'orang',
#   'fruit',
#   'citru',
#   'speci',
#   'famili',
#   'rutacea',
#   'primarili',
#   'refer',
#   'citru',
#   'sinensi',
#   'call',
#   'sweet',
#   'orang',
#   'distinguish',
#   'relat',
#   'citru',
#   'aurantium',
#   'refer',
#   'bitter',
#   'orang'],
#  ['loos',
#   'pear',
#   'pear',
#   'tree',
#   'pear',
#   'fruit',
#   'medicin',
#   'peopl',
#   'us',
#   'pear',
#   'condit',
#   'includ',
#   'indigest',
#   'diarrhea',
#   'constip'],
#  ['loos',
#   'potato',
#   'potato',
#   'edibl',
#   'tuber',
#   'avail',
#   'worldwid',
#   'year',
#   'long',
#   'rel',
#   'cheap',
#   'grow',
#   'rich',
#   'nutrient',
#   'delici',
#   'treat'],
#  ['loos', 'red', 'onion', 'special', 'select'],
#  ['loos',
#   'red',
#   'pepper',
#   'nthe',
#   'bell',
#   'pepper',
#   'fruit',
#   'plant',
#   'grossum',
#   'cultivar',
#   'group',
#   'speci',
#   'capsicum',
#   'annuum',
#   'cultivar',
#   'plant',
#   'produc',
#   'fruit',
#   'differ',
#   'color',
#   'includ',
#   'red',
#   'yellow',
#   'orang',
#   'green',
#   'white',
#   'purpl',
#   'bell',
#   'pepper',
#   'group',
#   'pungent',
#   'chili',
#   'varieti',
#   'sweet',
#   'pepper'],
#  ['loos',
#   'red',
#   'pepper',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'sweet',
#   'potato',
#   'sweet',
#   'potato',
#   'sweetpotato',
#   'dicotyledon',
#   'plant',
#   'belong',
#   'bindwe',
#   'morn',
#   'glori',
#   'famili',
#   'convolvulacea',
#   'larg',
#   'starchi',
#   'sweet',
#   'tast',
#   'tuber',
#   'root',
#   'root',
#   'veget',
#   'young',
#   'shoot',
#   'leav',
#   'eaten',
#   'green'],
#  ['loos',
#   'tomato',
#   'tomato',
#   'consum',
#   'divers',
#   'wai',
#   'raw',
#   'cook',
#   'dish',
#   'sauc',
#   'salad',
#   'drink',
#   'tomato',
#   'fruits—botan',
#   'classifi',
#   'berries—thei',
#   'commonli',
#   'culinarili',
#   'veget',
#   'ingredi',
#   'dish'],
#  ['loos',
#   'yellow',
#   'pepper',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['lucozad', 'origin', 'energi', 'drink', 'high', 'vitamin', 'vitamin'],
#  ['lux',
#   'soft',
#   'caress',
#   'beauti',
#   'soap',
#   'lux',
#   'beauti',
#   'soap',
#   'notic',
#   'soft',
#   'skin',
#   'expertli',
#   'craft',
#   'silkess',
#   'delic',
#   'white',
#   'flower',
#   'nwash',
#   'hand',
#   'frequent',
#   'soap',
#   'water',
#   'best',
#   'defenc',
#   'spread',
#   'germ',
#   'accord',
#   'world',
#   'health',
#   'organis',
#   'nation',
#   'institut',
#   'communic',
#   'diseas'],
#  ['lux',
#   'soft',
#   'caress',
#   'beauti',
#   'soap',
#   'indulg',
#   'sens',
#   'lux',
#   'soft',
#   'caress',
#   'bath',
#   'soap',
#   'bar',
#   'smooth',
#   'radiant',
#   'skin'],
#  ['magnum',
#   'classic',
#   'ic',
#   'cream',
#   'pint',
#   'peel',
#   'open',
#   'tub',
#   'magnum',
#   'stapl',
#   'classic',
#   'ic',
#   'cream',
#   'lose',
#   'luxuri',
#   'fold',
#   'smooth',
#   'creami',
#   'vanilla',
#   'ic',
#   'cream',
#   'shard',
#   'delect',
#   'milk',
#   'chocol'],
#  ['maizena',
#   'gluten',
#   'free',
#   'corn',
#   'flour',
#   'maizena',
#   'gluten',
#   'free',
#   'corn',
#   'flour'],
#  ['malfi', 'arancia', 'malfi', 'gin'],
#  ['mama',
#   'pi',
#   'frozen',
#   'pepper',
#   'steak',
#   'pi',
#   'carefulli',
#   'puff',
#   'pastri',
#   'pi',
#   'fill',
#   'juici',
#   'steak',
#   'rich',
#   'pepper',
#   'sauc'],
#  ['mama',
#   'roast',
#   'chicken',
#   'frozen',
#   'pie',
#   'carefulli',
#   'puff',
#   'pastri',
#   'pi',
#   'fill',
#   'chicken',
#   'roast',
#   'flavour',
#   'gravi'],
#  ['mama',
#   'steak',
#   'kidnei',
#   'frozen',
#   'pi',
#   'carefulli',
#   'puff',
#   'pastri',
#   'pi',
#   'fill',
#   'juici',
#   'steak',
#   'kidnei',
#   'rich',
#   'gravi'],
#  ['mango', 'pack', 'fresh', 'mango', 'juici', 'delici'],
#  ['manhattan',
#   'jellyland',
#   'sour',
#   'worm',
#   'super',
#   'sour',
#   'super',
#   'sweet',
#   'super',
#   'tasti',
#   'sour',
#   'worm'],
#  ['manhattan',
#   'milk',
#   'bottl',
#   'creami',
#   'delici',
#   'shape',
#   'like',
#   'mini',
#   'milk',
#   'bottl'],
#  ['manhattan',
#   'speckl',
#   'chocol',
#   'candi',
#   'coat',
#   'belgian',
#   'milk',
#   'chocol',
#   'milki',
#   'centr',
#   'real',
#   'belgian',
#   'chocol'],
#  ['marlton',
#   'anti',
#   'slip',
#   'stainless',
#   'steel',
#   'dog',
#   'bowl',
#   'dog',
#   'bowl'],
#  ['marlton', 'healthi', 'centr', 'chicken', 'cat', 'cat', 'treat'],
#  ['marlton', 'healthi', 'centr', 'salmon', 'cat', 'cat', 'treat'],
#  ['med', 'gouda', 'mustard', 'seed', 'special', 'select'],
#  ['med',
#   'lemon',
#   'origin',
#   'sachet',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['med',
#   'lemon',
#   'origin',
#   'sachet',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['med',
#   'lemon',
#   'origin',
#   'sachet',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['med',
#   'lemon',
#   'cold',
#   'flu',
#   'hot',
#   'medic',
#   'med',
#   'lemon',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter',
#   'good',
#   'time',
#   'feel',
#   'better'],
#  ['med',
#   'lemon',
#   'lemon',
#   'menthol',
#   'vitamin',
#   'hot',
#   'medic',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['miller', 'beer', 'bottl', 'premium', 'beer'],
#  ['milton', 'sterilis', 'fluid', 'kill', 'known', 'germ', 'includ', 'thrush'],
#  ['milton',
#   'sterilis',
#   'fluid',
#   'base',
#   'year',
#   'expertis',
#   'milton',
#   'care',
#   'famili',
#   'sterilis',
#   'hygien',
#   'world',
#   'war'],
#  ['milton',
#   'sterilis',
#   'surfac',
#   'sprai',
#   'ideal',
#   'disinfect',
#   'surfac',
#   'home',
#   'highchair',
#   'work',
#   'top',
#   'bathroom',
#   'potti',
#   'baby’',
#   'bath'],
#  ...]

# %%
w2v = embedding.word2vec(all_text)

# %%
w2v['skin']
# Out:
# array([ 0.8120286 , -1.075846  ,  0.3069056 , -0.11384587, -1.4837037 ,
#         0.23139429, -0.81555927,  1.9369663 , -1.1026706 , -1.011192  ],
#       dtype=float32)

# %%
w2v.vocab
# Out:
# {'flavour': <gensim.models.keyedvectors.Vocab at 0x20b762fa460>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x20b762faf10>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x20b7633b130>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x20b7633b190>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x20b7633b1f0>,
#  'tast': <gensim.models.keyedvectors.Vocab at 0x20b7633b250>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x20b7633b2b0>,
#  'babi': <gensim.models.keyedvectors.Vocab at 0x20b7633b310>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x20b7633b370>,
#  'chicken': <gensim.models.keyedvectors.Vocab at 0x20b7633b3d0>,
#  'rang': <gensim.models.keyedvectors.Vocab at 0x20b7633b430>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x20b7633b490>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x20b7633b4f0>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x20b7633b550>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x20b7633b5b0>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x20b7633b610>,
#  'enjoi': <gensim.models.keyedvectors.Vocab at 0x20b7633b670>,
#  'beer': <gensim.models.keyedvectors.Vocab at 0x20b7633b6d0>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x20b7633b730>,
#  'natur': <gensim.models.keyedvectors.Vocab at 0x20b7633b790>,
#  'pack': <gensim.models.keyedvectors.Vocab at 0x20b7633b7f0>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x20b7633b850>,
#  'refresh': <gensim.models.keyedvectors.Vocab at 0x20b7633b8b0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x20b7633b910>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x20b7633b970>,
#  'delici': <gensim.models.keyedvectors.Vocab at 0x20b7633b9d0>,
#  'juic': <gensim.models.keyedvectors.Vocab at 0x20b7633ba30>,
#  'appl': <gensim.models.keyedvectors.Vocab at 0x20b7633ba90>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x20b7633baf0>,
#  'bodi': <gensim.models.keyedvectors.Vocab at 0x20b7633bb50>,
#  'dai': <gensim.models.keyedvectors.Vocab at 0x20b7633bbb0>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x20b7633bc10>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x20b7633bc70>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x20b7633bcd0>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x20b7633bd30>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x20b7633bd90>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x20b7633bdf0>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x20b7633be50>,
#  'qualiti': <gensim.models.keyedvectors.Vocab at 0x20b7633beb0>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x20b7633bf10>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x20b7633bf70>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x20b7633bfd0>,
#  'select': <gensim.models.keyedvectors.Vocab at 0x20b7633e070>,
#  'coca': <gensim.models.keyedvectors.Vocab at 0x20b7633e0d0>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x20b62dcbf70>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x20b7633e130>,
#  'sourc': <gensim.models.keyedvectors.Vocab at 0x20b7633e190>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x20b7633e1f0>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x20b7633e250>,
#  'avg': <gensim.models.keyedvectors.Vocab at 0x20b7633e2b0>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x20b7633e310>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x20b7633e370>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x20b7633e3d0>,
#  'bath': <gensim.models.keyedvectors.Vocab at 0x20b7633e430>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x20b7633e490>,
#  'varieti': <gensim.models.keyedvectors.Vocab at 0x20b7633e4f0>,
#  'chocol': <gensim.models.keyedvectors.Vocab at 0x20b7633e550>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x20b7633e5b0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x20b7633e610>,
#  'vitamin': <gensim.models.keyedvectors.Vocab at 0x20b7633e670>,
#  'soap': <gensim.models.keyedvectors.Vocab at 0x20b7633e6d0>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x20b7633e730>,
#  'premium': <gensim.models.keyedvectors.Vocab at 0x20b7633e790>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x20b7633e7f0>,
#  'pamper': <gensim.models.keyedvectors.Vocab at 0x20b7633e850>,
#  'famili': <gensim.models.keyedvectors.Vocab at 0x20b7633e8b0>,
#  'cook': <gensim.models.keyedvectors.Vocab at 0x20b7633e910>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x20b7633e970>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x20b7633e9d0>,
#  'bottl': <gensim.models.keyedvectors.Vocab at 0x20b7633ea30>,
#  'balanc': <gensim.models.keyedvectors.Vocab at 0x20b7633ea90>,
#  'roast': <gensim.models.keyedvectors.Vocab at 0x20b7633eaf0>,
#  'nivea': <gensim.models.keyedvectors.Vocab at 0x20b7633eb50>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x20b7633ebb0>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x20b7633ec10>,
#  'veget': <gensim.models.keyedvectors.Vocab at 0x20b7633ec70>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x20b7633ecd0>,
#  'salad': <gensim.models.keyedvectors.Vocab at 0x20b7633ed30>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x20b7633ed90>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x20b7633edf0>,
#  'powder': <gensim.models.keyedvectors.Vocab at 0x20b7633ee50>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x20b7633eeb0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x20b7633ef10>,
#  'easi': <gensim.models.keyedvectors.Vocab at 0x20b7633ef70>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x20b7633efd0>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x20b76339070>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x20b763390d0>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x20b76339130>,
#  'ensur': <gensim.models.keyedvectors.Vocab at 0x20b76339190>,
#  'formula': <gensim.models.keyedvectors.Vocab at 0x20b763391f0>,
#  'lamb': <gensim.models.keyedvectors.Vocab at 0x20b76339250>,
#  'orang': <gensim.models.keyedvectors.Vocab at 0x20b763392b0>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x20b76339310>,
#  'bake': <gensim.models.keyedvectors.Vocab at 0x20b76339370>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x20b763393d0>,
#  'albani': <gensim.models.keyedvectors.Vocab at 0x20b76339430>,
#  'superior': <gensim.models.keyedvectors.Vocab at 0x20b76339490>,
#  'produc': <gensim.models.keyedvectors.Vocab at 0x20b763394f0>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x20b76339550>,
#  'sensit': <gensim.models.keyedvectors.Vocab at 0x20b763395b0>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x20b76339610>,
#  'minc': <gensim.models.keyedvectors.Vocab at 0x20b76339670>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x20b763396d0>,
#  'ad': <gensim.models.keyedvectors.Vocab at 0x20b76339730>,
#  'nthi': <gensim.models.keyedvectors.Vocab at 0x20b76339790>,
#  'activ': <gensim.models.keyedvectors.Vocab at 0x20b763397f0>,
#  'knorr': <gensim.models.keyedvectors.Vocab at 0x20b76339850>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x20b763398b0>,
#  'uniqu': <gensim.models.keyedvectors.Vocab at 0x20b76339910>,
#  'ingredi': <gensim.models.keyedvectors.Vocab at 0x20b76339970>,
#  'gentl': <gensim.models.keyedvectors.Vocab at 0x20b763399d0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x20b76339a30>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x20b76339a90>,
#  'moisturis': <gensim.models.keyedvectors.Vocab at 0x20b76339af0>,
#  'potato': <gensim.models.keyedvectors.Vocab at 0x20b76339b50>,
#  'snack': <gensim.models.keyedvectors.Vocab at 0x20b76339bb0>,
#  'soup': <gensim.models.keyedvectors.Vocab at 0x20b76339c10>,
#  'fragranc': <gensim.models.keyedvectors.Vocab at 0x20b76339c70>,
#  'healthi': <gensim.models.keyedvectors.Vocab at 0x20b76339cd0>,
#  'sparkl': <gensim.models.keyedvectors.Vocab at 0x20b76339d30>,
#  'mild': <gensim.models.keyedvectors.Vocab at 0x20b76339d90>,
#  'energi': <gensim.models.keyedvectors.Vocab at 0x20b76339df0>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x20b76339e50>,
#  'stain': <gensim.models.keyedvectors.Vocab at 0x20b76339eb0>,
#  'biscuit': <gensim.models.keyedvectors.Vocab at 0x20b76339f10>,
#  'leav': <gensim.models.keyedvectors.Vocab at 0x20b76339f70>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x20b76339fd0>,
#  'baker': <gensim.models.keyedvectors.Vocab at 0x20b7627c070>,
#  'tender': <gensim.models.keyedvectors.Vocab at 0x20b7627c0d0>,
#  'creami': <gensim.models.keyedvectors.Vocab at 0x20b7627c130>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x20b7627c190>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x20b7627c1f0>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x20b7627c250>,
#  'plu': <gensim.models.keyedvectors.Vocab at 0x20b7627c2b0>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x20b7627c310>,
#  'bic': <gensim.models.keyedvectors.Vocab at 0x20b7627c370>,
#  'pen': <gensim.models.keyedvectors.Vocab at 0x20b7627c3d0>,
#  'liquid': <gensim.models.keyedvectors.Vocab at 0x20b7627c430>,
#  'dish': <gensim.models.keyedvectors.Vocab at 0x20b7627c490>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x20b7633b070>,
#  'wider': <gensim.models.keyedvectors.Vocab at 0x20b7627c4f0>,
#  'continu': <gensim.models.keyedvectors.Vocab at 0x20b7627c550>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x20b7627c5b0>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x20b7627c610>,
#  'shower': <gensim.models.keyedvectors.Vocab at 0x20b7627c670>,
#  'sanex': <gensim.models.keyedvectors.Vocab at 0x20b7627c6d0>,
#  'gel': <gensim.models.keyedvectors.Vocab at 0x20b7627c730>,
#  'absorb': <gensim.models.keyedvectors.Vocab at 0x20b7627c790>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x20b7627c7f0>,
#  'bar': <gensim.models.keyedvectors.Vocab at 0x20b7627c850>,
#  'daili': <gensim.models.keyedvectors.Vocab at 0x20b7627c8b0>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x20b7627c910>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x20b7627c970>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x20b7627c9d0>,
#  'liqui': <gensim.models.keyedvectors.Vocab at 0x20b7627ca30>,
#  'fibr': <gensim.models.keyedvectors.Vocab at 0x20b7627ca90>,
#  'pad': <gensim.models.keyedvectors.Vocab at 0x20b7627caf0>,
#  'tradition': <gensim.models.keyedvectors.Vocab at 0x20b7627cb50>,
#  'toothpast': <gensim.models.keyedvectors.Vocab at 0x20b7627cbb0>,
#  'remov': <gensim.models.keyedvectors.Vocab at 0x20b7627cc10>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x20b7627cc70>,
#  'cooki': <gensim.models.keyedvectors.Vocab at 0x20b7627ccd0>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x20b7627cd30>,
#  'miner': <gensim.models.keyedvectors.Vocab at 0x20b7627cd90>,
#  'scent': <gensim.models.keyedvectors.Vocab at 0x20b7627cdf0>,
#  'lean': <gensim.models.keyedvectors.Vocab at 0x20b7627ce50>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x20b7627ceb0>,
#  'robertson': <gensim.models.keyedvectors.Vocab at 0x20b7627cf10>,
#  'dermo': <gensim.models.keyedvectors.Vocab at 0x20b7627cf70>,
#  'refil': <gensim.models.keyedvectors.Vocab at 0x20b7627cfd0>,
#  'lager': <gensim.models.keyedvectors.Vocab at 0x20b76284070>,
#  'chip': <gensim.models.keyedvectors.Vocab at 0x20b762840d0>,
#  'cereal': <gensim.models.keyedvectors.Vocab at 0x20b76284130>,
#  'nappi': <gensim.models.keyedvectors.Vocab at 0x20b76284190>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x20b762841f0>,
#  'pepper': <gensim.models.keyedvectors.Vocab at 0x20b76284250>,
#  'strawberri': <gensim.models.keyedvectors.Vocab at 0x20b762842b0>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x20b76284310>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x20b76284370>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x20b762843d0>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x20b76284430>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x20b76284490>,
#  'wai': <gensim.models.keyedvectors.Vocab at 0x20b762844f0>,
#  'egg': <gensim.models.keyedvectors.Vocab at 0x20b76284550>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x20b762845b0>,
#  'tasti': <gensim.models.keyedvectors.Vocab at 0x20b76284610>,
#  'aroma': <gensim.models.keyedvectors.Vocab at 0x20b76284670>,
#  'germ': <gensim.models.keyedvectors.Vocab at 0x20b762846d0>,
#  'anti': <gensim.models.keyedvectors.Vocab at 0x20b76284730>,
#  'recip': <gensim.models.keyedvectors.Vocab at 0x20b76284790>,
#  'provid': <gensim.models.keyedvectors.Vocab at 0x20b762847f0>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x20b76284850>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x20b762848b0>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x20b76284910>,
#  'african': <gensim.models.keyedvectors.Vocab at 0x20b76284970>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x20b762849d0>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x20b76284a30>,
#  'jelli': <gensim.models.keyedvectors.Vocab at 0x20b76284a90>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x20b76284af0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x20b76284b50>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x20b76284bb0>,
#  'averag': <gensim.models.keyedvectors.Vocab at 0x20b76284c10>,
#  'displai': <gensim.models.keyedvectors.Vocab at 0x20b76284c70>,
#  'citru': <gensim.models.keyedvectors.Vocab at 0x20b76284cd0>,
#  'herb': <gensim.models.keyedvectors.Vocab at 0x20b76284d30>,
#  'sauc': <gensim.models.keyedvectors.Vocab at 0x20b76284d90>,
#  'wheat': <gensim.models.keyedvectors.Vocab at 0x20b76284df0>,
#  'readi': <gensim.models.keyedvectors.Vocab at 0x20b76284e50>,
#  'pork': <gensim.models.keyedvectors.Vocab at 0x20b76284eb0>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x20b76284f10>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x20b76284f70>,
#  'ic': <gensim.models.keyedvectors.Vocab at 0x20b76284fd0>,
#  'headach': <gensim.models.keyedvectors.Vocab at 0x20b7627f070>,
#  'castl': <gensim.models.keyedvectors.Vocab at 0x20b7627f0d0>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x20b7627f130>,
#  'tablet': <gensim.models.keyedvectors.Vocab at 0x20b7627f190>,
#  'africa': <gensim.models.keyedvectors.Vocab at 0x20b7627f1f0>,
#  'slice': <gensim.models.keyedvectors.Vocab at 0x20b7627f250>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x20b7627f2b0>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x20b7627f310>,
#  'formul': <gensim.models.keyedvectors.Vocab at 0x20b7627f370>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x20b7627f3d0>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x20b7627f430>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x20b7627f490>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x20b7627f4f0>,
#  'everydai': <gensim.models.keyedvectors.Vocab at 0x20b7627f550>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x20b7627f5b0>,
#  'maxi': <gensim.models.keyedvectors.Vocab at 0x20b7627f610>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x20b7627f670>,
#  'dove': <gensim.models.keyedvectors.Vocab at 0x20b7627f6d0>,
#  'chees': <gensim.models.keyedvectors.Vocab at 0x20b7627f730>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x20b7627f790>,
#  'brew': <gensim.models.keyedvectors.Vocab at 0x20b7627f7f0>,
#  'clover': <gensim.models.keyedvectors.Vocab at 0x20b7627f850>,
#  'carefulli': <gensim.models.keyedvectors.Vocab at 0x20b7627f8b0>,
#  'kellogg': <gensim.models.keyedvectors.Vocab at 0x20b7627f910>,
#  'rice': <gensim.models.keyedvectors.Vocab at 0x20b7627f970>,
#  'addi': <gensim.models.keyedvectors.Vocab at 0x20b7627f9d0>,
#  'seed': <gensim.models.keyedvectors.Vocab at 0x20b7627fa30>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x20b7627fa90>,
#  'deliv': <gensim.models.keyedvectors.Vocab at 0x20b7627faf0>,
#  'valu': <gensim.models.keyedvectors.Vocab at 0x20b7627fb50>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x20b7627fbb0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x20b7627fc10>,
#  'indulg': <gensim.models.keyedvectors.Vocab at 0x20b7627fc70>,
#  'auto': <gensim.models.keyedvectors.Vocab at 0x20b7627fcd0>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x20b7627fd30>,
#  'beauti': <gensim.models.keyedvectors.Vocab at 0x20b7627fd90>,
#  'foam': <gensim.models.keyedvectors.Vocab at 0x20b7627fdf0>,
#  'sunlight': <gensim.models.keyedvectors.Vocab at 0x20b7627fe50>,
#  'wipe': <gensim.models.keyedvectors.Vocab at 0x20b7627feb0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x20b7627ff10>,
#  'it’': <gensim.models.keyedvectors.Vocab at 0x20b7627ff70>,
#  'coconut': <gensim.models.keyedvectors.Vocab at 0x20b7627ffd0>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x20b76275070>,
#  'sprai': <gensim.models.keyedvectors.Vocab at 0x20b762750d0>,
#  'hop': <gensim.models.keyedvectors.Vocab at 0x20b76275130>,
#  'spici': <gensim.models.keyedvectors.Vocab at 0x20b76275190>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x20b762751f0>,
#  'routin': <gensim.models.keyedvectors.Vocab at 0x20b76275250>,
#  'antibiot': <gensim.models.keyedvectors.Vocab at 0x20b762752b0>,
#  'pilsen': <gensim.models.keyedvectors.Vocab at 0x20b76275310>,
#  'bin': <gensim.models.keyedvectors.Vocab at 0x20b76275370>,
#  'surfac': <gensim.models.keyedvectors.Vocab at 0x20b762753d0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x20b76275430>,
#  'juici': <gensim.models.keyedvectors.Vocab at 0x20b76275490>,
#  'teeth': <gensim.models.keyedvectors.Vocab at 0x20b762754f0>,
#  'experi': <gensim.models.keyedvectors.Vocab at 0x20b76275550>,
#  'baby’': <gensim.models.keyedvectors.Vocab at 0x20b762755b0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x20b76275610>,
#  'bennett': <gensim.models.keyedvectors.Vocab at 0x20b76275670>,
#  'malt': <gensim.models.keyedvectors.Vocab at 0x20b762756d0>,
#  'hansa': <gensim.models.keyedvectors.Vocab at 0x20b76275730>,
#  'layer': <gensim.models.keyedvectors.Vocab at 0x20b76275790>,
#  'lil': <gensim.models.keyedvectors.Vocab at 0x20b762757f0>,
#  'cleaner': <gensim.models.keyedvectors.Vocab at 0x20b76275850>,
#  'hygien': <gensim.models.keyedvectors.Vocab at 0x20b762758b0>,
#  'finest': <gensim.models.keyedvectors.Vocab at 0x20b76275910>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x20b76275970>,
#  'cake': <gensim.models.keyedvectors.Vocab at 0x20b762759d0>,
#  'larg': <gensim.models.keyedvectors.Vocab at 0x20b76275a30>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x20b76275a90>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x20b76275af0>,
#  'conveni': <gensim.models.keyedvectors.Vocab at 0x20b76275b50>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x20b76275bb0>,
#  'farm': <gensim.models.keyedvectors.Vocab at 0x20b76275c10>,
#  'cape': <gensim.models.keyedvectors.Vocab at 0x20b76275c70>,
#  'coffe': <gensim.models.keyedvectors.Vocab at 0x20b76275cd0>,
#  'lotion': <gensim.models.keyedvectors.Vocab at 0x20b76275d30>,
#  'tomato': <gensim.models.keyedvectors.Vocab at 0x20b76275d90>,
#  'nnever': <gensim.models.keyedvectors.Vocab at 0x20b76275df0>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x20b76275e50>,
#  'vinegar': <gensim.models.keyedvectors.Vocab at 0x20b76275eb0>,
#  'tampon': <gensim.models.keyedvectors.Vocab at 0x20b76275f10>,
#  'rib': <gensim.models.keyedvectors.Vocab at 0x20b76275f70>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x20b76275fd0>,
#  'combin': <gensim.models.keyedvectors.Vocab at 0x20b7615e070>,
#  'luxuri': <gensim.models.keyedvectors.Vocab at 0x20b7615e0d0>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x20b7615e130>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x20b7615e190>,
#  'cube': <gensim.models.keyedvectors.Vocab at 0x20b7615e1f0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x20b7615e250>,
#  'chilli': <gensim.models.keyedvectors.Vocab at 0x20b7615e2b0>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x20b7615e310>,
#  'stew': <gensim.models.keyedvectors.Vocab at 0x20b7615e370>,
#  'toilet': <gensim.models.keyedvectors.Vocab at 0x20b7615e3d0>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x20b7615e430>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x20b7615e490>,
#  'biltong': <gensim.models.keyedvectors.Vocab at 0x20b7615e4f0>,
#  'ag': <gensim.models.keyedvectors.Vocab at 0x20b7615e550>,
#  'essenti': <gensim.models.keyedvectors.Vocab at 0x20b7615e5b0>,
#  'braai': <gensim.models.keyedvectors.Vocab at 0x20b7615e610>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x20b7615e670>,
#  'bonaqua': <gensim.models.keyedvectors.Vocab at 0x20b7615e6d0>,
#  'brutal': <gensim.models.keyedvectors.Vocab at 0x20b7615e730>,
#  'bulk': <gensim.models.keyedvectors.Vocab at 0x20b7615e790>,
#  'fever': <gensim.models.keyedvectors.Vocab at 0x20b7615e7f0>,
#  'yoghurt': <gensim.models.keyedvectors.Vocab at 0x20b7615e850>,
#  'lightli': <gensim.models.keyedvectors.Vocab at 0x20b7615e8b0>,
#  'cloth': <gensim.models.keyedvectors.Vocab at 0x20b7615e910>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x20b7615e970>,
#  'loos': <gensim.models.keyedvectors.Vocab at 0x20b7615e9d0>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x20b7615ea30>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x20b7615ea90>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x20b7615eaf0>,
#  'bun': <gensim.models.keyedvectors.Vocab at 0x20b7615eb50>,
#  'stai': <gensim.models.keyedvectors.Vocab at 0x20b7615ebb0>,
#  'spong': <gensim.models.keyedvectors.Vocab at 0x20b7615ec10>,
#  'syrup': <gensim.models.keyedvectors.Vocab at 0x20b7615ec70>,
#  'awai': <gensim.models.keyedvectors.Vocab at 0x20b7615ecd0>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x20b7615ed30>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x20b7615ed90>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x20b7615edf0>,
#  'onion': <gensim.models.keyedvectors.Vocab at 0x20b7615ee50>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x20b7615eeb0>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x20b7615ef10>,
#  'delic': <gensim.models.keyedvectors.Vocab at 0x20b7615ef70>,
#  'aromat': <gensim.models.keyedvectors.Vocab at 0x20b7615efd0>,
#  'sensodyn': <gensim.models.keyedvectors.Vocab at 0x20b7615b070>,
#  'tabard': <gensim.models.keyedvectors.Vocab at 0x20b7615b0d0>,
#  'dispos': <gensim.models.keyedvectors.Vocab at 0x20b7615b130>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x20b7615b190>,
#  'chill': <gensim.models.keyedvectors.Vocab at 0x20b7615b1f0>,
#  'meal': <gensim.models.keyedvectors.Vocab at 0x20b7615b250>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x20b7615b2b0>,
#  'improv': <gensim.models.keyedvectors.Vocab at 0x20b7615b310>,
#  'littl': <gensim.models.keyedvectors.Vocab at 0x20b7615b370>,
#  'capsul': <gensim.models.keyedvectors.Vocab at 0x20b7615b3d0>,
#  'tissu': <gensim.models.keyedvectors.Vocab at 0x20b7615b430>,
#  'favourit': <gensim.models.keyedvectors.Vocab at 0x20b7615b490>,
#  'subtl': <gensim.models.keyedvectors.Vocab at 0x20b7615b4f0>,
#  'gentli': <gensim.models.keyedvectors.Vocab at 0x20b7615b550>,
#  'hydrat': <gensim.models.keyedvectors.Vocab at 0x20b7615b5b0>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x20b7615b610>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x20b7615b670>,
#  'drumstick': <gensim.models.keyedvectors.Vocab at 0x20b7615b6d0>,
#  'colgat': <gensim.models.keyedvectors.Vocab at 0x20b7615b730>,
#  'imbo': <gensim.models.keyedvectors.Vocab at 0x20b7615b790>,
#  'infant': <gensim.models.keyedvectors.Vocab at 0x20b7615b7f0>,
#  'omo': <gensim.models.keyedvectors.Vocab at 0x20b7615b850>,
#  'pringl': <gensim.models.keyedvectors.Vocab at 0x20b7615b8b0>,
#  'garlic': <gensim.models.keyedvectors.Vocab at 0x20b7615b910>,
#  'mini': <gensim.models.keyedvectors.Vocab at 0x20b7615b970>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x20b7615b9d0>,
#  'import': <gensim.models.keyedvectors.Vocab at 0x20b7615ba30>,
#  'prevent': <gensim.models.keyedvectors.Vocab at 0x20b7615ba90>,
#  'quench': <gensim.models.keyedvectors.Vocab at 0x20b7615baf0>,
#  'thirst': <gensim.models.keyedvectors.Vocab at 0x20b7615bb50>,
#  'aquel': <gensim.models.keyedvectors.Vocab at 0x20b7615bbb0>,
#  'oat': <gensim.models.keyedvectors.Vocab at 0x20b7615bc10>,
#  'barlei': <gensim.models.keyedvectors.Vocab at 0x20b7615bc70>,
#  'tradit': <gensim.models.keyedvectors.Vocab at 0x20b7615bcd0>,
#  'cleans': <gensim.models.keyedvectors.Vocab at 0x20b7615bd30>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x20b7615bd90>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x20b7615bdf0>,
#  'hoppi': <gensim.models.keyedvectors.Vocab at 0x20b7615be50>,
#  'fabric': <gensim.models.keyedvectors.Vocab at 0x20b7615beb0>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x20b7615bf10>,
#  'perspir': <gensim.models.keyedvectors.Vocab at 0x20b7615bf70>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x20b7615bfd0>,
#  'protein': <gensim.models.keyedvectors.Vocab at 0x20b76158070>,
#  'smartfit': <gensim.models.keyedvectors.Vocab at 0x20b761580d0>,
#  'sliver': <gensim.models.keyedvectors.Vocab at 0x20b76158130>,
#  'moir': <gensim.models.keyedvectors.Vocab at 0x20b76158190>,
#  'loin': <gensim.models.keyedvectors.Vocab at 0x20b761581f0>,
#  'dress': <gensim.models.keyedvectors.Vocab at 0x20b76158250>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x20b761582b0>,
#  'fresher': <gensim.models.keyedvectors.Vocab at 0x20b76158310>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x20b76158370>,
#  'sanitari': <gensim.models.keyedvectors.Vocab at 0x20b761583d0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x20b76158430>,
#  'amaz': <gensim.models.keyedvectors.Vocab at 0x20b76158490>,
#  'expertli': <gensim.models.keyedvectors.Vocab at 0x20b761584f0>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x20b76158550>,
#  'peach': <gensim.models.keyedvectors.Vocab at 0x20b761585b0>,
#  'clinic': <gensim.models.keyedvectors.Vocab at 0x20b76158610>,
#  'flu': <gensim.models.keyedvectors.Vocab at 0x20b76158670>,
#  'boost': <gensim.models.keyedvectors.Vocab at 0x20b761586d0>,
#  'portion': <gensim.models.keyedvectors.Vocab at 0x20b76158730>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x20b76158790>,
#  'rubi': <gensim.models.keyedvectors.Vocab at 0x20b761587f0>,
#  'fruiti': <gensim.models.keyedvectors.Vocab at 0x20b76158850>,
#  'floral': <gensim.models.keyedvectors.Vocab at 0x20b761588b0>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x20b76158910>,
#  'satiskin': <gensim.models.keyedvectors.Vocab at 0x20b76158970>,
#  'simba': <gensim.models.keyedvectors.Vocab at 0x20b761589d0>,
#  'flour': <gensim.models.keyedvectors.Vocab at 0x20b76158a30>,
#  'slow': <gensim.models.keyedvectors.Vocab at 0x20b76158a90>,
#  'nfeatur': <gensim.models.keyedvectors.Vocab at 0x20b76158af0>,
#  'materi': <gensim.models.keyedvectors.Vocab at 0x20b76158b50>,
#  'dryness': <gensim.models.keyedvectors.Vocab at 0x20b76158bb0>,
#  'multigrain': <gensim.models.keyedvectors.Vocab at 0x20b76158c10>,
#  'softer': <gensim.models.keyedvectors.Vocab at 0x20b76158c70>,
#  'kilojoul': <gensim.models.keyedvectors.Vocab at 0x20b76158cd0>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x20b76158d30>,
#  'appletis': <gensim.models.keyedvectors.Vocab at 0x20b76158d90>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x20b76158df0>,
#  'stimul': <gensim.models.keyedvectors.Vocab at 0x20b76158e50>,
#  'ply': <gensim.models.keyedvectors.Vocab at 0x20b76158eb0>,
#  'grain': <gensim.models.keyedvectors.Vocab at 0x20b76158f10>,
#  'crunchi': <gensim.models.keyedvectors.Vocab at 0x20b76158f70>,
#  'crispi': <gensim.models.keyedvectors.Vocab at 0x20b76158fd0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x20b7614c070>,
#  'nfree': <gensim.models.keyedvectors.Vocab at 0x20b7614c0d0>,
#  'cough': <gensim.models.keyedvectors.Vocab at 0x20b7614c130>,
#  'tropic': <gensim.models.keyedvectors.Vocab at 0x20b7614c190>,
#  'mango': <gensim.models.keyedvectors.Vocab at 0x20b7614c1f0>,
#  'instant': <gensim.models.keyedvectors.Vocab at 0x20b7614c250>,
#  'boerewor': <gensim.models.keyedvectors.Vocab at 0x20b7614c2b0>,
#  'grass': <gensim.models.keyedvectors.Vocab at 0x20b7614c310>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x20b7614c370>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x20b7614c3d0>,
#  'safari': <gensim.models.keyedvectors.Vocab at 0x20b7614c430>,
#  'dettol': <gensim.models.keyedvectors.Vocab at 0x20b7614c490>,
#  'suitabl': <gensim.models.keyedvectors.Vocab at 0x20b7614c4f0>,
#  'includ': <gensim.models.keyedvectors.Vocab at 0x20b7614c550>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x20b7614c5b0>,
#  'bbq': <gensim.models.keyedvectors.Vocab at 0x20b7614c610>,
#  'maiz': <gensim.models.keyedvectors.Vocab at 0x20b7614c670>,
#  'brush': <gensim.models.keyedvectors.Vocab at 0x20b7614c6d0>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x20b7614c730>,
#  'effervesc': <gensim.models.keyedvectors.Vocab at 0x20b7614c790>,
#  'lavend': <gensim.models.keyedvectors.Vocab at 0x20b7614c7f0>,
#  'choic': <gensim.models.keyedvectors.Vocab at 0x20b7614c850>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x20b7614c8b0>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x20b7614c910>,
#  'sour': <gensim.models.keyedvectors.Vocab at 0x20b7614c970>,
#  'ariel': <gensim.models.keyedvectors.Vocab at 0x20b7614c9d0>,
#  'bud': <gensim.models.keyedvectors.Vocab at 0x20b7614ca30>,
#  'micro': <gensim.models.keyedvectors.Vocab at 0x20b7614ca90>,
#  'bui': <gensim.models.keyedvectors.Vocab at 0x20b7614caf0>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x20b7614cb50>,
#  'proven': <gensim.models.keyedvectors.Vocab at 0x20b7614cbb0>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x20b7614cc10>,
#  'bubbl': <gensim.models.keyedvectors.Vocab at 0x20b7614cc70>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x20b7614ccd0>,
#  'carl': <gensim.models.keyedvectors.Vocab at 0x20b7614cd30>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x20b7614cd90>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x20b7614cdf0>,
#  'steak': <gensim.models.keyedvectors.Vocab at 0x20b7614ce50>,
#  'envelop': <gensim.models.keyedvectors.Vocab at 0x20b7614ceb0>,
#  'roam': <gensim.models.keyedvectors.Vocab at 0x20b7614cf10>,
#  'fillet': <gensim.models.keyedvectors.Vocab at 0x20b7614cf70>,
#  'intens': <gensim.models.keyedvectors.Vocab at 0x20b7614cfd0>,
#  'cranberri': <gensim.models.keyedvectors.Vocab at 0x20b7614f070>,
#  'organ': <gensim.models.keyedvectors.Vocab at 0x20b7614f0d0>,
#  'biom': <gensim.models.keyedvectors.Vocab at 0x20b7614f130>,
#  'sta': <gensim.models.keyedvectors.Vocab at 0x20b7614f190>,
#  'nkeep': <gensim.models.keyedvectors.Vocab at 0x20b7614f1f0>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x20b7614f250>,
#  'seal': <gensim.models.keyedvectors.Vocab at 0x20b7614f2b0>,
#  'serv': <gensim.models.keyedvectors.Vocab at 0x20b7614f310>,
#  'bristl': <gensim.models.keyedvectors.Vocab at 0x20b7614f370>,
#  'textur': <gensim.models.keyedvectors.Vocab at 0x20b7614f3d0>,
#  'rooibo': <gensim.models.keyedvectors.Vocab at 0x20b7614f430>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x20b7614f490>,
#  'anytim': <gensim.models.keyedvectors.Vocab at 0x20b7614f4f0>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x20b7614f550>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x20b7614f5b0>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x20b7614f610>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x20b7614f670>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x20b7614f6d0>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x20b7614f730>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x20b7614f790>,
#  'nextra': <gensim.models.keyedvectors.Vocab at 0x20b7614f7f0>,
#  'promot': <gensim.models.keyedvectors.Vocab at 0x20b7614f850>,
#  'peopl': <gensim.models.keyedvectors.Vocab at 0x20b7614f8b0>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x20b7614f910>,
#  'lettuc': <gensim.models.keyedvectors.Vocab at 0x20b7614f970>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x20b7614f9d0>,
#  'respons': <gensim.models.keyedvectors.Vocab at 0x20b7614fa30>,
#  'carrot': <gensim.models.keyedvectors.Vocab at 0x20b7614fa90>,
#  'defenc': <gensim.models.keyedvectors.Vocab at 0x20b7614faf0>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x20b7614fb50>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x20b7614fbb0>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x20b7614fc10>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x20b7614fc70>,
#  'cere': <gensim.models.keyedvectors.Vocab at 0x20b7614fcd0>,
#  'italian': <gensim.models.keyedvectors.Vocab at 0x20b7614fd30>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x20b7614fd90>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x20b7614fdf0>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x20b7614fe50>,
#  'cup': <gensim.models.keyedvectors.Vocab at 0x20b7614feb0>,
#  'skinless': <gensim.models.keyedvectors.Vocab at 0x20b7614ff10>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x20b7614ff70>,
#  'oro': <gensim.models.keyedvectors.Vocab at 0x20b7614ffd0>,
#  'simpli': <gensim.models.keyedvectors.Vocab at 0x20b76145070>,
#  'ginger': <gensim.models.keyedvectors.Vocab at 0x20b761450d0>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x20b76145130>,
#  'johnni': <gensim.models.keyedvectors.Vocab at 0x20b76145190>,
#  'walker': <gensim.models.keyedvectors.Vocab at 0x20b761451f0>,
#  'rye': <gensim.models.keyedvectors.Vocab at 0x20b76145250>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x20b761452b0>,
#  'raw': <gensim.models.keyedvectors.Vocab at 0x20b76145310>,
#  'nthe': <gensim.models.keyedvectors.Vocab at 0x20b76145370>,
#  'dirt': <gensim.models.keyedvectors.Vocab at 0x20b761453d0>,
#  'handl': <gensim.models.keyedvectors.Vocab at 0x20b76145430>,
#  'innov': <gensim.models.keyedvectors.Vocab at 0x20b76145490>,
#  'avail': <gensim.models.keyedvectors.Vocab at 0x20b761454f0>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x20b76145550>,
#  'ball': <gensim.models.keyedvectors.Vocab at 0x20b761455b0>,
#  'butternut': <gensim.models.keyedvectors.Vocab at 0x20b76145610>,
#  'moistur': <gensim.models.keyedvectors.Vocab at 0x20b76145670>,
#  'liver': <gensim.models.keyedvectors.Vocab at 0x20b761456d0>,
#  'gin': <gensim.models.keyedvectors.Vocab at 0x20b76145730>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x20b76145790>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x20b761457f0>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x20b76145850>,
#  'pro': <gensim.models.keyedvectors.Vocab at 0x20b761458b0>,
#  'ballpoint': <gensim.models.keyedvectors.Vocab at 0x20b76145910>,
#  'nutrit': <gensim.models.keyedvectors.Vocab at 0x20b76145970>,
#  'nrb': <gensim.models.keyedvectors.Vocab at 0x20b761459d0>,
#  'peel': <gensim.models.keyedvectors.Vocab at 0x20b76145a30>,
#  'household': <gensim.models.keyedvectors.Vocab at 0x20b76145a90>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x20b76145af0>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x20b76145b50>,
#  'flake': <gensim.models.keyedvectors.Vocab at 0x20b76145bb0>,
#  'sweeten': <gensim.models.keyedvectors.Vocab at 0x20b76145c10>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x20b76145c70>,
#  'cocoa': <gensim.models.keyedvectors.Vocab at 0x20b76145cd0>,
#  'dens': <gensim.models.keyedvectors.Vocab at 0x20b76145d30>,
#  'complet': <gensim.models.keyedvectors.Vocab at 0x20b76145d90>,
#  'nwash': <gensim.models.keyedvectors.Vocab at 0x20b76145df0>,
#  'diseas': <gensim.models.keyedvectors.Vocab at 0x20b76145e50>,
#  'dinu': <gensim.models.keyedvectors.Vocab at 0x20b76145eb0>,
#  'repel': <gensim.models.keyedvectors.Vocab at 0x20b76145f10>,
#  'fly': <gensim.models.keyedvectors.Vocab at 0x20b76145f70>,
#  'gluten': <gensim.models.keyedvectors.Vocab at 0x20b76145fd0>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x20b76149070>,
#  'novalac': <gensim.models.keyedvectors.Vocab at 0x20b761490d0>,
#  'paraben': <gensim.models.keyedvectors.Vocab at 0x20b76149130>,
#  'minut': <gensim.models.keyedvectors.Vocab at 0x20b76149190>,
#  'berri': <gensim.models.keyedvectors.Vocab at 0x20b761491f0>,
#  'ultim': <gensim.models.keyedvectors.Vocab at 0x20b76149250>,
#  'consist': <gensim.models.keyedvectors.Vocab at 0x20b761492b0>,
#  'piec': <gensim.models.keyedvectors.Vocab at 0x20b76149310>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x20b76149370>,
#  'plastic': <gensim.models.keyedvectors.Vocab at 0x20b761493d0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x20b76149430>,
#  'technolog': <gensim.models.keyedvectors.Vocab at 0x20b76149490>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x20b761494f0>,
#  'leakag': <gensim.models.keyedvectors.Vocab at 0x20b76149550>,
#  'dri': <gensim.models.keyedvectors.Vocab at 0x20b761495b0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x20b76149610>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x20b76149670>,
#  'litchi': <gensim.models.keyedvectors.Vocab at 0x20b761496d0>,
#  'nourish': <gensim.models.keyedvectors.Vocab at 0x20b76149730>,
#  'digest': <gensim.models.keyedvectors.Vocab at 0x20b76149790>,
#  'irresist': <gensim.models.keyedvectors.Vocab at 0x20b761497f0>,
#  'morn': <gensim.models.keyedvectors.Vocab at 0x20b76149850>,
#  'wor': <gensim.models.keyedvectors.Vocab at 0x20b761498b0>,
#  'aqueou': <gensim.models.keyedvectors.Vocab at 0x20b76149910>,
#  'pump': <gensim.models.keyedvectors.Vocab at 0x20b76149970>,
#  'sale': <gensim.models.keyedvectors.Vocab at 0x20b761499d0>,
#  'handi': <gensim.models.keyedvectors.Vocab at 0x20b76149a30>,
#  'pineappl': <gensim.models.keyedvectors.Vocab at 0x20b76149a90>,
#  'versatil': <gensim.models.keyedvectors.Vocab at 0x20b76149af0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x20b76149b50>,
#  'banana': <gensim.models.keyedvectors.Vocab at 0x20b76149bb0>,
#  'farmer': <gensim.models.keyedvectors.Vocab at 0x20b76149c10>,
#  'pediatr': <gensim.models.keyedvectors.Vocab at 0x20b76149c70>,
#  'canderel': <gensim.models.keyedvectors.Vocab at 0x20b76149cd0>,
#  'linger': <gensim.models.keyedvectors.Vocab at 0x20b76149d30>,
#  'volum': <gensim.models.keyedvectors.Vocab at 0x20b76149d90>,
#  'cerebo': <gensim.models.keyedvectors.Vocab at 0x20b76149df0>,
#  'excess': <gensim.models.keyedvectors.Vocab at 0x20b76149e50>,
#  'croxlei': <gensim.models.keyedvectors.Vocab at 0x20b76149eb0>,
#  'accord': <gensim.models.keyedvectors.Vocab at 0x20b76149f10>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x20b76149f70>,
#  'dishwash': <gensim.models.keyedvectors.Vocab at 0x20b76149fd0>,
#  'outdoor': <gensim.models.keyedvectors.Vocab at 0x20b76143070>,
#  'hth': <gensim.models.keyedvectors.Vocab at 0x20b761430d0>,
#  'applic': <gensim.models.keyedvectors.Vocab at 0x20b76143130>,
#  'grape': <gensim.models.keyedvectors.Vocab at 0x20b76143190>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x20b761431f0>,
#  'panado': <gensim.models.keyedvectors.Vocab at 0x20b76143250>,
#  'parmalat': <gensim.models.keyedvectors.Vocab at 0x20b761432b0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x20b76143310>,
#  'snowflak': <gensim.models.keyedvectors.Vocab at 0x20b76143370>,
#  'brm': <gensim.models.keyedvectors.Vocab at 0x20b761433d0>,
#  'fulli': <gensim.models.keyedvectors.Vocab at 0x20b76143430>,
#  'curri': <gensim.models.keyedvectors.Vocab at 0x20b76143490>,
#  'whiski': <gensim.models.keyedvectors.Vocab at 0x20b761434f0>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x20b76143550>,
#  'waterless': <gensim.models.keyedvectors.Vocab at 0x20b761435b0>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x20b76143610>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x20b76143670>,
#  'metal': <gensim.models.keyedvectors.Vocab at 0x20b761436d0>,
#  'variant': <gensim.models.keyedvectors.Vocab at 0x20b76143730>,
#  'loav': <gensim.models.keyedvectors.Vocab at 0x20b76143790>,
#  'tinki': <gensim.models.keyedvectors.Vocab at 0x20b761437f0>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x20b76143850>,
#  'odour': <gensim.models.keyedvectors.Vocab at 0x20b761438b0>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x20b76143910>,
#  'barrier': <gensim.models.keyedvectors.Vocab at 0x20b76143970>,
#  'pre': <gensim.models.keyedvectors.Vocab at 0x20b761439d0>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x20b76143a30>,
#  'lax': <gensim.models.keyedvectors.Vocab at 0x20b76143a90>,
#  'oliv': <gensim.models.keyedvectors.Vocab at 0x20b76143af0>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x20b76143b50>,
#  'choc': <gensim.models.keyedvectors.Vocab at 0x20b76143bb0>,
#  'sprinkl': <gensim.models.keyedvectors.Vocab at 0x20b76143c10>,
#  'plant': <gensim.models.keyedvectors.Vocab at 0x20b76143c70>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x20b76143cd0>,
#  'easili': <gensim.models.keyedvectors.Vocab at 0x20b76143d30>,
#  'repair': <gensim.models.keyedvectors.Vocab at 0x20b76143d90>,
#  'physic': <gensim.models.keyedvectors.Vocab at 0x20b76143df0>,
#  'marker': <gensim.models.keyedvectors.Vocab at 0x20b76143e50>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x20b76143eb0>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x20b76143f10>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x20b76143f70>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x20b76143fd0>,
#  'bowl': <gensim.models.keyedvectors.Vocab at 0x20b7615c070>,
#  'blanc': <gensim.models.keyedvectors.Vocab at 0x20b7615c0d0>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x20b7615c130>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x20b7615c190>,
#  'perfectli': <gensim.models.keyedvectors.Vocab at 0x20b7615c1f0>,
#  'honei': <gensim.models.keyedvectors.Vocab at 0x20b7615c250>,
#  'dip': <gensim.models.keyedvectors.Vocab at 0x20b7615c2b0>,
#  'toothach': <gensim.models.keyedvectors.Vocab at 0x20b7615c310>,
#  'commit': <gensim.models.keyedvectors.Vocab at 0x20b7615c370>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x20b7615c3d0>,
#  'complement': <gensim.models.keyedvectors.Vocab at 0x20b7615c430>,
#  'kiln': <gensim.models.keyedvectors.Vocab at 0x20b7615c490>,
#  'straw': <gensim.models.keyedvectors.Vocab at 0x20b7615c4f0>,
#  'characteris': <gensim.models.keyedvectors.Vocab at 0x20b7615c550>,
#  'nnot': <gensim.models.keyedvectors.Vocab at 0x20b7615c5b0>,
#  'thigh': <gensim.models.keyedvectors.Vocab at 0x20b7615c610>,
#  'trim': <gensim.models.keyedvectors.Vocab at 0x20b7615c670>,
#  'charcoal': <gensim.models.keyedvectors.Vocab at 0x20b7615c6d0>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x20b7615c730>,
#  'soften': <gensim.models.keyedvectors.Vocab at 0x20b7615c790>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x20b7615c7f0>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x20b7615c850>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x20b7615c8b0>,
#  'nutrient': <gensim.models.keyedvectors.Vocab at 0x20b7615c910>,
#  'stroganoff': <gensim.models.keyedvectors.Vocab at 0x20b7615c970>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x20b7615c9d0>,
#  'wholefood': <gensim.models.keyedvectors.Vocab at 0x20b7615ca30>,
#  'jungl': <gensim.models.keyedvectors.Vocab at 0x20b7615ca90>,
#  'knorrox': <gensim.models.keyedvectors.Vocab at 0x20b7615caf0>,
#  'shell': <gensim.models.keyedvectors.Vocab at 0x20b7615cb50>,
#  'nulaid': <gensim.models.keyedvectors.Vocab at 0x20b7615cbb0>,
#  'valdo': <gensim.models.keyedvectors.Vocab at 0x20b7615cc10>,
#  'beautifulli': <gensim.models.keyedvectors.Vocab at 0x20b7615cc70>,
#  'mosquito': <gensim.models.keyedvectors.Vocab at 0x20b7615ccd0>,
#  'thirsti': <gensim.models.keyedvectors.Vocab at 0x20b7615cd30>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x20b7615cd90>,
#  'freezer': <gensim.models.keyedvectors.Vocab at 0x20b7615cdf0>,
#  'bean': <gensim.models.keyedvectors.Vocab at 0x20b7615ce50>,
#  'dimens': <gensim.models.keyedvectors.Vocab at 0x20b7615ceb0>,
#  'nour': <gensim.models.keyedvectors.Vocab at 0x20b7615cf10>,
#  'laundri': <gensim.models.keyedvectors.Vocab at 0x20b7615cf70>,
#  'deterg': <gensim.models.keyedvectors.Vocab at 0x20b7615cfd0>,
#  'gum': <gensim.models.keyedvectors.Vocab at 0x20b76142070>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x20b761420d0>,
#  'reduc': <gensim.models.keyedvectors.Vocab at 0x20b76142130>,
#  'xml': <gensim.models.keyedvectors.Vocab at 0x20b76142190>,
#  'option': <gensim.models.keyedvectors.Vocab at 0x20b761421f0>,
#  'approv': <gensim.models.keyedvectors.Vocab at 0x20b76142250>,
#  'confid': <gensim.models.keyedvectors.Vocab at 0x20b761422b0>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x20b76142310>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x20b76142370>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x20b761423d0>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x20b76142430>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x20b76142490>,
#  'incred': <gensim.models.keyedvectors.Vocab at 0x20b761424f0>,
#  'celebr': <gensim.models.keyedvectors.Vocab at 0x20b76142550>,
#  'drawn': <gensim.models.keyedvectors.Vocab at 0x20b761425b0>,
#  'underground': <gensim.models.keyedvectors.Vocab at 0x20b76142610>,
#  'healthier': <gensim.models.keyedvectors.Vocab at 0x20b76142670>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x20b761426d0>,
#  'memori': <gensim.models.keyedvectors.Vocab at 0x20b76142730>,
#  'peanut': <gensim.models.keyedvectors.Vocab at 0x20b76142790>,
#  'simpl': <gensim.models.keyedvectors.Vocab at 0x20b761427f0>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x20b76142850>,
#  'berocca': <gensim.models.keyedvectors.Vocab at 0x20b761428b0>,
#  'enhanc': <gensim.models.keyedvectors.Vocab at 0x20b76142910>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x20b76142970>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x20b761429d0>,
#  'especi': <gensim.models.keyedvectors.Vocab at 0x20b76142a30>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x20b76142a90>,
#  'pear': <gensim.models.keyedvectors.Vocab at 0x20b76142af0>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x20b76142b50>,
#  'onlin': <gensim.models.keyedvectors.Vocab at 0x20b76142bb0>,
#  'sensat': <gensim.models.keyedvectors.Vocab at 0x20b76142c10>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x20b76142c70>,
#  'afford': <gensim.models.keyedvectors.Vocab at 0x20b76142cd0>,
#  'lite': <gensim.models.keyedvectors.Vocab at 0x20b76142d30>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x20b76142d90>,
#  'spinach': <gensim.models.keyedvectors.Vocab at 0x20b76142df0>,
#  'frequent': <gensim.models.keyedvectors.Vocab at 0x20b76142e50>,
#  'organis': <gensim.models.keyedvectors.Vocab at 0x20b76142eb0>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x20b76142f10>,
#  'institut': <gensim.models.keyedvectors.Vocab at 0x20b76142f70>,
#  'communic': <gensim.models.keyedvectors.Vocab at 0x20b76142fd0>,
#  'dorito': <gensim.models.keyedvectors.Vocab at 0x20b76558070>,
#  'nbreathabl': <gensim.models.keyedvectors.Vocab at 0x20b765580d0>,
#  'refus': <gensim.models.keyedvectors.Vocab at 0x20b76558130>,
#  'smell': <gensim.models.keyedvectors.Vocab at 0x20b76558190>,
#  'grandpa': <gensim.models.keyedvectors.Vocab at 0x20b765581f0>,
#  'excel': <gensim.models.keyedvectors.Vocab at 0x20b76558250>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x20b765582b0>,
#  'lipton': <gensim.models.keyedvectors.Vocab at 0x20b76558310>,
#  'liquifruit': <gensim.models.keyedvectors.Vocab at 0x20b76558370>,
#  'skip': <gensim.models.keyedvectors.Vocab at 0x20b765583d0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x20b76558430>,
#  'peri': <gensim.models.keyedvectors.Vocab at 0x20b76558490>,
#  'marin': <gensim.models.keyedvectors.Vocab at 0x20b765584f0>,
#  'refriger': <gensim.models.keyedvectors.Vocab at 0x20b76558550>,
#  'nwhat': <gensim.models.keyedvectors.Vocab at 0x20b765585b0>,
#  'solut': <gensim.models.keyedvectors.Vocab at 0x20b76558610>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x20b76558670>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x20b765586d0>,
#  'wholewheat': <gensim.models.keyedvectors.Vocab at 0x20b76558730>,
#  'indic': <gensim.models.keyedvectors.Vocab at 0x20b76558790>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x20b765587f0>,
#  'doubl': <gensim.models.keyedvectors.Vocab at 0x20b76558850>,
#  'distinguish': <gensim.models.keyedvectors.Vocab at 0x20b765588b0>,
#  'tart': <gensim.models.keyedvectors.Vocab at 0x20b76558910>,
#  'concentr': <gensim.models.keyedvectors.Vocab at 0x20b76558970>,
#  'dissolv': <gensim.models.keyedvectors.Vocab at 0x20b765589d0>,
#  'litr': <gensim.models.keyedvectors.Vocab at 0x20b76558a30>,
#  'canola': <gensim.models.keyedvectors.Vocab at 0x20b76558a90>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x20b76558af0>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x20b76558b50>,
#  'gener': <gensim.models.keyedvectors.Vocab at 0x20b76558bb0>,
#  'attent': <gensim.models.keyedvectors.Vocab at 0x20b76558c10>,
#  'delight': <gensim.models.keyedvectors.Vocab at 0x20b76558c70>,
#  'coriand': <gensim.models.keyedvectors.Vocab at 0x20b76558cd0>,
#  'sooth': <gensim.models.keyedvectors.Vocab at 0x20b76558d30>,
#  'sachet': <gensim.models.keyedvectors.Vocab at 0x20b76558d90>,
#  'supplement': <gensim.models.keyedvectors.Vocab at 0x20b76558df0>,
#  'crystal': <gensim.models.keyedvectors.Vocab at 0x20b76558e50>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x20b76558eb0>,
#  'pencil': <gensim.models.keyedvectors.Vocab at 0x20b76558f10>,
#  'tip': <gensim.models.keyedvectors.Vocab at 0x20b76558f70>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x20b76558fd0>,
#  'skincar': <gensim.models.keyedvectors.Vocab at 0x20b7655b070>,
#  'contribut': <gensim.models.keyedvectors.Vocab at 0x20b7655b0d0>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x20b7655b130>,
#  'rusk': <gensim.models.keyedvectors.Vocab at 0x20b7655b190>,
#  'eleg': <gensim.models.keyedvectors.Vocab at 0x20b7655b1f0>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x20b7655b250>,
#  'spritzer': <gensim.models.keyedvectors.Vocab at 0x20b7655b2b0>,
#  'splash': <gensim.models.keyedvectors.Vocab at 0x20b7655b310>,
#  'that’': <gensim.models.keyedvectors.Vocab at 0x20b7655b370>,
#  'incept': <gensim.models.keyedvectors.Vocab at 0x20b7655b3d0>,
#  'compon': <gensim.models.keyedvectors.Vocab at 0x20b7655b430>,
#  '“qualiti': <gensim.models.keyedvectors.Vocab at 0x20b7655b490>,
#  'value”': <gensim.models.keyedvectors.Vocab at 0x20b7655b4f0>,
#  'meant': <gensim.models.keyedvectors.Vocab at 0x20b7655b550>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x20b7655b5b0>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x20b7655b610>,
#  'parti': <gensim.models.keyedvectors.Vocab at 0x20b7655b670>,
#  'tangi': <gensim.models.keyedvectors.Vocab at 0x20b7655b6d0>,
#  'uht': <gensim.models.keyedvectors.Vocab at 0x20b7655b730>,
#  'coco': <gensim.models.keyedvectors.Vocab at 0x20b7655b790>,
#  'punch': <gensim.models.keyedvectors.Vocab at 0x20b7655b7f0>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x20b7655b850>,
#  'crumb': <gensim.models.keyedvectors.Vocab at 0x20b7655b8b0>,
#  'smoother': <gensim.models.keyedvectors.Vocab at 0x20b7655b910>,
#  'domesto': <gensim.models.keyedvectors.Vocab at 0x20b7655b970>,
#  'relax': <gensim.models.keyedvectors.Vocab at 0x20b7655b9d0>,
#  'duracel': <gensim.models.keyedvectors.Vocab at 0x20b7655ba30>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x20b7655ba90>,
#  'ey': <gensim.models.keyedvectors.Vocab at 0x20b7655baf0>,
#  'feinschmeck': <gensim.models.keyedvectors.Vocab at 0x20b7655bb50>,
#  'vegetarian': <gensim.models.keyedvectors.Vocab at 0x20b7655bbb0>,
#  'basil': <gensim.models.keyedvectors.Vocab at 0x20b7655bc10>,
#  'andi': <gensim.models.keyedvectors.Vocab at 0x20b7655bc70>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x20b7655bcd0>,
#  'flavoursom': <gensim.models.keyedvectors.Vocab at 0x20b7655bd30>,
#  'floater': <gensim.models.keyedvectors.Vocab at 0x20b7655bd90>,
#  'espresso': <gensim.models.keyedvectors.Vocab at 0x20b7655bdf0>,
#  'lip': <gensim.models.keyedvectors.Vocab at 0x20b7655be50>,
#  'fed': <gensim.models.keyedvectors.Vocab at 0x20b7655beb0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x20b7655bf10>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x20b7655bf70>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x20b7655bfd0>,
#  'discov': <gensim.models.keyedvectors.Vocab at 0x20b7655e070>,
#  'rajah': <gensim.models.keyedvectors.Vocab at 0x20b7655e0d0>,
#  'nougat': <gensim.models.keyedvectors.Vocab at 0x20b7655e130>,
#  'parboil': <gensim.models.keyedvectors.Vocab at 0x20b7655e190>,
#  'citronella': <gensim.models.keyedvectors.Vocab at 0x20b7655e1f0>,
#  'candl': <gensim.models.keyedvectors.Vocab at 0x20b7655e250>,
#  'insect': <gensim.models.keyedvectors.Vocab at 0x20b7655e2b0>,
#  'tru': <gensim.models.keyedvectors.Vocab at 0x20b7655e310>,
#  'twinsav': <gensim.models.keyedvectors.Vocab at 0x20b7655e370>,
#  'vick': <gensim.models.keyedvectors.Vocab at 0x20b7655e3d0>,
#  'spatchcock': <gensim.models.keyedvectors.Vocab at 0x20b7655e430>,
#  'famou': <gensim.models.keyedvectors.Vocab at 0x20b7655e490>,
#  'cognac': <gensim.models.keyedvectors.Vocab at 0x20b7655e4f0>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x20b7655e550>,
#  'punnet': <gensim.models.keyedvectors.Vocab at 0x20b7655e5b0>,
#  'typic': <gensim.models.keyedvectors.Vocab at 0x20b7655e610>,
#  'broom': <gensim.models.keyedvectors.Vocab at 0x20b7655e670>,
#  'mop': <gensim.models.keyedvectors.Vocab at 0x20b7655e6d0>,
#  'foundat': <gensim.models.keyedvectors.Vocab at 0x20b7655e730>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x20b7655e790>,
#  'endors': <gensim.models.keyedvectors.Vocab at 0x20b7655e7f0>,
#  'ultra': <gensim.models.keyedvectors.Vocab at 0x20b7655e850>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x20b7655e8b0>,
#  'constip': <gensim.models.keyedvectors.Vocab at 0x20b7655e910>,
#  'mayonnais': <gensim.models.keyedvectors.Vocab at 0x20b7655e970>,
#  'virgin': <gensim.models.keyedvectors.Vocab at 0x20b7655e9d0>,
#  'caramel': <gensim.models.keyedvectors.Vocab at 0x20b7655ea30>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x20b7655ea90>,
#  'assort': <gensim.models.keyedvectors.Vocab at 0x20b7655eaf0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x20b7655eb50>,
#  'calori': <gensim.models.keyedvectors.Vocab at 0x20b7655ebb0>,
#  'slightli': <gensim.models.keyedvectors.Vocab at 0x20b7655ec10>,
#  'irrit': <gensim.models.keyedvectors.Vocab at 0x20b7655ec70>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x20b7655ecd0>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x20b7655ed30>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x20b7655ed90>,
#  'razor': <gensim.models.keyedvectors.Vocab at 0x20b7655edf0>,
#  'button': <gensim.models.keyedvectors.Vocab at 0x20b7655ee50>,
#  'ladi': <gensim.models.keyedvectors.Vocab at 0x20b7655eeb0>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x20b7655ef10>,
#  'vibrant': <gensim.models.keyedvectors.Vocab at 0x20b7655ef70>,
#  'cabbag': <gensim.models.keyedvectors.Vocab at 0x20b7655efd0>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x20b76561070>,
#  'grapefruit': <gensim.models.keyedvectors.Vocab at 0x20b765610d0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x20b76561130>,
#  'iodat': <gensim.models.keyedvectors.Vocab at 0x20b76561190>,
#  'coars': <gensim.models.keyedvectors.Vocab at 0x20b765611f0>,
#  'unbroken': <gensim.models.keyedvectors.Vocab at 0x20b76561250>,
#  'superb': <gensim.models.keyedvectors.Vocab at 0x20b765612b0>,
#  'cadburi': <gensim.models.keyedvectors.Vocab at 0x20b76561310>,
#  'nut': <gensim.models.keyedvectors.Vocab at 0x20b76561370>,
#  'succul': <gensim.models.keyedvectors.Vocab at 0x20b765613d0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x20b76561430>,
#  'aftertast': <gensim.models.keyedvectors.Vocab at 0x20b76561490>,
#  'vallei': <gensim.models.keyedvectors.Vocab at 0x20b765614f0>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x20b76561550>,
#  'nmax': <gensim.models.keyedvectors.Vocab at 0x20b765615b0>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x20b76561610>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x20b76561670>,
#  'moder': <gensim.models.keyedvectors.Vocab at 0x20b765616d0>,
#  'fair': <gensim.models.keyedvectors.Vocab at 0x20b76561730>,
#  'pine': <gensim.models.keyedvectors.Vocab at 0x20b76561790>,
#  'supercharg': <gensim.models.keyedvectors.Vocab at 0x20b765617f0>,
#  'drakensberg': <gensim.models.keyedvectors.Vocab at 0x20b76561850>,
#  'glycerin': <gensim.models.keyedvectors.Vocab at 0x20b765618b0>,
#  'cattl': <gensim.models.keyedvectors.Vocab at 0x20b76561910>,
#  'yellowish': <gensim.models.keyedvectors.Vocab at 0x20b76561970>,
#  'nguarante': <gensim.models.keyedvectors.Vocab at 0x20b765619d0>,
#  'sandwich': <gensim.models.keyedvectors.Vocab at 0x20b76561a30>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x20b76561a90>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x20b76561af0>,
#  'saaz': <gensim.models.keyedvectors.Vocab at 0x20b76561b50>,
#  'czech': <gensim.models.keyedvectors.Vocab at 0x20b76561bb0>,
#  'republ': <gensim.models.keyedvectors.Vocab at 0x20b76561c10>,
#  'hansa’': <gensim.models.keyedvectors.Vocab at 0x20b76561c70>,
#  'importantli': <gensim.models.keyedvectors.Vocab at 0x20b76561cd0>,
#  'savouri': <gensim.models.keyedvectors.Vocab at 0x20b76561d30>,
#  'nutti': <gensim.models.keyedvectors.Vocab at 0x20b76561d90>,
#  'bran': <gensim.models.keyedvectors.Vocab at 0x20b76561df0>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x20b76561e50>,
#  'nup': <gensim.models.keyedvectors.Vocab at 0x20b76561eb0>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x20b76561f10>,
#  'scotch': <gensim.models.keyedvectors.Vocab at 0x20b76561f70>,
#  'stir': <gensim.models.keyedvectors.Vocab at 0x20b76561fd0>,
#  'pasta': <gensim.models.keyedvectors.Vocab at 0x20b76565070>,
#  'pot': <gensim.models.keyedvectors.Vocab at 0x20b765650d0>,
#  'petroleum': <gensim.models.keyedvectors.Vocab at 0x20b76565130>,
#  'labello': <gensim.models.keyedvectors.Vocab at 0x20b76565190>,
#  'lancewood': <gensim.models.keyedvectors.Vocab at 0x20b765651f0>,
#  'kick': <gensim.models.keyedvectors.Vocab at 0x20b76565250>,
#  'pungent': <gensim.models.keyedvectors.Vocab at 0x20b765652b0>,
#  'sens': <gensim.models.keyedvectors.Vocab at 0x20b76565310>,
#  'med': <gensim.models.keyedvectors.Vocab at 0x20b76565370>,
#  'medic': <gensim.models.keyedvectors.Vocab at 0x20b765653d0>,
#  'whilst': <gensim.models.keyedvectors.Vocab at 0x20b76565430>,
#  'distribut': <gensim.models.keyedvectors.Vocab at 0x20b76565490>,
#  'evenli': <gensim.models.keyedvectors.Vocab at 0x20b765654f0>,
#  'nwet': <gensim.models.keyedvectors.Vocab at 0x20b76565550>,
#  'stretchi': <gensim.models.keyedvectors.Vocab at 0x20b765655b0>,
#  'nsilki': <gensim.models.keyedvectors.Vocab at 0x20b76565610>,
#  'prune': <gensim.models.keyedvectors.Vocab at 0x20b76565670>,
#  'nreadi': <gensim.models.keyedvectors.Vocab at 0x20b765656d0>,
#  'sticki': <gensim.models.keyedvectors.Vocab at 0x20b76565730>,
#  'adco': <gensim.models.keyedvectors.Vocab at 0x20b76565790>,
#  'towel': <gensim.models.keyedvectors.Vocab at 0x20b765657f0>,
#  'dustpan': <gensim.models.keyedvectors.Vocab at 0x20b76565850>,
#  'warranti': <gensim.models.keyedvectors.Vocab at 0x20b765658b0>,
#  'lifestyl': <gensim.models.keyedvectors.Vocab at 0x20b76565910>,
#  'ultima': <gensim.models.keyedvectors.Vocab at 0x20b76565970>,
#  'load': <gensim.models.keyedvectors.Vocab at 0x20b765659d0>,
#  'antioxid': <gensim.models.keyedvectors.Vocab at 0x20b76565a30>,
#  'runni': <gensim.models.keyedvectors.Vocab at 0x20b76565a90>,
#  'throat': <gensim.models.keyedvectors.Vocab at 0x20b76565af0>,
#  'dermatolog': <gensim.models.keyedvectors.Vocab at 0x20b76565b50>,
#  'fluid': <gensim.models.keyedvectors.Vocab at 0x20b76565bb0>,
#  'reliabl': <gensim.models.keyedvectors.Vocab at 0x20b76565c10>,
#  'golden': <gensim.models.keyedvectors.Vocab at 0x20b76565c70>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x20b76565cd0>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x20b76565d30>,
#  'extraordinari': <gensim.models.keyedvectors.Vocab at 0x20b76565d90>,
#  'separ': <gensim.models.keyedvectors.Vocab at 0x20b76565df0>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x20b76565e50>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x20b76565eb0>,
#  'choos': <gensim.models.keyedvectors.Vocab at 0x20b76565f10>,
#  'pillow': <gensim.models.keyedvectors.Vocab at 0x20b76565f70>,
#  'mari': <gensim.models.keyedvectors.Vocab at 0x20b76565fd0>,
#  'mash': <gensim.models.keyedvectors.Vocab at 0x20b76568070>,
#  'meati': <gensim.models.keyedvectors.Vocab at 0x20b765680d0>,
#  'dermatologist': <gensim.models.keyedvectors.Vocab at 0x20b76568130>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x20b76568190>,
#  'sore': <gensim.models.keyedvectors.Vocab at 0x20b765681f0>,
#  'bepanthen': <gensim.models.keyedvectors.Vocab at 0x20b76568250>,
#  'shave': <gensim.models.keyedvectors.Vocab at 0x20b765682b0>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x20b76568310>,
#  'perman': <gensim.models.keyedvectors.Vocab at 0x20b76568370>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x20b765683d0>,
#  'offic': <gensim.models.keyedvectors.Vocab at 0x20b76568430>,
#  'eras': <gensim.models.keyedvectors.Vocab at 0x20b76568490>,
#  'bio': <gensim.models.keyedvectors.Vocab at 0x20b765684f0>,
#  'rosemari': <gensim.models.keyedvectors.Vocab at 0x20b76568550>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x20b765685b0>,
#  'blueberri': <gensim.models.keyedvectors.Vocab at 0x20b76568610>,
#  'tabl': <gensim.models.keyedvectors.Vocab at 0x20b76568670>,
#  'nbonaqua': <gensim.models.keyedvectors.Vocab at 0x20b765686d0>,
#  'beverag': <gensim.models.keyedvectors.Vocab at 0x20b76568730>,
#  'bon': <gensim.models.keyedvectors.Vocab at 0x20b76568790>,
#  'aqua': <gensim.models.keyedvectors.Vocab at 0x20b765687f0>,
#  'zesti': <gensim.models.keyedvectors.Vocab at 0x20b76568850>,
#  'budweis': <gensim.models.keyedvectors.Vocab at 0x20b765688b0>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x20b76568910>,
#  'ripe': <gensim.models.keyedvectors.Vocab at 0x20b76568970>,
#  'pantri': <gensim.models.keyedvectors.Vocab at 0x20b765689d0>,
#  'bite': <gensim.models.keyedvectors.Vocab at 0x20b76568a30>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x20b76568a90>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x20b76568af0>,
#  'locat': <gensim.models.keyedvectors.Vocab at 0x20b76568b50>,
#  'soi': <gensim.models.keyedvectors.Vocab at 0x20b76568bb0>,
#  'cal': <gensim.models.keyedvectors.Vocab at 0x20b76568c10>,
#  'granular': <gensim.models.keyedvectors.Vocab at 0x20b76568c70>,
#  'palat': <gensim.models.keyedvectors.Vocab at 0x20b76568cd0>,
#  'carbohydr': <gensim.models.keyedvectors.Vocab at 0x20b76568d30>,
#  'stout': <gensim.models.keyedvectors.Vocab at 0x20b76568d90>,
#  'optimum': <gensim.models.keyedvectors.Vocab at 0x20b76568df0>,
#  'cherri': <gensim.models.keyedvectors.Vocab at 0x20b76568e50>,
#  'purpos': <gensim.models.keyedvectors.Vocab at 0x20b76568eb0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x20b76568f10>,
#  'cobra': <gensim.models.keyedvectors.Vocab at 0x20b76568f70>,
#  'uplift': <gensim.models.keyedvectors.Vocab at 0x20b76568fd0>,
#  'whiten': <gensim.models.keyedvectors.Vocab at 0x20b7656b070>,
#  'brighten': <gensim.models.keyedvectors.Vocab at 0x20b7656b0d0>,
#  'smile': <gensim.models.keyedvectors.Vocab at 0x20b7656b130>,
#  'toothbrush': <gensim.models.keyedvectors.Vocab at 0x20b7656b190>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x20b7656b1f0>,
#  'aromatherapi': <gensim.models.keyedvectors.Vocab at 0x20b7656b250>,
#  'iron': <gensim.models.keyedvectors.Vocab at 0x20b7656b2b0>,
#  'symptomat': <gensim.models.keyedvectors.Vocab at 0x20b7656b310>,
#  'counti': <gensim.models.keyedvectors.Vocab at 0x20b7656b370>,
#  'porridg': <gensim.models.keyedvectors.Vocab at 0x20b7656b3d0>,
#  'bleach': <gensim.models.keyedvectors.Vocab at 0x20b7656b430>,
#  'purchas': <gensim.models.keyedvectors.Vocab at 0x20b7656b490>,
#  'batteri': <gensim.models.keyedvectors.Vocab at 0x20b7656b4f0>,
#  'noodl': <gensim.models.keyedvectors.Vocab at 0x20b7656b550>,
#  'puls': <gensim.models.keyedvectors.Vocab at 0x20b7656b5b0>,
#  'inspir': <gensim.models.keyedvectors.Vocab at 0x20b7656b610>,
#  'gem': <gensim.models.keyedvectors.Vocab at 0x20b7656b670>,
#  'squash': <gensim.models.keyedvectors.Vocab at 0x20b7656b6d0>,
#  'goldi': <gensim.models.keyedvectors.Vocab at 0x20b7656b730>,
#  'grabouw': <gensim.models.keyedvectors.Vocab at 0x20b7656b790>,
#  'tripl': <gensim.models.keyedvectors.Vocab at 0x20b7656b7f0>,
#  'dietari': <gensim.models.keyedvectors.Vocab at 0x20b7656b850>,
#  'jacob': <gensim.models.keyedvectors.Vocab at 0x20b7656b8b0>,
#  'perfum': <gensim.models.keyedvectors.Vocab at 0x20b7656b910>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x20b7656b970>,
#  'krispi': <gensim.models.keyedvectors.Vocab at 0x20b7656b9d0>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x20b7656ba30>,
#  'pi': <gensim.models.keyedvectors.Vocab at 0x20b7656ba90>,
#  'milton': <gensim.models.keyedvectors.Vocab at 0x20b7656baf0>,
#  'exact': <gensim.models.keyedvectors.Vocab at 0x20b7656bb50>,
#  'raspberri': <gensim.models.keyedvectors.Vocab at 0x20b7656bbb0>,
#  'invis': <gensim.models.keyedvectors.Vocab at 0x20b7656bc10>,
#  ...}

# %%
import sc

# %%
embedding = sc.Embedding('autotagger.tsv')

# %%
all_text = embedding.preprocessing()

# %%
all_text
# Out:
# [['addi',
#   'flip',
#   'black',
#   'bin',
#   'dispos',
#   'unwant',
#   'rubbish',
#   'have',
#   'touch',
#   'bin',
#   'qualiti',
#   'pedal',
#   'bin',
#   'simpli',
#   'open',
#   'foot',
#   'drop',
#   'garbag',
#   'trash',
#   'bag'],
#  ['brm',
#   'peri',
#   'peri',
#   'spatchcock',
#   'chicken',
#   'fulli',
#   'cook',
#   'nreadi',
#   'minut',
#   'ncook',
#   'tender',
#   'marin',
#   'famou',
#   'peri',
#   'peri',
#   'sauc',
#   'nkeep',
#   'refriger',
#   'nbrm',
#   'spatchcock',
#   'chicken',
#   'fulli',
#   'cook',
#   'peri',
#   'peri',
#   'sauc'],
#  ['crush', 'ginger', 'perfect', 'stew', 'curri'],
#  ['uss', 'vsop', 'cognac', 'uss', 'vsop', 'cognac'],
#  ['dettol',
#   'liquid',
#   'bathroom',
#   'cleaner',
#   'ocean',
#   'fresh',
#   'ndettol',
#   'liquid',
#   'bathroom',
#   'cleaner',
#   'ocean',
#   'fresh'],
#  ['frozen', 'mix', 'berri', 'special', 'selecet'],
#  ['glad',
#   'small',
#   'zipper',
#   'freezer',
#   'bag',
#   'glad',
#   'freezer',
#   'bag',
#   'strong',
#   'suitabl',
#   'freez',
#   'type',
#   'food',
#   'includ',
#   'bag',
#   'tie',
#   'seal',
#   'fresh',
#   'minim',
#   'freezer',
#   'burn'],
#  ['johnni', 'walker', 'black', 'label', 'whiski'],
#  ['orang', 'special', 'select'],
#  ['qualifresh', 'crush', 'garlic', 'special', 'select'],
#  ['strawberri', 'fresh'],
#  ['soft',
#   'rye',
#   'bread',
#   'soft',
#   'mild',
#   'rye',
#   'bread',
#   'wheat',
#   'flour',
#   'rye',
#   'flour',
#   'carawai',
#   'seed',
#   'sourdough',
#   'slow',
#   'ferment',
#   'result',
#   'uniqu',
#   'flavour'],
#  ['beef',
#   'rib',
#   'fulli',
#   'cook',
#   'readi',
#   'minut',
#   'cook',
#   'tender',
#   'marin',
#   'famou',
#   'sweet',
#   'sticki',
#   'bbq',
#   'bast',
#   'sauc',
#   'nkeep',
#   'refriger',
#   'premium',
#   'qualiti',
#   'beef',
#   'rib'],
#  ['pork',
#   'loin',
#   'rib',
#   'fulli',
#   'cook',
#   'readi',
#   'minut',
#   'ncook',
#   'tender',
#   'marin',
#   'famou',
#   'sweet',
#   'sticki',
#   'bbq',
#   'bast',
#   'sauc',
#   'refriger',
#   'npork',
#   'loin',
#   'babi',
#   'rib',
#   'ultim',
#   'cut',
#   'rib'],
#  ['bean',
#   'salad',
#   'punnet',
#   'salad',
#   'dish',
#   'consist',
#   'mix',
#   'piec',
#   'food',
#   'typic',
#   'raw',
#   'ingredi',
#   'dress',
#   'typic',
#   'serv',
#   'room',
#   'temperatur',
#   'chill'],
#  ['wash', 'treat', 'wash', 'treat'],
#  ['leav', 'condition', 'leav', 'condition'],
#  ['ac', 'super', 'maiz', 'meal', 'maiz', 'meal'],
#  ['adco', 'hygien', 'surfac', 'disinfect'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['adco',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel',
#   'safe',
#   'heaalthi',
#   'clean',
#   'hand',
#   'power',
#   'hygien',
#   'waterless',
#   'hand',
#   'gel'],
#  ['addi',
#   'mini',
#   'flip',
#   'flap',
#   'bin',
#   'dispos',
#   'unwant',
#   'rubbish',
#   'have',
#   'touch',
#   'bin',
#   'qualiti',
#   'pedal',
#   'bin',
#   'simpli',
#   'open',
#   'foot',
#   'drop',
#   'garbag',
#   'trash',
#   'bag'],
#  ['addi',
#   'dish',
#   'terri',
#   'towel',
#   'wash',
#   'wipe',
#   'dry',
#   'dust',
#   'us',
#   'chemic',
#   'nthe',
#   'microfib',
#   'dirt',
#   'attract',
#   'hold',
#   'seven',
#   'time',
#   'weight',
#   'dirt',
#   'grime',
#   'liquid',
#   'super',
#   'absorb',
#   'leav',
#   'lint',
#   'streak',
#   'safe',
#   'us',
#   'surfac',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['addi',
#   'dustpan',
#   'brush',
#   'blue',
#   'set',
#   'addi',
#   'dustpan',
#   'brush',
#   'set',
#   'nour',
#   'brush',
#   'scrub',
#   'finest',
#   'bristl',
#   'special',
#   'design',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nwhat',
#   'box',
#   'dustpan',
#   'brush',
#   'nfeatur',
#   'finest',
#   'bristl',
#   'make',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nspecif',
#   'colour',
#   'blue',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'dustpan',
#   'brush',
#   'granit',
#   'set',
#   'addi',
#   'dustpan',
#   'brush',
#   'set',
#   'nour',
#   'brush',
#   'scrub',
#   'finest',
#   'bristl',
#   'special',
#   'design',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nwhat',
#   'box',
#   'dustpan',
#   'brush',
#   'nfeatur',
#   'finest',
#   'bristl',
#   'make',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'nspecif',
#   'colour',
#   'blue',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'floor',
#   'broom',
#   'addi',
#   'floor',
#   'broom',
#   'natur',
#   'nfloor',
#   'broom',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nfeatur',
#   'handl',
#   'includ',
#   'metal',
#   'hanger',
#   'easi',
#   'storag',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nspecif',
#   'materi',
#   'plastic',
#   'colour',
#   'natur',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'floor',
#   'broom',
#   'addi',
#   'floor',
#   'broom',
#   'natur',
#   'nfloor',
#   'broom',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nfeatur',
#   'handl',
#   'includ',
#   'metal',
#   'hanger',
#   'easi',
#   'storag',
#   'synthet',
#   'bristl',
#   'colour',
#   'end',
#   'nspecif',
#   'materi',
#   'plastic',
#   'colour',
#   'natur',
#   'dimens',
#   'weight',
#   'warranti',
#   'base',
#   'manufactur',
#   'default'],
#  ['addi',
#   'floor',
#   'polish',
#   'brush',
#   'select',
#   'clean',
#   'brush',
#   'help',
#   'deal',
#   'grime',
#   'germ',
#   'home',
#   'fresh',
#   'clean'],
#  ['addi',
#   'granit',
#   'toilet',
#   'brush',
#   'set',
#   'brush',
#   'scrub',
#   'finest',
#   'bristl',
#   'special',
#   'design',
#   'clean',
#   'challeng',
#   'quick',
#   'easi',
#   'clean',
#   'toilet',
#   'eas'],
#  ['addi',
#   'gutter',
#   'sweeper',
#   'pvc',
#   'pvc',
#   'ngutter',
#   'sweeper',
#   'nhard',
#   'broom',
#   'exterior',
#   'us'],
#  ['addi',
#   'laundri',
#   'basket',
#   'grei',
#   'steel',
#   'addi',
#   'slot',
#   'laundri',
#   'basket',
#   'grei',
#   'nwhen',
#   'wash',
#   'mop',
#   'soak',
#   'dai',
#   'addi',
#   'water',
#   'support',
#   'team',
#   'matter',
#   'hard',
#   'chore',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'colour',
#   'grei',
#   'dimens',
#   'weight'],
#  ['addi',
#   'mop',
#   'addi',
#   'anti',
#   'bacteri',
#   'mop',
#   'nwelcom',
#   'futur',
#   'love',
#   'clean',
#   'latest',
#   'technolog',
#   'smartest',
#   'idea',
#   'bring',
#   'innov',
#   'home',
#   'clean',
#   'solut',
#   'help',
#   'quick',
#   'easi',
#   'thorough',
#   'clean',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['addi',
#   'mop',
#   'addi',
#   'anti',
#   'bacteri',
#   'mop',
#   'nwelcom',
#   'futur',
#   'love',
#   'clean',
#   'latest',
#   'technolog',
#   'smartest',
#   'idea',
#   'bring',
#   'innov',
#   'home',
#   'clean',
#   'solut',
#   'help',
#   'quick',
#   'easi',
#   'thorough',
#   'clean',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['addi',
#   'terri',
#   'swab',
#   'addi',
#   'microfib',
#   'terri',
#   'swab',
#   'super',
#   'absorb',
#   'hold',
#   'time',
#   'weight',
#   'water',
#   'dirt',
#   'grime',
#   'open',
#   'space',
#   'fiber',
#   'hold',
#   'dust',
#   'dirt',
#   'oil',
#   'wash',
#   'mild',
#   'soap',
#   'deterg',
#   'clean',
#   'method',
#   'environment',
#   'friendli'],
#  ['addi',
#   'wet',
#   'mop',
#   'addi',
#   'wet',
#   'mop',
#   'nwelcom',
#   'futur',
#   'love',
#   'clean',
#   'latest',
#   'technolog',
#   'smartest',
#   'idea',
#   'bring',
#   'innov',
#   'home',
#   'clean',
#   'solut',
#   'help',
#   'quick',
#   'easi',
#   'thorough',
#   'clean',
#   'nfeatur',
#   'materi',
#   'plastic',
#   'dimens',
#   'weight'],
#  ['airmun',
#   'effervesc',
#   'tablet',
#   'airmun',
#   'combin',
#   'healthi',
#   'diet',
#   'support',
#   'immun'],
#  ['airwav',
#   'blackcurr',
#   'flavour',
#   'sugar',
#   'free',
#   'gum',
#   'chew',
#   'sugar',
#   'free',
#   'gum',
#   'eat',
#   'drink',
#   'increas',
#   'product',
#   'saliva',
#   'increas',
#   'saliva',
#   'flow',
#   'help',
#   'neutralis',
#   'plaqu',
#   'acid',
#   'help',
#   'maintain',
#   'tooth',
#   'mineralis',
#   'help',
#   'reduc',
#   'oral',
#   'dryness'],
#  ['airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'lavend',
#   'xml',
#   'airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'lavend',
#   'xml'],
#  ['airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'turquois',
#   'oasi',
#   'xml',
#   'airwick',
#   'electr',
#   'gadget',
#   'refil',
#   'turquois',
#   'oasi',
#   'xml'],
#  ['albani',
#   'hotdog',
#   'brown',
#   'roll',
#   'brown',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer'],
#  ['albani',
#   'hotdog',
#   'brown',
#   'roll',
#   'brown',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer'],
#  ['albani',
#   'hotdog',
#   'brown',
#   'roll',
#   'brown',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer'],
#  ['albani',
#   'superior',
#   'best',
#   'white',
#   'bread',
#   'albani',
#   'offer',
#   'comprehens',
#   'rang',
#   'bake',
#   'good',
#   'south',
#   'africa',
#   'option',
#   'famili',
#   'member',
#   'individual’',
#   'tast',
#   'lifestyl',
#   'nalbani',
#   'deliv',
#   'longer',
#   'last',
#   'fresh',
#   'bigger',
#   'consist',
#   'slice',
#   'better',
#   'textur',
#   'innov',
#   'packag',
#   'superior',
#   'qualiti',
#   'ngreat',
#   'tast',
#   'meet',
#   'balanc',
#   'lifestyl',
#   'albani',
#   'ultima',
#   'health',
#   'rang',
#   'avail',
#   'multigrain',
#   'brown',
#   'bread',
#   'rooibo',
#   'rye',
#   'brown',
#   'bread',
#   'approv',
#   'heart',
#   'stroke',
#   'foundat',
#   'it’',
#   'ultim',
#   'heart',
#   'smart',
#   'choic'],
#  ['albani',
#   'superior',
#   'best',
#   'white',
#   'bread',
#   'albani',
#   'offer',
#   'comprehens',
#   'rang',
#   'bake',
#   'good',
#   'south',
#   'africa',
#   'option',
#   'famili',
#   'member',
#   'individual’',
#   'tast',
#   'lifestyl',
#   'nalbani',
#   'deliv',
#   'longer',
#   'last',
#   'fresh',
#   'bigger',
#   'consist',
#   'slice',
#   'better',
#   'textur',
#   'innov',
#   'packag',
#   'superior',
#   'qualiti',
#   'ngreat',
#   'tast',
#   'meet',
#   'balanc',
#   'lifestyl',
#   'albani',
#   'ultima',
#   'health',
#   'rang',
#   'avail',
#   'multigrain',
#   'brown',
#   'bread',
#   'rooibo',
#   'rye',
#   'brown',
#   'bread',
#   'approv',
#   'heart',
#   'stroke',
#   'foundat',
#   'it’',
#   'ultim',
#   'heart',
#   'smart',
#   'choic'],
#  ['albani',
#   'superior',
#   'brown',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'brown',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'low',
#   'slice',
#   'brown',
#   'seed',
#   'bread',
#   'seed',
#   'pack',
#   'wholewheat',
#   'loaf',
#   'high',
#   'fibr',
#   'load',
#   'energi',
#   'long',
#   'last',
#   'fresh'],
#  ['albani',
#   'superior',
#   'low',
#   'slice',
#   'brown',
#   'seed',
#   'bread',
#   'seed',
#   'pack',
#   'wholewheat',
#   'loaf',
#   'high',
#   'fibr',
#   'load',
#   'energi',
#   'long',
#   'last',
#   'fresh'],
#  ['albani',
#   'superior',
#   'low',
#   'slice',
#   'brown',
#   'seed',
#   'bread',
#   'seed',
#   'pack',
#   'wholewheat',
#   'loaf',
#   'high',
#   'fibr',
#   'load',
#   'energi',
#   'long',
#   'last',
#   'fresh'],
#  ['albani',
#   'superior',
#   'low',
#   'white',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'low',
#   'white',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'slice',
#   'brown',
#   'bread',
#   'superior',
#   'brown',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'brown',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'bun',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'roll',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'roll',
#   'good',
#   'fresh',
#   'albani',
#   'superior',
#   'bread',
#   'roll',
#   'bun',
#   'bun',
#   'love',
#   'bake',
#   'stai',
#   'fresher',
#   'longer',
#   'number',
#   'uniqu',
#   'variant',
#   'enjoi',
#   'everydai',
#   'anytim'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'white',
#   'slice',
#   'bread',
#   'superior',
#   'white',
#   'loav',
#   'new',
#   'improv',
#   'recip',
#   'deliv',
#   'softer',
#   'white',
#   'bread'],
#  ['albani',
#   'superior',
#   'wheat',
#   'brown',
#   'bread',
#   'low',
#   'bake',
#   'famili',
#   'mind',
#   'understand',
#   'import',
#   'feel',
#   'fuller',
#   'longer',
#   'help',
#   'prevent',
#   'energi',
#   '‘high',
#   'lows’',
#   'wholewheat',
#   'brown',
#   'bread',
#   'high',
#   'fibr',
#   'help',
#   'famili',
#   'regular',
#   'healthi',
#   'provid',
#   'dai',
#   'energi',
#   'accomplish',
#   'dai',
#   'task'],
#  ['albani',
#   'superior',
#   'wheat',
#   'brown',
#   'bread',
#   'low',
#   'bake',
#   'famili',
#   'mind',
#   'understand',
#   'import',
#   'feel',
#   'fuller',
#   'longer',
#   'help',
#   'prevent',
#   'energi',
#   '‘high',
#   'lows’',
#   'wholewheat',
#   'brown',
#   'bread',
#   'high',
#   'fibr',
#   'help',
#   'famili',
#   'regular',
#   'healthi',
#   'provid',
#   'dai',
#   'energi',
#   'accomplish',
#   'dai',
#   'task'],
#  ['albani',
#   'superior',
#   'wheat',
#   'brown',
#   'bread',
#   'low',
#   'bake',
#   'famili',
#   'mind',
#   'understand',
#   'import',
#   'feel',
#   'fuller',
#   'longer',
#   'help',
#   'prevent',
#   'energi',
#   '‘high',
#   'lows’',
#   'wholewheat',
#   'brown',
#   'bread',
#   'high',
#   'fibr',
#   'help',
#   'famili',
#   'regular',
#   'healthi',
#   'provid',
#   'dai',
#   'energi',
#   'accomplish',
#   'dai',
#   'task'],
#  ['albani',
#   'tinki',
#   'strawberri',
#   'tingl',
#   'flavour',
#   'creami',
#   'spong',
#   'cake'],
#  ['albani',
#   'ultima',
#   'brown',
#   'bread',
#   'multigrain',
#   'multigrain',
#   'brown',
#   'high',
#   'fibr'],
#  ['albani',
#   'ultima',
#   'brown',
#   'kilojoul',
#   'control',
#   'bread',
#   'comprehens',
#   'rang',
#   'health',
#   'bread',
#   'provid',
#   'smart',
#   'carb',
#   'choic',
#   'rooibo',
#   'rye',
#   'brown',
#   'high',
#   'antioxid',
#   'vitamin',
#   'multigrain',
#   'brown',
#   'high',
#   'fibr',
#   'low',
#   'sustain',
#   'energi',
#   'kilojoul',
#   'control',
#   'brown',
#   'bread',
#   'low',
#   'fat',
#   'high',
#   'fibr',
#   'endors',
#   'heart',
#   'stroke',
#   'foundat',
#   'diabet'],
#  ['albani',
#   'ultima',
#   'brown',
#   'kilojoul',
#   'control',
#   'bread',
#   'comprehens',
#   'rang',
#   'health',
#   'bread',
#   'provid',
#   'smart',
#   'carb',
#   'choic',
#   'rooibo',
#   'rye',
#   'brown',
#   'high',
#   'antioxid',
#   'vitamin',
#   'multigrain',
#   'brown',
#   'high',
#   'fibr',
#   'low',
#   'sustain',
#   'energi',
#   'kilojoul',
#   'control',
#   'brown',
#   'bread',
#   'low',
#   'fat',
#   'high',
#   'fibr',
#   'endors',
#   'heart',
#   'stroke',
#   'foundat',
#   'diabet'],
#  ['albani',
#   'ultima',
#   'rooibo',
#   'rye',
#   'brown',
#   'bread',
#   'albani',
#   'freshli',
#   'bake',
#   'bread',
#   'nrooibo',
#   'rye',
#   'brown',
#   'bread'],
#  ['albani',
#   'valu',
#   'pack',
#   'brown',
#   'bread',
#   'slice',
#   'love',
#   'albany’',
#   'new',
#   'everydai',
#   'toaster',
#   'bread'],
#  ['albani',
#   'valu',
#   'pack',
#   'white',
#   'bread',
#   'slice',
#   'love',
#   'albany’',
#   'new',
#   'everydai',
#   'toaster',
#   'bread'],
#  ['allergex',
#   'non',
#   'drowsi',
#   'syrup',
#   'allergex',
#   'non',
#   'drowsi',
#   'relief',
#   'symptom',
#   'associ',
#   'allerg',
#   'rhiniti',
#   'sneez',
#   'rhinorrhea',
#   'runni',
#   'nose',
#   'itch',
#   'nose',
#   'throat',
#   'indic',
#   'relief',
#   'chronic',
#   'idiopath',
#   'urticaria',
#   'hive',
#   'allerg',
#   'dermatos',
#   'allerg',
#   'skin',
#   'reaction'],
#  ['almond',
#   'breez',
#   'milk',
#   'unsweeten',
#   'won',
#   'milk',
#   'almond',
#   'hand',
#   'best',
#   'qualiti',
#   'unsweet',
#   'milk',
#   'altern',
#   'almond',
#   'milk'],
#  ['everydai',
#   'liner',
#   'larg',
#   'unscent',
#   'odour',
#   'protect',
#   'nodour',
#   'neutral',
#   'technolog',
#   'feel',
#   'fresh',
#   'confid',
#   'dai',
#   'npanti',
#   'liner',
#   'protect',
#   'zone',
#   'improv',
#   'leakag',
#   'protect',
#   'soft',
#   'topsheet',
#   'ad',
#   'absorpt',
#   'comfort',
#   'soft',
#   'npanti',
#   'liner',
#   'dermatolog',
#   'test',
#   'gentl',
#   'skin'],
#  ['maxi',
#   'long',
#   'plu',
#   'duo',
#   'pad',
#   'maxi',
#   'sanitari',
#   'pad',
#   'feel',
#   'comfort',
#   'dai'],
#  ['maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'feel',
#   'comfort',
#   'night'],
#  ['maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'maxi',
#   'night',
#   'sanitari',
#   'pad',
#   'feel',
#   'comfort',
#   'night'],
#  ['maxi', 'night', 'sanitari', 'pad', 'leakag', 'protect'],
#  ['maxi',
#   'normal',
#   'sanitari',
#   'pad',
#   'maxi',
#   'hygien',
#   'pad',
#   'design',
#   'fit',
#   'curv',
#   'allow',
#   'help',
#   'protect',
#   'leak',
#   'sanitari',
#   'pad',
#   'featur',
#   'leakguard',
#   'core',
#   'plu',
#   'barrier',
#   'pull',
#   'fluid',
#   'deep',
#   'core',
#   'awai',
#   'edg',
#   'cotton',
#   'like',
#   'dri',
#   'weav',
#   'cover',
#   'clean',
#   'dry',
#   'protect',
#   'nmaximum',
#   'protect',
#   'sanitari',
#   'pad',
#   'size',
#   'wider',
#   'coverag',
#   'regular',
#   'long',
#   'super',
#   'overnight',
#   'hygien',
#   'pad',
#   'sanitari',
#   'pad',
#   'sign',
#   'protect',
#   'pad',
#   'best',
#   'protect',
#   'nactipearl',
#   'neutral',
#   'odour',
#   'mask',
#   'nsecur',
#   'guard',
#   'protect',
#   'contour',
#   'keep',
#   'fluid',
#   'check',
#   'nstai',
#   'wing',
#   'doubl',
#   'curv',
#   'wing',
#   'pad',
#   'place',
#   'ncotton',
#   'like',
#   'feel',
#   'sheet',
#   'super',
#   'soft',
#   'skin',
#   'nsuper',
#   'absorb',
#   'core',
#   'lock',
#   'fluid',
#   'awai'],
#  ['ultra',
#   'cotton',
#   'soft',
#   'normal',
#   'sanitari',
#   'pad',
#   'pad',
#   'safe',
#   'reliabl',
#   'materi',
#   'ultim',
#   'protect',
#   'comfort',
#   'sacrif',
#   'health',
#   'safeti',
#   'pad',
#   'trust',
#   'million',
#   'women',
#   'found'],
#  ['ultra',
#   'normal',
#   'sanitari',
#   'pad',
#   'ultra',
#   'extra',
#   'absorb',
#   'normal',
#   'sanitari',
#   'pad',
#   'wing',
#   'valu',
#   'pack'],
#  ['ultra',
#   'sanitari',
#   'night',
#   'pad',
#   'night',
#   'leakag',
#   'protect',
#   'anti',
#   'leakag',
#   'barrier',
#   'round',
#   'protect',
#   'leak'],
#  ['ultra',
#   'long',
#   'sanitari',
#   'pad',
#   'pad',
#   'safe',
#   'reliabl',
#   'materi',
#   'ultim',
#   'protect',
#   'comfort',
#   'sacrif',
#   'health',
#   'safeti',
#   'pad',
#   'trust',
#   'million',
#   'women',
#   'found'],
#  ['amaren', 'mix', 'berri'],
#  ['amaz', 'ball', 'coconut', 'amaz'],
#  ['amaz', 'ball', 'pretzel', 'amaz'],
#  ['amstel',
#   'lager',
#   'can',
#   'distinguish',
#   'ancestri',
#   'amstel',
#   'lager',
#   'began',
#   'friendship',
#   'dedic',
#   'develop',
#   'better',
#   'beer',
#   'amstel',
#   'set',
#   'bar',
#   'consist',
#   'high',
#   'qualiti',
#   'defin',
#   'premium',
#   'beer',
#   'south',
#   'africa',
#   'green',
#   'bottl',
#   'produc'],
#  ['annabel', 'cuvé', 'blanch', 'annabel', 'cuvé'],
#  ['appl',
#   'golden',
#   'delici',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['appl',
#   'granni',
#   'smith',
#   'granni',
#   'smith',
#   'appl',
#   'famou',
#   'sour',
#   'green',
#   'appl',
#   'flavor',
#   'strong',
#   'tart',
#   'flavor',
#   'bright',
#   'acid',
#   'tang',
#   'appl',
#   'incred',
#   'crisp',
#   'firm',
#   'juici'],
#  ['appl',
#   'red',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'sparkl',
#   'appletis',
#   'crisp',
#   'tast',
#   'enjoi',
#   'moment',
#   'nno',
#   'preserv'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'quench',
#   'thirst',
#   'amaz',
#   'appl',
#   'flavour',
#   'tiser'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'quench',
#   'thirst',
#   'amaz',
#   'appl',
#   'flavour',
#   'pack',
#   'tiser'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'quench',
#   'thirst',
#   'amaz',
#   'appl',
#   'flavour',
#   'tiser'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['appletis',
#   'sparkl',
#   'appl',
#   'juic',
#   'bottl',
#   'indulg',
#   'sparkl',
#   'appletis',
#   'expertli',
#   'blend',
#   'luxuri',
#   'appl',
#   'juic',
#   'make',
#   'moment',
#   'extraordinari',
#   'worth',
#   'celebr'],
#  ['aquafresh',
#   'littl',
#   'teeth',
#   'toothpast',
#   'aquafresh',
#   'help',
#   'defend',
#   'teeth',
#   'caviti',
#   'plaqu',
#   'regular',
#   'brush'],
#  ['aquel',
#   'natur',
#   'sparkl',
#   'spring',
#   'water',
#   'quench',
#   'thirst',
#   'amaz',
#   'sparkl',
#   'water',
#   'aquel'],
#  ['aquel',
#   'natur',
#   'sparkl',
#   'spring',
#   'water',
#   'quench',
#   'thirst',
#   'amaz',
#   'sparkl',
#   'water',
#   'aquel'],
#  ['aquel',
#   'natur',
#   'sparkl',
#   'spring',
#   'water',
#   'quench',
#   'thirst',
#   'amaz',
#   'sparkl',
#   'water',
#   'aquel'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'nenjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'sparkl',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'sparkl',
#   'water',
#   'litchi',
#   'like',
#   'refresh',
#   'burst',
#   'flavour',
#   'try',
#   'litchi',
#   'flavour',
#   'sparkl',
#   'water'],
#  ['aquel',
#   'sparkl',
#   'water',
#   'litchi',
#   'like',
#   'refresh',
#   'burst',
#   'flavour',
#   'try',
#   'litchi',
#   'flavour',
#   'sparkl',
#   'water'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['aquel',
#   'natur',
#   'spring',
#   'water',
#   'enjoi',
#   'except',
#   'tast',
#   'natur',
#   'spring',
#   'water',
#   'drawn',
#   'underground',
#   'spring'],
#  ['ariel',
#   'auto',
#   'deterg',
#   'capsul',
#   'ariel',
#   'pod',
#   'wash',
#   'capsul',
#   'come',
#   'multi',
#   'compart',
#   'design',
#   'keep',
#   'ingredi',
#   'separ',
#   'reach',
#   'wash',
#   'pack',
#   'super',
#   'concentr',
#   'clean',
#   'power',
#   'littl',
#   'pod',
#   'innov',
#   'film',
#   'dissolv',
#   'contact',
#   'water',
#   'releas',
#   'power',
#   'stain',
#   'remov',
#   'technolog'],
#  ['ariel',
#   'auto',
#   'concentr',
#   'wash',
#   'liquid',
#   'us',
#   'ariel',
#   'auto',
#   'wash',
#   'liquid',
#   'great',
#   'stain',
#   'fight',
#   'power',
#   'wash',
#   'litr',
#   'liquid',
#   'wash',
#   'powder',
#   'ariel',
#   'matic',
#   'powder'],
#  ['ariel', 'automat', 'anti', 'germ', 'wash', 'powder', 'ariel'],
#  ['ariel',
#   'automat',
#   'wash',
#   'liquid',
#   'ariel',
#   'wash',
#   'liquid',
#   'pre',
#   'treat',
#   'cap',
#   'give',
#   'outstand',
#   'stain',
#   'remov',
#   'wash'],
#  ['ariel',
#   'downi',
#   'auto',
#   'wash',
#   'powder',
#   'ariel',
#   'touch',
#   'fresh',
#   'downi',
#   'long',
#   'last',
#   'fresh',
#   'impecc',
#   'clean',
#   'wash'],
#  ['ariel',
#   'power',
#   'capsul',
#   'deterg',
#   'need',
#   'concentr',
#   'laundri',
#   'solut',
#   'innov',
#   'give',
#   'outstand',
#   'stain',
#   'remov',
#   'time',
#   'ariel',
#   'pod',
#   'need',
#   'wash',
#   'capsul',
#   'brows',
#   'power',
#   'pod',
#   'learn',
#   'dose',
#   'write',
#   'review',
#   'share',
#   'wash',
#   'capsul',
#   'experi',
#   'ariel',
#   'user'],
#  ['aspen', 'brooklax', 'lax', 'pack', 'relief', 'occasion', 'constip'],
#  ['blend',
#   'canola',
#   'oliv',
#   'oil',
#   'blend',
#   'canola',
#   'oliv',
#   'oil',
#   'best',
#   'choic',
#   'want',
#   'healthier'],
#  ['canola',
#   'mayo',
#   'reduc',
#   'oil',
#   'low',
#   'oil',
#   'mayonnais',
#   'reduc',
#   'fat',
#   'content',
#   'delici',
#   'concern',
#   'waistlin',
#   'choos',
#   'healthier',
#   'life',
#   'suitabl',
#   'enjoi',
#   'uniqu',
#   'benefit',
#   'except',
#   'function',
#   'mayonnais',
#   'wise',
#   'choic'],
#  ['canola', 'oil', 'canola', 'oil', 'healthier', 'option', 'satur', 'fat'],
#  ['canola', 'oil', 'canola', 'oil', 'healthier', 'option', 'satur', 'fat'],
#  ['canola',
#   'creami',
#   'mayo',
#   'like',
#   'tast',
#   'healthi',
#   'mayonnais',
#   'stimul',
#   'tast',
#   'bud'],
#  ['pure',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'extra',
#   'virgin',
#   'oil',
#   'contain',
#   'natur',
#   'vitamin',
#   'antioxid',
#   'oliv',
#   'high',
#   'monounsatur',
#   'fat',
#   'content',
#   'make',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'smart',
#   'choic',
#   'health'],
#  ['pure',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'extra',
#   'virgin',
#   'oil',
#   'contain',
#   'natur',
#   'vitamin',
#   'antioxid',
#   'oliv',
#   'high',
#   'monounsatur',
#   'fat',
#   'content',
#   'make',
#   'extra',
#   'virgin',
#   'oliv',
#   'oil',
#   'smart',
#   'choic',
#   'health'],
#  ['babi',
#   'butternut',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['babi',
#   'dove',
#   'rich',
#   'moistur',
#   'babi',
#   'soap',
#   'formul',
#   'moisturis',
#   'cream',
#   'hypoallergen',
#   'nourish',
#   'babi',
#   'bar',
#   'care',
#   'baby’',
#   'skin',
#   'suitabl',
#   'daili',
#   'us'],
#  ['babi',
#   'dove',
#   'rich',
#   'moistur',
#   'babi',
#   'soap',
#   'formul',
#   'moisturis',
#   'cream',
#   'hypoallergen',
#   'nourish',
#   'babi',
#   'bar',
#   'care',
#   'baby’',
#   'skin',
#   'suitabl',
#   'daili',
#   'us'],
#  ['babi',
#   'potato',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'toilet',
#   'roll',
#   'ply',
#   'white',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['babi',
#   'soft',
#   'white',
#   'ply',
#   'toilet',
#   'paper',
#   'babi',
#   'soft',
#   'fresh',
#   'white',
#   'toilet',
#   'tissu',
#   'special',
#   'micro',
#   'pillow',
#   'technolog',
#   'give',
#   'perfect',
#   'balanc',
#   'soft',
#   'strength',
#   'leav',
#   'famili',
#   'feel',
#   'clean',
#   'fresh',
#   'confid'],
#  ['bacardi', 'spice', 'spirit', 'aperitif', 'rum', 'bottl', 'rum'],
#  ['bake', 'vanilla', 'cupcak', 'bake'],
#  ['baker',
#   'betta',
#   'snack',
#   'caramel',
#   'chocol',
#   'wholewheat',
#   'digest',
#   'biscuit',
#   'betta',
#   'snack',
#   'caramel',
#   'choc',
#   'flavour',
#   'biscuit',
#   'grain',
#   'snack',
#   'easi',
#   'digest',
#   'good',
#   'stomach',
#   'sweet',
#   'fresh',
#   'crunchi',
#   'best',
#   'snack',
#   'bui',
#   'monei',
#   'tast',
#   'bud',
#   'ask'],
#  ['baker',
#   'betta',
#   'snack',
#   'milk',
#   'chocol',
#   'wholewheat',
#   'digest',
#   'biscuit',
#   'sun',
#   'drench',
#   'wheat',
#   'golden',
#   'syrup',
#   'origin',
#   'baker',
#   'digest',
#   'cooki',
#   'irresist'],
#  ['baker',
#   'blue',
#   'label',
#   'mari',
#   'biscuit',
#   'nthese',
#   'mari',
#   'biscuit',
#   'bake',
#   'origin',
#   'best',
#   'wai',
#   'us',
#   'base',
#   'fridg',
#   'tart',
#   'cheesecak',
#   'mash',
#   'baby’',
#   'tast',
#   'sweet',
#   'solid',
#   'simpli',
#   'enjoi',
#   'mari',
#   'biscuit',
#   'firm',
#   'favourit',
#   'tea'],
#  ['baker',
#   'blue',
#   'label',
#   'mari',
#   'biscuit',
#   'nthese',
#   'mari',
#   'biscuit',
#   'bake',
#   'origin',
#   'best',
#   'wai',
#   'us',
#   'base',
#   'fridg',
#   'tart',
#   'cheesecak',
#   'mash',
#   'baby’',
#   'tast',
#   'sweet',
#   'solid',
#   'simpli',
#   'enjoi',
#   'mari',
#   'biscuit',
#   'firm',
#   'favourit',
#   'tea'],
#  ['baker',
#   'chees',
#   'mini',
#   'cheddar',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'chees',
#   'mini',
#   'cheddar',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'choc',
#   'kit',
#   'chocol',
#   'oat',
#   'biscuit',
#   'crispi',
#   'golden',
#   'biscuit',
#   'fill',
#   'benefit',
#   'wheat',
#   'oat',
#   'sprinkl',
#   'coconut',
#   'winner',
#   'crispi',
#   'golden',
#   'biscuit',
#   'fill',
#   'benefit',
#   'wheat',
#   'oat',
#   'sprinkl',
#   'coconut',
#   'winner'],
#  ['baker',
#   'choic',
#   'assort',
#   'biscuit',
#   'delici',
#   'baker',
#   'red',
#   'label',
#   'lemon',
#   'cream',
#   'jam',
#   'fill',
#   'baker',
#   'strawberri',
#   'whirl',
#   'perfect',
#   'afternoon',
#   'tea',
#   'time'],
#  ['baker',
#   'cream',
#   'cracker',
#   'valu',
#   'pack',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'eet',
#   'sum',
#   'mor',
#   'choc',
#   'chip',
#   'quick',
#   'snack',
#   'lunch',
#   'choc',
#   'chip',
#   'want'],
#  ['baker',
#   'eet',
#   'sum',
#   'mor',
#   'shortbread',
#   'biscuit',
#   'baker',
#   'eet',
#   'sum',
#   'mor',
#   'shortbread',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'fruit',
#   'chutnei',
#   'mini',
#   'cheddar',
#   'pack',
#   'neach',
#   'delici',
#   'varieti',
#   'bring',
#   'special',
#   'sprinkl',
#   'baker',
#   'magic',
#   'occas'],
#  ['baker',
#   'good',
#   'morn',
#   'milk',
#   'cereal',
#   'biscuit',
#   'great',
#   'morn',
#   'snack',
#   'busi',
#   'dai'],
#  ['baker',
#   'good',
#   'morn',
#   'peach',
#   'apricot',
#   'breakfast',
#   'biscuit',
#   'baker',
#   'good',
#   'morn',
#   'provid',
#   'sourc',
#   'fibr',
#   'contain',
#   'wheat',
#   'barlei',
#   'oat',
#   'rye',
#   'lot',
#   'energi',
#   'good',
#   'start'],
#  ['baker',
#   'gossip',
#   'strawberri',
#   'baker',
#   'gossip',
#   'wafer',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'jolli',
#   'jammer',
#   'choc',
#   'cream',
#   'delici',
#   'butteri',
#   'biscuit',
#   'choc',
#   'cream',
#   'sandiwch',
#   'delight',
#   'smilei',
#   'face',
#   'bring',
#   'joi',
#   'sweet',
#   'treat'],
#  ['baker',
#   'mini',
#   'biscuit',
#   'zoofari',
#   'kid',
#   'biscuit',
#   'great',
#   'quick',
#   'snack',
#   'school'],
#  ['baker',
#   'mini',
#   'biscuit',
#   'zoofari',
#   'kid',
#   'biscuit',
#   'great',
#   'quick',
#   'snack',
#   'school'],
#  ['baker',
#   'mini',
#   'biscuit',
#   'zoofari',
#   'kid',
#   'biscuit',
#   'great',
#   'quick',
#   'snack',
#   'school'],
#  ['baker',
#   'mini',
#   'eet',
#   'sum',
#   'mor',
#   'biscuit',
#   'baker',
#   'eet',
#   'sum',
#   'mor',
#   'shortbread',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'provita',
#   'wheat',
#   'crispbread',
#   'health',
#   'focus',
#   'delici',
#   'high',
#   'fibr',
#   'low',
#   'biscuit',
#   'calori',
#   'serv',
#   'perfect',
#   'like',
#   'smash',
#   'avo',
#   'lick',
#   'creami',
#   'peanut',
#   'butter'],
#  ['baker',
#   'romani',
#   'cream',
#   'classic',
#   'chocol',
#   'biscuit',
#   'baker',
#   'romani',
#   'cream',
#   'classic',
#   'chocol',
#   'biscuit',
#   'best',
#   'ingredi',
#   'childhood',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['baker',
#   'strawberri',
#   'vanilla',
#   'whirl',
#   'biscuit',
#   'baker',
#   'strawberri',
#   'vanilla',
#   'flavour',
#   'whirl',
#   'biscuit',
#   'best',
#   'ingredi',
#   'memori',
#   'gener',
#   'love',
#   'attent'],
#  ['beacon', 'mmmmallow', 'milk', 'chocol', 'mallow', 'egg', 'pack', 'egg'],
#  ['beef',
#   'biltong',
#   'beef',
#   'biltong',
#   'tradit',
#   'south',
#   'african',
#   'recip',
#   'mildli',
#   'spice',
#   'biltong',
#   'rich',
#   'meati',
#   'flavour',
#   'subtl',
#   'underton',
#   'coriand'],
#  ['beef', 'bone', 'avg', 'beef'],
#  ['beef', 'chuck', 'avg', 'fresh', 'beef', 'meat'],
#  ['beef', 'chuck', 'avg', 'fresh', 'beef', 'meat'],
#  ['beef', 'chuck', 'avg', 'fresh', 'beef', 'meat'],
#  ['beef',
#   'dry',
#   'wor',
#   'biltong',
#   'drywor',
#   'tradit',
#   'ndri',
#   'cure',
#   'nthin',
#   'beef',
#   'sausag',
#   'nspice',
#   'season',
#   'flavour',
#   'perfect',
#   'nseason',
#   'delici',
#   'tradit',
#   'recip'],
#  ['beef',
#   'liver',
#   'avg',
#   'beef',
#   'liver',
#   'special',
#   'select',
#   'flavour',
#   'tender',
#   'nthi',
#   'random',
#   'mass',
#   'product',
#   'averag',
#   'mass',
#   'displai'],
#  ['beef', 'short', 'rib', 'avg', 'beef'],
#  ['beef', 'short', 'rib', 'avg', 'beef'],
#  ['beef', 'short', 'rib', 'avg', 'beef'],
#  ['beefeat',
#   'gin',
#   'blood',
#   'orang',
#   'beefeat',
#   'blood',
#   'orang',
#   'london',
#   'dry',
#   'gin'],
#  ['beetroot',
#   'salad',
#   'punnet',
#   'home',
#   'plant',
#   'base',
#   'recip',
#   'beetroot',
#   'salad',
#   'njump',
#   'recipe·print',
#   'recip',
#   'nthi',
#   'healthi',
#   'nutriti',
#   'raw',
#   'vegan',
#   'beetroot',
#   'salad',
#   'quick',
#   'easi',
#   'make',
#   'delici',
#   'plant',
#   'base',
#   'salad',
#   'spring',
#   'summer',
#   'light',
#   'simpl',
#   'beetroot',
#   'feta',
#   'salad',
#   'balsam',
#   'dress',
#   'spiralis',
#   'fresh',
#   'beetroot',
#   'vegan',
#   'feta',
#   'chees',
#   'pepita'],
#  ['belgravia', 'london', 'dry', 'gin'],
#  ['belgravia', 'non', 'alcohol', 'gin', 'dry', 'lemon', 'non', 'alcohol'],
#  ['belgravia', 'non', 'alcohol', 'gin', 'tonic', 'non', 'alcohol'],
#  ['bennett',
#   'aqueou',
#   'cream',
#   'pump',
#   'fragranc',
#   'free',
#   'endors',
#   'dermatologist',
#   'colour',
#   'fragranc',
#   'free',
#   'recommend',
#   'bath',
#   'babi',
#   'week',
#   'baby’',
#   'life',
#   'prevent',
#   'skin',
#   'dry',
#   'recommend',
#   'moisturis',
#   'baby’',
#   'skin',
#   'bath',
#   'keep',
#   'baby’',
#   'skin',
#   'soft',
#   'moist',
#   'birth'],
#  ['bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'fragranc',
#   'bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'fragranc',
#   'effect',
#   'gentl',
#   'moisturis',
#   'altern',
#   'harsh',
#   'soap',
#   'bath',
#   'babi'],
#  ['bennett',
#   'babi',
#   'aqueou',
#   'fragranc',
#   'free',
#   'cream',
#   'endors',
#   'dermatologist',
#   'colour',
#   'fragranc',
#   'free',
#   'recommend',
#   'bath',
#   'babi',
#   'week',
#   'baby’',
#   'life',
#   'prevent',
#   'skin',
#   'dry',
#   'recommend',
#   'moisturis',
#   'baby’',
#   'skin',
#   'bath',
#   'keep',
#   'baby’',
#   'skin',
#   'soft',
#   'moist',
#   'birth'],
#  ['bennett',
#   'babi',
#   'aqueou',
#   'pump',
#   'fragranc',
#   'babi',
#   'aqueou',
#   'cream',
#   'pump',
#   'fragranc',
#   'sale',
#   'nbennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'pump',
#   'fragranc',
#   'nfast',
#   'effici',
#   'deliveri',
#   'nationwid',
#   'nfree',
#   'deliveri',
#   'order',
#   'deliveri',
#   'fee',
#   'order',
#   'dai',
#   'hassl',
#   'return',
#   'polici',
#   'nmanufactur',
#   'warranti',
#   'nsecur',
#   'check',
#   'payment',
#   'option',
#   'endors',
#   'dermatologist',
#   'slightli',
#   'fragranc',
#   'babi',
#   'pink',
#   'colour',
#   'recommend',
#   'babi',
#   'month',
#   'toddler',
#   'ag',
#   'babi',
#   'sensit',
#   'easili',
#   'irrit',
#   'skin'],
#  ['bennett', 'babi', 'bum', 'cream', 'tube', 'nthe', 'bum', 'cream', 'need'],
#  ['bennett',
#   'babi',
#   'eazi',
#   'breath',
#   'kit',
#   'congest',
#   'babi',
#   'unhappi',
#   'babi'],
#  ['bennett',
#   'babi',
#   'fragranc',
#   'free',
#   'aqueou',
#   'cream',
#   'bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'altern',
#   'soap',
#   'gentli',
#   'bath',
#   'babi'],
#  ['bennett',
#   'babi',
#   'wipe',
#   'moistur',
#   'stai',
#   'wipe',
#   'us',
#   'sensit',
#   'skin',
#   'durabl',
#   'soft',
#   'good',
#   'qualiti',
#   'wet',
#   'wipe'],
#  ['bennett',
#   'famili',
#   'care',
#   'hygien',
#   'wipe',
#   'hand',
#   'surfac',
#   'sanitis',
#   'wipe',
#   'alcohol',
#   'nalso',
#   'avail',
#   'pack'],
#  ['bennett',
#   'fragranc',
#   'babi',
#   'aqueou',
#   'cream',
#   'bennett',
#   'babi',
#   'aqueou',
#   'cream',
#   'effect',
#   'moisturis',
#   'altern',
#   'soap',
#   'bath',
#   'babi'],
#  ['bennett',
#   'hair',
#   'bodi',
#   'wash',
#   'moisturis',
#   'hr',
#   'clinic',
#   'test',
#   'mild',
#   'fragranc',
#   'free',
#   'suitabl',
#   'birth'],
#  ['bennett', 'hygien', 'wipe', 'hygien', 'famili', 'care', 'wipe'],
#  ['bennett',
#   'nippl',
#   'cream',
#   'bennett',
#   'nippl',
#   'cream',
#   'breastfeed',
#   'mother',
#   'special',
#   'formul',
#   'easili',
#   'absorb',
#   'help',
#   'sooth',
#   'crack',
#   'sore',
#   'nippl',
#   'suitabl',
#   'sensit',
#   'skin',
#   'need',
#   'wash',
#   'feed',
#   'babi',
#   'clinic',
#   'test',
#   'mild',
#   'dermatolog',
#   'approv'],
#  ['bennett',
#   'salin',
#   'nose',
#   'sprai',
#   'mom',
#   'want',
#   'babi',
#   'suffer',
#   'block',
#   'nose',
#   'occur',
#   'simpli',
#   'us',
#   'bennett',
#   'salin',
#   'nose',
#   'drop'],
#  ['bennett',
#   'salin',
#   'nose',
#   'sprai',
#   'aspir',
#   'babi',
#   'healthi',
#   'cough',
#   'flu',
#   'free',
#   'bennett',
#   'salin',
#   'nose',
#   'sprai',
#   'aspir'],
#  ['bennett',
#   'wash',
#   'bodi',
#   'hair',
#   'bennett',
#   'hair',
#   'bodi',
#   'wash',
#   'mild',
#   'moisturis',
#   'formul',
#   'gentli',
#   'effect',
#   'cleans',
#   'baby’',
#   'hair',
#   'skin'],
#  ['benylin',
#   'wet',
#   'cough',
#   'mucu',
#   'benylin',
#   'wet',
#   'cough',
#   'mucu',
#   'relief',
#   'syrup',
#   'fast',
#   'act',
#   'syrup',
#   'help',
#   'silenc',
#   'hack',
#   'disrupt',
#   'cough',
#   'dai',
#   'special',
#   'formul',
#   'loosen',
#   'chest',
#   'mucu',
#   'expel',
#   'cough',
#   'provid',
#   'quick',
#   'relief',
#   'cough',
#   'catarrh'],
#  ['bepanthen',
#   'babi',
#   'ointment',
#   'bepanthen',
#   'contain',
#   'dexpanthenol',
#   'pro',
#   'vitamin',
#   'gentli',
#   'help',
#   'sensit',
#   'skin',
#   'repair',
#   'natur',
#   'protect',
#   'barrier',
#   'keep',
#   'soft',
#   'smooth',
#   'moisturis'],
#  ['bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'sooth',
#   'repair',
#   'protect',
#   'babi',
#   'sensit',
#   'skin'],
#  ['bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'bepanthen',
#   'nappi',
#   'care',
#   'ointment',
#   'sooth',
#   'repair',
#   'protect',
#   'babi',
#   'sensit',
#   'skin'],
#  ['bernini',
#   'amber',
#   'product',
#   'weight',
#   'kgproduct',
#   'dimensionsmm',
#   'ship',
#   'weight',
#   'kgship',
#   'dimensionsmm'],
#  ['berocca',
#   'boost',
#   'liquid',
#   'energi',
#   'sachet',
#   'berocca',
#   'boost',
#   'couldn',
#   'appropri',
#   'name',
#   'delici',
#   'tast',
#   'drink',
#   'contain',
#   'guarana',
#   'help',
#   'mental',
#   'physic',
#   'boost',
#   'need'],
#  ['berocca',
#   'boost',
#   'guarana',
#   'effervesc',
#   'tablet',
#   'berocca',
#   'boost',
#   'specif',
#   'tailor',
#   'vitamin',
#   'miner',
#   'supplement',
#   'help',
#   'enhanc',
#   'mental',
#   'physic',
#   'perform',
#   'taken',
#   'daili'],
#  ['berocca',
#   'boost',
#   'guarana',
#   'effervesc',
#   'tablet',
#   'berocca',
#   'boost',
#   'specif',
#   'tailor',
#   'vitamin',
#   'miner',
#   'supplement',
#   'help',
#   'enhanc',
#   'mental',
#   'physic',
#   'perform',
#   'taken',
#   'daili'],
#  ['berocca',
#   'boost',
#   'guarana',
#   'effervesc',
#   'tablet',
#   'berocca',
#   'boost',
#   'specif',
#   'tailor',
#   'vitamin',
#   'miner',
#   'supplement',
#   'help',
#   'enhanc',
#   'mental',
#   'physic',
#   'perform',
#   'taken',
#   'daili'],
#  ['berocca',
#   'multi',
#   'vitamin',
#   'effervesc',
#   'tablet',
#   'tropic',
#   'nberocca',
#   'perform',
#   'combin',
#   'vitamin',
#   'vitamin',
#   'essenti',
#   'miner',
#   'like',
#   'calcium',
#   'magnesium',
#   'zinc',
#   'work',
#   'support',
#   'mental',
#   'alert',
#   'physic',
#   'energi',
#   'dai'],
#  ['bic',
#   'classic',
#   'dispos',
#   'razer',
#   'come',
#   'pack',
#   'ndispos',
#   'shave',
#   'razor'],
#  ['bic',
#   'sensit',
#   'dispos',
#   'razor',
#   'come',
#   'pack',
#   'ndispos',
#   'sensit',
#   'razor'],
#  ['bic', 'assort', 'crystal', 'ballpoint', 'pen', 'pack', 'pen'],
#  ['bic',
#   'atlanti',
#   'medium',
#   'ballpoint',
#   'pen',
#   'black',
#   'box',
#   'medium',
#   'point',
#   'retract',
#   'ball',
#   'pen',
#   'grip',
#   'comfort',
#   'grip',
#   'cap',
#   'colour',
#   'match',
#   'ink',
#   'colour'],
#  ['bic',
#   'black',
#   'ball',
#   'point',
#   'pen',
#   'smooth',
#   'regular',
#   'write',
#   'brass',
#   'fine',
#   'point',
#   'line',
#   'width'],
#  ['bic',
#   'clic',
#   'ballpoint',
#   'pen',
#   'pack',
#   'black',
#   'medium',
#   'point',
#   'ball',
#   'pen',
#   'retract',
#   'push',
#   'button',
#   'visibl',
#   'ink',
#   'level',
#   'pocket',
#   'clip',
#   'nwhat',
#   'box',
#   'nbic',
#   'clic',
#   'medium',
#   'ballpoint',
#   'pen',
#   'black'],
#  ['bic',
#   'cristal',
#   'black',
#   'ballpoint',
#   'pen',
#   'pack',
#   'everydai',
#   'essenti',
#   'design',
#   'mind'],
#  ['bic',
#   'cristal',
#   'black',
#   'ballpoint',
#   'pen',
#   'pack',
#   'everydai',
#   'essenti',
#   'design',
#   'mind'],
#  ['bic', 'cristal', 'ball', 'pen', 'assort', 'pack', 'assort', 'pen'],
#  ['bic', 'crystal', 'fashion', 'pen', 'assort', 'pen'],
#  ['bic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'ballpoint',
#   'pen',
#   'blue',
#   'blister',
#   'pen'],
#  ['bic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'ballpoint',
#   'pen',
#   'blue',
#   'blister',
#   'pen'],
#  ['bic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'ballpoint',
#   'pen',
#   'black',
#   'classic',
#   'bic',
#   'crystal',
#   'origin',
#   'pen',
#   'world',
#   'best',
#   'sell',
#   'ballpoint',
#   'pen',
#   'nthi',
#   'medium',
#   'point',
#   'black',
#   'ink',
#   'lightweight',
#   'hexagon',
#   'pen',
#   'write',
#   'nthe',
#   'minim',
#   'design',
#   'icon',
#   'object',
#   'perman',
#   'collect',
#   'new',
#   'york',
#   'museum',
#   'modern',
#   'art',
#   'moma',
#   'mu',
#   'art',
#   'modern',
#   'pompid',
#   'centr',
#   'pari',
#   'nventil',
#   'cap',
#   'nwhat',
#   'box',
#   'nbic',
#   'crystal',
#   'medium',
#   'xtra',
#   'life',
#   'black',
#   'ballpoint',
#   'pen',
#   'pack'],
#  ['bic',
#   'evolut',
#   'origin',
#   'graphit',
#   'pencil',
#   'pen',
#   'pencil',
#   'marker',
#   'colour',
#   'correct',
#   'bic',
#   'stationeri',
#   'product',
#   'design',
#   'longest',
#   'us',
#   'meet',
#   'consum',
#   'need',
#   'school',
#   'home',
#   'offic'],
#  ['bic',
#   'firelight',
#   'pre',
#   'cut',
#   'cube',
#   'ght',
#   'braai',
#   'eas',
#   'bic',
#   'firelight',
#   'pack',
#   'pre',
#   'cut',
#   'cube',
#   'individu',
#   'wrap',
#   'foil',
#   'light',
#   'foil',
#   'low',
#   'odor',
#   'wax',
#   'base',
#   'formula',
#   'burn',
#   'minut',
#   'nwhat',
#   'box',
#   'firelight',
#   'cube'],
#  ['bic', 'kid', 'cascad', 'fibr', 'tip', 'pen', 'marker', 'pack', 'pen'],
#  ['bic',
#   'kid',
#   'evolut',
#   'tropicolour',
#   'color',
#   'pencil',
#   'colour',
#   'world',
#   'bic',
#   'colour',
#   'pencil'],
#  ['bic',
#   'metal',
#   'men',
#   'dispos',
#   'shave',
#   'razor',
#   'bic',
#   'metal',
#   'dispos',
#   'razor',
#   'pack',
#   'featur',
#   'uniqu',
#   'metal',
#   'guard',
#   'bar',
#   'protect',
#   'skin',
#   'close',
#   'comfort',
#   'shave'],
#  ['bic',
#   'metal',
#   'men',
#   'dispos',
#   'shave',
#   'razor',
#   'bic',
#   'metal',
#   'dispos',
#   'razor',
#   'pack',
#   'featur',
#   'uniqu',
#   'metal',
#   'guard',
#   'bar',
#   'protect',
#   'skin',
#   'close',
#   'comfort',
#   'shave'],
#  ['bic', 'orang', 'fine', 'ballpoint', 'pen', 'blue', 'pack', 'pen'],
#  ['bic',
#   'orang',
#   'fine',
#   'point',
#   'black',
#   'fine',
#   'point',
#   'ball',
#   'pen',
#   'ventil',
#   'cap',
#   'ideal',
#   'school',
#   'offic',
#   'home',
#   'write',
#   'ncap',
#   'ball',
#   'pen',
#   'fine',
#   'line',
#   'width',
#   'nhexagon',
#   'transpar',
#   'barrel',
#   'control',
#   'lead',
#   'level',
#   'nball',
#   'line',
#   'width',
#   'nperman',
#   'ink',
#   'nextra',
#   'strong',
#   'tungsten',
#   'carbid',
#   'ball',
#   'nwhat',
#   'box',
#   'nbic',
#   'orang',
#   'fine',
#   'ball',
#   'point',
#   'pen',
#   'black',
#   'pack'],
#  ['bic',
#   'orang',
#   'grip',
#   'fine',
#   'point',
#   'blue',
#   'fine',
#   'point',
#   'pen',
#   'pack',
#   'colour',
#   'blue'],
#  ['bic',
#   'orang',
#   'red',
#   'pen',
#   'pen',
#   'pencil',
#   'marker',
#   'colour',
#   'correct',
#   'bic',
#   'stationeri',
#   'product',
#   'design',
#   'longest',
#   'us',
#   'meet',
#   'consum',
#   'need',
#   'school',
#   'home',
#   'offic'],
#  ['bic',
#   'perman',
#   'marker',
#   'black',
#   'perman',
#   'surfac',
#   'won',
#   'dry',
#   'cap',
#   'left',
#   'week',
#   'low',
#   'odour',
#   'xylen',
#   'toluen'],
#  ['bic',
#   'perman',
#   'marker',
#   'blue',
#   'pack',
#   'blue',
#   'bic',
#   'perman',
#   'marker',
#   'rug',
#   'bullet',
#   'nib',
#   'creat',
#   'clean',
#   'line',
#   'width',
#   'nan',
#   'indel',
#   'pen',
#   'work',
#   'surfac',
#   'paper',
#   'cardboard',
#   'plastic',
#   'glass',
#   'metal',
#   'cd',
#   'nwhat',
#   'box',
#   'nbic',
#   'perman',
#   'marker',
#   'bullet',
#   'point',
#   'blue'],
#  ['bic', 'shatterproof', 'ruler', 'shaterproof', 'ruler'],
#  ['bic', 'twin', 'ladi', 'shaver', 'women'],
#  ['bic',
#   'velleda',
#   'whiteboard',
#   'fine',
#   'point',
#   'marker',
#   'whiteboard',
#   'fine',
#   'point',
#   'marker',
#   'nfeatur',
#   'pack',
#   'fix',
#   'bullet',
#   'tip',
#   'fine',
#   'line',
#   'width',
#   'low',
#   'odour',
#   'easi',
#   'eras',
#   'whiteboard',
#   'surfac'],
#  ['bio',
#   'oil',
#   'skincar',
#   'oil',
#   'natur',
#   'clinic',
#   'proven',
#   'reduc',
#   'appear',
#   'scar',
#   'stretch',
#   'mark',
#   'natur',
#   'formul',
#   'light',
#   'non',
#   'greasi',
#   'absorb',
#   'easili',
#   'boost',
#   'elast',
#   'promot',
#   'skin',
#   'regener'],
#  ['bio',
#   'oil',
#   'skincar',
#   'oil',
#   'bio',
#   'oil',
#   'world',
#   'lead',
#   'scar',
#   'stretch',
#   'mark',
#   'product'],
#  ['bio',
#   'oil',
#   'tissu',
#   'oil',
#   'bio',
#   'oil',
#   'specialist',
#   'skincar',
#   'product',
#   'formul',
#   'help',
#   'improv',
#   'appear',
#   'scar',
#   'stretch',
#   'mar',
#   'uneven',
#   'skin',
#   'tone',
#   'uniqu',
#   'formul',
#   'contain',
#   'breakthrough',
#   'ingredi',
#   'purcellin',
#   'oil™',
#   'highli',
#   'effect',
#   'ag',
#   'dehydr',
#   'skin',
#   'nvitamin',
#   'ncalendula',
#   'lavend',
#   'rosemari',
#   'chamomil',
#   'oil',
# ...
#   'greater',
#   'comfort',
#   'fit',
#   'protect'],
#  ['lil',
#   'let',
#   'smartfit',
#   'super',
#   'plu',
#   'tampon',
#   'non',
#   'applic',
#   'tampon',
#   'round',
#   'shape',
#   'smooth',
#   'cover',
#   'eas',
#   'insert'],
#  ['lil',
#   'let',
#   'smartfit',
#   'super',
#   'plu',
#   'tampon',
#   'lil',
#   'let',
#   'smartfit',
#   'non',
#   'applic',
#   'tampon',
#   'work',
#   'expand',
#   'wai',
#   'greater',
#   'comfort',
#   'fit',
#   'protect'],
#  ['lil',
#   'let',
#   'smartfit',
#   'super',
#   'tampon',
#   'lil',
#   'let',
#   'super',
#   'tampon',
#   'suitabl',
#   'medium',
#   'heavi',
#   'flow',
#   'dai'],
#  ['lil',
#   'let',
#   'smartfit',
#   'unscent',
#   'pantylin',
#   'ncushion',
#   'comfort',
#   'everydai',
#   'protect'],
#  ['lil', 'let', 'ultra', 'duo', 'pad', 'comfort', 'finest'],
#  ['lindt',
#   'le',
#   'grand',
#   'milk',
#   'hazelnut',
#   'lindt',
#   'le',
#   'grand',
#   'hazelnut',
#   'milk',
#   'chocol',
#   'passion',
#   'creat',
#   'lindt',
#   'master',
#   'swiss',
#   'chocolati',
#   'uniqu',
#   'blend',
#   'roast',
#   'nut',
#   'crunchi',
#   'caramel',
#   'nut',
#   'sliver',
#   'enrob',
#   'smooth',
#   'swiss',
#   'chocol',
#   'le',
#   'grand',
#   'irresist',
#   'crunchi'],
#  ['lion', 'match', 'unit', 'lion', 'match', 'unit'],
#  ['lipton',
#   'ic',
#   'tea',
#   'lemon',
#   'lipton',
#   'lemon',
#   'flavour',
#   'ic',
#   'tea',
#   'low',
#   'kilojoul',
#   'blend',
#   'good',
#   'tea',
#   'delici',
#   'flavour',
#   'lemon',
#   'enjoi',
#   'refresh',
#   'drink',
#   'low',
#   'calori',
#   'sugar'],
#  ['lipton', 'ic', 'tea', 'peach', 'lipton', 'ic', 'tea', 'peach'],
#  ['lipton',
#   'ic',
#   'tea',
#   'peach',
#   'lipton',
#   'peach',
#   'ic',
#   'tea',
#   'perfectli',
#   'infus',
#   'uniqu',
#   'blend',
#   'real',
#   'tea',
#   'peach',
#   'essenc',
#   'delici',
#   'tast',
#   'refresh',
#   'bodi',
#   'mind'],
#  ['lipton',
#   'ic',
#   'tea',
#   'peach',
#   'sugar',
#   'free',
#   'lipton',
#   'ic',
#   'tea',
#   'peach',
#   'sugar',
#   'free'],
#  ['lipton',
#   'peach',
#   'ic',
#   'tea',
#   'can',
#   'soft',
#   'drink',
#   'tea',
#   'extract',
#   'peach',
#   'flavour'],
#  ['liqui',
#   'fruit',
#   'berri',
#   'blaze',
#   'fruit',
#   'juic',
#   'blend',
#   'enrich',
#   'flavour',
#   'fruit',
#   'juic',
#   'blend',
#   'bring',
#   'best',
#   'natur',
#   'good'],
#  ['liqui',
#   'fruit',
#   'berri',
#   'blaze',
#   'fruit',
#   'juic',
#   'blend',
#   'enrich',
#   'flavour',
#   'fruit',
#   'juic',
#   'blend',
#   'bring',
#   'best',
#   'natur',
#   'good'],
#  ['liqui',
#   'fruit',
#   'breakfast',
#   'punch',
#   'fruit',
#   'juic',
#   'blend',
#   'liven',
#   'morn',
#   'hit',
#   'ground',
#   'run',
#   'readi',
#   'dai',
#   'pure',
#   'fruit',
#   'good',
#   'breakfast',
#   'punch',
#   'it’',
#   'refresh',
#   'mix',
#   'citru',
#   'fruit',
#   'need',
#   'stai',
#   'game'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'fruit',
#   'juic',
#   'blend',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl',
#   'it’',
#   'pure',
#   'fruit',
#   'good',
#   'perfect',
#   'wai',
#   'refresh',
#   'moment',
#   'leav',
#   'feel',
#   'invigor'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'fruit',
#   'juic',
#   'blend',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl',
#   'it’',
#   'pure',
#   'fruit',
#   'good',
#   'perfect',
#   'wai',
#   'refresh',
#   'moment',
#   'leav',
#   'feel',
#   'invigor'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'juic',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'juic',
#   'pure',
#   'crisp',
#   'refresh',
#   'treat',
#   'tast',
#   'bud',
#   'classic',
#   'crisp',
#   'tast',
#   'clear',
#   'appl'],
#  ['liqui',
#   'fruit',
#   'clear',
#   'appl',
#   'juic',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'clear',
#   'appl',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liqui',
#   'fruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liqui',
#   'fruit',
#   'litchi',
#   'fruit',
#   'juic',
#   'blend',
#   'nliqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'litchi',
#   'fruit',
#   'juic',
#   'blend',
#   'nliqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'long',
#   'life',
#   'orang',
#   'kick',
#   'dai',
#   'like',
#   'refresh',
#   'glass',
#   'orang',
#   'juic',
#   'treat',
#   'wholesom',
#   'good',
#   'leav',
#   'feel',
#   'good',
#   'readi',
#   'dai',
#   'best'],
#  ['liqui',
#   'fruit',
#   'mango',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'mango',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'mango',
#   'orang',
#   'juic',
#   'box',
#   'life',
#   'better',
#   'good',
#   'thing',
#   'come',
#   'like',
#   'mango',
#   'orang',
#   'liqui',
#   'fruit',
#   'refresh',
#   'recharg',
#   'flavour',
#   'that’',
#   'soft',
#   'smooth',
#   'fill',
#   'pure',
#   'fruit',
#   'good'],
#  ['liqui',
#   'fruit',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'start',
#   'dai',
#   'classic',
#   'beat',
#   'glass',
#   'liqui',
#   'fruit',
#   'orang',
#   'juic',
#   'dai',
#   'start',
#   'indulg',
#   'healthi',
#   'good',
#   'feel',
#   'good',
#   'readi',
#   'dai'],
#  ['liqui',
#   'fruit',
#   'orang',
#   'fruit',
#   'juic',
#   'blend',
#   'start',
#   'dai',
#   'classic',
#   'beat',
#   'glass',
#   'liqui',
#   'fruit',
#   'orang',
#   'juic',
#   'dai',
#   'start',
#   'indulg',
#   'healthi',
#   'good',
#   'feel',
#   'good',
#   'readi',
#   'dai'],
#  ['liqui',
#   'fruit',
#   'orang',
#   'juic',
#   'kick',
#   'dai',
#   'like',
#   'refresh',
#   'glass',
#   'orang',
#   'juic',
#   'treat',
#   'wholesom',
#   'good',
#   'leav',
#   'feel',
#   'good',
#   'readi',
#   'dai',
#   'best'],
#  ['liqui',
#   'fruit',
#   'red',
#   'grape',
#   'juic',
#   'juici',
#   'favourit',
#   'impress',
#   'fussiest',
#   'tast',
#   'bud',
#   'crisp',
#   'juici',
#   'refresh',
#   'tast',
#   'red',
#   'grape',
#   'it’',
#   'classic',
#   'it’',
#   'favourit',
#   'it’',
#   'refresh',
#   'life',
#   'wholesom',
#   'good'],
#  ['liqui',
#   'fruit',
#   'red',
#   'grape',
#   'juic',
#   'impress',
#   'fussiest',
#   'tast',
#   'bud',
#   'crisp',
#   'juici',
#   'refresh',
#   'tast',
#   'red',
#   'grape',
#   'it’',
#   'classic',
#   'it’',
#   'favourit',
#   'it’',
#   'refresh',
#   'life',
#   'wholesom',
#   'good'],
#  ['liqui',
#   'fruit',
#   'summer',
#   'pine',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liqui',
#   'fruit',
#   'summer',
#   'pine',
#   'fruit',
#   'juic',
#   'blend',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler',
#   'live',
#   'healthi',
#   'life',
#   'enjoi',
#   'feel',
#   'good',
#   'refresh',
#   'anytim'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'bui',
#   'liquifruit',
#   'cranberri',
#   'cooler',
#   'fruit',
#   'juic',
#   'blend',
#   'price',
#   'save'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'juic',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler'],
#  ['liquifruit',
#   'cranberri',
#   'cooler',
#   'juic',
#   'sweet',
#   'sharp',
#   'superbl',
#   'refresh',
#   'supercharg',
#   'dai',
#   'delici',
#   'refresh',
#   'cranberri',
#   'cooler'],
#  ['liquifruit',
#   'mango',
#   'orang',
#   'juic',
#   'favourit',
#   'life',
#   'better',
#   'good',
#   'thing',
#   'come',
#   'like',
#   'mango',
#   'orang',
#   'liqui',
#   'fruit',
#   'refresh',
#   'recharg',
#   'flavour',
#   'soft',
#   'smooth',
#   'fill',
#   'pure',
#   'fruit',
#   'good'],
#  ['liquifruit',
#   'mango',
#   'orang',
#   'juic',
#   'favourit',
#   'life',
#   'better',
#   'good',
#   'thing',
#   'come',
#   'like',
#   'mango',
#   'orang',
#   'liqui',
#   'fruit',
#   'refresh',
#   'recharg',
#   'flavour',
#   'soft',
#   'smooth',
#   'fill',
#   'pure',
#   'fruit',
#   'good'],
#  ['liquifruit',
#   'tropic',
#   'liqui',
#   'fruit',
#   'fruit',
#   'great',
#   'conveni',
#   'wai',
#   'add',
#   'extra',
#   'good',
#   'daili',
#   'diet'],
#  ['litchi',
#   'punnet',
#   'lyche',
#   'litchi',
#   'chinensi',
#   'known',
#   'litchi',
#   'liche',
#   'small',
#   'tropic',
#   'fruit',
#   'soapberri',
#   'famili',
#   'popular',
#   'fruit',
#   'famili',
#   'includ',
#   'rambutan',
#   'longan',
#   'lyche',
#   'ined',
#   'pink',
#   'red',
#   'leatheri',
#   'skin',
#   'remov',
#   'consumpt'],
#  ['loos',
#   'avocado',
#   'avocado',
#   'fruit',
#   'provid',
#   'substanti',
#   'healthi',
#   'monounsatur',
#   'fatti',
#   'acid',
#   'avocado',
#   'natur',
#   'nutrient',
#   'dens',
#   'food',
#   'contain',
#   'nearli',
#   'vitamin',
#   'miner',
#   'readi',
#   'eat'],
#  ['loos',
#   'babi',
#   'cabbag',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'banana',
#   'banana',
#   'popular',
#   'fruit',
#   'potenti',
#   'health',
#   'benefit',
#   'boost',
#   'digest',
#   'heart',
#   'health',
#   'thank',
#   'fiber',
#   'antioxid',
#   'content'],
#  ['loos', 'brown', 'onion', 'special', 'select'],
#  ['loos', 'fresh', 'celeri', 'loos', 'fresh', 'celeri'],
#  ['loos',
#   'grape',
#   'fruit',
#   'grapefruit',
#   'incred',
#   'healthi',
#   'food',
#   'includ',
#   'diet',
#   'high',
#   'nutrient',
#   'low',
#   'calori'],
#  ['loos',
#   'green',
#   'pepper',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'lemon',
#   'versatil',
#   'flavour',
#   'dish',
#   'add',
#   'favourit',
#   'cocktail',
#   'life',
#   'give',
#   'lemon',
#   'us'],
#  ['loos',
#   'mango',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'orang',
#   'orang',
#   'fruit',
#   'citru',
#   'speci',
#   'famili',
#   'rutacea',
#   'primarili',
#   'refer',
#   'citru',
#   'sinensi',
#   'call',
#   'sweet',
#   'orang',
#   'distinguish',
#   'relat',
#   'citru',
#   'aurantium',
#   'refer',
#   'bitter',
#   'orang'],
#  ['loos',
#   'pear',
#   'pear',
#   'tree',
#   'pear',
#   'fruit',
#   'medicin',
#   'peopl',
#   'us',
#   'pear',
#   'condit',
#   'includ',
#   'indigest',
#   'diarrhea',
#   'constip'],
#  ['loos',
#   'potato',
#   'potato',
#   'edibl',
#   'tuber',
#   'avail',
#   'worldwid',
#   'year',
#   'long',
#   'rel',
#   'cheap',
#   'grow',
#   'rich',
#   'nutrient',
#   'delici',
#   'treat'],
#  ['loos', 'red', 'onion', 'special', 'select'],
#  ['loos',
#   'red',
#   'pepper',
#   'nthe',
#   'bell',
#   'pepper',
#   'fruit',
#   'plant',
#   'grossum',
#   'cultivar',
#   'group',
#   'speci',
#   'capsicum',
#   'annuum',
#   'cultivar',
#   'plant',
#   'produc',
#   'fruit',
#   'differ',
#   'color',
#   'includ',
#   'red',
#   'yellow',
#   'orang',
#   'green',
#   'white',
#   'purpl',
#   'bell',
#   'pepper',
#   'group',
#   'pungent',
#   'chili',
#   'varieti',
#   'sweet',
#   'pepper'],
#  ['loos',
#   'red',
#   'pepper',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['loos',
#   'sweet',
#   'potato',
#   'sweet',
#   'potato',
#   'sweetpotato',
#   'dicotyledon',
#   'plant',
#   'belong',
#   'bindwe',
#   'morn',
#   'glori',
#   'famili',
#   'convolvulacea',
#   'larg',
#   'starchi',
#   'sweet',
#   'tast',
#   'tuber',
#   'root',
#   'root',
#   'veget',
#   'young',
#   'shoot',
#   'leav',
#   'eaten',
#   'green'],
#  ['loos',
#   'tomato',
#   'tomato',
#   'consum',
#   'divers',
#   'wai',
#   'raw',
#   'cook',
#   'dish',
#   'sauc',
#   'salad',
#   'drink',
#   'tomato',
#   'fruits—botan',
#   'classifi',
#   'berries—thei',
#   'commonli',
#   'culinarili',
#   'veget',
#   'ingredi',
#   'dish'],
#  ['loos',
#   'yellow',
#   'pepper',
#   'fresh',
#   'fruit',
#   'veget',
#   'sourc',
#   'need',
#   'ensur',
#   'wider',
#   'varieti',
#   'continu',
#   'tradition',
#   'season',
#   'fresh',
#   'produc',
#   'enjoi'],
#  ['lucozad', 'origin', 'energi', 'drink', 'high', 'vitamin', 'vitamin'],
#  ['lux',
#   'soft',
#   'caress',
#   'beauti',
#   'soap',
#   'lux',
#   'beauti',
#   'soap',
#   'notic',
#   'soft',
#   'skin',
#   'expertli',
#   'craft',
#   'silkess',
#   'delic',
#   'white',
#   'flower',
#   'nwash',
#   'hand',
#   'frequent',
#   'soap',
#   'water',
#   'best',
#   'defenc',
#   'spread',
#   'germ',
#   'accord',
#   'world',
#   'health',
#   'organis',
#   'nation',
#   'institut',
#   'communic',
#   'diseas'],
#  ['lux',
#   'soft',
#   'caress',
#   'beauti',
#   'soap',
#   'indulg',
#   'sens',
#   'lux',
#   'soft',
#   'caress',
#   'bath',
#   'soap',
#   'bar',
#   'smooth',
#   'radiant',
#   'skin'],
#  ['magnum',
#   'classic',
#   'ic',
#   'cream',
#   'pint',
#   'peel',
#   'open',
#   'tub',
#   'magnum',
#   'stapl',
#   'classic',
#   'ic',
#   'cream',
#   'lose',
#   'luxuri',
#   'fold',
#   'smooth',
#   'creami',
#   'vanilla',
#   'ic',
#   'cream',
#   'shard',
#   'delect',
#   'milk',
#   'chocol'],
#  ['maizena',
#   'gluten',
#   'free',
#   'corn',
#   'flour',
#   'maizena',
#   'gluten',
#   'free',
#   'corn',
#   'flour'],
#  ['malfi', 'arancia', 'malfi', 'gin'],
#  ['mama',
#   'pi',
#   'frozen',
#   'pepper',
#   'steak',
#   'pi',
#   'carefulli',
#   'puff',
#   'pastri',
#   'pi',
#   'fill',
#   'juici',
#   'steak',
#   'rich',
#   'pepper',
#   'sauc'],
#  ['mama',
#   'roast',
#   'chicken',
#   'frozen',
#   'pie',
#   'carefulli',
#   'puff',
#   'pastri',
#   'pi',
#   'fill',
#   'chicken',
#   'roast',
#   'flavour',
#   'gravi'],
#  ['mama',
#   'steak',
#   'kidnei',
#   'frozen',
#   'pi',
#   'carefulli',
#   'puff',
#   'pastri',
#   'pi',
#   'fill',
#   'juici',
#   'steak',
#   'kidnei',
#   'rich',
#   'gravi'],
#  ['mango', 'pack', 'fresh', 'mango', 'juici', 'delici'],
#  ['manhattan',
#   'jellyland',
#   'sour',
#   'worm',
#   'super',
#   'sour',
#   'super',
#   'sweet',
#   'super',
#   'tasti',
#   'sour',
#   'worm'],
#  ['manhattan',
#   'milk',
#   'bottl',
#   'creami',
#   'delici',
#   'shape',
#   'like',
#   'mini',
#   'milk',
#   'bottl'],
#  ['manhattan',
#   'speckl',
#   'chocol',
#   'candi',
#   'coat',
#   'belgian',
#   'milk',
#   'chocol',
#   'milki',
#   'centr',
#   'real',
#   'belgian',
#   'chocol'],
#  ['marlton',
#   'anti',
#   'slip',
#   'stainless',
#   'steel',
#   'dog',
#   'bowl',
#   'dog',
#   'bowl'],
#  ['marlton', 'healthi', 'centr', 'chicken', 'cat', 'cat', 'treat'],
#  ['marlton', 'healthi', 'centr', 'salmon', 'cat', 'cat', 'treat'],
#  ['med', 'gouda', 'mustard', 'seed', 'special', 'select'],
#  ['med',
#   'lemon',
#   'origin',
#   'sachet',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['med',
#   'lemon',
#   'origin',
#   'sachet',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['med',
#   'lemon',
#   'origin',
#   'sachet',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['med',
#   'lemon',
#   'cold',
#   'flu',
#   'hot',
#   'medic',
#   'med',
#   'lemon',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter',
#   'good',
#   'time',
#   'feel',
#   'better'],
#  ['med',
#   'lemon',
#   'lemon',
#   'menthol',
#   'vitamin',
#   'hot',
#   'medic',
#   'hot',
#   'medic',
#   'vitamin',
#   'flavour',
#   'cold',
#   'flu',
#   'fighter'],
#  ['miller', 'beer', 'bottl', 'premium', 'beer'],
#  ['milton', 'sterilis', 'fluid', 'kill', 'known', 'germ', 'includ', 'thrush'],
#  ['milton',
#   'sterilis',
#   'fluid',
#   'base',
#   'year',
#   'expertis',
#   'milton',
#   'care',
#   'famili',
#   'sterilis',
#   'hygien',
#   'world',
#   'war'],
#  ['milton',
#   'sterilis',
#   'surfac',
#   'sprai',
#   'ideal',
#   'disinfect',
#   'surfac',
#   'home',
#   'highchair',
#   'work',
#   'top',
#   'bathroom',
#   'potti',
#   'baby’',
#   'bath'],
#  ...]

# %%
w2v = embedding.word2vec(all_text)

# %%
w2v['skin']
# Out:
# array([ 0.8120286 , -1.075846  ,  0.3069056 , -0.11384587, -1.4837037 ,
#         0.23139429, -0.81555927,  1.9369663 , -1.1026706 , -1.011192  ],
#       dtype=float32)
