# %%
import requests
import json
import warnings

warnings.filterwarnings('ignore', message='Unverified HTTPS request')


def send_order_info_to_rakuten(order_data):
    try:
        # Big Commerce production
        BIG_COMMERCE_TOKEN = 'tdrrt2hz30x3b999dk2gvajr5e45wxs'
        STORE_HASH = 'gtc7x3vv2v'
        MID = 35610
        # Big Commerce sandbox
        # BIG_COMMERCE_TOKEN = '8r3ihw4kn5fwcn34z4zc5kr0n379log'
        # STORE_HASH = 'lh5zla80ko'
        customer_status = "NEW"
        conversion_type = "Sale"
        coupon_code = ""
        coupon_amount = 0

        # Rakuten request object
        
        selected_items = []
#         json_data = event.Data()
#         print(json_data, flush=True)
        # todo uncomment
        print("Rakuten affiliate get data goes into json", flush=True)
        rakuten = json.loads(json_data)
        print("Rakuten affiliate film data", flush=True)
        rakuten2 = rakuten["globale"]["details"]
        
        
        print(rakuten['globale']['details']['CustomerCurrencyCode'])
        print(rakuten['globale']['details']['OrderID'])
        
        my_dict = {}
        my_dict['CurrencyCode'] = order_obj['globale']['details']['CustomerCurrencyCode']
        my_dict['OrderID'] = order_obj['globale']['details']['OrderID']
        selected_items = [{kv.split(':')[0]:kv.split(':')[1]} for kv in order_obj['rakuten'].split('|')]
        my_dict['atrv'] = x[1]['atrv']
        
        print(my_dict)
    
        # print(rakuten2, flush=True)
#         for key, value in rakuten2.items():
#             if key == "CustomerCurrencyCode":
#                 selected_items.append((key, value))
#             if key == "OrderID":
#                 selected_items.append((key, value))




#         for key, value in rakuten.items():
#             if key == "rakuten":
#                 atrv_creater(key, selected_items, value)
#                 # selected_items.append((key,value))
#             elif key == "atrv":
#                 selected_items.append((key, value))
                
                
        print("selected_items:", flush=True)
        print(selected_items, flush=True)
        try:
            for i, j in selected_items:
                if i == "OrderID" and j != '':
                    print('the order id has its own value so it can proceed to the next task', flush=True)
                elif i == "CustomerCurrencyCode" and j != '':
                    print('the CustomerCurrencyCode has its own value so it can proceed to the next task',
                          flush=True)
                elif i == "rakuten" and j != '':
                    print('rakuten  has its own value so it can proceed to the next task', flush=True)
                elif i == "atrv" and j != '':
                    print("atrv has its own value so itcan proceed to the next task", flush=True)
        except Exception as e:
            # logging.warning(f"Could not get order because of {e}")
            print(f"Could not get Rakuten order because of {e}", flush=True)

        if selected_items == []:
            print("selected_items is empty, so no Rakuten data", flush=True)
        else:
            print("No exception gotten - there is Rakuten data", flush=True)
            print("The selected data to be stored in the Rakuten database table before try statement is:",
                  selected_items, flush=True)
            try:
                print("About to save Rakuten Data before with statement", flush=True)
                with sync_runaway_session as db_rakuten:
                    print("About to save Rakuten Data after with statement", flush=True)
                    sync_RakutenData = RakutenData(
                        orderid=selected_items[0][1],
                        customercurrencycode=selected_items[1][1],
                        atrv=selected_items[2][1]
                    )

                    print("RakutenData class created", flush=True)
                    print(sync_RakutenData, flush=True)
                    db_rakuten.add(sync_RakutenData)
                    db_rakuten.commit()
                    print("Rakuten Data saved", flush=True)
            except Exception as e:
                print("Could not save Rakuten Data")
                print(e)
                pass
            
    except:
        print("Could not save Rakuten Data")
        pass

null = float('NaN')
# Order Sample
order_obj = {
      "globale": {
        "Steps": {
          "LOADED": 0,
          "CONFIRMATION": 4
        },
        "IsSuccess": True,
        "OrderId": "GE2205192375US",
        "MerchantOrderId": null,
        "AuthCode": 5,
        "StepId": 4,
        "details": {
          "OrderID": "GE2205192375US",
          "MerchantOrderID": null,
          "ReplacementOrder": False,
          "CustomerCurrencyCode": "HUF",
          "MerchantCurrencyCode": "USD",
          "IsEU": False,
          "CustomerDetails": {
            "MerchantUserId": null,
            "ShippingAddress": null,
            "BillingAddress": null
          },
          "HubCountryCode": "US",
          "Region": null,
          "SiteURL": "https://store.heartmath.com/",
          "DutiesGuaranteed": True,
          "ShippingMethodName": "undefined",
          "ShippingMethodType": "Standard Courier",
          "DeliveryDaysRangeFrom": 0,
          "DeliveryDaysRangeTo": 0,
          "OrderPrices": {
            "MerchantTransaction": {
              "EstimatedTotalPrice": 0,
              "TotalProductsPrice": 7.73,
              "TotalDiscountedProductsPrice": 0,
              "EstimatedShippingCost": 0,
              "ShippingVATRate": 0,
              "DutiesAndTaxes": 0,
              "ProductTotalVAT": 0,
              "TotalVAT": 0,
              "RemoteAreaSurchargeFee": 0
            },
            "MerchantTransactionExcludingLocalVAT": {
              "EstimatedTotalPriceExcludingVAT": 0,
              "TotalProductsPriceExcludingVAT": 7.73,
              "TotalDiscountedProductsPriceExcludingVAT": 0,
              "EstimatedShippingCostExcludingVAT": 0,
              "CustomerShippingPriceExcludingVAT": 0,
              "DutiesAndTaxesExcludingVAT": 0,
              "RemoteAreaSurchargeFeeExcludingVAT": 0
            },
            "CustomerTransaction": {
              "CustomerTotalPrice": 0,
              "CustomerTotalProductsPrice": 2750,
              "CustomerTotalDiscountedProductsPrice": 0,
              "CustomerShippingPrice": 0,
              "CustomerDutiesAndTaxes": 0,
              "CustomerTotalVAT": 0,
              "CustomerShippingVATRate": 0,
              "CustomerUSSalesTax": 0,
              "Fees": {
                "CustomerCCF": 0,
                "CustomerCODFee": 0,
                "CustomerDangerousGoodsFee": 0,
                "CustomerSizeOverchargeFee": 0,
                "CustomerRemoteAreaSurchargeFee": 0
              }
            },
            "CustomerTransactionInMerchantCurrency": {
              "CustomerTotalPriceInMerchantCurrency": 0,
              "CustomerTotalProductsPriceInMerchantCurrency": 8.04,
              "CustomerTotalDiscountedProductsPriceInMerchantCurrency": 0,
              "CustomerShippingPriceInMerchantCurrency": 0,
              "CustomerVATInMerchantCurrency": 0,
              "CustomerShippingVATRate": 0,
              "CustomerDutiesAndTaxesInMerchantCurrency": 0,
              "CustomerUSSalesTaxInMerchantCurrency": 0,
              "Fees": {
                "CustomerCCFInMerchantCurrency": 0,
                "CustomerCODFeeInMerchantCurrency": 0,
                "CustomerDangerousGoodsFeeInMerchantCurrency": 0,
                "CustomerSizeOverchargeFeeInMerchantCurrency": 0,
                "CustomerRemoteAreaSurchargeFeeInMerchantCurrency": 0
              }
            }
          },
          "ProductInformation": [
            {
              "ProductName": "Solution for Better Sleep (eBook)",
              "ProductURL": "https://store.heartmath.com/solution-for-better-sleep-ebook/",
              "Categories": null,
              "Brand": null,
              "SKU": "EESBS",
              "ProductGroupCode": "EESBS",
              "SecondaryProductCode": null,
              "Quantity": "1",
              "CartItemId": "92db7ded-a962-45e8-83cb-89d6bdbc1bc9",
              "ProductCouponCodes": ["willeg"],
              "ParentCartItemID": null,
              "CartItemOptionId": null,
              "MetaData": null,
              "ProductAttributes": null,
              "ProductPrices": {
                "MerchantTransaction": {
                  "ListPrice": 7.73,
                  "SalePrice": 7.73,
                  "TotalPrice": 7.73,
                  "VATRate": 0,
                  "DiscountedPrice": 0
                },
                "MerchantTransactionExcludingLocalVAT": {
                  "ListPriceExcludingVAT": 7.73,
                  "SalePriceExcludingVAT": 7.73,
                  "TotalPriceExcludingVAT": 7.73,
                  "DiscountedPriceExcludingVAT": 0
                },
                "CustomerTransaction": {
                  "CustomerListPrice": 2750,
                  "CustomerSalePrice": 2750,
                  "CustomerTotalPrice": 2750,
                  "CustomerVATRate": 0,
                  "CustomerDiscountedPrice": 0
                },
                "CustomerTransactionInMerchantCurrency": {
                  "CustomerListPriceInMerchantCurrency": 8.04,
                  "CustomerSalePriceInMerchantCurrency": 8.04,
                  "CustomerTotalPriceInMerchantCurrency": 8.04,
                  "CustomerDiscountedPriceInMerchantCurrency": 0
                }
              }
            }
          ],
          "PaymentMethods": [
            {
              "PaymentMethodName": "CouponPayment",
              "PaymentMethodCode": "39",
              "PaymentMethodTypeCode": "4",
              "PaymentMethodTypeName": "Coupon"
            }
          ],
          "Discounts": [
            {
              "Description": "will global e test",
              "DiscountCode": "",
              "DiscountTypeId": 1,
              "DiscountTypeName": "Cart discount",
              "CouponCode": "willeg",
              "ProductCartItemId": null,
              "DiscountPrices": {
                "MerchantTransaction": {
                  "Price": 7.73,
                  "VATRate": 0
                },
                "MerchantTransactionExcludingLocalVAT": {
                  "PriceExcludingVAT": 7.73
                },
                "CustomerTransaction": {
                  "CustomerPrice": 2750,
                  "CustomerVATRate": 0
                },
                "CustomerTransactionInMerchantCurrency": {
                  "CustomerPriceInMerchantCurrency": 8.04,
                  "CustomerVATRate": 0
                }
              }
            }
          ],
          "OrderPaymentMethods": [],
          "GiftCards": null,
          "AllowMailsFromMerchant": False,
          "AllowDirectCommunicationFromMerchant": False,
          "cultureCode": "en-US",
          "InitialCheckoutCultureCode": "en-US",
          "URL": null,
          "CustomURL": null,
          "CheckoutStep": null,
          "MerchantID": 10001024,
          "Title": "Global-e Order Transaction",
          "HostName": "https://web.global-e.com/",
          "CustomHostName": null,
          "PageType": 0,
          "CartToken": "e0da215d-0139-4e34-9ff4-7e1b4770f2e4",
          "CountryCode": "HU",
          "UrlReferer": null,
          "DoLog": False
        }
      },
      "rakuten": "ald:20220516_1847|atrv:uuQBtDButww-lv.90hhIQnvIcf6_AxH9Rw"
    }

# Call the method here
response = send_order_info_to_rakuten(order_obj)
print("AFTER METHOD CALL")
print(response)
# Out:
# Rakuten affiliate get data goes into json
# Could not save Rakuten Data
# AFTER METHOD CALL
# None

# %%
order_obj
# Out:
# {'globale': {'Steps': {'LOADED': 0, 'CONFIRMATION': 4},
#   'IsSuccess': True,
#   'OrderId': 'GE2205192375US',
#   'MerchantOrderId': nan,
#   'AuthCode': 5,
#   'StepId': 4,
#   'details': {'OrderID': 'GE2205192375US',
#    'MerchantOrderID': nan,
#    'ReplacementOrder': False,
#    'CustomerCurrencyCode': 'HUF',
#    'MerchantCurrencyCode': 'USD',
#    'IsEU': False,
#    'CustomerDetails': {'MerchantUserId': nan,
#     'ShippingAddress': nan,
#     'BillingAddress': nan},
#    'HubCountryCode': 'US',
#    'Region': nan,
#    'SiteURL': 'https://store.heartmath.com/',
#    'DutiesGuaranteed': True,
#    'ShippingMethodName': 'undefined',
#    'ShippingMethodType': 'Standard Courier',
#    'DeliveryDaysRangeFrom': 0,
#    'DeliveryDaysRangeTo': 0,
#    'OrderPrices': {'MerchantTransaction': {'EstimatedTotalPrice': 0,
#      'TotalProductsPrice': 7.73,
#      'TotalDiscountedProductsPrice': 0,
#      'EstimatedShippingCost': 0,
#      'ShippingVATRate': 0,
# ...

# %%
order_obj.keys()
# Out:
# dict_keys(['globale', 'rakuten'])

# %%
order_obj1 = {
    
    'globale':{'details':{'CustomerCurrencyCode':'HUF','OrderID':'GE2205192375US'}},
    'rakuten' : 'ald:20220516_1847|atrv:uuQBtDButww-lv.90hhIQnvIcf6_AxH9Rw'
}

# %%
[{kv.split(':')[0]:kv.split(':')[1]} for kv in order_obj1['rakuten'].split('|')]
# Out:
# [{'ald': '20220516_1847'}, {'atrv': 'uuQBtDButww-lv.90hhIQnvIcf6_AxH9Rw'}]

# %%
order_obj1['globale']['details']['CustomerCurrencyCode']
# Out:
# 'HUF'

# %%
order_obj1['globale']['details']['OrderID']
# Out:
# 'GE2205192375US'

# %%
def send_order_info_to_rakuten(order_data):
       
    selected_items = []

    rakuten2 = order_data["globale"]["details"]

    print(order_data['globale']['details']['CustomerCurrencyCode'])
    print(order_data['globale']['details']['OrderID'])

    my_dict = {}
    my_dict['CurrencyCode'] = order_data['globale']['details']['CustomerCurrencyCode']
    my_dict['OrderID'] = order_data['globale']['details']['OrderID']
    selected_items = [{kv.split(':')[0]:kv.split(':')[1]} for kv in order_data['rakuten'].split('|')]
    my_dict['atrv'] = x[1]['atrv']

    print(my_dict['atrv'])
    print(my_dict)

# %%
send_order_info_to_rakuten(order_obj)
# Out:
# HUF
# GE2205192375US
# uuQBtDButww-lv.90hhIQnvIcf6_AxH9Rw
# {'CurrencyCode': 'HUF', 'OrderID': 'GE2205192375US', 'atrv': 'uuQBtDButww-lv.90hhIQnvIcf6_AxH9Rw'}

# %%
a = None

# %%
a == None
# Out:
# True
