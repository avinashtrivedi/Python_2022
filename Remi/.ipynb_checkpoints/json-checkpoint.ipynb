# %%
with open('1.json', 'w') as fp:
    json.dump(mykeys, fp)
    
with open('1.json') as f:
    key = json.load(f)

# %%
client = Client(config.API_KEY, config.API_SECRET, tld='us')

# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager

# %%
api_key = 12654111
api_secret =747777777

# %%
client = Client('1411111', '25222222',tld='us')

# %%
client.get_order_book(symbol='BNBBTC')
# Out:
# {'lastUpdateId': 202830354,
#  'bids': [['0.00951080', '24.00000000'],
#   ['0.00951050', '2.65000000'],
#   ['0.00951040', '1.50000000'],
#   ['0.00950720', '4.98000000'],
#   ['0.00950690', '10.00000000'],
#   ['0.00950630', '14.31000000'],
#   ['0.00950600', '23.73000000'],
#   ['0.00950240', '0.18000000'],
#   ['0.00950230', '23.75000000'],
#   ['0.00950130', '8.15000000'],
#   ['0.00950110', '26.96000000'],
#   ['0.00949520', '13.73000000'],
#   ['0.00949500', '2.79000000'],
#   ['0.00949490', '0.02000000'],
#   ['0.00949380', '0.38000000'],
#   ['0.00948950', '34.18000000'],
#   ['0.00948920', '0.13000000'],
#   ['0.00948850', '22.65000000'],
#   ['0.00948550', '0.11000000'],
#   ['0.00948530', '0.05000000'],
#   ['0.00948270', '0.04000000'],
#   ['0.00948130', '0.05000000'],
#   ['0.00948070', '0.05000000'],
#   ['0.00948000', '0.05000000'],
#   ['0.00947990', '12.92000000'],
#   ['0.00947670', '55.09000000'],
#   ['0.00947190', '0.25000000'],
#   ['0.00947120', '39.29000000'],
#   ['0.00946710', '0.05000000'],
#   ['0.00946120', '28.01000000'],
#   ['0.00946050', '2.80000000'],
#   ['0.00945900', '0.51000000'],
#   ['0.00945540', '0.12000000'],
#   ['0.00945460', '0.02000000'],
#   ['0.00945190', '0.04000000'],
#   ['0.00945010', '39.42000000'],
#   ['0.00945000', '0.05000000'],
#   ['0.00944890', '0.05000000'],
#   ['0.00944860', '0.05000000'],
#   ['0.00944090', '41.92000000'],
#   ['0.00943870', '0.25000000'],
#   ['0.00943460', '0.05000000'],
#   ['0.00943330', '0.05000000'],
#   ['0.00943310', '0.56000000'],
#   ['0.00943110', '0.04000000'],
#   ['0.00943070', '0.05000000'],
#   ['0.00942990', '37.33000000'],
#   ['0.00942880', '0.13000000'],
#   ['0.00942550', '0.12000000'],
#   ['0.00942460', '0.22000000'],
#   ['0.00942440', '0.47000000'],
#   ['0.00942120', '0.24000000'],
#   ['0.00941970', '33.60000000'],
#   ['0.00941870', '0.75000000'],
#   ['0.00941450', '0.02000000'],
#   ['0.00941260', '0.05000000'],
#   ['0.00940570', '0.25000000'],
#   ['0.00940540', '27.97000000'],
#   ['0.00940210', '0.05000000'],
#   ['0.00940170', '0.06000000'],
#   ['0.00940000', '0.02000000'],
#   ['0.00939880', '0.13000000'],
#   ['0.00939560', '0.12000000'],
#   ['0.00939450', '0.05000000'],
#   ['0.00939420', '0.50000000'],
#   ['0.00939190', '0.04000000'],
#   ['0.00939100', '41.91000000'],
#   ['0.00939000', '0.38000000'],
#   ['0.00938810', '0.05000000'],
#   ['0.00938640', '0.05000000'],
#   ['0.00938600', '0.05000000'],
#   ['0.00938380', '0.63000000'],
#   ['0.00938010', '0.03000000'],
#   ['0.00937980', '0.04000000'],
#   ['0.00937910', '0.04000000'],
#   ['0.00937710', '46.63000000'],
#   ['0.00937640', '0.05000000'],
#   ['0.00937460', '0.02000000'],
#   ['0.00937270', '0.25000000'],
#   ['0.00936880', '0.13000000'],
#   ['0.00936590', '0.12000000'],
#   ['0.00936540', '55.08000000'],
#   ['0.00936230', '0.24000000'],
#   ['0.00935840', '0.05000000'],
#   ['0.00935560', '0.39000000'],
#   ['0.00935520', '0.49000000'],
#   ['0.00935490', '0.06000000'],
#   ['0.00935450', '0.05000000'],
#   ['0.00935340', '39.53000000'],
#   ['0.00935170', '0.11000000'],
#   ['0.00934210', '0.28000000'],
#   ['0.00934190', '0.05000000'],
#   ['0.00934060', '43.68000000'],
#   ['0.00934040', '0.05000000'],
#   ['0.00933990', '0.05000000'],
#   ['0.00933980', '0.26000000'],
#   ['0.00933920', '0.10000000'],
#   ['0.00933900', '0.18000000'],
#   ['0.00933620', '0.12000000'],
#   ['0.00933330', '12.00000000']],
#  'asks': [['0.00951450', '0.02000000'],
#   ['0.00951810', '21.05000000'],
#   ['0.00952100', '10.86000000'],
#   ['0.00952530', '0.09000000'],
#   ['0.00952540', '2.65000000'],
#   ['0.00952730', '7.26000000'],
#   ['0.00952880', '30.85000000'],
#   ['0.00953330', '6.69000000'],
#   ['0.00953500', '19.56000000'],
#   ['0.00954070', '43.87000000'],
#   ['0.00954080', '0.05000000'],
#   ['0.00954120', '8.20000000'],
#   ['0.00954770', '9.63000000'],
#   ['0.00954880', '0.02000000'],
#   ['0.00955350', '51.66000000'],
#   ['0.00955420', '5.38000000'],
#   ['0.00955840', '0.23000000'],
#   ['0.00955910', '0.24000000'],
#   ['0.00955920', '0.04000000'],
#   ['0.00956210', '17.77000000'],
#   ['0.00956220', '0.05000000'],
#   ['0.00956480', '0.11000000'],
#   ['0.00956550', '0.05000000'],
#   ['0.00956910', '0.13000000'],
#   ['0.00957040', '13.85000000'],
#   ['0.00957760', '0.04000000'],
#   ['0.00957870', '17.21000000'],
#   ['0.00958290', '0.38000000'],
#   ['0.00958390', '2.78000000'],
#   ['0.00958470', '0.11000000'],
#   ['0.00958710', '29.43000000'],
#   ['0.00959210', '0.25000000'],
#   ['0.00959220', '0.04000000'],
#   ['0.00959380', '0.05000000'],
#   ['0.00959480', '0.05000000'],
#   ['0.00959490', '0.02000000'],
#   ['0.00959530', '0.11000000'],
#   ['0.00959550', '0.05000000'],
#   ['0.00959610', '0.04000000'],
#   ['0.00959960', '0.13000000'],
#   ['0.00959990', '12.00000000'],
#   ['0.00960000', '0.02000000'],
#   ['0.00960100', '26.87000000'],
#   ['0.00960600', '0.04000000'],
#   ['0.00960790', '0.21000000'],
#   ['0.00961000', '0.05000000'],
#   ['0.00961170', '21.61000000'],
#   ['0.00961420', '0.05000000'],
#   ['0.00961460', '0.04000000'],
#   ['0.00961810', '0.38000000'],
#   ['0.00961890', '2.77000000'],
#   ['0.00961920', '0.23000000'],
#   ['0.00962110', '0.21000000'],
#   ['0.00962330', '38.74000000'],
#   ['0.00962570', '0.11000000'],
#   ['0.00962580', '0.25000000'],
#   ['0.00962840', '0.51000000'],
#   ['0.00963030', '0.13000000'],
#   ['0.00963230', '0.09000000'],
#   ['0.00963310', '0.04000000'],
#   ['0.00963380', '0.10000000'],
#   ['0.00963440', '0.20000000'],
#   ['0.00963490', '26.18000000'],
#   ['0.00963570', '0.02000000'],
#   ['0.00963790', '0.03000000'],
#   ['0.00964160', '0.05000000'],
#   ['0.00964240', '0.05000000'],
#   ['0.00964370', '0.04000000'],
#   ['0.00964620', '22.32000000'],
#   ['0.00964650', '0.22000000'],
#   ['0.00964760', '0.20000000'],
#   ['0.00965170', '0.04000000'],
#   ['0.00965340', '0.38000000'],
#   ['0.00965350', '0.04000000'],
#   ['0.00965400', '2.76000000'],
#   ['0.00965630', '0.11000000'],
#   ['0.00965800', '0.05000000'],
#   ['0.00965840', '0.04000000'],
#   ['0.00965960', '0.25000000'],
#   ['0.00966000', '0.77000000'],
#   ['0.00966050', '29.52000000'],
#   ['0.00966090', '0.20000000'],
#   ['0.00966110', '0.12000000'],
#   ['0.00966320', '0.05000000'],
#   ['0.00966730', '0.52000000'],
#   ['0.00966950', '0.02000000'],
#   ['0.00967030', '0.04000000'],
#   ['0.00967420', '0.20000000'],
#   ['0.00967460', '40.68000000'],
#   ['0.00967680', '0.02000000'],
#   ['0.00967970', '0.22000000'],
#   ['0.00968700', '0.11000000'],
#   ['0.00968750', '0.04000000'],
#   ['0.00968760', '0.20000000'],
#   ['0.00968870', '29.67000000'],
#   ['0.00968890', '0.37000000'],
#   ['0.00968900', '0.04000000'],
#   ['0.00968920', '2.79000000'],
#   ['0.00968930', '4.70000000'],
#   ['0.00968950', '0.05000000']]}

# %%
client.get_withdraw_history()
print(withdraws)
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# <ipython-input-7-fa476828e487> in <module>
# ----> 1 client.get_withdraw_history()
#       2 print(withdraws)
#
# ~\anaconda3\lib\site-packages\binance\client.py in get_withdraw_history(self, **params)
#    2623
#    2624         """
# -> 2625         return self._request_margin_api('get', 'capital/withdraw/history', True, data=params)
#    2626
#    2627     def get_withdraw_history_id(self, withdraw_id, **params):
#
# ~\anaconda3\lib\site-packages\binance\client.py in _request_margin_api(self, method, path, signed, **kwargs)
#     362         uri = self._create_margin_api_uri(path)
#     363
# --> 364         return self._request(method, uri, signed, **kwargs)
#     365
#     366     def _request_website(self, method, path, signed=False, **kwargs) -> Dict:
#
# ~\anaconda3\lib\site-packages\binance\client.py in _request(self, method, uri, signed, force_params, **kwargs)
#     313
#     314         self.response = getattr(self.session, method)(uri, **kwargs)
# --> 315         return self._handle_response(self.response)
#     316
#     317     @staticmethod
#
# ~\anaconda3\lib\site-packages\binance\client.py in _handle_response(response)
#     322         """
#     323         if not (200 <= response.status_code < 300):
# --> 324             raise BinanceAPIException(response, response.status_code, response.text)
#     325         try:
#     326             return response.json()
#
# BinanceAPIException: APIError(code=-2008): Invalid Api-Key ID.
