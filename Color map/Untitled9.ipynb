# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/BrijeshYadav001st/HighRadius-csv-file-/main/H2HBABBA1492.csv')

# %%
data.head(50)
# Out:
#    business_code cust_number        name_customer           clear_date  \
# 0           CA02  0140105678      SAPUTO  systems                  NaN
# 1           U001  0200750051     ALBER foundation  2019-07-03 00:00:00
# 2           U001  0200769623      WAL-MAR systems                  NaN
# 3           U001  0200416837          DEC systems  2019-03-25 00:00:00
# 4           U001      CCCA02            KRAFT  co  2019-11-27 00:00:00
# 5           U001  0200726979          BJ'S  trust                  NaN
# 6           U001  0200763152       PERFOR systems  2019-08-01 00:00:00
# 7           U001  0200780825         SYSCO FO llc  2019-09-18 00:00:00
# 8           U001  0200781803               JRD in  2019-11-22 00:00:00
# 9           U001  0200720238     WOODM associates  2019-11-22 00:00:00
# 10          U001  0200794332              COST in  2019-12-05 00:00:00
# 11          U001  0200794332     COST corporation  2019-12-06 00:00:00
# 12          U001  0200769623         WAL-MAR corp  2019-10-02 00:00:00
# 13          U001  0200769623        WAL-MAR trust  2019-05-24 00:00:00
# 14          U001   200769623         WAL-MAR corp  2019-03-11 00:00:00
# 15          CA02  0140106408    WAL-M corporation  2019-03-05 00:00:00
# 16          U001  0200515231                 US    2019-12-09 00:00:00
# 17          U001  0200780825          SYSCO FO us                  NaN
# 18          U001  0200769623           WAL-MAR in  2019-11-19 00:00:00
# 19          CA02  0140104340        COLABOR  corp  2019-08-01 00:00:00
# 20          U001  0200726979     BJ'S  foundation  2019-12-20 00:00:00
# 21          U001  0200762301    C&S WH foundation  2019-04-16 00:00:00
# 22          U001  0200761734           H E BUT us                  NaN
# 23          U001  0200759878       SA corporation  2019-04-02 00:00:00
# 24          U001  0200772595            SAFEW llc  2019-09-10 00:00:00
# 25          U001  0200707741            SMART &    2020-02-12 00:00:00
# 26          U001   200769623  WAL-MAR corporation  2019-04-15 00:00:00
# 27          CA02  0140104429            COSTCO us                  NaN
# 28          U001  0200705742          DOT systems  2019-10-04 00:00:00
# 29          U001  0200705742              DOT llc  2020-02-18 00:00:00
# 30          U001  0100036318              TFC llc  2019-10-11 00:00:00
# 31          U001  0200769623        WAL-MAR trust  2019-03-05 00:00:00
# 32          U001  0200714710         SYSCO  trust  2019-04-18 00:00:00
# 33          U001  0200424504           M  systems  2019-08-16 00:00:00
# 34          U001  0200416837      DEC corporation  2019-06-17 00:00:00
# 35          U001  0200769623         WAL-MAR corp  2019-02-08 00:00:00
# 36          CA02      CCU001          KRAFT  corp                  NaN
# 37          U001  0200760666     KEHE  associates  2019-08-30 00:00:00
# 38          U001   200769623           WAL-MAR us  2019-06-12 00:00:00
# 39          U001  0200434439     BAUGH SU systems  2019-05-17 00:00:00
# 40          U001  0200769623           WAL-MAR us                  NaN
# 41          U001  0200769623           WAL-MAR us  2019-04-02 00:00:00
# 42          U001  0200762301            C&S WH us  2019-10-08 00:00:00
# 43          U001  0200799367       MCL associates  2019-06-27 00:00:00
# 44          U001  0200230690              DECA co                  NaN
# 45          U001  0200794332              COST us  2019-09-09 00:00:00
# 46          U001  0200769623   WAL-MAR associates                  NaN
# 47          U001  0200769623  WAL-MAR corporation  2019-11-25 00:00:00
# 48          U001  0200759878             SA trust                  NaN
# 49          U013  0140103409             BUTTE co  2019-11-22 00:00:00
#
#     buisness_year        doc_id posting_date  document_create_date  \
# 0          2020.0  2.960620e+09   2020-03-10              20200310
# 1          2019.0  1.929516e+09   2019-06-18              20190619
# 2          2020.0  1.930689e+09   2020-03-24              20200323
# 3          2019.0  1.928996e+09   2019-03-20              20190320
# 4          2019.0  1.929976e+09   2019-10-08              20191007
# 5          2020.0  1.930752e+09   2020-04-06              20200406
# 6          2019.0  1.929624e+09   2019-07-17              20190716
# 7          2019.0  1.929830e+09   2019-09-06              20190905
# 8          2019.0  1.930093e+09   2019-11-02              20191102
# 9          2019.0  1.930077e+09   2019-10-30              20191031
# 10         2019.0  1.930173e+09   2019-11-21              20191120
# 11         2019.0  1.930185e+09   2019-11-22              20191122
# 12         2019.0  1.929909e+09   2019-09-22              20190921
# 13         2019.0  1.929292e+09   2019-05-13              20190510
# 14         2019.0  1.928825e+09   2019-02-20              20190220
# 15         2019.0  2.960529e+09   2019-02-16              20190216
# 16         2019.0  1.930180e+09   2019-11-21              20191121
# 17         2020.0  1.930628e+09   2020-03-10              20200309
# 18         2019.0  1.930096e+09   2019-11-03              20191103
# 19         2019.0  2.960566e+09   2019-07-20              20190720
# 20         2019.0  1.930212e+09   2019-12-05              20191203
# 21         2019.0  1.929057e+09   2019-03-31              20190330
# 22         2020.0  1.930701e+09   2020-03-28              20200325
# 23         2019.0  1.928960e+09   2019-03-14              20190314
# 24         2019.0  1.929792e+09   2019-08-26              20190826
# 25         2020.0  1.930465e+09   2020-01-31              20200201
# 26         2019.0  1.929067e+09   2019-04-03              20190401
# 27         2020.0  2.960619e+09   2020-03-08              20200308
# 28         2019.0  1.929898e+09   2019-09-19              20190919
# 29         2020.0  1.930444e+09   2020-01-26              20200127
# 30         2019.0  1.929957e+09   2019-10-02              20191003
# 31         2019.0  1.928839e+09   2019-02-21              20190222
# 32         2019.0  1.929061e+09   2019-04-02              20190331
# 33         2019.0  1.929613e+09   2019-07-13              20190712
# 34         2019.0  1.929443e+09   2019-06-06              20190606
# 35         2019.0  1.928660e+09   2019-01-23              20190122
# 36         2020.0  2.960624e+09   2020-03-27              20200327
# 37         2019.0  1.929731e+09   2019-08-14              20190809
# 38         2019.0  1.929409e+09   2019-06-01              20190531
# 39         2019.0  1.929294e+09   2019-05-10              20190510
# 40         2020.0  1.930874e+09   2020-05-07              20200507
# 41         2019.0  1.929007e+09   2019-03-22              20190321
# 42         2019.0  1.929907e+09   2019-09-23              20190921
# 43         2019.0  1.929038e+09   2019-03-28              20190327
# 44         2020.0  1.930670e+09   2020-03-19              20200319
# 45         2019.0  1.929790e+09   2019-08-26              20190824
# 46         2020.0  1.930833e+09   2020-04-29              20200428
# 47         2019.0  1.930143e+09   2019-11-13              20191112
# 48         2020.0  1.930707e+09   2020-03-28              20200326
# 49         2019.0  1.991834e+09   2019-10-27              20191023
#
#     document_create_date.1  due_in_date invoice_currency document type  \
# 0                 20200310   20200329.0              CAD            RV
# 1                 20190618   20190703.0              USD            RV
# 2                 20200324   20200408.0              USD            RV
# 3                 20190320   20190326.0              USD            RV
# 4                 20191008   20191112.0              USD            RV
# 5                 20200406   20200421.0              USD            RV
# 6                 20190717   20190801.0              USD            RV
# 7                 20190906   20190921.0              USD            RV
# 8                 20191102   20191122.0              USD            RV
# 9                 20191030   20191114.0              USD            RV
# 10                20191121   20191206.0              USD            RV
# 11                20191122   20191207.0              USD            RV
# 12                20190922   20191007.0              USD            RV
# 13                20190513   20190528.0              USD            RV
# 14                20190220   20190307.0              USD            RV
# 15                20190216   20190226.0              CAD            RV
# 16                20191121   20191206.0              USD            RV
# 17                20200310   20200325.0              USD            RV
# 18                20191103   20191118.0              USD            RV
# 19                20190720   20190731.0              CAD            RV
# 20                20191205   20191220.0              USD            RV
# 21                20190331   20190415.0              USD            RV
# 22                20200328   20200412.0              USD            RV
# 23                20190314   20190329.0              USD            RV
# 24                20190826   20190910.0              USD            RV
# 25                20200131   20200215.0              USD            RV
# 26                20190403   20190418.0              USD            RV
# 27                20200308   20200320.0              CAD            RV
# 28                20190919   20191009.0              USD            RV
# 29                20200126   20200210.0              USD            RV
# 30                20191002   20191012.0              USD            RV
# 31                20190221   20190308.0              USD            RV
# 32                20190402   20190417.0              USD            RV
# 33                20190713   20190815.0              USD            RV
# 34                20190606   20190624.0              USD            RV
# 35                20190123   20190207.0              USD            RV
# 36                20200327   20200504.0              CAD            RV
# 37                20190814   20190829.0              USD            RV
# 38                20190601   20190616.0              USD            RV
# 39                20190510   20190530.0              USD            RV
# 40                20200507   20200522.0              USD            RV
# 41                20190322   20190406.0              USD            RV
# 42                20190923   20191008.0              USD            RV
# 43                20190328   20190412.0              USD            RV
# 44                20200319   20200323.0              USD            RV
# 45                20190826   20190910.0              USD            RV
# 46                20200429   20200514.0              USD            RV
# 47                20191113   20191128.0              USD            RV
# 48                20200328   20200412.0              USD            RV
# 49                20191027   20191126.0              USD            RV
#
#     posting_id  area_business  total_open_amount  baseline_create_date  \
# 0          1.0            NaN           12140.10            20200319.0
# 1          1.0            NaN          101378.70            20190618.0
# 2          1.0            NaN           46117.37            20200324.0
# 3          1.0            NaN           12904.41            20190316.0
# 4          1.0            NaN           12965.40            20191008.0
# 5          1.0            NaN             404.74            20200406.0
# 6          1.0            NaN           42241.46            20190717.0
# 7          1.0            NaN            1698.40            20190906.0
# 8          1.0            NaN            1836.36            20191102.0
# 9          1.0            NaN          114484.20            20191030.0
# 10         1.0            NaN           67422.11            20191121.0
# 11         1.0            NaN           88825.59            20191122.0
# 12         1.0            NaN           36746.04            20190922.0
# 13         1.0            NaN           62761.85            20190513.0
# 14         1.0            NaN            2707.70            20190220.0
# 15         1.0            NaN           87422.31            20190216.0
# 16         1.0            NaN           77748.92            20191121.0
# 17         1.0            NaN            7090.54            20200310.0
# 18         1.0            NaN           32418.31            20191103.0
# 19         1.0            NaN           31736.78            20190721.0
# 20         1.0            NaN            9222.81            20191205.0
# 21         1.0            NaN           23344.39            20190331.0
# 22         1.0            NaN           87170.76            20200328.0
# 23         1.0            NaN           12636.17            20190314.0
# 24         1.0            NaN            3309.79            20190826.0
# 25         1.0            NaN           54976.92            20200131.0
# 26         1.0            NaN           59898.06            20190403.0
# 27         1.0            NaN             336.62            20200310.0
# 28         1.0            NaN           49917.89            20190919.0
# 29         1.0            NaN             284.74            20200126.0
# 30         1.0            NaN           33644.00            20191002.0
# 31         1.0            NaN           51645.93            20190221.0
# 32         1.0            NaN            3624.20            20190402.0
# 33         1.0            NaN           21813.22            20190815.0
# 34         1.0            NaN             601.56            20190601.0
# 35         1.0            NaN            1036.26            20190123.0
# 36         1.0            NaN           39202.86            20200330.0
# 37         1.0            NaN           11741.18            20190814.0
# 38         1.0            NaN           51704.60            20190601.0
# 39         1.0            NaN            5339.18            20190510.0
# 40         1.0            NaN           39594.98            20200507.0
# 41         1.0            NaN           56278.02            20190322.0
# 42         1.0            NaN           10438.37            20190923.0
# 43         1.0            NaN             248.71            20190328.0
# 44         1.0            NaN             667.28            20200316.0
# 45         1.0            NaN           11721.94            20190826.0
# 46         1.0            NaN           32580.84            20200429.0
# 47         1.0            NaN              32.36            20191113.0
# 48         1.0            NaN           13361.87            20200328.0
# 49         1.0            NaN            5829.42            20191027.0
#
#    cust_payment_terms    invoice_id  isOpen
# 0                CA10  2.960620e+09       1
# 1                NAA8  1.929516e+09       0
# 2                NAH4  1.930689e+09       1
# 3                NAM2  1.928996e+09       0
# 4                NAG2  1.929976e+09       0
# 5                NAA8  1.930752e+09       1
# 6                NAA8  1.929624e+09       0
# 7                NAA8  1.929830e+09       0
# 8                NAD1  1.930093e+09       0
# 9                NAA8  1.930077e+09       0
# 10               NAAX  1.930173e+09       0
# 11               NAAX  1.930185e+09       0
# 12               NAH4  1.929909e+09       0
# 13               NAH4  1.929292e+09       0
# 14               NAH4  1.928825e+09       0
# 15               CA10  2.960529e+09       0
# 16               NAA8  1.930180e+09       0
# 17               NAA8  1.930628e+09       1
# 18               NAH4  1.930096e+09       0
# 19               CA10  2.960566e+09       0
# 20               NAA8  1.930212e+09       0
# 21               NAC6  1.929057e+09       0
# 22               NAA8  1.930701e+09       1
# 23               NAH4  1.928960e+09       0
# 24               NAA8  1.929792e+09       0
# 25               NAA8  1.930465e+09       0
# 26               NAH4  1.929067e+09       0
# 27               CA10  2.960619e+09       1
# 28               NAD1  1.929898e+09       0
# 29               NAA8  1.930444e+09       0
# 30               NA10  1.929957e+09       0
# 31               NAH4  1.928839e+09       0
# 32               NAA8  1.929061e+09       0
# 33               NATM  1.929613e+09       0
# 34               NAM4  1.929443e+09       0
# 35               NAH4  1.928660e+09       0
# 36               NAG2  2.960624e+09       1
# 37               NAA8  1.929731e+09       0
# 38               NAH4  1.929409e+09       0
# 39               NAD1  1.929294e+09       0
# 40               NAH4  1.930874e+09       1
# 41               NAH4  1.929007e+09       0
# 42               NAC6  1.929907e+09       0
# 43               NAA8  1.929038e+09       0
# 44               NAM1  1.930670e+09       1
# 45               NAAX  1.929790e+09       0
# 46               NAH4  1.930833e+09       1
# 47               NAH4  1.930143e+09       0
# 48               NAH4  1.930707e+09       1
# 49               NAVE  1.991834e+09       0

# %%
data.tail()
# Out:
#       business_code cust_number   name_customer           clear_date  \
# 49995          U001  0200769623        WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878  SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557        BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463       KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720  DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 49995         2020.0  1.930357e+09   2020-01-07              20200105
# 49996         2019.0  1.929009e+09   2019-03-24              20190322
# 49997         2019.0  1.928940e+09   2019-03-12              20190312
# 49998         2019.0  1.929669e+09   2019-07-30              20190727
# 49999         2019.0  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 49995                20200107   20200122.0              USD            RV
# 49996                20190324   20190408.0              USD            RV
# 49997                20190312   20190516.0              USD            RV
# 49998                20190730   20190814.0              USD            RV
# 49999                20191023   20191108.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 49995         1.0            NaN             311.84            20200107.0
# 49996         1.0            NaN           40742.51            20190324.0
# 49997         1.0            NaN            1929.63            20190312.0
# 49998         1.0            NaN           17519.05            20190730.0
# 49999         1.0            NaN             501.84            20191016.0
#
#       cust_payment_terms    invoice_id  isOpen
# 49995               NAH4  1.930357e+09       0
# 49996               NAH4  1.929009e+09       0
# 49997               NAGD  1.928940e+09       0
# 49998               NAA8  1.929669e+09       0
# 49999               NAM4  1.930046e+09       0

# %%
data.columns
# Out:
# Index(['business_code', 'cust_number', 'name_customer', 'clear_date',
#        'buisness_year', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'invoice_currency',
#        'document type', 'posting_id', 'area_business', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'isOpen'],
#       dtype='object')

# %%
data.shape
# Out:
# (50000, 19)

# %%
data.nunique()
# Out:
# business_code                 5
# cust_number                1409
# name_customer              4177
# clear_date                  401
# buisness_year                 2
# doc_id                    48853
# posting_date                504
# document_create_date        504
# document_create_date.1      505
# due_in_date                 548
# invoice_currency              2
# document type                 2
# posting_id                    1
# area_business                 0
# total_open_amount         44306
# baseline_create_date        510
# cust_payment_terms           76
# invoice_id                48847
# isOpen                        2
# dtype: int64

# %%
data.drop(['area_business','posting_id'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 0              CA02  0140105678   SAPUTO  systems                  NaN
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 2              U001  0200769623   WAL-MAR systems                  NaN
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2020.0  2.960620e+09   2020-03-10              20200310
# 1             2019.0  1.929516e+09   2019-06-18              20190619
# 2             2020.0  1.930689e+09   2020-03-24              20200323
# 3             2019.0  1.928996e+09   2019-03-20              20190320
# 4             2019.0  1.929976e+09   2019-10-08              20191007
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930357e+09   2020-01-07              20200105
# 49996         2019.0  1.929009e+09   2019-03-24              20190322
# 49997         2019.0  1.928940e+09   2019-03-12              20190312
# 49998         2019.0  1.929669e+09   2019-07-30              20190727
# 49999         2019.0  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200310   20200329.0              CAD            RV
# 1                    20190618   20190703.0              USD            RV
# 2                    20200324   20200408.0              USD            RV
# 3                    20190320   20190326.0              USD            RV
# 4                    20191008   20191112.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200107   20200122.0              USD            RV
# 49996                20190324   20190408.0              USD            RV
# 49997                20190312   20190516.0              USD            RV
# 49998                20190730   20190814.0              USD            RV
# 49999                20191023   20191108.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               12140.10            20200319.0               CA10
# 1              101378.70            20190618.0               NAA8
# 2               46117.37            20200324.0               NAH4
# 3               12904.41            20190316.0               NAM2
# 4               12965.40            20191008.0               NAG2
# ...                  ...                   ...                ...
# 49995             311.84            20200107.0               NAH4
# 49996           40742.51            20190324.0               NAH4
# 49997            1929.63            20190312.0               NAGD
# 49998           17519.05            20190730.0               NAA8
# 49999             501.84            20191016.0               NAM4
#
#          invoice_id  isOpen
# 0      2.960620e+09       1
# 1      1.929516e+09       0
# 2      1.930689e+09       1
# 3      1.928996e+09       0
# 4      1.929976e+09       0
# ...             ...     ...
# 49995  1.930357e+09       0
# 49996  1.929009e+09       0
# 49997  1.928940e+09       0
# 49998  1.929669e+09       0
# 49999  1.930046e+09       0
#
# [50000 rows x 17 columns]

# %%
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    6
# isOpen                        0
# dtype: int64

# %%
data.invoice_id.interpolate(inplace=True)

# %%
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    0
# isOpen                        0
# dtype: int64

# %%
newdata = data[data.clear_date.isna()].copy()
newdata
# Out:
#       business_code cust_number    name_customer clear_date  buisness_year  \
# 0              CA02  0140105678  SAPUTO  systems        NaN         2020.0
# 2              U001  0200769623  WAL-MAR systems        NaN         2020.0
# 5              U001  0200726979      BJ'S  trust        NaN         2020.0
# 17             U001  0200780825      SYSCO FO us        NaN         2020.0
# 22             U001  0200761734       H E BUT us        NaN         2020.0
# ...             ...         ...              ...        ...            ...
# 49986          U001  0200769623    WAL-MAR trust        NaN         2020.0
# 49987          CA02  0140104440    SO associates        NaN         2020.0
# 49988          U002  0200501669          WAL MA         NaN         2020.0
# 49991          U001  0200799342         MITCH us        NaN         2020.0
# 49993          U001  0100036318           TFC us        NaN         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      2.960620e+09   2020-03-10              20200310
# 2      1.930689e+09   2020-03-24              20200323
# 5      1.930752e+09   2020-04-06              20200406
# 17     1.930628e+09   2020-03-10              20200309
# 22     1.930701e+09   2020-03-28              20200325
# ...             ...          ...                   ...
# 49986  1.930846e+09   2020-05-01              20200501
# 49987  2.960621e+09   2020-03-12              20200312
# 49988  1.990572e+09   2020-03-20              20200318
# 49991  1.930773e+09   2020-04-10              20200410
# 49993  1.930880e+09   2020-05-08              20200508
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200310   20200329.0              CAD            RV
# 2                    20200324   20200408.0              USD            RV
# 5                    20200406   20200421.0              USD            RV
# 17                   20200310   20200325.0              USD            RV
# 22                   20200328   20200412.0              USD            RV
# ...                       ...          ...              ...           ...
# 49986                20200501   20200516.0              USD            RV
# 49987                20200312   20200327.0              CAD            RV
# 49988                20200320   20200424.0              USD            RV
# 49991                20200410   20200425.0              USD            RV
# 49993                20200508   20200518.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               12140.10            20200319.0               CA10
# 2               46117.37            20200324.0               NAH4
# 5                 404.74            20200406.0               NAA8
# 17               7090.54            20200310.0               NAA8
# 22              87170.76            20200328.0               NAA8
# ...                  ...                   ...                ...
# 49986           57004.06            20200501.0               NAH4
# 49987           61690.42            20200317.0               CA10
# 49988           37988.63            20200320.0               NAG2
# 49991           11175.46            20200410.0               NAA8
# 49993           28778.75            20200508.0               NA10
#
#          invoice_id  isOpen
# 0      2.960620e+09       1
# 2      1.930689e+09       1
# 5      1.930752e+09       1
# 17     1.930628e+09       1
# 22     1.930701e+09       1
# ...             ...     ...
# 49986  1.930846e+09       1
# 49987  2.960621e+09       1
# 49988  1.990572e+09       1
# 49991  1.930773e+09       1
# 49993  1.930880e+09       1
#
# [10000 rows x 17 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# 6              U001  0200763152    PERFOR systems  2019-08-01 00:00:00
# 7              U001  0200780825      SYSCO FO llc  2019-09-18 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 1             2019.0  1.929516e+09   2019-06-18              20190619
# 3             2019.0  1.928996e+09   2019-03-20              20190320
# 4             2019.0  1.929976e+09   2019-10-08              20191007
# 6             2019.0  1.929624e+09   2019-07-17              20190716
# 7             2019.0  1.929830e+09   2019-09-06              20190905
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930357e+09   2020-01-07              20200105
# 49996         2019.0  1.929009e+09   2019-03-24              20190322
# 49997         2019.0  1.928940e+09   2019-03-12              20190312
# 49998         2019.0  1.929669e+09   2019-07-30              20190727
# 49999         2019.0  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 1                    20190618   20190703.0              USD            RV
# 3                    20190320   20190326.0              USD            RV
# 4                    20191008   20191112.0              USD            RV
# 6                    20190717   20190801.0              USD            RV
# 7                    20190906   20190921.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200107   20200122.0              USD            RV
# 49996                20190324   20190408.0              USD            RV
# 49997                20190312   20190516.0              USD            RV
# 49998                20190730   20190814.0              USD            RV
# 49999                20191023   20191108.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 1              101378.70            20190618.0               NAA8
# 3               12904.41            20190316.0               NAM2
# 4               12965.40            20191008.0               NAG2
# 6               42241.46            20190717.0               NAA8
# 7                1698.40            20190906.0               NAA8
# ...                  ...                   ...                ...
# 49995             311.84            20200107.0               NAH4
# 49996           40742.51            20190324.0               NAH4
# 49997            1929.63            20190312.0               NAGD
# 49998           17519.05            20190730.0               NAA8
# 49999             501.84            20191016.0               NAM4
#
#          invoice_id  isOpen
# 1      1.929516e+09       0
# 3      1.928996e+09       0
# 4      1.929976e+09       0
# 6      1.929624e+09       0
# 7      1.929830e+09       0
# ...             ...     ...
# 49995  1.930357e+09       0
# 49996  1.929009e+09       0
# 49997  1.928940e+09       0
# 49998  1.929669e+09       0
# 49999  1.930046e+09       0
#
# [40000 rows x 17 columns]

# %%
data.nunique()
# Out:
# business_code                 5
# cust_number                1333
# name_customer              3896
# clear_date                  401
# buisness_year                 2
# doc_id                    39166
# posting_date                422
# document_create_date        424
# document_create_date.1      423
# due_in_date                 491
# invoice_currency              2
# document type                 2
# total_open_amount         35685
# baseline_create_date        435
# cust_payment_terms           74
# invoice_id                39166
# isOpen                        1
# dtype: int64

# %%
data.isnull().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                0
# isOpen                    0
# dtype: int64

# %%
data.drop(['isOpen'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# 6              U001  0200763152    PERFOR systems  2019-08-01 00:00:00
# 7              U001  0200780825      SYSCO FO llc  2019-09-18 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 1             2019.0  1.929516e+09   2019-06-18              20190619
# 3             2019.0  1.928996e+09   2019-03-20              20190320
# 4             2019.0  1.929976e+09   2019-10-08              20191007
# 6             2019.0  1.929624e+09   2019-07-17              20190716
# 7             2019.0  1.929830e+09   2019-09-06              20190905
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930357e+09   2020-01-07              20200105
# 49996         2019.0  1.929009e+09   2019-03-24              20190322
# 49997         2019.0  1.928940e+09   2019-03-12              20190312
# 49998         2019.0  1.929669e+09   2019-07-30              20190727
# 49999         2019.0  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 1                    20190618   20190703.0              USD            RV
# 3                    20190320   20190326.0              USD            RV
# 4                    20191008   20191112.0              USD            RV
# 6                    20190717   20190801.0              USD            RV
# 7                    20190906   20190921.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200107   20200122.0              USD            RV
# 49996                20190324   20190408.0              USD            RV
# 49997                20190312   20190516.0              USD            RV
# 49998                20190730   20190814.0              USD            RV
# 49999                20191023   20191108.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 1              101378.70            20190618.0               NAA8
# 3               12904.41            20190316.0               NAM2
# 4               12965.40            20191008.0               NAG2
# 6               42241.46            20190717.0               NAA8
# 7                1698.40            20190906.0               NAA8
# ...                  ...                   ...                ...
# 49995             311.84            20200107.0               NAH4
# 49996           40742.51            20190324.0               NAH4
# 49997            1929.63            20190312.0               NAGD
# 49998           17519.05            20190730.0               NAA8
# 49999             501.84            20191016.0               NAM4
#
#          invoice_id
# 1      1.929516e+09
# 3      1.928996e+09
# 4      1.929976e+09
# 6      1.929624e+09
# 7      1.929830e+09
# ...             ...
# 49995  1.930357e+09
# 49996  1.929009e+09
# 49997  1.928940e+09
# 49998  1.929669e+09
# 49999  1.930046e+09
#
# [40000 rows x 16 columns]

# %%
data.buisness_year .value_counts()
# Out:
# 2019.0    34755
# 2020.0     5245
# Name: buisness_year, dtype: int64

# %%
data['actual_open_amount'] = data['total_open_amount'].where(data['invoice_currency']=='USD', data['total_open_amount'] * 0.8)

# %%
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# 6              U001  0200763152    PERFOR systems  2019-08-01 00:00:00
# 7              U001  0200780825      SYSCO FO llc  2019-09-18 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 1             2019.0  1.929516e+09   2019-06-18              20190619
# 3             2019.0  1.928996e+09   2019-03-20              20190320
# 4             2019.0  1.929976e+09   2019-10-08              20191007
# 6             2019.0  1.929624e+09   2019-07-17              20190716
# 7             2019.0  1.929830e+09   2019-09-06              20190905
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930357e+09   2020-01-07              20200105
# 49996         2019.0  1.929009e+09   2019-03-24              20190322
# 49997         2019.0  1.928940e+09   2019-03-12              20190312
# 49998         2019.0  1.929669e+09   2019-07-30              20190727
# 49999         2019.0  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 1                    20190618   20190703.0              USD            RV
# 3                    20190320   20190326.0              USD            RV
# 4                    20191008   20191112.0              USD            RV
# 6                    20190717   20190801.0              USD            RV
# 7                    20190906   20190921.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200107   20200122.0              USD            RV
# 49996                20190324   20190408.0              USD            RV
# 49997                20190312   20190516.0              USD            RV
# 49998                20190730   20190814.0              USD            RV
# 49999                20191023   20191108.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 1              101378.70            20190618.0               NAA8
# 3               12904.41            20190316.0               NAM2
# 4               12965.40            20191008.0               NAG2
# 6               42241.46            20190717.0               NAA8
# 7                1698.40            20190906.0               NAA8
# ...                  ...                   ...                ...
# 49995             311.84            20200107.0               NAH4
# 49996           40742.51            20190324.0               NAH4
# 49997            1929.63            20190312.0               NAGD
# 49998           17519.05            20190730.0               NAA8
# 49999             501.84            20191016.0               NAM4
#
#          invoice_id  actual_open_amount
# 1      1.929516e+09           101378.70
# 3      1.928996e+09            12904.41
# 4      1.929976e+09            12965.40
# 6      1.929624e+09            42241.46
# 7      1.929830e+09             1698.40
# ...             ...                 ...
# 49995  1.930357e+09              311.84
# 49996  1.929009e+09            40742.51
# 49997  1.928940e+09             1929.63
# 49998  1.929669e+09            17519.05
# 49999  1.930046e+09              501.84
#
# [40000 rows x 17 columns]

# %%
data.drop(['invoice_currency'],axis =1,inplace = True)
data
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 1              U001  0200750051  ALBER foundation  2019-07-03 00:00:00
# 3              U001  0200416837       DEC systems  2019-03-25 00:00:00
# 4              U001      CCCA02         KRAFT  co  2019-11-27 00:00:00
# 6              U001  0200763152    PERFOR systems  2019-08-01 00:00:00
# 7              U001  0200780825      SYSCO FO llc  2019-09-18 00:00:00
# ...             ...         ...               ...                  ...
# 49995          U001  0200769623          WAL-MAR   2020-01-21 00:00:00
# 49996          U001   200759878    SA corporation  2019-04-09 00:00:00
# 49997          U001  0100015557          BI trust  2019-03-25 00:00:00
# 49998          U001  0200776463         KROGE llc  2019-08-14 00:00:00
# 49999          U001  0200803720    DEC foundation  2019-11-01 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 1             2019.0  1.929516e+09   2019-06-18              20190619
# 3             2019.0  1.928996e+09   2019-03-20              20190320
# 4             2019.0  1.929976e+09   2019-10-08              20191007
# 6             2019.0  1.929624e+09   2019-07-17              20190716
# 7             2019.0  1.929830e+09   2019-09-06              20190905
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930357e+09   2020-01-07              20200105
# 49996         2019.0  1.929009e+09   2019-03-24              20190322
# 49997         2019.0  1.928940e+09   2019-03-12              20190312
# 49998         2019.0  1.929669e+09   2019-07-30              20190727
# 49999         2019.0  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 1                    20190618   20190703.0            RV          101378.70
# 3                    20190320   20190326.0            RV           12904.41
# 4                    20191008   20191112.0            RV           12965.40
# 6                    20190717   20190801.0            RV           42241.46
# 7                    20190906   20190921.0            RV            1698.40
# ...                       ...          ...           ...                ...
# 49995                20200107   20200122.0            RV             311.84
# 49996                20190324   20190408.0            RV           40742.51
# 49997                20190312   20190516.0            RV            1929.63
# 49998                20190730   20190814.0            RV           17519.05
# 49999                20191023   20191108.0            RV             501.84
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 1                20190618.0               NAA8  1.929516e+09
# 3                20190316.0               NAM2  1.928996e+09
# 4                20191008.0               NAG2  1.929976e+09
# 6                20190717.0               NAA8  1.929624e+09
# 7                20190906.0               NAA8  1.929830e+09
# ...                     ...                ...           ...
# 49995            20200107.0               NAH4  1.930357e+09
# 49996            20190324.0               NAH4  1.929009e+09
# 49997            20190312.0               NAGD  1.928940e+09
# 49998            20190730.0               NAA8  1.929669e+09
# 49999            20191016.0               NAM4  1.930046e+09
#
#        actual_open_amount
# 1               101378.70
# 3                12904.41
# 4                12965.40
# 6                42241.46
# 7                 1698.40
# ...                   ...
# 49995              311.84
# 49996            40742.51
# 49997             1929.63
# 49998            17519.05
# 49999              501.84
#
# [40000 rows x 16 columns]

# %%
data['clear_date']=pd.to_datetime(data['clear_date']).dt.normalize()
data
# Out:
#       business_code cust_number     name_customer clear_date  buisness_year  \
# 1              U001  0200750051  ALBER foundation 2019-07-03         2019.0
# 3              U001  0200416837       DEC systems 2019-03-25         2019.0
# 4              U001      CCCA02         KRAFT  co 2019-11-27         2019.0
# 6              U001  0200763152    PERFOR systems 2019-08-01         2019.0
# 7              U001  0200780825      SYSCO FO llc 2019-09-18         2019.0
# ...             ...         ...               ...        ...            ...
# 49995          U001  0200769623          WAL-MAR  2020-01-21         2020.0
# 49996          U001   200759878    SA corporation 2019-04-09         2019.0
# 49997          U001  0100015557          BI trust 2019-03-25         2019.0
# 49998          U001  0200776463         KROGE llc 2019-08-14         2019.0
# 49999          U001  0200803720    DEC foundation 2019-11-01         2019.0
#
#              doc_id posting_date  document_create_date  \
# 1      1.929516e+09   2019-06-18              20190619
# 3      1.928996e+09   2019-03-20              20190320
# 4      1.929976e+09   2019-10-08              20191007
# 6      1.929624e+09   2019-07-17              20190716
# 7      1.929830e+09   2019-09-06              20190905
# ...             ...          ...                   ...
# 49995  1.930357e+09   2020-01-07              20200105
# 49996  1.929009e+09   2019-03-24              20190322
# 49997  1.928940e+09   2019-03-12              20190312
# 49998  1.929669e+09   2019-07-30              20190727
# 49999  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 1                    20190618   20190703.0            RV          101378.70
# 3                    20190320   20190326.0            RV           12904.41
# 4                    20191008   20191112.0            RV           12965.40
# 6                    20190717   20190801.0            RV           42241.46
# 7                    20190906   20190921.0            RV            1698.40
# ...                       ...          ...           ...                ...
# 49995                20200107   20200122.0            RV             311.84
# 49996                20190324   20190408.0            RV           40742.51
# 49997                20190312   20190516.0            RV            1929.63
# 49998                20190730   20190814.0            RV           17519.05
# 49999                20191023   20191108.0            RV             501.84
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 1                20190618.0               NAA8  1.929516e+09
# 3                20190316.0               NAM2  1.928996e+09
# 4                20191008.0               NAG2  1.929976e+09
# 6                20190717.0               NAA8  1.929624e+09
# 7                20190906.0               NAA8  1.929830e+09
# ...                     ...                ...           ...
# 49995            20200107.0               NAH4  1.930357e+09
# 49996            20190324.0               NAH4  1.929009e+09
# 49997            20190312.0               NAGD  1.928940e+09
# 49998            20190730.0               NAA8  1.929669e+09
# 49999            20191016.0               NAM4  1.930046e+09
#
#        actual_open_amount
# 1               101378.70
# 3                12904.41
# 4                12965.40
# 6                42241.46
# 7                 1698.40
# ...                   ...
# 49995              311.84
# 49996            40742.51
# 49997             1929.63
# 49998            17519.05
# 49999              501.84
#
# [40000 rows x 16 columns]

# %%
data['posting_date']=pd.to_datetime(data['posting_date']).dt.normalize()
data
# Out:
#       business_code cust_number     name_customer clear_date  buisness_year  \
# 1              U001  0200750051  ALBER foundation 2019-07-03         2019.0
# 3              U001  0200416837       DEC systems 2019-03-25         2019.0
# 4              U001      CCCA02         KRAFT  co 2019-11-27         2019.0
# 6              U001  0200763152    PERFOR systems 2019-08-01         2019.0
# 7              U001  0200780825      SYSCO FO llc 2019-09-18         2019.0
# ...             ...         ...               ...        ...            ...
# 49995          U001  0200769623          WAL-MAR  2020-01-21         2020.0
# 49996          U001   200759878    SA corporation 2019-04-09         2019.0
# 49997          U001  0100015557          BI trust 2019-03-25         2019.0
# 49998          U001  0200776463         KROGE llc 2019-08-14         2019.0
# 49999          U001  0200803720    DEC foundation 2019-11-01         2019.0
#
#              doc_id posting_date  document_create_date  \
# 1      1.929516e+09   2019-06-18              20190619
# 3      1.928996e+09   2019-03-20              20190320
# 4      1.929976e+09   2019-10-08              20191007
# 6      1.929624e+09   2019-07-17              20190716
# 7      1.929830e+09   2019-09-06              20190905
# ...             ...          ...                   ...
# 49995  1.930357e+09   2020-01-07              20200105
# 49996  1.929009e+09   2019-03-24              20190322
# 49997  1.928940e+09   2019-03-12              20190312
# 49998  1.929669e+09   2019-07-30              20190727
# 49999  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 1                    20190618   20190703.0            RV          101378.70
# 3                    20190320   20190326.0            RV           12904.41
# 4                    20191008   20191112.0            RV           12965.40
# 6                    20190717   20190801.0            RV           42241.46
# 7                    20190906   20190921.0            RV            1698.40
# ...                       ...          ...           ...                ...
# 49995                20200107   20200122.0            RV             311.84
# 49996                20190324   20190408.0            RV           40742.51
# 49997                20190312   20190516.0            RV            1929.63
# 49998                20190730   20190814.0            RV           17519.05
# 49999                20191023   20191108.0            RV             501.84
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 1                20190618.0               NAA8  1.929516e+09
# 3                20190316.0               NAM2  1.928996e+09
# 4                20191008.0               NAG2  1.929976e+09
# 6                20190717.0               NAA8  1.929624e+09
# 7                20190906.0               NAA8  1.929830e+09
# ...                     ...                ...           ...
# 49995            20200107.0               NAH4  1.930357e+09
# 49996            20190324.0               NAH4  1.929009e+09
# 49997            20190312.0               NAGD  1.928940e+09
# 49998            20190730.0               NAA8  1.929669e+09
# 49999            20191016.0               NAM4  1.930046e+09
#
#        actual_open_amount
# 1               101378.70
# 3                12904.41
# 4                12965.40
# 6                42241.46
# 7                 1698.40
# ...                   ...
# 49995              311.84
# 49996            40742.51
# 49997             1929.63
# 49998            17519.05
# 49999              501.84
#
# [40000 rows x 16 columns]

# %%
data['due_in_date']=pd.to_datetime(data['due_in_date'],format='%Y%m%d')
data
# Out:
#       business_code cust_number     name_customer clear_date  buisness_year  \
# 1              U001  0200750051  ALBER foundation 2019-07-03         2019.0
# 3              U001  0200416837       DEC systems 2019-03-25         2019.0
# 4              U001      CCCA02         KRAFT  co 2019-11-27         2019.0
# 6              U001  0200763152    PERFOR systems 2019-08-01         2019.0
# 7              U001  0200780825      SYSCO FO llc 2019-09-18         2019.0
# ...             ...         ...               ...        ...            ...
# 49995          U001  0200769623          WAL-MAR  2020-01-21         2020.0
# 49996          U001   200759878    SA corporation 2019-04-09         2019.0
# 49997          U001  0100015557          BI trust 2019-03-25         2019.0
# 49998          U001  0200776463         KROGE llc 2019-08-14         2019.0
# 49999          U001  0200803720    DEC foundation 2019-11-01         2019.0
#
#              doc_id posting_date  document_create_date  \
# 1      1.929516e+09   2019-06-18              20190619
# 3      1.928996e+09   2019-03-20              20190320
# 4      1.929976e+09   2019-10-08              20191007
# 6      1.929624e+09   2019-07-17              20190716
# 7      1.929830e+09   2019-09-06              20190905
# ...             ...          ...                   ...
# 49995  1.930357e+09   2020-01-07              20200105
# 49996  1.929009e+09   2019-03-24              20190322
# 49997  1.928940e+09   2019-03-12              20190312
# 49998  1.929669e+09   2019-07-30              20190727
# 49999  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1 due_in_date document type  total_open_amount  \
# 1                    20190618  2019-07-03            RV          101378.70
# 3                    20190320  2019-03-26            RV           12904.41
# 4                    20191008  2019-11-12            RV           12965.40
# 6                    20190717  2019-08-01            RV           42241.46
# 7                    20190906  2019-09-21            RV            1698.40
# ...                       ...         ...           ...                ...
# 49995                20200107  2020-01-22            RV             311.84
# 49996                20190324  2019-04-08            RV           40742.51
# 49997                20190312  2019-05-16            RV            1929.63
# 49998                20190730  2019-08-14            RV           17519.05
# 49999                20191023  2019-11-08            RV             501.84
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 1                20190618.0               NAA8  1.929516e+09
# 3                20190316.0               NAM2  1.928996e+09
# 4                20191008.0               NAG2  1.929976e+09
# 6                20190717.0               NAA8  1.929624e+09
# 7                20190906.0               NAA8  1.929830e+09
# ...                     ...                ...           ...
# 49995            20200107.0               NAH4  1.930357e+09
# 49996            20190324.0               NAH4  1.929009e+09
# 49997            20190312.0               NAGD  1.928940e+09
# 49998            20190730.0               NAA8  1.929669e+09
# 49999            20191016.0               NAM4  1.930046e+09
#
#        actual_open_amount
# 1               101378.70
# 3                12904.41
# 4                12965.40
# 6                42241.46
# 7                 1698.40
# ...                   ...
# 49995              311.84
# 49996            40742.51
# 49997             1929.63
# 49998            17519.05
# 49999              501.84
#
# [40000 rows x 16 columns]

# %%
data['delay_days'] = pd.to_numeric((data['clear_date']- data['due_in_date']).dt.days, downcast='integer')
data
# Out:
#       business_code cust_number     name_customer clear_date  buisness_year  \
# 1              U001  0200750051  ALBER foundation 2019-07-03         2019.0
# 3              U001  0200416837       DEC systems 2019-03-25         2019.0
# 4              U001      CCCA02         KRAFT  co 2019-11-27         2019.0
# 6              U001  0200763152    PERFOR systems 2019-08-01         2019.0
# 7              U001  0200780825      SYSCO FO llc 2019-09-18         2019.0
# ...             ...         ...               ...        ...            ...
# 49995          U001  0200769623          WAL-MAR  2020-01-21         2020.0
# 49996          U001   200759878    SA corporation 2019-04-09         2019.0
# 49997          U001  0100015557          BI trust 2019-03-25         2019.0
# 49998          U001  0200776463         KROGE llc 2019-08-14         2019.0
# 49999          U001  0200803720    DEC foundation 2019-11-01         2019.0
#
#              doc_id posting_date  document_create_date  \
# 1      1.929516e+09   2019-06-18              20190619
# 3      1.928996e+09   2019-03-20              20190320
# 4      1.929976e+09   2019-10-08              20191007
# 6      1.929624e+09   2019-07-17              20190716
# 7      1.929830e+09   2019-09-06              20190905
# ...             ...          ...                   ...
# 49995  1.930357e+09   2020-01-07              20200105
# 49996  1.929009e+09   2019-03-24              20190322
# 49997  1.928940e+09   2019-03-12              20190312
# 49998  1.929669e+09   2019-07-30              20190727
# 49999  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1 due_in_date document type  total_open_amount  \
# 1                    20190618  2019-07-03            RV          101378.70
# 3                    20190320  2019-03-26            RV           12904.41
# 4                    20191008  2019-11-12            RV           12965.40
# 6                    20190717  2019-08-01            RV           42241.46
# 7                    20190906  2019-09-21            RV            1698.40
# ...                       ...         ...           ...                ...
# 49995                20200107  2020-01-22            RV             311.84
# 49996                20190324  2019-04-08            RV           40742.51
# 49997                20190312  2019-05-16            RV            1929.63
# 49998                20190730  2019-08-14            RV           17519.05
# 49999                20191023  2019-11-08            RV             501.84
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 1                20190618.0               NAA8  1.929516e+09
# 3                20190316.0               NAM2  1.928996e+09
# 4                20191008.0               NAG2  1.929976e+09
# 6                20190717.0               NAA8  1.929624e+09
# 7                20190906.0               NAA8  1.929830e+09
# ...                     ...                ...           ...
# 49995            20200107.0               NAH4  1.930357e+09
# 49996            20190324.0               NAH4  1.929009e+09
# 49997            20190312.0               NAGD  1.928940e+09
# 49998            20190730.0               NAA8  1.929669e+09
# 49999            20191016.0               NAM4  1.930046e+09
#
#        actual_open_amount  delay_days
# 1               101378.70           0
# 3                12904.41          -1
# 4                12965.40          15
# 6                42241.46           0
# 7                 1698.40          -3
# ...                   ...         ...
# 49995              311.84          -1
# 49996            40742.51           1
# 49997             1929.63         -52
# 49998            17519.05           0
# 49999              501.84          -7
#
# [40000 rows x 17 columns]

# %%
newdata1 = data[data.due_in_date.isna()].copy()
newdata
# Out:
#       business_code cust_number    name_customer clear_date  buisness_year  \
# 0              CA02  0140105678  SAPUTO  systems        NaN         2020.0
# 2              U001  0200769623  WAL-MAR systems        NaN         2020.0
# 5              U001  0200726979      BJ'S  trust        NaN         2020.0
# 17             U001  0200780825      SYSCO FO us        NaN         2020.0
# 22             U001  0200761734       H E BUT us        NaN         2020.0
# ...             ...         ...              ...        ...            ...
# 49986          U001  0200769623    WAL-MAR trust        NaN         2020.0
# 49987          CA02  0140104440    SO associates        NaN         2020.0
# 49988          U002  0200501669          WAL MA         NaN         2020.0
# 49991          U001  0200799342         MITCH us        NaN         2020.0
# 49993          U001  0100036318           TFC us        NaN         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      2.960620e+09   2020-03-10              20200310
# 2      1.930689e+09   2020-03-24              20200323
# 5      1.930752e+09   2020-04-06              20200406
# 17     1.930628e+09   2020-03-10              20200309
# 22     1.930701e+09   2020-03-28              20200325
# ...             ...          ...                   ...
# 49986  1.930846e+09   2020-05-01              20200501
# 49987  2.960621e+09   2020-03-12              20200312
# 49988  1.990572e+09   2020-03-20              20200318
# 49991  1.930773e+09   2020-04-10              20200410
# 49993  1.930880e+09   2020-05-08              20200508
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200310   20200329.0              CAD            RV
# 2                    20200324   20200408.0              USD            RV
# 5                    20200406   20200421.0              USD            RV
# 17                   20200310   20200325.0              USD            RV
# 22                   20200328   20200412.0              USD            RV
# ...                       ...          ...              ...           ...
# 49986                20200501   20200516.0              USD            RV
# 49987                20200312   20200327.0              CAD            RV
# 49988                20200320   20200424.0              USD            RV
# 49991                20200410   20200425.0              USD            RV
# 49993                20200508   20200518.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               12140.10            20200319.0               CA10
# 2               46117.37            20200324.0               NAH4
# 5                 404.74            20200406.0               NAA8
# 17               7090.54            20200310.0               NAA8
# 22              87170.76            20200328.0               NAA8
# ...                  ...                   ...                ...
# 49986           57004.06            20200501.0               NAH4
# 49987           61690.42            20200317.0               CA10
# 49988           37988.63            20200320.0               NAG2
# 49991           11175.46            20200410.0               NAA8
# 49993           28778.75            20200508.0               NA10
#
#          invoice_id  isOpen
# 0      2.960620e+09       1
# 2      1.930689e+09       1
# 5      1.930752e+09       1
# 17     1.930628e+09       1
# 22     1.930701e+09       1
# ...             ...     ...
# 49986  1.930846e+09       1
# 49987  2.960621e+09       1
# 49988  1.990572e+09       1
# 49991  1.930773e+09       1
# 49993  1.930880e+09       1
#
# [10000 rows x 17 columns]

# %%
data.drop(['clear_date','due_in_date'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number     name_customer  buisness_year  \
# 1              U001  0200750051  ALBER foundation         2019.0
# 3              U001  0200416837       DEC systems         2019.0
# 4              U001      CCCA02         KRAFT  co         2019.0
# 6              U001  0200763152    PERFOR systems         2019.0
# 7              U001  0200780825      SYSCO FO llc         2019.0
# ...             ...         ...               ...            ...
# 49995          U001  0200769623          WAL-MAR          2020.0
# 49996          U001   200759878    SA corporation         2019.0
# 49997          U001  0100015557          BI trust         2019.0
# 49998          U001  0200776463         KROGE llc         2019.0
# 49999          U001  0200803720    DEC foundation         2019.0
#
#              doc_id posting_date  document_create_date  \
# 1      1.929516e+09   2019-06-18              20190619
# 3      1.928996e+09   2019-03-20              20190320
# 4      1.929976e+09   2019-10-08              20191007
# 6      1.929624e+09   2019-07-17              20190716
# 7      1.929830e+09   2019-09-06              20190905
# ...             ...          ...                   ...
# 49995  1.930357e+09   2020-01-07              20200105
# 49996  1.929009e+09   2019-03-24              20190322
# 49997  1.928940e+09   2019-03-12              20190312
# 49998  1.929669e+09   2019-07-30              20190727
# 49999  1.930046e+09   2019-10-23              20191023
#
#        document_create_date.1 document type  total_open_amount  \
# 1                    20190618            RV          101378.70
# 3                    20190320            RV           12904.41
# 4                    20191008            RV           12965.40
# 6                    20190717            RV           42241.46
# 7                    20190906            RV            1698.40
# ...                       ...           ...                ...
# 49995                20200107            RV             311.84
# 49996                20190324            RV           40742.51
# 49997                20190312            RV            1929.63
# 49998                20190730            RV           17519.05
# 49999                20191023            RV             501.84
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 1                20190618.0               NAA8  1.929516e+09
# 3                20190316.0               NAM2  1.928996e+09
# 4                20191008.0               NAG2  1.929976e+09
# 6                20190717.0               NAA8  1.929624e+09
# 7                20190906.0               NAA8  1.929830e+09
# ...                     ...                ...           ...
# 49995            20200107.0               NAH4  1.930357e+09
# 49996            20190324.0               NAH4  1.929009e+09
# 49997            20190312.0               NAGD  1.928940e+09
# 49998            20190730.0               NAA8  1.929669e+09
# 49999            20191016.0               NAM4  1.930046e+09
#
#        actual_open_amount  delay_days
# 1               101378.70           0
# 3                12904.41          -1
# 4                12965.40          15
# 6                42241.46           0
# 7                 1698.40          -3
# ...                   ...         ...
# 49995              311.84          -1
# 49996            40742.51           1
# 49997             1929.63         -52
# 49998            17519.05           0
# 49999              501.84          -7
#
# [40000 rows x 15 columns]

# %%
data.shape
# Out:
# (40000, 15)

# %%
data.sort_values(by=['posting_date'],inplace=True)
data
# Out:
#       business_code cust_number      name_customer  buisness_year  \
# 15815          U001  0200726979  BJ'S  corporation         2019.0
# 39090          U001  0200723794       MID MO trust         2019.0
# 17323          U001  0200014556   ALBER associates         2019.0
# 935            U001  0200743123            KROGER          2019.0
# 48912          U001  0200769623         WAL-MAR us         2019.0
# ...             ...         ...                ...            ...
# 39845          U001  0100031704          DELHAIZE          2020.0
# 44229          CA02  0140105686       SYSC systems         2020.0
# 6944           U001  0200418007      AM associates         2020.0
# 44468          U001  0200126819     MCLANE systems         2020.0
# 738            U001  0200794332         COST trust         2020.0
#
#              doc_id posting_date  document_create_date  \
# 15815  1.928539e+09   2018-12-30              20181229
# 39090  1.928540e+09   2018-12-30              20181229
# 17323  1.928545e+09   2018-12-30              20181231
# 935    1.928540e+09   2018-12-30              20181229
# 48912  1.928540e+09   2018-12-30              20181229
# ...             ...          ...                   ...
# 39845  1.930579e+09   2020-02-27              20200227
# 44229  2.960617e+09   2020-02-27              20200227
# 6944   1.930568e+09   2020-02-27              20200225
# 44468  1.930558e+09   2020-02-27              20200222
# 738    1.930574e+09   2020-02-27              20200226
#
#        document_create_date.1 document type  total_open_amount  \
# 15815                20181230            RV              53.25
# 39090                20181230            RV          169989.59
# 17323                20181230            RV           69249.78
# 935                  20181230            RV           33241.74
# 48912                20181230            RV           17567.05
# ...                       ...           ...                ...
# 39845                20200227            RV          101667.64
# 44229                20200227            RV            5478.80
# 6944                 20200227            RV           10349.36
# 44468                20200227            RV           53264.58
# 738                  20200227            RV           10990.81
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 15815            20181230.0               NAA8  1.928539e+09
# 39090            20181230.0               NAA8  1.928540e+09
# 17323            20181230.0               NAA8  1.928545e+09
# 935              20181230.0               NAA8  1.928540e+09
# 48912            20181230.0               NAH4  1.928540e+09
# ...                     ...                ...           ...
# 39845            20200227.0               NAA8  1.930579e+09
# 44229            20200229.0               CA10  2.960617e+09
# 6944             20200227.0               NAA8  1.930568e+09
# 44468            20200227.0               NAA8  1.930558e+09
# 738              20200227.0               NAAX  1.930574e+09
#
#        actual_open_amount  delay_days
# 15815               53.25           1
# 39090           169989.59           0
# 17323            69249.78           0
# 935              33241.74           0
# 48912            17567.05          -5
# ...                   ...         ...
# 39845           101667.64           4
# 44229             4383.04           2
# 6944             10349.36           6
# 44468            53264.58           5
# 738              10990.81          -1
#
# [40000 rows x 15 columns]

# %%
data.set_index
data
# Out:
#       business_code cust_number      name_customer  buisness_year  \
# 15815          U001  0200726979  BJ'S  corporation         2019.0
# 39090          U001  0200723794       MID MO trust         2019.0
# 17323          U001  0200014556   ALBER associates         2019.0
# 935            U001  0200743123            KROGER          2019.0
# 48912          U001  0200769623         WAL-MAR us         2019.0
# ...             ...         ...                ...            ...
# 39845          U001  0100031704          DELHAIZE          2020.0
# 44229          CA02  0140105686       SYSC systems         2020.0
# 6944           U001  0200418007      AM associates         2020.0
# 44468          U001  0200126819     MCLANE systems         2020.0
# 738            U001  0200794332         COST trust         2020.0
#
#              doc_id posting_date  document_create_date  \
# 15815  1.928539e+09   2018-12-30              20181229
# 39090  1.928540e+09   2018-12-30              20181229
# 17323  1.928545e+09   2018-12-30              20181231
# 935    1.928540e+09   2018-12-30              20181229
# 48912  1.928540e+09   2018-12-30              20181229
# ...             ...          ...                   ...
# 39845  1.930579e+09   2020-02-27              20200227
# 44229  2.960617e+09   2020-02-27              20200227
# 6944   1.930568e+09   2020-02-27              20200225
# 44468  1.930558e+09   2020-02-27              20200222
# 738    1.930574e+09   2020-02-27              20200226
#
#        document_create_date.1 document type  total_open_amount  \
# 15815                20181230            RV              53.25
# 39090                20181230            RV          169989.59
# 17323                20181230            RV           69249.78
# 935                  20181230            RV           33241.74
# 48912                20181230            RV           17567.05
# ...                       ...           ...                ...
# 39845                20200227            RV          101667.64
# 44229                20200227            RV            5478.80
# 6944                 20200227            RV           10349.36
# 44468                20200227            RV           53264.58
# 738                  20200227            RV           10990.81
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 15815            20181230.0               NAA8  1.928539e+09
# 39090            20181230.0               NAA8  1.928540e+09
# 17323            20181230.0               NAA8  1.928545e+09
# 935              20181230.0               NAA8  1.928540e+09
# 48912            20181230.0               NAH4  1.928540e+09
# ...                     ...                ...           ...
# 39845            20200227.0               NAA8  1.930579e+09
# 44229            20200229.0               CA10  2.960617e+09
# 6944             20200227.0               NAA8  1.930568e+09
# 44468            20200227.0               NAA8  1.930558e+09
# 738              20200227.0               NAAX  1.930574e+09
#
#        actual_open_amount  delay_days
# 15815               53.25           1
# 39090           169989.59           0
# 17323            69249.78           0
# 935              33241.74           0
# 48912            17567.05          -5
# ...                   ...         ...
# 39845           101667.64           4
# 44229             4383.04           2
# 6944             10349.36           6
# 44468            53264.58           5
# 738              10990.81          -1
#
# [40000 rows x 15 columns]

# %%
data.reset_index(drop=True, inplace=True)
data
# Out:
#       business_code cust_number      name_customer  buisness_year  \
# 0              U001  0200726979  BJ'S  corporation         2019.0
# 1              U001  0200723794       MID MO trust         2019.0
# 2              U001  0200014556   ALBER associates         2019.0
# 3              U001  0200743123            KROGER          2019.0
# 4              U001  0200769623         WAL-MAR us         2019.0
# ...             ...         ...                ...            ...
# 39995          U001  0100031704          DELHAIZE          2020.0
# 39996          CA02  0140105686       SYSC systems         2020.0
# 39997          U001  0200418007      AM associates         2020.0
# 39998          U001  0200126819     MCLANE systems         2020.0
# 39999          U001  0200794332         COST trust         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928539e+09   2018-12-30              20181229
# 1      1.928540e+09   2018-12-30              20181229
# 2      1.928545e+09   2018-12-30              20181231
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928540e+09   2018-12-30              20181229
# ...             ...          ...                   ...
# 39995  1.930579e+09   2020-02-27              20200227
# 39996  2.960617e+09   2020-02-27              20200227
# 39997  1.930568e+09   2020-02-27              20200225
# 39998  1.930558e+09   2020-02-27              20200222
# 39999  1.930574e+09   2020-02-27              20200226
#
#        document_create_date.1 document type  total_open_amount  \
# 0                    20181230            RV              53.25
# 1                    20181230            RV          169989.59
# 2                    20181230            RV           69249.78
# 3                    20181230            RV           33241.74
# 4                    20181230            RV           17567.05
# ...                       ...           ...                ...
# 39995                20200227            RV          101667.64
# 39996                20200227            RV            5478.80
# 39997                20200227            RV           10349.36
# 39998                20200227            RV           53264.58
# 39999                20200227            RV           10990.81
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20181230.0               NAA8  1.928539e+09
# 1                20181230.0               NAA8  1.928540e+09
# 2                20181230.0               NAA8  1.928545e+09
# 3                20181230.0               NAA8  1.928540e+09
# 4                20181230.0               NAH4  1.928540e+09
# ...                     ...                ...           ...
# 39995            20200227.0               NAA8  1.930579e+09
# 39996            20200229.0               CA10  2.960617e+09
# 39997            20200227.0               NAA8  1.930568e+09
# 39998            20200227.0               NAA8  1.930558e+09
# 39999            20200227.0               NAAX  1.930574e+09
#
#        actual_open_amount  delay_days
# 0                   53.25           1
# 1               169989.59           0
# 2                69249.78           0
# 3                33241.74           0
# 4                17567.05          -5
# ...                   ...         ...
# 39995           101667.64           4
# 39996             4383.04           2
# 39997            10349.36           6
# 39998            53264.58           5
# 39999            10990.81          -1
#
# [40000 rows x 15 columns]

# %%
data.drop('total_open_amount' ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number      name_customer  buisness_year  \
# 0              U001  0200726979  BJ'S  corporation         2019.0
# 1              U001  0200723794       MID MO trust         2019.0
# 2              U001  0200014556   ALBER associates         2019.0
# 3              U001  0200743123            KROGER          2019.0
# 4              U001  0200769623         WAL-MAR us         2019.0
# ...             ...         ...                ...            ...
# 39995          U001  0100031704          DELHAIZE          2020.0
# 39996          CA02  0140105686       SYSC systems         2020.0
# 39997          U001  0200418007      AM associates         2020.0
# 39998          U001  0200126819     MCLANE systems         2020.0
# 39999          U001  0200794332         COST trust         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928539e+09   2018-12-30              20181229
# 1      1.928540e+09   2018-12-30              20181229
# 2      1.928545e+09   2018-12-30              20181231
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928540e+09   2018-12-30              20181229
# ...             ...          ...                   ...
# 39995  1.930579e+09   2020-02-27              20200227
# 39996  2.960617e+09   2020-02-27              20200227
# 39997  1.930568e+09   2020-02-27              20200225
# 39998  1.930558e+09   2020-02-27              20200222
# 39999  1.930574e+09   2020-02-27              20200226
#
#        document_create_date.1 document type  baseline_create_date  \
# 0                    20181230            RV            20181230.0
# 1                    20181230            RV            20181230.0
# 2                    20181230            RV            20181230.0
# 3                    20181230            RV            20181230.0
# 4                    20181230            RV            20181230.0
# ...                       ...           ...                   ...
# 39995                20200227            RV            20200227.0
# 39996                20200227            RV            20200229.0
# 39997                20200227            RV            20200227.0
# 39998                20200227            RV            20200227.0
# 39999                20200227            RV            20200227.0
#
#       cust_payment_terms    invoice_id  actual_open_amount  delay_days
# 0                   NAA8  1.928539e+09               53.25           1
# 1                   NAA8  1.928540e+09           169989.59           0
# 2                   NAA8  1.928545e+09            69249.78           0
# 3                   NAA8  1.928540e+09            33241.74           0
# 4                   NAH4  1.928540e+09            17567.05          -5
# ...                  ...           ...                 ...         ...
# 39995               NAA8  1.930579e+09           101667.64           4
# 39996               CA10  2.960617e+09             4383.04           2
# 39997               NAA8  1.930568e+09            10349.36           6
# 39998               NAA8  1.930558e+09            53264.58           5
# 39999               NAAX  1.930574e+09            10990.81          -1
#
# [40000 rows x 14 columns]

# %%
X = data.drop('delay_days',axis=1)

# %%
y = data['delay_days']

# %%
from sklearn.model_selection import train_test_split
X_train,X_inter_test,y_train,y_inter_test = train_test_split(X,y,test_size=0.5,random_state=42 , shuffle = False)

# %%
X_val,X_test,y_val,y_test = train_test_split(X_inter_test,y_inter_test,test_size=0.5,random_state=42 , shuffle = False)

# %%
X_train.shape , X_val.shape , X_test.shape
# Out:
# ((20000, 13), (10000, 13), (10000, 13))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   buisness_year           20000 non-null  float64
#  4   doc_id                  20000 non-null  float64
#  5   posting_date            20000 non-null  datetime64[ns]
#  6   document_create_date    20000 non-null  int64
#  7   document_create_date.1  20000 non-null  int64
#  8   document type           20000 non-null  object
#  9   baseline_create_date    20000 non-null  float64
#  10  cust_payment_terms      20000 non-null  object
#  11  invoice_id              20000 non-null  float64
#  12  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
X_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 20000 to 29999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           10000 non-null  object
#  1   cust_number             10000 non-null  object
#  2   name_customer           10000 non-null  object
#  3   buisness_year           10000 non-null  float64
#  4   doc_id                  10000 non-null  float64
#  5   posting_date            10000 non-null  datetime64[ns]
#  6   document_create_date    10000 non-null  int64
#  7   document_create_date.1  10000 non-null  int64
#  8   document type           10000 non-null  object
#  9   baseline_create_date    10000 non-null  float64
#  10  cust_payment_terms      10000 non-null  object
#  11  invoice_id              10000 non-null  float64
#  12  actual_open_amount      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 30000 to 39999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           10000 non-null  object
#  1   cust_number             10000 non-null  object
#  2   name_customer           10000 non-null  object
#  3   buisness_year           10000 non-null  float64
#  4   doc_id                  10000 non-null  float64
#  5   posting_date            10000 non-null  datetime64[ns]
#  6   document_create_date    10000 non-null  int64
#  7   document_create_date.1  10000 non-null  int64
#  8   document type           10000 non-null  object
#  9   baseline_create_date    10000 non-null  float64
#  10  cust_payment_terms      10000 non-null  object
#  11  invoice_id              10000 non-null  float64
#  12  actual_open_amount      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
y_train
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4        -5
#          ..
# 19995     2
# 19996     4
# 19997     2
# 19998   -10
# 19999    42
# Name: delay_days, Length: 20000, dtype: int16

# %%
sns.distplot(y_train)
# Out:
# <AxesSubplot:xlabel='delay_days', ylabel='Density'>

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   buisness_year           20000 non-null  float64
#  4   doc_id                  20000 non-null  float64
#  5   posting_date            20000 non-null  datetime64[ns]
#  6   document_create_date    20000 non-null  int64
#  7   document_create_date.1  20000 non-null  int64
#  8   document type           20000 non-null  object
#  9   baseline_create_date    20000 non-null  float64
#  10  cust_payment_terms      20000 non-null  object
#  11  invoice_id              20000 non-null  float64
#  12  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
X_train.merge(y_train,on=X_train.index)
# Out:
#        key_0 business_code cust_number      name_customer  buisness_year  \
# 0          0          U001  0200726979  BJ'S  corporation         2019.0
# 1          1          U001  0200723794       MID MO trust         2019.0
# 2          2          U001  0200014556   ALBER associates         2019.0
# 3          3          U001  0200743123            KROGER          2019.0
# 4          4          U001  0200769623         WAL-MAR us         2019.0
# ...      ...           ...         ...                ...            ...
# 19995  19995          U001  0200759878            SA corp         2019.0
# 19996  19996          CA02  0140104409     LOB associates         2019.0
# 19997  19997          U001  0200726979   BJ'S  associates         2019.0
# 19998  19998          U001  0200708411              SHAM          2019.0
# 19999  19999          U001      CCU013         KRAFT F us         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928539e+09   2018-12-30              20181229
# 1      1.928540e+09   2018-12-30              20181229
# 2      1.928545e+09   2018-12-30              20181231
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928540e+09   2018-12-30              20181229
# ...             ...          ...                   ...
# 19995  1.929626e+09   2019-07-19              20190717
# 19996  2.960566e+09   2019-07-19              20190719
# 19997  1.929635e+09   2019-07-19              20190718
# 19998  1.929636e+09   2019-07-19              20190718
# 19999  1.929637e+09   2019-07-19              20190719
#
#        document_create_date.1 document type  baseline_create_date  \
# 0                    20181230            RV            20181230.0
# 1                    20181230            RV            20181230.0
# 2                    20181230            RV            20181230.0
# 3                    20181230            RV            20181230.0
# 4                    20181230            RV            20181230.0
# ...                       ...           ...                   ...
# 19995                20190719            RV            20190719.0
# 19996                20190719            RV            20190719.0
# 19997                20190719            RV            20190719.0
# 19998                20190719            RV            20190719.0
# 19999                20190719            RV            20190719.0
#
#       cust_payment_terms    invoice_id  actual_open_amount  delay_days
# 0                   NAA8  1.928539e+09               53.25           1
# 1                   NAA8  1.928540e+09           169989.59           0
# 2                   NAA8  1.928545e+09            69249.78           0
# 3                   NAA8  1.928540e+09            33241.74           0
# 4                   NAH4  1.928540e+09            17567.05          -5
# ...                  ...           ...                 ...         ...
# 19995               NAH4  1.929626e+09            15358.44           2
# 19996               CA10  2.960566e+09            74836.52           4
# 19997               NAA8  1.929635e+09               64.74           2
# 19998               NAA8  1.929636e+09            49514.59         -10
# 19999               NAX2  1.929637e+09             9312.00          42
#
# [20000 rows x 15 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   buisness_year           20000 non-null  float64
#  4   doc_id                  20000 non-null  float64
#  5   posting_date            20000 non-null  datetime64[ns]
#  6   document_create_date    20000 non-null  int64
#  7   document_create_date.1  20000 non-null  int64
#  8   document type           20000 non-null  object
#  9   baseline_create_date    20000 non-null  float64
#  10  cust_payment_terms      20000 non-null  object
#  11  invoice_id              20000 non-null  float64
#  12  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
sns.scatterplot(data=X_train.merge(y_train,on=X_train.index) , x = 'delay_days',y='posting_date')
# Out:
# <AxesSubplot:xlabel='delay_days', ylabel='posting_date'>

# %%
sns.scatterplot(data=X_train.merge(y_train,on=X_train.index) , x = 'document_create_date' , y='delay_days')
# Out:
# <AxesSubplot:xlabel='document_create_date', ylabel='delay_days'>

# %%
data.columns
# Out:
# Index(['business_code', 'cust_number', 'name_customer', 'buisness_year',
#        'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'document type', 'baseline_create_date',
#        'cust_payment_terms', 'invoice_id', 'actual_open_amount', 'delay_days'],
#       dtype='object')

# %%
X_train.nunique()
# Out:
# business_code                 5
# cust_number                1099
# name_customer              2820
# buisness_year                 1
# doc_id                    19575
# posting_date                202
# document_create_date        204
# document_create_date.1      203
# document type                 2
# baseline_create_date        212
# cust_payment_terms           62
# invoice_id                19575
# actual_open_amount        18131
# dtype: int64

# %%
X_train.drop('buisness_year' ,axis=1 , inplace=True)
X_val.drop('buisness_year' ,axis=1 , inplace=True)
X_test.drop('buisness_year' ,axis=1 , inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   doc_id                  20000 non-null  float64
#  4   posting_date            20000 non-null  datetime64[ns]
#  5   document_create_date    20000 non-null  int64
#  6   document_create_date.1  20000 non-null  int64
#  7   document type           20000 non-null  object
#  8   baseline_create_date    20000 non-null  float64
#  9   cust_payment_terms      20000 non-null  object
#  10  invoice_id              20000 non-null  float64
#  11  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
business_code_enc = LabelEncoder()
business_code_enc.fit(X_train['business_code'])
X_train['business_code_enc'] = business_code_enc.transform(X_train['business_code'])

# %%
X_train[['business_code_enc','business_code']]
# Out:
#        business_code_enc business_code
# 0                      1          U001
# 1                      1          U001
# 2                      1          U001
# 3                      1          U001
# 4                      1          U001
# ...                  ...           ...
# 19995                  1          U001
# 19996                  0          CA02
# 19997                  1          U001
# 19998                  1          U001
# 19999                  1          U001
#
# [20000 rows x 2 columns]

# %%
X_val['business_code_enc'] = business_code_enc.transform(X_val['business_code'])
X_val[['business_code_enc','business_code']]
# Out:
#        business_code_enc business_code
# 20000                  1          U001
# 20001                  1          U001
# 20002                  1          U001
# 20003                  1          U001
# 20004                  1          U001
# ...                  ...           ...
# 29995                  1          U001
# 29996                  1          U001
# 29997                  1          U001
# 29998                  1          U001
# 29999                  1          U001
#
# [10000 rows x 2 columns]

# %%
X_test['business_code_enc'] = business_code_enc.transform(X_test['business_code'])
X_test[['business_code_enc','business_code']]
# Out:
#        business_code_enc business_code
# 30000                  0          CA02
# 30001                  1          U001
# 30002                  1          U001
# 30003                  1          U001
# 30004                  1          U001
# ...                  ...           ...
# 39995                  1          U001
# 39996                  0          CA02
# 39997                  1          U001
# 39998                  1          U001
# 39999                  1          U001
#
# [10000 rows x 2 columns]

# %%
X_val
# Out:
#       business_code cust_number        name_customer        doc_id  \
# 20000          U001  0200769623        WAL-MAR trust  1.929637e+09
# 20001          U001  0200732755   KROGER corporation  1.929633e+09
# 20002          U001  0200792283            SYSCO  in  1.929633e+09
# 20003          U001   200769623  WAL-MAR corporation  1.929631e+09
# 20004          U001  0200020431            DEC trust  1.929638e+09
# ...             ...         ...                  ...           ...
# 29995          U001  0200704858              WAKE in  1.930056e+09
# 29996          U001  0200707822             PUBLI us  1.930057e+09
# 29997          U001  0200771157      WEIS associates  1.930057e+09
# 29998          U001  0200207985            BAY  corp  1.930058e+09
# 29999          U001      CCU013          KRAFT F llc  1.930051e+09
#
#       posting_date  document_create_date  document_create_date.1  \
# 20000   2019-07-19              20190719                20190719
# 20001   2019-07-19              20190718                20190719
# 20002   2019-07-19              20190718                20190719
# 20003   2019-07-19              20190717                20190719
# 20004   2019-07-19              20190719                20190719
# ...            ...                   ...                     ...
# 29995   2019-10-28              20191027                20191028
# 29996   2019-10-28              20191027                20191028
# 29997   2019-10-28              20191028                20191028
# 29998   2019-10-28              20191028                20191028
# 29999   2019-10-28              20191024                20191028
#
#       document type  baseline_create_date cust_payment_terms    invoice_id  \
# 20000            RV            20190719.0               NAH4  1.929637e+09
# 20001            RV            20190719.0               NAA8  1.929633e+09
# 20002            RV            20190719.0               NA32  1.929633e+09
# 20003            RV            20190719.0               NAH4  1.929631e+09
# 20004            RV            20190716.0               NAM4  1.929638e+09
# ...             ...                   ...                ...           ...
# 29995            RV            20191028.0               NAA8  1.930056e+09
# 29996            RV            20191028.0               NAA8  1.930057e+09
# 29997            RV            20191028.0               NAA8  1.930057e+09
# 29998            RV            20191028.0               NAVM  1.930058e+09
# 29999            RV            20191028.0               NAX2  1.930051e+09
#
#        actual_open_amount  business_code_enc
# 20000            60177.67                  1
# 20001            30005.71                  1
# 20002            19314.39                  1
# 20003             1263.67                  1
# 20004              437.22                  1
# ...                   ...                ...
# 29995           136435.26                  1
# 29996            66001.28                  1
# 29997            75379.62                  1
# 29998            97461.70                  1
# 29999             4217.86                  1
#
# [10000 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(X_train['document type'])
X_train['document_type_enc'] = enc.transform(X_train['document type'])

# %%
X_train[['document_type_enc','document type']]
# Out:
#        document_type_enc document type
# 0                      0            RV
# 1                      0            RV
# 2                      0            RV
# 3                      0            RV
# 4                      0            RV
# ...                  ...           ...
# 19995                  0            RV
# 19996                  0            RV
# 19997                  0            RV
# 19998                  0            RV
# 19999                  0            RV
#
# [20000 rows x 2 columns]

# %%
X_val['document_type_enc'] = enc.transform(X_val['document type'])
X_val[['document_type_enc','document type']]
# Out:
#        document_type_enc document type
# 20000                  0            RV
# 20001                  0            RV
# 20002                  0            RV
# 20003                  0            RV
# 20004                  0            RV
# ...                  ...           ...
# 29995                  0            RV
# 29996                  0            RV
# 29997                  0            RV
# 29998                  0            RV
# 29999                  0            RV
#
# [10000 rows x 2 columns]

# %%
X_test['document_type_enc'] = enc.transform(X_test['document type'])
X_test[['document_type_enc','document type']]
# Out:
#        document_type_enc document type
# 30000                  0            RV
# 30001                  0            RV
# 30002                  0            RV
# 30003                  0            RV
# 30004                  0            RV
# ...                  ...           ...
# 39995                  0            RV
# 39996                  0            RV
# 39997                  0            RV
# 39998                  0            RV
# 39999                  0            RV
#
# [10000 rows x 2 columns]

# %%
X_train.drop(['document type','business_code','cust_number','name_customer','cust_payment_terms'],axis=1,inplace = True)
X_test.drop(['document type','business_code','cust_number','name_customer','cust_payment_terms'],axis=1,inplace = True)
X_val.drop(['document type','business_code','cust_number','name_customer','cust_payment_terms'],axis=1,inplace = True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   doc_id                  20000 non-null  float64
#  1   posting_date            20000 non-null  datetime64[ns]
#  2   document_create_date    20000 non-null  int64
#  3   document_create_date.1  20000 non-null  int64
#  4   baseline_create_date    20000 non-null  float64
#  5   invoice_id              20000 non-null  float64
#  6   actual_open_amount      20000 non-null  float64
#  7   business_code_enc       20000 non-null  int32
#  8   document_type_enc       20000 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2)
# memory usage: 1.4 MB

# %%
X_train.nunique()
# Out:
# doc_id                    19575
# posting_date                202
# document_create_date        204
# document_create_date.1      203
# baseline_create_date        212
# invoice_id                19575
# actual_open_amount        18131
# business_code_enc             5
# document_type_enc             2
# dtype: int64

# %%
X_train['business_days'] = pd.DatetimeIndex(X_train['posting_date']).day
X_train['business_month'] = pd. DatetimeIndex(X_train['posting_date']).month
X_train
# Out:
#              doc_id posting_date  document_create_date  \
# 0      1.928539e+09   2018-12-30              20181229
# 1      1.928540e+09   2018-12-30              20181229
# 2      1.928545e+09   2018-12-30              20181231
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928540e+09   2018-12-30              20181229
# ...             ...          ...                   ...
# 19995  1.929626e+09   2019-07-19              20190717
# 19996  2.960566e+09   2019-07-19              20190719
# 19997  1.929635e+09   2019-07-19              20190718
# 19998  1.929636e+09   2019-07-19              20190718
# 19999  1.929637e+09   2019-07-19              20190719
#
#        document_create_date.1  baseline_create_date    invoice_id  \
# 0                    20181230            20181230.0  1.928539e+09
# 1                    20181230            20181230.0  1.928540e+09
# 2                    20181230            20181230.0  1.928545e+09
# 3                    20181230            20181230.0  1.928540e+09
# 4                    20181230            20181230.0  1.928540e+09
# ...                       ...                   ...           ...
# 19995                20190719            20190719.0  1.929626e+09
# 19996                20190719            20190719.0  2.960566e+09
# 19997                20190719            20190719.0  1.929635e+09
# 19998                20190719            20190719.0  1.929636e+09
# 19999                20190719            20190719.0  1.929637e+09
#
#        actual_open_amount  business_code_enc  document_type_enc  \
# 0                   53.25                  1                  0
# 1               169989.59                  1                  0
# 2                69249.78                  1                  0
# 3                33241.74                  1                  0
# 4                17567.05                  1                  0
# ...                   ...                ...                ...
# 19995            15358.44                  1                  0
# 19996            74836.52                  0                  0
# 19997               64.74                  1                  0
# 19998            49514.59                  1                  0
# 19999             9312.00                  1                  0
#
#        business_days  business_month
# 0                 30              12
# 1                 30              12
# 2                 30              12
# 3                 30              12
# 4                 30              12
# ...              ...             ...
# 19995             19               7
# 19996             19               7
# 19997             19               7
# 19998             19               7
# 19999             19               7
#
# [20000 rows x 11 columns]

# %%
X_val['business_days'] = pd.DatetimeIndex(X_val['posting_date']).day
X_val['business_month'] = pd. DatetimeIndex(X_val['posting_date']).month
X_val
# Out:
#              doc_id posting_date  document_create_date  \
# 20000  1.929637e+09   2019-07-19              20190719
# 20001  1.929633e+09   2019-07-19              20190718
# 20002  1.929633e+09   2019-07-19              20190718
# 20003  1.929631e+09   2019-07-19              20190717
# 20004  1.929638e+09   2019-07-19              20190719
# ...             ...          ...                   ...
# 29995  1.930056e+09   2019-10-28              20191027
# 29996  1.930057e+09   2019-10-28              20191027
# 29997  1.930057e+09   2019-10-28              20191028
# 29998  1.930058e+09   2019-10-28              20191028
# 29999  1.930051e+09   2019-10-28              20191024
#
#        document_create_date.1  baseline_create_date    invoice_id  \
# 20000                20190719            20190719.0  1.929637e+09
# 20001                20190719            20190719.0  1.929633e+09
# 20002                20190719            20190719.0  1.929633e+09
# 20003                20190719            20190719.0  1.929631e+09
# 20004                20190719            20190716.0  1.929638e+09
# ...                       ...                   ...           ...
# 29995                20191028            20191028.0  1.930056e+09
# 29996                20191028            20191028.0  1.930057e+09
# 29997                20191028            20191028.0  1.930057e+09
# 29998                20191028            20191028.0  1.930058e+09
# 29999                20191028            20191028.0  1.930051e+09
#
#        actual_open_amount  business_code_enc  document_type_enc  \
# 20000            60177.67                  1                  0
# 20001            30005.71                  1                  0
# 20002            19314.39                  1                  0
# 20003             1263.67                  1                  0
# 20004              437.22                  1                  0
# ...                   ...                ...                ...
# 29995           136435.26                  1                  0
# 29996            66001.28                  1                  0
# 29997            75379.62                  1                  0
# 29998            97461.70                  1                  0
# 29999             4217.86                  1                  0
#
#        business_days  business_month
# 20000             19               7
# 20001             19               7
# 20002             19               7
# 20003             19               7
# 20004             19               7
# ...              ...             ...
# 29995             28              10
# 29996             28              10
# 29997             28              10
# 29998             28              10
# 29999             28              10
#
# [10000 rows x 11 columns]

# %%
X_test['business_days'] = pd.DatetimeIndex(X_test['posting_date']).day
X_test['business_month'] = pd. DatetimeIndex(X_test['posting_date']).month
X_test
# Out:
#              doc_id posting_date  document_create_date  \
# 30000  2.960587e+09   2019-10-28              20191028
# 30001  1.930054e+09   2019-10-28              20191025
# 30002  1.930057e+09   2019-10-28              20191027
# 30003  1.930055e+09   2019-10-28              20191027
# 30004  1.930057e+09   2019-10-28              20191027
# ...             ...          ...                   ...
# 39995  1.930579e+09   2020-02-27              20200227
# 39996  2.960617e+09   2020-02-27              20200227
# 39997  1.930568e+09   2020-02-27              20200225
# 39998  1.930558e+09   2020-02-27              20200222
# 39999  1.930574e+09   2020-02-27              20200226
#
#        document_create_date.1  baseline_create_date    invoice_id  \
# 30000                20191028            20191105.0  2.960587e+09
# 30001                20191028            20191028.0  1.930054e+09
# 30002                20191028            20191028.0  1.930057e+09
# 30003                20191028            20191028.0  1.930055e+09
# 30004                20191028            20191028.0  1.930057e+09
# ...                       ...                   ...           ...
# 39995                20200227            20200227.0  1.930579e+09
# 39996                20200227            20200229.0  2.960617e+09
# 39997                20200227            20200227.0  1.930568e+09
# 39998                20200227            20200227.0  1.930558e+09
# 39999                20200227            20200227.0  1.930574e+09
#
#        actual_open_amount  business_code_enc  document_type_enc  \
# 30000            5351.904                  0                  0
# 30001            2304.000                  1                  0
# 30002            9286.730                  1                  0
# 30003           62251.360                  1                  0
# 30004            2474.290                  1                  0
# ...                   ...                ...                ...
# 39995          101667.640                  1                  0
# 39996            4383.040                  0                  0
# 39997           10349.360                  1                  0
# 39998           53264.580                  1                  0
# 39999           10990.810                  1                  0
#
#        business_days  business_month
# 30000             28              10
# 30001             28              10
# 30002             28              10
# 30003             28              10
# 30004             28              10
# ...              ...             ...
# 39995             27               2
# 39996             27               2
# 39997             27               2
# 39998             27               2
# 39999             27               2
#
# [10000 rows x 11 columns]

# %%
X_train.drop(['posting_date'],axis=1,inplace = True)
X_test.drop(['posting_date'],axis=1,inplace = True)
X_val.drop(['posting_date'],axis=1,inplace = True)

# %%
X_train
# Out:
#              doc_id  document_create_date  document_create_date.1  \
# 0      1.928539e+09              20181229                20181230
# 1      1.928540e+09              20181229                20181230
# 2      1.928545e+09              20181231                20181230
# 3      1.928540e+09              20181229                20181230
# 4      1.928540e+09              20181229                20181230
# ...             ...                   ...                     ...
# 19995  1.929626e+09              20190717                20190719
# 19996  2.960566e+09              20190719                20190719
# 19997  1.929635e+09              20190718                20190719
# 19998  1.929636e+09              20190718                20190719
# 19999  1.929637e+09              20190719                20190719
#
#        baseline_create_date    invoice_id  actual_open_amount  \
# 0                20181230.0  1.928539e+09               53.25
# 1                20181230.0  1.928540e+09           169989.59
# 2                20181230.0  1.928545e+09            69249.78
# 3                20181230.0  1.928540e+09            33241.74
# 4                20181230.0  1.928540e+09            17567.05
# ...                     ...           ...                 ...
# 19995            20190719.0  1.929626e+09            15358.44
# 19996            20190719.0  2.960566e+09            74836.52
# 19997            20190719.0  1.929635e+09               64.74
# 19998            20190719.0  1.929636e+09            49514.59
# 19999            20190719.0  1.929637e+09             9312.00
#
#        business_code_enc  document_type_enc  business_days  business_month
# 0                      1                  0             30              12
# 1                      1                  0             30              12
# 2                      1                  0             30              12
# 3                      1                  0             30              12
# 4                      1                  0             30              12
# ...                  ...                ...            ...             ...
# 19995                  1                  0             19               7
# 19996                  0                  0             19               7
# 19997                  1                  0             19               7
# 19998                  1                  0             19               7
# 19999                  1                  0             19               7
#
# [20000 rows x 10 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   doc_id                  20000 non-null  float64
#  1   document_create_date    20000 non-null  int64
#  2   document_create_date.1  20000 non-null  int64
#  3   baseline_create_date    20000 non-null  float64
#  4   invoice_id              20000 non-null  float64
#  5   actual_open_amount      20000 non-null  float64
#  6   business_code_enc       20000 non-null  int32
#  7   document_type_enc       20000 non-null  int32
#  8   business_days           20000 non-null  int64
#  9   business_month          20000 non-null  int64
# dtypes: float64(4), int32(2), int64(4)
# memory usage: 1.5 MB

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,10))

sns.heatmap(X_train.merge(y_train , on = X_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:>

# %%
X_train.drop(['doc_id','document_create_date.1','invoice_id','baseline_create_date','business_code_enc','document_type_enc'],axis=1,inplace = True)
X_test.drop(['doc_id','document_create_date.1','invoice_id','baseline_create_date','business_code_enc','document_type_enc'],axis=1,inplace = True)
X_val.drop(['doc_id','document_create_date.1','invoice_id','baseline_create_date','business_code_enc','document_type_enc'],axis=1,inplace = True)

# %%
X_train
# Out:
#        document_create_date  actual_open_amount  business_days  business_month
# 0                  20181229               53.25             30              12
# 1                  20181229           169989.59             30              12
# 2                  20181231            69249.78             30              12
# 3                  20181229            33241.74             30              12
# 4                  20181229            17567.05             30              12
# ...                     ...                 ...            ...             ...
# 19995              20190717            15358.44             19               7
# 19996              20190719            74836.52             19               7
# 19997              20190718               64.74             19               7
# 19998              20190718            49514.59             19               7
# 19999              20190719             9312.00             19               7
#
# [20000 rows x 4 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   document_create_date  20000 non-null  int64
#  1   actual_open_amount    20000 non-null  float64
#  2   business_days         20000 non-null  int64
#  3   business_month        20000 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 781.2 KB

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,10))

sns.heatmap(X_train.merge(y_train , on = X_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
base_model = LinearRegression()
base_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr_predict = base_model.predict(X_val)
lr_predict
# Out:
# array([0.91553336, 1.01817975, 1.05451327, ..., 0.48066401, 0.40561999,
#        0.72293952])

# %%
y_val
# Out:
# 20000    -3
# 20001     2
# 20002     1
# 20003    -4
# 20004    -7
#          ..
# 29995    -5
# 29996     0
# 29997     0
# 29998   -79
# 29999    30
# Name: delay_days, Length: 10000, dtype: int16

# %%
pd.DataFrame(zip(lr_predict, y_val),columns=['Predicted','Actuals'])
# Out:
#       Predicted  Actuals
# 0      0.915533       -3
# 1      1.018180        2
# 2      1.054513        1
# 3      1.115967       -4
# 4      1.118556       -7
# ...         ...      ...
# 9995   0.273281       -5
# 9996   0.512645        0
# 9997   0.480664        0
# 9998   0.405620      -79
# 9999   0.722940       30
#
# [10000 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error as mse 
mse(y_val,lr_predict,squared=False)
# Out:
# 9.734680388598255

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_val,lr_predict)
# Out:
# 4.56380439034514

# %%
lr_predict2= base_model.predict(X_test)

# %%
mae(y_test,lr_predict2)
# Out:
# 4.120588555251301

# %%
pd.DataFrame(zip(y_val , y_test),columns=['Predicted','Actuals'])
# Out:
#       Predicted  Actuals
# 0            -3       12
# 1             2        0
# 2             1       -4
# 3            -4        1
# 4            -7        0
# ...         ...      ...
# 9995         -5        4
# 9996          0        2
# 9997          0        6
# 9998        -79        5
# 9999         30       -1
#
# [10000 rows x 2 columns]

# %%
lr_accuracy = base_model.score(X_test,y_test)

# %%
print(lr_accuracy * 100)
# Out:
# 2.149848720878844

# %%
from sklearn.svm import SVR

# %%
svr_model = SVR(kernel = 'rbf')

# %%
svr_model.fit(X_train,y_train)

# %%
svr_predict1 = svr_model.predict(X_val)
svr_predict1

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_val , svr_predict1,squared = False)

# %%
svr_accuracy = svr_model.score(X_test,y_test)

# %%
print(svr_accuracy *100)

# %%
from sklearn.tree import DecisionTreeRegressor
tree_model = DecisionTreeRegressor(max_depth=6)
tree_model.fit(X_train,y_train)

# %%
tr_predict = tree_model.predict(X_val)
tr_predict

# %%
mse(y_val,tr_predict,squared=False)

# %%
from sklearn.metrics import mean_squared_error as mse
mse(y_test,tr_predict,squared=False)

# %%
tr_predict1 = tree_model.predict(X_test)

# %%
mse(y_test,tr_predict1,squared=False)

# %%
tr_accuracy = tree_model.score(X_test,y_test)

# %%
print(tr_accuracy * 100)
# Out:
# -84.72779869507492

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr_model = RandomForestRegressor(n_estimators = 100 , random_state = 0)

# %%
rfr_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
rfr_predict1 = rfr_model.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error as mse
mse(y_val,rfr_predict1,squared =False)
# Out:
# 10.079168146892547

# %%
rfr_predict2 = rfr_model.predict(X_test)
mse(y_test,rfr_predict2,squared = False)
# Out:
# 13.441438244597684

# %%
rfr_accuracy = rfr_model.score(X_test,y_test)

# %%
print(rfr_accuracy * 100)
# Out:
# -58.47043946025477

# %%
Algn = ['Linear Regression','SVR','Decision Tree Regression','Random Forest Regressor','XGB Regresson']

# %%
mse = [mse(y_test,lr_predict2,squared = False),mse(y_test,svr_predict1, squared=False),
       mse(y_test,tr_predict1,squared=False),mse(y_test, rfr_predict2, squared=False),]

# %%
accuracy = [lr_accuracy,svr_accuracy,tr_accuracy,rfr_accuracy]

# %%
models = pd.DataFrame(list(zip(Algn,mse,accuracy)))

# %%
models
# Out:
#                           0          1         2
# 0         Linear Regression  10.536171  0.026306
# 1                       SVR  10.725951  0.022260
# 2  Decision Tree Regression  14.512350 -0.847278
# 3   Random Forest Regressor  13.441438 -0.584704

# %%
model = pd.DataFrame(list(zip(Algn,mse,accuracy)))
Frame=pd.DataFrame(models.values, columns = ["Algn", "mse", "accuracy"])
Frame
# Out:
#                        Algn        mse  accuracy
# 0         Linear Regression  10.536171  0.026306
# 1                       SVR  10.725951   0.02226
# 2  Decision Tree Regression   14.51235 -0.847278
# 3   Random Forest Regressor  13.441438 -0.584704

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28000 entries, 0 to 27999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   doc_id                28000 non-null  float64
#  1   document_create_date  28000 non-null  int64
#  2   actual_open_amount    28000 non-null  float64
#  3   business_code_enc     28000 non-null  int32
#  4   document_type_enc     28000 non-null  int32
#  5   business_days         28000 non-null  int64
#  6   business_month        28000 non-null  int64
# dtypes: float64(2), int32(2), int64(3)
# memory usage: 1.5 MB

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 3 to 49995
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           10000 non-null  object
#  1   cust_number             10000 non-null  object
#  2   name_customer           10000 non-null  object
#  3   clear_date              0 non-null      object
#  4   buisness_year           10000 non-null  float64
#  5   doc_id                  10000 non-null  float64
#  6   posting_date            10000 non-null  object
#  7   document_create_date    10000 non-null  int64
#  8   document_create_date.1  10000 non-null  int64
#  9   due_in_date             10000 non-null  float64
#  10  invoice_currency        10000 non-null  object
#  11  document type           10000 non-null  object
#  12  total_open_amount       10000 non-null  float64
#  13  baseline_create_date    10000 non-null  float64
#  14  cust_payment_terms      10000 non-null  object
#  15  invoice_id              10000 non-null  float64
#  16  isOpen                  10000 non-null  int64
# dtypes: float64(6), int64(3), object(8)
# memory usage: 1.4+ MB

# %%
newdata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           0 non-null      object
#  1   cust_number             0 non-null      object
#  2   name_customer           0 non-null      object
#  3   clear_date              0 non-null      datetime64[ns]
#  4   buisness_year           0 non-null      float64
#  5   doc_id                  0 non-null      float64
#  6   posting_date            0 non-null      datetime64[ns]
#  7   document_create_date    0 non-null      int64
#  8   document_create_date.1  0 non-null      int64
#  9   due_in_date             0 non-null      datetime64[ns]
#  10  document type           0 non-null      object
#  11  total_open_amount       0 non-null      float64
#  12  baseline_create_date    0 non-null      float64
#  13  cust_payment_terms      0 non-null      object
#  14  invoice_id              0 non-null      float64
#  15  actual_open_amount      0 non-null      float64
#  16  delay_days              0 non-null      int16
# dtypes: datetime64[ns](3), float64(6), int16(1), int64(2), object(5)
# memory usage: 0.0+ bytes

# %%
newdata.nunique()
# Out:
# business_code                6
# cust_number                694
# name_customer             1766
# clear_date                   0
# buisness_year                1
# doc_id                    9681
# posting_date                83
# document_create_date        91
# document_create_date.1      83
# due_in_date                124
# invoice_currency             2
# document type                1
# total_open_amount         9079
# baseline_create_date        83
# cust_payment_terms          43
# invoice_id                9681
# isOpen                       1
# dtype: int64

# %%
newdata.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    0
# isOpen                        0
# dtype: int64

# %%
newdata.drop(['clear_date'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 0              U001  0200769623            WAL-MAR          2019.0
# 1              U001  0200794332             COST us         2019.0
# 2              U001  0200769623     WAL-MAR systems         2019.0
# 3              U001  0200726979    BJ'S  foundation         2019.0
# 4              U001  0200707822            PUBLI us         2019.0
# ...             ...         ...                 ...            ...
# 39995          U001      CCCA02  KRAFT  corporation         2020.0
# 39996          U001  0200726979          BJ'S  corp         2020.0
# 39997          U001  0200759878             SA corp         2020.0
# 39998          U001  0200739044  PERFOR corporation         2020.0
# 39999          U001  0200418007       AM associates         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928542e+09   2018-12-30              20181229
# 1      1.928535e+09   2018-12-30              20181229
# 2      1.928543e+09   2018-12-30              20181230
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 39995  1.930565e+09   2020-02-26              20200224
# 39996  1.930569e+09   2020-02-26              20200225
# 39997  1.930574e+09   2020-02-27              20200226
# 39998  1.930574e+09   2020-02-27              20200226
# 39999  1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1 document type  baseline_create_date  \
# 0                    20181230            RV            20181230.0
# 1                    20181230            RV            20181230.0
# 2                    20181230            RV            20181230.0
# 3                    20181230            RV            20181230.0
# 4                    20181230            RV            20181230.0
# ...                       ...           ...                   ...
# 39995                20200226            RV            20200226.0
# 39996                20200226            RV            20200226.0
# 39997                20200227            RV            20200227.0
# 39998                20200227            RV            20200227.0
# 39999                20200227            RV            20200227.0
#
#       cust_payment_terms    invoice_id  actual_open_amount  delay_days
# 0                   NAH4  1.928542e+09            12491.86           1
# 1                   NAAX  1.928535e+09            51473.49           1
# 2                   NAH4  1.928543e+09            41840.55          -4
# 3                   NAA8  1.928540e+09               58.18           1
# 4                   NAA8  1.928545e+09           110990.78           0
# ...                  ...           ...                 ...         ...
# 39995               NAG2  1.930565e+09            30576.00          -5
# 39996               NAA8  1.930569e+09              553.46           0
# 39997               NAH4  1.930574e+09            49290.19           0
# 39998               NAA8  1.930574e+09            25143.02           3
# 39999               NAA8  1.930568e+09            10349.36           6
#
# [40000 rows x 14 columns]

# %%
newdata.drop(['baseline_create_date','name_customer','isOpen','document_create_date.1','buisness_year',
             'cust_number','cust_payment_terms','invoice_id'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 0              U001  0200769623            WAL-MAR          2019.0
# 1              U001  0200794332             COST us         2019.0
# 2              U001  0200769623     WAL-MAR systems         2019.0
# 3              U001  0200726979    BJ'S  foundation         2019.0
# 4              U001  0200707822            PUBLI us         2019.0
# ...             ...         ...                 ...            ...
# 39995          U001      CCCA02  KRAFT  corporation         2020.0
# 39996          U001  0200726979          BJ'S  corp         2020.0
# 39997          U001  0200759878             SA corp         2020.0
# 39998          U001  0200739044  PERFOR corporation         2020.0
# 39999          U001  0200418007       AM associates         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928542e+09   2018-12-30              20181229
# 1      1.928535e+09   2018-12-30              20181229
# 2      1.928543e+09   2018-12-30              20181230
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 39995  1.930565e+09   2020-02-26              20200224
# 39996  1.930569e+09   2020-02-26              20200225
# 39997  1.930574e+09   2020-02-27              20200226
# 39998  1.930574e+09   2020-02-27              20200226
# 39999  1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1 document type  baseline_create_date  \
# 0                    20181230            RV            20181230.0
# 1                    20181230            RV            20181230.0
# 2                    20181230            RV            20181230.0
# 3                    20181230            RV            20181230.0
# 4                    20181230            RV            20181230.0
# ...                       ...           ...                   ...
# 39995                20200226            RV            20200226.0
# 39996                20200226            RV            20200226.0
# 39997                20200227            RV            20200227.0
# 39998                20200227            RV            20200227.0
# 39999                20200227            RV            20200227.0
#
#       cust_payment_terms    invoice_id  actual_open_amount  delay_days
# 0                   NAH4  1.928542e+09            12491.86           1
# 1                   NAAX  1.928535e+09            51473.49           1
# 2                   NAH4  1.928543e+09            41840.55          -4
# 3                   NAA8  1.928540e+09               58.18           1
# 4                   NAA8  1.928545e+09           110990.78           0
# ...                  ...           ...                 ...         ...
# 39995               NAG2  1.930565e+09            30576.00          -5
# 39996               NAA8  1.930569e+09              553.46           0
# 39997               NAH4  1.930574e+09            49290.19           0
# 39998               NAA8  1.930574e+09            25143.02           3
# 39999               NAA8  1.930568e+09            10349.36           6
#
# [40000 rows x 14 columns]

# %%
newdata.nunique()
# Out:
# business_code              6
# doc_id                  9681
# posting_date              83
# document_create_date      91
# due_in_date              124
# invoice_currency           2
# document type              1
# total_open_amount       9079
# dtype: int64

# %%
newdata['actual_open_amount'] = newdata['total_open_amount'].where(newdata['invoice_currency']=='USD', 
                                                             newdata['total_open_amount'] * 0.8)

# %%
newdata
# Out:
#       business_code        doc_id posting_date  document_create_date  \
# 3              CA02  2.960623e+09   2020-03-30              20200330
# 7              U001  1.930659e+09   2020-03-19              20200318
# 10             U001  1.930611e+09   2020-03-11              20200306
# 14             U001  1.930788e+09   2020-04-15              20200415
# 15             U001  1.930817e+09   2020-04-23              20200423
# ...             ...           ...          ...                   ...
# 49975          U001  1.930625e+09   2020-03-10              20200309
# 49980          U001  1.930851e+09   2020-05-03              20200502
# 49982          U001  1.930638e+09   2020-03-11              20200311
# 49992          U001  1.930702e+09   2020-03-25              20200325
# 49995          U001  1.930797e+09   2020-04-21              20200417
#
#        due_in_date invoice_currency document type  total_open_amount  \
# 3       20200410.0              CAD            RV            3299.70
# 7       20200403.0              USD            RV           11173.02
# 10      20200326.0              USD            RV            3525.59
# 14      20200430.0              USD            RV          121105.65
# 15      20200426.0              USD            RV            3726.06
# ...            ...              ...           ...                ...
# 49975   20200325.0              USD            RV           13114.99
# 49980   20200518.0              USD            RV            8899.71
# 49982   20200326.0              USD            RV            4967.06
# 49992   20200409.0              USD            RV            1998.64
# 49995   20200506.0              USD            RV            3187.86
#
#        actual_open_amount
# 3                 2639.76
# 7                11173.02
# 10                3525.59
# 14              121105.65
# 15                3726.06
# ...                   ...
# 49975            13114.99
# 49980             8899.71
# 49982             4967.06
# 49992             1998.64
# 49995             3187.86
#
# [10000 rows x 9 columns]

# %%
newdata.drop(['invoice_currency','total_open_amount'],axis =1,inplace = True)
newdata
# Out:
#       business_code        doc_id posting_date  document_create_date  \
# 3              CA02  2.960623e+09   2020-03-30              20200330
# 7              U001  1.930659e+09   2020-03-19              20200318
# 10             U001  1.930611e+09   2020-03-11              20200306
# 14             U001  1.930788e+09   2020-04-15              20200415
# 15             U001  1.930817e+09   2020-04-23              20200423
# ...             ...           ...          ...                   ...
# 49975          U001  1.930625e+09   2020-03-10              20200309
# 49980          U001  1.930851e+09   2020-05-03              20200502
# 49982          U001  1.930638e+09   2020-03-11              20200311
# 49992          U001  1.930702e+09   2020-03-25              20200325
# 49995          U001  1.930797e+09   2020-04-21              20200417
#
#        due_in_date document type  actual_open_amount
# 3       20200410.0            RV             2639.76
# 7       20200403.0            RV            11173.02
# 10      20200326.0            RV             3525.59
# 14      20200430.0            RV           121105.65
# 15      20200426.0            RV             3726.06
# ...            ...           ...                 ...
# 49975   20200325.0            RV            13114.99
# 49980   20200518.0            RV             8899.71
# 49982   20200326.0            RV             4967.06
# 49992   20200409.0            RV             1998.64
# 49995   20200506.0            RV             3187.86
#
# [10000 rows x 7 columns]

# %%
newdata['posting_date']=pd.to_datetime(data['posting_date']).dt.normalize()
newdata
# Out:
#       business_code        doc_id posting_date  document_create_date  \
# 3              CA02  2.960623e+09   2018-12-30              20200330
# 7              U001  1.930659e+09   2018-12-30              20200318
# 10             U001  1.930611e+09   2018-12-30              20200306
# 14             U001  1.930788e+09   2018-12-30              20200415
# 15             U001  1.930817e+09   2018-12-30              20200423
# ...             ...           ...          ...                   ...
# 49975          U001  1.930625e+09          NaT              20200309
# 49980          U001  1.930851e+09          NaT              20200502
# 49982          U001  1.930638e+09          NaT              20200311
# 49992          U001  1.930702e+09          NaT              20200325
# 49995          U001  1.930797e+09          NaT              20200417
#
#        due_in_date document type  actual_open_amount
# 3       20200410.0            RV             2639.76
# 7       20200403.0            RV            11173.02
# 10      20200326.0            RV             3525.59
# 14      20200430.0            RV           121105.65
# 15      20200426.0            RV             3726.06
# ...            ...           ...                 ...
# 49975   20200325.0            RV            13114.99
# 49980   20200518.0            RV             8899.71
# 49982   20200326.0            RV             4967.06
# 49992   20200409.0            RV             1998.64
# 49995   20200506.0            RV             3187.86
#
# [10000 rows x 7 columns]

# %%
newdata['business_days'] = pd.DatetimeIndex(newdata['posting_date']).day
newdata['business_month'] = pd. DatetimeIndex(newdata['posting_date']).month

# %%
newdata.drop(['posting_date'],axis=1,inplace = True)

# %%
newdata['due_in_date']=pd.to_datetime(newdata['due_in_date'],format='%Y%m%d')
data_temp = pd.DataFrame(newdata['due_in_date'])

# %%
newdata.drop(['due_in_date'],axis=1,inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
business_code_enc = LabelEncoder()
business_code_enc.fit(newdata['business_code'])
newdata['business_code_enc'] = business_code_enc.transform(newdata['business_code'])

# %%
newdata.drop(['business_code'],axis=1,inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(newdata['document type'])
newdata['document_type_enc'] = enc.transform(newdata['document type'])

# %%
newdata.drop(['document type'],axis=1,inplace = True)

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 3 to 49995
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   doc_id                10000 non-null  float64
#  1   document_create_date  10000 non-null  int64
#  2   actual_open_amount    10000 non-null  float64
#  3   business_days         7948 non-null   float64
#  4   business_month        7948 non-null   float64
#  5   business_code_enc     10000 non-null  int32
#  6   document_type_enc     10000 non-null  int32
# dtypes: float64(4), int32(2), int64(1)
# memory usage: 546.9 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28000 entries, 0 to 27999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   doc_id                28000 non-null  float64
#  1   document_create_date  28000 non-null  int64
#  2   actual_open_amount    28000 non-null  float64
#  3   business_code_enc     28000 non-null  int32
#  4   document_type_enc     28000 non-null  int32
#  5   business_days         28000 non-null  int64
#  6   business_month        28000 non-null  int64
# dtypes: float64(2), int32(2), int64(3)
# memory usage: 1.5 MB

# %%
newdata.isnull().sum()
# Out:
# doc_id                     0
# document_create_date       0
# actual_open_amount         0
# business_days           2052
# business_month          2052
# business_code_enc          0
# document_type_enc          0
# dtype: int64

# %%
newdata1.isnull().sum()
# Out:
# business_code             0.0
# cust_number               0.0
# name_customer             0.0
# clear_date                0.0
# buisness_year             0.0
# doc_id                    0.0
# posting_date              0.0
# document_create_date      0.0
# document_create_date.1    0.0
# due_in_date               0.0
# document type             0.0
# total_open_amount         0.0
# baseline_create_date      0.0
# cust_payment_terms        0.0
# invoice_id                0.0
# actual_open_amount        0.0
# delay_days                0.0
# dtype: float64

# %%
newdata.dropna(inplace=True)
newdata
# Out:
#              doc_id  document_create_date  actual_open_amount  business_days  \
# 3      2.960623e+09              20200330             2639.76           30.0
# 7      1.930659e+09              20200318            11173.02           30.0
# 10     1.930611e+09              20200306             3525.59           30.0
# 14     1.930788e+09              20200415           121105.65           30.0
# 15     1.930817e+09              20200423             3726.06           30.0
# ...             ...                   ...                 ...            ...
# 39986  1.930760e+09              20200408            20445.58           26.0
# 39987  1.930735e+09              20200402            33117.10           26.0
# 39994  1.930709e+09              20200326            14209.44           26.0
# 39995  1.930704e+09              20200325            39880.93           26.0
# 39998  1.930854e+09              20200503            55955.55           27.0
#
#        business_month  business_code_enc  document_type_enc
# 3                12.0                  0                  0
# 7                12.0                  1                  0
# 10               12.0                  1                  0
# 14               12.0                  1                  0
# 15               12.0                  1                  0
# ...               ...                ...                ...
# 39986             2.0                  1                  0
# 39987             2.0                  1                  0
# 39994             2.0                  1                  0
# 39995             2.0                  1                  0
# 39998             2.0                  1                  0
#
# [7948 rows x 7 columns]

# %%
predication_result = base_model.predict(newdata)

# %%
predication_result = pd.Series(predication_result,name='delay_days')

# %%
newdata = newdata.merge(predication_result,on=newdata.index)

# %%
newdata.head()
# Out:
#    key_0        doc_id  document_create_date  actual_open_amount  \
# 0      3  2.960623e+09              20200330             2639.76
# 1      7  1.930659e+09              20200318            11173.02
# 2     10  1.930611e+09              20200306             3525.59
# 3     14  1.930788e+09              20200415           121105.65
# 4     15  1.930817e+09              20200423             3726.06
#
#    business_days  business_month  business_code_enc  document_type_enc  \
# 0           30.0            12.0                  0                  0
# 1           30.0            12.0                  1                  0
# 2           30.0            12.0                  1                  0
# 3           30.0            12.0                  1                  0
# 4           30.0            12.0                  1                  0
#
#    delay_days
# 0  183.471984
# 1  174.743097
# 2  174.791235
# 3  174.054870
# 4  174.778465

# %%
result=pd.concat([newdata,data_temp],axis=1,join = "inner")

# %%
result.head()
# Out:
#     key_0        doc_id  document_create_date  actual_open_amount  \
# 3      14  1.930788e+09              20200415           121105.65
# 7      27  1.930592e+09              20200302            11380.83
# 10     45  1.930698e+09              20200325              138.60
# 14     70  2.960625e+09              20200327             2263.68
# 15     76  1.930577e+09              20200227            14514.68
#
#     business_days  business_month  business_code_enc  document_type_enc  \
# 3            30.0            12.0                  1                  0
# 7            30.0            12.0                  1                  0
# 10           30.0            12.0                  1                  0
# 14           31.0            12.0                  0                  0
# 15           31.0            12.0                  1                  0
#
#     delay_days due_in_date
# 3   174.054870  2020-04-10
# 7   174.743064  2020-04-03
# 10  174.810716  2020-03-26
# 14  185.757624  2020-04-30
# 15  177.015079  2020-04-26

# %%
result['payment_date']=pd.to_datetime(result.due_in_date)+pd.to_timedelta(pd.np.ceil(result.delay_days),unit="D")
result.head(20)
# Out:
#     key_0        doc_id  document_create_date  actual_open_amount  \
# 3      14  1.930788e+09              20200415          121105.650
# 7      27  1.930592e+09              20200302           11380.830
# 10     45  1.930698e+09              20200325             138.600
# 14     70  2.960625e+09              20200327            2263.680
# 15     76  1.930577e+09              20200227           14514.680
# 22     95  1.930753e+09              20200406           11394.840
# 25    112  1.930633e+09              20200310           14994.010
# 27    131  1.930752e+09              20200406           25836.190
# 35    197  1.930768e+09              20200409            4537.140
# 37    200  1.930739e+09              20200403             367.710
# 45    258  2.960633e+09              20200506           49406.056
# 51    275  1.930801e+09              20200418           11217.330
# 52    277  1.930777e+09              20200411           12554.130
# 57    312  1.930716e+09              20200330            8299.700
# 70    402  1.930593e+09              20200302           99091.710
# 76    433  1.930831e+09              20200427            8885.570
# 77    440  1.930630e+09              20200310           15893.270
# 79    445  1.930806e+09              20200421          119384.360
# 83    458  1.930862e+09              20200506           81500.860
# 84    468  1.930710e+09              20200327             749.140
#
#     business_days  business_month  business_code_enc  document_type_enc  \
# 3            30.0            12.0                  1                  0
# 7            30.0            12.0                  1                  0
# 10           30.0            12.0                  1                  0
# 14           31.0            12.0                  0                  0
# 15           31.0            12.0                  1                  0
# 22           31.0            12.0                  1                  0
# 25           31.0            12.0                  1                  0
# 27           31.0            12.0                  1                  0
# 35            2.0             1.0                  1                  0
# 37            2.0             1.0                  1                  0
# 45            3.0             1.0                  0                  0
# 51            3.0             1.0                  1                  0
# 52            3.0             1.0                  1                  0
# 57            3.0             1.0                  1                  0
# 70            4.0             1.0                  1                  0
# 76            4.0             1.0                  1                  0
# 77            5.0             1.0                  1                  0
# 79            5.0             1.0                  1                  0
# 83            5.0             1.0                  1                  0
# 84            5.0             1.0                  1                  0
#
#     delay_days due_in_date payment_date
# 3   174.054870  2020-04-10   2020-10-02
# 7   174.743064  2020-04-03   2020-09-25
# 10  174.810716  2020-03-26   2020-09-17
# 14  185.757624  2020-04-30   2020-11-02
# 15  177.015079  2020-04-26   2020-10-21
# 22  177.015499  2020-04-05   2020-09-30
# 25  177.003174  2020-03-16   2020-09-10
# 27  176.926390  2020-03-17   2020-09-10
# 35   11.058360  2020-04-22   2020-05-04
# 37   11.084524  2020-05-08   2020-05-20
# 45   21.730240  2020-04-08   2020-04-30
# 51   13.299372  2020-03-28   2020-04-11
# 52   13.291712  2020-05-24   2020-06-07
# 57   13.326641  2020-03-27   2020-04-10
# 70   15.051542  2020-04-10   2020-04-26
# 76   15.595957  2020-03-14   2020-03-30
# 77   17.847275  2020-04-25   2020-05-13
# 79   17.197600  2020-04-24   2020-05-12
# 83   17.422179  2020-04-14   2020-05-02
# 84   17.939458  2020-04-14   2020-05-02

# %%
result['Aging_Bucket'] =""
result.loc[result['delay_days'].apply(int)>60,'Aging_Bucket']='>60'
result.loc[(result['delay_days'].apply(int)>=46) &(result['delay_days'].apply(int) <= 60),'Aging_Bucket'] = '46-60'
result.loc[(result['delay_days'].apply(int) >= 31) & (result['delay_days'].apply(int) <= 45),'Aging_Bucket'] = '31-45'
result.loc[(result['delay_days'].apply(int) >= 16) & (result['delay_days'].apply(int) <= 30),'Aging_Bucket'] = '16-30'
result.loc[(result['delay_days'].apply(int) >= 1 ) & (result['delay_days'].apply(int) <= 15),'Aging_Bucket'] = '1-15'
result.loc[result['delay_days'].apply(int) <= 0, 'Aging_Bucket'] = 'No delay'

# %%
result
# Out:
#       key_0        doc_id  document_create_date  actual_open_amount  \
# 3        14  1.930788e+09              20200415           121105.65
# 7        27  1.930592e+09              20200302            11380.83
# 10       45  1.930698e+09              20200325              138.60
# 14       70  2.960625e+09              20200327             2263.68
# 15       76  1.930577e+09              20200227            14514.68
# ...     ...           ...                   ...                 ...
# 7928  39932  1.930687e+09              20200323             5602.09
# 7930  39940  1.930603e+09              20200304            21340.41
# 7934  39950  1.930847e+09              20200501            86404.54
# 7937  39961  1.930749e+09              20200404             2156.42
# 7941  39978  1.930660e+09              20200316              235.39
#
#       business_days  business_month  business_code_enc  document_type_enc  \
# 3              30.0            12.0                  1                  0
# 7              30.0            12.0                  1                  0
# 10             30.0            12.0                  1                  0
# 14             31.0            12.0                  0                  0
# 15             31.0            12.0                  1                  0
# ...             ...             ...                ...                ...
# 7928           26.0             2.0                  1                  0
# 7930           26.0             2.0                  1                  0
# 7934           26.0             2.0                  1                  0
# 7937           26.0             2.0                  1                  0
# 7941           26.0             2.0                  1                  0
#
#       delay_days due_in_date payment_date Aging_Bucket
# 3     174.054870  2020-04-10   2020-10-02          >60
# 7     174.743064  2020-04-03   2020-09-25          >60
# 10    174.810716  2020-03-26   2020-09-17          >60
# 14    185.757624  2020-04-30   2020-11-02          >60
# 15    177.015079  2020-04-26   2020-10-21          >60
# ...          ...         ...          ...          ...
# 7928   74.924239  2020-05-16   2020-07-30          >60
# 7930   74.828582  2020-05-26   2020-08-09          >60
# 7934   74.406824  2020-04-10   2020-06-24          >60
# 7937   74.936831  2020-03-21   2020-06-04          >60
# 7941   74.957918  2020-05-21   2020-08-04          >60
#
# [1495 rows x 12 columns]
