# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('dataset.csv')

# %%
data.shape
# Out:
# (50000, 19)

# %%
data.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1          U001  0200980828              BEN E   2019-08-08 00:00:00
# 2          U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3          CA02  0140105686            SYSC llc                  NaN
# 4          U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2020.0  1.930438e+09   2020-01-26              20200125
# 1         2019.0  1.929646e+09   2019-07-22              20190722
# 2         2019.0  1.929874e+09   2019-09-14              20190914
# 3         2020.0  2.960623e+09   2020-03-30              20200330
# 4         2019.0  1.930148e+09   2019-11-13              20191113
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20200126   20200210.0              USD            RV
# 1                20190722   20190811.0              USD            RV
# 2                20190914   20190929.0              USD            RV
# 3                20200330   20200410.0              CAD            RV
# 4                20191113   20191128.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN           54273.28            20200126.0
# 1         1.0            NaN           79656.60            20190722.0
# 2         1.0            NaN            2253.86            20190914.0
# 3         1.0            NaN            3299.70            20200331.0
# 4         1.0            NaN           33133.29            20191113.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAH4  1.930438e+09       0
# 1               NAD1  1.929646e+09       0
# 2               NAA8  1.929874e+09       0
# 3               CA10  2.960623e+09       1
# 4               NAH4  1.930148e+09       0

# %%
data.tail()
# Out:
#       business_code cust_number     name_customer           clear_date  \
# 49995          U001  0200561861    CO corporation                  NaN
# 49996          U001  0200769623        WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595  SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979         BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431          DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 49995         2020.0  1.930797e+09   2020-04-21              20200417
# 49996         2019.0  1.929744e+09   2019-08-15              20190814
# 49997         2020.0  1.930537e+09   2020-02-19              20200218
# 49998         2019.0  1.930199e+09   2019-11-27              20191126
# 49999         2019.0  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 49995                20200421   20200506.0              USD            RV
# 49996                20190815   20190830.0              USD            RV
# 49997                20200219   20200305.0              USD            RV
# 49998                20191127   20191212.0              USD            RV
# 49999                20190105   20190124.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 49995         1.0            NaN            3187.86            20200421.0
# 49996         1.0            NaN            6766.54            20190815.0
# 49997         1.0            NaN            6120.86            20200219.0
# 49998         1.0            NaN              63.48            20191127.0
# 49999         1.0            NaN            1790.30            20190101.0
#
#       cust_payment_terms    invoice_id  isOpen
# 49995               NAA8  1.930797e+09       1
# 49996               NAH4  1.929744e+09       0
# 49997               NAA8  1.930537e+09       0
# 49998               NAA8  1.930199e+09       0
# 49999               NAM4  1.928576e+09       0

# %%
data.columns
# Out:
# Index(['business_code', 'cust_number', 'name_customer', 'clear_date',
#        'buisness_year', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'invoice_currency',
#        'document type', 'posting_id', 'area_business', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'isOpen'],
#       dtype='object')

# %%
data.shape
# Out:
# (50000, 19)

# %%
data.nunique()
# Out:
# business_code                 6
# cust_number                1425
# name_customer              4197
# clear_date                  403
# buisness_year                 2
# doc_id                    48839
# posting_date                506
# document_create_date        507
# document_create_date.1      506
# due_in_date                 547
# invoice_currency              2
# document type                 2
# posting_id                    1
# area_business                 0
# total_open_amount         44349
# baseline_create_date        506
# cust_payment_terms           74
# invoice_id                48833
# isOpen                        2
# dtype: int64

# %%
data.drop(['area_business','posting_id'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1              U001  0200980828              BEN E   2019-08-08 00:00:00
# 2              U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 3              CA02  0140105686            SYSC llc                  NaN
# 4              U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200561861      CO corporation                  NaN
# 49996          U001  0200769623          WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595    SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979           BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431            DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2020.0  1.930438e+09   2020-01-26              20200125
# 1             2019.0  1.929646e+09   2019-07-22              20190722
# 2             2019.0  1.929874e+09   2019-09-14              20190914
# 3             2020.0  2.960623e+09   2020-03-30              20200330
# 4             2019.0  1.930148e+09   2019-11-13              20191113
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930797e+09   2020-04-21              20200417
# 49996         2019.0  1.929744e+09   2019-08-15              20190814
# 49997         2020.0  1.930537e+09   2020-02-19              20200218
# 49998         2019.0  1.930199e+09   2019-11-27              20191126
# 49999         2019.0  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200126   20200210.0              USD            RV
# 1                    20190722   20190811.0              USD            RV
# 2                    20190914   20190929.0              USD            RV
# 3                    20200330   20200410.0              CAD            RV
# 4                    20191113   20191128.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200421   20200506.0              USD            RV
# 49996                20190815   20190830.0              USD            RV
# 49997                20200219   20200305.0              USD            RV
# 49998                20191127   20191212.0              USD            RV
# 49999                20190105   20190124.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               54273.28            20200126.0               NAH4
# 1               79656.60            20190722.0               NAD1
# 2                2253.86            20190914.0               NAA8
# 3                3299.70            20200331.0               CA10
# 4               33133.29            20191113.0               NAH4
# ...                  ...                   ...                ...
# 49995            3187.86            20200421.0               NAA8
# 49996            6766.54            20190815.0               NAH4
# 49997            6120.86            20200219.0               NAA8
# 49998              63.48            20191127.0               NAA8
# 49999            1790.30            20190101.0               NAM4
#
#          invoice_id  isOpen
# 0      1.930438e+09       0
# 1      1.929646e+09       0
# 2      1.929874e+09       0
# 3      2.960623e+09       1
# 4      1.930148e+09       0
# ...             ...     ...
# 49995  1.930797e+09       1
# 49996  1.929744e+09       0
# 49997  1.930537e+09       0
# 49998  1.930199e+09       0
# 49999  1.928576e+09       0
#
# [50000 rows x 17 columns]

# %%
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    6
# isOpen                        0
# dtype: int64

# %%
data.invoice_id.interpolate(inplace=True)

# %%
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    0
# isOpen                        0
# dtype: int64

# %%
newdata = data[data.clear_date.isna()].copy()
newdata
# Out:
#       business_code cust_number        name_customer clear_date  \
# 3              CA02  0140105686             SYSC llc        NaN
# 7              U001  0200744019              TARG us        NaN
# 10             U001  0200418007                  AM         NaN
# 14             U001  0200739534           OK systems        NaN
# 15             U001  0200353024     DECA corporation        NaN
# ...             ...         ...                  ...        ...
# 49975          U001  0200769623           WAL-MAR in        NaN
# 49980          U001  0200769623  WAL-MAR corporation        NaN
# 49982          U001  0200148860             DOLLA co        NaN
# 49992          U001  0200900909             SYSCO co        NaN
# 49995          U001  0200561861       CO corporation        NaN
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 3             2020.0  2.960623e+09   2020-03-30              20200330
# 7             2020.0  1.930659e+09   2020-03-19              20200318
# 10            2020.0  1.930611e+09   2020-03-11              20200306
# 14            2020.0  1.930788e+09   2020-04-15              20200415
# 15            2020.0  1.930817e+09   2020-04-23              20200423
# ...              ...           ...          ...                   ...
# 49975         2020.0  1.930625e+09   2020-03-10              20200309
# 49980         2020.0  1.930851e+09   2020-05-03              20200502
# 49982         2020.0  1.930638e+09   2020-03-11              20200311
# 49992         2020.0  1.930702e+09   2020-03-25              20200325
# 49995         2020.0  1.930797e+09   2020-04-21              20200417
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 3                    20200330   20200410.0              CAD            RV
# 7                    20200319   20200403.0              USD            RV
# 10                   20200311   20200326.0              USD            RV
# 14                   20200415   20200430.0              USD            RV
# 15                   20200423   20200426.0              USD            RV
# ...                       ...          ...              ...           ...
# 49975                20200310   20200325.0              USD            RV
# 49980                20200503   20200518.0              USD            RV
# 49982                20200311   20200326.0              USD            RV
# 49992                20200325   20200409.0              USD            RV
# 49995                20200421   20200506.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 3                3299.70            20200331.0               CA10
# 7               11173.02            20200319.0               NAA8
# 10               3525.59            20200311.0               NAA8
# 14             121105.65            20200415.0               NAA8
# 15               3726.06            20200416.0               NAM2
# ...                  ...                   ...                ...
# 49975           13114.99            20200310.0               NAH4
# 49980            8899.71            20200503.0               NAH4
# 49982            4967.06            20200311.0               NAA8
# 49992            1998.64            20200325.0               NAA8
# 49995            3187.86            20200421.0               NAA8
#
#          invoice_id  isOpen
# 3      2.960623e+09       1
# 7      1.930659e+09       1
# 10     1.930611e+09       1
# 14     1.930788e+09       1
# 15     1.930817e+09       1
# ...             ...     ...
# 49975  1.930625e+09       1
# 49980  1.930851e+09       1
# 49982  1.930638e+09       1
# 49992  1.930702e+09       1
# 49995  1.930797e+09       1
#
# [10000 rows x 17 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1              U001  0200980828              BEN E   2019-08-08 00:00:00
# 2              U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 4              U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# 5              CA02  0140106181    THE  corporation  2019-12-04 00:00:00
# ...             ...         ...                 ...                  ...
# 49994          U001  0200762301        C&S WH trust  2019-07-25 00:00:00
# 49996          U001  0200769623          WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595    SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979           BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431            DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2020.0  1.930438e+09   2020-01-26              20200125
# 1             2019.0  1.929646e+09   2019-07-22              20190722
# 2             2019.0  1.929874e+09   2019-09-14              20190914
# 4             2019.0  1.930148e+09   2019-11-13              20191113
# 5             2019.0  2.960581e+09   2019-09-20              20190920
# ...              ...           ...          ...                   ...
# 49994         2019.0  1.929601e+09   2019-07-10              20190709
# 49996         2019.0  1.929744e+09   2019-08-15              20190814
# 49997         2020.0  1.930537e+09   2020-02-19              20200218
# 49998         2019.0  1.930199e+09   2019-11-27              20191126
# 49999         2019.0  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200126   20200210.0              USD            RV
# 1                    20190722   20190811.0              USD            RV
# 2                    20190914   20190929.0              USD            RV
# 4                    20191113   20191128.0              USD            RV
# 5                    20190920   20191004.0              CAD            RV
# ...                       ...          ...              ...           ...
# 49994                20190710   20190725.0              USD            RV
# 49996                20190815   20190830.0              USD            RV
# 49997                20200219   20200305.0              USD            RV
# 49998                20191127   20191212.0              USD            RV
# 49999                20190105   20190124.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               54273.28            20200126.0               NAH4
# 1               79656.60            20190722.0               NAD1
# 2                2253.86            20190914.0               NAA8
# 4               33133.29            20191113.0               NAH4
# 5               22225.84            20190924.0               CA10
# ...                  ...                   ...                ...
# 49994           84780.40            20190710.0               NAC6
# 49996            6766.54            20190815.0               NAH4
# 49997            6120.86            20200219.0               NAA8
# 49998              63.48            20191127.0               NAA8
# 49999            1790.30            20190101.0               NAM4
#
#          invoice_id  isOpen
# 0      1.930438e+09       0
# 1      1.929646e+09       0
# 2      1.929874e+09       0
# 4      1.930148e+09       0
# 5      2.960581e+09       0
# ...             ...     ...
# 49994  1.929601e+09       0
# 49996  1.929744e+09       0
# 49997  1.930537e+09       0
# 49998  1.930199e+09       0
# 49999  1.928576e+09       0
#
# [40000 rows x 17 columns]

# %%
data.nunique()
# Out:
# business_code                 6
# cust_number                1344
# name_customer              3889
# clear_date                  403
# buisness_year                 2
# doc_id                    39158
# posting_date                424
# document_create_date        427
# document_create_date.1      424
# due_in_date                 491
# invoice_currency              2
# document type                 2
# total_open_amount         35664
# baseline_create_date        431
# cust_payment_terms           70
# invoice_id                39158
# isOpen                        1
# dtype: int64

# %%
data.isnull().sum()
# Out:
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# invoice_id                0
# isOpen                    0
# dtype: int64

# %%
data.drop(['isOpen'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1              U001  0200980828              BEN E   2019-08-08 00:00:00
# 2              U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 4              U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# 5              CA02  0140106181    THE  corporation  2019-12-04 00:00:00
# ...             ...         ...                 ...                  ...
# 49994          U001  0200762301        C&S WH trust  2019-07-25 00:00:00
# 49996          U001  0200769623          WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595    SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979           BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431            DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2020.0  1.930438e+09   2020-01-26              20200125
# 1             2019.0  1.929646e+09   2019-07-22              20190722
# 2             2019.0  1.929874e+09   2019-09-14              20190914
# 4             2019.0  1.930148e+09   2019-11-13              20191113
# 5             2019.0  2.960581e+09   2019-09-20              20190920
# ...              ...           ...          ...                   ...
# 49994         2019.0  1.929601e+09   2019-07-10              20190709
# 49996         2019.0  1.929744e+09   2019-08-15              20190814
# 49997         2020.0  1.930537e+09   2020-02-19              20200218
# 49998         2019.0  1.930199e+09   2019-11-27              20191126
# 49999         2019.0  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200126   20200210.0              USD            RV
# 1                    20190722   20190811.0              USD            RV
# 2                    20190914   20190929.0              USD            RV
# 4                    20191113   20191128.0              USD            RV
# 5                    20190920   20191004.0              CAD            RV
# ...                       ...          ...              ...           ...
# 49994                20190710   20190725.0              USD            RV
# 49996                20190815   20190830.0              USD            RV
# 49997                20200219   20200305.0              USD            RV
# 49998                20191127   20191212.0              USD            RV
# 49999                20190105   20190124.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               54273.28            20200126.0               NAH4
# 1               79656.60            20190722.0               NAD1
# 2                2253.86            20190914.0               NAA8
# 4               33133.29            20191113.0               NAH4
# 5               22225.84            20190924.0               CA10
# ...                  ...                   ...                ...
# 49994           84780.40            20190710.0               NAC6
# 49996            6766.54            20190815.0               NAH4
# 49997            6120.86            20200219.0               NAA8
# 49998              63.48            20191127.0               NAA8
# 49999            1790.30            20190101.0               NAM4
#
#          invoice_id
# 0      1.930438e+09
# 1      1.929646e+09
# 2      1.929874e+09
# 4      1.930148e+09
# 5      2.960581e+09
# ...             ...
# 49994  1.929601e+09
# 49996  1.929744e+09
# 49997  1.930537e+09
# 49998  1.930199e+09
# 49999  1.928576e+09
#
# [40000 rows x 16 columns]

# %%
data.buisness_year .value_counts()
# Out:
# 2019.0    34715
# 2020.0     5285
# Name: buisness_year, dtype: int64

# %%
data['actual_open_amount'] = data['total_open_amount'].where(data['invoice_currency']=='USD', data['total_open_amount'] * 0.79)

# %%
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1              U001  0200980828              BEN E   2019-08-08 00:00:00
# 2              U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 4              U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# 5              CA02  0140106181    THE  corporation  2019-12-04 00:00:00
# ...             ...         ...                 ...                  ...
# 49994          U001  0200762301        C&S WH trust  2019-07-25 00:00:00
# 49996          U001  0200769623          WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595    SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979           BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431            DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2020.0  1.930438e+09   2020-01-26              20200125
# 1             2019.0  1.929646e+09   2019-07-22              20190722
# 2             2019.0  1.929874e+09   2019-09-14              20190914
# 4             2019.0  1.930148e+09   2019-11-13              20191113
# 5             2019.0  2.960581e+09   2019-09-20              20190920
# ...              ...           ...          ...                   ...
# 49994         2019.0  1.929601e+09   2019-07-10              20190709
# 49996         2019.0  1.929744e+09   2019-08-15              20190814
# 49997         2020.0  1.930537e+09   2020-02-19              20200218
# 49998         2019.0  1.930199e+09   2019-11-27              20191126
# 49999         2019.0  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20200126   20200210.0              USD            RV
# 1                    20190722   20190811.0              USD            RV
# 2                    20190914   20190929.0              USD            RV
# 4                    20191113   20191128.0              USD            RV
# 5                    20190920   20191004.0              CAD            RV
# ...                       ...          ...              ...           ...
# 49994                20190710   20190725.0              USD            RV
# 49996                20190815   20190830.0              USD            RV
# 49997                20200219   20200305.0              USD            RV
# 49998                20191127   20191212.0              USD            RV
# 49999                20190105   20190124.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               54273.28            20200126.0               NAH4
# 1               79656.60            20190722.0               NAD1
# 2                2253.86            20190914.0               NAA8
# 4               33133.29            20191113.0               NAH4
# 5               22225.84            20190924.0               CA10
# ...                  ...                   ...                ...
# 49994           84780.40            20190710.0               NAC6
# 49996            6766.54            20190815.0               NAH4
# 49997            6120.86            20200219.0               NAA8
# 49998              63.48            20191127.0               NAA8
# 49999            1790.30            20190101.0               NAM4
#
#          invoice_id  actual_open_amount
# 0      1.930438e+09          54273.2800
# 1      1.929646e+09          79656.6000
# 2      1.929874e+09           2253.8600
# 4      1.930148e+09          33133.2900
# 5      2.960581e+09          17558.4136
# ...             ...                 ...
# 49994  1.929601e+09          84780.4000
# 49996  1.929744e+09           6766.5400
# 49997  1.930537e+09           6120.8600
# 49998  1.930199e+09             63.4800
# 49999  1.928576e+09           1790.3000
#
# [40000 rows x 17 columns]

# %%
data.drop(['invoice_currency'],axis =1,inplace = True)
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2020-02-11 00:00:00
# 1              U001  0200980828              BEN E   2019-08-08 00:00:00
# 2              U001  0200792734          MDV/ trust  2019-12-30 00:00:00
# 4              U001  0200769623  WAL-MAR foundation  2019-11-25 00:00:00
# 5              CA02  0140106181    THE  corporation  2019-12-04 00:00:00
# ...             ...         ...                 ...                  ...
# 49994          U001  0200762301        C&S WH trust  2019-07-25 00:00:00
# 49996          U001  0200769623          WAL-MAR co  2019-09-03 00:00:00
# 49997          U001  0200772595    SAFEW associates  2020-03-05 00:00:00
# 49998          U001  0200726979           BJ'S  llc  2019-12-12 00:00:00
# 49999          U001  0200020431            DEC corp  2019-01-15 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2020.0  1.930438e+09   2020-01-26              20200125
# 1             2019.0  1.929646e+09   2019-07-22              20190722
# 2             2019.0  1.929874e+09   2019-09-14              20190914
# 4             2019.0  1.930148e+09   2019-11-13              20191113
# 5             2019.0  2.960581e+09   2019-09-20              20190920
# ...              ...           ...          ...                   ...
# 49994         2019.0  1.929601e+09   2019-07-10              20190709
# 49996         2019.0  1.929744e+09   2019-08-15              20190814
# 49997         2020.0  1.930537e+09   2020-02-19              20200218
# 49998         2019.0  1.930199e+09   2019-11-27              20191126
# 49999         2019.0  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 0                    20200126   20200210.0            RV           54273.28
# 1                    20190722   20190811.0            RV           79656.60
# 2                    20190914   20190929.0            RV            2253.86
# 4                    20191113   20191128.0            RV           33133.29
# 5                    20190920   20191004.0            RV           22225.84
# ...                       ...          ...           ...                ...
# 49994                20190710   20190725.0            RV           84780.40
# 49996                20190815   20190830.0            RV            6766.54
# 49997                20200219   20200305.0            RV            6120.86
# 49998                20191127   20191212.0            RV              63.48
# 49999                20190105   20190124.0            RV            1790.30
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20200126.0               NAH4  1.930438e+09
# 1                20190722.0               NAD1  1.929646e+09
# 2                20190914.0               NAA8  1.929874e+09
# 4                20191113.0               NAH4  1.930148e+09
# 5                20190924.0               CA10  2.960581e+09
# ...                     ...                ...           ...
# 49994            20190710.0               NAC6  1.929601e+09
# 49996            20190815.0               NAH4  1.929744e+09
# 49997            20200219.0               NAA8  1.930537e+09
# 49998            20191127.0               NAA8  1.930199e+09
# 49999            20190101.0               NAM4  1.928576e+09
#
#        actual_open_amount
# 0              54273.2800
# 1              79656.6000
# 2               2253.8600
# 4              33133.2900
# 5              17558.4136
# ...                   ...
# 49994          84780.4000
# 49996           6766.5400
# 49997           6120.8600
# 49998             63.4800
# 49999           1790.3000
#
# [40000 rows x 16 columns]

# %%
data['clear_date']=pd.to_datetime(data['clear_date']).dt.normalize()
data
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2020-02-11         2020.0
# 1              U001  0200980828              BEN E  2019-08-08         2019.0
# 2              U001  0200792734          MDV/ trust 2019-12-30         2019.0
# 4              U001  0200769623  WAL-MAR foundation 2019-11-25         2019.0
# 5              CA02  0140106181    THE  corporation 2019-12-04         2019.0
# ...             ...         ...                 ...        ...            ...
# 49994          U001  0200762301        C&S WH trust 2019-07-25         2019.0
# 49996          U001  0200769623          WAL-MAR co 2019-09-03         2019.0
# 49997          U001  0200772595    SAFEW associates 2020-03-05         2020.0
# 49998          U001  0200726979           BJ'S  llc 2019-12-12         2019.0
# 49999          U001  0200020431            DEC corp 2019-01-15         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.930438e+09   2020-01-26              20200125
# 1      1.929646e+09   2019-07-22              20190722
# 2      1.929874e+09   2019-09-14              20190914
# 4      1.930148e+09   2019-11-13              20191113
# 5      2.960581e+09   2019-09-20              20190920
# ...             ...          ...                   ...
# 49994  1.929601e+09   2019-07-10              20190709
# 49996  1.929744e+09   2019-08-15              20190814
# 49997  1.930537e+09   2020-02-19              20200218
# 49998  1.930199e+09   2019-11-27              20191126
# 49999  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 0                    20200126   20200210.0            RV           54273.28
# 1                    20190722   20190811.0            RV           79656.60
# 2                    20190914   20190929.0            RV            2253.86
# 4                    20191113   20191128.0            RV           33133.29
# 5                    20190920   20191004.0            RV           22225.84
# ...                       ...          ...           ...                ...
# 49994                20190710   20190725.0            RV           84780.40
# 49996                20190815   20190830.0            RV            6766.54
# 49997                20200219   20200305.0            RV            6120.86
# 49998                20191127   20191212.0            RV              63.48
# 49999                20190105   20190124.0            RV            1790.30
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20200126.0               NAH4  1.930438e+09
# 1                20190722.0               NAD1  1.929646e+09
# 2                20190914.0               NAA8  1.929874e+09
# 4                20191113.0               NAH4  1.930148e+09
# 5                20190924.0               CA10  2.960581e+09
# ...                     ...                ...           ...
# 49994            20190710.0               NAC6  1.929601e+09
# 49996            20190815.0               NAH4  1.929744e+09
# 49997            20200219.0               NAA8  1.930537e+09
# 49998            20191127.0               NAA8  1.930199e+09
# 49999            20190101.0               NAM4  1.928576e+09
#
#        actual_open_amount
# 0              54273.2800
# 1              79656.6000
# 2               2253.8600
# 4              33133.2900
# 5              17558.4136
# ...                   ...
# 49994          84780.4000
# 49996           6766.5400
# 49997           6120.8600
# 49998             63.4800
# 49999           1790.3000
#
# [40000 rows x 16 columns]

# %%
data['posting_date']=pd.to_datetime(data['posting_date']).dt.normalize()
data
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2020-02-11         2020.0
# 1              U001  0200980828              BEN E  2019-08-08         2019.0
# 2              U001  0200792734          MDV/ trust 2019-12-30         2019.0
# 4              U001  0200769623  WAL-MAR foundation 2019-11-25         2019.0
# 5              CA02  0140106181    THE  corporation 2019-12-04         2019.0
# ...             ...         ...                 ...        ...            ...
# 49994          U001  0200762301        C&S WH trust 2019-07-25         2019.0
# 49996          U001  0200769623          WAL-MAR co 2019-09-03         2019.0
# 49997          U001  0200772595    SAFEW associates 2020-03-05         2020.0
# 49998          U001  0200726979           BJ'S  llc 2019-12-12         2019.0
# 49999          U001  0200020431            DEC corp 2019-01-15         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.930438e+09   2020-01-26              20200125
# 1      1.929646e+09   2019-07-22              20190722
# 2      1.929874e+09   2019-09-14              20190914
# 4      1.930148e+09   2019-11-13              20191113
# 5      2.960581e+09   2019-09-20              20190920
# ...             ...          ...                   ...
# 49994  1.929601e+09   2019-07-10              20190709
# 49996  1.929744e+09   2019-08-15              20190814
# 49997  1.930537e+09   2020-02-19              20200218
# 49998  1.930199e+09   2019-11-27              20191126
# 49999  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1  due_in_date document type  total_open_amount  \
# 0                    20200126   20200210.0            RV           54273.28
# 1                    20190722   20190811.0            RV           79656.60
# 2                    20190914   20190929.0            RV            2253.86
# 4                    20191113   20191128.0            RV           33133.29
# 5                    20190920   20191004.0            RV           22225.84
# ...                       ...          ...           ...                ...
# 49994                20190710   20190725.0            RV           84780.40
# 49996                20190815   20190830.0            RV            6766.54
# 49997                20200219   20200305.0            RV            6120.86
# 49998                20191127   20191212.0            RV              63.48
# 49999                20190105   20190124.0            RV            1790.30
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20200126.0               NAH4  1.930438e+09
# 1                20190722.0               NAD1  1.929646e+09
# 2                20190914.0               NAA8  1.929874e+09
# 4                20191113.0               NAH4  1.930148e+09
# 5                20190924.0               CA10  2.960581e+09
# ...                     ...                ...           ...
# 49994            20190710.0               NAC6  1.929601e+09
# 49996            20190815.0               NAH4  1.929744e+09
# 49997            20200219.0               NAA8  1.930537e+09
# 49998            20191127.0               NAA8  1.930199e+09
# 49999            20190101.0               NAM4  1.928576e+09
#
#        actual_open_amount
# 0              54273.2800
# 1              79656.6000
# 2               2253.8600
# 4              33133.2900
# 5              17558.4136
# ...                   ...
# 49994          84780.4000
# 49996           6766.5400
# 49997           6120.8600
# 49998             63.4800
# 49999           1790.3000
#
# [40000 rows x 16 columns]

# %%
data['due_in_date']=pd.to_datetime(data['due_in_date'],format='%Y%m%d')
data
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2020-02-11         2020.0
# 1              U001  0200980828              BEN E  2019-08-08         2019.0
# 2              U001  0200792734          MDV/ trust 2019-12-30         2019.0
# 4              U001  0200769623  WAL-MAR foundation 2019-11-25         2019.0
# 5              CA02  0140106181    THE  corporation 2019-12-04         2019.0
# ...             ...         ...                 ...        ...            ...
# 49994          U001  0200762301        C&S WH trust 2019-07-25         2019.0
# 49996          U001  0200769623          WAL-MAR co 2019-09-03         2019.0
# 49997          U001  0200772595    SAFEW associates 2020-03-05         2020.0
# 49998          U001  0200726979           BJ'S  llc 2019-12-12         2019.0
# 49999          U001  0200020431            DEC corp 2019-01-15         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.930438e+09   2020-01-26              20200125
# 1      1.929646e+09   2019-07-22              20190722
# 2      1.929874e+09   2019-09-14              20190914
# 4      1.930148e+09   2019-11-13              20191113
# 5      2.960581e+09   2019-09-20              20190920
# ...             ...          ...                   ...
# 49994  1.929601e+09   2019-07-10              20190709
# 49996  1.929744e+09   2019-08-15              20190814
# 49997  1.930537e+09   2020-02-19              20200218
# 49998  1.930199e+09   2019-11-27              20191126
# 49999  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1 due_in_date document type  total_open_amount  \
# 0                    20200126  2020-02-10            RV           54273.28
# 1                    20190722  2019-08-11            RV           79656.60
# 2                    20190914  2019-09-29            RV            2253.86
# 4                    20191113  2019-11-28            RV           33133.29
# 5                    20190920  2019-10-04            RV           22225.84
# ...                       ...         ...           ...                ...
# 49994                20190710  2019-07-25            RV           84780.40
# 49996                20190815  2019-08-30            RV            6766.54
# 49997                20200219  2020-03-05            RV            6120.86
# 49998                20191127  2019-12-12            RV              63.48
# 49999                20190105  2019-01-24            RV            1790.30
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20200126.0               NAH4  1.930438e+09
# 1                20190722.0               NAD1  1.929646e+09
# 2                20190914.0               NAA8  1.929874e+09
# 4                20191113.0               NAH4  1.930148e+09
# 5                20190924.0               CA10  2.960581e+09
# ...                     ...                ...           ...
# 49994            20190710.0               NAC6  1.929601e+09
# 49996            20190815.0               NAH4  1.929744e+09
# 49997            20200219.0               NAA8  1.930537e+09
# 49998            20191127.0               NAA8  1.930199e+09
# 49999            20190101.0               NAM4  1.928576e+09
#
#        actual_open_amount
# 0              54273.2800
# 1              79656.6000
# 2               2253.8600
# 4              33133.2900
# 5              17558.4136
# ...                   ...
# 49994          84780.4000
# 49996           6766.5400
# 49997           6120.8600
# 49998             63.4800
# 49999           1790.3000
#
# [40000 rows x 16 columns]

# %%
data['delay_days'] = pd.to_numeric((data['clear_date']- data['due_in_date']).dt.days, downcast='integer')
data
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2020-02-11         2020.0
# 1              U001  0200980828              BEN E  2019-08-08         2019.0
# 2              U001  0200792734          MDV/ trust 2019-12-30         2019.0
# 4              U001  0200769623  WAL-MAR foundation 2019-11-25         2019.0
# 5              CA02  0140106181    THE  corporation 2019-12-04         2019.0
# ...             ...         ...                 ...        ...            ...
# 49994          U001  0200762301        C&S WH trust 2019-07-25         2019.0
# 49996          U001  0200769623          WAL-MAR co 2019-09-03         2019.0
# 49997          U001  0200772595    SAFEW associates 2020-03-05         2020.0
# 49998          U001  0200726979           BJ'S  llc 2019-12-12         2019.0
# 49999          U001  0200020431            DEC corp 2019-01-15         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.930438e+09   2020-01-26              20200125
# 1      1.929646e+09   2019-07-22              20190722
# 2      1.929874e+09   2019-09-14              20190914
# 4      1.930148e+09   2019-11-13              20191113
# 5      2.960581e+09   2019-09-20              20190920
# ...             ...          ...                   ...
# 49994  1.929601e+09   2019-07-10              20190709
# 49996  1.929744e+09   2019-08-15              20190814
# 49997  1.930537e+09   2020-02-19              20200218
# 49998  1.930199e+09   2019-11-27              20191126
# 49999  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1 due_in_date document type  total_open_amount  \
# 0                    20200126  2020-02-10            RV           54273.28
# 1                    20190722  2019-08-11            RV           79656.60
# 2                    20190914  2019-09-29            RV            2253.86
# 4                    20191113  2019-11-28            RV           33133.29
# 5                    20190920  2019-10-04            RV           22225.84
# ...                       ...         ...           ...                ...
# 49994                20190710  2019-07-25            RV           84780.40
# 49996                20190815  2019-08-30            RV            6766.54
# 49997                20200219  2020-03-05            RV            6120.86
# 49998                20191127  2019-12-12            RV              63.48
# 49999                20190105  2019-01-24            RV            1790.30
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20200126.0               NAH4  1.930438e+09
# 1                20190722.0               NAD1  1.929646e+09
# 2                20190914.0               NAA8  1.929874e+09
# 4                20191113.0               NAH4  1.930148e+09
# 5                20190924.0               CA10  2.960581e+09
# ...                     ...                ...           ...
# 49994            20190710.0               NAC6  1.929601e+09
# 49996            20190815.0               NAH4  1.929744e+09
# 49997            20200219.0               NAA8  1.930537e+09
# 49998            20191127.0               NAA8  1.930199e+09
# 49999            20190101.0               NAM4  1.928576e+09
#
#        actual_open_amount  delay_days
# 0              54273.2800           1
# 1              79656.6000          -3
# 2               2253.8600          92
# 4              33133.2900          -3
# 5              17558.4136          61
# ...                   ...         ...
# 49994          84780.4000           0
# 49996           6766.5400           4
# 49997           6120.8600           0
# 49998             63.4800           0
# 49999           1790.3000          -9
#
# [40000 rows x 17 columns]

# %%
newdata1 = data[data.due_in_date.isna()].copy()
newdata
# Out:
#       business_code cust_number        name_customer clear_date  \
# 3              CA02  0140105686             SYSC llc        NaN
# 7              U001  0200744019              TARG us        NaN
# 10             U001  0200418007                  AM         NaN
# 14             U001  0200739534           OK systems        NaN
# 15             U001  0200353024     DECA corporation        NaN
# ...             ...         ...                  ...        ...
# 49975          U001  0200769623           WAL-MAR in        NaN
# 49980          U001  0200769623  WAL-MAR corporation        NaN
# 49982          U001  0200148860             DOLLA co        NaN
# 49992          U001  0200900909             SYSCO co        NaN
# 49995          U001  0200561861       CO corporation        NaN
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 3             2020.0  2.960623e+09   2020-03-30              20200330
# 7             2020.0  1.930659e+09   2020-03-19              20200318
# 10            2020.0  1.930611e+09   2020-03-11              20200306
# 14            2020.0  1.930788e+09   2020-04-15              20200415
# 15            2020.0  1.930817e+09   2020-04-23              20200423
# ...              ...           ...          ...                   ...
# 49975         2020.0  1.930625e+09   2020-03-10              20200309
# 49980         2020.0  1.930851e+09   2020-05-03              20200502
# 49982         2020.0  1.930638e+09   2020-03-11              20200311
# 49992         2020.0  1.930702e+09   2020-03-25              20200325
# 49995         2020.0  1.930797e+09   2020-04-21              20200417
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 3                    20200330   20200410.0              CAD            RV
# 7                    20200319   20200403.0              USD            RV
# 10                   20200311   20200326.0              USD            RV
# 14                   20200415   20200430.0              USD            RV
# 15                   20200423   20200426.0              USD            RV
# ...                       ...          ...              ...           ...
# 49975                20200310   20200325.0              USD            RV
# 49980                20200503   20200518.0              USD            RV
# 49982                20200311   20200326.0              USD            RV
# 49992                20200325   20200409.0              USD            RV
# 49995                20200421   20200506.0              USD            RV
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 3                3299.70            20200331.0               CA10
# 7               11173.02            20200319.0               NAA8
# 10               3525.59            20200311.0               NAA8
# 14             121105.65            20200415.0               NAA8
# 15               3726.06            20200416.0               NAM2
# ...                  ...                   ...                ...
# 49975           13114.99            20200310.0               NAH4
# 49980            8899.71            20200503.0               NAH4
# 49982            4967.06            20200311.0               NAA8
# 49992            1998.64            20200325.0               NAA8
# 49995            3187.86            20200421.0               NAA8
#
#          invoice_id  isOpen
# 3      2.960623e+09       1
# 7      1.930659e+09       1
# 10     1.930611e+09       1
# 14     1.930788e+09       1
# 15     1.930817e+09       1
# ...             ...     ...
# 49975  1.930625e+09       1
# 49980  1.930851e+09       1
# 49982  1.930638e+09       1
# 49992  1.930702e+09       1
# 49995  1.930797e+09       1
#
# [10000 rows x 17 columns]

# %%
data.drop(['clear_date','due_in_date'] ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp         2020.0
# 1              U001  0200980828              BEN E          2019.0
# 2              U001  0200792734          MDV/ trust         2019.0
# 4              U001  0200769623  WAL-MAR foundation         2019.0
# 5              CA02  0140106181    THE  corporation         2019.0
# ...             ...         ...                 ...            ...
# 49994          U001  0200762301        C&S WH trust         2019.0
# 49996          U001  0200769623          WAL-MAR co         2019.0
# 49997          U001  0200772595    SAFEW associates         2020.0
# 49998          U001  0200726979           BJ'S  llc         2019.0
# 49999          U001  0200020431            DEC corp         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.930438e+09   2020-01-26              20200125
# 1      1.929646e+09   2019-07-22              20190722
# 2      1.929874e+09   2019-09-14              20190914
# 4      1.930148e+09   2019-11-13              20191113
# 5      2.960581e+09   2019-09-20              20190920
# ...             ...          ...                   ...
# 49994  1.929601e+09   2019-07-10              20190709
# 49996  1.929744e+09   2019-08-15              20190814
# 49997  1.930537e+09   2020-02-19              20200218
# 49998  1.930199e+09   2019-11-27              20191126
# 49999  1.928576e+09   2019-01-05              20190105
#
#        document_create_date.1 document type  total_open_amount  \
# 0                    20200126            RV           54273.28
# 1                    20190722            RV           79656.60
# 2                    20190914            RV            2253.86
# 4                    20191113            RV           33133.29
# 5                    20190920            RV           22225.84
# ...                       ...           ...                ...
# 49994                20190710            RV           84780.40
# 49996                20190815            RV            6766.54
# 49997                20200219            RV            6120.86
# 49998                20191127            RV              63.48
# 49999                20190105            RV            1790.30
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20200126.0               NAH4  1.930438e+09
# 1                20190722.0               NAD1  1.929646e+09
# 2                20190914.0               NAA8  1.929874e+09
# 4                20191113.0               NAH4  1.930148e+09
# 5                20190924.0               CA10  2.960581e+09
# ...                     ...                ...           ...
# 49994            20190710.0               NAC6  1.929601e+09
# 49996            20190815.0               NAH4  1.929744e+09
# 49997            20200219.0               NAA8  1.930537e+09
# 49998            20191127.0               NAA8  1.930199e+09
# 49999            20190101.0               NAM4  1.928576e+09
#
#        actual_open_amount  delay_days
# 0              54273.2800           1
# 1              79656.6000          -3
# 2               2253.8600          92
# 4              33133.2900          -3
# 5              17558.4136          61
# ...                   ...         ...
# 49994          84780.4000           0
# 49996           6766.5400           4
# 49997           6120.8600           0
# 49998             63.4800           0
# 49999           1790.3000          -9
#
# [40000 rows x 15 columns]

# %%
data.shape
# Out:
# (40000, 15)

# %%
data.sort_values(by=['posting_date'],inplace=True)
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 2509           U001  0200769623            WAL-MAR          2019.0
# 12937          U001  0200794332             COST us         2019.0
# 1339           U001  0200769623     WAL-MAR systems         2019.0
# 7610           U001  0200726979    BJ'S  foundation         2019.0
# 28243          U001  0200707822            PUBLI us         2019.0
# ...             ...         ...                 ...            ...
# 15526          U001      CCCA02  KRAFT  corporation         2020.0
# 26741          U001  0200726979          BJ'S  corp         2020.0
# 16955          U001  0200759878             SA corp         2020.0
# 19322          U001  0200739044  PERFOR corporation         2020.0
# 2874           U001  0200418007       AM associates         2020.0
#
#              doc_id posting_date  document_create_date  \
# 2509   1.928542e+09   2018-12-30              20181229
# 12937  1.928535e+09   2018-12-30              20181229
# 1339   1.928543e+09   2018-12-30              20181230
# 7610   1.928540e+09   2018-12-30              20181229
# 28243  1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 15526  1.930565e+09   2020-02-26              20200224
# 26741  1.930569e+09   2020-02-26              20200225
# 16955  1.930574e+09   2020-02-27              20200226
# 19322  1.930574e+09   2020-02-27              20200226
# 2874   1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1 document type  total_open_amount  \
# 2509                 20181230            RV           12491.86
# 12937                20181230            RV           51473.49
# 1339                 20181230            RV           41840.55
# 7610                 20181230            RV              58.18
# 28243                20181230            RV          110990.78
# ...                       ...           ...                ...
# 15526                20200226            RV           30576.00
# 26741                20200226            RV             553.46
# 16955                20200227            RV           49290.19
# 19322                20200227            RV           25143.02
# 2874                 20200227            RV           10349.36
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 2509             20181230.0               NAH4  1.928542e+09
# 12937            20181230.0               NAAX  1.928535e+09
# 1339             20181230.0               NAH4  1.928543e+09
# 7610             20181230.0               NAA8  1.928540e+09
# 28243            20181230.0               NAA8  1.928545e+09
# ...                     ...                ...           ...
# 15526            20200226.0               NAG2  1.930565e+09
# 26741            20200226.0               NAA8  1.930569e+09
# 16955            20200227.0               NAH4  1.930574e+09
# 19322            20200227.0               NAA8  1.930574e+09
# 2874             20200227.0               NAA8  1.930568e+09
#
#        actual_open_amount  delay_days
# 2509             12491.86           1
# 12937            51473.49           1
# 1339             41840.55          -4
# 7610                58.18           1
# 28243           110990.78           0
# ...                   ...         ...
# 15526            30576.00          -5
# 26741              553.46           0
# 16955            49290.19           0
# 19322            25143.02           3
# 2874             10349.36           6
#
# [40000 rows x 15 columns]

# %%
data.set_index
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 2509           U001  0200769623            WAL-MAR          2019.0
# 12937          U001  0200794332             COST us         2019.0
# 1339           U001  0200769623     WAL-MAR systems         2019.0
# 7610           U001  0200726979    BJ'S  foundation         2019.0
# 28243          U001  0200707822            PUBLI us         2019.0
# ...             ...         ...                 ...            ...
# 15526          U001      CCCA02  KRAFT  corporation         2020.0
# 26741          U001  0200726979          BJ'S  corp         2020.0
# 16955          U001  0200759878             SA corp         2020.0
# 19322          U001  0200739044  PERFOR corporation         2020.0
# 2874           U001  0200418007       AM associates         2020.0
#
#              doc_id posting_date  document_create_date  \
# 2509   1.928542e+09   2018-12-30              20181229
# 12937  1.928535e+09   2018-12-30              20181229
# 1339   1.928543e+09   2018-12-30              20181230
# 7610   1.928540e+09   2018-12-30              20181229
# 28243  1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 15526  1.930565e+09   2020-02-26              20200224
# 26741  1.930569e+09   2020-02-26              20200225
# 16955  1.930574e+09   2020-02-27              20200226
# 19322  1.930574e+09   2020-02-27              20200226
# 2874   1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1 document type  total_open_amount  \
# 2509                 20181230            RV           12491.86
# 12937                20181230            RV           51473.49
# 1339                 20181230            RV           41840.55
# 7610                 20181230            RV              58.18
# 28243                20181230            RV          110990.78
# ...                       ...           ...                ...
# 15526                20200226            RV           30576.00
# 26741                20200226            RV             553.46
# 16955                20200227            RV           49290.19
# 19322                20200227            RV           25143.02
# 2874                 20200227            RV           10349.36
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 2509             20181230.0               NAH4  1.928542e+09
# 12937            20181230.0               NAAX  1.928535e+09
# 1339             20181230.0               NAH4  1.928543e+09
# 7610             20181230.0               NAA8  1.928540e+09
# 28243            20181230.0               NAA8  1.928545e+09
# ...                     ...                ...           ...
# 15526            20200226.0               NAG2  1.930565e+09
# 26741            20200226.0               NAA8  1.930569e+09
# 16955            20200227.0               NAH4  1.930574e+09
# 19322            20200227.0               NAA8  1.930574e+09
# 2874             20200227.0               NAA8  1.930568e+09
#
#        actual_open_amount  delay_days
# 2509             12491.86           1
# 12937            51473.49           1
# 1339             41840.55          -4
# 7610                58.18           1
# 28243           110990.78           0
# ...                   ...         ...
# 15526            30576.00          -5
# 26741              553.46           0
# 16955            49290.19           0
# 19322            25143.02           3
# 2874             10349.36           6
#
# [40000 rows x 15 columns]

# %%
data.reset_index(drop=True, inplace=True)
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 0              U001  0200769623            WAL-MAR          2019.0
# 1              U001  0200794332             COST us         2019.0
# 2              U001  0200769623     WAL-MAR systems         2019.0
# 3              U001  0200726979    BJ'S  foundation         2019.0
# 4              U001  0200707822            PUBLI us         2019.0
# ...             ...         ...                 ...            ...
# 39995          U001      CCCA02  KRAFT  corporation         2020.0
# 39996          U001  0200726979          BJ'S  corp         2020.0
# 39997          U001  0200759878             SA corp         2020.0
# 39998          U001  0200739044  PERFOR corporation         2020.0
# 39999          U001  0200418007       AM associates         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928542e+09   2018-12-30              20181229
# 1      1.928535e+09   2018-12-30              20181229
# 2      1.928543e+09   2018-12-30              20181230
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 39995  1.930565e+09   2020-02-26              20200224
# 39996  1.930569e+09   2020-02-26              20200225
# 39997  1.930574e+09   2020-02-27              20200226
# 39998  1.930574e+09   2020-02-27              20200226
# 39999  1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1 document type  total_open_amount  \
# 0                    20181230            RV           12491.86
# 1                    20181230            RV           51473.49
# 2                    20181230            RV           41840.55
# 3                    20181230            RV              58.18
# 4                    20181230            RV          110990.78
# ...                       ...           ...                ...
# 39995                20200226            RV           30576.00
# 39996                20200226            RV             553.46
# 39997                20200227            RV           49290.19
# 39998                20200227            RV           25143.02
# 39999                20200227            RV           10349.36
#
#        baseline_create_date cust_payment_terms    invoice_id  \
# 0                20181230.0               NAH4  1.928542e+09
# 1                20181230.0               NAAX  1.928535e+09
# 2                20181230.0               NAH4  1.928543e+09
# 3                20181230.0               NAA8  1.928540e+09
# 4                20181230.0               NAA8  1.928545e+09
# ...                     ...                ...           ...
# 39995            20200226.0               NAG2  1.930565e+09
# 39996            20200226.0               NAA8  1.930569e+09
# 39997            20200227.0               NAH4  1.930574e+09
# 39998            20200227.0               NAA8  1.930574e+09
# 39999            20200227.0               NAA8  1.930568e+09
#
#        actual_open_amount  delay_days
# 0                12491.86           1
# 1                51473.49           1
# 2                41840.55          -4
# 3                   58.18           1
# 4               110990.78           0
# ...                   ...         ...
# 39995            30576.00          -5
# 39996              553.46           0
# 39997            49290.19           0
# 39998            25143.02           3
# 39999            10349.36           6
#
# [40000 rows x 15 columns]

# %%
data.drop('total_open_amount' ,axis=1 , inplace=True)
data
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 0              U001  0200769623            WAL-MAR          2019.0
# 1              U001  0200794332             COST us         2019.0
# 2              U001  0200769623     WAL-MAR systems         2019.0
# 3              U001  0200726979    BJ'S  foundation         2019.0
# 4              U001  0200707822            PUBLI us         2019.0
# ...             ...         ...                 ...            ...
# 39995          U001      CCCA02  KRAFT  corporation         2020.0
# 39996          U001  0200726979          BJ'S  corp         2020.0
# 39997          U001  0200759878             SA corp         2020.0
# 39998          U001  0200739044  PERFOR corporation         2020.0
# 39999          U001  0200418007       AM associates         2020.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928542e+09   2018-12-30              20181229
# 1      1.928535e+09   2018-12-30              20181229
# 2      1.928543e+09   2018-12-30              20181230
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 39995  1.930565e+09   2020-02-26              20200224
# 39996  1.930569e+09   2020-02-26              20200225
# 39997  1.930574e+09   2020-02-27              20200226
# 39998  1.930574e+09   2020-02-27              20200226
# 39999  1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1 document type  baseline_create_date  \
# 0                    20181230            RV            20181230.0
# 1                    20181230            RV            20181230.0
# 2                    20181230            RV            20181230.0
# 3                    20181230            RV            20181230.0
# 4                    20181230            RV            20181230.0
# ...                       ...           ...                   ...
# 39995                20200226            RV            20200226.0
# 39996                20200226            RV            20200226.0
# 39997                20200227            RV            20200227.0
# 39998                20200227            RV            20200227.0
# 39999                20200227            RV            20200227.0
#
#       cust_payment_terms    invoice_id  actual_open_amount  delay_days
# 0                   NAH4  1.928542e+09            12491.86           1
# 1                   NAAX  1.928535e+09            51473.49           1
# 2                   NAH4  1.928543e+09            41840.55          -4
# 3                   NAA8  1.928540e+09               58.18           1
# 4                   NAA8  1.928545e+09           110990.78           0
# ...                  ...           ...                 ...         ...
# 39995               NAG2  1.930565e+09            30576.00          -5
# 39996               NAA8  1.930569e+09              553.46           0
# 39997               NAH4  1.930574e+09            49290.19           0
# 39998               NAA8  1.930574e+09            25143.02           3
# 39999               NAA8  1.930568e+09            10349.36           6
#
# [40000 rows x 14 columns]

# %%
X = data.drop('delay_days',axis=1)

# %%
y = data['delay_days']

# %%
from sklearn.model_selection import train_test_split
X_train,X_inter_test,y_train,y_inter_test = train_test_split(X,y,test_size=0.5,random_state=42 , shuffle = False)

# %%
X_val,X_test,y_val,y_test = train_test_split(X_inter_test,y_inter_test,test_size=0.5,random_state=42 , shuffle = False)

# %%
X_train.shape , X_val.shape , X_test.shape
# Out:
# ((20000, 13), (10000, 13), (10000, 13))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   buisness_year           20000 non-null  float64
#  4   doc_id                  20000 non-null  float64
#  5   posting_date            20000 non-null  datetime64[ns]
#  6   document_create_date    20000 non-null  int64
#  7   document_create_date.1  20000 non-null  int64
#  8   document type           20000 non-null  object
#  9   baseline_create_date    20000 non-null  float64
#  10  cust_payment_terms      20000 non-null  object
#  11  invoice_id              20000 non-null  float64
#  12  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
X_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 20000 to 29999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           10000 non-null  object
#  1   cust_number             10000 non-null  object
#  2   name_customer           10000 non-null  object
#  3   buisness_year           10000 non-null  float64
#  4   doc_id                  10000 non-null  float64
#  5   posting_date            10000 non-null  datetime64[ns]
#  6   document_create_date    10000 non-null  int64
#  7   document_create_date.1  10000 non-null  int64
#  8   document type           10000 non-null  object
#  9   baseline_create_date    10000 non-null  float64
#  10  cust_payment_terms      10000 non-null  object
#  11  invoice_id              10000 non-null  float64
#  12  actual_open_amount      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 30000 to 39999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           10000 non-null  object
#  1   cust_number             10000 non-null  object
#  2   name_customer           10000 non-null  object
#  3   buisness_year           10000 non-null  float64
#  4   doc_id                  10000 non-null  float64
#  5   posting_date            10000 non-null  datetime64[ns]
#  6   document_create_date    10000 non-null  int64
#  7   document_create_date.1  10000 non-null  int64
#  8   document type           10000 non-null  object
#  9   baseline_create_date    10000 non-null  float64
#  10  cust_payment_terms      10000 non-null  object
#  11  invoice_id              10000 non-null  float64
#  12  actual_open_amount      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
y_train
# Out:
# 0         1
# 1         1
# 2        -4
# 3         1
# 4         0
#          ..
# 19995     2
# 19996    59
# 19997    11
# 19998     1
# 19999     1
# Name: delay_days, Length: 20000, dtype: int16

# %%
sns.distplot(y_train)
# Out:
# <AxesSubplot:xlabel='delay_days', ylabel='Density'>

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   buisness_year           20000 non-null  float64
#  4   doc_id                  20000 non-null  float64
#  5   posting_date            20000 non-null  datetime64[ns]
#  6   document_create_date    20000 non-null  int64
#  7   document_create_date.1  20000 non-null  int64
#  8   document type           20000 non-null  object
#  9   baseline_create_date    20000 non-null  float64
#  10  cust_payment_terms      20000 non-null  object
#  11  invoice_id              20000 non-null  float64
#  12  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
X_train.merge(y_train,on=X_train.index)
# Out:
#        key_0 business_code cust_number        name_customer  buisness_year  \
# 0          0          U001  0200769623             WAL-MAR          2019.0
# 1          1          U001  0200794332              COST us         2019.0
# 2          2          U001  0200769623      WAL-MAR systems         2019.0
# 3          3          U001  0200726979     BJ'S  foundation         2019.0
# 4          4          U001  0200707822             PUBLI us         2019.0
# ...      ...           ...         ...                  ...            ...
# 19995  19995          U001  0200759878                SA in         2019.0
# 19996  19996          CA02  0140106181             THE  llc         2019.0
# 19997  19997          CA02  0140104263  BAKEMAR corporation         2019.0
# 19998  19998          U001  0200743996           STATER  in         2019.0
# 19999  19999          U001  0200794332                COST          2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.928542e+09   2018-12-30              20181229
# 1      1.928535e+09   2018-12-30              20181229
# 2      1.928543e+09   2018-12-30              20181230
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 19995  1.929636e+09   2019-07-20              20190719
# 19996  2.960567e+09   2019-07-20              20190720
# 19997  2.960567e+09   2019-07-20              20190720
# 19998  1.929643e+09   2019-07-20              20190720
# 19999  1.929638e+09   2019-07-20              20190719
#
#        document_create_date.1 document type  baseline_create_date  \
# 0                    20181230            RV            20181230.0
# 1                    20181230            RV            20181230.0
# 2                    20181230            RV            20181230.0
# 3                    20181230            RV            20181230.0
# 4                    20181230            RV            20181230.0
# ...                       ...           ...                   ...
# 19995                20190720            RV            20190720.0
# 19996                20190720            RV            20190725.0
# 19997                20190720            RV            20190730.0
# 19998                20190720            RV            20190720.0
# 19999                20190720            RV            20190720.0
#
#       cust_payment_terms    invoice_id  actual_open_amount  delay_days
# 0                   NAH4  1.928542e+09           12491.860           1
# 1                   NAAX  1.928535e+09           51473.490           1
# 2                   NAH4  1.928543e+09           41840.550          -4
# 3                   NAA8  1.928540e+09              58.180           1
# 4                   NAA8  1.928545e+09          110990.780           0
# ...                  ...           ...                 ...         ...
# 19995               NAH4  1.929636e+09           14272.220           2
# 19996               CA10  2.960567e+09            8030.508          59
# 19997               CA10  2.960567e+09            9622.832          11
# 19998               NAA8  1.929643e+09          107582.010           1
# 19999               NAAX  1.929638e+09           23510.530           1
#
# [20000 rows x 15 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   buisness_year           20000 non-null  float64
#  4   doc_id                  20000 non-null  float64
#  5   posting_date            20000 non-null  datetime64[ns]
#  6   document_create_date    20000 non-null  int64
#  7   document_create_date.1  20000 non-null  int64
#  8   document type           20000 non-null  object
#  9   baseline_create_date    20000 non-null  float64
#  10  cust_payment_terms      20000 non-null  object
#  11  invoice_id              20000 non-null  float64
#  12  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
sns.scatterplot(data=X_train.merge(y_train,on=X_train.index) , x = 'delay_days',y='posting_date')
# Out:
# <AxesSubplot:xlabel='delay_days', ylabel='posting_date'>

# %%
sns.scatterplot(data=X_train.merge(y_train,on=X_train.index) , x = 'document_create_date' , y='delay_days')
# Out:
# <AxesSubplot:xlabel='document_create_date', ylabel='delay_days'>

# %%
data.columns
# Out:
# Index(['business_code', 'cust_number', 'name_customer', 'buisness_year',
#        'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'document type', 'baseline_create_date',
#        'cust_payment_terms', 'invoice_id', 'actual_open_amount', 'delay_days'],
#       dtype='object')

# %%
X_train.nunique()
# Out:
# business_code                 6
# cust_number                1119
# name_customer              2856
# buisness_year                 1
# doc_id                    19573
# posting_date                203
# document_create_date        208
# document_create_date.1      203
# document type                 2
# baseline_create_date        212
# cust_payment_terms           60
# invoice_id                19573
# actual_open_amount        18197
# dtype: int64

# %%
X_train.drop('buisness_year' ,axis=1 , inplace=True)
X_val.drop('buisness_year' ,axis=1 , inplace=True)
X_test.drop('buisness_year' ,axis=1 , inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           20000 non-null  object
#  1   cust_number             20000 non-null  object
#  2   name_customer           20000 non-null  object
#  3   doc_id                  20000 non-null  float64
#  4   posting_date            20000 non-null  datetime64[ns]
#  5   document_create_date    20000 non-null  int64
#  6   document_create_date.1  20000 non-null  int64
#  7   document type           20000 non-null  object
#  8   baseline_create_date    20000 non-null  float64
#  9   cust_payment_terms      20000 non-null  object
#  10  invoice_id              20000 non-null  float64
#  11  actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 2.0+ MB

# %%
X_train.drop(['document type','business_code','cust_number','name_customer','cust_payment_terms'],axis=1,inplace = True)
X_test.drop(['document type','business_code','cust_number','name_customer','cust_payment_terms'],axis=1,inplace = True)
X_val.drop(['document type','business_code','cust_number','name_customer','cust_payment_terms'],axis=1,inplace = True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   doc_id                  20000 non-null  float64
#  1   posting_date            20000 non-null  datetime64[ns]
#  2   document_create_date    20000 non-null  int64
#  3   document_create_date.1  20000 non-null  int64
#  4   baseline_create_date    20000 non-null  float64
#  5   invoice_id              20000 non-null  float64
#  6   actual_open_amount      20000 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2)
# memory usage: 1.2 MB

# %%
X_train.nunique()
# Out:
# doc_id                    19573
# posting_date                203
# document_create_date        208
# document_create_date.1      203
# baseline_create_date        212
# invoice_id                19573
# actual_open_amount        18197
# dtype: int64

# %%
X_train['business_days'] = pd.DatetimeIndex(X_train['posting_date']).day
X_train['business_month'] = pd. DatetimeIndex(X_train['posting_date']).month
X_train
# Out:
#              doc_id posting_date  document_create_date  \
# 0      1.928542e+09   2018-12-30              20181229
# 1      1.928535e+09   2018-12-30              20181229
# 2      1.928543e+09   2018-12-30              20181230
# 3      1.928540e+09   2018-12-30              20181229
# 4      1.928545e+09   2018-12-30              20181230
# ...             ...          ...                   ...
# 19995  1.929636e+09   2019-07-20              20190719
# 19996  2.960567e+09   2019-07-20              20190720
# 19997  2.960567e+09   2019-07-20              20190720
# 19998  1.929643e+09   2019-07-20              20190720
# 19999  1.929638e+09   2019-07-20              20190719
#
#        document_create_date.1  baseline_create_date    invoice_id  \
# 0                    20181230            20181230.0  1.928542e+09
# 1                    20181230            20181230.0  1.928535e+09
# 2                    20181230            20181230.0  1.928543e+09
# 3                    20181230            20181230.0  1.928540e+09
# 4                    20181230            20181230.0  1.928545e+09
# ...                       ...                   ...           ...
# 19995                20190720            20190720.0  1.929636e+09
# 19996                20190720            20190725.0  2.960567e+09
# 19997                20190720            20190730.0  2.960567e+09
# 19998                20190720            20190720.0  1.929643e+09
# 19999                20190720            20190720.0  1.929638e+09
#
#        actual_open_amount  business_days  business_month
# 0               12491.860             30              12
# 1               51473.490             30              12
# 2               41840.550             30              12
# 3                  58.180             30              12
# 4              110990.780             30              12
# ...                   ...            ...             ...
# 19995           14272.220             20               7
# 19996            8030.508             20               7
# 19997            9622.832             20               7
# 19998          107582.010             20               7
# 19999           23510.530             20               7
#
# [20000 rows x 9 columns]

# %%
X_val['business_days'] = pd.DatetimeIndex(X_val['posting_date']).day
X_val['business_month'] = pd. DatetimeIndex(X_val['posting_date']).month
X_val
# Out:
#              doc_id posting_date  document_create_date  \
# 20000  1.929636e+09   2019-07-20              20190718
# 20001  1.929638e+09   2019-07-20              20190720
# 20002  1.929637e+09   2019-07-20              20190719
# 20003  1.929643e+09   2019-07-20              20190720
# 20004  1.929635e+09   2019-07-20              20190718
# ...             ...          ...                   ...
# 29995  1.930053e+09   2019-10-28              20191026
# 29996  1.930056e+09   2019-10-28              20191027
# 29997  1.930051e+09   2019-10-28              20191024
# 29998  1.930057e+09   2019-10-28              20191028
# 29999  1.930053e+09   2019-10-28              20191025
#
#        document_create_date.1  baseline_create_date    invoice_id  \
# 20000                20190720            20190720.0  1.929636e+09
# 20001                20190720            20190720.0  1.929638e+09
# 20002                20190720            20190720.0  1.929637e+09
# 20003                20190720            20190720.0  1.929643e+09
# 20004                20190720            20190720.0  1.929635e+09
# ...                       ...                   ...           ...
# 29995                20191028            20191028.0  1.930053e+09
# 29996                20191028            20191028.0  1.930056e+09
# 29997                20191028            20191028.0  1.930051e+09
# 29998                20191028            20191028.0  1.930057e+09
# 29999                20191028            20191028.0  1.930053e+09
#
#        actual_open_amount  business_days  business_month
# 20000            66206.62             20               7
# 20001            11163.46             20               7
# 20002             1052.32             20               7
# 20003           100859.28             20               7
# 20004             1071.10             20               7
# ...                   ...            ...             ...
# 29995            74168.16             28              10
# 29996             9080.68             28              10
# 29997            32975.20             28              10
# 29998            61585.17             28              10
# 29999              707.54             28              10
#
# [10000 rows x 9 columns]

# %%
X_test['business_days'] = pd.DatetimeIndex(X_test['posting_date']).day
X_test['business_month'] = pd. DatetimeIndex(X_test['posting_date']).month
X_test
# Out:
#              doc_id posting_date  document_create_date  \
# 30000  1.930049e+09   2019-10-28              20191024
# 30001  1.930056e+09   2019-10-28              20191026
# 30002  1.930059e+09   2019-10-28              20191028
# 30003  1.930062e+09   2019-10-28              20191028
# 30004  1.930056e+09   2019-10-28              20191027
# ...             ...          ...                   ...
# 39995  1.930565e+09   2020-02-26              20200224
# 39996  1.930569e+09   2020-02-26              20200225
# 39997  1.930574e+09   2020-02-27              20200226
# 39998  1.930574e+09   2020-02-27              20200226
# 39999  1.930568e+09   2020-02-27              20200225
#
#        document_create_date.1  baseline_create_date    invoice_id  \
# 30000                20191028            20191028.0  1.930049e+09
# 30001                20191028            20191028.0  1.930056e+09
# 30002                20191028            20191028.0  1.930059e+09
# 30003                20191028            20191028.0  1.930062e+09
# 30004                20191028            20191028.0  1.930056e+09
# ...                       ...                   ...           ...
# 39995                20200226            20200226.0  1.930565e+09
# 39996                20200226            20200226.0  1.930569e+09
# 39997                20200227            20200227.0  1.930574e+09
# 39998                20200227            20200227.0  1.930574e+09
# 39999                20200227            20200227.0  1.930568e+09
#
#        actual_open_amount  business_days  business_month
# 30000             8755.61             28              10
# 30001            28452.83             28              10
# 30002            54609.17             28              10
# 30003             9251.89             28              10
# 30004            64529.54             28              10
# ...                   ...            ...             ...
# 39995            30576.00             26               2
# 39996              553.46             26               2
# 39997            49290.19             27               2
# 39998            25143.02             27               2
# 39999            10349.36             27               2
#
# [10000 rows x 9 columns]

# %%
X_train.drop(['posting_date'],axis=1,inplace = True)
X_test.drop(['posting_date'],axis=1,inplace = True)
X_val.drop(['posting_date'],axis=1,inplace = True)

# %%
X_train
# Out:
#              doc_id  document_create_date  document_create_date.1  \
# 0      1.928542e+09              20181229                20181230
# 1      1.928535e+09              20181229                20181230
# 2      1.928543e+09              20181230                20181230
# 3      1.928540e+09              20181229                20181230
# 4      1.928545e+09              20181230                20181230
# ...             ...                   ...                     ...
# 19995  1.929636e+09              20190719                20190720
# 19996  2.960567e+09              20190720                20190720
# 19997  2.960567e+09              20190720                20190720
# 19998  1.929643e+09              20190720                20190720
# 19999  1.929638e+09              20190719                20190720
#
#        baseline_create_date    invoice_id  actual_open_amount  business_days  \
# 0                20181230.0  1.928542e+09           12491.860             30
# 1                20181230.0  1.928535e+09           51473.490             30
# 2                20181230.0  1.928543e+09           41840.550             30
# 3                20181230.0  1.928540e+09              58.180             30
# 4                20181230.0  1.928545e+09          110990.780             30
# ...                     ...           ...                 ...            ...
# 19995            20190720.0  1.929636e+09           14272.220             20
# 19996            20190725.0  2.960567e+09            8030.508             20
# 19997            20190730.0  2.960567e+09            9622.832             20
# 19998            20190720.0  1.929643e+09          107582.010             20
# 19999            20190720.0  1.929638e+09           23510.530             20
#
#        business_month
# 0                  12
# 1                  12
# 2                  12
# 3                  12
# 4                  12
# ...               ...
# 19995               7
# 19996               7
# 19997               7
# 19998               7
# 19999               7
#
# [20000 rows x 8 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   doc_id                  20000 non-null  float64
#  1   document_create_date    20000 non-null  int64
#  2   document_create_date.1  20000 non-null  int64
#  3   baseline_create_date    20000 non-null  float64
#  4   invoice_id              20000 non-null  float64
#  5   actual_open_amount      20000 non-null  float64
#  6   business_days           20000 non-null  int64
#  7   business_month          20000 non-null  int64
# dtypes: float64(4), int64(4)
# memory usage: 1.4 MB

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,10))

sns.heatmap(X_train.merge(y_train , on = X_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:>

# %%
X_train.drop(['doc_id','document_create_date.1','invoice_id','baseline_create_date'],axis=1,inplace = True)
X_test.drop(['doc_id','document_create_date.1','invoice_id','baseline_create_date'],axis=1,inplace = True)
X_val.drop(['doc_id','document_create_date.1','invoice_id','baseline_create_date'],axis=1,inplace = True)

# %%
X_train
# Out:
#        document_create_date  actual_open_amount  business_days  business_month
# 0                  20181229           12491.860             30              12
# 1                  20181229           51473.490             30              12
# 2                  20181230           41840.550             30              12
# 3                  20181229              58.180             30              12
# 4                  20181230          110990.780             30              12
# ...                     ...                 ...            ...             ...
# 19995              20190719           14272.220             20               7
# 19996              20190720            8030.508             20               7
# 19997              20190720            9622.832             20               7
# 19998              20190720          107582.010             20               7
# 19999              20190719           23510.530             20               7
#
# [20000 rows x 4 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 19999
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   document_create_date  20000 non-null  int64
#  1   actual_open_amount    20000 non-null  float64
#  2   business_days         20000 non-null  int64
#  3   business_month        20000 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 781.2 KB

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,10))

sns.heatmap(X_train.merge(y_train , on = X_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
base_model = LinearRegression()
base_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr_predict = base_model.predict(X_val)
lr_predict
# Out:
# array([0.80590577, 0.9775549 , 1.00921281, ..., 0.65819186, 0.56850564,
#        0.75883282])

# %%
y_val
# Out:
# 20000    2
# 20001   -3
# 20002    2
# 20003    1
# 20004   -5
#         ..
# 29995    0
# 29996   -5
# 29997    5
# 29998    3
# 29999    6
# Name: delay_days, Length: 10000, dtype: int16

# %%
pd.DataFrame(zip(lr_predict, y_val),columns=['Predicted','Actuals'])
# Out:
#       Predicted  Actuals
# 0      0.805906        2
# 1      0.977555       -3
# 2      1.009213        2
# 3      0.697541        1
# 4      1.009247       -5
# ...         ...      ...
# 9995   0.529409        0
# 9996   0.732508       -5
# 9997   0.658192        5
# 9998   0.568506        3
# 9999   0.758833        6
#
# [10000 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error as mae
mae(y_val,lr_predict)
# Out:
# 4.528281380649203

# %%
lr_predict2= base_model.predict(X_test)

# %%
mae(y_test,lr_predict2)
# Out:
# 4.232080781017205

# %%
pd.DataFrame(zip(y_val , y_test),columns=['Predicted','Actuals'])
# Out:
#       Predicted  Actuals
# 0             2        0
# 1            -3        1
# 2             2       -4
# 3             1       33
# 4            -5        1
# ...         ...      ...
# 9995          0       -5
# 9996         -5        0
# 9997          5        0
# 9998          3        3
# 9999          6        6
#
# [10000 rows x 2 columns]
