# %%
# https://www.fao.org/faolex/opendata/en/

import pandas as pd

# %%
# http://extwprlegs1.fao.org/docs/pdf/FAOLEX_Agriculture.zip?
# download the data from above link and save 
# enter the correct path and load the dataset

df = pd.read_csv('E:\dataset\FAOLEX_Agriculture.csv')

# %%
# check one entry for Fisheries and Agriculture based on Record Id
df[(df['Record Id']=='LEX-FAOC096511') | (df['Record Id']=='LEX-FAOC022343')].T

# %%
list(df)

# %%
# select necessary columns
imp_col = ['Record Id','Abstract','Title','Type of text','Date of original text','Document URL',
 'Keywords','Country/Territory','Primary subjects','Domain','Repealed','Territorial subdivision']

# %%
# filter the dataframe
df = df[imp_col]

# %%
# new columns to be created based on few key word search
new_col = ['digital innovations','data infrastructure', 'business development',
          'enabling environments for digitalization']

# key words to look for, while creating new columns
key_dict = {'digital innovations':['digital', 'development', 'innovation', 'tech', 'advance', 'advancement'],
            'data infrastructure' :['data', 'development', 'tech', 'info'],
            'business development':['business', 'development', 'growth'],
            'enabling environments for digitalization' : ['enabling', 'enable', 'supporting']}

# %%
# function to search keyword within abstract (text)
def search(keys,text):
    
    # if text is string then it will search the keywords
    if isinstance(text,str):
        return any(key in text for key in keys)
    
    # for few entry there is no abstract i.e NaN, therefore handle it in else case
    else:
        return False
    
for col in new_col:
    df[col] = df['Abstract'].apply(lambda text:'Yes' if search(key_dict[col],text) else 'No')

# %%
df.head()

# %%
# save the dataframe as csv
df.to_csv('Complete_faolex_data.csv')

# %%
df['Document URL']

# %%
d = pd.read_csv('test (6).csv')

# %%
d['Link'][10]

# %%
d

# %% [markdown]
# # URL 2nd TASK PDF DOWNLOAD AND THEN .....

# %%
from bs4 import BeautifulSoup
import urllib3
import os
import requests
import pandas as pd

# %%
df_url = pd.read_csv('URL_added_v1.csv',encoding='ANSI')

# %%
df_url = df_url[df_url['URL'] != "#VALUE!"]

# %%
df_url = df_url[df_url['URL'].apply(lambda x: True if '.pdf' in x else False)]
df_url.reset_index(drop=True,inplace=True)

# %%
df_url['URL'].to_list()
# Out:
# ['http://faolex.fao.org/docs/pdf/aus161858.pdf',
#  'https://www.industry.gov.au/sites/default/files/2018-12/australias-tech-future.pdf',
#  'https://digitaleconomy.pmc.gov.au/sites/default/files/2021-05/digital-economy-strategy.pdf',
#  'https://agriculture.vic.gov.au/__data/assets/pdf_file/0006/567051/Digital-agriculture-strategy-2018.pdf',
#  'https://nff.org.au/wp-content/uploads/2020/02/Farm_Data_Code_Edition_1_WEB_FINAL.pdf',
#  'https://www.centralbankbahamas.com/viewPDF/documents/2020-12-10-21-15-37-2019-06-19-04-04-54-Payment-Instruments-Oversight-Regulations-2017.pdf',
#  'http://laws.bahamas.gov.bs/cms/images/LEGISLATION/PRINCIPAL/2003/2003-0004/ElectronicCommunicationsandTransactionsAct_1.pdf',
#  'http://laws.bahamas.gov.bs/cms/images/LEGISLATION/PRINCIPAL/2003/2003-0002/ComputerMisuseAct_1.pdf',
#  'https://d3n8a8pro7vhmx.cloudfront.net/itsnojoke/pages/94/attachments/original/1492607359/e-business_guide.pdf?1492607359',
# ...

# %%
def pdf_download(url,filename):
    try:
        pdf_loc =  'pdf' + '/' + f'{filename}.pdf'
        s={'Accept': '*/*',
                            'Accept-Language': 'en-US,en;q=0.5',
                            'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:28.0) Gecko/20100101 Firefox/28.0',
                            'X-Requested-With': 'XMLHttpRequest'
                            }
        response = requests.get(url,headers=s)
        if response.status_code==200:
            with open(pdf_loc, 'wb') as f:
                f.write(response.content)
            return True
        else:
            print(f'Error in {filename}: {url}')
            return False
    except:
        print(f'Error in {filename}: {url}')
        return False

# %%
# pdf_download('http://faolex.fao.odocs/pdf/aus161858.pdf')

# %%
error = []
for indx in list(df_url.index):
    url = df_url.iloc[indx]['URL']
    flag = pdf_download(url,indx)
    if flag:
        print(f'file {indx}: {url} downloaded..')
    else:
        error.append(indx)
# Out:
# file 0: http://faolex.fao.org/docs/pdf/aus161858.pdf downloaded..
# file 1: https://www.industry.gov.au/sites/default/files/2018-12/australias-tech-future.pdf downloaded..
# file 2: https://digitaleconomy.pmc.gov.au/sites/default/files/2021-05/digital-economy-strategy.pdf downloaded..
# file 3: https://agriculture.vic.gov.au/__data/assets/pdf_file/0006/567051/Digital-agriculture-strategy-2018.pdf downloaded..
# file 4: https://nff.org.au/wp-content/uploads/2020/02/Farm_Data_Code_Edition_1_WEB_FINAL.pdf downloaded..
# file 5: https://www.centralbankbahamas.com/viewPDF/documents/2020-12-10-21-15-37-2019-06-19-04-04-54-Payment-Instruments-Oversight-Regulations-2017.pdf downloaded..
# Error in 6: http://laws.bahamas.gov.bs/cms/images/LEGISLATION/PRINCIPAL/2003/2003-0004/ElectronicCommunicationsandTransactionsAct_1.pdf
# Error in 7: http://laws.bahamas.gov.bs/cms/images/LEGISLATION/PRINCIPAL/2003/2003-0002/ComputerMisuseAct_1.pdf
# ...

# %%
len(error)
# Out:
# 25

# %%
len(error)
# Out:
# 25

# %%
~df_url.index.isin(error)
# Out:
# array([ True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True, False, False, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
df_processed = df_url.iloc[~df_url.index.isin(error)]

# %%
df_processed = df_processed[['Country/Territory', 'Title', 'Type', 'Link', 'URL']]

# %%
df_processed['PDF_Name'] = [str(i)+'.pdf' for i in list(df_processed.index)]
# Out:
# C:\Users\avitr\AppData\Local\Temp\ipykernel_12776\3204436192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_processed['PDF_Name'] = [str(i)+'.pdf' for i in list(df_processed.index)]

# %%
df_processed = df_processed[:40]

# %%
for word in search_word:
    df_processed[word] = df_processed['PDF_Name'].apply(lambda x: search(x,word))

#  = df_processed['PDF_Name'].apply(lambda x: search(x,'data infrastructure'))
#  = df_processed['PDF_Name'].apply(lambda x: search(x,'business development'))
#  = df_processed['PDF_Name'].apply(lambda x: search(x,'enabling environment'))
#  = df_processed['PDF_Name'].apply(lambda x: search(x,'Data is defined'))
#  = df_processed['PDF_Name'].apply(lambda x: search(x,'Definition of data'))
# Out:
# mupdf: cmsOpenProfileFromMem failed
# C:\Users\avitr\AppData\Local\Temp\ipykernel_12776\3345096752.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_processed[word] = df_processed['PDF_Name'].apply(lambda x: search(x,word))
# mupdf: cmsOpenProfileFromMem failed
# C:\Users\avitr\AppData\Local\Temp\ipykernel_12776\3345096752.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_processed[word] = df_processed['PDF_Name'].apply(lambda x: search(x,word))
# ...

# %%
df_processed
# Out:
#     Country/Territory                                              Title  \
# 0           australia  Australia's Second National Plan of Action to ...
# 1           australia                              Australia Tech Future
# 2           australia                      Digital Economy Strategy 2021
# 3           australia              Digital Agriculture Strategy Victoria
# 4           australia                      Farm Data Code 2020 Edition 1
# 5             bahamas  Payments Instruments (Oversight) Regulations 2...
# 8             bahamas  Connect Your E-Business Strategy To The Bahama...
# 9             bahamas  Five Year Sector Strategy Pan for Fisheries an...
# 10            bahamas  The Bahamas National Pathway for Food Systems\...
# 11         bangladesh  Country Investment Plan - A road map towards i...
# 12         bangladesh                         National Fisheries Policy.
# 13         bangladesh  Medium Term Strategy and Business Plan of the ...
# ...

# %%
import fitz #pymuPDF
import warnings
warnings.filterwarnings('ignore')
search_word = ["digital innovation",
"data infrastructure",
"business development",
"enabling environment",
"Data is defined",
"Definition of data"]

# %%
import re
def search(filename,search_word):
    try:
        
        file = fitz.open(f'pdf/{filename}')
        list_file=[]
        for i in file.pages():
            list_file.append(i.getText())

        for j in range(file.pageCount):
            for i in ['\n','\xa0','\xad']:
                if i in list_file[j]:
                    list_file[j]=list_file[j].replace(i,' ')
        file.close()
        file_str = ''
        for i in list_file:
            file_str = file_str + i

        file_str = file_str.lower().strip()

    #     print(f'************** {filename} ********************')

        phrase_lower = search_word.lower()
        pattern1 = rf'\b{phrase_lower}\b'
        found1 = re.findall(pattern1, file_str)

        phrase_lower_s = phrase_lower+'s'
        pattern2 = rf'\b{phrase_lower_s}\b'
        found2 = re.findall(pattern2, file_str)

        if found2:
            new_phrase = '-'.join(phrase_lower_s.split())
            file_str = file_str.replace(phrase_lower_s,new_phrase)
            x = file_str.split()
            loc = x.index(new_phrase)
            text = ' '.join(x[loc+1: loc+51])
            return text

        elif found1:
            new_phrase = '-'.join(phrase_lower.split())
            file_str = file_str.replace(phrase_lower,new_phrase)
            x = file_str.split()
            loc = x.index(new_phrase)
            text = ' '.join(x[loc+1: loc+51])
            return text
        else:
            return float('NaN')
    except:
        return float('NaN')
        
#         indx = file_str.find(phrase_lower)

#         if indx!=-1:
#             new_phrase = '-'.join(phrase_lower.split())
#             file_str = file_str.replace(phrase_lower,new_phrase)
#             x = file_str.split()
#             loc = x.index(new_phrase)
#             text = ' '.join(x[loc+1: loc+51])
#             return text
#     else:
#         return float('NaN')
        
#     for phrase in search_word:
        
#         phrase_lower = phrase.lower()
#         indx = file_str.find(phrase_lower)
        
#         if indx==-1:
#             return float('NaN')
#         else:
#             new_phrase = '-'.join(phrase_lower.split())
#             file_str = file_str.replace(phrase_lower,new_phrase)
#             x = file_str.split()
#             loc = x.index(new_phrase)
#             text = ' '.join(x[loc+1: loc+51])
#             return text

# %%
search('132.pdf','business developments')
# Out:
# nan

# %%
for i in os.listdir('pdf')[1:][:40]:
    print(search(i))
# Out:
# ************** 0.pdf ********************
# nan
# ************** 1.pdf ********************
# australia’s tech future - 41 cyber security australians feel safe online, the modern economy is protected from cyber security threats and australia is home to a globally competitive cyber security industry. outcomes: • australians have confidence in the ability of our digital infrastructure to stand up to cyber security threats
# ************** 10.pdf ********************
# and entrepreneurship in the agricultural and fisheries sectors. its strategic orientation is guided by the five focus areas below: 1 food import substitution - aim to take advantage of the national market by implementing an import substitution strategy and by linking producers to the tourism industry’s supply chain.9 9 for
# ************** 100.pdf ********************
# nan
# mupdf: cannot recognize xref format
# ************** 101.pdf ********************
# ...

# %%
file = fitz.open("pdf/132.pdf")
list_file=[]
for i in file.pages():
    list_file.append(i.getText())

for j in range(file.pageCount):
    for i in ['\n','\xa0','\xad']:
        if i in list_file[j]:
            list_file[j]=list_file[j].replace(i,' ')
file.close()
file_str = ''
for i in list_file:
    file_str = file_str + i

file_str = file_str.lower().strip()

# %%
for i in search_word:
    phrase_lower = i.lower()
    indx = file_str.find(phrase_lower)
    
    if indx!=-1:
        new_phrase = '-'.join(phrase_lower.split())
        file_str = file_str.replace(phrase_lower,new_phrase)
        x = file_str.split()
        loc = x.index(new_phrase)
        text = ' '.join(x[loc+1: loc+51])
        print(text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [163], in <cell line: 1>()
#       7 file_str = file_str.replace(phrase_lower,new_phrase)
#       8 x = file_str.split()
# ----> 9 loc = x.index(new_phrase)
#      10 text = ' '.join(x[loc+1: loc+51])
#      11 print(text)
#
# ValueError: 'business-development' is not in list

# %%
new_phrase = '-'.join(phrase_lower.split())
file_str = file_str.replace(phrase_lower,new_phrase)
x = file_str.split()
loc = x.index(new_phrase)
text = ' '.join(x[loc+1: loc+51])

# %%
file_str
# Out:
# "the agriculture promotion policy   (2016 – 2020)        building on the successes of the ata, closing key  gaps            policy and strategy document                              2 | p a g e     contents  1.  foreword ........................................................................................................................................ 3  2.  acknowledgement of stakeholders ............................................................................................... 4  3.  executive summary ........................................................................................................................ 5  4.  introduction to the agricultural promotion policy (app) ............................................................. 7  4.1  building on the ata legacy ........................................................................................................ 7  4.2  the buhari administration’s vision and approach ......................................
# ...

# %%
import re
i = 'business developments'
pattern = rf'\b{i}\b'
found1 = re.findall(pattern, file_str)

# %%
i in file_str
# Out:
# False

# %%
file_str.count(i)
# Out:
# 3

# %%
i
# Out:
# 'business developments'

# %%
f"{i+'k'}"
# Out:
# 'business developmentsk'

# %%
i = 'hello'
x = i+'s'
pattern1 = rf'\b{x}\b'
found1 = re.findall(pattern1, s)

# %%
s = 'hellos worlds hello'

# %%
found1
# Out:
# ['hellos']
