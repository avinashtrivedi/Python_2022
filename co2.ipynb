# %%
import pandas as pd
import os

files = [_ for _ in os.listdir('datasets/') if ".csv" in _]

for file in files:
    df = pd.read_csv(f'datasets/{file}', skiprows = 3)
    print(f'Dataset: {file}')
    print('Columns: ' + ", ".join(df.columns))
    print('Indicators: ' + ", ".join(df['Indicator Name'].unique()))
    print('Countries: ' + str(len(df['Country Name'].unique())))
    print("")
# Out:
# Dataset: co2.csv
# Columns: Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, Unnamed: 65
# Indicators: CO2 emissions (kt)
# Countries: 266
#
# Dataset: forest_area.csv
# Columns: Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, Unnamed: 65
# Indicators: Forest area (% of land area)
# Countries: 266
#
# Dataset: freshwater.csv
# Columns: Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, Unnamed: 65
# Indicators: Annual freshwater withdrawals, total (% of internal resources)
# Countries: 266
#
# Dataset: mortality_rate_under5.csv
# Columns: Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, Unnamed: 65
# Indicators: Mortality rate, under-5 (per 1,000 live births)
# Countries: 266
#
# Dataset: renewable_consumption.csv
# Columns: Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, Unnamed: 65
# Indicators: Renewable energy consumption (% of total final energy consumption)
# Countries: 266
#
# Dataset: total_population.csv
# Columns: Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, Unnamed: 65
# Indicators: Population, total
# Countries: 266

# %%
pre_path = 'datasets/'
co2_df = pd.read_csv(pre_path + files[0], skiprows = 3)
forest_area_df = pd.read_csv(pre_path + files[1], skiprows = 3)
freshwater_df = pd.read_csv(pre_path + files[2], skiprows = 3)
mortality_rate_under5_df = pd.read_csv(pre_path + files[3], skiprows = 3)
renewable_consumption_df = pd.read_csv(pre_path + files[4], skiprows = 3)
total_population_df = pd.read_csv(pre_path + files[5], skiprows = 3)

# %%
co2_df = co2_df[[_ for _ in co2_df.columns if "Code" not in _]]
forest_area_df = forest_area_df[[_ for _ in forest_area_df.columns if "Code" not in _]]
freshwater_df = freshwater_df[[_ for _ in freshwater_df.columns if "Code" not in _]]
mortality_rate_under5_df = mortality_rate_under5_df[[_ for _ in mortality_rate_under5_df.columns if "Code" not in _]]
renewable_consumption_df = renewable_consumption_df[[_ for _ in renewable_consumption_df.columns if "Code" not in _]]
total_population_df = total_population_df[[_ for _ in total_population_df.columns if "Code" not in _]]

# %%
col = ['Country Name',
 '1960',
 '1961',
 '1962',
 '1963',
 '1964',
 '1965',
 '1966',
 '1967',
 '1968',
 '1969',
 '1970',
 '1971',
 '1972',
 '1973',
 '1974',
 '1975',
 '1976',
 '1977',
 '1978',
 '1979',
 '1980',
 '1981',
 '1982',
 '1983',
 '1984',
 '1985',
 '1986',
 '1987',
 '1988',
 '1989',
 '1990',
 '1991',
 '1992',
 '1993',
 '1994',
 '1995',
 '1996',
 '1997',
 '1998',
 '1999',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018']

# %%
co2 = co2_df[col].dropna()

# %%
forest_area_df[col]
# Out:
#                     Country Name  1960  1961  1962  1963  1964  1965  1966  \
# 0                          Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                    Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     Africa Western and Central   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                         Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..                           ...   ...   ...   ...   ...   ...   ...   ...
# 261                       Kosovo   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263                 South Africa   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1967  1968  ...       2009       2010       2011       2012       2013  \
# 0     NaN   NaN  ...   2.333333   2.333333   2.333333   2.333333   2.333333
# 1     NaN   NaN  ...  36.906596  31.910878  32.183135  31.972492  31.761842
# 2     NaN   NaN  ...   1.850994   1.850994   1.850994   1.850994   1.850994
# 3     NaN   NaN  ...  20.766139  20.674012  20.586055  20.498099  20.410143
# 4     NaN   NaN  ...  58.324425  57.879201  57.433976  56.988751  56.543526
# ..    ...   ...  ...        ...        ...        ...        ...        ...
# 261   NaN   NaN  ...        NaN        NaN        NaN        NaN        NaN
# 262   NaN   NaN  ...   1.039832   1.039832   1.039832   1.039832   1.039832
# 263   NaN   NaN  ...  14.385157  14.355151  14.325145  14.295139  14.265133
# 264   NaN   NaN  ...  62.863100  62.814942  62.561805  62.308667  62.055529
# 265   NaN   NaN  ...  46.403903  46.284813  46.165723  46.046633  45.927543
#
#           2014       2015       2016       2017       2018
# 0     2.333333   2.333333   2.333333   2.333333   2.333333
# 1    31.551270  31.340526  31.119431  30.903543  30.690224
# 2     1.850994   1.850994   1.850994   1.850994   1.850994
# 3    20.322187  20.234231  20.152610  20.071327  19.986100
# 4    56.098301  55.653076  55.207845  54.762629  54.317406
# ..         ...        ...        ...        ...        ...
# 261        NaN        NaN        NaN        NaN        NaN
# 262   1.039832   1.039832   1.039832   1.039832   1.039832
# 263  14.235127  14.205121  14.175115  14.145109  14.115103
# 264  61.802392  61.549254  61.295955  61.042885  60.789707
# 265  45.808453  45.689363  45.570273  45.451183  45.332093
#
# [266 rows x 60 columns]

# %%
x = forest_area_df.isna().sum()

# %%
col1  = ['Country Name','1990',
 '1991',
 '1992',
 '1993',
 '1994',
 '1995',
 '1996',
 '1997',
 '1998',
 '1999',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018']

# %%
for i,j in zip(x,x.index):
    print(j,'--',i)
# Out:
# Country Name -- 0
# Indicator Name -- 0
# 1960 -- 266
# 1961 -- 266
# 1962 -- 266
# 1963 -- 266
# 1964 -- 266
# 1965 -- 266
# 1966 -- 266
# 1967 -- 266
# 1968 -- 266
# 1969 -- 266
# 1970 -- 266
# 1971 -- 266
# 1972 -- 266
# 1973 -- 266
# 1974 -- 266
# 1975 -- 266
# 1976 -- 266
# 1977 -- 266
# 1978 -- 266
# 1979 -- 266
# 1980 -- 266
# 1981 -- 266
# 1982 -- 266
# 1983 -- 266
# 1984 -- 266
# 1985 -- 266
# 1986 -- 266
# 1987 -- 266
# 1988 -- 266
# 1989 -- 266
# 1990 -- 13
# 1991 -- 9
# 1992 -- 9
# 1993 -- 9
# 1994 -- 9
# 1995 -- 9
# 1996 -- 9
# 1997 -- 9
# 1998 -- 9
# 1999 -- 9
# 2000 -- 5
# 2001 -- 8
# 2002 -- 8
# 2003 -- 8
# 2004 -- 8
# 2005 -- 8
# 2006 -- 8
# 2007 -- 8
# 2008 -- 8
# 2009 -- 8
# 2010 -- 5
# 2011 -- 4
# 2012 -- 4
# 2013 -- 4
# 2014 -- 4
# 2015 -- 4
# 2016 -- 4
# 2017 -- 5
# 2018 -- 5
# 2019 -- 9
# 2020 -- 9
# Unnamed: 65 -- 266

# %%
fa = forest_area_df[col1].dropna()

# %%
fa
# Out:
#                     Country Name       1990       1991       1992       1993  \
# 0                          Aruba   2.333333   2.333333   2.333333   2.333333
# 1    Africa Eastern and Southern  40.565912  40.403946  40.235807  40.269690
# 2                    Afghanistan   1.850994   1.850994   1.850994   1.850994
# 3     Africa Western and Central  22.776908  22.658746  22.540583  22.422421
# 4                         Angola  63.578070  63.453407  63.328745  63.204082
# ..                           ...        ...        ...        ...        ...
# 260                        Samoa  62.236749  62.066431  61.896113  61.725795
# 262                  Yemen, Rep.   1.039832   1.039832   1.039832   1.039832
# 263                 South Africa  14.955271  14.925265  14.895259  14.865253
# 264                       Zambia  63.778098  63.729940  63.681782  63.633624
# 265                     Zimbabwe  48.666615  48.547525  48.428435  48.309345
#
#           1994       1995       1996       1997       1998  ...       2009  \
# 0     2.333333   2.333333   2.333333   2.333333   2.333333  ...   2.333333
# 1    40.103270  39.936851  39.770431  39.604012  39.437592  ...  36.906596
# 2     1.850994   1.850994   1.850994   1.850994   1.850994  ...   1.850994
# 3    22.304258  22.186096  22.067933  21.949771  21.831608  ...  20.766139
# 4    63.079419  62.954757  62.830094  62.705431  62.580768  ...  58.324425
# ..         ...        ...        ...        ...        ...  ...        ...
# 260  61.555477  61.385159  61.214841  61.044523  60.874205  ...  59.000707
# 262   1.039832   1.039832   1.039832   1.039832   1.039832  ...   1.039832
# 263  14.835247  14.805241  14.775235  14.745229  14.715223  ...  14.385157
# 264  63.585467  63.537309  63.489151  63.440993  63.392836  ...  62.863100
# 265  48.190255  48.071165  47.952074  47.832984  47.713894  ...  46.403903
#
#           2010       2011       2012       2013       2014       2015  \
# 0     2.333333   2.333333   2.333333   2.333333   2.333333   2.333333
# 1    31.910878  32.183135  31.972492  31.761842  31.551270  31.340526
# 2     1.850994   1.850994   1.850994   1.850994   1.850994   1.850994
# 3    20.674012  20.586055  20.498099  20.410143  20.322187  20.234231
# 4    57.879201  57.433976  56.988751  56.543526  56.098301  55.653076
# ..         ...        ...        ...        ...        ...        ...
# 260  58.830389  58.659364  58.488339  58.317314  58.146290  57.975265
# 262   1.039832   1.039832   1.039832   1.039832   1.039832   1.039832
# 263  14.355151  14.325145  14.295139  14.265133  14.235127  14.205121
# 264  62.814942  62.561805  62.308667  62.055529  61.802392  61.549254
# 265  46.284813  46.165723  46.046633  45.927543  45.808453  45.689363
#
#           2016       2017       2018
# 0     2.333333   2.333333   2.333333
# 1    31.119431  30.903543  30.690224
# 2     1.850994   1.850994   1.850994
# 3    20.152610  20.071327  19.986100
# 4    55.207845  54.762629  54.317406
# ..         ...        ...        ...
# 260  57.805654  57.636042  57.466431
# 262   1.039832   1.039832   1.039832
# 263  14.175115  14.145109  14.115103
# 264  61.295955  61.042885  60.789707
# 265  45.570273  45.451183  45.332093
#
# [252 rows x 30 columns]

# %%
co2 = co2[col1]

# %%
fa[fa['Country Name'].isin(list(co2['Country Name']))]
# Out:
#                     Country Name       1990       1991       1992       1993  \
# 1    Africa Eastern and Southern  40.565912  40.403946  40.235807  40.269690
# 2                    Afghanistan   1.850994   1.850994   1.850994   1.850994
# 3     Africa Western and Central  22.776908  22.658746  22.540583  22.422421
# 4                         Angola  63.578070  63.453407  63.328745  63.204082
# 5                        Albania  28.788321  28.717153  28.645985  28.574818
# ..                           ...        ...        ...        ...        ...
# 254                Venezuela, RB  58.983051  58.657106  58.331160  58.005215
# 257                      Vietnam  28.805678  29.545528  30.285379  31.025230
# 260                        Samoa  62.236749  62.066431  61.896113  61.725795
# 262                  Yemen, Rep.   1.039832   1.039832   1.039832   1.039832
# 263                 South Africa  14.955271  14.925265  14.895259  14.865253
#
#           1994       1995       1996       1997       1998  ...       2009  \
# 1    40.103270  39.936851  39.770431  39.604012  39.437592  ...  36.906596
# 2     1.850994   1.850994   1.850994   1.850994   1.850994  ...   1.850994
# 3    22.304258  22.186096  22.067933  21.949771  21.831608  ...  20.766139
# 4    63.079419  62.954757  62.830094  62.705431  62.580768  ...  58.324425
# 5    28.503650  28.432482  28.361314  28.290146  28.218978  ...  28.496095
# ..         ...        ...        ...        ...        ...  ...        ...
# 254  57.679270  57.353325  57.027379  56.701434  56.375489  ...  54.044102
# 257  31.765080  32.504931  33.244782  33.984632  34.724483  ...  42.660251
# 260  61.555477  61.385159  61.214841  61.044523  60.874205  ...  59.000707
# 262   1.039832   1.039832   1.039832   1.039832   1.039832  ...   1.039832
# 263  14.835247  14.805241  14.775235  14.745229  14.715223  ...  14.385157
#
#           2010       2011       2012       2013       2014       2015  \
# 1    31.910878  32.183135  31.972492  31.761842  31.551270  31.340526
# 2     1.850994   1.850994   1.850994   1.850994   1.850994   1.850994
# 3    20.674012  20.586055  20.498099  20.410143  20.322187  20.234231
# 4    57.879201  57.433976  56.988751  56.543526  56.098301  55.653076
# 5    28.542701  28.594653  28.646606  28.698558  28.750511  28.802464
# ..         ...        ...        ...        ...        ...        ...
# 254  53.857491  53.671107  53.484723  53.298339  53.111955  52.925571
# 257  43.177541  43.612152  44.046764  44.481375  44.915987  45.350598
# 260  58.830389  58.659364  58.488339  58.317314  58.146290  57.975265
# 262   1.039832   1.039832   1.039832   1.039832   1.039832   1.039832
# 263  14.355151  14.325145  14.295139  14.265133  14.235127  14.205121
#
#           2016       2017       2018
# 1    31.119431  30.903543  30.690224
# 2     1.850994   1.850994   1.850994
# 3    20.152610  20.071327  19.986100
# 4    55.207845  54.762629  54.317406
# 5    28.802190  28.792062  28.791971
# ..         ...        ...        ...
# 254  52.767145  52.636676  52.534165
# 257  46.369142  46.490760  46.735544
# 260  57.805654  57.636042  57.466431
# 262   1.039832   1.039832   1.039832
# 263  14.175115  14.145109  14.115103
#
# [188 rows x 30 columns]

# %%
list(co2['Country Name'])
# Out:
# ['Africa Eastern and Southern',
#  'Afghanistan',
#  'Africa Western and Central',
#  'Angola',
#  'Albania',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Belize',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Cyprus',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'East Asia & Pacific (excluding high income)',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'Spain',
#  'Ethiopia',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Finland',
#  'Fiji',
#  'France',
#  'Gabon',
#  'United Kingdom',
#  'Ghana',
#  'Guinea',
#  'Gambia, The',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guyana',
#  'High income',
#  'Honduras',
#  'Heavily indebted poor countries (HIPC)',
#  'Haiti',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA total',
#  'IDA blend',
#  'Indonesia',
#  'IDA only',
#  'India',
#  'Ireland',
#  'Iran, Islamic Rep.',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kenya',
#  'Cambodia',
#  'St. Kitts and Nevis',
#  'Korea, Rep.',
#  'Kuwait',
#  'Latin America & Caribbean (excluding high income)',
#  'Lao PDR',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'St. Lucia',
#  'Latin America & Caribbean',
#  'Least developed countries: UN classification',
#  'Low income',
#  'Sri Lanka',
#  'Lower middle income',
#  'Low & middle income',
#  'Late-demographic dividend',
#  'Luxembourg',
#  'Morocco',
#  'Madagascar',
#  'Middle East & North Africa',
#  'Mexico',
#  'Middle income',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Middle East & North Africa (excluding high income)',
#  'Mongolia',
#  'Mozambique',
#  'Mauritania',
#  'Mauritius',
#  'Malaysia',
#  'North America',
#  'Niger',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'New Zealand',
#  'OECD members',
#  'Other small states',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Palau',
#  'Papua New Guinea',
#  'Poland',
#  'Pre-demographic dividend',
#  "Korea, Dem. People's Rep.",
#  'Portugal',
#  'Paraguay',
#  'Pacific island small states',
#  'Post-demographic dividend',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'South Asia',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'Somalia',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sub-Saharan Africa',
#  'Small states',
#  'Sao Tome and Principe',
#  'Suriname',
#  'Sweden',
#  'Syrian Arab Republic',
#  'Chad',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Togo',
#  'Thailand',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Tonga',
#  'South Asia (IDA & IBRD)',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Tanzania',
#  'Uganda',
#  'Upper middle income',
#  'Uruguay',
#  'United States',
#  'St. Vincent and the Grenadines',
#  'Venezuela, RB',
#  'Vietnam',
#  'World',
#  'Samoa',
#  'Yemen, Rep.',
#  'South Africa']

# %%
x = fa[fa['Country Name']=='Afghanistan']

# %%
y = co2[co2['Country Name']=='Afghanistan']

# %%
x.loc[2][1:].values
# Out:
# array([1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323], dtype=object)

# %%
y.loc[2][1:].values
# Out:
# array([2960.0, 2740.0, 1430.0, 1360.0, 1300.0, 1250.0, 1180.0, 1100.0,
#        1050.0, 820.0, 770.0, 810.0, 1100.0, 1350.0, 1130.0, 1640.0,
#        1940.0, 2360.0, 4390.0, 6000.0, 8670.0, 12260.0, 10450.0, 8510.0,
#        7810.0, 7990.0, 7390.0, 7380.0, 7440.0], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(list(range(len(x.loc[2][1:].values))),x.loc[2][1:].values,color='red',label='forest')
plt.plot(list(range(len(y.loc[2][1:].values))),y.loc[2][1:].values,color='green',label='co2')
plt.legend()
plt.show()

# %%
x.loc[2][1:].values
# Out:
# array([1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323, 1.85099408755323,
#        1.85099408755323, 1.85099408755323], dtype=object)

# %%
fa
# Out:
#                     Country Name       1990       1991       1992       1993  \
# 0                          Aruba   2.333333   2.333333   2.333333   2.333333
# 1    Africa Eastern and Southern  40.565912  40.403946  40.235807  40.269690
# 2                    Afghanistan   1.850994   1.850994   1.850994   1.850994
# 3     Africa Western and Central  22.776908  22.658746  22.540583  22.422421
# 4                         Angola  63.578070  63.453407  63.328745  63.204082
# ..                           ...        ...        ...        ...        ...
# 260                        Samoa  62.236749  62.066431  61.896113  61.725795
# 262                  Yemen, Rep.   1.039832   1.039832   1.039832   1.039832
# 263                 South Africa  14.955271  14.925265  14.895259  14.865253
# 264                       Zambia  63.778098  63.729940  63.681782  63.633624
# 265                     Zimbabwe  48.666615  48.547525  48.428435  48.309345
#
#           1994       1995       1996       1997       1998  ...       2009  \
# 0     2.333333   2.333333   2.333333   2.333333   2.333333  ...   2.333333
# 1    40.103270  39.936851  39.770431  39.604012  39.437592  ...  36.906596
# 2     1.850994   1.850994   1.850994   1.850994   1.850994  ...   1.850994
# 3    22.304258  22.186096  22.067933  21.949771  21.831608  ...  20.766139
# 4    63.079419  62.954757  62.830094  62.705431  62.580768  ...  58.324425
# ..         ...        ...        ...        ...        ...  ...        ...
# 260  61.555477  61.385159  61.214841  61.044523  60.874205  ...  59.000707
# 262   1.039832   1.039832   1.039832   1.039832   1.039832  ...   1.039832
# 263  14.835247  14.805241  14.775235  14.745229  14.715223  ...  14.385157
# 264  63.585467  63.537309  63.489151  63.440993  63.392836  ...  62.863100
# 265  48.190255  48.071165  47.952074  47.832984  47.713894  ...  46.403903
#
#           2010       2011       2012       2013       2014       2015  \
# 0     2.333333   2.333333   2.333333   2.333333   2.333333   2.333333
# 1    31.910878  32.183135  31.972492  31.761842  31.551270  31.340526
# 2     1.850994   1.850994   1.850994   1.850994   1.850994   1.850994
# 3    20.674012  20.586055  20.498099  20.410143  20.322187  20.234231
# 4    57.879201  57.433976  56.988751  56.543526  56.098301  55.653076
# ..         ...        ...        ...        ...        ...        ...
# 260  58.830389  58.659364  58.488339  58.317314  58.146290  57.975265
# 262   1.039832   1.039832   1.039832   1.039832   1.039832   1.039832
# 263  14.355151  14.325145  14.295139  14.265133  14.235127  14.205121
# 264  62.814942  62.561805  62.308667  62.055529  61.802392  61.549254
# 265  46.284813  46.165723  46.046633  45.927543  45.808453  45.689363
#
#           2016       2017       2018
# 0     2.333333   2.333333   2.333333
# 1    31.119431  30.903543  30.690224
# 2     1.850994   1.850994   1.850994
# 3    20.152610  20.071327  19.986100
# 4    55.207845  54.762629  54.317406
# ..         ...        ...        ...
# 260  57.805654  57.636042  57.466431
# 262   1.039832   1.039832   1.039832
# 263  14.175115  14.145109  14.115103
# 264  61.295955  61.042885  60.789707
# 265  45.570273  45.451183  45.332093
#
# [252 rows x 30 columns]

# %%
fa[list(fa)[1:]].mean(axis=1)
# Out:
# 0       2.333333
# 1      36.466950
# 2       1.850994
# 3      21.282540
# 4      59.942584
#          ...
# 260    59.851712
# 262     1.039832
# 263    14.535187
# 264    62.849418
# 265    46.999354
# Length: 252, dtype: float64

# %%
co2
# Out:
#                     Country Name          1990          1991          1992  \
# 1    Africa Eastern and Southern  3.099808e+05  3.044077e+05  3.003300e+05
# 2                    Afghanistan  2.960000e+03  2.740000e+03  1.430000e+03
# 3     Africa Western and Central  9.021000e+04  9.988000e+04  1.115900e+05
# 4                         Angola  6.330000e+03  6.530000e+03  6.370000e+03
# 5                        Albania  6.050000e+03  4.110000e+03  2.240000e+03
# ..                           ...           ...           ...           ...
# 257                      Vietnam  1.841000e+04  1.831000e+04  1.931000e+04
# 259                        World  2.060783e+07  2.079934e+07  2.074166e+07
# 260                        Samoa  1.100000e+02  1.100000e+02  1.200000e+02
# 262                  Yemen, Rep.  6.640000e+03  8.500000e+03  9.130000e+03
# 263                 South Africa  2.476600e+05  2.423300e+05  2.388200e+05
#
#              1993          1994          1995          1996          1997  \
# 1    3.065746e+05  3.126770e+05  3.308930e+05  3.414124e+05  3.579631e+05
# 2    1.360000e+03  1.300000e+03  1.250000e+03  1.180000e+03  1.100000e+03
# 3    1.150800e+05  1.122200e+05  1.139800e+05  1.218900e+05  1.204500e+05
# 4    6.900000e+03  6.690000e+03  1.078000e+04  1.141000e+04  1.173000e+04
# 5    2.070000e+03  2.140000e+03  1.950000e+03  1.970000e+03  1.480000e+03
# ..            ...           ...           ...           ...           ...
# 257  2.425000e+04  2.675000e+04  3.032000e+04  3.417000e+04  4.014000e+04
# 259  2.087411e+07  2.098379e+07  2.158284e+07  2.203945e+07  2.239405e+07
# 260  1.200000e+02  1.200000e+02  1.200000e+02  1.300000e+02  1.300000e+02
# 262  8.120000e+03  8.480000e+03  9.870000e+03  1.008000e+04  1.085000e+04
# 263  2.464300e+05  2.520100e+05  2.641900e+05  2.739800e+05  2.889200e+05
#
#              1998  ...          2009          2010          2011  \
# 1    3.666345e+05  ...  5.156825e+05  5.438087e+05  5.356044e+05
# 2    1.050000e+03  ...  6.000000e+03  8.670000e+03  1.226000e+04
# 3    1.169300e+05  ...  1.455500e+05  1.657500e+05  1.790700e+05
# 4    1.137000e+04  ...  2.715000e+04  2.853000e+04  2.946000e+04
# 5    1.800000e+03  ...  4.320000e+03  4.580000e+03  5.040000e+03
# ..            ...  ...           ...           ...           ...
# 257  4.487000e+04  ...  1.317200e+05  1.494400e+05  1.490200e+05
# 259  2.250978e+07  ...  2.925376e+07  3.103180e+07  3.200403e+07
# 260  1.400000e+02  ...  1.900000e+02  1.900000e+02  2.000000e+02
# 262  1.173000e+04  ...  2.565000e+04  2.399000e+04  2.069000e+04
# 263  2.965100e+05  ...  4.040200e+05  4.251100e+05  4.091200e+05
#
#              2012          2013          2014          2015          2016  \
# 1    5.593339e+05  5.805109e+05  6.018602e+05  5.863850e+05  5.922996e+05
# 2    1.045000e+04  8.510000e+03  7.810000e+03  7.990000e+03  7.390000e+03
# 3    1.817400e+05  1.919900e+05  1.984400e+05  1.930600e+05  1.951200e+05
# 4    3.025000e+04  3.282000e+04  3.463000e+04  3.516000e+04  3.541000e+04
# 5    4.580000e+03  4.790000e+03  5.220000e+03  5.070000e+03  4.930000e+03
# ..            ...           ...           ...           ...           ...
# 257  1.472700e+05  1.536300e+05  1.685600e+05  2.092000e+05  2.238700e+05
# 259  3.244419e+07  3.305385e+07  3.308519e+07  3.294343e+07  3.294065e+07
# 260  2.000000e+02  2.000000e+02  2.100000e+02  2.400000e+02  3.000000e+02
# 262  1.968000e+04  2.635000e+04  2.671000e+04  1.421000e+04  1.088000e+04
# 263  4.267100e+05  4.368700e+05  4.479800e+05  4.248800e+05  4.251800e+05
#
#              2017          2018
# 1    6.013234e+05  6.003511e+05
# 2    7.380000e+03  7.440000e+03
# 3    2.019000e+05  2.243800e+05
# 4    3.084000e+04  2.734000e+04
# 5    5.600000e+03  5.560000e+03
# ..            ...           ...
# 257  2.221300e+05  2.578600e+05
# 259  3.335161e+07  3.404105e+07
# 260  3.000000e+02  3.200000e+02
# 262  1.006000e+04  9.310000e+03
# 263  4.351400e+05  4.332500e+05
#
# [192 rows x 30 columns]

# %%
set1 = set(co2['Country Name'])

# %%
set2 = set(fa['Country Name'])

# %%
common = list(set1.intersection(set2))

# %%
fa = fa[fa['Country Name'].isin(common)]
co2 = co2[co2['Country Name'].isin(common)]

# %%
y1 = fa[list(fa)[1:]].mean(axis=1)[:20]
y2 = co2[list(co2)[1:]].mean(axis=1)[:20]

# %%
y2
# Out:
# 1     4.498348e+05
# 2     3.951034e+03
# 3     1.475493e+05
# 4     1.950586e+04
# 5     3.845517e+03
# 7     1.200067e+06
# 8     1.226493e+05
# 9     1.456383e+05
# 12    4.303448e+02
# 13    3.452714e+05
# 14    6.575517e+04
# 17    1.073159e+05
# 18    3.159655e+03
# 19    1.677586e+03
# 20    3.700690e+04
# 21    4.891276e+04
# 22    2.046448e+04
# 23    2.368621e+03
# 26    5.431034e+02
# 28    1.219586e+04
# dtype: float64

# %%
# importing package
import matplotlib.pyplot as plt

# create data
x = common[:20]
plt.figure(figsize=(10,5))
# plot bars in stack manner
plt.bar(x, y1, color='r')
plt.bar(x, y2, bottom=y1, color='b')
# plt.plot(list(range(len(y1))),y1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(list(range(len(y1))),y1)
